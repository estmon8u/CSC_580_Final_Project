# %% [markdown]
# # Tiny Dreamer Highway — Final Run
#
# **Name:** Esteban Montelongo | **Course:** CSC 580 AI 2 | **Assignment:** Final Project — Dream the Road | **AI tools:** GitHub Copilot
#
# ---
#
# This notebook trains and evaluates a **DreamerV1** continuous-control agent on `highway-v0`.
#
# DreamerV1 separates world-model learning from policy learning: the RSSM (Recurrent State-Space Model) learns a compressed latent representation of the environment from pixel observations, then the actor-critic is trained entirely inside imagined latent rollouts — never touching the real environment during policy updates. See the project report for full algorithm derivations.
#
# ## Experiment Design
#
# | Phase | Environment | Config | Purpose |
# |-------|-------------|--------|---------|
# | **A — training** | 4 lanes, 28 cars | `final_run.yaml` | Learn a speed-maximising continuous-control policy |
# | **B — showcase** | 6 lanes, 45 cars | `final_showcase_eval.yaml` | Evaluate trained weights in denser, wider traffic |
#
# **Sections:** Setup → Config → Training → Training curves → N-step prediction eval → Driving demos → Submission bundle

# %% [markdown]
# ## 1 · Environment Setup
#
# Mount Drive for artifact persistence (Colab VMs are ephemeral — everything under `/content/` is lost on disconnect), then clone/update the repo and install the package in editable mode so imports resolve from source.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)

print('Drive root:', DRIVE_ROOT)
print('Artifact root:', ARTIFACT_ROOT)
# Out:
# Mounted at /content/drive
# Drive root: /content/drive/MyDrive/CSC_580_Final_Project
# Artifact root: /content/drive/MyDrive/CSC_580_Final_Project/artifacts

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='GrandpaDrivers'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is behind 'origin/GrandpaDrivers' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# Updating faa9926..d4df7b5
# Fast-forward
#  examples/final_showcase_eval.yaml |    6 +-
#  notebooks/08_final_run.ipynb      | 4257 +++++++++++++++++++++++++++----------
#  2 files changed, 3163 insertions(+), 1100 deletions(-)
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD
#    faa9926..d4df7b5  GrandpaDrivers -> origin/GrandpaDrivers
# Already on 'GrandpaDrivers'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD

# %% [markdown]
# ## 2 · Experiment Configuration
#
# Key choices in `final_run.yaml` and their rationale:
#
# | Setting | Value | Why |
# |---------|-------|-----|
# | `lanes_count` | 4 | Project requirement (minimum 4) |
# | `vehicles_count` | 28 | Moderately hard — enough traffic to require overtaking without overwhelming random resets during warm-start |
# | `high_speed_reward` | 0.8 | Stronger speed signal than 0.7, enough to make passive following less attractive without touching steering stability |
# | `right_lane_reward` | 0.0 | Zero — any positive value creates a degenerate "lane-hugger" policy that ignores speed |
# | `reward_speed_range` | [22, 35] | Raises the minimum rewarded speed so cruising behind slower traffic earns less reward |
# | `steering_penalty` | 0.0075 | Slightly lower than baseline, but not so low that lane changes become twitchy |
# | `steering_change_penalty` | 0.02 | Reduced more conservatively to allow overtaking without inviting oscillation |
# | `max_episode_steps` | 75 | Extended from 50 — gives the agent more runway to build speed after a lane change |
# | `imagination_horizon` | 20 | Long enough for multi-step lane-change credit assignment; beyond ~25 steps RSSM drift degrades λ-return estimates |
# | `free_nats` | 3.0 | Prevents posterior collapse early in training by ignoring KL below this threshold |
# | `use_amp` / `bfloat16` | true | H100 tensor-core throughput; bfloat16 preserves fp32 exponent range, safe for KL spikes |
# | `batch_size` / updates | 256 / 16 | Large batches keep world-model and behavior updates stable on H100 hardware |

# %%
import json
import sys
import torch
from pathlib import

 Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

# Phase-A training config — tuned for aggressive, fast continuous control
CONFIG_PATH = PROJECT_ROOT / 'examples' / 'final_run.yaml'
config = load_experiment_config(CONFIG_PATH)

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)
if 'H100' not in gpu_name:
    print('Note: config is optimised for H100 but will run on any CUDA device.')

print('\n--- Environment ---')
print('Action type:', config.env.action.type)
print('Lanes count:', config.env.lanes_count)
print('Vehicles count:', config.env.vehicles_count)
print('Max episode steps:', config.env.max_episode_steps)

print('\n--- Reward shaping ---')
print('high_speed_reward:', config.env.reward.high_speed_reward)
print('right_lane_reward:', config.env.reward.right_lane_reward)
print('reward_speed_range:', config.env.reward.reward_speed_range)
print('offroad_terminal:', config.env.reward.offroad_terminal)

print('\n--- Training knobs ---')
print('grad_clip_norm:', config.training.grad_clip_norm)
print('lr_warmup_steps:', config.training.lr_warmup_steps)
print('use_amp:', config.training.use_amp, f'({config.training.amp_dtype})')
print('batch_size:', config.training.batch_size)
print('world_model_updates_per_cycle:', config.training.world_model_updates_per_cycle)
print('behavior_updates_per_cycle:', config.training.behavior_updates_per_cycle)
# Out:
# Loaded config from: /content/CSC_580_Final_Project/examples/final_run.yaml
# GPU: NVIDIA A100-SXM4-80GB
# Note: config is optimised for H100 but will run on any CUDA device.
#
# --- Environment ---
# Action type: continuous
# Lanes count: 4
# Vehicles count: 28
# Max episode steps: 50
#
# --- Reward shaping ---
# high_speed_reward: 0.5
# right_lane_reward: 0.0
# reward_speed_range: (20.0, 30.0)
# offroad_terminal: True
#
# --- Training knobs ---
# grad_clip_norm: 100.0
# lr_warmup_steps: 0
# use_amp: False (bfloat16)
# use_flash_optimizer: False
# batch_size: 256
# world_model_updates_per_cycle: 8
# behavior_updates_per_cycle: 8
#
# FlashAdamW: not installed — will fall back to AdamW

# %% [markdown]
# ## 3 · Training
#
# `run_training_experiment` drives the outer loop. Each *cycle* runs:
# 1. **World model update** (`world_model_updates_per_cycle` gradient steps) — sample sequences from the replay buffer, compute the ELBO (reconstruction + KL + reward + continue losses), update encoder/RSSM/decoder weights.
# 2. **Behavior update** (`behavior_updates_per_cycle` gradient steps) — imagine `imagination_horizon` steps via the RSSM prior, build λ-return targets, update actor and critic.
# 3. **Environment collection** (`policy_steps` real env steps) — run the trained actor, add new transitions to the replay buffer.
#
# `warm_start_steps` pre-fills the replay buffer with random transitions before any gradient updates begin. `RESUME_FROM = None` starts fresh; set it to a checkpoint path to continue an interrupted run.

# %%
RUN_NAME = 'final_run_001'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

# Use None to take values from the YAML; override to shorten without editing config.
CYCLES              = None   # None → YAML default (2000)
WARM_START_STEPS    = None   # None → YAML default (10000)
POLICY_STEPS        = None   # None → YAML default (64)
CHECKPOINT_INTERVAL = None   # None → YAML default (25)

# Always start fresh for the first post-fix run — checkpoints now store richer
# replay and scheduler state that must be rebuilt from scratch.
RESUME_FROM = None

print('Run name:', RUN_NAME)
print('Artifact root:', RUN_ARTIFACT_ROOT)
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective warm-start steps:',
      config.training.warm_start_steps if WARM_START_STEPS is None else WARM_START_STEPS)
print('Sequence length:', config.replay.sequence_length)
print('Replay capacity:', config.replay.capacity)
# Out:
# Run name: final_run_001
# Artifact root: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001
# Effective cycles: 2000
# Effective warm-start steps: 10000
# Sequence length: 16
# Replay capacity: 500000

# %% [markdown]
# ### Launch
#
# Override any YAML default by setting the variable to a non-`None` value. The training loop prints one line per cycle with current losses and evaluation reward. Full derivations of the ELBO objective, λ-returns, and overshooting regularisation are in the project report.

# %%
print('Launching Phase-A final continuous-control run.')
print('Environment: 4 lanes, 28 cars — reward-tuned for speed and overtaking.')
print('Per-cycle progress lines will appear below.\n')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('\nCompleted cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching Phase-A final continuous-control run.
# Environment: 4 lanes, 28 cars — reward-tuned for speed and overtaking.
# Per-cycle progress lines will appear below.
#
# [train] starting run | cycles=2000 | start_step=1 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1/2000 | warm=10000 | policy=32 | replay=10032 | world_total=5313.9733 | actor=-1.9431 | critic=2.7234 | eval_reward=n/a | cycle_s=601.2 | elapsed_s=601.2 | checkpoint=-
# [train] step=2/2000 | warm=0 | policy=32 | replay=10064 | world_total=4004.1777 | actor=-5.9479 | critic=14.2073 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=607.1 | checkpoint=-
# [train] step=3/2000 | warm=0 | policy=32 | replay=10096 | world_total=3911.9569 | actor=-7.6522 | critic=19.1343 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=613.4 | checkpoint=-
# [train] step=4/2000 | warm=0 | policy=32 | replay=10128 | world_total=3871.2385 | actor=-10.8705 | critic=35.9467 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=618.9 | checkpoint=-
# [train] step=5/2000 | warm=0 | policy=32 | replay=10160 | world_total=3844.9211 | actor=-11.1017 | critic=19.9799 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=624.9 | checkpoint=-
# [train] step=6/2000 | warm=0 | policy=32 | replay=10192 | world_total=3832.5099 | actor=-14.4770 | critic=24.3183 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=630.9 | checkpoint=-
# [train] step=7/2000 | warm=0 | policy=32 | replay=10224 | world_total=3829.2550 | actor=-16.3219 | critic=23.0895 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=636.3 | checkpoint=-
# [train] step=8/2000 | warm=0 | policy=32 | replay=10256 | world_total=3826.7921 | actor=-17.4655 | critic=16.0806 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=642.4 | checkpoint=-
# [train] step=9/2000 | warm=0 | policy=32 | replay=10288 | world_total=3826.0935 | actor=-17.9088 | critic=7.2083 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=648.6 | checkpoint=-
# [train] step=10/2000 | warm=0 | policy=32 | replay=10320 | world_total=3824.4141 | actor=-20.4277 | critic=7.5340 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=654.6 | checkpoint=-
# [train] step=11/2000 | warm=0 | policy=32 | replay=10352 | world_total=3822.9849 | actor=-26.2530 | critic=24.4235 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=660.6 | checkpoint=-
# [train] step=12/2000 | warm=0 | policy=32 | replay=10384 | world_total=3822.1759 | actor=-25.6507 | critic=3.7726 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=666.6 | checkpoint=-
# [train] step=13/2000 | warm=0 | policy=32 | replay=10416 | world_total=3821.8032 | actor=-28.0397 | critic=4.1577 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=672.6 | checkpoint=-
# [train] step=14/2000 | warm=0 | policy=32 | replay=10448 | world_total=3822.0215 | actor=-28.1610 | critic=4.9954 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=679.1 | checkpoint=-
# [train] step=15/2000 | warm=0 | policy=32 | replay=10480 | world_total=3820.9468 | actor=-30.2951 | critic=4.1518 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=684.8 | checkpoint=-
# [train] step=16/2000 | warm=0 | policy=32 | replay=10512 | world_total=3820.0836 | actor=-31.5376 | critic=4.3483 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=690.8 | checkpoint=-
# [train] step=17/2000 | warm=0 | policy=32 | replay=10544 | world_total=3819.3873 | actor=-35.1112 | critic=4.6469 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=696.8 | checkpoint=-
# [train] step=18/2000 | warm=0 | policy=32 | replay=10576 | world_total=3818.1847 | actor=-38.0089 | critic=3.8603 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=702.6 | checkpoint=-
# [train] step=19/2000 | warm=0 | policy=32 | replay=10608 | world_total=3816.9306 | actor=-39.4104 | critic=3.7775 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=709.1 | checkpoint=-
# [train] step=20/2000 | warm=0 | policy=32 | replay=10640 | world_total=3815.3857 | actor=-41.5004 | critic=3.7896 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=715.6 | checkpoint=-
# [train] step=21/2000 | warm=0 | policy=32 | replay=10672 | world_total=3813.7364 | actor=-43.1580 | critic=3.3424 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=722.0 | checkpoint=-
# [train] step=22/2000 | warm=0 | policy=32 | replay=10704 | world_total=3812.3154 | actor=-41.7821 | critic=4.7066 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=728.5 | checkpoint=-
# [train] step=23/2000 | warm=0 | policy=32 | replay=10736 | world_total=3810.7794 | actor=-41.0993 | critic=2.9532 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=734.9 | checkpoint=-
# [train] step=24/2000 | warm=0 | policy=32 | replay=10768 | world_total=3808.6644 | actor=-40.1411 | critic=3.0950 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=741.5 | checkpoint=-
# [train] step=25/2000 | warm=0 | policy=32 | replay=10800 | world_total=3806.3205 | actor=-38.9023 | critic=3.5263 | eval_reward=2.1683 | cycle_s=11.8 | elapsed_s=753.2 | checkpoint=checkpoint_00025.pt
# [train] step=26/2000 | warm=0 | policy=32 | replay=10832 | world_total=3803.9641 | actor=-37.5523 | critic=3.4461 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=760.2 | checkpoint=-
# [train] step=27/2000 | warm=0 | policy=32 | replay=10864 | world_total=3801.5089 | actor=-38.4882 | critic=3.5667 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=766.7 | checkpoint=-
# [train] step=28/2000 | warm=0 | policy=32 | replay=10896 | world_total=3799.2402 | actor=-39.0291 | critic=3.4274 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=773.0 | checkpoint=-
# [train] step=29/2000 | warm=0 | policy=32 | replay=10928 | world_total=3797.5389 | actor=-40.6586 | critic=3.5744 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=779.5 | checkpoint=-
# [train] step=30/2000 | warm=0 | policy=32 | replay=10960 | world_total=3795.9403 | actor=-42.5640 | critic=3.7637 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=786.0 | checkpoint=-
# [train] step=31/2000 | warm=0 | policy=32 | replay=10992 | world_total=3794.5705 | actor=-45.7551 | critic=4.0703 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=792.7 | checkpoint=-
# [train] step=32/2000 | warm=0 | policy=32 | replay=11024 | world_total=3793.5717 | actor=-48.5014 | critic=4.4242 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=799.2 | checkpoint=-
# [train] step=33/2000 | warm=0 | policy=32 | replay=11056 | world_total=3792.6024 | actor=-52.4800 | critic=4.9074 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=805.9 | checkpoint=-
# [train] step=34/2000 | warm=0 | policy=32 | replay=11088 | world_total=3792.0233 | actor=-57.6196 | critic=5.9723 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=812.6 | checkpoint=-
# [train] step=35/2000 | warm=0 | policy=32 | replay=11120 | world_total=3791.2205 | actor=-59.6837 | critic=8.8943 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=819.4 | checkpoint=-
# [train] step=36/2000 | warm=0 | policy=32 | replay=11152 | world_total=3790.6585 | actor=-59.6425 | critic=6.4012 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=826.1 | checkpoint=-
# [train] step=37/2000 | warm=0 | policy=32 | replay=11184 | world_total=3790.0825 | actor=-54.8880 | critic=6.7198 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=833.0 | checkpoint=-
# [train] step=38/2000 | warm=0 | policy=32 | replay=11216 | world_total=3789.5297 | actor=-46.2190 | critic=14.1158 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=839.8 | checkpoint=-
# [train] step=39/2000 | warm=0 | policy=32 | replay=11248 | world_total=3789.0208 | actor=-38.2177 | critic=17.0504 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=846.5 | checkpoint=-
# [train] step=40/2000 | warm=0 | policy=32 | replay=11280 | world_total=3788.7219 | actor=-31.7312 | critic=13.1285 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=853.1 | checkpoint=-
# [train] step=41/2000 | warm=0 | policy=32 | replay=11312 | world_total=3788.3407 | actor=-22.7559 | critic=25.7899 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=859.6 | checkpoint=-
# [train] step=42/2000 | warm=0 | policy=32 | replay=11344 | world_total=3787.9117 | actor=-18.4464 | critic=11.4099 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=866.3 | checkpoint=-
# [train] step=43/2000 | warm=0 | policy=32 | replay=11376 | world_total=3787.5135 | actor=-12.9274 | critic=8.4918 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=873.0 | checkpoint=-
# [train] step=44/2000 | warm=0 | policy=32 | replay=11408 | world_total=3787.1789 | actor=-9.1228 | critic=6.6569 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=879.9 | checkpoint=-
# [train] step=45/2000 | warm=0 | policy=32 | replay=11440 | world_total=3786.8503 | actor=-4.8525 | critic=10.6128 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=886.6 | checkpoint=-
# [train] step=46/2000 | warm=0 | policy=32 | replay=11472 | world_total=3786.5209 | actor=-4.1750 | critic=5.2408 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=893.4 | checkpoint=-
# [train] step=47/2000 | warm=0 | policy=32 | replay=11504 | world_total=3786.1053 | actor=-3.7080 | critic=3.8888 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=900.0 | checkpoint=-
# [train] step=48/2000 | warm=0 | policy=32 | replay=11536 | world_total=3785.7573 | actor=-3.7518 | critic=2.6164 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=906.5 | checkpoint=-
# [train] step=49/2000 | warm=0 | policy=32 | replay=11568 | world_total=3785.6877 | actor=-3.6349 | critic=2.0266 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=912.9 | checkpoint=-
# [train] step=50/2000 | warm=0 | policy=32 | replay=11600 | world_total=3785.3943 | actor=-3.4567 | critic=1.7964 | eval_reward=2.0426 | cycle_s=11.6 | elapsed_s=924.6 | checkpoint=checkpoint_00050.pt
# [train] step=51/2000 | warm=0 | policy=32 | replay=11632 | world_total=3784.9752 | actor=-3.3464 | critic=1.6182 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=931.0 | checkpoint=-
# [train] step=52/2000 | warm=0 | policy=32 | replay=11664 | world_total=3784.7046 | actor=-3.1561 | critic=1.5200 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=937.3 | checkpoint=-
# [train] step=53/2000 | warm=0 | policy=32 | replay=11696 | world_total=3784.5245 | actor=-3.1282 | critic=1.5391 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=943.5 | checkpoint=-
# [train] step=54/2000 | warm=0 | policy=32 | replay=11728 | world_total=3784.3315 | actor=-4.7326 | critic=4.0194 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=949.5 | checkpoint=-
# [train] step=55/2000 | warm=0 | policy=32 | replay=11760 | world_total=3783.9893 | actor=-8.2504 | critic=12.1028 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=956.1 | checkpoint=-
# [train] step=56/2000 | warm=0 | policy=32 | replay=11792 | world_total=3783.7370 | actor=-8.8236 | critic=11.2181 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=961.9 | checkpoint=-
# [train] step=57/2000 | warm=0 | policy=32 | replay=11824 | world_total=3783.4806 | actor=-10.1586 | critic=10.2776 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=967.4 | checkpoint=-
# [train] step=58/2000 | warm=0 | policy=32 | replay=11856 | world_total=3783.4097 | actor=-12.4342 | critic=11.0183 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=972.7 | checkpoint=-
# [train] step=59/2000 | warm=0 | policy=32 | replay=11888 | world_total=3783.3638 | actor=-15.7804 | critic=11.9217 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=978.1 | checkpoint=-
# [train] step=60/2000 | warm=0 | policy=32 | replay=11920 | world_total=3783.0666 | actor=-19.7145 | critic=13.8361 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=983.9 | checkpoint=-
# [train] step=61/2000 | warm=0 | policy=32 | replay=11952 | world_total=3782.7945 | actor=-23.1673 | critic=12.4303 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=989.3 | checkpoint=-
# [train] step=62/2000 | warm=0 | policy=32 | replay=11984 | world_total=3782.6504 | actor=-27.7331 | critic=11.8519 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=994.6 | checkpoint=-
# [train] step=63/2000 | warm=0 | policy=32 | replay=12016 | world_total=3782.6295 | actor=-30.8310 | critic=8.6288 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=999.9 | checkpoint=-
# [train] step=64/2000 | warm=0 | policy=32 | replay=12048 | world_total=3782.5207 | actor=-34.2013 | critic=7.9066 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1005.3 | checkpoint=-
# [train] step=65/2000 | warm=0 | policy=32 | replay=12080 | world_total=3782.2368 | actor=-38.0968 | critic=7.6338 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1010.5 | checkpoint=-
# [train] step=66/2000 | warm=0 | policy=32 | replay=12112 | world_total=3782.0357 | actor=-41.6586 | critic=6.8851 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1015.9 | checkpoint=-
# [train] step=67/2000 | warm=0 | policy=32 | replay=12144 | world_total=3781.9656 | actor=-45.5665 | critic=7.0664 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1021.2 | checkpoint=-
# [train] step=68/2000 | warm=0 | policy=32 | replay=12176 | world_total=3781.9272 | actor=-49.8879 | critic=6.6500 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1026.8 | checkpoint=-
# [train] step=69/2000 | warm=0 | policy=32 | replay=12208 | world_total=3781.7346 | actor=-53.2633 | critic=7.3833 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1032.1 | checkpoint=-
# [train] step=70/2000 | warm=0 | policy=32 | replay=12240 | world_total=3781.5965 | actor=-55.1746 | critic=9.3938 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1037.4 | checkpoint=-
# [train] step=71/2000 | warm=0 | policy=32 | replay=12272 | world_total=3781.6131 | actor=-55.6728 | critic=7.8278 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1042.9 | checkpoint=-
# [train] step=72/2000 | warm=0 | policy=32 | replay=12304 | world_total=3781.5862 | actor=-56.1218 | critic=7.7787 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1048.3 | checkpoint=-
# [train] step=73/2000 | warm=0 | policy=32 | replay=12336 | world_total=3781.2710 | actor=-55.6212 | critic=8.6250 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1053.7 | checkpoint=-
# [train] step=74/2000 | warm=0 | policy=32 | replay=12368 | world_total=3781.1402 | actor=-54.7160 | critic=9.6805 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1059.1 | checkpoint=-
# [train] step=75/2000 | warm=0 | policy=32 | replay=12400 | world_total=3781.1262 | actor=-54.9347 | critic=6.3229 | eval_reward=16.0722 | cycle_s=15.3 | elapsed_s=1074.3 | checkpoint=checkpoint_00075.pt
# [train] step=76/2000 | warm=0 | policy=32 | replay=12432 | world_total=3781.1717 | actor=-53.9526 | critic=8.4969 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1079.7 | checkpoint=-
# [train] step=77/2000 | warm=0 | policy=32 | replay=12464 | world_total=3781.0964 | actor=-53.5202 | critic=7.9528 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1085.1 | checkpoint=-
# [train] step=78/2000 | warm=0 | policy=32 | replay=12496 | world_total=3780.8953 | actor=-53.0153 | critic=7.6850 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1090.5 | checkpoint=-
# [train] step=79/2000 | warm=0 | policy=32 | replay=12528 | world_total=3780.7223 | actor=-52.2794 | critic=8.7350 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1095.9 | checkpoint=-
# [train] step=80/2000 | warm=0 | policy=32 | replay=12560 | world_total=3780.5985 | actor=-51.7097 | critic=7.9681 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1101.2 | checkpoint=-
# [train] step=81/2000 | warm=0 | policy=32 | replay=12592 | world_total=3780.5219 | actor=-49.6456 | critic=9.2599 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1106.8 | checkpoint=-
# [train] step=82/2000 | warm=0 | policy=32 | replay=12624 | world_total=3780.5979 | actor=-48.8706 | critic=7.1686 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1112.2 | checkpoint=-
# [train] step=83/2000 | warm=0 | policy=32 | replay=12656 | world_total=3780.4073 | actor=-48.5116 | critic=6.7677 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1117.5 | checkpoint=-
# [train] step=84/2000 | warm=0 | policy=32 | replay=12688 | world_total=3780.3337 | actor=-46.5127 | critic=10.5218 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1123.1 | checkpoint=-
# [train] step=85/2000 | warm=0 | policy=32 | replay=12720 | world_total=3780.3989 | actor=-46.5501 | critic=7.2506 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1128.2 | checkpoint=-
# [train] step=86/2000 | warm=0 | policy=32 | replay=12752 | world_total=3780.2741 | actor=-44.4868 | critic=8.2046 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1133.5 | checkpoint=-
# [train] step=87/2000 | warm=0 | policy=32 | replay=12784 | world_total=3780.1552 | actor=-45.1648 | critic=6.3308 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1138.9 | checkpoint=-
# [train] step=88/2000 | warm=0 | policy=32 | replay=12816 | world_total=3780.0296 | actor=-47.0698 | critic=6.2416 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1144.3 | checkpoint=-
# [train] step=89/2000 | warm=0 | policy=32 | replay=12848 | world_total=3779.9532 | actor=-47.1501 | critic=9.6092 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=1149.8 | checkpoint=-
# [train] step=90/2000 | warm=0 | policy=32 | replay=12880 | world_total=3780.0375 | actor=-47.5976 | critic=7.1884 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1154.9 | checkpoint=-
# [train] step=91/2000 | warm=0 | policy=32 | replay=12912 | world_total=3779.8857 | actor=-46.3116 | critic=7.4093 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1160.5 | checkpoint=-
# [train] step=92/2000 | warm=0 | policy=32 | replay=12944 | world_total=3779.9463 | actor=-45.5402 | critic=7.4298 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1165.9 | checkpoint=-
# [train] step=93/2000 | warm=0 | policy=32 | replay=12976 | world_total=3779.8371 | actor=-44.4364 | critic=7.6778 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1171.5 | checkpoint=-
# [train] step=94/2000 | warm=0 | policy=32 | replay=13008 | world_total=3779.7658 | actor=-42.6898 | critic=9.3043 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1176.9 | checkpoint=-
# [train] step=95/2000 | warm=0 | policy=32 | replay=13040 | world_total=3779.7076 | actor=-42.2827 | critic=6.6391 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1182.5 | checkpoint=-
# [train] step=96/2000 | warm=0 | policy=32 | replay=13072 | world_total=3779.7981 | actor=-41.2313 | critic=7.0740 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1187.8 | checkpoint=-
# [train] step=97/2000 | warm=0 | policy=32 | replay=13104 | world_total=3779.6468 | actor=-40.0908 | critic=7.5183 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1193.2 | checkpoint=-
# [train] step=98/2000 | warm=0 | policy=32 | replay=13136 | world_total=3779.5911 | actor=-41.7266 | critic=5.7758 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1198.5 | checkpoint=-
# [train] step=99/2000 | warm=0 | policy=32 | replay=13168 | world_total=3779.4655 | actor=-41.5132 | critic=6.9642 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1203.9 | checkpoint=-
# [train] step=100/2000 | warm=0 | policy=32 | replay=13200 | world_total=3779.4527 | actor=-42.1594 | critic=7.0876 | eval_reward=25.8253 | cycle_s=18.8 | elapsed_s=1222.6 | checkpoint=checkpoint_00100.pt
# [train] step=101/2000 | warm=0 | policy=32 | replay=13232 | world_total=3779.5599 | actor=-40.8732 | critic=7.1577 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1228.0 | checkpoint=-
# [train] step=102/2000 | warm=0 | policy=32 | replay=13264 | world_total=3779.4912 | actor=-42.7444 | critic=4.5201 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1233.2 | checkpoint=-
# [train] step=103/2000 | warm=0 | policy=32 | replay=13296 | world_total=3779.3506 | actor=-45.7709 | critic=4.3491 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1238.4 | checkpoint=-
# [train] step=104/2000 | warm=0 | policy=32 | replay=13328 | world_total=3779.3600 | actor=-49.1653 | critic=3.4978 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1243.5 | checkpoint=-
# [train] step=105/2000 | warm=0 | policy=32 | replay=13360 | world_total=3779.2832 | actor=-52.9755 | critic=3.0572 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1248.6 | checkpoint=-
# [train] step=106/2000 | warm=0 | policy=32 | replay=13392 | world_total=3779.2166 | actor=-56.2828 | critic=3.1011 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1253.7 | checkpoint=-
# [train] step=107/2000 | warm=0 | policy=32 | replay=13424 | world_total=3779.1335 | actor=-59.1886 | critic=2.8630 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1258.8 | checkpoint=-
# [train] step=108/2000 | warm=0 | policy=32 | replay=13456 | world_total=3779.1857 | actor=-60.4814 | critic=4.0439 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1264.1 | checkpoint=-
# [train] step=109/2000 | warm=0 | policy=32 | replay=13488 | world_total=3779.0903 | actor=-60.2929 | critic=2.7659 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1269.3 | checkpoint=-
# [train] step=110/2000 | warm=0 | policy=32 | replay=13520 | world_total=3779.1125 | actor=-60.5132 | critic=3.0737 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1274.3 | checkpoint=-
# [train] step=111/2000 | warm=0 | policy=32 | replay=13552 | world_total=3779.0172 | actor=-60.3430 | critic=2.7894 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1279.4 | checkpoint=-
# [train] step=112/2000 | warm=0 | policy=32 | replay=13584 | world_total=3778.9540 | actor=-60.7504 | critic=2.5905 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1284.5 | checkpoint=-
# [train] step=113/2000 | warm=0 | policy=32 | replay=13616 | world_total=3778.9393 | actor=-61.5225 | critic=2.6784 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1289.7 | checkpoint=-
# [train] step=114/2000 | warm=0 | policy=32 | replay=13648 | world_total=3778.9089 | actor=-61.1491 | critic=3.0890 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1294.8 | checkpoint=-
# [train] step=115/2000 | warm=0 | policy=32 | replay=13680 | world_total=3778.8308 | actor=-61.8990 | critic=2.3732 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1299.8 | checkpoint=-
# [train] step=116/2000 | warm=0 | policy=32 | replay=13712 | world_total=3778.8069 | actor=-62.3556 | critic=2.7360 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1305.0 | checkpoint=-
# [train] step=117/2000 | warm=0 | policy=32 | replay=13744 | world_total=3778.7317 | actor=-62.8563 | critic=2.5310 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1310.1 | checkpoint=-
# [train] step=118/2000 | warm=0 | policy=32 | replay=13776 | world_total=3778.7221 | actor=-63.5109 | critic=2.7484 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1315.2 | checkpoint=-
# [train] step=119/2000 | warm=0 | policy=32 | replay=13808 | world_total=3778.8920 | actor=-63.5982 | critic=2.7576 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1320.4 | checkpoint=-
# [train] step=120/2000 | warm=0 | policy=32 | replay=13840 | world_total=3778.7138 | actor=-63.5817 | critic=2.4064 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1325.5 | checkpoint=-
# [train] step=121/2000 | warm=0 | policy=32 | replay=13872 | world_total=3778.6533 | actor=-63.6384 | critic=2.7660 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1330.7 | checkpoint=-
# [train] step=122/2000 | warm=0 | policy=32 | replay=13904 | world_total=3778.5685 | actor=-64.1463 | critic=2.6222 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1335.8 | checkpoint=-
# [train] step=123/2000 | warm=0 | policy=32 | replay=13936 | world_total=3778.5188 | actor=-64.4716 | critic=2.5253 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1341.0 | checkpoint=-
# [train] step=124/2000 | warm=0 | policy=32 | replay=13968 | world_total=3778.5736 | actor=-64.9296 | critic=2.4567 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1346.1 | checkpoint=-
# [train] step=125/2000 | warm=0 | policy=32 | replay=14000 | world_total=3778.4367 | actor=-65.6710 | critic=2.6982 | eval_reward=35.1313 | cycle_s=27.1 | elapsed_s=1373.2 | checkpoint=checkpoint_00125.pt
# [train] step=126/2000 | warm=0 | policy=32 | replay=14032 | world_total=3778.3964 | actor=-65.8917 | critic=2.5896 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1378.4 | checkpoint=-
# [train] step=127/2000 | warm=0 | policy=32 | replay=14064 | world_total=3778.4170 | actor=-65.8307 | critic=2.6968 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1383.6 | checkpoint=-
# [train] step=128/2000 | warm=0 | policy=32 | replay=14096 | world_total=3778.4483 | actor=-66.4509 | critic=2.4542 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1388.8 | checkpoint=-
# [train] step=129/2000 | warm=0 | policy=32 | replay=14128 | world_total=3778.4783 | actor=-65.5845 | critic=2.6349 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1393.9 | checkpoint=-
# [train] step=130/2000 | warm=0 | policy=32 | replay=14160 | world_total=3778.3540 | actor=-65.6974 | critic=2.4860 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1399.2 | checkpoint=-
# [train] step=131/2000 | warm=0 | policy=32 | replay=14192 | world_total=3778.3061 | actor=-65.9240 | critic=2.6687 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1404.4 | checkpoint=-
# [train] step=132/2000 | warm=0 | policy=32 | replay=14224 | world_total=3778.3433 | actor=-66.1343 | critic=2.3986 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1409.7 | checkpoint=-
# [train] step=133/2000 | warm=0 | policy=32 | replay=14256 | world_total=3778.2489 | actor=-66.4832 | critic=2.5852 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1414.8 | checkpoint=-
# [train] step=134/2000 | warm=0 | policy=32 | replay=14288 | world_total=3778.2540 | actor=-66.4928 | critic=2.3348 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1419.9 | checkpoint=-
# [train] step=135/2000 | warm=0 | policy=32 | replay=14320 | world_total=3778.2134 | actor=-66.4867 | critic=2.6487 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1425.0 | checkpoint=-
# [train] step=136/2000 | warm=0 | policy=32 | replay=14352 | world_total=3778.2001 | actor=-66.6411 | critic=2.4173 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1430.2 | checkpoint=-
# [train] step=137/2000 | warm=0 | policy=32 | replay=14384 | world_total=3778.1832 | actor=-66.1752 | critic=2.6172 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1435.3 | checkpoint=-
# [train] step=138/2000 | warm=0 | policy=32 | replay=14416 | world_total=3778.0953 | actor=-66.9498 | critic=2.4676 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1440.5 | checkpoint=-
# [train] step=139/2000 | warm=0 | policy=32 | replay=14448 | world_total=3778.0545 | actor=-67.0788 | critic=2.5143 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1445.6 | checkpoint=-
# [train] step=140/2000 | warm=0 | policy=32 | replay=14480 | world_total=3778.1231 | actor=-67.4295 | critic=2.6041 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1450.7 | checkpoint=-
# [train] step=141/2000 | warm=0 | policy=32 | replay=14512 | world_total=3778.2067 | actor=-66.9577 | critic=2.7599 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1455.9 | checkpoint=-
# [train] step=142/2000 | warm=0 | policy=32 | replay=14544 | world_total=3777.9957 | actor=-67.1814 | critic=2.5064 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1461.0 | checkpoint=-
# [train] step=143/2000 | warm=0 | policy=32 | replay=14576 | world_total=3777.9700 | actor=-67.6067 | critic=2.5563 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1466.3 | checkpoint=-
# [train] step=144/2000 | warm=0 | policy=32 | replay=14608 | world_total=3778.0174 | actor=-68.7599 | critic=2.4875 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1471.5 | checkpoint=-
# [train] step=145/2000 | warm=0 | policy=32 | replay=14640 | world_total=3777.9539 | actor=-70.1133 | critic=2.4958 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1476.9 | checkpoint=-
# [train] step=146/2000 | warm=0 | policy=32 | replay=14672 | world_total=3777.8811 | actor=-70.2131 | critic=2.6579 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1482.1 | checkpoint=-
# [train] step=147/2000 | warm=0 | policy=32 | replay=14704 | world_total=3777.9859 | actor=-69.7952 | critic=2.4129 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1487.2 | checkpoint=-
# [train] step=148/2000 | warm=0 | policy=32 | replay=14736 | world_total=3777.8830 | actor=-69.3194 | critic=2.5047 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1492.6 | checkpoint=-
# [train] step=149/2000 | warm=0 | policy=32 | replay=14768 | world_total=3777.9368 | actor=-68.5770 | critic=2.5850 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1497.8 | checkpoint=-
# [train] step=150/2000 | warm=0 | policy=32 | replay=14800 | world_total=3777.9959 | actor=-68.8822 | critic=2.7754 | eval_reward=31.5193 | cycle_s=24.5 | elapsed_s=1522.3 | checkpoint=checkpoint_00150.pt
# [train] step=151/2000 | warm=0 | policy=32 | replay=14832 | world_total=3777.8788 | actor=-69.5359 | critic=2.4096 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1527.4 | checkpoint=-
# [train] step=152/2000 | warm=0 | policy=32 | replay=14864 | world_total=3777.8077 | actor=-70.0493 | critic=2.6851 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1532.7 | checkpoint=-
# [train] step=153/2000 | warm=0 | policy=32 | replay=14896 | world_total=3777.8124 | actor=-70.2539 | critic=2.7298 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1538.0 | checkpoint=-
# [train] step=154/2000 | warm=0 | policy=32 | replay=14928 | world_total=3777.8388 | actor=-69.7259 | critic=2.5661 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1543.5 | checkpoint=-
# [train] step=155/2000 | warm=0 | policy=32 | replay=14960 | world_total=3777.8156 | actor=-69.4863 | critic=2.4590 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1548.8 | checkpoint=-
# [train] step=156/2000 | warm=0 | policy=32 | replay=14992 | world_total=3777.7320 | actor=-69.3979 | critic=2.4221 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1554.0 | checkpoint=-
# [train] step=157/2000 | warm=0 | policy=32 | replay=15024 | world_total=3777.7455 | actor=-69.3638 | critic=2.4417 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1559.4 | checkpoint=-
# [train] step=158/2000 | warm=0 | policy=32 | replay=15056 | world_total=3777.6961 | actor=-68.2631 | critic=2.4765 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1564.5 | checkpoint=-
# [train] step=159/2000 | warm=0 | policy=32 | replay=15088 | world_total=3777.7556 | actor=-67.3760 | critic=2.2605 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1569.7 | checkpoint=-
# [train] step=160/2000 | warm=0 | policy=32 | replay=15120 | world_total=3777.9045 | actor=-67.0112 | critic=2.4228 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1574.9 | checkpoint=-
# [train] step=161/2000 | warm=0 | policy=32 | replay=15152 | world_total=3777.7236 | actor=-66.5370 | critic=2.5038 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1580.0 | checkpoint=-
# [train] step=162/2000 | warm=0 | policy=32 | replay=15184 | world_total=3777.7043 | actor=-66.8048 | critic=2.3751 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1585.1 | checkpoint=-
# [train] step=163/2000 | warm=0 | policy=32 | replay=15216 | world_total=3777.7687 | actor=-67.2337 | critic=2.3963 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1590.5 | checkpoint=-
# [train] step=164/2000 | warm=0 | policy=32 | replay=15248 | world_total=3777.6557 | actor=-67.4917 | critic=2.3306 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1595.6 | checkpoint=-
# [train] step=165/2000 | warm=0 | policy=32 | replay=15280 | world_total=3777.5948 | actor=-68.4429 | critic=2.3456 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1600.8 | checkpoint=-
# [train] step=166/2000 | warm=0 | policy=32 | replay=15312 | world_total=3777.6764 | actor=-68.9545 | critic=2.3476 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1606.0 | checkpoint=-
# [train] step=167/2000 | warm=0 | policy=32 | replay=15344 | world_total=3777.6585 | actor=-69.7993 | critic=2.3854 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1611.1 | checkpoint=-
# [train] step=168/2000 | warm=0 | policy=32 | replay=15376 | world_total=3777.6892 | actor=-71.1319 | critic=2.5016 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1616.3 | checkpoint=-
# [train] step=169/2000 | warm=0 | policy=32 | replay=15408 | world_total=3777.6804 | actor=-71.4016 | critic=2.6682 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1621.5 | checkpoint=-
# [train] step=170/2000 | warm=0 | policy=32 | replay=15440 | world_total=3777.6154 | actor=-70.6499 | critic=2.4142 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1626.6 | checkpoint=-
# [train] step=171/2000 | warm=0 | policy=32 | replay=15472 | world_total=3777.5508 | actor=-68.8212 | critic=2.5781 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1631.8 | checkpoint=-
# [train] step=172/2000 | warm=0 | policy=32 | replay=15504 | world_total=3777.5223 | actor=-67.8319 | critic=2.2805 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1636.9 | checkpoint=-
# [train] step=173/2000 | warm=0 | policy=32 | replay=15536 | world_total=3777.6370 | actor=-67.1137 | critic=2.3801 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1642.0 | checkpoint=-
# [train] step=174/2000 | warm=0 | policy=32 | replay=15568 | world_total=3777.6059 | actor=-66.6416 | critic=2.3569 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1647.4 | checkpoint=-
# [train] step=175/2000 | warm=0 | policy=32 | replay=15600 | world_total=3777.7591 | actor=-67.3999 | critic=2.3190 | eval_reward=32.5386 | cycle_s=24.9 | elapsed_s=1672.3 | checkpoint=checkpoint_00175.pt
# [train] step=176/2000 | warm=0 | policy=32 | replay=15632 | world_total=3777.5613 | actor=-67.4899 | critic=2.6233 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1677.5 | checkpoint=-
# [train] step=177/2000 | warm=0 | policy=32 | replay=15664 | world_total=3777.5657 | actor=-68.0179 | critic=2.3901 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=1683.0 | checkpoint=-
# [train] step=178/2000 | warm=0 | policy=32 | replay=15696 | world_total=3777.5561 | actor=-68.4287 | critic=2.5181 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1688.1 | checkpoint=-
# [train] step=179/2000 | warm=0 | policy=32 | replay=15728 | world_total=3777.4795 | actor=-68.6948 | critic=2.4135 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=1693.6 | checkpoint=-
# [train] step=180/2000 | warm=0 | policy=32 | replay=15760 | world_total=3777.5430 | actor=-68.4800 | critic=2.3966 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1698.8 | checkpoint=-
# [train] step=181/2000 | warm=0 | policy=32 | replay=15792 | world_total=3777.5071 | actor=-68.5717 | critic=2.2465 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1703.9 | checkpoint=-
# [train] step=182/2000 | warm=0 | policy=32 | replay=15824 | world_total=3777.4625 | actor=-68.2933 | critic=2.4774 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1709.0 | checkpoint=-
# [train] step=183/2000 | warm=0 | policy=32 | replay=15856 | world_total=3777.4082 | actor=-68.5782 | critic=2.2773 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1714.4 | checkpoint=-
# [train] step=184/2000 | warm=0 | policy=32 | replay=15888 | world_total=3777.5105 | actor=-68.3680 | critic=2.3054 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1719.5 | checkpoint=-
# [train] step=185/2000 | warm=0 | policy=32 | replay=15920 | world_total=3777.4387 | actor=-68.4840 | critic=2.3156 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1724.7 | checkpoint=-
# [train] step=186/2000 | warm=0 | policy=32 | replay=15952 | world_total=3777.4118 | actor=-67.6991 | critic=2.3498 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1729.8 | checkpoint=-
# [train] step=187/2000 | warm=0 | policy=32 | replay=15984 | world_total=3777.4590 | actor=-67.2373 | critic=2.1597 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1735.0 | checkpoint=-
# [train] step=188/2000 | warm=0 | policy=32 | replay=16016 | world_total=3777.3912 | actor=-66.7089 | critic=2.2955 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1740.1 | checkpoint=-
# [train] step=189/2000 | warm=0 | policy=32 | replay=16048 | world_total=3777.4972 | actor=-66.4417 | critic=2.1943 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1745.3 | checkpoint=-
# [train] step=190/2000 | warm=0 | policy=32 | replay=16080 | world_total=3777.4020 | actor=-67.8656 | critic=2.2705 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1750.5 | checkpoint=-
# [train] step=191/2000 | warm=0 | policy=32 | replay=16112 | world_total=3777.4031 | actor=-68.6577 | critic=2.3681 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1755.6 | checkpoint=-
# [train] step=192/2000 | warm=0 | policy=32 | replay=16144 | world_total=3777.3112 | actor=-69.7736 | critic=2.3523 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1760.7 | checkpoint=-
# [train] step=193/2000 | warm=0 | policy=32 | replay=16176 | world_total=3777.2850 | actor=-70.5228 | critic=2.3410 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1766.0 | checkpoint=-
# [train] step=194/2000 | warm=0 | policy=32 | replay=16208 | world_total=3777.2874 | actor=-70.7280 | critic=2.2649 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1771.1 | checkpoint=-
# [train] step=195/2000 | warm=0 | policy=32 | replay=16240 | world_total=3777.3243 | actor=-70.3247 | critic=2.4596 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1776.2 | checkpoint=-
# [train] step=196/2000 | warm=0 | policy=32 | replay=16272 | world_total=3777.3423 | actor=-69.9504 | critic=2.3002 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1781.5 | checkpoint=-
# [train] step=197/2000 | warm=0 | policy=32 | replay=16304 | world_total=3777.3598 | actor=-69.1508 | critic=2.3976 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1786.6 | checkpoint=-
# [train] step=198/2000 | warm=0 | policy=32 | replay=16336 | world_total=3777.3029 | actor=-69.4139 | critic=2.3548 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1791.7 | checkpoint=-
# [train] step=199/2000 | warm=0 | policy=32 | replay=16368 | world_total=3777.2540 | actor=-69.3843 | critic=2.3105 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1796.8 | checkpoint=-
# [train] step=200/2000 | warm=0 | policy=32 | replay=16400 | world_total=3777.2674 | actor=-69.3979 | critic=2.3575 | eval_reward=27.8701 | cycle_s=21.9 | elapsed_s=1818.8 | checkpoint=checkpoint_00200.pt
# [train] step=201/2000 | warm=0 | policy=32 | replay=16432 | world_total=3777.2569 | actor=-69.3110 | critic=2.3305 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1823.9 | checkpoint=-
# [train] step=202/2000 | warm=0 | policy=32 | replay=16464 | world_total=3777.3308 | actor=-69.2019 | critic=2.2796 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1829.3 | checkpoint=-
# [train] step=203/2000 | warm=0 | policy=32 | replay=16496 | world_total=3777.2701 | actor=-68.6927 | critic=2.4324 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1834.5 | checkpoint=-
# [train] step=204/2000 | warm=0 | policy=32 | replay=16528 | world_total=3777.2398 | actor=-68.9039 | critic=2.3653 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1839.6 | checkpoint=-
# [train] step=205/2000 | warm=0 | policy=32 | replay=16560 | world_total=3777.2800 | actor=-69.3212 | critic=2.2511 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1844.7 | checkpoint=-
# [train] step=206/2000 | warm=0 | policy=32 | replay=16592 | world_total=3777.2810 | actor=-69.7925 | critic=2.2430 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1849.8 | checkpoint=-
# [train] step=207/2000 | warm=0 | policy=32 | replay=16624 | world_total=3777.3647 | actor=-69.3730 | critic=2.5428 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1855.0 | checkpoint=-
# [train] step=208/2000 | warm=0 | policy=32 | replay=16656 | world_total=3777.3015 | actor=-69.4813 | critic=2.3131 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1860.1 | checkpoint=-
# [train] step=209/2000 | warm=0 | policy=32 | replay=16688 | world_total=3777.2220 | actor=-69.7557 | critic=2.4659 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1865.2 | checkpoint=-
# [train] step=210/2000 | warm=0 | policy=32 | replay=16720 | world_total=3777.1552 | actor=-70.2266 | critic=2.4125 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1870.7 | checkpoint=-
# [train] step=211/2000 | warm=0 | policy=32 | replay=16752 | world_total=3777.2062 | actor=-70.7435 | critic=2.4271 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1875.8 | checkpoint=-
# [train] step=212/2000 | warm=0 | policy=32 | replay=16784 | world_total=3777.1522 | actor=-70.5048 | critic=2.3234 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1881.0 | checkpoint=-
# [train] step=213/2000 | warm=0 | policy=32 | replay=16816 | world_total=3777.1518 | actor=-69.4566 | critic=2.3673 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1886.1 | checkpoint=-
# [train] step=214/2000 | warm=0 | policy=32 | replay=16848 | world_total=3777.1534 | actor=-68.9207 | critic=2.2038 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1891.3 | checkpoint=-
# [train] step=215/2000 | warm=0 | policy=32 | replay=16880 | world_total=3777.1392 | actor=-68.4154 | critic=2.3487 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1896.7 | checkpoint=-
# [train] step=216/2000 | warm=0 | policy=32 | replay=16912 | world_total=3777.1606 | actor=-68.5660 | critic=2.3209 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1901.8 | checkpoint=-
# [train] step=217/2000 | warm=0 | policy=32 | replay=16944 | world_total=3777.1808 | actor=-69.6559 | critic=2.3540 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1907.0 | checkpoint=-
# [train] step=218/2000 | warm=0 | policy=32 | replay=16976 | world_total=3777.1896 | actor=-69.8255 | critic=2.4025 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1912.1 | checkpoint=-
# [train] step=219/2000 | warm=0 | policy=32 | replay=17008 | world_total=3777.1225 | actor=-69.3302 | critic=2.3759 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1917.2 | checkpoint=-
# [train] step=220/2000 | warm=0 | policy=32 | replay=17040 | world_total=3777.0746 | actor=-69.7707 | critic=2.2222 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1922.4 | checkpoint=-
# [train] step=221/2000 | warm=0 | policy=32 | replay=17072 | world_total=3777.2318 | actor=-69.9968 | critic=2.2225 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1927.5 | checkpoint=-
# [train] step=222/2000 | warm=0 | policy=32 | replay=17104 | world_total=3777.1387 | actor=-69.7328 | critic=2.3036 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1932.8 | checkpoint=-
# [train] step=223/2000 | warm=0 | policy=32 | replay=17136 | world_total=3777.1095 | actor=-69.9331 | critic=2.4584 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1937.9 | checkpoint=-
# [train] step=224/2000 | warm=0 | policy=32 | replay=17168 | world_total=3777.1251 | actor=-69.9719 | critic=2.2111 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1943.1 | checkpoint=-
# [train] step=225/2000 | warm=0 | policy=32 | replay=17200 | world_total=3777.1309 | actor=-69.9864 | critic=2.2849 | eval_reward=31.0651 | cycle_s=23.6 | elapsed_s=1966.7 | checkpoint=checkpoint_00225.pt
# [train] step=226/2000 | warm=0 | policy=32 | replay=17232 | world_total=3777.1304 | actor=-70.3794 | critic=2.2758 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1971.8 | checkpoint=-
# [train] step=227/2000 | warm=0 | policy=32 | replay=17264 | world_total=3777.0706 | actor=-70.0670 | critic=2.2859 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1977.2 | checkpoint=-
# [train] step=228/2000 | warm=0 | policy=32 | replay=17296 | world_total=3777.0990 | actor=-70.3177 | critic=2.5645 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1982.4 | checkpoint=-
# [train] step=229/2000 | warm=0 | policy=32 | replay=17328 | world_total=3777.0750 | actor=-69.8611 | critic=2.2395 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1987.5 | checkpoint=-
# [train] step=230/2000 | warm=0 | policy=32 | replay=17360 | world_total=3777.0280 | actor=-69.2783 | critic=2.2112 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1992.6 | checkpoint=-
# [train] step=231/2000 | warm=0 | policy=32 | replay=17392 | world_total=3777.0566 | actor=-69.8217 | critic=2.4238 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=1997.8 | checkpoint=-
# [train] step=232/2000 | warm=0 | policy=32 | replay=17424 | world_total=3777.1078 | actor=-70.1261 | critic=2.3660 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=2003.1 | checkpoint=-
# [train] step=233/2000 | warm=0 | policy=32 | replay=17456 | world_total=3777.0909 | actor=-72.0630 | critic=2.2574 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2008.3 | checkpoint=-
# [train] step=234/2000 | warm=0 | policy=32 | replay=17488 | world_total=3777.0060 | actor=-71.6567 | critic=3.0418 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=2013.7 | checkpoint=-
# [train] step=235/2000 | warm=0 | policy=32 | replay=17520 | world_total=3777.0340 | actor=-69.8801 | critic=2.1798 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2018.8 | checkpoint=-
# [train] step=236/2000 | warm=0 | policy=32 | replay=17552 | world_total=3776.9902 | actor=-68.0696 | critic=2.2568 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2023.9 | checkpoint=-
# [train] step=237/2000 | warm=0 | policy=32 | replay=17584 | world_total=3777.0077 | actor=-67.1635 | critic=2.3063 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=2029.3 | checkpoint=-
# [train] step=238/2000 | warm=0 | policy=32 | replay=17616 | world_total=3777.0081 | actor=-68.1182 | critic=2.1693 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2034.5 | checkpoint=-
# [train] step=239/2000 | warm=0 | policy=32 | replay=17648 | world_total=3777.0013 | actor=-68.8060 | critic=2.3521 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2039.6 | checkpoint=-
# [train] step=240/2000 | warm=0 | policy=32 | replay=17680 | world_total=3777.0350 | actor=-68.2351 | critic=2.4015 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2044.8 | checkpoint=-
# [train] step=241/2000 | warm=0 | policy=32 | replay=17712 | world_total=3777.0458 | actor=-67.8294 | critic=2.2622 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2050.0 | checkpoint=-
# [train] step=242/2000 | warm=0 | policy=32 | replay=17744 | world_total=3777.1100 | actor=-66.5524 | critic=2.0847 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=2055.6 | checkpoint=-
# [train] step=243/2000 | warm=0 | policy=32 | replay=17776 | world_total=3777.0179 | actor=-67.1598 | critic=2.2313 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=2061.2 | checkpoint=-
# [train] step=244/2000 | warm=0 | policy=32 | replay=17808 | world_total=3777.0150 | actor=-68.4519 | critic=2.3001 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2066.3 | checkpoint=-
# [train] step=245/2000 | warm=0 | policy=32 | replay=17840 | world_total=3776.9130 | actor=-69.9749 | critic=2.3410 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2071.4 | checkpoint=-
# [train] step=246/2000 | warm=0 | policy=32 | replay=17872 | world_total=3776.9598 | actor=-69.3831 | critic=2.3851 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2076.6 | checkpoint=-
# [train] step=247/2000 | warm=0 | policy=32 | replay=17904 | world_total=3776.9567 | actor=-68.2209 | critic=2.1492 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2081.7 | checkpoint=-
# [train] step=248/2000 | warm=0 | policy=32 | replay=17936 | world_total=3777.0052 | actor=-66.3760 | critic=2.4651 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2086.8 | checkpoint=-
# [train] step=249/2000 | warm=0 | policy=32 | replay=17968 | world_total=3776.9298 | actor=-65.5324 | critic=2.1665 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2091.9 | checkpoint=-
# [train] step=250/2000 | warm=0 | policy=32 | replay=18000 | world_total=3776.9658 | actor=-66.3661 | critic=2.2928 | eval_reward=37.1214 | cycle_s=25.0 | elapsed_s=2116.9 | checkpoint=checkpoint_00250.pt
# [train] step=251/2000 | warm=0 | policy=32 | replay=18032 | world_total=3776.9130 | actor=-69.0093 | critic=2.3500 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2122.1 | checkpoint=-
# [train] step=252/2000 | warm=0 | policy=32 | replay=18064 | world_total=3776.9383 | actor=-70.8416 | critic=2.4941 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=2127.8 | checkpoint=-
# [train] step=253/2000 | warm=0 | policy=32 | replay=18096 | world_total=3777.0009 | actor=-68.9790 | critic=2.4113 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=2133.2 | checkpoint=-
# [train] step=254/2000 | warm=0 | policy=32 | replay=18128 | world_total=3776.9039 | actor=-67.6226 | critic=2.1282 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2138.3 | checkpoint=-
# [train] step=255/2000 | warm=0 | policy=32 | replay=18160 | world_total=3776.9187 | actor=-65.4718 | critic=2.4669 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2143.4 | checkpoint=-
# [train] step=256/2000 | warm=0 | policy=32 | replay=18192 | world_total=3776.9488 | actor=-65.4563 | critic=2.2220 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=2148.7 | checkpoint=-
# [train] step=257/2000 | warm=0 | policy=32 | replay=18224 | world_total=3776.9191 | actor=-66.1711 | critic=2.3081 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2153.8 | checkpoint=-
# [train] step=258/2000 | warm=0 | policy=32 | replay=18256 | world_total=3776.8545 | actor=-67.6296 | critic=2.1985 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2158.9 | checkpoint=-
# [train] step=259/2000 | warm=0 | policy=32 | replay=18288 | world_total=3776.8850 | actor=-67.8633 | critic=2.7240 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2164.1 | checkpoint=-
# [train] step=260/2000 | warm=0 | policy=32 | replay=18320 | world_total=3776.8388 | actor=-66.4429 | critic=2.1002 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2169.2 | checkpoint=-
# [train] step=261/2000 | warm=0 | policy=32 | replay=18352 | world_total=3776.8814 | actor=-64.5790 | critic=2.2681 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=2174.5 | checkpoint=-
# [train] step=262/2000 | warm=0 | policy=32 | replay=18384 | world_total=3776.9554 | actor=-64.0703 | critic=2.1655 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2179.7 | checkpoint=-
# [train] step=263/2000 | warm=0 | policy=32 | replay=18416 | world_total=3776.8951 | actor=-66.2064 | critic=2.3090 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2184.8 | checkpoint=-
# ...
# [train] step=1921/2000 | warm=0 | policy=32 | replay=71472 | world_total=3772.5162 | actor=-66.8492 | critic=1.2576 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12416.1 | checkpoint=-
# [train] step=1922/2000 | warm=0 | policy=32 | replay=71504 | world_total=3772.4227 | actor=-66.7116 | critic=1.0526 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12421.3 | checkpoint=-
# [train] step=1923/2000 | warm=0 | policy=32 | replay=71536 | world_total=3772.4688 | actor=-66.5536 | critic=1.0778 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12426.5 | checkpoint=-
# [train] step=1924/2000 | warm=0 | policy=32 | replay=71568 | world_total=3772.4902 | actor=-66.0955 | critic=1.2538 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12431.8 | checkpoint=-
# [train] step=1925/2000 | warm=0 | policy=32 | replay=71600 | world_total=3772.4530 | actor=-66.0904 | critic=1.0699 | eval_reward=34.5356 | cycle_s=30.9 | elapsed_s=12462.6 | checkpoint=checkpoint_01925.pt
# [train] step=1926/2000 | warm=0 | policy=32 | replay=71632 | world_total=3772.5094 | actor=-67.2529 | critic=1.0045 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12467.9 | checkpoint=-
# [train] step=1927/2000 | warm=0 | policy=32 | replay=71664 | world_total=3772.4988 | actor=-68.1782 | critic=1.5506 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=12473.9 | checkpoint=-
# [train] step=1928/2000 | warm=0 | policy=32 | replay=71696 | world_total=3772.4962 | actor=-68.0779 | critic=1.3145 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=12479.9 | checkpoint=-
# [train] step=1929/2000 | warm=0 | policy=32 | replay=71728 | world_total=3772.4784 | actor=-67.8100 | critic=1.4835 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12485.1 | checkpoint=-
# [train] step=1930/2000 | warm=0 | policy=32 | replay=71760 | world_total=3772.4742 | actor=-67.6063 | critic=1.4947 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12490.4 | checkpoint=-
# [train] step=1931/2000 | warm=0 | policy=32 | replay=71792 | world_total=3772.4886 | actor=-67.0495 | critic=1.2206 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12495.6 | checkpoint=-
# [train] step=1932/2000 | warm=0 | policy=32 | replay=71824 | world_total=3772.4610 | actor=-66.9126 | critic=1.2225 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12500.8 | checkpoint=-
# [train] step=1933/2000 | warm=0 | policy=32 | replay=71856 | world_total=3772.4914 | actor=-67.6243 | critic=1.1501 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12506.0 | checkpoint=-
# [train] step=1934/2000 | warm=0 | policy=32 | replay=71888 | world_total=3772.5395 | actor=-67.9763 | critic=1.0310 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12511.2 | checkpoint=-
# [train] step=1935/2000 | warm=0 | policy=32 | replay=71920 | world_total=3772.4805 | actor=-67.2379 | critic=1.6694 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12516.5 | checkpoint=-
# [train] step=1936/2000 | warm=0 | policy=32 | replay=71952 | world_total=3772.4273 | actor=-66.2859 | critic=1.6538 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12521.7 | checkpoint=-
# [train] step=1937/2000 | warm=0 | policy=32 | replay=71984 | world_total=3772.5233 | actor=-66.3285 | critic=1.4773 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12526.9 | checkpoint=-
# [train] step=1938/2000 | warm=0 | policy=32 | replay=72016 | world_total=3772.4759 | actor=-67.6350 | critic=1.0578 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12532.1 | checkpoint=-
# [train] step=1939/2000 | warm=0 | policy=32 | replay=72048 | world_total=3772.4282 | actor=-69.2944 | critic=1.1433 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12537.5 | checkpoint=-
# [train] step=1940/2000 | warm=0 | policy=32 | replay=72080 | world_total=3772.4750 | actor=-70.2628 | critic=1.3331 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12542.7 | checkpoint=-
# [train] step=1941/2000 | warm=0 | policy=32 | replay=72112 | world_total=3772.4763 | actor=-69.4430 | critic=1.6371 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12547.9 | checkpoint=-
# [train] step=1942/2000 | warm=0 | policy=32 | replay=72144 | world_total=3772.5295 | actor=-68.2015 | critic=1.2846 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12553.2 | checkpoint=-
# [train] step=1943/2000 | warm=0 | policy=32 | replay=72176 | world_total=3772.5257 | actor=-67.5962 | critic=1.5831 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12558.4 | checkpoint=-
# [train] step=1944/2000 | warm=0 | policy=32 | replay=72208 | world_total=3772.5125 | actor=-67.8969 | critic=1.4479 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12563.7 | checkpoint=-
# [train] step=1945/2000 | warm=0 | policy=32 | replay=72240 | world_total=3772.5086 | actor=-69.1257 | critic=1.0289 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12568.9 | checkpoint=-
# [train] step=1946/2000 | warm=0 | policy=32 | replay=72272 | world_total=3772.4471 | actor=-70.1649 | critic=1.2456 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12574.2 | checkpoint=-
# [train] step=1947/2000 | warm=0 | policy=32 | replay=72304 | world_total=3772.4693 | actor=-69.4547 | critic=1.0208 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12579.4 | checkpoint=-
# [train] step=1948/2000 | warm=0 | policy=32 | replay=72336 | world_total=3772.4733 | actor=-68.1660 | critic=0.9997 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12584.6 | checkpoint=-
# [train] step=1949/2000 | warm=0 | policy=32 | replay=72368 | world_total=3772.4520 | actor=-68.0009 | critic=0.9787 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12589.8 | checkpoint=-
# [train] step=1950/2000 | warm=0 | policy=32 | replay=72400 | world_total=3772.4215 | actor=-67.6570 | critic=1.0261 | eval_reward=34.5095 | cycle_s=30.9 | elapsed_s=12620.7 | checkpoint=checkpoint_01950.pt
# [train] step=1951/2000 | warm=0 | policy=32 | replay=72432 | world_total=3772.4063 | actor=-67.6353 | critic=1.0268 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12626.0 | checkpoint=-
# [train] step=1952/2000 | warm=0 | policy=32 | replay=72464 | world_total=3772.4887 | actor=-68.9021 | critic=0.9883 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=12631.4 | checkpoint=-
# [train] step=1953/2000 | warm=0 | policy=32 | replay=72496 | world_total=3772.4449 | actor=-70.1497 | critic=1.0443 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=12637.0 | checkpoint=-
# [train] step=1954/2000 | warm=0 | policy=32 | replay=72528 | world_total=3772.4814 | actor=-69.5356 | critic=1.6897 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=12642.9 | checkpoint=-
# [train] step=1955/2000 | warm=0 | policy=32 | replay=72560 | world_total=3772.4364 | actor=-67.8589 | critic=1.5819 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12648.1 | checkpoint=-
# [train] step=1956/2000 | warm=0 | policy=32 | replay=72592 | world_total=3772.4601 | actor=-67.4813 | critic=1.6461 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12653.4 | checkpoint=-
# [train] step=1957/2000 | warm=0 | policy=32 | replay=72624 | world_total=3772.4474 | actor=-67.7745 | critic=2.2255 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12658.6 | checkpoint=-
# [train] step=1958/2000 | warm=0 | policy=32 | replay=72656 | world_total=3772.4684 | actor=-67.4328 | critic=1.5404 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=12664.0 | checkpoint=-
# [train] step=1959/2000 | warm=0 | policy=32 | replay=72688 | world_total=3772.5091 | actor=-67.2998 | critic=2.1914 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12669.3 | checkpoint=-
# [train] step=1960/2000 | warm=0 | policy=32 | replay=72720 | world_total=3772.5216 | actor=-67.9582 | critic=1.2821 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12674.5 | checkpoint=-
# [train] step=1961/2000 | warm=0 | policy=32 | replay=72752 | world_total=3772.4681 | actor=-68.2781 | critic=1.2658 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12679.7 | checkpoint=-
# [train] step=1962/2000 | warm=0 | policy=32 | replay=72784 | world_total=3772.5469 | actor=-67.6503 | critic=1.3808 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12684.9 | checkpoint=-
# [train] step=1963/2000 | warm=0 | policy=32 | replay=72816 | world_total=3772.4889 | actor=-67.2627 | critic=1.5210 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12690.1 | checkpoint=-
# [train] step=1964/2000 | warm=0 | policy=32 | replay=72848 | world_total=3772.4820 | actor=-67.9408 | critic=1.0231 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12695.3 | checkpoint=-
# [train] step=1965/2000 | warm=0 | policy=32 | replay=72880 | world_total=3772.4667 | actor=-68.1542 | critic=3.4498 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12700.6 | checkpoint=-
# [train] step=1966/2000 | warm=0 | policy=32 | replay=72912 | world_total=3772.4987 | actor=-66.8083 | critic=2.7447 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12705.8 | checkpoint=-
# [train] step=1967/2000 | warm=0 | policy=32 | replay=72944 | world_total=3772.4777 | actor=-67.1714 | critic=2.0057 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12711.0 | checkpoint=-
# [train] step=1968/2000 | warm=0 | policy=32 | replay=72976 | world_total=3772.4929 | actor=-68.3573 | critic=1.0003 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12716.3 | checkpoint=-
# [train] step=1969/2000 | warm=0 | policy=32 | replay=73008 | world_total=3772.4355 | actor=-68.5503 | critic=1.0865 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12721.5 | checkpoint=-
# [train] step=1970/2000 | warm=0 | policy=32 | replay=73040 | world_total=3772.4795 | actor=-68.0712 | critic=0.9722 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12726.7 | checkpoint=-
# [train] step=1971/2000 | warm=0 | policy=32 | replay=73072 | world_total=3772.4743 | actor=-67.6029 | critic=0.9763 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12732.0 | checkpoint=-
# [train] step=1972/2000 | warm=0 | policy=32 | replay=73104 | world_total=3772.5377 | actor=-67.9134 | critic=1.0784 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12737.3 | checkpoint=-
# [train] step=1973/2000 | warm=0 | policy=32 | replay=73136 | world_total=3772.5013 | actor=-68.3449 | critic=1.2055 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12742.5 | checkpoint=-
# [train] step=1974/2000 | warm=0 | policy=32 | replay=73168 | world_total=3772.4400 | actor=-68.1392 | critic=1.0616 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12747.7 | checkpoint=-
# [train] step=1975/2000 | warm=0 | policy=32 | replay=73200 | world_total=3772.4738 | actor=-67.2885 | critic=1.0114 | eval_reward=34.4472 | cycle_s=31.1 | elapsed_s=12778.8 | checkpoint=checkpoint_01975.pt
# [train] step=1976/2000 | warm=0 | policy=32 | replay=73232 | world_total=3772.4841 | actor=-67.2857 | critic=1.1699 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12784.0 | checkpoint=-
# [train] step=1977/2000 | warm=0 | policy=32 | replay=73264 | world_total=3772.4617 | actor=-68.4429 | critic=2.0025 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=12790.0 | checkpoint=-
# [train] step=1978/2000 | warm=0 | policy=32 | replay=73296 | world_total=3772.4712 | actor=-67.7818 | critic=5.3283 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=12795.4 | checkpoint=-
# [train] step=1979/2000 | warm=0 | policy=32 | replay=73328 | world_total=3772.4266 | actor=-65.4292 | critic=2.0033 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12800.6 | checkpoint=-
# [train] step=1980/2000 | warm=0 | policy=32 | replay=73360 | world_total=3772.4118 | actor=-66.1448 | critic=1.0739 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12805.8 | checkpoint=-
# [train] step=1981/2000 | warm=0 | policy=32 | replay=73392 | world_total=3772.4489 | actor=-67.3681 | critic=2.1423 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=12811.0 | checkpoint=-
# [train] step=1982/2000 | warm=0 | policy=32 | replay=73424 | world_total=3772.4449 | actor=-66.9866 | critic=1.0329 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12816.2 | checkpoint=-
# [train] step=1983/2000 | warm=0 | policy=32 | replay=73456 | world_total=3772.4492 | actor=-66.7737 | critic=1.1137 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12821.4 | checkpoint=-
# [train] step=1984/2000 | warm=0 | policy=32 | replay=73488 | world_total=3772.4778 | actor=-66.8927 | critic=0.9558 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12826.6 | checkpoint=-
# [train] step=1985/2000 | warm=0 | policy=32 | replay=73520 | world_total=3772.4870 | actor=-67.2210 | critic=0.9612 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12831.7 | checkpoint=-
# [train] step=1986/2000 | warm=0 | policy=32 | replay=73552 | world_total=3772.4625 | actor=-68.3263 | critic=1.3378 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12836.9 | checkpoint=-
# [train] step=1987/2000 | warm=0 | policy=32 | replay=73584 | world_total=3772.3946 | actor=-68.7936 | critic=1.3541 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12842.1 | checkpoint=-
# [train] step=1988/2000 | warm=0 | policy=32 | replay=73616 | world_total=3772.4373 | actor=-67.0425 | critic=0.9959 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12847.3 | checkpoint=-
# [train] step=1989/2000 | warm=0 | policy=32 | replay=73648 | world_total=3772.4094 | actor=-65.8926 | critic=1.0668 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12852.5 | checkpoint=-
# [train] step=1990/2000 | warm=0 | policy=32 | replay=73680 | world_total=3772.4432 | actor=-66.7472 | critic=1.2336 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12857.7 | checkpoint=-
# [train] step=1991/2000 | warm=0 | policy=32 | replay=73712 | world_total=3772.4640 | actor=-68.0472 | critic=1.3081 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12862.9 | checkpoint=-
# [train] step=1992/2000 | warm=0 | policy=32 | replay=73744 | world_total=3772.4592 | actor=-67.9627 | critic=1.2650 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12868.1 | checkpoint=-
# [train] step=1993/2000 | warm=0 | policy=32 | replay=73776 | world_total=3772.5444 | actor=-66.9317 | critic=0.9815 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12873.3 | checkpoint=-
# [train] step=1994/2000 | warm=0 | policy=32 | replay=73808 | world_total=3772.4655 | actor=-66.6034 | critic=1.9899 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12878.5 | checkpoint=-
# [train] step=1995/2000 | warm=0 | policy=32 | replay=73840 | world_total=3772.4970 | actor=-66.7607 | critic=1.5267 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12883.7 | checkpoint=-
# [train] step=1996/2000 | warm=0 | policy=32 | replay=73872 | world_total=3772.5510 | actor=-67.0070 | critic=1.0402 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12889.0 | checkpoint=-
# [train] step=1997/2000 | warm=0 | policy=32 | replay=73904 | world_total=3773.7726 | actor=-68.0417 | critic=1.3519 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12894.2 | checkpoint=-
# [train] step=1998/2000 | warm=0 | policy=32 | replay=73936 | world_total=3774.2765 | actor=-68.0542 | critic=2.9887 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=12899.5 | checkpoint=-
# [train] step=1999/2000 | warm=0 | policy=32 | replay=73968 | world_total=3773.4028 | actor=-66.4742 | critic=1.0302 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=12904.8 | checkpoint=-
# [train] step=2000/2000 | warm=0 | policy=32 | replay=74000 | world_total=3772.8103 | actor=-66.7694 | critic=1.1538 | eval_reward=31.2700 | cycle_s=29.5 | elapsed_s=12934.2 | checkpoint=checkpoint_02000.pt
#
# Completed cycles: 2000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/checkpoints/checkpoint_02000.pt
# Latest metrics: {'step': 2000, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 74000, 'world_model/reconstruction_loss': 3766.517303466797, 'world_model/reconstruction_mse': 0.001242727434146218, 'world_model/observation_log_prob': -3766.517303466797, 'world_model/reward_loss': 0.9193104133009911, 'world_model/continue_loss': 0.000594707133132033, 'world_model/kl_loss': 3.3970067501068115, 'world_model/kl_loss_raw': 3.3878791332244873, 'world_model/overshooting_kl_loss': 3.952137142419815, 'world_model/overshooting_feature_mse': 3.3801735639572144, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 3772.810302734375, 'behavior/actor_loss': -66.76936912536621, 'behavior/critic_loss': 1.1537511944770813, 'behavior/imagined_reward_mean': 0.6882529556751251, 'behavior/imagined_value_mean': 66.6378984451294, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 31.270015411974793, 'evaluation/mean_steps': 46.5, 'evaluation/crash_rate': 0.1}

# %% [markdown]
# ## 4 · Training History
#
# `export_training_history_artifacts` reads `cycle_metrics.csv` and writes a multi-panel PNG (`curves`) and a JSON summary (`summary`).
#
# **How to read the reward panel:**
#
# - `behavior/imagined_reward_mean` is the world model's **average predicted reward per imagined step** during actor training, not an episode return. It therefore lives on a much smaller scale than evaluation reward.
# - `evaluation/mean_reward` is the **total real-environment reward per evaluation episode**. This is the headline performance metric and is usually much larger than imagined reward mean.
# - The updated plot uses separate y-axes so both reward signals remain visible even when their scales differ substantially.
#
# **What to look for in the curves:**
# - `reconstruction_loss` — should decrease steadily as the encoder/decoder learns to compress observations.
# - `kl_loss` — should settle at a stable positive value; collapse to zero means the stochastic state is unused.
# - `evaluation/mean_reward` — the primary performance signal; should trend upward as the actor learns.
# - `evaluation/crash_rate` — should decrease toward zero for a robust policy.

# %%
from IPython.display import Image, display
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as _ta_mod

_ta_mod = importlib.reload(_ta_mod)
export_training_history_artifacts = _ta_mod.export_training_history_artifacts

history_artifacts = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

# export_training_history_artifacts returns:
#   history_artifacts['curves']  — multi-panel learning-curves PNG
#   history_artifacts['summary'] — JSON Path with per-metric summary stats
display(Image(filename=str(history_artifacts['curves'])))
analysis_summary = json.loads(history_artifacts['summary'].read_text(encoding='utf-8'))
print(json.dumps(analysis_summary, indent=2))
# Out:
# {
#   "best_eval_mean_reward": 39.22143026556208,
#   "best_eval_reward_step": 275,
#   "best_imagined_reward_mean": 1.4093468189239502,
#   "best_imagined_reward_step": 2,
#   "best_world_model_step": 1987,
#   "best_world_model_total_loss": 3772.394561767578,
#   "largest_replay_size": 74000,
#   "largest_replay_step": 2000,
#   "last_metrics": {
#     "behavior/actor_loss": -66.76936912536621,
#     "behavior/critic_loss": 1.1537511944770813,
#     "behavior/imagined_reward_mean": 0.6882529556751251,
#     "behavior/imagined_value_mean": 66.6378984451294,
#     "evaluation/crash_rate": 0.1,
#     "evaluation/episodes": 10.0,
#     "evaluation/mean_reward": 31.270015411974793,
#     "evaluation/mean_steps": 46.5,
#     "policy_added": 32,
#     "replay_size": 74000,
#     "step": 2000,
#     "warm_start_added": 0,
#     "world_model/continue_loss": 0.000594707133132033,
#     "world_model/kl_loss": 3.3970067501068115,
#     "world_model/kl_loss_raw": 3.3878791332244873,
#     "world_model/observation_log_prob": -3766.517303466797,
#     "world_model/overshooting_feature_mse": 3.3801735639572144,
#     "world_model/overshooting_kl_loss": 3.952137142419815,
#     "world_model/overshooting_pairs": 65.0,
#     "world_model/reconstruction_loss": 3766.517303466797,
#     "world_model/reconstruction_mse": 0.001242727434146218,
#     "world_model/reward_loss": 0.9193104133009911,
#     "world_model/total_loss": 3772.810302734375
#   },
#   "last_step": 2000,
#   "num_records": 2000
# }

# %% [markdown]
# ## 5 · N-step World Model Prediction Evaluation
#
# Given a **seed observation** and the **real actions** recorded in the replay buffer, the world model is asked to predict what the next `EVAL_HORIZON` frames would look like using only the RSSM prior — no observations after the first.
#
# **Protocol:**
# 1. Encode the seed frame → posterior state (RSSM grounded in reality).
# 2. Roll forward `EVAL_HORIZON` steps via the prior, applying the recorded actions.
# 3. Decode each imagined latent to a pixel prediction.
# 4. Compare predicted vs. actual frames with MSE, PSNR, and SSIM per step.
#
# **Expected pattern:** metrics degrade with step count because autonomous vehicles move unpredictably and the prior accumulates uncertainty. Graceful degradation (slow MSE rise) indicates a well-regularised RSSM; a sharp cliff at step 2–3 indicates the prior has not learned useful multi-step dynamics.
#
# First, load the checkpoint and replay buffer companion file saved by the training loop.

# %%
import torch
from tiny_dreamer_highway.data.replay_buffer import ReplayBuffer
from tiny_dreamer_highway.evaluation.policy_rollout import _load_models_from_checkpoint
from tiny_dreamer_highway.evaluation.prediction_eval import (
    evaluate_n_step_predictions,
    evaluate_latent_rollout_consistency,
)
from tiny_dreamer_highway.evaluation.visualization import export_prediction_media_bundle

# ── Load world model and actor weights from the latest checkpoint ────────────
DEVICE = torch.device(config.device if torch.cuda.is_available() else 'cpu')
CKPT_PATH = training_summary.latest_checkpoint
world_model, actor = _load_models_from_checkpoint(CKPT_PATH, config, DEVICE)
print('World model loaded from:', CKPT_PATH)

# ── Restore the replay buffer for ground-truth observation sequences ──────────
# Each checkpoint has a companion replay_{step:05d}.pt in the same directory,
# saved automatically by the training loop.
step_num = int(CKPT_PATH.stem.split('_')[-1])
replay_path = CKPT_PATH.with_name(f'replay_{step_num:05d}.pt')
replay_buffer = ReplayBuffer(capacity=config.replay.capacity)
replay_state = torch.load(replay_path, map_location='cpu', weights_only=False)
replay_buffer.load_state_dict(replay_state)
print(f'Replay buffer restored: {len(replay_buffer):,} transitions  '
      f'(capacity: {replay_buffer.capacity:,})')
# Out:
# World model loaded from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/checkpoints/checkpoint_02000.pt
# Replay buffer restored: 74,000 transitions  (capacity: 500,000)

# %% [markdown]
# ### Checkpoint and Replay Buffer
#
# The checkpoint saved by the training loop contains:
# ```
# step              — environment step count at save time
# world_model       — state dict for encoder, RSSM, decoder, reward head, continue head
# actor             — state dict for the policy MLP (tanh-Normal output)
# critic            — state dict for the value MLP
# wm_optimizer      — AdamW / FlashAdamW state for world model parameters
# actor_optimizer   — optimizer state for actor
# critic_optimizer  — optimizer state for critic
# metrics           — list of per-cycle metric dicts logged during training
# ```
#
# The companion `replay_{step:05d}.pt` is loaded to get real held-out sequences for the prediction evaluation. Using replay data (rather than new rollouts) ensures the evaluation tests generalisation to transitions not seen during the most recent gradient updates.

# %%
# ── Sample ground-truth sequences from the replay buffer ─────────────────────
# We request sequences of length (EVAL_HORIZON + 1) so that:
#   observations[:, 0]            → seed frame fed to the encoder
#   observations[:, 1:H+1]        → H actual next frames (prediction targets)
#   actions[:, :H]                 → H actions that produced those transitions

EVAL_HORIZON = 15   # Number of imagination steps
EVAL_BATCH   = 8    # Sequences per evaluation (metrics averaged over this)

seq_batch = replay_buffer.sample_sequence_batch(
    batch_size=EVAL_BATCH,
    sequence_length=EVAL_HORIZON + 1,
)

seed_obs       = torch.as_tensor(seq_batch.observations[:, 0], device=DEVICE)
future_actions = torch.as_tensor(
    seq_batch.actions[:, :EVAL_HORIZON], dtype=torch.float32, device=DEVICE
)
target_obs     = torch.as_tensor(seq_batch.observations[:, 1:EVAL_HORIZON + 1], device=DEVICE)

print(f'seed_obs:       {tuple(seed_obs.shape)}')
print(f'future_actions: {tuple(future_actions.shape)}')
print(f'target_obs:     {tuple(target_obs.shape)}')

# ── Pixel-level n-step prediction evaluation ─────────────────────────────────
# Imagines EVAL_HORIZON steps from the seed frame, then computes MSE/PSNR/SSIM
# per step against the actual frames captured during the same transitions.
n_step_result = evaluate_n_step_predictions(world_model, seed_obs, future_actions, target_obs)

print('\nN-step prediction summary (average over all steps and batch):')
for key, value in n_step_result['summary'].items():
    print(f'  {key}: {value:.4f}')

print('\nPer-step pixel metrics (first 5 steps):')
for item in n_step_result['step_metrics'][:5]:
    step = int(item['step'])
    print(f"  step {step:2d}  MSE={item['mse']:.4f}  "
          f"PSNR={item['psnr']:.2f} dB  SSIM={item['ssim']:.4f}")
# Out:
# seed_obs:       (8, 1, 64, 64)
# future_actions: (8, 15, 2)
# target_obs:     (8, 15, 1, 64, 64)
#
# N-step prediction summary (average over all steps and batch):
#   mse_mean: 0.0400
#   psnr_mean: 14.1010
#   ssim_mean: 0.1444
#   nll_mean: 3845.8787
#
# Per-step pixel metrics (first 5 steps):
#   step  1  MSE=0.0196  PSNR=17.07 dB  SSIM=0.5495
#   step  2  MSE=0.0427  PSNR=13.69 dB  SSIM=0.0883
#   step  3  MSE=0.0440  PSNR=13.56 dB  SSIM=0.0636
#   step  4  MSE=0.0234  PSNR=16.30 dB  SSIM=0.4999
#   step  5  MSE=0.0349  PSNR=14.57 dB  SSIM=0.2819

# %% [markdown]
# ### Prediction Media Export
#
# `export_prediction_media_bundle` produces three files:
# - **`metrics_plot.png`** — MSE / PSNR / SSIM curves vs. imagination step.
# - **`comparison_grid.png`** — rows = steps, columns = Target | Predicted | Absolute Error (magma colormap).
# - **`comparison_video.gif`** — animated version of the grid at 2 fps.
#
# MSE should rise and PSNR should fall with step count. The error column highlights *where* in the frame prediction accuracy is weakest — bright regions around vehicle boundaries are expected; bright errors on empty road indicate decoder quality issues.

# %%
# ── Export side-by-side comparison media ─────────────────────────────────────
# Produces three artifacts per run:
#   metrics_plot     — PNG with per-step MSE / PSNR / SSIM curves
#   comparison_grid  — PNG with rows=steps, cols=(Target | Predicted | Error)
#   comparison_video — animated GIF showing the same layout over time (fps=2
#                      so each step is visible clearly)
from IPython.display import Image, display

pred_media = export_prediction_media_bundle(
    n_step_result['step_metrics'],
    n_step_result['predictions'],
    target_obs,
    RUN_ARTIFACT_ROOT / 'world_model_predictions',
    prefix=RUN_NAME,
    max_steps=EVAL_HORIZON,
    fps=2,
)

print('Exported prediction artifacts:')
for key, path in pred_media.items():
    print(f'  {key}: {path.name}')

print('\nPer-step metric curves (MSE / PSNR / SSIM vs imagination step):')
display(Image(filename=str(pred_media['metrics_plot'])))

print('\nComparison grid — Target | Predicted | Absolute Error per step:')
display(Image(filename=str(pred_media['comparison_grid'])))

print('\nPrediction GIF — animated Target | Predicted | Error:')
display(Image(filename=str(pred_media['comparison_video'])))
# Out:
# Exported prediction artifacts:
#   metrics_plot: final_run_001_metrics.png
#   comparison_grid: final_run_001_comparison.png
#   comparison_video: final_run_001_comparison.gif
#
# Per-step metric curves (MSE / PSNR / SSIM vs imagination step):
# Comparison grid — Target | Predicted | Absolute Error per step:
# Prediction GIF — animated Target | Predicted | Error:

# %% [markdown]
# ### Latent Rollout Consistency
#
# Measures how far the RSSM's **imagined** latent state drifts from the **observation-corrected posterior** state when the same actions are applied.
#
# Two paths from the same starting state:
# - **Grounded** — at every step the model receives the real observation and updates via the posterior.
# - **Imagined** — the model runs entirely via the prior, no observations after step 0.
#
# `latent_mse` in the table below is the feature-space MSE between these two paths at each step. Low drift means the prior has learned to stay close to what the posterior would be — which is what makes imagination-based planning reliable. The `free_nats = 3.0` threshold is the floor below which the training loss does not penalise prior–posterior divergence.

# %%
# ── Latent-space rollout consistency ─────────────────────────────────────────
# Measures how quickly the latent state drifts when the model rolls out purely
# in imagination (no observation correction).  Lower drift → tighter world model.
latent_result = evaluate_latent_rollout_consistency(
    world_model,
    seed_obs,
    future_actions,
    target_obs,
)

print('=== Latent Rollout Consistency ===')
print(f"Summary: {latent_result['summary']}")
print()
print(f"{'Step':>4}  {'Det MSE':>12}  {'Stoch MSE':>12}  {'Feature MSE':>12}  {'Prior-Post KL':>14}")
print('-' * 62)
for s in latent_result['step_metrics']:
    print(
        f"{int(s['step']):>4}  "
        f"{s['deterministic_mse']:>12.6f}  "
        f"{s['stochastic_mse']:>12.6f}  "
        f"{s['feature_mse']:>12.6f}  "
        f"{s['prior_posterior_kl']:>14.6f}"
    )
# Out:
# === Latent Rollout Consistency ===
# Summary: {'deterministic_mse_mean': 0.07221161673466364, 'stochastic_mse_mean': 34.070474243164064, 'feature_mse_mean': 4.506767161687216, 'prior_posterior_kl_mean': 5.359197616577148}
#
# Step       Det MSE     Stoch MSE   Feature MSE   Prior-Post KL
# --------------------------------------------------------------
#    1      0.000000     49.272556      6.426855        4.035267
#    2      0.034738     43.150192      5.658493        5.612714
#    3      0.051704     34.672329      4.567438        6.010641
#    4      0.063415     29.351248      3.883567        4.436328
#    5      0.063524     35.659542      4.706483        4.446596
#    6      0.077760     16.221384      2.183450        4.515190
#    7      0.066940     28.993202      3.839930        5.649538
#    8      0.078854     52.369282      6.899343        6.011278
#    9      0.095956     25.425793      3.399848        5.449274
#   10      0.080772     43.118183      5.694346        5.533346
#   11      0.087697     34.571499      4.585584        6.487088
#   12      0.092880     31.449501      4.182874        5.326008
#   13      0.097683     20.329603      2.736629        5.258543
#   14      0.089756     40.613819      5.375503        6.622055
#   15      0.101494     25.858980      3.461166        4.994099

# %% [markdown]
# ## 6 · Agent Driving Demo — Training Environment (Phase A)
#
# Record the trained actor in the **same 4-lane, 28-car environment it was trained in**. At inference the policy runs a real-time RSSM posterior loop: encode frame → observe step → actor mode (tanh of mean, not a sample) → smooth with previous action → scale and execute.
#
# 10 episodes, up to 400 steps each. A well-trained agent should accelerate in clear lanes, initiate lane changes ahead of blocked traffic, and avoid collisions.

# %%
from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos
from IPython.display import Image, display

demo_output_dir = RUN_ARTIFACT_ROOT / 'demo_training_env'

demo_bundle = record_demo_videos(
    config=config,
    checkpoint_path=CKPT_PATH,
    output_dir=demo_output_dir,
    num_episodes=10,
    max_steps=400,
    fps=15,
    seed=42,
    prefix=f'{RUN_NAME}_train_env',
    device=DEVICE,
)

# DemoBundle fields: video_paths (list of Path), results (list of RolloutResult)
ep_rewards = [result.total_reward for result in demo_bundle.results]
ep_lengths = [result.steps for result in demo_bundle.results]

print(f'Episodes recorded : {len(demo_bundle.video_paths)}')
print(f'Mean reward       : {sum(ep_rewards)/len(ep_rewards):.3f}')
print(f'Mean episode len  : {sum(ep_lengths)/len(ep_lengths):.1f}')
print(f'Videos saved to   : {demo_output_dir}')

if demo_bundle.video_paths:
    # Display first episode GIF
    display(Image(filename=str(demo_bundle.video_paths[0])))
else:
    print('No demo GIFs were written; check env.render() / render_mode configuration.')
# Out:
# [demo] episode 1/10 | steps=51 | reward=34.43 | OK | saved final_run_001_train_env_ep01.gif
# [demo] episode 2/10 | steps=51 | reward=34.51 | OK | saved final_run_001_train_env_ep02.gif
# [demo] episode 3/10 | steps=51 | reward=34.48 | OK | saved final_run_001_train_env_ep03.gif
# [demo] episode 4/10 | steps=51 | reward=34.48 | OK | saved final_run_001_train_env_ep04.gif
# [demo] episode 5/10 | steps=51 | reward=34.51 | OK | saved final_run_001_train_env_ep05.gif
# [demo] episode 6/10 | steps=51 | reward=34.32 | OK | saved final_run_001_train_env_ep06.gif
# [demo] episode 7/10 | steps=51 | reward=34.27 | OK | saved final_run_001_train_env_ep07.gif
# [demo] episode 8/10 | steps=51 | reward=34.20 | OK | saved final_run_001_train_env_ep08.gif
# [demo] episode 9/10 | steps=51 | reward=34.44 | OK | saved final_run_001_train_env_ep09.gif
# [demo] episode 10/10 | steps=51 | reward=34.49 | OK | saved final_run_001_train_env_ep10.gif
# [demo] done | avg_reward=34.41 | summary=final_run_001_train_env_summary.json
# Episodes recorded : 10
# Mean reward       : 34.412
# Mean episode len  : 51.0
# Videos saved to   : /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/demo_training_env

# %% [markdown]
# ## 7 · Showcase Demo — 6 Lanes, 45 Cars (Phase B)
#
# Evaluate the **same checkpoint** in a harder environment not seen during training. No fine-tuning — the same weights are deployed directly. The observation is always a 64×64 image, so the CNN encoder processes wider roads the same way it processes the training layout; lane markings simply appear at different pixel positions.
#
# 5 episodes, up to 600 steps each. Some reward reduction compared to Phase A is expected due to denser traffic; qualitative behaviour (staying on road, overtaking) should remain intact.

# %%
from tiny_dreamer_highway.config import load_experiment_config

showcase_config = load_experiment_config(
    PROJECT_ROOT / 'examples' / 'final_showcase_eval.yaml'
)
print(f"Showcase env: {showcase_config.env.lanes_count} lanes, "
      f"{showcase_config.env.vehicles_count} vehicles")

showcase_output_dir = RUN_ARTIFACT_ROOT / 'demo_showcase_env'

showcase_bundle = record_demo_videos(
    config=showcase_config,
    checkpoint_path=CKPT_PATH,   # same weights as training-env demo
    output_dir=showcase_output_dir,
    num_episodes=5,
    max_steps=600,
    fps=15,
    seed=99,
    prefix=f'{RUN_NAME}_showcase',
    device=DEVICE,
)

sc_rewards = [result.total_reward for result in showcase_bundle.results]
sc_lengths = [result.steps for result in showcase_bundle.results]

print(f'\nShowcase Demo (6 lanes / 45 cars):')
print(f'  Episodes recorded : {len(showcase_bundle.video_paths)}')
print(f'  Mean reward       : {sum(sc_rewards)/len(sc_rewards):.3f}')
print(f'  Mean episode len  : {sum(sc_lengths)/len(sc_lengths):.1f}')
print(f'  Videos saved to   : {showcase_output_dir}')

if showcase_bundle.video_paths:
    display(Image(filename=str(showcase_bundle.video_paths[0])))
else:
    print('No showcase GIFs were written; check env.render() / render_mode configuration.')
# Out:
# Showcase env: 6 lanes, 45 vehicles
# [demo] episode 1/5 | steps=61 | reward=41.13 | OK | saved final_run_001_showcase_ep01.gif
# [demo] episode 2/5 | steps=61 | reward=41.15 | OK | saved final_run_001_showcase_ep02.gif
# [demo] episode 3/5 | steps=61 | reward=41.08 | OK | saved final_run_001_showcase_ep03.gif
# [demo] episode 4/5 | steps=61 | reward=41.08 | OK | saved final_run_001_showcase_ep04.gif
# [demo] episode 5/5 | steps=61 | reward=41.07 | OK | saved final_run_001_showcase_ep05.gif
# [demo] done | avg_reward=41.10 | summary=final_run_001_showcase_summary.json
#
# Showcase Demo (6 lanes / 45 cars):
#   Episodes recorded : 5
#   Mean reward       : 41.101
#   Mean episode len  : 61.0
#   Videos saved to   : /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/demo_showcase_env

# %% [markdown]
# ## 8 · Submission Bundle
#
# `export_submission_bundle` copies all artifact files into a single directory and writes a `manifest.json` with the bundle name, file list, and any metadata passed in. `create_archive=True` additionally tars and gzips the directory.
#
# | Artifact | Description |
# |----------|-------------|
# | Training curves PNG | Multi-panel learning-curves figure |
# | Checkpoint | World model + actor + critic weights |
# | Comparison grid PNG | Target vs. predicted frames per step |
# | Prediction metrics plot | MSE / PSNR / SSIM curves |
# | Prediction GIF | Animated target / predicted / error |
# | Demo videos | Phase A (training env) and Phase B (showcase) first episodes |
# | JSON summaries | N-step summary, latent summary, episode stats |

# %%
from tiny_dreamer_highway.evaluation.artifact_bundle import export_submission_bundle
import json
import datetime

# ── Compute episode stats from DemoBundle.results ────────────────────────────
ep_rewards = [result.total_reward for result in demo_bundle.results]
sc_rewards = [result.total_reward for result in showcase_bundle.results]

# ── Write lightweight JSON sidecar summaries ──────────────────────────────────
summary_dir = RUN_ARTIFACT_ROOT / 'summaries'
summary_dir.mkdir(parents=True, exist_ok=True)

sidecars = {
    'n_step_summary.json': n_step_result['summary'],
    'latent_summary.json': latent_result['summary'],
    'demo_train_stats.json': {
        'num_episodes': len(demo_bundle.video_paths),
        'mean_reward': sum(ep_rewards) / len(ep_rewards),
        'rewards': ep_rewards,
    },
    'demo_showcase_stats.json': {
        'num_episodes': len(showcase_bundle.video_paths),
        'mean_reward': sum(sc_rewards) / len(sc_rewards),
        'rewards': sc_rewards,
    },
}
for fname, data in sidecars.items():
    (summary_dir / fname).write_text(json.dumps(data, indent=2, default=str))

# ── Bundle all artifacts ──────────────────────────────────────────────────────
# export_submission_bundle copies files and writes a manifest with bundle_name,
# files list, and optional metadata. No SHA digests are generated by default.
artifacts = {
    'training_curves': history_artifacts['curves'],
    'checkpoint': CKPT_PATH,
    'prediction_metrics_plot': pred_media['metrics_plot'],
    'comparison_grid': pred_media['comparison_grid'],
    'prediction_gif': pred_media['comparison_video'],
    'n_step_summary': summary_dir / 'n_step_summary.json',
    'latent_summary': summary_dir / 'latent_summary.json',
    'demo_train_stats': summary_dir / 'demo_train_stats.json',
    'demo_showcase_stats': summary_dir / 'demo_showcase_stats.json',
}
if demo_bundle.video_paths:
    artifacts['demo_train_ep0'] = demo_bundle.video_paths[0]
if showcase_bundle.video_paths:
    artifacts['demo_showcase_ep0'] = showcase_bundle.video_paths[0]

bundle_paths = export_submission_bundle(
    artifacts=artifacts,
    output_dir=DRIVE_ROOT / 'submission',
    bundle_name=f'csc580_final_{RUN_NAME}',
    metadata={
        'run_name': RUN_NAME,
        'timestamp': datetime.datetime.now().isoformat(),
        'lanes': config.env.lanes_count,
        'vehicles': config.env.vehicles_count,
        'n_step_summary': n_step_result['summary'],
        'latent_summary': latent_result['summary'],
        'demo_mean_reward': sum(ep_rewards) / len(ep_rewards),
        'showcase_mean_reward': sum(sc_rewards) / len(sc_rewards),
    },
    create_archive=True,
)

print('=== Submission Bundle ===')
for key, path in bundle_paths.items():
    print(f'  {key}: {path}')
print('\nUpload the .tar.gz to the class submission portal.')
# Out:
# === Submission Bundle ===
#   bundle_dir: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001
#   manifest: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/manifest.json
#   training_curves: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_curves.png
#   checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/checkpoint_02000.pt
#   prediction_metrics_plot: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_metrics.png
#   comparison_grid: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_comparison.png
#   prediction_gif: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_comparison.gif
#   n_step_summary: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/n_step_summary.json
#   latent_summary: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/latent_summary.json
#   demo_train_stats: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/demo_train_stats.json
#   demo_showcase_stats: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/demo_showcase_stats.json
#   demo_train_ep0: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_train_env_ep01.gif
#   demo_showcase_ep0: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_showcase_ep01.gif
#   archive: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001.zip
#
# Upload the .tar.gz to the class submission portal.
