# %% [markdown]
# # Tiny Dreamer Highway — Iter 11: Combined Speed + Anti-Jitter
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 cumulative (smoothing=0.5, vehicles=12, npc_speed=0.65, normalize=false, frame_stack=3)
# **Combined changes (Phase 2 isolation winners):**
# - Iter 8: `reward_speed_range: [26,35] → [22,30]` (anti-crash)
# - Iter 9: `high_speed_reward: 0.8 → 0.3` (anti-crash)
# - Iter 10: `steering_penalty: 0.0075 → 0.025` (anti-jitter)
#
# **Hypothesis:** Speed crashes and L/R jitter are independent problems. Combining the winners from isolated testing should fix both.

# %% [markdown]
# ## Iteration 11 — Combined winners from Phase 2
#
# Iters 6-7 (steering_change_penalty, lateral_scale) stopped traffic avoidance — rejected.
# Iters 8-9 reduced speed crashes. Iter 10 reduced jitter. This combines all three.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides (current working config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nIter5 base overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 11 Combined Overrides (Phase 2 winners) ---
# Iter 8: reward_speed_range [26,35] -> [22,30]: lower target speed
config.env.reward.reward_speed_range = [22.0, 30.0]
# Iter 9: high_speed_reward 0.8 -> 0.3: reduce speed incentive
config.env.reward.high_speed_reward = 0.3
# Iter 10: steering_penalty 0.0075 -> 0.025: penalize steering magnitude
config.env.reward.steering_penalty = 0.025

print('\nIter 11 combined overrides:')
print(f'  reward_speed_range = {config.env.reward.reward_speed_range}')
print(f'  high_speed_reward = {config.env.reward.high_speed_reward}')
print(f'  steering_penalty = {config.env.reward.steering_penalty}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Iter5 base overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#
# Iter 11 combined overrides:
#   reward_speed_range = [22.0, 30.0]
#   high_speed_reward = 0.3
#   steering_penalty = 0.025

# %%
RUN_NAME = 'iter11_combined_speed_jitter'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter11_combined_speed_jitter/checkpoints/checkpoint_00250.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter11_combined_speed_jitter
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter5_framestack/checkpoints/checkpoint_00025.pt
# Effective cycles: 250
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=250 | start_step=26 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=26/250 | warm=0 | policy=32 | replay=10832 | world_total=11450.0482 | actor=-9.9766 | critic=1.0570 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=4.8 | checkpoint=-
# [train] step=27/250 | warm=0 | policy=32 | replay=10864 | world_total=11561.0874 | actor=-1.2783 | critic=6.9642 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=8.8 | checkpoint=-
# [train] step=28/250 | warm=0 | policy=32 | replay=10896 | world_total=11486.8442 | actor=-4.3984 | critic=4.3149 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=13.1 | checkpoint=-
# [train] step=29/250 | warm=0 | policy=32 | replay=10928 | world_total=11460.6544 | actor=-10.9375 | critic=8.1135 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=17.3 | checkpoint=-
# [train] step=30/250 | warm=0 | policy=32 | replay=10960 | world_total=11455.9730 | actor=-10.1719 | critic=2.5884 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=21.5 | checkpoint=-
# [train] step=31/250 | warm=0 | policy=32 | replay=10992 | world_total=11452.1166 | actor=-11.6484 | critic=2.3735 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=25.9 | checkpoint=-
# [train] step=32/250 | warm=0 | policy=32 | replay=11024 | world_total=11450.3269 | actor=-11.1250 | critic=1.5032 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=30.3 | checkpoint=-
# [train] step=33/250 | warm=0 | policy=32 | replay=11056 | world_total=11449.3668 | actor=-11.2344 | critic=1.8863 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=34.2 | checkpoint=-
# [train] step=34/250 | warm=0 | policy=32 | replay=11088 | world_total=11448.8352 | actor=-12.6562 | critic=1.3815 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=38.7 | checkpoint=-
# [train] step=35/250 | warm=0 | policy=32 | replay=11120 | world_total=11451.4657 | actor=-9.7031 | critic=2.6982 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=42.9 | checkpoint=-
# [train] step=36/250 | warm=0 | policy=32 | replay=11152 | world_total=11449.9396 | actor=-9.1875 | critic=1.6576 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=47.4 | checkpoint=-
# [train] step=37/250 | warm=0 | policy=32 | replay=11184 | world_total=11448.3606 | actor=-10.4453 | critic=1.8533 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=51.7 | checkpoint=-
# [train] step=38/250 | warm=0 | policy=32 | replay=11216 | world_total=11446.5427 | actor=-9.2812 | critic=1.3153 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=55.6 | checkpoint=-
# [train] step=39/250 | warm=0 | policy=32 | replay=11248 | world_total=11445.9160 | actor=-8.9375 | critic=1.4026 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=60.1 | checkpoint=-
# [train] step=40/250 | warm=0 | policy=32 | replay=11280 | world_total=11444.7983 | actor=-8.0352 | critic=1.5124 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=64.3 | checkpoint=-
# [train] step=41/250 | warm=0 | policy=32 | replay=11312 | world_total=11443.6073 | actor=-7.6523 | critic=1.2755 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=68.5 | checkpoint=-
# [train] step=42/250 | warm=0 | policy=32 | replay=11344 | world_total=11442.3640 | actor=-7.4414 | critic=1.2345 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=72.7 | checkpoint=-
# [train] step=43/250 | warm=0 | policy=32 | replay=11376 | world_total=11440.9885 | actor=-6.9883 | critic=1.2866 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=77.1 | checkpoint=-
# [train] step=44/250 | warm=0 | policy=32 | replay=11408 | world_total=11438.9486 | actor=-6.1719 | critic=1.5379 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=81.0 | checkpoint=-
# [train] step=45/250 | warm=0 | policy=32 | replay=11440 | world_total=11438.0203 | actor=-6.0859 | critic=1.3882 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=85.0 | checkpoint=-
# [train] step=46/250 | warm=0 | policy=32 | replay=11472 | world_total=11437.4172 | actor=-5.0312 | critic=1.3011 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=89.2 | checkpoint=-
# [train] step=47/250 | warm=0 | policy=32 | replay=11504 | world_total=11435.8976 | actor=-4.7656 | critic=1.3475 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=93.4 | checkpoint=-
# [train] step=48/250 | warm=0 | policy=32 | replay=11536 | world_total=11434.1024 | actor=-4.2930 | critic=1.3537 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=97.3 | checkpoint=-
# [train] step=49/250 | warm=0 | policy=32 | replay=11568 | world_total=11432.8785 | actor=-3.8105 | critic=1.2252 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=101.6 | checkpoint=-
# [train] step=50/250 | warm=0 | policy=32 | replay=11600 | world_total=11431.5472 | actor=-3.8438 | critic=1.1887 | eval_reward=-0.3458 | cycle_s=10.7 | elapsed_s=112.3 | checkpoint=checkpoint_00050.pt
# [train] step=51/250 | warm=0 | policy=32 | replay=11632 | world_total=11430.6260 | actor=-3.5156 | critic=1.1677 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=116.5 | checkpoint=-
# [train] step=52/250 | warm=0 | policy=32 | replay=11664 | world_total=11429.2321 | actor=-3.2461 | critic=1.1802 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=120.5 | checkpoint=-
# [train] step=53/250 | warm=0 | policy=32 | replay=11696 | world_total=11427.9976 | actor=-3.0742 | critic=1.1537 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=124.7 | checkpoint=-
# [train] step=54/250 | warm=0 | policy=32 | replay=11728 | world_total=11427.0463 | actor=-3.0586 | critic=1.1482 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=129.1 | checkpoint=-
# [train] step=55/250 | warm=0 | policy=32 | replay=11760 | world_total=11426.3478 | actor=-2.9277 | critic=1.1590 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=133.0 | checkpoint=-
# [train] step=56/250 | warm=0 | policy=32 | replay=11792 | world_total=11425.0927 | actor=-3.1289 | critic=1.1489 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=137.0 | checkpoint=-
# [train] step=57/250 | warm=0 | policy=32 | replay=11824 | world_total=11423.9564 | actor=-3.6074 | critic=1.2045 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=141.0 | checkpoint=-
# [train] step=58/250 | warm=0 | policy=32 | replay=11856 | world_total=11422.7555 | actor=-4.0254 | critic=1.1410 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=144.8 | checkpoint=-
# [train] step=59/250 | warm=0 | policy=32 | replay=11888 | world_total=11421.3522 | actor=-5.1367 | critic=1.2877 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=148.3 | checkpoint=-
# [train] step=60/250 | warm=0 | policy=32 | replay=11920 | world_total=11420.0958 | actor=-5.9023 | critic=1.3636 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=152.1 | checkpoint=-
# [train] step=61/250 | warm=0 | policy=32 | replay=11952 | world_total=11418.6329 | actor=-6.9531 | critic=1.4183 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=156.1 | checkpoint=-
# [train] step=62/250 | warm=0 | policy=32 | replay=11984 | world_total=11418.1914 | actor=-8.4297 | critic=2.0281 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=160.0 | checkpoint=-
# [train] step=63/250 | warm=0 | policy=32 | replay=12016 | world_total=11416.4265 | actor=-8.7500 | critic=1.7444 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=163.9 | checkpoint=-
# [train] step=64/250 | warm=0 | policy=32 | replay=12048 | world_total=11415.1650 | actor=-10.1562 | critic=1.8143 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=168.2 | checkpoint=-
# [train] step=65/250 | warm=0 | policy=32 | replay=12080 | world_total=11412.9198 | actor=-11.3438 | critic=1.8002 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=172.3 | checkpoint=-
# [train] step=66/250 | warm=0 | policy=32 | replay=12112 | world_total=11411.3217 | actor=-11.7969 | critic=2.1925 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=176.5 | checkpoint=-
# [train] step=67/250 | warm=0 | policy=32 | replay=12144 | world_total=11410.0629 | actor=-12.0234 | critic=2.5220 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=180.8 | checkpoint=-
# [train] step=68/250 | warm=0 | policy=32 | replay=12176 | world_total=11408.2125 | actor=-9.2578 | critic=5.8933 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=185.1 | checkpoint=-
# [train] step=69/250 | warm=0 | policy=32 | replay=12208 | world_total=11406.5403 | actor=-7.8516 | critic=3.0143 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=189.3 | checkpoint=-
# [train] step=70/250 | warm=0 | policy=32 | replay=12240 | world_total=11404.9219 | actor=-6.9609 | critic=1.9986 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=193.4 | checkpoint=-
# [train] step=71/250 | warm=0 | policy=32 | replay=12272 | world_total=11403.0876 | actor=-6.4336 | critic=1.9605 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=197.4 | checkpoint=-
# [train] step=72/250 | warm=0 | policy=32 | replay=12304 | world_total=11401.9641 | actor=-5.8125 | critic=2.9520 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=201.3 | checkpoint=-
# [train] step=73/250 | warm=0 | policy=32 | replay=12336 | world_total=11401.1082 | actor=-5.1289 | critic=2.9645 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=205.8 | checkpoint=-
# [train] step=74/250 | warm=0 | policy=32 | replay=12368 | world_total=11399.3341 | actor=-5.5898 | critic=2.3084 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=210.0 | checkpoint=-
# [train] step=75/250 | warm=0 | policy=32 | replay=12400 | world_total=11397.4545 | actor=-4.7578 | critic=2.7359 | eval_reward=-0.4120 | cycle_s=10.6 | elapsed_s=220.6 | checkpoint=checkpoint_00075.pt
# [train] step=76/250 | warm=0 | policy=32 | replay=12432 | world_total=11395.8384 | actor=-4.8516 | critic=2.8010 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=224.9 | checkpoint=-
# [train] step=77/250 | warm=0 | policy=32 | replay=12464 | world_total=11394.3348 | actor=-2.4941 | critic=3.6101 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=229.2 | checkpoint=-
# [train] step=78/250 | warm=0 | policy=32 | replay=12496 | world_total=11392.2627 | actor=-2.9941 | critic=2.3221 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=233.5 | checkpoint=-
# [train] step=79/250 | warm=0 | policy=32 | replay=12528 | world_total=11390.3459 | actor=-2.4473 | critic=1.8947 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=237.7 | checkpoint=-
# [train] step=80/250 | warm=0 | policy=32 | replay=12560 | world_total=11388.6816 | actor=-1.8574 | critic=1.7985 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=241.9 | checkpoint=-
# [train] step=81/250 | warm=0 | policy=32 | replay=12592 | world_total=11387.1625 | actor=-3.3145 | critic=2.5997 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=245.8 | checkpoint=-
# [train] step=82/250 | warm=0 | policy=32 | replay=12624 | world_total=11384.9529 | actor=-1.8779 | critic=2.0643 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=250.1 | checkpoint=-
# [train] step=83/250 | warm=0 | policy=32 | replay=12656 | world_total=11383.0181 | actor=-2.5645 | critic=2.1008 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=254.6 | checkpoint=-
# [train] step=84/250 | warm=0 | policy=32 | replay=12688 | world_total=11381.8599 | actor=-1.1426 | critic=1.7098 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=258.5 | checkpoint=-
# [train] step=85/250 | warm=0 | policy=32 | replay=12720 | world_total=11380.3746 | actor=-1.0615 | critic=1.4699 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=262.7 | checkpoint=-
# [train] step=86/250 | warm=0 | policy=32 | replay=12752 | world_total=11379.3450 | actor=-0.7266 | critic=1.2645 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=267.3 | checkpoint=-
# [train] step=87/250 | warm=0 | policy=32 | replay=12784 | world_total=11378.5450 | actor=-0.6797 | critic=1.2371 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=271.7 | checkpoint=-
# [train] step=88/250 | warm=0 | policy=32 | replay=12816 | world_total=11376.7694 | actor=-0.6475 | critic=1.2056 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=276.0 | checkpoint=-
# [train] step=89/250 | warm=0 | policy=32 | replay=12848 | world_total=11375.5303 | actor=-1.0107 | critic=1.3531 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=280.2 | checkpoint=-
# [train] step=90/250 | warm=0 | policy=32 | replay=12880 | world_total=11374.5533 | actor=-0.9380 | critic=1.2617 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=284.4 | checkpoint=-
# [train] step=91/250 | warm=0 | policy=32 | replay=12912 | world_total=11373.4501 | actor=-0.7354 | critic=1.2212 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=288.6 | checkpoint=-
# [train] step=92/250 | warm=0 | policy=32 | replay=12944 | world_total=11372.4207 | actor=-0.6265 | critic=1.1812 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=292.5 | checkpoint=-
# [train] step=93/250 | warm=0 | policy=32 | replay=12976 | world_total=11371.7568 | actor=-0.7676 | critic=1.1779 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=296.7 | checkpoint=-
# [train] step=94/250 | warm=0 | policy=32 | replay=13008 | world_total=11370.7382 | actor=-0.8008 | critic=1.1792 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=300.8 | checkpoint=-
# [train] step=95/250 | warm=0 | policy=32 | replay=13040 | world_total=11369.7169 | actor=-0.5981 | critic=1.1402 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=304.8 | checkpoint=-
# [train] step=96/250 | warm=0 | policy=32 | replay=13072 | world_total=11368.6267 | actor=-0.6055 | critic=1.1204 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=309.2 | checkpoint=-
# [train] step=97/250 | warm=0 | policy=32 | replay=13104 | world_total=11368.0217 | actor=-0.6836 | critic=1.1335 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=313.6 | checkpoint=-
# [train] step=98/250 | warm=0 | policy=32 | replay=13136 | world_total=11366.8989 | actor=-0.6138 | critic=1.1216 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=317.7 | checkpoint=-
# [train] step=99/250 | warm=0 | policy=32 | replay=13168 | world_total=11366.3313 | actor=-0.7378 | critic=1.1759 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=321.9 | checkpoint=-
# [train] step=100/250 | warm=0 | policy=32 | replay=13200 | world_total=11365.1698 | actor=-1.0942 | critic=1.2474 | eval_reward=-0.3432 | cycle_s=10.8 | elapsed_s=332.7 | checkpoint=checkpoint_00100.pt
# [train] step=101/250 | warm=0 | policy=32 | replay=13232 | world_total=11364.0522 | actor=-1.3203 | critic=1.3109 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=336.1 | checkpoint=-
# [train] step=102/250 | warm=0 | policy=32 | replay=13264 | world_total=11363.1154 | actor=-1.9160 | critic=1.5575 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=340.0 | checkpoint=-
# [train] step=103/250 | warm=0 | policy=32 | replay=13296 | world_total=11362.0615 | actor=-2.6660 | critic=2.0283 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=343.7 | checkpoint=-
# [train] step=104/250 | warm=0 | policy=32 | replay=13328 | world_total=11360.9604 | actor=-2.9414 | critic=2.1666 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=347.6 | checkpoint=-
# [train] step=105/250 | warm=0 | policy=32 | replay=13360 | world_total=11360.4824 | actor=-3.0254 | critic=2.2704 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=351.0 | checkpoint=-
# [train] step=106/250 | warm=0 | policy=32 | replay=13392 | world_total=11359.7780 | actor=-2.8828 | critic=2.0570 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=354.6 | checkpoint=-
# [train] step=107/250 | warm=0 | policy=32 | replay=13424 | world_total=11359.1984 | actor=-3.1328 | critic=2.0392 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=358.2 | checkpoint=-
# [train] step=108/250 | warm=0 | policy=32 | replay=13456 | world_total=11358.1891 | actor=-3.0352 | critic=1.9769 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=362.0 | checkpoint=-
# [train] step=109/250 | warm=0 | policy=32 | replay=13488 | world_total=11357.6854 | actor=-3.0430 | critic=2.0259 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=365.6 | checkpoint=-
# [train] step=110/250 | warm=0 | policy=32 | replay=13520 | world_total=11356.6736 | actor=-2.9336 | critic=1.9737 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=368.9 | checkpoint=-
# [train] step=111/250 | warm=0 | policy=32 | replay=13552 | world_total=11355.7461 | actor=-3.2871 | critic=2.0033 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=372.4 | checkpoint=-
# [train] step=112/250 | warm=0 | policy=32 | replay=13584 | world_total=11355.2510 | actor=-3.4023 | critic=2.0297 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=375.9 | checkpoint=-
# [train] step=113/250 | warm=0 | policy=32 | replay=13616 | world_total=11354.4752 | actor=-3.9004 | critic=2.1326 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=378.8 | checkpoint=-
# [train] step=114/250 | warm=0 | policy=32 | replay=13648 | world_total=11354.2892 | actor=-4.1367 | critic=2.0767 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=382.4 | checkpoint=-
# [train] step=115/250 | warm=0 | policy=32 | replay=13680 | world_total=11354.1099 | actor=-4.5547 | critic=2.1068 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=385.5 | checkpoint=-
# [train] step=116/250 | warm=0 | policy=32 | replay=13712 | world_total=11353.5389 | actor=-5.2383 | critic=2.2801 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=388.5 | checkpoint=-
# [train] step=117/250 | warm=0 | policy=32 | replay=13744 | world_total=11353.7887 | actor=-6.1211 | critic=2.4227 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=391.6 | checkpoint=-
# [train] step=118/250 | warm=0 | policy=32 | replay=13776 | world_total=11354.0916 | actor=-7.0742 | critic=2.6297 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=394.7 | checkpoint=-
# [train] step=119/250 | warm=0 | policy=32 | replay=13808 | world_total=11353.2593 | actor=-8.1250 | critic=2.6781 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=397.6 | checkpoint=-
# [train] step=120/250 | warm=0 | policy=32 | replay=13840 | world_total=11353.4890 | actor=-9.3516 | critic=3.0015 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=400.7 | checkpoint=-
# [train] step=121/250 | warm=0 | policy=32 | replay=13872 | world_total=11353.1876 | actor=-10.4766 | critic=3.5970 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=404.1 | checkpoint=-
# [train] step=122/250 | warm=0 | policy=32 | replay=13904 | world_total=11352.8722 | actor=-12.2969 | critic=3.6484 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=407.7 | checkpoint=-
# [train] step=123/250 | warm=0 | policy=32 | replay=13936 | world_total=11352.3683 | actor=-13.6875 | critic=3.5278 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=410.8 | checkpoint=-
# [train] step=124/250 | warm=0 | policy=32 | replay=13968 | world_total=11351.8325 | actor=-14.9922 | critic=3.9092 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=414.1 | checkpoint=-
# [train] step=125/250 | warm=0 | policy=32 | replay=14000 | world_total=11351.9335 | actor=-16.4844 | critic=3.6248 | eval_reward=3.3114 | cycle_s=10.8 | elapsed_s=424.9 | checkpoint=checkpoint_00125.pt
# [train] step=126/250 | warm=0 | policy=32 | replay=14032 | world_total=11352.1871 | actor=-17.0312 | critic=4.1440 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=427.8 | checkpoint=-
# [train] step=127/250 | warm=0 | policy=32 | replay=14064 | world_total=11352.1973 | actor=-16.9844 | critic=5.3664 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=430.9 | checkpoint=-
# [train] step=128/250 | warm=0 | policy=32 | replay=14096 | world_total=11352.2083 | actor=-16.0781 | critic=5.3677 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=434.0 | checkpoint=-
# [train] step=129/250 | warm=0 | policy=32 | replay=14128 | world_total=11351.5098 | actor=-16.0938 | critic=4.4012 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=437.1 | checkpoint=-
# [train] step=130/250 | warm=0 | policy=32 | replay=14160 | world_total=11351.1970 | actor=-14.7188 | critic=4.6595 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=440.3 | checkpoint=-
# [train] step=131/250 | warm=0 | policy=32 | replay=14192 | world_total=11351.2914 | actor=-14.6562 | critic=4.7102 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=442.8 | checkpoint=-
# [train] step=132/250 | warm=0 | policy=32 | replay=14224 | world_total=11351.3529 | actor=-15.1172 | critic=3.9172 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=446.0 | checkpoint=-
# [train] step=133/250 | warm=0 | policy=32 | replay=14256 | world_total=11350.9612 | actor=-16.3281 | critic=3.7988 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=449.1 | checkpoint=-
# [train] step=134/250 | warm=0 | policy=32 | replay=14288 | world_total=11350.5872 | actor=-16.5156 | critic=5.4088 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=452.1 | checkpoint=-
# [train] step=135/250 | warm=0 | policy=32 | replay=14320 | world_total=11350.2626 | actor=-17.8281 | critic=4.0318 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=455.5 | checkpoint=-
# [train] step=136/250 | warm=0 | policy=32 | replay=14352 | world_total=11349.6451 | actor=-17.9375 | critic=4.3461 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=459.0 | checkpoint=-
# [train] step=137/250 | warm=0 | policy=32 | replay=14384 | world_total=11349.5785 | actor=-16.7812 | critic=6.1896 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=462.0 | checkpoint=-
# [train] step=138/250 | warm=0 | policy=32 | replay=14416 | world_total=11348.8320 | actor=-17.0312 | critic=3.8570 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=465.1 | checkpoint=-
# [train] step=139/250 | warm=0 | policy=32 | replay=14448 | world_total=11349.0756 | actor=-17.1094 | critic=3.5957 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=468.0 | checkpoint=-
# [train] step=140/250 | warm=0 | policy=32 | replay=14480 | world_total=11349.0679 | actor=-17.9219 | critic=3.7931 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=471.2 | checkpoint=-
# [train] step=141/250 | warm=0 | policy=32 | replay=14512 | world_total=11348.9783 | actor=-18.2656 | critic=4.2665 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=474.0 | checkpoint=-
# [train] step=142/250 | warm=0 | policy=32 | replay=14544 | world_total=11348.7496 | actor=-18.4844 | critic=4.4694 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=477.0 | checkpoint=-
# [train] step=143/250 | warm=0 | policy=32 | replay=14576 | world_total=11348.3914 | actor=-17.7188 | critic=4.5903 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=479.9 | checkpoint=-
# [train] step=144/250 | warm=0 | policy=32 | replay=14608 | world_total=11347.9324 | actor=-16.9375 | critic=4.5310 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=483.1 | checkpoint=-
# [train] step=145/250 | warm=0 | policy=32 | replay=14640 | world_total=11347.8481 | actor=-16.9688 | critic=3.3486 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=486.3 | checkpoint=-
# [train] step=146/250 | warm=0 | policy=32 | replay=14672 | world_total=11347.7500 | actor=-18.1406 | critic=3.3584 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=489.3 | checkpoint=-
# [train] step=147/250 | warm=0 | policy=32 | replay=14704 | world_total=11347.4309 | actor=-19.5625 | critic=4.1498 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=492.2 | checkpoint=-
# [train] step=148/250 | warm=0 | policy=32 | replay=14736 | world_total=11346.6146 | actor=-19.5781 | critic=6.7206 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=495.2 | checkpoint=-
# [train] step=149/250 | warm=0 | policy=32 | replay=14768 | world_total=11346.6265 | actor=-18.7812 | critic=5.5468 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=498.0 | checkpoint=-
# [train] step=150/250 | warm=0 | policy=32 | replay=14800 | world_total=11346.2106 | actor=-17.0938 | critic=5.1723 | eval_reward=7.7955 | cycle_s=11.0 | elapsed_s=509.0 | checkpoint=checkpoint_00150.pt
# [train] step=151/250 | warm=0 | policy=32 | replay=14832 | world_total=11346.1857 | actor=-15.6719 | critic=3.7793 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=512.0 | checkpoint=-
# [train] step=152/250 | warm=0 | policy=32 | replay=14864 | world_total=11346.0319 | actor=-15.2188 | critic=3.3140 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=514.9 | checkpoint=-
# [train] step=153/250 | warm=0 | policy=32 | replay=14896 | world_total=11345.8297 | actor=-14.9062 | critic=4.4726 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=517.8 | checkpoint=-
# [train] step=154/250 | warm=0 | policy=32 | replay=14928 | world_total=11345.9274 | actor=-14.6562 | critic=4.4606 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=521.2 | checkpoint=-
# [train] step=155/250 | warm=0 | policy=32 | replay=14960 | world_total=11345.5848 | actor=-14.0156 | critic=4.2793 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=523.9 | checkpoint=-
# [train] step=156/250 | warm=0 | policy=32 | replay=14992 | world_total=11345.0552 | actor=-13.6562 | critic=3.5386 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=527.0 | checkpoint=-
# [train] step=157/250 | warm=0 | policy=32 | replay=15024 | world_total=11345.1539 | actor=-13.8750 | critic=4.0219 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=529.8 | checkpoint=-
# [train] step=158/250 | warm=0 | policy=32 | replay=15056 | world_total=11345.1252 | actor=-14.2578 | critic=3.0314 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=532.9 | checkpoint=-
# [train] step=159/250 | warm=0 | policy=32 | replay=15088 | world_total=11345.2203 | actor=-16.0000 | critic=4.2923 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=536.2 | checkpoint=-
# [train] step=160/250 | warm=0 | policy=32 | replay=15120 | world_total=11345.2222 | actor=-16.8438 | critic=4.1727 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=540.0 | checkpoint=-
# [train] step=161/250 | warm=0 | policy=32 | replay=15152 | world_total=11345.2678 | actor=-17.2031 | critic=4.5124 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=543.0 | checkpoint=-
# [train] step=162/250 | warm=0 | policy=32 | replay=15184 | world_total=11344.9211 | actor=-18.0312 | critic=3.7560 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=546.1 | checkpoint=-
# [train] step=163/250 | warm=0 | policy=32 | replay=15216 | world_total=11345.1901 | actor=-16.9062 | critic=4.8196 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=549.1 | checkpoint=-
# [train] step=164/250 | warm=0 | policy=32 | replay=15248 | world_total=11344.8066 | actor=-15.2891 | critic=5.8040 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=552.1 | checkpoint=-
# [train] step=165/250 | warm=0 | policy=32 | replay=15280 | world_total=11344.5393 | actor=-16.4688 | critic=3.6836 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=555.0 | checkpoint=-
# [train] step=166/250 | warm=0 | policy=32 | replay=15312 | world_total=11344.8835 | actor=-16.4844 | critic=3.4199 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=557.8 | checkpoint=-
# [train] step=167/250 | warm=0 | policy=32 | replay=15344 | world_total=11344.1515 | actor=-16.7969 | critic=4.1924 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=560.7 | checkpoint=-
# [train] step=168/250 | warm=0 | policy=32 | replay=15376 | world_total=11344.3698 | actor=-19.1562 | critic=4.0095 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=563.7 | checkpoint=-
# [train] step=169/250 | warm=0 | policy=32 | replay=15408 | world_total=11344.1577 | actor=-20.8750 | critic=4.3065 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=566.8 | checkpoint=-
# [train] step=170/250 | warm=0 | policy=32 | replay=15440 | world_total=11343.7792 | actor=-21.2500 | critic=6.4559 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=569.9 | checkpoint=-
# [train] step=171/250 | warm=0 | policy=32 | replay=15472 | world_total=11344.1007 | actor=-19.3750 | critic=8.2811 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=572.9 | checkpoint=-
# [train] step=172/250 | warm=0 | policy=32 | replay=15504 | world_total=11343.3732 | actor=-18.6719 | critic=3.9036 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=575.8 | checkpoint=-
# [train] step=173/250 | warm=0 | policy=32 | replay=15536 | world_total=11343.9493 | actor=-18.0938 | critic=4.0519 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=578.8 | checkpoint=-
# [train] step=174/250 | warm=0 | policy=32 | replay=15568 | world_total=11343.4976 | actor=-18.1875 | critic=4.4801 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=581.6 | checkpoint=-
# [train] step=175/250 | warm=0 | policy=32 | replay=15600 | world_total=11342.9548 | actor=-17.7969 | critic=5.0132 | eval_reward=7.5104 | cycle_s=11.1 | elapsed_s=592.7 | checkpoint=checkpoint_00175.pt
# [train] step=176/250 | warm=0 | policy=32 | replay=15632 | world_total=11342.9397 | actor=-17.2188 | critic=4.5658 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=595.8 | checkpoint=-
# [train] step=177/250 | warm=0 | policy=32 | replay=15664 | world_total=11342.4659 | actor=-17.3594 | critic=4.8418 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=598.8 | checkpoint=-
# [train] step=178/250 | warm=0 | policy=32 | replay=15696 | world_total=11342.3135 | actor=-16.4844 | critic=4.4042 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=601.9 | checkpoint=-
# [train] step=179/250 | warm=0 | policy=32 | replay=15728 | world_total=11341.6687 | actor=-16.1797 | critic=4.3315 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=604.7 | checkpoint=-
# [train] step=180/250 | warm=0 | policy=32 | replay=15760 | world_total=11341.9159 | actor=-16.2031 | critic=3.2218 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=607.6 | checkpoint=-
# [train] step=181/250 | warm=0 | policy=32 | replay=15792 | world_total=11341.9287 | actor=-15.7500 | critic=3.7421 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=610.4 | checkpoint=-
# [train] step=182/250 | warm=0 | policy=32 | replay=15824 | world_total=11341.6510 | actor=-15.5625 | critic=4.1620 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=613.4 | checkpoint=-
# [train] step=183/250 | warm=0 | policy=32 | replay=15856 | world_total=11341.4106 | actor=-15.9219 | critic=3.1527 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=616.4 | checkpoint=-
# [train] step=184/250 | warm=0 | policy=32 | replay=15888 | world_total=11341.1689 | actor=-16.4531 | critic=3.1819 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=619.5 | checkpoint=-
# [train] step=185/250 | warm=0 | policy=32 | replay=15920 | world_total=11340.9895 | actor=-17.1250 | critic=3.5293 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=622.3 | checkpoint=-
# [train] step=186/250 | warm=0 | policy=32 | replay=15952 | world_total=11341.1635 | actor=-18.4688 | critic=3.2955 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=625.6 | checkpoint=-
# [train] step=187/250 | warm=0 | policy=32 | replay=15984 | world_total=11340.8318 | actor=-18.6250 | critic=4.6318 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=629.0 | checkpoint=-
# [train] step=188/250 | warm=0 | policy=32 | replay=16016 | world_total=11340.3555 | actor=-19.4688 | critic=3.5811 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=631.9 | checkpoint=-
# [train] step=189/250 | warm=0 | policy=32 | replay=16048 | world_total=11340.6113 | actor=-20.3594 | critic=3.4047 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=634.6 | checkpoint=-
# [train] step=190/250 | warm=0 | policy=32 | replay=16080 | world_total=11340.1486 | actor=-20.7188 | critic=3.8517 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=637.5 | checkpoint=-
# [train] step=191/250 | warm=0 | policy=32 | replay=16112 | world_total=11339.8812 | actor=-21.7188 | critic=3.1388 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=640.3 | checkpoint=-
# [train] step=192/250 | warm=0 | policy=32 | replay=16144 | world_total=11340.0167 | actor=-22.7812 | critic=3.7336 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=643.2 | checkpoint=-
# [train] step=193/250 | warm=0 | policy=32 | replay=16176 | world_total=11339.7919 | actor=-22.5938 | critic=5.2125 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=646.0 | checkpoint=-
# [train] step=194/250 | warm=0 | policy=32 | replay=16208 | world_total=11339.9028 | actor=-22.0938 | critic=4.4801 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=649.0 | checkpoint=-
# [train] step=195/250 | warm=0 | policy=32 | replay=16240 | world_total=11340.3008 | actor=-19.3906 | critic=5.7904 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=651.9 | checkpoint=-
# [train] step=196/250 | warm=0 | policy=32 | replay=16272 | world_total=11339.7406 | actor=-18.0938 | critic=3.2612 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=655.1 | checkpoint=-
# [train] step=197/250 | warm=0 | policy=32 | replay=16304 | world_total=11339.5217 | actor=-17.2812 | critic=3.1406 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=657.7 | checkpoint=-
# [train] step=198/250 | warm=0 | policy=32 | replay=16336 | world_total=11339.1869 | actor=-16.8906 | critic=3.3153 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=660.8 | checkpoint=-
# [train] step=199/250 | warm=0 | policy=32 | replay=16368 | world_total=11339.0311 | actor=-16.9531 | critic=3.3741 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=663.6 | checkpoint=-
# [train] step=200/250 | warm=0 | policy=32 | replay=16400 | world_total=11338.7549 | actor=-17.7812 | critic=3.9753 | eval_reward=3.3979 | cycle_s=10.8 | elapsed_s=674.4 | checkpoint=checkpoint_00200.pt
# [train] step=201/250 | warm=0 | policy=32 | replay=16432 | world_total=11338.6138 | actor=-17.7500 | critic=3.5976 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=677.4 | checkpoint=-
# [train] step=202/250 | warm=0 | policy=32 | replay=16464 | world_total=11338.5438 | actor=-17.2500 | critic=4.7118 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=680.4 | checkpoint=-
# [train] step=203/250 | warm=0 | policy=32 | replay=16496 | world_total=11338.2480 | actor=-18.0469 | critic=4.0147 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=683.3 | checkpoint=-
# [train] step=204/250 | warm=0 | policy=32 | replay=16528 | world_total=11337.9913 | actor=-17.1719 | critic=4.2286 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=686.2 | checkpoint=-
# [train] step=205/250 | warm=0 | policy=32 | replay=16560 | world_total=11337.7273 | actor=-16.1328 | critic=4.6889 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=688.9 | checkpoint=-
# [train] step=206/250 | warm=0 | policy=32 | replay=16592 | world_total=11337.9137 | actor=-16.2969 | critic=3.1319 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=691.7 | checkpoint=-
# [train] step=207/250 | warm=0 | policy=32 | replay=16624 | world_total=11337.8914 | actor=-16.7188 | critic=2.9699 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=694.3 | checkpoint=-
# [train] step=208/250 | warm=0 | policy=32 | replay=16656 | world_total=11337.6106 | actor=-17.0000 | critic=3.2992 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=697.5 | checkpoint=-
# [train] step=209/250 | warm=0 | policy=32 | replay=16688 | world_total=11337.5406 | actor=-17.3125 | critic=4.4048 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=700.5 | checkpoint=-
# [train] step=210/250 | warm=0 | policy=32 | replay=16720 | world_total=11337.6713 | actor=-17.5312 | critic=3.8184 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=703.7 | checkpoint=-
# [train] step=211/250 | warm=0 | policy=32 | replay=16752 | world_total=11337.1523 | actor=-17.9531 | critic=3.5840 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=706.7 | checkpoint=-
# [train] step=212/250 | warm=0 | policy=32 | replay=16784 | world_total=11336.8481 | actor=-18.2656 | critic=3.7423 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=709.8 | checkpoint=-
# [train] step=213/250 | warm=0 | policy=32 | replay=16816 | world_total=11336.9595 | actor=-16.6719 | critic=6.2295 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=712.9 | checkpoint=-
# [train] step=214/250 | warm=0 | policy=32 | replay=16848 | world_total=11336.7888 | actor=-15.9453 | critic=4.2381 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=715.6 | checkpoint=-
# [train] step=215/250 | warm=0 | policy=32 | replay=16880 | world_total=11336.5803 | actor=-15.7734 | critic=3.4821 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=718.5 | checkpoint=-
# [train] step=216/250 | warm=0 | policy=32 | replay=16912 | world_total=11336.6680 | actor=-15.5078 | critic=3.2927 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=721.3 | checkpoint=-
# [train] step=217/250 | warm=0 | policy=32 | replay=16944 | world_total=11336.6389 | actor=-16.2734 | critic=3.4421 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=724.2 | checkpoint=-
# [train] step=218/250 | warm=0 | policy=32 | replay=16976 | world_total=11336.4520 | actor=-18.0000 | critic=3.6850 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=727.4 | checkpoint=-
# [train] step=219/250 | warm=0 | policy=32 | replay=17008 | world_total=11336.1257 | actor=-16.5469 | critic=6.2804 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=730.0 | checkpoint=-
# [train] step=220/250 | warm=0 | policy=32 | replay=17040 | world_total=11336.0286 | actor=-18.1094 | critic=3.9095 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=733.3 | checkpoint=-
# [train] step=221/250 | warm=0 | policy=32 | replay=17072 | world_total=11336.0311 | actor=-18.1562 | critic=2.8795 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=735.9 | checkpoint=-
# [train] step=222/250 | warm=0 | policy=32 | replay=17104 | world_total=11335.7412 | actor=-18.7500 | critic=4.2236 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=738.7 | checkpoint=-
# [train] step=223/250 | warm=0 | policy=32 | replay=17136 | world_total=11335.8044 | actor=-18.5000 | critic=4.7540 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=741.7 | checkpoint=-
# [train] step=224/250 | warm=0 | policy=32 | replay=17168 | world_total=11335.5150 | actor=-16.7031 | critic=5.6154 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=744.8 | checkpoint=-
# [train] step=225/250 | warm=0 | policy=32 | replay=17200 | world_total=11335.5109 | actor=-16.0312 | critic=4.3153 | eval_reward=6.4233 | cycle_s=11.5 | elapsed_s=756.3 | checkpoint=checkpoint_00225.pt
# [train] step=226/250 | warm=0 | policy=32 | replay=17232 | world_total=11335.3461 | actor=-15.6328 | critic=3.3813 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=759.4 | checkpoint=-
# [train] step=227/250 | warm=0 | policy=32 | replay=17264 | world_total=11335.3125 | actor=-15.5625 | critic=3.0517 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=762.1 | checkpoint=-
# [train] step=228/250 | warm=0 | policy=32 | replay=17296 | world_total=11335.1000 | actor=-16.6406 | critic=3.5937 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=765.2 | checkpoint=-
# [train] step=229/250 | warm=0 | policy=32 | replay=17328 | world_total=11335.1243 | actor=-18.4062 | critic=3.6304 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=768.1 | checkpoint=-
# [train] step=230/250 | warm=0 | policy=32 | replay=17360 | world_total=11334.8240 | actor=-19.7969 | critic=3.8778 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=771.2 | checkpoint=-
# [train] step=231/250 | warm=0 | policy=32 | replay=17392 | world_total=11334.8286 | actor=-20.8906 | critic=4.6133 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=774.2 | checkpoint=-
# [train] step=232/250 | warm=0 | policy=32 | replay=17424 | world_total=11334.6851 | actor=-19.4531 | critic=6.6600 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=777.0 | checkpoint=-
# [train] step=233/250 | warm=0 | policy=32 | replay=17456 | world_total=11334.5107 | actor=-19.0156 | critic=4.0230 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=780.1 | checkpoint=-
# [train] step=234/250 | warm=0 | policy=32 | replay=17488 | world_total=11334.1357 | actor=-17.2031 | critic=3.9770 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=783.3 | checkpoint=-
# [train] step=235/250 | warm=0 | policy=32 | replay=17520 | world_total=11334.2418 | actor=-17.7344 | critic=3.4331 | eval_reward=n/a | cycle_s=2.5 | elapsed_s=785.8 | checkpoint=-
# [train] step=236/250 | warm=0 | policy=32 | replay=17552 | world_total=11334.1747 | actor=-17.2188 | critic=3.1974 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=790.0 | checkpoint=-
# [train] step=237/250 | warm=0 | policy=32 | replay=17584 | world_total=11334.0366 | actor=-18.4062 | critic=3.3069 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=792.9 | checkpoint=-
# [train] step=238/250 | warm=0 | policy=32 | replay=17616 | world_total=11334.0093 | actor=-19.0625 | critic=3.7295 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=795.7 | checkpoint=-
# [train] step=239/250 | warm=0 | policy=32 | replay=17648 | world_total=11333.8263 | actor=-18.4062 | critic=4.7922 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=798.7 | checkpoint=-
# [train] step=240/250 | warm=0 | policy=32 | replay=17680 | world_total=11333.5878 | actor=-19.4688 | critic=3.1425 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=801.3 | checkpoint=-
# [train] step=241/250 | warm=0 | policy=32 | replay=17712 | world_total=11333.5604 | actor=-20.5156 | critic=3.2024 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=804.4 | checkpoint=-
# [train] step=242/250 | warm=0 | policy=32 | replay=17744 | world_total=11333.5503 | actor=-20.0938 | critic=4.7153 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=807.6 | checkpoint=-
# [train] step=243/250 | warm=0 | policy=32 | replay=17776 | world_total=11333.2277 | actor=-17.2188 | critic=9.4680 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=810.4 | checkpoint=-
# [train] step=244/250 | warm=0 | policy=32 | replay=17808 | world_total=11332.9934 | actor=-15.6953 | critic=4.3251 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=813.3 | checkpoint=-
# [train] step=245/250 | warm=0 | policy=32 | replay=17840 | world_total=11333.1573 | actor=-14.9453 | critic=2.7420 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=816.3 | checkpoint=-
# [train] step=246/250 | warm=0 | policy=32 | replay=17872 | world_total=11332.9142 | actor=-15.7031 | critic=3.4992 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=819.1 | checkpoint=-
# [train] step=247/250 | warm=0 | policy=32 | replay=17904 | world_total=11332.9067 | actor=-17.3438 | critic=3.5012 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=821.9 | checkpoint=-
# [train] step=248/250 | warm=0 | policy=32 | replay=17936 | world_total=11332.7102 | actor=-18.1094 | critic=3.7532 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=825.0 | checkpoint=-
# [train] step=249/250 | warm=0 | policy=32 | replay=17968 | world_total=11332.7432 | actor=-17.8594 | critic=5.7927 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=828.2 | checkpoint=-
# [train] step=250/250 | warm=0 | policy=32 | replay=18000 | world_total=11332.5967 | actor=-18.0469 | critic=3.3949 | eval_reward=14.7566 | cycle_s=12.3 | elapsed_s=840.5 | checkpoint=checkpoint_00250.pt
# Completed cycles: 250
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter11_combined_speed_jitter/checkpoints/checkpoint_00250.pt
# Latest metrics: {'step': 250, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 18000, 'world_model/reconstruction_loss': 11318.894775390625, 'world_model/reconstruction_mse': 0.00439092650776729, 'world_model/observation_log_prob': -11318.894775390625, 'world_model/reward_loss': 1.1989633589982986, 'world_model/continue_loss': 0.022560003213584423, 'world_model/kl_loss': 8.112407088279724, 'world_model/kl_loss_raw': 8.112407088279724, 'world_model/overshooting_kl_loss': 8.73555612564087, 'world_model/overshooting_feature_mse': 0.08281358145177364, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11332.5966796875, 'behavior/actor_loss': -18.046875, 'behavior/critic_loss': 3.394896447658539, 'behavior/imagined_reward_mean': 0.5107421875, 'behavior/imagined_value_mean': 18.09375, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 14.75662878057253, 'evaluation/mean_steps': 30.7, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter11_combined_speed_jitter/checkpoints/checkpoint_00250.pt',
#  'latest_metrics': {'behavior/actor_loss': -18.046875,
#   'behavior/critic_loss': 3.394896447658539,
#   'behavior/imagined_reward_mean': 0.5107421875,
#   'behavior/imagined_value_mean': 18.09375,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 14.75662878057253,
#   'evaluation/mean_steps': 30.7,
#   'policy_added': 32,
#   'replay_size': 18000,
#   'step': 250,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.022560003213584423,
#   'world_model/kl_loss': 8.112407088279724,
#   'world_model/kl_loss_raw': 8.112407088279724,
#   'world_model/observation_log_prob': -11318.894775390625,
#   'world_model/overshooting_feature_mse': 0.08281358145177364,
#   'world_model/overshooting_kl_loss': 8.73555612564087,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11318.894775390625,
#   'world_model/reconstruction_mse': 0.00439092650776729,
#   'world_model/reward_loss': 1.1989633589982986,
#   'world_model/total_loss': 11332.5966796875},
#  'latest_step': 250}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 14.75662878057253,
#   'best_eval_reward_step': 250,
#   'best_imagined_reward_mean': 0.640625,
#   'best_imagined_reward_step': 159,
#   'best_world_model_step': 250,
#   'best_world_model_total_loss': 11332.5966796875,
#   'largest_replay_size': 18000,
#   'largest_replay_step': 250,
#   'last_metrics': {'behavior/actor_loss': -18.046875,
#    'behavior/critic_loss': 3.394896447658539,
#    'behavior/imagined_reward_mean': 0.5107421875,
#    'behavior/imagined_value_mean': 18.09375,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 14.75662878057253,
#    'evaluation/mean_steps': 30.7,
#    'policy_added': 32,
#    'replay_size': 18000,
#    'step': 250,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.022560003213584423,
#    'world_model/kl_loss': 8.112407088279724,
#    'world_model/kl_loss_raw': 8.112407088279724,
#    'world_model/observation_log_prob': -11318.894775390625,
#    'world_model/overshooting_feature_mse': 0.08281358145177364,
#    'world_model/overshooting_kl_loss': 8.73555612564087,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11318.894775390625,
#    'world_model/reconstruction_mse': 0.00439092650776729,
#    'world_model/reward_loss': 1.1989633589982986,
#    'world_model/total_loss': 11332.5966796875},
#   'last_step': 250,
#   'num_records': 225},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11318.894775390625',
#   'world_model/reconstruction_mse': '0.00439092650776729',
#   'world_model/observation_log_prob': '-11318.894775390625',
#   'world_model/overshooting_kl_loss': '8.73555612564087',
#   'world_model/overshooting_feature_mse': '0.08281358145177364',
#   'evaluation/mean_reward': '14.75662878057253',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=24 | reward=12.07 | CRASH | saved iter11_combined_speed_jitter_ep01.gif
# [demo] episode 2/10 | steps=9 | reward=-0.10 | CRASH | saved iter11_combined_speed_jitter_ep02.gif
# [demo] episode 3/10 | steps=31 | reward=16.08 | CRASH | saved iter11_combined_speed_jitter_ep03.gif
# [demo] episode 4/10 | steps=37 | reward=19.37 | CRASH | saved iter11_combined_speed_jitter_ep04.gif
# [demo] episode 5/10 | steps=27 | reward=11.96 | CRASH | saved iter11_combined_speed_jitter_ep05.gif
# [demo] episode 6/10 | steps=15 | reward=6.74 | CRASH | saved iter11_combined_speed_jitter_ep06.gif
# [demo] episode 7/10 | steps=20 | reward=7.18 | CRASH | saved iter11_combined_speed_jitter_ep07.gif
# [demo] episode 8/10 | steps=16 | reward=4.29 | CRASH | saved iter11_combined_speed_jitter_ep08.gif
# [demo] episode 9/10 | steps=7 | reward=-0.42 | CRASH | saved iter11_combined_speed_jitter_ep09.gif
# [demo] episode 10/10 | steps=7 | reward=-0.36 | CRASH | saved iter11_combined_speed_jitter_ep10.gif
# [demo] done | avg_reward=7.68 | summary=iter11_combined_speed_jitter_summary.json
#
# iter11_combined_speed_jitter_ep01.gif
# iter11_combined_speed_jitter_ep02.gif
# iter11_combined_speed_jitter_ep03.gif
# iter11_combined_speed_jitter_ep04.gif
# iter11_combined_speed_jitter_ep05.gif
# iter11_combined_speed_jitter_ep06.gif
# iter11_combined_speed_jitter_ep07.gif
# iter11_combined_speed_jitter_ep08.gif
# iter11_combined_speed_jitter_ep09.gif
# iter11_combined_speed_jitter_ep10.gif
