# %% [markdown]
# # Tiny Dreamer Highway — Iter 24: Mid Steering Penalty on Iter 17 Base
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10 + iter17 (no entropy)
# **Change:** `steering_penalty: 0.025 → 0.020`
#
# **Hypothesis:** Iter 22 (0.015) went off-road — too much steering freedom.
# Iter 17 (0.025) is passive — won't lane-change at all past ~1500 cycles.
# 0.020 is the tightest middle ground: still penalizes jitter but may allow
# occasional lane changes when the overtake reward is high enough.

# %% [markdown]
# ## Iteration 24 — Mid steering penalty (0.020)
#
# Phase 4 showed 0.015 goes off-road (iters 22, 23) while 0.025 goes passive.
# This tests the narrowest middle ground on the stable iter 17 base.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/GrandpaDrivers'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD
# Already on 'GrandpaDrivers'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'examples' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base + Iter10 winner (current best config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nBase overrides (iter5 + iter10):')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 17 Combined Overrides (Phase 3 winners) ---
# Iter 13: max_episode_steps 75 -> 120: longer episodes for more diverse data
config.env.max_episode_steps = 120
# Iter 15: batch_size 256 -> 384: more diverse transitions per update
config.training.batch_size = 384

# --- Iter 24: Mid steering penalty ---
# 0.025 (iter 17) = passive; 0.015 (iter 22) = off-road; 0.020 = middle ground
config.env.reward.steering_penalty = 0.020

print('\nIter 17 base overrides:')
print(f'  max_episode_steps = {config.env.max_episode_steps}')
print(f'  batch_size = {config.training.batch_size}')
print(f'\nIter 24 change:')
print(f'  steering_penalty = {config.env.reward.steering_penalty}  (was 0.025)')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "actor_entropy_weight": 0.0,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Base overrides (iter5 + iter10):
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#
# Iter 17 base overrides:
#   max_episode_steps = 120
#   batch_size = 384
#
# Iter 24 change:
#   steering_penalty = 0.02  (was 0.025)

# %%
RUN_NAME = 'iter24_mid_steering'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 1000
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/' + RUN_NAME + '/checkpoints/checkpoint_00500.pt'

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter24_mid_steering
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter24_mid_steering/checkpoints/checkpoint_00500.pt
# Effective cycles: 1000
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=1000 | start_step=501 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=501/1000 | warm=0 | policy=32 | replay=15352 | world_total=11301.4473 | actor=-60.1250 | critic=2.5264 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=6.8 | checkpoint=-
# [train] step=502/1000 | warm=0 | policy=32 | replay=15384 | world_total=11301.4857 | actor=-60.3125 | critic=2.6192 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=13.8 | checkpoint=-
# [train] step=503/1000 | warm=0 | policy=32 | replay=15416 | world_total=11301.4381 | actor=-59.8750 | critic=3.5357 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=20.7 | checkpoint=-
# [train] step=504/1000 | warm=0 | policy=32 | replay=15448 | world_total=11301.3998 | actor=-59.7812 | critic=3.3553 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=27.2 | checkpoint=-
# [train] step=505/1000 | warm=0 | policy=32 | replay=15480 | world_total=11301.3767 | actor=-59.3750 | critic=4.1736 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=33.9 | checkpoint=-
# [train] step=506/1000 | warm=0 | policy=32 | replay=15512 | world_total=11301.3750 | actor=-59.1875 | critic=4.8994 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=40.9 | checkpoint=-
# [train] step=507/1000 | warm=0 | policy=32 | replay=15544 | world_total=11301.3265 | actor=-59.1250 | critic=4.2577 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=47.7 | checkpoint=-
# [train] step=508/1000 | warm=0 | policy=32 | replay=15576 | world_total=11301.3292 | actor=-59.0938 | critic=3.6484 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=54.3 | checkpoint=-
# [train] step=509/1000 | warm=0 | policy=32 | replay=15608 | world_total=11301.3019 | actor=-58.4375 | critic=3.7316 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=61.3 | checkpoint=-
# [train] step=510/1000 | warm=0 | policy=32 | replay=15640 | world_total=11301.2892 | actor=-58.7500 | critic=3.2595 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=68.5 | checkpoint=-
# [train] step=511/1000 | warm=0 | policy=32 | replay=15672 | world_total=11301.2872 | actor=-58.5312 | critic=2.6951 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=75.6 | checkpoint=-
# [train] step=512/1000 | warm=0 | policy=32 | replay=15704 | world_total=11301.2670 | actor=-58.1250 | critic=2.3649 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=82.1 | checkpoint=-
# [train] step=513/1000 | warm=0 | policy=32 | replay=15736 | world_total=11301.2657 | actor=-57.5625 | critic=2.0581 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=88.6 | checkpoint=-
# [train] step=514/1000 | warm=0 | policy=32 | replay=15768 | world_total=11301.4810 | actor=-57.0000 | critic=2.0606 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=95.3 | checkpoint=-
# [train] step=515/1000 | warm=0 | policy=32 | replay=15800 | world_total=11302.3718 | actor=-56.8125 | critic=2.0857 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=102.1 | checkpoint=-
# [train] step=516/1000 | warm=0 | policy=32 | replay=15832 | world_total=11302.3417 | actor=-57.9062 | critic=1.9617 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=108.5 | checkpoint=-
# [train] step=517/1000 | warm=0 | policy=32 | replay=15864 | world_total=11301.7632 | actor=-58.4688 | critic=2.1610 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=114.8 | checkpoint=-
# [train] step=518/1000 | warm=0 | policy=32 | replay=15896 | world_total=11301.9785 | actor=-58.2188 | critic=2.5495 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=121.5 | checkpoint=-
# [train] step=519/1000 | warm=0 | policy=32 | replay=15928 | world_total=11301.8041 | actor=-58.7188 | critic=2.4427 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=128.4 | checkpoint=-
# [train] step=520/1000 | warm=0 | policy=32 | replay=15960 | world_total=11302.9603 | actor=-58.5000 | critic=2.1318 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=135.4 | checkpoint=-
# [train] step=521/1000 | warm=0 | policy=32 | replay=15992 | world_total=11303.1151 | actor=-58.7500 | critic=2.2963 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=142.3 | checkpoint=-
# [train] step=522/1000 | warm=0 | policy=32 | replay=16024 | world_total=11302.0298 | actor=-58.2500 | critic=2.3637 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=148.9 | checkpoint=-
# [train] step=523/1000 | warm=0 | policy=32 | replay=16056 | world_total=11302.1866 | actor=-58.5312 | critic=2.3126 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=156.6 | checkpoint=-
# [train] step=524/1000 | warm=0 | policy=32 | replay=16088 | world_total=11301.9833 | actor=-58.7812 | critic=3.6523 | eval_reward=n/a | cycle_s=18.6 | elapsed_s=175.2 | checkpoint=-
# [train] step=525/1000 | warm=0 | policy=32 | replay=16120 | world_total=11301.8170 | actor=-59.3438 | critic=4.0018 | eval_reward=-0.5258 | cycle_s=29.3 | elapsed_s=204.5 | checkpoint=checkpoint_00525.pt
# [train] step=526/1000 | warm=0 | policy=32 | replay=16152 | world_total=11301.8711 | actor=-59.6250 | critic=3.2578 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=214.4 | checkpoint=-
# [train] step=527/1000 | warm=0 | policy=32 | replay=16184 | world_total=11301.7886 | actor=-59.0312 | critic=3.2747 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=222.8 | checkpoint=-
# [train] step=528/1000 | warm=0 | policy=32 | replay=16216 | world_total=11301.7920 | actor=-58.6875 | critic=3.1269 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=229.5 | checkpoint=-
# [train] step=529/1000 | warm=0 | policy=32 | replay=16248 | world_total=11301.6255 | actor=-59.2188 | critic=3.1508 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=236.3 | checkpoint=-
# [train] step=530/1000 | warm=0 | policy=32 | replay=16280 | world_total=11301.4855 | actor=-58.4375 | critic=2.2638 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=243.7 | checkpoint=-
# [train] step=531/1000 | warm=0 | policy=32 | replay=16312 | world_total=11301.4069 | actor=-59.1875 | critic=2.6021 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=250.8 | checkpoint=-
# [train] step=532/1000 | warm=0 | policy=32 | replay=16344 | world_total=11301.2924 | actor=-58.6875 | critic=1.8976 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=257.6 | checkpoint=-
# [train] step=533/1000 | warm=0 | policy=32 | replay=16376 | world_total=11301.2610 | actor=-58.0938 | critic=1.9560 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=264.8 | checkpoint=-
# [train] step=534/1000 | warm=0 | policy=32 | replay=16408 | world_total=11301.2336 | actor=-58.2188 | critic=1.6220 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=271.7 | checkpoint=-
# [train] step=535/1000 | warm=0 | policy=32 | replay=16440 | world_total=11301.2019 | actor=-58.1875 | critic=1.7196 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=279.0 | checkpoint=-
# [train] step=536/1000 | warm=0 | policy=32 | replay=16472 | world_total=11301.1755 | actor=-57.0938 | critic=1.6069 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=285.1 | checkpoint=-
# [train] step=537/1000 | warm=0 | policy=32 | replay=16504 | world_total=11301.1620 | actor=-57.3125 | critic=1.6495 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=291.9 | checkpoint=-
# [train] step=538/1000 | warm=0 | policy=32 | replay=16536 | world_total=11301.1301 | actor=-56.2500 | critic=1.7025 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=298.7 | checkpoint=-
# [train] step=539/1000 | warm=0 | policy=32 | replay=16568 | world_total=11301.1257 | actor=-52.5000 | critic=1.8704 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=305.9 | checkpoint=-
# [train] step=540/1000 | warm=0 | policy=32 | replay=16600 | world_total=11301.1434 | actor=-48.5938 | critic=1.7886 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=312.9 | checkpoint=-
# [train] step=541/1000 | warm=0 | policy=32 | replay=16632 | world_total=11301.1218 | actor=-49.2188 | critic=1.7171 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=319.6 | checkpoint=-
# [train] step=542/1000 | warm=0 | policy=32 | replay=16664 | world_total=11301.1011 | actor=-49.6875 | critic=2.0606 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=326.5 | checkpoint=-
# [train] step=543/1000 | warm=0 | policy=32 | replay=16696 | world_total=11302.8895 | actor=-48.6875 | critic=1.8383 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=333.1 | checkpoint=-
# [train] step=544/1000 | warm=0 | policy=32 | replay=16728 | world_total=11301.9497 | actor=-50.7188 | critic=1.5391 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=340.1 | checkpoint=-
# [train] step=545/1000 | warm=0 | policy=32 | replay=16760 | world_total=11301.8623 | actor=-52.4688 | critic=1.6642 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=346.8 | checkpoint=-
# [train] step=546/1000 | warm=0 | policy=32 | replay=16792 | world_total=11302.0922 | actor=-55.4375 | critic=1.8945 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=353.8 | checkpoint=-
# [train] step=547/1000 | warm=0 | policy=32 | replay=16824 | world_total=11301.8646 | actor=-59.1562 | critic=2.1752 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=360.5 | checkpoint=-
# [train] step=548/1000 | warm=0 | policy=32 | replay=16856 | world_total=11301.9963 | actor=-58.2500 | critic=1.8700 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=367.1 | checkpoint=-
# [train] step=549/1000 | warm=0 | policy=32 | replay=16888 | world_total=11302.2036 | actor=-58.2188 | critic=1.7392 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=374.1 | checkpoint=-
# [train] step=550/1000 | warm=0 | policy=32 | replay=16920 | world_total=11302.6050 | actor=-58.2500 | critic=1.7041 | eval_reward=-0.5315 | cycle_s=61.1 | elapsed_s=435.1 | checkpoint=checkpoint_00550.pt
# [train] step=551/1000 | warm=0 | policy=32 | replay=16952 | world_total=11302.7639 | actor=-58.5312 | critic=2.5284 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=441.6 | checkpoint=-
# [train] step=552/1000 | warm=0 | policy=32 | replay=16984 | world_total=11302.4293 | actor=-59.5000 | critic=3.7330 | eval_reward=n/a | cycle_s=11.5 | elapsed_s=453.0 | checkpoint=-
# [train] step=553/1000 | warm=0 | policy=32 | replay=17016 | world_total=11302.8091 | actor=-59.4062 | critic=3.8575 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=461.0 | checkpoint=-
# [train] step=554/1000 | warm=0 | policy=32 | replay=17048 | world_total=11302.4304 | actor=-59.9062 | critic=4.1342 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=467.7 | checkpoint=-
# [train] step=555/1000 | warm=0 | policy=32 | replay=17080 | world_total=11302.3567 | actor=-59.6250 | critic=3.4226 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=475.2 | checkpoint=-
# [train] step=556/1000 | warm=0 | policy=32 | replay=17112 | world_total=11302.2932 | actor=-60.1250 | critic=3.3650 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=481.6 | checkpoint=-
# [train] step=557/1000 | warm=0 | policy=32 | replay=17144 | world_total=11302.2257 | actor=-59.6875 | critic=3.1858 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=488.4 | checkpoint=-
# [train] step=558/1000 | warm=0 | policy=32 | replay=17176 | world_total=11302.1128 | actor=-60.4375 | critic=2.7559 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=495.2 | checkpoint=-
# [train] step=559/1000 | warm=0 | policy=32 | replay=17208 | world_total=11302.2000 | actor=-59.7500 | critic=2.9611 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=501.5 | checkpoint=-
# [train] step=560/1000 | warm=0 | policy=32 | replay=17240 | world_total=11302.1544 | actor=-60.5312 | critic=2.4636 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=508.7 | checkpoint=-
# [train] step=561/1000 | warm=0 | policy=32 | replay=17272 | world_total=11301.9806 | actor=-59.9688 | critic=3.0808 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=515.3 | checkpoint=-
# [train] step=562/1000 | warm=0 | policy=32 | replay=17304 | world_total=11302.0259 | actor=-60.8125 | critic=2.3716 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=522.2 | checkpoint=-
# [train] step=563/1000 | warm=0 | policy=32 | replay=17336 | world_total=11301.9407 | actor=-60.4062 | critic=2.7555 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=529.4 | checkpoint=-
# [train] step=564/1000 | warm=0 | policy=32 | replay=17368 | world_total=11301.9426 | actor=-59.9375 | critic=2.9601 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=536.3 | checkpoint=-
# [train] step=565/1000 | warm=0 | policy=32 | replay=17400 | world_total=11302.0795 | actor=-60.0938 | critic=2.3324 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=542.7 | checkpoint=-
# [train] step=566/1000 | warm=0 | policy=32 | replay=17432 | world_total=11301.9462 | actor=-60.5312 | critic=2.2467 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=549.6 | checkpoint=-
# [train] step=567/1000 | warm=0 | policy=32 | replay=17464 | world_total=11301.9478 | actor=-60.4375 | critic=2.7565 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=556.6 | checkpoint=-
# [train] step=568/1000 | warm=0 | policy=32 | replay=17496 | world_total=11302.0701 | actor=-60.6562 | critic=2.2931 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=564.6 | checkpoint=-
# [train] step=569/1000 | warm=0 | policy=32 | replay=17528 | world_total=11301.9852 | actor=-60.6875 | critic=2.0853 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=570.7 | checkpoint=-
# [train] step=570/1000 | warm=0 | policy=32 | replay=17560 | world_total=11301.9679 | actor=-60.1875 | critic=2.6397 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=577.5 | checkpoint=-
# [train] step=571/1000 | warm=0 | policy=32 | replay=17592 | world_total=11302.0033 | actor=-60.3125 | critic=2.6465 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=586.5 | checkpoint=-
# [train] step=572/1000 | warm=0 | policy=32 | replay=17624 | world_total=11301.9818 | actor=-60.4688 | critic=2.0921 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=593.9 | checkpoint=-
# [train] step=573/1000 | warm=0 | policy=32 | replay=17656 | world_total=11302.0414 | actor=-60.9375 | critic=1.9998 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=600.8 | checkpoint=-
# [train] step=574/1000 | warm=0 | policy=32 | replay=17688 | world_total=11301.4808 | actor=-60.6875 | critic=2.0472 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=609.8 | checkpoint=-
# [train] step=575/1000 | warm=0 | policy=32 | replay=17720 | world_total=11301.2897 | actor=-60.7188 | critic=2.4959 | eval_reward=-0.5287 | cycle_s=68.4 | elapsed_s=678.2 | checkpoint=checkpoint_00575.pt
# [train] step=576/1000 | warm=0 | policy=32 | replay=17752 | world_total=11301.1261 | actor=-60.3438 | critic=3.3686 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=686.1 | checkpoint=-
# [train] step=577/1000 | warm=0 | policy=32 | replay=17784 | world_total=11301.0487 | actor=-60.3125 | critic=3.7190 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=693.3 | checkpoint=-
# [train] step=578/1000 | warm=0 | policy=32 | replay=17816 | world_total=11300.9966 | actor=-59.8750 | critic=3.7335 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=700.4 | checkpoint=-
# [train] step=579/1000 | warm=0 | policy=32 | replay=17848 | world_total=11300.9454 | actor=-60.0312 | critic=3.7815 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=708.0 | checkpoint=-
# [train] step=580/1000 | warm=0 | policy=32 | replay=17880 | world_total=11300.8994 | actor=-59.4688 | critic=3.6407 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=714.6 | checkpoint=-
# [train] step=581/1000 | warm=0 | policy=32 | replay=17912 | world_total=11300.9094 | actor=-59.4688 | critic=3.3421 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=721.3 | checkpoint=-
# [train] step=582/1000 | warm=0 | policy=32 | replay=17944 | world_total=11300.8651 | actor=-59.0625 | critic=3.0798 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=728.3 | checkpoint=-
# [train] step=583/1000 | warm=0 | policy=32 | replay=17976 | world_total=11300.8474 | actor=-59.0000 | critic=3.0093 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=735.2 | checkpoint=-
# [train] step=584/1000 | warm=0 | policy=32 | replay=18008 | world_total=11300.8479 | actor=-58.9062 | critic=2.6522 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=742.5 | checkpoint=-
# [train] step=585/1000 | warm=0 | policy=32 | replay=18040 | world_total=11300.8448 | actor=-58.5938 | critic=2.0646 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=749.4 | checkpoint=-
# [train] step=586/1000 | warm=0 | policy=32 | replay=18072 | world_total=11300.8207 | actor=-58.2500 | critic=2.0830 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=756.2 | checkpoint=-
# [train] step=587/1000 | warm=0 | policy=32 | replay=18104 | world_total=11300.8174 | actor=-58.5625 | critic=1.8607 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=763.3 | checkpoint=-
# [train] step=588/1000 | warm=0 | policy=32 | replay=18136 | world_total=11300.8176 | actor=-58.0938 | critic=1.7875 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=769.9 | checkpoint=-
# [train] step=589/1000 | warm=0 | policy=32 | replay=18168 | world_total=11300.8003 | actor=-58.1562 | critic=1.5505 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=776.8 | checkpoint=-
# [train] step=590/1000 | warm=0 | policy=32 | replay=18200 | world_total=11300.7792 | actor=-58.1875 | critic=1.4982 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=783.4 | checkpoint=-
# [train] step=591/1000 | warm=0 | policy=32 | replay=18232 | world_total=11300.7650 | actor=-58.4375 | critic=1.4691 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=790.2 | checkpoint=-
# [train] step=592/1000 | warm=0 | policy=32 | replay=18264 | world_total=11300.8872 | actor=-57.5000 | critic=1.5948 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=797.3 | checkpoint=-
# [train] step=593/1000 | warm=0 | policy=32 | replay=18296 | world_total=11301.7410 | actor=-58.3438 | critic=1.6173 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=804.1 | checkpoint=-
# [train] step=594/1000 | warm=0 | policy=32 | replay=18328 | world_total=11301.2610 | actor=-57.7812 | critic=1.4722 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=810.9 | checkpoint=-
# [train] step=595/1000 | warm=0 | policy=32 | replay=18360 | world_total=11301.4253 | actor=-58.0000 | critic=1.5253 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=817.5 | checkpoint=-
# [train] step=596/1000 | warm=0 | policy=32 | replay=18392 | world_total=11302.0308 | actor=-58.3750 | critic=1.6050 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=824.4 | checkpoint=-
# [train] step=597/1000 | warm=0 | policy=32 | replay=18424 | world_total=11301.7107 | actor=-58.0312 | critic=1.6028 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=831.1 | checkpoint=-
# [train] step=598/1000 | warm=0 | policy=32 | replay=18456 | world_total=11301.4100 | actor=-58.6250 | critic=1.4125 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=837.6 | checkpoint=-
# [train] step=599/1000 | warm=0 | policy=32 | replay=18488 | world_total=11301.5956 | actor=-58.3438 | critic=1.6775 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=844.8 | checkpoint=-
# [train] step=600/1000 | warm=0 | policy=32 | replay=18520 | world_total=11301.3461 | actor=-58.2500 | critic=1.6894 | eval_reward=-0.5294 | cycle_s=14.7 | elapsed_s=859.5 | checkpoint=checkpoint_00600.pt
# [train] step=601/1000 | warm=0 | policy=32 | replay=18552 | world_total=11301.6587 | actor=-58.2500 | critic=1.8287 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=868.2 | checkpoint=-
# [train] step=602/1000 | warm=0 | policy=32 | replay=18584 | world_total=11301.5775 | actor=-58.6562 | critic=1.7579 | eval_reward=n/a | cycle_s=16.1 | elapsed_s=884.3 | checkpoint=-
# [train] step=603/1000 | warm=0 | policy=32 | replay=18616 | world_total=11301.3912 | actor=-58.0000 | critic=1.5840 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=890.7 | checkpoint=-
# [train] step=604/1000 | warm=0 | policy=32 | replay=18648 | world_total=11301.6045 | actor=-57.9688 | critic=2.3251 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=895.0 | checkpoint=-
# [train] step=605/1000 | warm=0 | policy=32 | replay=18680 | world_total=11301.4191 | actor=-59.8125 | critic=3.9036 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=902.6 | checkpoint=-
# [train] step=606/1000 | warm=0 | policy=32 | replay=18712 | world_total=11301.3450 | actor=-59.3750 | critic=4.1741 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=909.4 | checkpoint=-
# [train] step=607/1000 | warm=0 | policy=32 | replay=18744 | world_total=11301.4956 | actor=-58.5625 | critic=4.2560 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=915.9 | checkpoint=-
# [train] step=608/1000 | warm=0 | policy=32 | replay=18776 | world_total=11301.7886 | actor=-60.5312 | critic=4.1885 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=922.8 | checkpoint=-
# [train] step=609/1000 | warm=0 | policy=32 | replay=18808 | world_total=11301.7402 | actor=-61.2500 | critic=3.5578 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=929.9 | checkpoint=-
# [train] step=610/1000 | warm=0 | policy=32 | replay=18840 | world_total=11301.6067 | actor=-59.3438 | critic=3.2431 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=936.9 | checkpoint=-
# [train] step=611/1000 | warm=0 | policy=32 | replay=18872 | world_total=11301.7660 | actor=-58.7812 | critic=3.2716 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=943.9 | checkpoint=-
# [train] step=612/1000 | warm=0 | policy=32 | replay=18904 | world_total=11301.3892 | actor=-59.1562 | critic=2.8143 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=951.0 | checkpoint=-
# [train] step=613/1000 | warm=0 | policy=32 | replay=18936 | world_total=11301.4434 | actor=-59.9375 | critic=3.5757 | eval_reward=n/a | cycle_s=10.9 | elapsed_s=961.9 | checkpoint=-
# [train] step=614/1000 | warm=0 | policy=32 | replay=18968 | world_total=11301.1516 | actor=-59.6875 | critic=4.1635 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=969.1 | checkpoint=-
# [train] step=615/1000 | warm=0 | policy=32 | replay=19000 | world_total=11301.0319 | actor=-59.9375 | critic=3.4145 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=977.2 | checkpoint=-
# [train] step=616/1000 | warm=0 | policy=32 | replay=19032 | world_total=11300.9056 | actor=-59.6250 | critic=3.5947 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=983.8 | checkpoint=-
# [train] step=617/1000 | warm=0 | policy=32 | replay=19064 | world_total=11300.8192 | actor=-59.9062 | critic=3.4931 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=993.2 | checkpoint=-
# [train] step=618/1000 | warm=0 | policy=32 | replay=19096 | world_total=11300.7648 | actor=-59.7812 | critic=3.4260 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1001.1 | checkpoint=-
# [train] step=619/1000 | warm=0 | policy=32 | replay=19128 | world_total=11300.7026 | actor=-59.1250 | critic=3.6616 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1010.4 | checkpoint=-
# [train] step=620/1000 | warm=0 | policy=32 | replay=19160 | world_total=11300.6912 | actor=-59.0938 | critic=3.5990 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1017.8 | checkpoint=-
# [train] step=621/1000 | warm=0 | policy=32 | replay=19192 | world_total=11300.6666 | actor=-58.6562 | critic=2.9174 | eval_reward=n/a | cycle_s=12.4 | elapsed_s=1030.2 | checkpoint=-
# [train] step=622/1000 | warm=0 | policy=32 | replay=19224 | world_total=11300.6763 | actor=-58.5938 | critic=3.0757 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1037.7 | checkpoint=-
# [train] step=623/1000 | warm=0 | policy=32 | replay=19256 | world_total=11300.6359 | actor=-58.0000 | critic=4.0897 | eval_reward=n/a | cycle_s=10.9 | elapsed_s=1048.6 | checkpoint=-
# [train] step=624/1000 | warm=0 | policy=32 | replay=19288 | world_total=11300.6266 | actor=-57.1250 | critic=2.8312 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1055.9 | checkpoint=-
# [train] step=625/1000 | warm=0 | policy=32 | replay=19320 | world_total=11300.5981 | actor=-56.3750 | critic=2.9515 | eval_reward=-0.5336 | cycle_s=15.8 | elapsed_s=1071.7 | checkpoint=checkpoint_00625.pt
# [train] step=626/1000 | warm=0 | policy=32 | replay=19352 | world_total=11300.5961 | actor=-55.0000 | critic=2.5652 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=1076.8 | checkpoint=-
# [train] step=627/1000 | warm=0 | policy=32 | replay=19384 | world_total=11300.5829 | actor=-54.7812 | critic=2.3639 | eval_reward=n/a | cycle_s=10.4 | elapsed_s=1087.2 | checkpoint=-
# [train] step=628/1000 | warm=0 | policy=32 | replay=19416 | world_total=11300.5754 | actor=-55.4375 | critic=2.2081 | eval_reward=n/a | cycle_s=12.2 | elapsed_s=1099.4 | checkpoint=-
# [train] step=629/1000 | warm=0 | policy=32 | replay=19448 | world_total=11300.5814 | actor=-57.7500 | critic=2.0429 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=1109.0 | checkpoint=-
# [train] step=630/1000 | warm=0 | policy=32 | replay=19480 | world_total=11300.5706 | actor=-58.0938 | critic=1.7204 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1116.4 | checkpoint=-
# [train] step=631/1000 | warm=0 | policy=32 | replay=19512 | world_total=11300.5703 | actor=-56.3750 | critic=1.7419 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1123.7 | checkpoint=-
# [train] step=632/1000 | warm=0 | policy=32 | replay=19544 | world_total=11300.5599 | actor=-55.6875 | critic=1.5704 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1131.0 | checkpoint=-
# [train] step=633/1000 | warm=0 | policy=32 | replay=19576 | world_total=11300.5298 | actor=-55.0625 | critic=1.6829 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1137.5 | checkpoint=-
# [train] step=634/1000 | warm=0 | policy=32 | replay=19608 | world_total=11300.5201 | actor=-54.3438 | critic=1.6579 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1144.0 | checkpoint=-
# [train] step=635/1000 | warm=0 | policy=32 | replay=19640 | world_total=11300.6243 | actor=-51.9375 | critic=1.9749 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1150.6 | checkpoint=-
# [train] step=636/1000 | warm=0 | policy=32 | replay=19672 | world_total=11301.4971 | actor=-50.6875 | critic=1.7220 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1157.9 | checkpoint=-
# [train] step=637/1000 | warm=0 | policy=32 | replay=19704 | world_total=11302.2174 | actor=-50.4062 | critic=1.6316 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=1164.0 | checkpoint=-
# [train] step=638/1000 | warm=0 | policy=32 | replay=19736 | world_total=11302.2855 | actor=-53.3750 | critic=3.9570 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1170.4 | checkpoint=-
# [train] step=639/1000 | warm=0 | policy=32 | replay=19768 | world_total=11302.0068 | actor=-59.6562 | critic=3.9610 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1177.6 | checkpoint=-
# [train] step=640/1000 | warm=0 | policy=32 | replay=19800 | world_total=11302.8328 | actor=-61.3438 | critic=2.6164 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1184.1 | checkpoint=-
# [train] step=641/1000 | warm=0 | policy=32 | replay=19832 | world_total=11303.2023 | actor=-58.7500 | critic=1.9061 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1190.8 | checkpoint=-
# [train] step=642/1000 | warm=0 | policy=32 | replay=19864 | world_total=11302.8778 | actor=-60.8125 | critic=1.8592 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1197.6 | checkpoint=-
# [train] step=643/1000 | warm=0 | policy=32 | replay=19896 | world_total=11302.7606 | actor=-62.7812 | critic=1.9089 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1204.6 | checkpoint=-
# [train] step=644/1000 | warm=0 | policy=32 | replay=19928 | world_total=11301.8759 | actor=-64.6250 | critic=1.8972 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1211.2 | checkpoint=-
# [train] step=645/1000 | warm=0 | policy=32 | replay=19960 | world_total=11301.8837 | actor=-66.8125 | critic=1.8891 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1217.9 | checkpoint=-
# [train] step=646/1000 | warm=0 | policy=32 | replay=19992 | world_total=11301.8280 | actor=-67.6875 | critic=1.7065 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1225.0 | checkpoint=-
# [train] step=647/1000 | warm=0 | policy=32 | replay=20024 | world_total=11301.7841 | actor=-68.1875 | critic=1.6843 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=1234.7 | checkpoint=-
# [train] step=648/1000 | warm=0 | policy=32 | replay=20056 | world_total=11301.8475 | actor=-71.1875 | critic=1.8799 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1242.5 | checkpoint=-
# [train] step=649/1000 | warm=0 | policy=32 | replay=20088 | world_total=11301.5752 | actor=-77.2500 | critic=2.7131 | eval_reward=n/a | cycle_s=10.8 | elapsed_s=1253.3 | checkpoint=-
# [train] step=650/1000 | warm=0 | policy=32 | replay=20120 | world_total=11301.6543 | actor=-86.8125 | critic=3.9663 | eval_reward=-0.5259 | cycle_s=16.2 | elapsed_s=1269.5 | checkpoint=checkpoint_00650.pt
# [train] step=651/1000 | warm=0 | policy=32 | replay=20152 | world_total=11301.5521 | actor=-98.3125 | critic=6.6884 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1274.9 | checkpoint=-
# [train] step=652/1000 | warm=0 | policy=32 | replay=20184 | world_total=11301.5092 | actor=-96.1250 | critic=5.1484 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=1281.0 | checkpoint=-
# [train] step=653/1000 | warm=0 | policy=32 | replay=20216 | world_total=11301.5204 | actor=-83.3750 | critic=5.8965 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=1285.9 | checkpoint=-
# [train] step=654/1000 | warm=0 | policy=32 | replay=20248 | world_total=11301.5048 | actor=-68.1875 | critic=6.9311 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=1295.9 | checkpoint=-
# [train] step=655/1000 | warm=0 | policy=32 | replay=20280 | world_total=11301.5509 | actor=-58.5938 | critic=4.3747 | eval_reward=n/a | cycle_s=10.4 | elapsed_s=1306.3 | checkpoint=-
# [train] step=656/1000 | warm=0 | policy=32 | replay=20312 | world_total=11301.4054 | actor=-59.7812 | critic=2.7596 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1313.2 | checkpoint=-
# [train] step=657/1000 | warm=0 | policy=32 | replay=20344 | world_total=11301.4012 | actor=-66.0312 | critic=2.5807 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1320.0 | checkpoint=-
# [train] step=658/1000 | warm=0 | policy=32 | replay=20376 | world_total=11301.4490 | actor=-71.3125 | critic=3.1737 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1327.0 | checkpoint=-
# [train] step=659/1000 | warm=0 | policy=32 | replay=20408 | world_total=11301.4064 | actor=-77.5000 | critic=3.7211 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1334.1 | checkpoint=-
# [train] step=660/1000 | warm=0 | policy=32 | replay=20440 | world_total=11301.4067 | actor=-86.4375 | critic=6.2014 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1340.8 | checkpoint=-
# [train] step=661/1000 | warm=0 | policy=32 | replay=20472 | world_total=11301.3899 | actor=-98.3125 | critic=9.4339 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1347.9 | checkpoint=-
# [train] step=662/1000 | warm=0 | policy=32 | replay=20504 | world_total=11301.4952 | actor=-99.7500 | critic=7.2657 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1354.9 | checkpoint=-
# [train] step=663/1000 | warm=0 | policy=32 | replay=20536 | world_total=11301.2268 | actor=-95.5625 | critic=3.9455 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1361.8 | checkpoint=-
# [train] step=664/1000 | warm=0 | policy=32 | replay=20568 | world_total=11301.2334 | actor=-90.6875 | critic=3.9799 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1368.6 | checkpoint=-
# [train] step=665/1000 | warm=0 | policy=32 | replay=20600 | world_total=11301.2437 | actor=-80.9375 | critic=4.9489 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1375.4 | checkpoint=-
# [train] step=666/1000 | warm=0 | policy=32 | replay=20632 | world_total=11301.3013 | actor=-70.5625 | critic=5.6620 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1382.2 | checkpoint=-
# [train] step=667/1000 | warm=0 | policy=32 | replay=20664 | world_total=11301.1283 | actor=-61.2812 | critic=4.5188 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1389.2 | checkpoint=-
# [train] step=668/1000 | warm=0 | policy=32 | replay=20696 | world_total=11301.1273 | actor=-57.8125 | critic=3.0269 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1395.8 | checkpoint=-
# [train] step=669/1000 | warm=0 | policy=32 | replay=20728 | world_total=11301.3005 | actor=-59.2188 | critic=2.2316 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1402.8 | checkpoint=-
# [train] step=670/1000 | warm=0 | policy=32 | replay=20760 | world_total=11301.1309 | actor=-63.3438 | critic=1.8921 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1409.5 | checkpoint=-
# [train] step=671/1000 | warm=0 | policy=32 | replay=20792 | world_total=11301.1068 | actor=-66.6250 | critic=2.4615 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1416.3 | checkpoint=-
# [train] step=672/1000 | warm=0 | policy=32 | replay=20824 | world_total=11301.2139 | actor=-70.0000 | critic=2.3732 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1423.2 | checkpoint=-
# [train] step=673/1000 | warm=0 | policy=32 | replay=20856 | world_total=11301.2867 | actor=-73.1875 | critic=2.7111 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1429.4 | checkpoint=-
# [train] step=674/1000 | warm=0 | policy=32 | replay=20888 | world_total=11301.1102 | actor=-77.7500 | critic=3.3577 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1437.1 | checkpoint=-
# [train] step=675/1000 | warm=0 | policy=32 | replay=20920 | world_total=11301.0890 | actor=-84.5000 | critic=4.3613 | eval_reward=-0.5237 | cycle_s=21.2 | elapsed_s=1458.3 | checkpoint=checkpoint_00675.pt
# [train] step=676/1000 | warm=0 | policy=32 | replay=20952 | world_total=11301.3047 | actor=-93.4375 | critic=6.5719 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1464.6 | checkpoint=-
# [train] step=677/1000 | warm=0 | policy=32 | replay=20984 | world_total=11301.4078 | actor=-99.1250 | critic=7.4190 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1471.1 | checkpoint=-
# [train] step=678/1000 | warm=0 | policy=32 | replay=21016 | world_total=11301.3352 | actor=-98.3125 | critic=4.3242 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1477.3 | checkpoint=-
# [train] step=679/1000 | warm=0 | policy=32 | replay=21048 | world_total=11301.4628 | actor=-95.5000 | critic=2.8481 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1482.1 | checkpoint=-
# [train] step=680/1000 | warm=0 | policy=32 | replay=21080 | world_total=11301.5505 | actor=-91.3125 | critic=3.0040 | eval_reward=n/a | cycle_s=11.4 | elapsed_s=1493.5 | checkpoint=-
# [train] step=681/1000 | warm=0 | policy=32 | replay=21112 | world_total=11301.8508 | actor=-87.3125 | critic=3.4306 | eval_reward=n/a | cycle_s=13.9 | elapsed_s=1507.4 | checkpoint=-
# [train] step=682/1000 | warm=0 | policy=32 | replay=21144 | world_total=11302.4447 | actor=-83.0625 | critic=3.0089 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1514.5 | checkpoint=-
# [train] step=683/1000 | warm=0 | policy=32 | replay=21176 | world_total=11301.7377 | actor=-82.1250 | critic=2.5365 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1521.0 | checkpoint=-
# [train] step=684/1000 | warm=0 | policy=32 | replay=21208 | world_total=11301.3430 | actor=-84.6250 | critic=2.7762 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1527.8 | checkpoint=-
# [train] step=685/1000 | warm=0 | policy=32 | replay=21240 | world_total=11301.1448 | actor=-89.0000 | critic=3.0194 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1534.4 | checkpoint=-
# [train] step=686/1000 | warm=0 | policy=32 | replay=21272 | world_total=11301.0397 | actor=-94.4375 | critic=5.4150 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1540.8 | checkpoint=-
# [train] step=687/1000 | warm=0 | policy=32 | replay=21304 | world_total=11300.8101 | actor=-99.8750 | critic=5.6506 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1548.0 | checkpoint=-
# [train] step=688/1000 | warm=0 | policy=32 | replay=21336 | world_total=11300.6195 | actor=-97.9375 | critic=3.5501 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1554.7 | checkpoint=-
# [train] step=689/1000 | warm=0 | policy=32 | replay=21368 | world_total=11300.5066 | actor=-94.6250 | critic=3.1743 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1562.0 | checkpoint=-
# [train] step=690/1000 | warm=0 | policy=32 | replay=21400 | world_total=11300.4652 | actor=-90.1875 | critic=2.9466 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1568.9 | checkpoint=-
# [train] step=691/1000 | warm=0 | policy=32 | replay=21432 | world_total=11300.4126 | actor=-85.3750 | critic=3.3448 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1574.9 | checkpoint=-
# [train] step=692/1000 | warm=0 | policy=32 | replay=21464 | world_total=11300.3756 | actor=-80.2500 | critic=2.8180 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1581.8 | checkpoint=-
# [train] step=693/1000 | warm=0 | policy=32 | replay=21496 | world_total=11300.3441 | actor=-75.2500 | critic=2.7077 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1588.9 | checkpoint=-
# [train] step=694/1000 | warm=0 | policy=32 | replay=21528 | world_total=11300.3386 | actor=-71.8750 | critic=3.0757 | eval_reward=n/a | cycle_s=10.2 | elapsed_s=1599.1 | checkpoint=-
# [train] step=695/1000 | warm=0 | policy=32 | replay=21560 | world_total=11300.3207 | actor=-68.0000 | critic=2.6108 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1606.6 | checkpoint=-
# [train] step=696/1000 | warm=0 | policy=32 | replay=21592 | world_total=11300.2859 | actor=-64.2188 | critic=2.9323 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1614.0 | checkpoint=-
# [train] step=697/1000 | warm=0 | policy=32 | replay=21624 | world_total=11300.2770 | actor=-61.6562 | critic=2.7942 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1620.2 | checkpoint=-
# [train] step=698/1000 | warm=0 | policy=32 | replay=21656 | world_total=11300.3079 | actor=-59.6562 | critic=2.7121 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1626.7 | checkpoint=-
# [train] step=699/1000 | warm=0 | policy=32 | replay=21688 | world_total=11300.2634 | actor=-59.8750 | critic=2.8707 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1633.7 | checkpoint=-
# [train] step=700/1000 | warm=0 | policy=32 | replay=21720 | world_total=11300.2598 | actor=-60.4375 | critic=2.9333 | eval_reward=-0.5280 | cycle_s=15.4 | elapsed_s=1649.0 | checkpoint=checkpoint_00700.pt
# [train] step=701/1000 | warm=0 | policy=32 | replay=21752 | world_total=11300.2565 | actor=-60.0625 | critic=3.1109 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1654.5 | checkpoint=-
# [train] step=702/1000 | warm=0 | policy=32 | replay=21784 | world_total=11300.2550 | actor=-59.9688 | critic=4.3202 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1659.7 | checkpoint=-
# [train] step=703/1000 | warm=0 | policy=32 | replay=21816 | world_total=11300.2466 | actor=-60.0312 | critic=3.3739 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=1665.2 | checkpoint=-
# [train] step=704/1000 | warm=0 | policy=32 | replay=21848 | world_total=11300.2047 | actor=-59.7188 | critic=3.3709 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1670.7 | checkpoint=-
# [train] step=705/1000 | warm=0 | policy=32 | replay=21880 | world_total=11300.2092 | actor=-59.1562 | critic=4.4357 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=1675.6 | checkpoint=-
# [train] step=706/1000 | warm=0 | policy=32 | replay=21912 | world_total=11300.2109 | actor=-59.8438 | critic=3.1378 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1683.4 | checkpoint=-
# [train] step=707/1000 | warm=0 | policy=32 | replay=21944 | world_total=11300.1996 | actor=-59.5000 | critic=3.7131 | eval_reward=n/a | cycle_s=12.7 | elapsed_s=1696.1 | checkpoint=-
# [train] step=708/1000 | warm=0 | policy=32 | replay=21976 | world_total=11300.1923 | actor=-58.6875 | critic=4.0815 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1701.6 | checkpoint=-
# [train] step=709/1000 | warm=0 | policy=32 | replay=22008 | world_total=11300.6002 | actor=-58.6562 | critic=3.5370 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1708.9 | checkpoint=-
# [train] step=710/1000 | warm=0 | policy=32 | replay=22040 | world_total=11302.2433 | actor=-58.9062 | critic=3.7075 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=1715.0 | checkpoint=-
# [train] step=711/1000 | warm=0 | policy=32 | replay=22072 | world_total=11301.2528 | actor=-60.4375 | critic=3.8430 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1722.0 | checkpoint=-
# [train] step=712/1000 | warm=0 | policy=32 | replay=22104 | world_total=11301.2458 | actor=-61.0938 | critic=2.4418 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1728.7 | checkpoint=-
# [train] step=713/1000 | warm=0 | policy=32 | replay=22136 | world_total=11300.9221 | actor=-61.1250 | critic=1.5923 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1735.8 | checkpoint=-
# [train] step=714/1000 | warm=0 | policy=32 | replay=22168 | world_total=11301.0873 | actor=-60.7188 | critic=1.5530 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1742.6 | checkpoint=-
# [train] step=715/1000 | warm=0 | policy=32 | replay=22200 | world_total=11300.9755 | actor=-60.8438 | critic=1.5581 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1749.3 | checkpoint=-
# [train] step=716/1000 | warm=0 | policy=32 | replay=22232 | world_total=11300.7487 | actor=-60.6562 | critic=1.5620 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1755.5 | checkpoint=-
# [train] step=717/1000 | warm=0 | policy=32 | replay=22264 | world_total=11301.1592 | actor=-60.6250 | critic=1.5388 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1762.9 | checkpoint=-
# [train] step=718/1000 | warm=0 | policy=32 | replay=22296 | world_total=11300.8060 | actor=-60.6562 | critic=1.4524 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1769.5 | checkpoint=-
# [train] step=719/1000 | warm=0 | policy=32 | replay=22328 | world_total=11300.8837 | actor=-61.1562 | critic=1.3821 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1776.8 | checkpoint=-
# [train] step=720/1000 | warm=0 | policy=32 | replay=22360 | world_total=11300.8234 | actor=-60.6250 | critic=1.4263 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1783.5 | checkpoint=-
# [train] step=721/1000 | warm=0 | policy=32 | replay=22392 | world_total=11300.9863 | actor=-60.5000 | critic=1.2868 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1789.9 | checkpoint=-
# [train] step=722/1000 | warm=0 | policy=32 | replay=22424 | world_total=11300.8300 | actor=-60.5625 | critic=1.2954 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1796.5 | checkpoint=-
# [train] step=723/1000 | warm=0 | policy=32 | replay=22456 | world_total=11300.8823 | actor=-61.5000 | critic=1.3386 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1803.7 | checkpoint=-
# [train] step=724/1000 | warm=0 | policy=32 | replay=22488 | world_total=11300.9263 | actor=-62.3750 | critic=1.6845 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1810.1 | checkpoint=-
# [train] step=725/1000 | warm=0 | policy=32 | replay=22520 | world_total=11300.8184 | actor=-63.8750 | critic=1.8028 | eval_reward=-0.5280 | cycle_s=21.2 | elapsed_s=1831.3 | checkpoint=checkpoint_00725.pt
# [train] step=726/1000 | warm=0 | policy=32 | replay=22552 | world_total=11300.7993 | actor=-65.9375 | critic=1.9530 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1838.1 | checkpoint=-
# [train] step=727/1000 | warm=0 | policy=32 | replay=22584 | world_total=11300.8467 | actor=-67.9375 | critic=1.9145 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1845.3 | checkpoint=-
# [train] step=728/1000 | warm=0 | policy=32 | replay=22616 | world_total=11301.0156 | actor=-70.5000 | critic=2.3076 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1852.2 | checkpoint=-
# [train] step=729/1000 | warm=0 | policy=32 | replay=22648 | world_total=11300.9226 | actor=-74.1875 | critic=3.7509 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1858.5 | checkpoint=-
# [train] step=730/1000 | warm=0 | policy=32 | replay=22680 | world_total=11300.9091 | actor=-79.5000 | critic=4.1842 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1863.9 | checkpoint=-
# [train] step=731/1000 | warm=0 | policy=32 | replay=22712 | world_total=11300.9298 | actor=-85.5000 | critic=4.5716 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1871.3 | checkpoint=-
# [train] step=732/1000 | warm=0 | policy=32 | replay=22744 | world_total=11300.7507 | actor=-93.6250 | critic=6.4403 | eval_reward=n/a | cycle_s=15.0 | elapsed_s=1886.3 | checkpoint=-
# [train] step=733/1000 | warm=0 | policy=32 | replay=22776 | world_total=11300.7020 | actor=-99.1875 | critic=7.8862 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1892.8 | checkpoint=-
# [train] step=734/1000 | warm=0 | policy=32 | replay=22808 | world_total=11300.7552 | actor=-99.0000 | critic=4.5170 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1899.0 | checkpoint=-
# [train] step=735/1000 | warm=0 | policy=32 | replay=22840 | world_total=11300.7639 | actor=-95.4375 | critic=3.1675 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1905.1 | checkpoint=-
# [train] step=736/1000 | warm=0 | policy=32 | replay=22872 | world_total=11301.1039 | actor=-93.4375 | critic=3.3165 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1911.7 | checkpoint=-
# [train] step=737/1000 | warm=0 | policy=32 | replay=22904 | world_total=11300.9268 | actor=-89.3750 | critic=2.8960 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1918.6 | checkpoint=-
# [train] step=738/1000 | warm=0 | policy=32 | replay=22936 | world_total=11300.6908 | actor=-83.8750 | critic=3.4693 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1925.3 | checkpoint=-
# [train] step=739/1000 | warm=0 | policy=32 | replay=22968 | world_total=11300.7383 | actor=-78.6250 | critic=3.1800 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1932.2 | checkpoint=-
# [train] step=740/1000 | warm=0 | policy=32 | replay=23000 | world_total=11300.5303 | actor=-73.7500 | critic=3.4291 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1939.3 | checkpoint=-
# [train] step=741/1000 | warm=0 | policy=32 | replay=23032 | world_total=11300.3948 | actor=-68.7500 | critic=3.6421 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1946.2 | checkpoint=-
# [train] step=742/1000 | warm=0 | policy=32 | replay=23064 | world_total=11300.2786 | actor=-64.0625 | critic=3.3992 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1952.7 | checkpoint=-
# [train] step=743/1000 | warm=0 | policy=32 | replay=23096 | world_total=11300.1821 | actor=-60.4062 | critic=2.3422 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1958.9 | checkpoint=-
# [train] step=744/1000 | warm=0 | policy=32 | replay=23128 | world_total=11300.1377 | actor=-59.5625 | critic=2.4278 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1965.7 | checkpoint=-
# [train] step=745/1000 | warm=0 | policy=32 | replay=23160 | world_total=11300.1072 | actor=-60.1875 | critic=1.9595 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1972.5 | checkpoint=-
# [train] step=746/1000 | warm=0 | policy=32 | replay=23192 | world_total=11300.0819 | actor=-61.0000 | critic=2.1560 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1979.5 | checkpoint=-
# [train] step=747/1000 | warm=0 | policy=32 | replay=23224 | world_total=11300.0636 | actor=-60.6562 | critic=2.0934 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1986.4 | checkpoint=-
# [train] step=748/1000 | warm=0 | policy=32 | replay=23256 | world_total=11300.0334 | actor=-60.4688 | critic=2.0366 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1994.0 | checkpoint=-
# [train] step=749/1000 | warm=0 | policy=32 | replay=23288 | world_total=11300.0338 | actor=-59.6250 | critic=2.5355 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=2000.6 | checkpoint=-
# [train] step=750/1000 | warm=0 | policy=32 | replay=23320 | world_total=11300.0383 | actor=-59.8750 | critic=2.2408 | eval_reward=-0.5329 | cycle_s=15.1 | elapsed_s=2015.7 | checkpoint=checkpoint_00750.pt
# [train] step=751/1000 | warm=0 | policy=32 | replay=23352 | world_total=11300.0125 | actor=-59.3438 | critic=2.9995 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=2020.9 | checkpoint=-
# [train] step=752/1000 | warm=0 | policy=32 | replay=23384 | world_total=11300.0096 | actor=-59.3750 | critic=2.9839 | eval_reward=n/a | cycle_s=12.3 | elapsed_s=2033.2 | checkpoint=-
# [train] step=753/1000 | warm=0 | policy=32 | replay=23416 | world_total=11299.9821 | actor=-59.2500 | critic=3.3842 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2040.5 | checkpoint=-
# [train] step=754/1000 | warm=0 | policy=32 | replay=23448 | world_total=11299.9757 | actor=-59.1250 | critic=3.4632 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=2047.0 | checkpoint=-
# [train] step=755/1000 | warm=0 | policy=32 | replay=23480 | world_total=11299.9677 | actor=-59.0938 | critic=3.6352 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=2053.1 | checkpoint=-
# [train] step=756/1000 | warm=0 | policy=32 | replay=23512 | world_total=11299.9719 | actor=-58.9375 | critic=3.8151 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=2059.1 | checkpoint=-
# [train] step=757/1000 | warm=0 | policy=32 | replay=23544 | world_total=11299.9562 | actor=-58.9688 | critic=3.8799 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=2064.9 | checkpoint=-
# [train] step=758/1000 | warm=0 | policy=32 | replay=23576 | world_total=11299.9736 | actor=-58.6562 | critic=3.7660 | eval_reward=n/a | cycle_s=10.7 | elapsed_s=2075.7 | checkpoint=-
# [train] step=759/1000 | warm=0 | policy=32 | replay=23608 | world_total=11299.9675 | actor=-58.8125 | critic=3.3699 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=2082.5 | checkpoint=-
# [train] step=760/1000 | warm=0 | policy=32 | replay=23640 | world_total=11299.9363 | actor=-58.4688 | critic=3.1733 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=2089.4 | checkpoint=-
# [train] step=761/1000 | warm=0 | policy=32 | replay=23672 | world_total=11299.9188 | actor=-57.9375 | critic=2.9540 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=2096.4 | checkpoint=-
# [train] step=762/1000 | warm=0 | policy=32 | replay=23704 | world_total=11299.9370 | actor=-58.2812 | critic=2.6358 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=2103.2 | checkpoint=-
# ...
# [train] step=920/1000 | warm=0 | policy=32 | replay=28760 | world_total=11300.4423 | actor=-61.1562 | critic=1.8779 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3324.7 | checkpoint=-
# [train] step=921/1000 | warm=0 | policy=32 | replay=28792 | world_total=11300.3605 | actor=-61.2188 | critic=1.8805 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3331.2 | checkpoint=-
# [train] step=922/1000 | warm=0 | policy=32 | replay=28824 | world_total=11300.2263 | actor=-60.5625 | critic=1.5555 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3338.1 | checkpoint=-
# [train] step=923/1000 | warm=0 | policy=32 | replay=28856 | world_total=11300.1195 | actor=-60.9062 | critic=1.8597 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=3344.9 | checkpoint=-
# [train] step=924/1000 | warm=0 | policy=32 | replay=28888 | world_total=11300.2957 | actor=-62.0938 | critic=1.8257 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=3352.2 | checkpoint=-
# [train] step=925/1000 | warm=0 | policy=32 | replay=28920 | world_total=11300.2073 | actor=-61.9375 | critic=1.7812 | eval_reward=-0.5231 | cycle_s=16.6 | elapsed_s=3368.8 | checkpoint=checkpoint_00925.pt
# [train] step=926/1000 | warm=0 | policy=32 | replay=28952 | world_total=11300.0442 | actor=-61.5938 | critic=1.6128 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3375.1 | checkpoint=-
# [train] step=927/1000 | warm=0 | policy=32 | replay=28984 | world_total=11300.1322 | actor=-61.6875 | critic=1.7002 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3381.5 | checkpoint=-
# [train] step=928/1000 | warm=0 | policy=32 | replay=29016 | world_total=11300.2252 | actor=-61.8125 | critic=1.6883 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=3387.2 | checkpoint=-
# [train] step=929/1000 | warm=0 | policy=32 | replay=29048 | world_total=11300.3990 | actor=-61.0625 | critic=1.5878 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=3392.7 | checkpoint=-
# [train] step=930/1000 | warm=0 | policy=32 | replay=29080 | world_total=11300.3771 | actor=-61.0312 | critic=1.6780 | eval_reward=n/a | cycle_s=14.5 | elapsed_s=3407.1 | checkpoint=-
# [train] step=931/1000 | warm=0 | policy=32 | replay=29112 | world_total=11300.2858 | actor=-60.6250 | critic=1.7024 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=3413.0 | checkpoint=-
# [train] step=932/1000 | warm=0 | policy=32 | replay=29144 | world_total=11300.3346 | actor=-60.5000 | critic=1.8795 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=3420.1 | checkpoint=-
# [train] step=933/1000 | warm=0 | policy=32 | replay=29176 | world_total=11300.3298 | actor=-60.2500 | critic=2.3235 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3426.6 | checkpoint=-
# [train] step=934/1000 | warm=0 | policy=32 | replay=29208 | world_total=11300.1273 | actor=-61.0312 | critic=1.7086 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3432.7 | checkpoint=-
# [train] step=935/1000 | warm=0 | policy=32 | replay=29240 | world_total=11300.0627 | actor=-62.5938 | critic=1.8849 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=3441.2 | checkpoint=-
# [train] step=936/1000 | warm=0 | policy=32 | replay=29272 | world_total=11300.2504 | actor=-65.7500 | critic=2.2097 | eval_reward=n/a | cycle_s=12.8 | elapsed_s=3454.0 | checkpoint=-
# [train] step=937/1000 | warm=0 | policy=32 | replay=29304 | world_total=11300.0852 | actor=-69.6875 | critic=2.7269 | eval_reward=n/a | cycle_s=10.3 | elapsed_s=3464.4 | checkpoint=-
# [train] step=938/1000 | warm=0 | policy=32 | replay=29336 | world_total=11300.1229 | actor=-74.8125 | critic=3.4638 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=3472.3 | checkpoint=-
# [train] step=939/1000 | warm=0 | policy=32 | replay=29368 | world_total=11300.1481 | actor=-84.0000 | critic=5.0739 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=3480.0 | checkpoint=-
# [train] step=940/1000 | warm=0 | policy=32 | replay=29400 | world_total=11300.1771 | actor=-96.3750 | critic=8.5028 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3486.7 | checkpoint=-
# [train] step=941/1000 | warm=0 | policy=32 | replay=29432 | world_total=11300.1096 | actor=-100.8750 | critic=8.2415 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3493.3 | checkpoint=-
# [train] step=942/1000 | warm=0 | policy=32 | replay=29464 | world_total=11300.1003 | actor=-97.1250 | critic=3.3772 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3500.3 | checkpoint=-
# [train] step=943/1000 | warm=0 | policy=32 | replay=29496 | world_total=11300.1716 | actor=-92.3125 | critic=3.1351 | eval_reward=n/a | cycle_s=11.0 | elapsed_s=3511.2 | checkpoint=-
# [train] step=944/1000 | warm=0 | policy=32 | replay=29528 | world_total=11300.2729 | actor=-86.1250 | critic=3.9981 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=3518.7 | checkpoint=-
# [train] step=945/1000 | warm=0 | policy=32 | replay=29560 | world_total=11300.1866 | actor=-78.7500 | critic=3.9940 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=3526.1 | checkpoint=-
# [train] step=946/1000 | warm=0 | policy=32 | replay=29592 | world_total=11299.9259 | actor=-70.6875 | critic=3.9864 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3532.7 | checkpoint=-
# [train] step=947/1000 | warm=0 | policy=32 | replay=29624 | world_total=11299.7833 | actor=-64.1562 | critic=3.8979 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=3540.3 | checkpoint=-
# [train] step=948/1000 | warm=0 | policy=32 | replay=29656 | world_total=11299.6484 | actor=-59.0000 | critic=2.8551 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3546.6 | checkpoint=-
# [train] step=949/1000 | warm=0 | policy=32 | replay=29688 | world_total=11299.5709 | actor=-57.6562 | critic=2.2137 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3553.2 | checkpoint=-
# [train] step=950/1000 | warm=0 | policy=32 | replay=29720 | world_total=11299.5452 | actor=-58.8125 | critic=3.0324 | eval_reward=-0.5343 | cycle_s=16.8 | elapsed_s=3570.0 | checkpoint=checkpoint_00950.pt
# [train] step=951/1000 | warm=0 | policy=32 | replay=29752 | world_total=11299.5129 | actor=-60.5625 | critic=2.4772 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=3575.7 | checkpoint=-
# [train] step=952/1000 | warm=0 | policy=32 | replay=29784 | world_total=11299.4987 | actor=-61.3438 | critic=2.1311 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=3581.0 | checkpoint=-
# [train] step=953/1000 | warm=0 | policy=32 | replay=29816 | world_total=11299.5060 | actor=-60.2812 | critic=3.7421 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=3587.2 | checkpoint=-
# [train] step=954/1000 | warm=0 | policy=32 | replay=29848 | world_total=11299.4719 | actor=-59.3125 | critic=4.3144 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=3593.1 | checkpoint=-
# [train] step=955/1000 | warm=0 | policy=32 | replay=29880 | world_total=11299.4957 | actor=-59.8750 | critic=3.0381 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=3599.1 | checkpoint=-
# [train] step=956/1000 | warm=0 | policy=32 | replay=29912 | world_total=11299.4894 | actor=-60.0000 | critic=2.5529 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3606.0 | checkpoint=-
# [train] step=957/1000 | warm=0 | policy=32 | replay=29944 | world_total=11299.5032 | actor=-59.0938 | critic=4.5565 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3612.0 | checkpoint=-
# [train] step=958/1000 | warm=0 | policy=32 | replay=29976 | world_total=11299.4952 | actor=-58.9375 | critic=4.3600 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=3617.5 | checkpoint=-
# [train] step=959/1000 | warm=0 | policy=32 | replay=30008 | world_total=11299.5038 | actor=-59.3750 | critic=4.1416 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3623.2 | checkpoint=-
# [train] step=960/1000 | warm=0 | policy=32 | replay=30040 | world_total=11299.4734 | actor=-59.3125 | critic=3.2437 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=3630.3 | checkpoint=-
# [train] step=961/1000 | warm=0 | policy=32 | replay=30072 | world_total=11299.4788 | actor=-58.9062 | critic=4.5675 | eval_reward=n/a | cycle_s=14.9 | elapsed_s=3645.2 | checkpoint=-
# [train] step=962/1000 | warm=0 | policy=32 | replay=30104 | world_total=11299.4478 | actor=-58.5000 | critic=3.9820 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=3653.7 | checkpoint=-
# [train] step=963/1000 | warm=0 | policy=32 | replay=30136 | world_total=11299.4297 | actor=-58.5312 | critic=3.5170 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=3662.5 | checkpoint=-
# [train] step=964/1000 | warm=0 | policy=32 | replay=30168 | world_total=11299.4205 | actor=-58.1250 | critic=3.4631 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3668.7 | checkpoint=-
# [train] step=965/1000 | warm=0 | policy=32 | replay=30200 | world_total=11299.4033 | actor=-58.0938 | critic=3.0396 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3675.2 | checkpoint=-
# [train] step=966/1000 | warm=0 | policy=32 | replay=30232 | world_total=11299.4021 | actor=-58.3438 | critic=2.7324 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3681.5 | checkpoint=-
# [train] step=967/1000 | warm=0 | policy=32 | replay=30264 | world_total=11300.3456 | actor=-58.0312 | critic=3.0842 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3687.8 | checkpoint=-
# [train] step=968/1000 | warm=0 | policy=32 | replay=30296 | world_total=11300.2628 | actor=-58.7812 | critic=3.9020 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=3694.1 | checkpoint=-
# [train] step=969/1000 | warm=0 | policy=32 | replay=30328 | world_total=11300.5121 | actor=-59.0938 | critic=3.5509 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3699.8 | checkpoint=-
# [train] step=970/1000 | warm=0 | policy=32 | replay=30360 | world_total=11300.0083 | actor=-59.1875 | critic=3.3593 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=3705.8 | checkpoint=-
# [train] step=971/1000 | warm=0 | policy=32 | replay=30392 | world_total=11300.0344 | actor=-59.4688 | critic=2.8265 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=3711.4 | checkpoint=-
# [train] step=972/1000 | warm=0 | policy=32 | replay=30424 | world_total=11300.3367 | actor=-59.6562 | critic=2.3331 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3718.1 | checkpoint=-
# [train] step=973/1000 | warm=0 | policy=32 | replay=30456 | world_total=11300.3003 | actor=-59.4688 | critic=3.8366 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=3723.9 | checkpoint=-
# [train] step=974/1000 | warm=0 | policy=32 | replay=30488 | world_total=11300.4082 | actor=-58.8125 | critic=4.7573 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3730.3 | checkpoint=-
# [train] step=975/1000 | warm=0 | policy=32 | replay=30520 | world_total=11300.0936 | actor=-59.7500 | critic=3.8652 | eval_reward=-0.5245 | cycle_s=15.8 | elapsed_s=3746.1 | checkpoint=checkpoint_00975.pt
# [train] step=976/1000 | warm=0 | policy=32 | replay=30552 | world_total=11300.5750 | actor=-60.3750 | critic=3.4815 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=3751.0 | checkpoint=-
# [train] step=977/1000 | warm=0 | policy=32 | replay=30584 | world_total=11300.2797 | actor=-60.1875 | critic=3.7528 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=3756.5 | checkpoint=-
# [train] step=978/1000 | warm=0 | policy=32 | replay=30616 | world_total=11300.2461 | actor=-60.2188 | critic=2.5853 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=3761.7 | checkpoint=-
# [train] step=979/1000 | warm=0 | policy=32 | replay=30648 | world_total=11299.9943 | actor=-60.2812 | critic=2.5579 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3768.6 | checkpoint=-
# [train] step=980/1000 | warm=0 | policy=32 | replay=30680 | world_total=11300.4241 | actor=-60.5000 | critic=1.7395 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3775.1 | checkpoint=-
# [train] step=981/1000 | warm=0 | policy=32 | replay=30712 | world_total=11300.1598 | actor=-60.8438 | critic=1.4178 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3781.6 | checkpoint=-
# [train] step=982/1000 | warm=0 | policy=32 | replay=30744 | world_total=11300.3339 | actor=-60.4062 | critic=1.4137 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3787.3 | checkpoint=-
# [train] step=983/1000 | warm=0 | policy=32 | replay=30776 | world_total=11300.2096 | actor=-60.5000 | critic=1.4625 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=3792.8 | checkpoint=-
# [train] step=984/1000 | warm=0 | policy=32 | replay=30808 | world_total=11300.2338 | actor=-60.6250 | critic=1.8592 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=3797.7 | checkpoint=-
# [train] step=985/1000 | warm=0 | policy=32 | replay=30840 | world_total=11300.1407 | actor=-61.1562 | critic=2.2697 | eval_reward=n/a | cycle_s=16.1 | elapsed_s=3813.9 | checkpoint=-
# [train] step=986/1000 | warm=0 | policy=32 | replay=30872 | world_total=11300.2164 | actor=-62.1562 | critic=1.9509 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3820.8 | checkpoint=-
# [train] step=987/1000 | warm=0 | policy=32 | replay=30904 | world_total=11300.1539 | actor=-64.0625 | critic=2.0917 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=3826.9 | checkpoint=-
# [train] step=988/1000 | warm=0 | policy=32 | replay=30936 | world_total=11300.1057 | actor=-66.8750 | critic=2.2047 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=3834.0 | checkpoint=-
# [train] step=989/1000 | warm=0 | policy=32 | replay=30968 | world_total=11300.1035 | actor=-71.3125 | critic=2.8795 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3840.6 | checkpoint=-
# [train] step=990/1000 | warm=0 | policy=32 | replay=31000 | world_total=11300.1559 | actor=-77.5625 | critic=3.8367 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3846.9 | checkpoint=-
# [train] step=991/1000 | warm=0 | policy=32 | replay=31032 | world_total=11300.2534 | actor=-84.6250 | critic=5.3646 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3853.4 | checkpoint=-
# [train] step=992/1000 | warm=0 | policy=32 | replay=31064 | world_total=11300.0486 | actor=-92.9375 | critic=7.1242 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3860.0 | checkpoint=-
# [train] step=993/1000 | warm=0 | policy=32 | replay=31096 | world_total=11300.9393 | actor=-99.6250 | critic=8.8422 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3866.5 | checkpoint=-
# [train] step=994/1000 | warm=0 | policy=32 | replay=31128 | world_total=11300.1299 | actor=-98.2500 | critic=7.4602 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3872.8 | checkpoint=-
# [train] step=995/1000 | warm=0 | policy=32 | replay=31160 | world_total=11299.9476 | actor=-93.8750 | critic=5.6204 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3879.4 | checkpoint=-
# [train] step=996/1000 | warm=0 | policy=32 | replay=31192 | world_total=11299.7412 | actor=-88.1250 | critic=4.5933 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3885.5 | checkpoint=-
# [train] step=997/1000 | warm=0 | policy=32 | replay=31224 | world_total=11299.5641 | actor=-80.9375 | critic=4.8572 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3892.2 | checkpoint=-
# [train] step=998/1000 | warm=0 | policy=32 | replay=31256 | world_total=11299.4475 | actor=-73.7500 | critic=5.2601 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3898.5 | checkpoint=-
# [train] step=999/1000 | warm=0 | policy=32 | replay=31288 | world_total=11299.3983 | actor=-65.8438 | critic=6.3495 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3904.9 | checkpoint=-
# [train] step=1000/1000 | warm=0 | policy=32 | replay=31320 | world_total=11299.3693 | actor=-59.9062 | critic=5.4292 | eval_reward=-0.5364 | cycle_s=16.2 | elapsed_s=3921.0 | checkpoint=checkpoint_01000.pt
# Completed cycles: 1000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter24_mid_steering/checkpoints/checkpoint_01000.pt
# Latest metrics: {'step': 1000, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 31320, 'world_model/reconstruction_loss': 11295.247680664062, 'world_model/reconstruction_mse': 0.0005420816596597433, 'world_model/observation_log_prob': -11295.247680664062, 'world_model/reward_loss': 0.9189832806587219, 'world_model/continue_loss': 1.8869684259570363e-08, 'world_model/kl_loss': 3.0, 'world_model/kl_loss_raw': 2.1540675163269043, 'world_model/overshooting_kl_loss': 0.40520190075039864, 'world_model/overshooting_feature_mse': 0.003113117825705558, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11299.369262695312, 'behavior/actor_loss': -59.90625, 'behavior/critic_loss': 5.42922306060791, 'behavior/imagined_reward_mean': 0.6552734375, 'behavior/imagined_value_mean': 60.625, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': -0.5363927943110467, 'evaluation/mean_steps': 5.2, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter24_mid_steering/checkpoints/checkpoint_01000.pt',
#  'latest_metrics': {'behavior/actor_loss': -59.90625,
#   'behavior/critic_loss': 5.42922306060791,
#   'behavior/imagined_reward_mean': 0.6552734375,
#   'behavior/imagined_value_mean': 60.625,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': -0.5363927943110467,
#   'evaluation/mean_steps': 5.2,
#   'policy_added': 32,
#   'replay_size': 31320,
#   'step': 1000,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 1.8869684259570363e-08,
#   'world_model/kl_loss': 3.0,
#   'world_model/kl_loss_raw': 2.1540675163269043,
#   'world_model/observation_log_prob': -11295.247680664062,
#   'world_model/overshooting_feature_mse': 0.003113117825705558,
#   'world_model/overshooting_kl_loss': 0.40520190075039864,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11295.247680664062,
#   'world_model/reconstruction_mse': 0.0005420816596597433,
#   'world_model/reward_loss': 0.9189832806587219,
#   'world_model/total_loss': 11299.369262695312},
#  'latest_step': 1000}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': -0.5230781863629818,
#   'best_eval_reward_step': 925,
#   'best_imagined_reward_mean': 0.81103515625,
#   'best_imagined_reward_step': 683,
#   'best_world_model_step': 1000,
#   'best_world_model_total_loss': 11299.369262695312,
#   'largest_replay_size': 31320,
#   'largest_replay_step': 1000,
#   'last_metrics': {'behavior/actor_loss': -59.90625,
#    'behavior/critic_loss': 5.42922306060791,
#    'behavior/imagined_reward_mean': 0.6552734375,
#    'behavior/imagined_value_mean': 60.625,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': -0.5363927943110467,
#    'evaluation/mean_steps': 5.2,
#    'policy_added': 32,
#    'replay_size': 31320,
#    'step': 1000,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 1.8869684259570363e-08,
#    'world_model/kl_loss': 3.0,
#    'world_model/kl_loss_raw': 2.1540675163269043,
#    'world_model/observation_log_prob': -11295.247680664062,
#    'world_model/overshooting_feature_mse': 0.003113117825705558,
#    'world_model/overshooting_kl_loss': 0.40520190075039864,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11295.247680664062,
#    'world_model/reconstruction_mse': 0.0005420816596597433,
#    'world_model/reward_loss': 0.9189832806587219,
#    'world_model/total_loss': 11299.369262695312},
#   'last_step': 1000,
#   'num_records': 975},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11295.247680664062',
#   'world_model/reconstruction_mse': '0.0005420816596597433',
#   'world_model/observation_log_prob': '-11295.247680664062',
#   'world_model/overshooting_kl_loss': '0.40520190075039864',
#   'world_model/overshooting_feature_mse': '0.003113117825705558',
#   'evaluation/mean_reward': '-0.5363927943110467',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=132,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=6 | reward=-0.54 | CRASH | saved iter24_mid_steering_ep01.gif
# [demo] episode 2/10 | steps=5 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep02.gif
# [demo] episode 3/10 | steps=6 | reward=-0.54 | CRASH | saved iter24_mid_steering_ep03.gif
# [demo] episode 4/10 | steps=4 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep04.gif
# [demo] episode 5/10 | steps=6 | reward=-0.54 | CRASH | saved iter24_mid_steering_ep05.gif
# [demo] episode 6/10 | steps=4 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep06.gif
# [demo] episode 7/10 | steps=5 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep07.gif
# [demo] episode 8/10 | steps=4 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep08.gif
# [demo] episode 9/10 | steps=5 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep09.gif
# [demo] episode 10/10 | steps=4 | reward=-0.53 | CRASH | saved iter24_mid_steering_ep10.gif
# [demo] done | avg_reward=-0.53 | summary=iter24_mid_steering_summary.json
#
# iter24_mid_steering_ep01.gif
# iter24_mid_steering_ep02.gif
# iter24_mid_steering_ep03.gif
# iter24_mid_steering_ep04.gif
# iter24_mid_steering_ep05.gif
# iter24_mid_steering_ep06.gif
# iter24_mid_steering_ep07.gif
# iter24_mid_steering_ep08.gif
# iter24_mid_steering_ep09.gif
# iter24_mid_steering_ep10.gif
