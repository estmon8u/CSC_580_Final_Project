# %% [markdown]
# # Tiny Dreamer Highway — Iter 24: Mid Steering Penalty on Iter 17 Base
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10 + iter17 (no entropy)
# **Change:** `steering_penalty: 0.025 → 0.020`
#
# **Hypothesis:** Iter 22 (0.015) went off-road — too much steering freedom.
# Iter 17 (0.025) is passive — won't lane-change at all past ~1500 cycles.
# 0.020 is the tightest middle ground: still penalizes jitter but may allow
# occasional lane changes when the overtake reward is high enough.

# %% [markdown]
# ## Iteration 24 — Mid steering penalty (0.020)
#
# Phase 4 showed 0.015 goes off-road (iters 22, 23) while 0.025 goes passive.
# This tests the narrowest middle ground on the stable iter 17 base.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main       -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main       -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base + Iter10 winner (current best config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nBase overrides (iter5 + iter10):')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 17 Combined Overrides (Phase 3 winners) ---
# Iter 13: max_episode_steps 75 -> 120: longer episodes for more diverse data
config.env.max_episode_steps = 120
# Iter 15: batch_size 256 -> 384: more diverse transitions per update
config.training.batch_size = 384

# --- Iter 24: Mid steering penalty ---
# 0.025 (iter 17) = passive; 0.015 (iter 22) = off-road; 0.020 = middle ground
config.env.reward.steering_penalty = 0.020

print('\nIter 17 base overrides:')
print(f'  max_episode_steps = {config.env.max_episode_steps}')
print(f'  batch_size = {config.training.batch_size}')
print(f'\nIter 24 change:')
print(f'  steering_penalty = {config.env.reward.steering_penalty}  (was 0.025)')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 3,
#     "max_episode_steps": 120,
#     "lanes_count": 4,
#     "vehicles_count": 12,
#     "npc_speed_scale": 0.65,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.5,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": false,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.025,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 384,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "actor_entropy_weight": 0.0,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/notebooks/configs/training_run.yaml
# GPU: NVIDIA A100-SXM4-40GB
#
# Base overrides (iter5 + iter10):
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#
# Iter 17 base overrides:
#   max_episode_steps = 120
#   batch_size = 384
#
# Iter 24 change:
#   steering_penalty = 0.02  (was 0.025)

# %%
RUN_NAME = 'iter24_mid_steering'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = None

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter24_mid_steering
# Resume from: (fresh run — old artifacts will be cleared)
# Effective cycles: 500
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=500 | start_step=1 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1/500 | warm=10000 | policy=32 | replay=10032 | world_total=15148.7727 | actor=-0.4607 | critic=2.6231 | eval_reward=n/a | cycle_s=419.1 | elapsed_s=419.1 | checkpoint=-
# [train] step=2/500 | warm=0 | policy=32 | replay=10064 | world_total=13392.8597 | actor=0.8945 | critic=2.0824 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=425.9 | checkpoint=-
# [train] step=3/500 | warm=0 | policy=32 | replay=10096 | world_total=12649.5885 | actor=-0.0429 | critic=1.6451 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=434.1 | checkpoint=-
# [train] step=4/500 | warm=0 | policy=32 | replay=10128 | world_total=12433.4911 | actor=-0.6714 | critic=1.9053 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=442.9 | checkpoint=-
# [train] step=5/500 | warm=0 | policy=32 | replay=10160 | world_total=12148.8278 | actor=-4.2988 | critic=9.2209 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=451.5 | checkpoint=-
# [train] step=6/500 | warm=0 | policy=32 | replay=10192 | world_total=11891.3130 | actor=-5.1445 | critic=5.7045 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=460.5 | checkpoint=-
# [train] step=7/500 | warm=0 | policy=32 | replay=10224 | world_total=11704.2725 | actor=-6.4883 | critic=4.9215 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=469.4 | checkpoint=-
# [train] step=8/500 | warm=0 | policy=32 | replay=10256 | world_total=11626.3518 | actor=-4.7148 | critic=1.6741 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=477.9 | checkpoint=-
# [train] step=9/500 | warm=0 | policy=32 | replay=10288 | world_total=11558.2159 | actor=-4.7578 | critic=2.2352 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=487.0 | checkpoint=-
# [train] step=10/500 | warm=0 | policy=32 | replay=10320 | world_total=11522.7493 | actor=-7.0938 | critic=1.2320 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=495.1 | checkpoint=-
# [train] step=11/500 | warm=0 | policy=32 | replay=10352 | world_total=11511.0233 | actor=-6.1484 | critic=1.1139 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=502.8 | checkpoint=-
# [train] step=12/500 | warm=0 | policy=32 | replay=10384 | world_total=11506.6489 | actor=-8.1875 | critic=2.4195 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=511.4 | checkpoint=-
# [train] step=13/500 | warm=0 | policy=32 | replay=10416 | world_total=11492.5065 | actor=-7.4609 | critic=1.5832 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=520.1 | checkpoint=-
# [train] step=14/500 | warm=0 | policy=32 | replay=10448 | world_total=11484.2603 | actor=-10.1250 | critic=2.3225 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=528.6 | checkpoint=-
# [train] step=15/500 | warm=0 | policy=32 | replay=10480 | world_total=11476.1753 | actor=-11.1172 | critic=1.6243 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=537.3 | checkpoint=-
# [train] step=16/500 | warm=0 | policy=32 | replay=10512 | world_total=11469.4868 | actor=-12.8438 | critic=1.4416 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=546.6 | checkpoint=-
# [train] step=17/500 | warm=0 | policy=32 | replay=10544 | world_total=11463.8468 | actor=-13.9609 | critic=1.1672 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=555.8 | checkpoint=-
# [train] step=18/500 | warm=0 | policy=32 | replay=10576 | world_total=11462.8286 | actor=-14.5625 | critic=1.1808 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=565.7 | checkpoint=-
# [train] step=19/500 | warm=0 | policy=32 | replay=10608 | world_total=11461.8418 | actor=-15.2266 | critic=1.1721 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=574.6 | checkpoint=-
# [train] step=20/500 | warm=0 | policy=32 | replay=10640 | world_total=11458.2928 | actor=-16.0547 | critic=1.1706 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=583.9 | checkpoint=-
# [train] step=21/500 | warm=0 | policy=32 | replay=10672 | world_total=11458.3986 | actor=-16.0469 | critic=1.2155 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=593.3 | checkpoint=-
# [train] step=22/500 | warm=0 | policy=32 | replay=10704 | world_total=11456.4917 | actor=-16.5312 | critic=1.2436 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=602.5 | checkpoint=-
# [train] step=23/500 | warm=0 | policy=32 | replay=10736 | world_total=11454.6667 | actor=-16.5156 | critic=1.2350 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=611.5 | checkpoint=-
# [train] step=24/500 | warm=0 | policy=32 | replay=10768 | world_total=11453.5177 | actor=-17.4062 | critic=1.2957 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=620.6 | checkpoint=-
# [train] step=25/500 | warm=0 | policy=32 | replay=10800 | world_total=11452.3645 | actor=-18.0000 | critic=1.2213 | eval_reward=-0.5304 | cycle_s=17.0 | elapsed_s=637.5 | checkpoint=checkpoint_00025.pt
# [train] step=26/500 | warm=0 | policy=32 | replay=10832 | world_total=11451.7424 | actor=-18.3906 | critic=1.1690 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=645.9 | checkpoint=-
# [train] step=27/500 | warm=0 | policy=32 | replay=10864 | world_total=11450.8712 | actor=-18.1875 | critic=1.2910 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=654.3 | checkpoint=-
# [train] step=28/500 | warm=0 | policy=32 | replay=10896 | world_total=11450.1855 | actor=-18.3438 | critic=1.2415 | eval_reward=n/a | cycle_s=10.6 | elapsed_s=664.9 | checkpoint=-
# [train] step=29/500 | warm=0 | policy=32 | replay=10928 | world_total=11449.5135 | actor=-18.3750 | critic=1.1977 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=673.8 | checkpoint=-
# [train] step=30/500 | warm=0 | policy=32 | replay=10960 | world_total=11448.9567 | actor=-18.4688 | critic=1.2151 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=682.8 | checkpoint=-
# [train] step=31/500 | warm=0 | policy=32 | replay=10992 | world_total=11448.2031 | actor=-19.5469 | critic=1.4914 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=692.1 | checkpoint=-
# [train] step=32/500 | warm=0 | policy=32 | replay=11024 | world_total=11448.0663 | actor=-18.5938 | critic=1.4624 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=701.1 | checkpoint=-
# [train] step=33/500 | warm=0 | policy=32 | replay=11056 | world_total=11446.9846 | actor=-19.2188 | critic=1.3658 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=709.3 | checkpoint=-
# [train] step=34/500 | warm=0 | policy=32 | replay=11088 | world_total=11446.2579 | actor=-18.6562 | critic=1.4004 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=717.7 | checkpoint=-
# [train] step=35/500 | warm=0 | policy=32 | replay=11120 | world_total=11445.1324 | actor=-19.8594 | critic=1.9348 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=726.2 | checkpoint=-
# [train] step=36/500 | warm=0 | policy=32 | replay=11152 | world_total=11443.7070 | actor=-20.3281 | critic=1.4641 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=734.0 | checkpoint=-
# [train] step=37/500 | warm=0 | policy=32 | replay=11184 | world_total=11442.5551 | actor=-20.6094 | critic=1.8214 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=741.6 | checkpoint=-
# [train] step=38/500 | warm=0 | policy=32 | replay=11216 | world_total=11441.5016 | actor=-20.1406 | critic=1.5097 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=750.2 | checkpoint=-
# [train] step=39/500 | warm=0 | policy=32 | replay=11248 | world_total=11440.0768 | actor=-19.4844 | critic=1.5475 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=758.9 | checkpoint=-
# [train] step=40/500 | warm=0 | policy=32 | replay=11280 | world_total=11438.3530 | actor=-19.3906 | critic=1.5741 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=767.5 | checkpoint=-
# [train] step=41/500 | warm=0 | policy=32 | replay=11312 | world_total=11436.8986 | actor=-19.3750 | critic=1.5506 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=775.9 | checkpoint=-
# [train] step=42/500 | warm=0 | policy=32 | replay=11344 | world_total=11434.9156 | actor=-19.5469 | critic=1.6025 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=784.7 | checkpoint=-
# [train] step=43/500 | warm=0 | policy=32 | replay=11376 | world_total=11433.4871 | actor=-19.0469 | critic=1.6759 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=793.1 | checkpoint=-
# [train] step=44/500 | warm=0 | policy=32 | replay=11408 | world_total=11431.9849 | actor=-19.6562 | critic=1.7937 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=801.3 | checkpoint=-
# [train] step=45/500 | warm=0 | policy=32 | replay=11440 | world_total=11431.5021 | actor=-19.3438 | critic=1.7252 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=809.8 | checkpoint=-
# [train] step=46/500 | warm=0 | policy=32 | replay=11472 | world_total=11430.5751 | actor=-19.2500 | critic=2.1194 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=818.6 | checkpoint=-
# [train] step=47/500 | warm=0 | policy=32 | replay=11504 | world_total=11429.1071 | actor=-17.6875 | critic=2.5028 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=827.3 | checkpoint=-
# [train] step=48/500 | warm=0 | policy=32 | replay=11536 | world_total=11427.8037 | actor=-16.5781 | critic=1.8061 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=835.9 | checkpoint=-
# [train] step=49/500 | warm=0 | policy=32 | replay=11568 | world_total=11426.6887 | actor=-15.7344 | critic=1.8079 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=844.9 | checkpoint=-
# [train] step=50/500 | warm=0 | policy=32 | replay=11600 | world_total=11425.0114 | actor=-15.9453 | critic=1.9912 | eval_reward=-0.5334 | cycle_s=16.3 | elapsed_s=861.3 | checkpoint=checkpoint_00050.pt
# [train] step=51/500 | warm=0 | policy=32 | replay=11632 | world_total=11423.7479 | actor=-16.2344 | critic=2.5134 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=869.8 | checkpoint=-
# [train] step=52/500 | warm=0 | policy=32 | replay=11664 | world_total=11423.9802 | actor=-15.9688 | critic=2.7748 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=878.3 | checkpoint=-
# [train] step=53/500 | warm=0 | policy=32 | replay=11696 | world_total=11422.6392 | actor=-15.2891 | critic=3.1322 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=886.8 | checkpoint=-
# [train] step=54/500 | warm=0 | policy=32 | replay=11728 | world_total=11421.1155 | actor=-15.2734 | critic=2.8994 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=896.0 | checkpoint=-
# [train] step=55/500 | warm=0 | policy=32 | replay=11760 | world_total=11419.5928 | actor=-16.8750 | critic=3.5708 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=904.4 | checkpoint=-
# [train] step=56/500 | warm=0 | policy=32 | replay=11792 | world_total=11418.0525 | actor=-15.6797 | critic=6.5004 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=912.5 | checkpoint=-
# [train] step=57/500 | warm=0 | policy=32 | replay=11824 | world_total=11416.3235 | actor=-17.7969 | critic=4.1603 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=921.0 | checkpoint=-
# [train] step=58/500 | warm=0 | policy=32 | replay=11856 | world_total=11414.7087 | actor=-16.9531 | critic=4.9082 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=930.9 | checkpoint=-
# [train] step=59/500 | warm=0 | policy=32 | replay=11888 | world_total=11412.4740 | actor=-15.1094 | critic=7.9625 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=939.5 | checkpoint=-
# [train] step=60/500 | warm=0 | policy=32 | replay=11920 | world_total=11411.3774 | actor=-15.6953 | critic=4.7118 | eval_reward=n/a | cycle_s=9.8 | elapsed_s=949.3 | checkpoint=-
# [train] step=61/500 | warm=0 | policy=32 | replay=11952 | world_total=11409.5354 | actor=-15.6484 | critic=5.2215 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=958.3 | checkpoint=-
# [train] step=62/500 | warm=0 | policy=32 | replay=11984 | world_total=11407.9940 | actor=-16.2578 | critic=6.8643 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=968.0 | checkpoint=-
# [train] step=63/500 | warm=0 | policy=32 | replay=12016 | world_total=11406.5450 | actor=-17.0312 | critic=9.3881 | eval_reward=n/a | cycle_s=10.2 | elapsed_s=978.2 | checkpoint=-
# [train] step=64/500 | warm=0 | policy=32 | replay=12048 | world_total=11404.9346 | actor=-18.7656 | critic=8.5723 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=987.1 | checkpoint=-
# [train] step=65/500 | warm=0 | policy=32 | replay=12080 | world_total=11403.0492 | actor=-19.1562 | critic=11.8560 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=996.0 | checkpoint=-
# [train] step=66/500 | warm=0 | policy=32 | replay=12112 | world_total=11401.8019 | actor=-23.2969 | critic=13.8548 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1004.7 | checkpoint=-
# [train] step=67/500 | warm=0 | policy=32 | replay=12144 | world_total=11400.0255 | actor=-23.5781 | critic=16.2609 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1012.6 | checkpoint=-
# [train] step=68/500 | warm=0 | policy=32 | replay=12176 | world_total=11398.0308 | actor=-28.7031 | critic=18.8719 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1021.0 | checkpoint=-
# [train] step=69/500 | warm=0 | policy=32 | replay=12208 | world_total=11396.0167 | actor=-31.0000 | critic=24.4488 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=1029.9 | checkpoint=-
# [train] step=70/500 | warm=0 | policy=32 | replay=12240 | world_total=11394.1821 | actor=-35.0000 | critic=29.9750 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1039.1 | checkpoint=-
# [train] step=71/500 | warm=0 | policy=32 | replay=12272 | world_total=11392.4988 | actor=-31.3125 | critic=56.8379 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=1048.2 | checkpoint=-
# [train] step=72/500 | warm=0 | policy=32 | replay=12304 | world_total=11390.5021 | actor=-37.4062 | critic=37.0480 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1057.0 | checkpoint=-
# [train] step=73/500 | warm=0 | policy=32 | replay=12336 | world_total=11388.4452 | actor=-38.0000 | critic=43.1969 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1065.8 | checkpoint=-
# [train] step=74/500 | warm=0 | policy=32 | replay=12368 | world_total=11386.6227 | actor=-36.9062 | critic=74.6957 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1074.8 | checkpoint=-
# [train] step=75/500 | warm=0 | policy=32 | replay=12400 | world_total=11385.0958 | actor=-37.4688 | critic=63.1339 | eval_reward=-0.5301 | cycle_s=16.7 | elapsed_s=1091.6 | checkpoint=checkpoint_00075.pt
# [train] step=76/500 | warm=0 | policy=32 | replay=12432 | world_total=11383.0283 | actor=-36.9062 | critic=63.1491 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1100.3 | checkpoint=-
# [train] step=77/500 | warm=0 | policy=32 | replay=12464 | world_total=11381.7573 | actor=-41.8438 | critic=79.9073 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=1109.4 | checkpoint=-
# [train] step=78/500 | warm=0 | policy=32 | replay=12496 | world_total=11380.0338 | actor=-55.1250 | critic=106.6695 | eval_reward=n/a | cycle_s=9.8 | elapsed_s=1119.1 | checkpoint=-
# [train] step=79/500 | warm=0 | policy=32 | replay=12528 | world_total=11379.4266 | actor=-51.9688 | critic=157.7494 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=1129.2 | checkpoint=-
# [train] step=80/500 | warm=0 | policy=32 | replay=12560 | world_total=11377.6641 | actor=-57.5625 | critic=147.3312 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1138.3 | checkpoint=-
# [train] step=81/500 | warm=0 | policy=32 | replay=12592 | world_total=11376.2734 | actor=-46.0312 | critic=171.8326 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1146.5 | checkpoint=-
# [train] step=82/500 | warm=0 | policy=32 | replay=12624 | world_total=11375.2944 | actor=-43.5000 | critic=126.4447 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1154.3 | checkpoint=-
# [train] step=83/500 | warm=0 | policy=32 | replay=12656 | world_total=11373.4714 | actor=-35.5312 | critic=96.7033 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1162.5 | checkpoint=-
# [train] step=84/500 | warm=0 | policy=32 | replay=12688 | world_total=11371.6294 | actor=-36.7812 | critic=106.1269 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=1170.6 | checkpoint=-
# [train] step=85/500 | warm=0 | policy=32 | replay=12720 | world_total=11369.7727 | actor=-42.7500 | critic=130.0507 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1178.8 | checkpoint=-
# [train] step=86/500 | warm=0 | policy=32 | replay=12752 | world_total=11368.0592 | actor=-33.5781 | critic=163.7445 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1187.0 | checkpoint=-
# [train] step=87/500 | warm=0 | policy=32 | replay=12784 | world_total=11366.0419 | actor=-38.2812 | critic=119.9259 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1195.2 | checkpoint=-
# [train] step=88/500 | warm=0 | policy=32 | replay=12816 | world_total=11363.9594 | actor=-32.0625 | critic=94.1259 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=1204.5 | checkpoint=-
# [train] step=89/500 | warm=0 | policy=32 | replay=12848 | world_total=11362.2590 | actor=-18.3047 | critic=83.8292 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=1213.6 | checkpoint=-
# [train] step=90/500 | warm=0 | policy=32 | replay=12880 | world_total=11360.6205 | actor=-15.0156 | critic=49.1574 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=1223.3 | checkpoint=-
# [train] step=91/500 | warm=0 | policy=32 | replay=12912 | world_total=11358.9098 | actor=-11.5156 | critic=33.3746 | eval_reward=n/a | cycle_s=10.3 | elapsed_s=1233.6 | checkpoint=-
# [train] step=92/500 | warm=0 | policy=32 | replay=12944 | world_total=11357.2330 | actor=-13.6719 | critic=33.7364 | eval_reward=n/a | cycle_s=10.1 | elapsed_s=1243.7 | checkpoint=-
# [train] step=93/500 | warm=0 | policy=32 | replay=12976 | world_total=11355.6345 | actor=-12.0078 | critic=30.9234 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=1252.6 | checkpoint=-
# [train] step=94/500 | warm=0 | policy=32 | replay=13008 | world_total=11354.3048 | actor=-9.1133 | critic=21.8932 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1261.6 | checkpoint=-
# [train] step=95/500 | warm=0 | policy=32 | replay=13040 | world_total=11353.0095 | actor=-8.3359 | critic=17.8668 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1270.3 | checkpoint=-
# [train] step=96/500 | warm=0 | policy=32 | replay=13072 | world_total=11351.7554 | actor=-6.7891 | critic=13.3711 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1279.0 | checkpoint=-
# [train] step=97/500 | warm=0 | policy=32 | replay=13104 | world_total=11350.8108 | actor=-7.9570 | critic=13.5402 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1287.4 | checkpoint=-
# [train] step=98/500 | warm=0 | policy=32 | replay=13136 | world_total=11350.2458 | actor=-6.3125 | critic=12.5279 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1295.7 | checkpoint=-
# [train] step=99/500 | warm=0 | policy=32 | replay=13168 | world_total=11349.3628 | actor=-5.4648 | critic=9.6743 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1304.0 | checkpoint=-
# [train] step=100/500 | warm=0 | policy=32 | replay=13200 | world_total=11348.3781 | actor=-4.2500 | critic=6.9494 | eval_reward=-0.5308 | cycle_s=18.0 | elapsed_s=1322.0 | checkpoint=checkpoint_00100.pt
# [train] step=101/500 | warm=0 | policy=32 | replay=13232 | world_total=11347.4364 | actor=-5.7070 | critic=8.3588 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=1332.0 | checkpoint=-
# [train] step=102/500 | warm=0 | policy=32 | replay=13264 | world_total=11346.6833 | actor=-4.7422 | critic=7.0880 | eval_reward=n/a | cycle_s=9.8 | elapsed_s=1341.8 | checkpoint=-
# [train] step=103/500 | warm=0 | policy=32 | replay=13296 | world_total=11345.9310 | actor=-4.0801 | critic=6.3570 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1349.7 | checkpoint=-
# [train] step=104/500 | warm=0 | policy=32 | replay=13328 | world_total=11345.3907 | actor=-4.0098 | critic=5.4131 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1358.1 | checkpoint=-
# [train] step=105/500 | warm=0 | policy=32 | replay=13360 | world_total=11344.6725 | actor=-3.3340 | critic=4.4992 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1365.9 | checkpoint=-
# [train] step=106/500 | warm=0 | policy=32 | replay=13392 | world_total=11344.1646 | actor=-3.5234 | critic=4.4486 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1374.2 | checkpoint=-
# [train] step=107/500 | warm=0 | policy=32 | replay=13424 | world_total=11343.6626 | actor=-1.7910 | critic=3.4023 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1382.3 | checkpoint=-
# [train] step=108/500 | warm=0 | policy=32 | replay=13456 | world_total=11343.1399 | actor=-2.0098 | critic=2.9326 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1390.9 | checkpoint=-
# [train] step=109/500 | warm=0 | policy=32 | replay=13488 | world_total=11342.7618 | actor=-1.9766 | critic=2.6734 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1399.8 | checkpoint=-
# [train] step=110/500 | warm=0 | policy=32 | replay=13520 | world_total=11342.7773 | actor=-1.4385 | critic=2.3613 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1408.8 | checkpoint=-
# [train] step=111/500 | warm=0 | policy=32 | replay=13552 | world_total=11342.5138 | actor=-1.2124 | critic=2.1358 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=1418.2 | checkpoint=-
# [train] step=112/500 | warm=0 | policy=32 | replay=13584 | world_total=11341.6953 | actor=-1.3799 | critic=2.1157 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=1427.8 | checkpoint=-
# [train] step=113/500 | warm=0 | policy=32 | replay=13616 | world_total=11341.3271 | actor=-1.1074 | critic=1.8593 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=1437.2 | checkpoint=-
# [train] step=114/500 | warm=0 | policy=32 | replay=13648 | world_total=11340.9734 | actor=-0.8394 | critic=1.8097 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=1447.2 | checkpoint=-
# [train] step=115/500 | warm=0 | policy=32 | replay=13680 | world_total=11340.4559 | actor=-0.3750 | critic=1.7863 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1456.4 | checkpoint=-
# [train] step=116/500 | warm=0 | policy=32 | replay=13712 | world_total=11340.0671 | actor=-0.3201 | critic=1.6229 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=1465.4 | checkpoint=-
# [train] step=117/500 | warm=0 | policy=32 | replay=13744 | world_total=11339.7805 | actor=-0.3723 | critic=1.6159 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1473.8 | checkpoint=-
# [train] step=118/500 | warm=0 | policy=32 | replay=13776 | world_total=11339.4569 | actor=-0.3884 | critic=1.5355 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1482.9 | checkpoint=-
# [train] step=119/500 | warm=0 | policy=32 | replay=13808 | world_total=11339.2030 | actor=0.0146 | critic=1.6068 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=1492.5 | checkpoint=-
# [train] step=120/500 | warm=0 | policy=32 | replay=13840 | world_total=11339.1897 | actor=-0.1216 | critic=1.5386 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1501.5 | checkpoint=-
# [train] step=121/500 | warm=0 | policy=32 | replay=13872 | world_total=11338.7567 | actor=-0.4121 | critic=1.4767 | eval_reward=n/a | cycle_s=9.5 | elapsed_s=1511.0 | checkpoint=-
# [train] step=122/500 | warm=0 | policy=32 | replay=13904 | world_total=11338.4976 | actor=-0.5286 | critic=1.3905 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=1520.4 | checkpoint=-
# [train] step=123/500 | warm=0 | policy=32 | replay=13936 | world_total=11338.3619 | actor=0.2603 | critic=1.7449 | eval_reward=n/a | cycle_s=9.5 | elapsed_s=1530.0 | checkpoint=-
# [train] step=124/500 | warm=0 | policy=32 | replay=13968 | world_total=11338.0183 | actor=-0.0173 | critic=1.5182 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=1539.7 | checkpoint=-
# [train] step=125/500 | warm=0 | policy=32 | replay=14000 | world_total=11337.6200 | actor=-0.1422 | critic=1.4510 | eval_reward=-0.5308 | cycle_s=18.6 | elapsed_s=1558.3 | checkpoint=checkpoint_00125.pt
# [train] step=126/500 | warm=0 | policy=32 | replay=14032 | world_total=11337.3879 | actor=-0.0903 | critic=1.3719 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1567.0 | checkpoint=-
# [train] step=127/500 | warm=0 | policy=32 | replay=14064 | world_total=11337.0099 | actor=0.1438 | critic=1.4886 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1575.4 | checkpoint=-
# [train] step=128/500 | warm=0 | policy=32 | replay=14096 | world_total=11336.7908 | actor=-0.0489 | critic=1.3652 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1583.7 | checkpoint=-
# [train] step=129/500 | warm=0 | policy=32 | replay=14128 | world_total=11336.6580 | actor=-0.2217 | critic=1.3697 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1591.6 | checkpoint=-
# [train] step=130/500 | warm=0 | policy=32 | replay=14160 | world_total=11336.3619 | actor=-0.2117 | critic=1.3587 | eval_reward=n/a | cycle_s=9.5 | elapsed_s=1601.1 | checkpoint=-
# [train] step=131/500 | warm=0 | policy=32 | replay=14192 | world_total=11336.2223 | actor=-0.0976 | critic=1.3396 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1610.3 | checkpoint=-
# [train] step=132/500 | warm=0 | policy=32 | replay=14224 | world_total=11336.0127 | actor=0.1131 | critic=1.3673 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1619.3 | checkpoint=-
# [train] step=133/500 | warm=0 | policy=32 | replay=14256 | world_total=11335.7604 | actor=-0.0766 | critic=1.3961 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1628.0 | checkpoint=-
# [train] step=134/500 | warm=0 | policy=32 | replay=14288 | world_total=11335.6033 | actor=0.0374 | critic=1.3486 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=1637.1 | checkpoint=-
# [train] step=135/500 | warm=0 | policy=32 | replay=14320 | world_total=11335.5033 | actor=-0.1736 | critic=1.3321 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1645.9 | checkpoint=-
# [train] step=136/500 | warm=0 | policy=32 | replay=14352 | world_total=11335.3212 | actor=-0.0274 | critic=1.3305 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=1655.6 | checkpoint=-
# [train] step=137/500 | warm=0 | policy=32 | replay=14384 | world_total=11335.0497 | actor=0.0481 | critic=1.3373 | eval_reward=n/a | cycle_s=9.5 | elapsed_s=1665.1 | checkpoint=-
# [train] step=138/500 | warm=0 | policy=32 | replay=14416 | world_total=11334.8872 | actor=0.0780 | critic=1.3850 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1673.8 | checkpoint=-
# [train] step=139/500 | warm=0 | policy=32 | replay=14448 | world_total=11334.7245 | actor=-0.2344 | critic=1.3672 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1682.4 | checkpoint=-
# [train] step=140/500 | warm=0 | policy=32 | replay=14480 | world_total=11334.5710 | actor=-0.1541 | critic=1.3377 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1691.3 | checkpoint=-
# [train] step=141/500 | warm=0 | policy=32 | replay=14512 | world_total=11334.3285 | actor=-0.1784 | critic=1.3312 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1699.9 | checkpoint=-
# [train] step=142/500 | warm=0 | policy=32 | replay=14544 | world_total=11334.1530 | actor=-0.0412 | critic=1.3482 | eval_reward=n/a | cycle_s=9.7 | elapsed_s=1709.6 | checkpoint=-
# [train] step=143/500 | warm=0 | policy=32 | replay=14576 | world_total=11334.0299 | actor=-0.1327 | critic=1.3484 | eval_reward=n/a | cycle_s=10.1 | elapsed_s=1719.7 | checkpoint=-
# [train] step=144/500 | warm=0 | policy=32 | replay=14608 | world_total=11333.9059 | actor=-0.1206 | critic=1.3202 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1728.4 | checkpoint=-
# [train] step=145/500 | warm=0 | policy=32 | replay=14640 | world_total=11333.7585 | actor=-0.2118 | critic=1.3416 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1737.6 | checkpoint=-
# [train] step=146/500 | warm=0 | policy=32 | replay=14672 | world_total=11333.4929 | actor=-0.1014 | critic=1.3892 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=1746.5 | checkpoint=-
# [train] step=147/500 | warm=0 | policy=32 | replay=14704 | world_total=11333.4523 | actor=0.0506 | critic=1.3878 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1755.5 | checkpoint=-
# [train] step=148/500 | warm=0 | policy=32 | replay=14736 | world_total=11333.1689 | actor=-0.3234 | critic=1.4113 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1764.5 | checkpoint=-
# [train] step=149/500 | warm=0 | policy=32 | replay=14768 | world_total=11333.1565 | actor=-0.0615 | critic=1.4473 | eval_reward=n/a | cycle_s=9.8 | elapsed_s=1774.3 | checkpoint=-
# [train] step=150/500 | warm=0 | policy=32 | replay=14800 | world_total=11332.9674 | actor=0.1544 | critic=1.4567 | eval_reward=-0.5336 | cycle_s=17.8 | elapsed_s=1792.1 | checkpoint=checkpoint_00150.pt
# [train] step=151/500 | warm=0 | policy=32 | replay=14832 | world_total=11332.8046 | actor=0.1136 | critic=1.4640 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1800.6 | checkpoint=-
# [train] step=152/500 | warm=0 | policy=32 | replay=14864 | world_total=11332.6610 | actor=0.0564 | critic=1.4281 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1809.6 | checkpoint=-
# [train] step=153/500 | warm=0 | policy=32 | replay=14896 | world_total=11332.5603 | actor=-0.0606 | critic=1.4012 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=1819.2 | checkpoint=-
# [train] step=154/500 | warm=0 | policy=32 | replay=14928 | world_total=11332.4153 | actor=0.1730 | critic=1.4597 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1828.4 | checkpoint=-
# [train] step=155/500 | warm=0 | policy=32 | replay=14960 | world_total=11332.2784 | actor=0.0868 | critic=1.4291 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=1838.1 | checkpoint=-
# [train] step=156/500 | warm=0 | policy=32 | replay=14992 | world_total=11332.2391 | actor=0.0403 | critic=1.3976 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=1847.5 | checkpoint=-
# [train] step=157/500 | warm=0 | policy=32 | replay=15024 | world_total=11332.0017 | actor=0.0750 | critic=1.3982 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=1856.8 | checkpoint=-
# [train] step=158/500 | warm=0 | policy=32 | replay=15056 | world_total=11332.0505 | actor=0.2097 | critic=1.4418 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1865.5 | checkpoint=-
# [train] step=159/500 | warm=0 | policy=32 | replay=15088 | world_total=11331.8953 | actor=-0.0584 | critic=1.4360 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=1874.7 | checkpoint=-
# [train] step=160/500 | warm=0 | policy=32 | replay=15120 | world_total=11331.6573 | actor=-0.0742 | critic=1.4039 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1883.1 | checkpoint=-
# [train] step=161/500 | warm=0 | policy=32 | replay=15152 | world_total=11331.5653 | actor=-0.0982 | critic=1.3626 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1891.8 | checkpoint=-
# [train] step=162/500 | warm=0 | policy=32 | replay=15184 | world_total=11331.4890 | actor=0.0445 | critic=1.3783 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1900.3 | checkpoint=-
# [train] step=163/500 | warm=0 | policy=32 | replay=15216 | world_total=11331.3596 | actor=-0.2063 | critic=1.4297 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1909.6 | checkpoint=-
# [train] step=164/500 | warm=0 | policy=32 | replay=15248 | world_total=11331.1699 | actor=-0.2429 | critic=1.3992 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=1919.5 | checkpoint=-
# [train] step=165/500 | warm=0 | policy=32 | replay=15280 | world_total=11331.1910 | actor=-0.0115 | critic=1.4222 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1928.7 | checkpoint=-
# [train] step=166/500 | warm=0 | policy=32 | replay=15312 | world_total=11330.9398 | actor=0.0680 | critic=1.4717 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=1937.9 | checkpoint=-
# [train] step=167/500 | warm=0 | policy=32 | replay=15344 | world_total=11330.8835 | actor=-0.1171 | critic=1.5596 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1946.8 | checkpoint=-
# [train] step=168/500 | warm=0 | policy=32 | replay=15376 | world_total=11331.2902 | actor=0.2101 | critic=1.9623 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1955.0 | checkpoint=-
# [train] step=169/500 | warm=0 | policy=32 | replay=15408 | world_total=11331.9741 | actor=-0.8306 | critic=2.3831 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1963.5 | checkpoint=-
# [train] step=170/500 | warm=0 | policy=32 | replay=15440 | world_total=11331.6273 | actor=-0.6626 | critic=2.3181 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1970.9 | checkpoint=-
# [train] step=171/500 | warm=0 | policy=32 | replay=15472 | world_total=11331.2073 | actor=-0.8389 | critic=2.3622 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1978.5 | checkpoint=-
# [train] step=172/500 | warm=0 | policy=32 | replay=15504 | world_total=11331.0677 | actor=-1.1558 | critic=2.6685 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1985.7 | checkpoint=-
# [train] step=173/500 | warm=0 | policy=32 | replay=15536 | world_total=11331.0452 | actor=-1.8115 | critic=2.9292 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1993.5 | checkpoint=-
# [train] step=174/500 | warm=0 | policy=32 | replay=15568 | world_total=11330.9937 | actor=-2.5137 | critic=3.3379 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2000.8 | checkpoint=-
# [train] step=175/500 | warm=0 | policy=32 | replay=15600 | world_total=11330.8160 | actor=-3.4004 | critic=3.9875 | eval_reward=1.5176 | cycle_s=17.4 | elapsed_s=2018.2 | checkpoint=checkpoint_00175.pt
# [train] step=176/500 | warm=0 | policy=32 | replay=15632 | world_total=11330.9376 | actor=-4.3047 | critic=5.0067 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2026.5 | checkpoint=-
# [train] step=177/500 | warm=0 | policy=32 | replay=15664 | world_total=11330.6260 | actor=-5.3008 | critic=5.6909 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2034.8 | checkpoint=-
# [train] step=178/500 | warm=0 | policy=32 | replay=15696 | world_total=11330.4276 | actor=-6.3516 | critic=5.9203 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=2043.8 | checkpoint=-
# [train] step=179/500 | warm=0 | policy=32 | replay=15728 | world_total=11330.3544 | actor=-6.9492 | critic=5.7062 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2051.8 | checkpoint=-
# [train] step=180/500 | warm=0 | policy=32 | replay=15760 | world_total=11330.2081 | actor=-9.7109 | critic=6.8161 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=2061.2 | checkpoint=-
# [train] step=181/500 | warm=0 | policy=32 | replay=15792 | world_total=11330.0963 | actor=-12.5703 | critic=7.6718 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2070.0 | checkpoint=-
# [train] step=182/500 | warm=0 | policy=32 | replay=15824 | world_total=11330.1727 | actor=-15.4453 | critic=7.5690 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2078.3 | checkpoint=-
# [train] step=183/500 | warm=0 | policy=32 | replay=15856 | world_total=11330.0813 | actor=-18.0625 | critic=7.5494 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2086.6 | checkpoint=-
# [train] step=184/500 | warm=0 | policy=32 | replay=15888 | world_total=11329.8916 | actor=-21.5156 | critic=10.0021 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2095.1 | checkpoint=-
# [train] step=185/500 | warm=0 | policy=32 | replay=15920 | world_total=11329.7493 | actor=-22.7969 | critic=12.3086 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=2103.2 | checkpoint=-
# [train] step=186/500 | warm=0 | policy=32 | replay=15952 | world_total=11329.5873 | actor=-23.4844 | critic=10.3838 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2111.1 | checkpoint=-
# [train] step=187/500 | warm=0 | policy=32 | replay=15984 | world_total=11329.4888 | actor=-22.0625 | critic=11.7998 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2119.8 | checkpoint=-
# [train] step=188/500 | warm=0 | policy=32 | replay=16016 | world_total=11329.3304 | actor=-21.4688 | critic=8.9609 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2128.3 | checkpoint=-
# [train] step=189/500 | warm=0 | policy=32 | replay=16048 | world_total=11329.3156 | actor=-20.1562 | critic=10.1413 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=2135.9 | checkpoint=-
# [train] step=190/500 | warm=0 | policy=32 | replay=16080 | world_total=11329.4210 | actor=-19.4531 | critic=10.8670 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2144.7 | checkpoint=-
# [train] step=191/500 | warm=0 | policy=32 | replay=16112 | world_total=11329.4800 | actor=-19.9062 | critic=10.1265 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2153.3 | checkpoint=-
# [train] step=192/500 | warm=0 | policy=32 | replay=16144 | world_total=11329.3164 | actor=-18.1719 | critic=13.2395 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2162.2 | checkpoint=-
# [train] step=193/500 | warm=0 | policy=32 | replay=16176 | world_total=11329.1538 | actor=-17.5938 | critic=9.7038 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2171.0 | checkpoint=-
# [train] step=194/500 | warm=0 | policy=32 | replay=16208 | world_total=11329.1605 | actor=-16.7812 | critic=7.8867 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=2179.1 | checkpoint=-
# [train] step=195/500 | warm=0 | policy=32 | replay=16240 | world_total=11329.1097 | actor=-14.1328 | critic=11.5944 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2188.0 | checkpoint=-
# [train] step=196/500 | warm=0 | policy=32 | replay=16272 | world_total=11330.5229 | actor=-16.6250 | critic=11.3942 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=2195.3 | checkpoint=-
# [train] step=197/500 | warm=0 | policy=32 | replay=16304 | world_total=11331.7534 | actor=-13.1875 | critic=11.8282 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2203.8 | checkpoint=-
# [train] step=198/500 | warm=0 | policy=32 | replay=16336 | world_total=11330.4735 | actor=-15.2969 | critic=8.6733 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2211.5 | checkpoint=-
# [train] step=199/500 | warm=0 | policy=32 | replay=16368 | world_total=11329.7573 | actor=-14.0391 | critic=10.3781 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2219.7 | checkpoint=-
# [train] step=200/500 | warm=0 | policy=32 | replay=16400 | world_total=11329.3369 | actor=-13.6406 | critic=10.2790 | eval_reward=2.0530 | cycle_s=17.8 | elapsed_s=2237.5 | checkpoint=checkpoint_00200.pt
# [train] step=201/500 | warm=0 | policy=32 | replay=16432 | world_total=11329.2122 | actor=-15.6328 | critic=8.9835 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2245.3 | checkpoint=-
# [train] step=202/500 | warm=0 | policy=32 | replay=16464 | world_total=11329.2090 | actor=-17.4219 | critic=10.2469 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2253.2 | checkpoint=-
# [train] step=203/500 | warm=0 | policy=32 | replay=16496 | world_total=11329.3743 | actor=-17.1250 | critic=13.1469 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2260.5 | checkpoint=-
# [train] step=204/500 | warm=0 | policy=32 | replay=16528 | world_total=11329.1965 | actor=-18.3125 | critic=12.4516 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2268.1 | checkpoint=-
# [train] step=205/500 | warm=0 | policy=32 | replay=16560 | world_total=11329.1569 | actor=-19.9844 | critic=10.4870 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2275.8 | checkpoint=-
# [train] step=206/500 | warm=0 | policy=32 | replay=16592 | world_total=11330.0745 | actor=-21.7344 | critic=12.3927 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2283.7 | checkpoint=-
# [train] step=207/500 | warm=0 | policy=32 | replay=16624 | world_total=11330.4543 | actor=-21.9688 | critic=13.1583 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2292.5 | checkpoint=-
# [train] step=208/500 | warm=0 | policy=32 | replay=16656 | world_total=11330.7292 | actor=-22.4062 | critic=15.4672 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2300.9 | checkpoint=-
# [train] step=209/500 | warm=0 | policy=32 | replay=16688 | world_total=11330.4948 | actor=-22.7500 | critic=14.3109 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2308.9 | checkpoint=-
# [train] step=210/500 | warm=0 | policy=32 | replay=16720 | world_total=11330.2549 | actor=-23.6094 | critic=10.7893 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2317.8 | checkpoint=-
# [train] step=211/500 | warm=0 | policy=32 | replay=16752 | world_total=11330.0010 | actor=-25.2812 | critic=12.7709 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2325.5 | checkpoint=-
# [train] step=212/500 | warm=0 | policy=32 | replay=16784 | world_total=11329.9591 | actor=-25.8594 | critic=11.9459 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2333.5 | checkpoint=-
# [train] step=213/500 | warm=0 | policy=32 | replay=16816 | world_total=11329.8975 | actor=-26.7969 | critic=13.9060 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2342.4 | checkpoint=-
# [train] step=214/500 | warm=0 | policy=32 | replay=16848 | world_total=11329.8096 | actor=-25.8438 | critic=14.3563 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2350.9 | checkpoint=-
# [train] step=215/500 | warm=0 | policy=32 | replay=16880 | world_total=11329.6995 | actor=-24.6562 | critic=15.1471 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=2359.9 | checkpoint=-
# [train] step=216/500 | warm=0 | policy=32 | replay=16912 | world_total=11329.5721 | actor=-24.5000 | critic=11.7908 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2368.6 | checkpoint=-
# [train] step=217/500 | warm=0 | policy=32 | replay=16944 | world_total=11329.6113 | actor=-25.0000 | critic=11.1233 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2377.4 | checkpoint=-
# [train] step=218/500 | warm=0 | policy=32 | replay=16976 | world_total=11329.4658 | actor=-25.8438 | critic=11.6146 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2386.2 | checkpoint=-
# [train] step=219/500 | warm=0 | policy=32 | replay=17008 | world_total=11329.3816 | actor=-26.9062 | critic=11.7096 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2395.1 | checkpoint=-
# [train] step=220/500 | warm=0 | policy=32 | replay=17040 | world_total=11329.3690 | actor=-26.3750 | critic=13.3266 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=2404.2 | checkpoint=-
# [train] step=221/500 | warm=0 | policy=32 | replay=17072 | world_total=11329.1448 | actor=-25.7969 | critic=13.6365 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2411.5 | checkpoint=-
# [train] step=222/500 | warm=0 | policy=32 | replay=17104 | world_total=11328.7598 | actor=-25.5000 | critic=11.3425 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2419.7 | checkpoint=-
# [train] step=223/500 | warm=0 | policy=32 | replay=17136 | world_total=11328.6703 | actor=-23.6875 | critic=13.3005 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2427.4 | checkpoint=-
# [train] step=224/500 | warm=0 | policy=32 | replay=17168 | world_total=11328.5093 | actor=-21.0312 | critic=13.8599 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2435.7 | checkpoint=-
# [train] step=225/500 | warm=0 | policy=32 | replay=17200 | world_total=11328.3989 | actor=-20.6406 | critic=9.9000 | eval_reward=16.9973 | cycle_s=24.0 | elapsed_s=2459.7 | checkpoint=checkpoint_00225.pt
# [train] step=226/500 | warm=0 | policy=32 | replay=17232 | world_total=11328.4153 | actor=-21.0781 | critic=9.1793 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=2468.9 | checkpoint=-
# [train] step=227/500 | warm=0 | policy=32 | replay=17264 | world_total=11328.4222 | actor=-18.5625 | critic=13.6940 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2477.1 | checkpoint=-
# [train] step=228/500 | warm=0 | policy=32 | replay=17296 | world_total=11328.3613 | actor=-21.9844 | critic=9.9213 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2485.4 | checkpoint=-
# [train] step=229/500 | warm=0 | policy=32 | replay=17328 | world_total=11328.2080 | actor=-23.2188 | critic=9.8198 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2494.0 | checkpoint=-
# [train] step=230/500 | warm=0 | policy=32 | replay=17360 | world_total=11328.1482 | actor=-24.6562 | critic=12.6247 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2502.9 | checkpoint=-
# [train] step=231/500 | warm=0 | policy=32 | replay=17392 | world_total=11328.1338 | actor=-26.1875 | critic=12.7410 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2511.5 | checkpoint=-
# [train] step=232/500 | warm=0 | policy=32 | replay=17424 | world_total=11328.0054 | actor=-26.5000 | critic=13.2855 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2520.1 | checkpoint=-
# [train] step=233/500 | warm=0 | policy=32 | replay=17456 | world_total=11328.0121 | actor=-26.8281 | critic=12.5465 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2528.4 | checkpoint=-
# [train] step=234/500 | warm=0 | policy=32 | replay=17488 | world_total=11327.9829 | actor=-28.2500 | critic=12.0302 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=2535.9 | checkpoint=-
# [train] step=235/500 | warm=0 | policy=32 | replay=17520 | world_total=11327.9735 | actor=-27.9375 | critic=13.4688 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2543.9 | checkpoint=-
# [train] step=236/500 | warm=0 | policy=32 | replay=17552 | world_total=11327.9822 | actor=-29.3281 | critic=11.1776 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2552.1 | checkpoint=-
# [train] step=237/500 | warm=0 | policy=32 | replay=17584 | world_total=11327.8407 | actor=-29.9375 | critic=10.3327 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2560.7 | checkpoint=-
# [train] step=238/500 | warm=0 | policy=32 | replay=17616 | world_total=11327.8333 | actor=-29.5781 | critic=14.6638 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2569.3 | checkpoint=-
# [train] step=239/500 | warm=0 | policy=32 | replay=17648 | world_total=11327.7542 | actor=-27.8906 | critic=14.6149 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2578.0 | checkpoint=-
# [train] step=240/500 | warm=0 | policy=32 | replay=17680 | world_total=11327.7230 | actor=-25.3750 | critic=15.0516 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2586.2 | checkpoint=-
# [train] step=241/500 | warm=0 | policy=32 | replay=17712 | world_total=11327.6445 | actor=-26.9688 | critic=11.8462 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2594.7 | checkpoint=-
# [train] step=242/500 | warm=0 | policy=32 | replay=17744 | world_total=11327.8014 | actor=-26.6562 | critic=11.4041 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2603.3 | checkpoint=-
# [train] step=243/500 | warm=0 | policy=32 | replay=17776 | world_total=11327.5659 | actor=-28.5938 | critic=11.9928 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=2612.4 | checkpoint=-
# [train] step=244/500 | warm=0 | policy=32 | replay=17808 | world_total=11327.5670 | actor=-31.0312 | critic=10.7442 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2620.8 | checkpoint=-
# [train] step=245/500 | warm=0 | policy=32 | replay=17840 | world_total=11327.3983 | actor=-33.0625 | critic=12.8337 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2628.7 | checkpoint=-
# [train] step=246/500 | warm=0 | policy=32 | replay=17872 | world_total=11327.4554 | actor=-36.0625 | critic=9.8721 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=2636.8 | checkpoint=-
# [train] step=247/500 | warm=0 | policy=32 | replay=17904 | world_total=11327.4220 | actor=-34.4375 | critic=17.0456 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=2643.9 | checkpoint=-
# [train] step=248/500 | warm=0 | policy=32 | replay=17936 | world_total=11327.3214 | actor=-30.2812 | critic=22.4149 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=2651.3 | checkpoint=-
# [train] step=249/500 | warm=0 | policy=32 | replay=17968 | world_total=11327.2135 | actor=-28.3438 | critic=10.8823 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=2658.9 | checkpoint=-
# [train] step=250/500 | warm=0 | policy=32 | replay=18000 | world_total=11327.2185 | actor=-25.5781 | critic=11.6101 | eval_reward=12.2044 | cycle_s=21.0 | elapsed_s=2679.8 | checkpoint=checkpoint_00250.pt
# [train] step=251/500 | warm=0 | policy=32 | replay=18032 | world_total=11327.1327 | actor=-25.7031 | critic=11.1467 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2688.0 | checkpoint=-
# [train] step=252/500 | warm=0 | policy=32 | replay=18064 | world_total=11327.0988 | actor=-26.1094 | critic=10.2918 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2696.4 | checkpoint=-
# [train] step=253/500 | warm=0 | policy=32 | replay=18096 | world_total=11327.0834 | actor=-27.7500 | critic=11.3687 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2704.8 | checkpoint=-
# [train] step=254/500 | warm=0 | policy=32 | replay=18128 | world_total=11326.9413 | actor=-29.2031 | critic=11.5415 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2713.2 | checkpoint=-
# [train] step=255/500 | warm=0 | policy=32 | replay=18160 | world_total=11326.9764 | actor=-27.9375 | critic=15.9548 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2721.4 | checkpoint=-
# [train] step=256/500 | warm=0 | policy=32 | replay=18192 | world_total=11326.8595 | actor=-28.5781 | critic=12.0915 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2730.3 | checkpoint=-
# [train] step=257/500 | warm=0 | policy=32 | replay=18224 | world_total=11326.9185 | actor=-28.4219 | critic=9.1100 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=2739.4 | checkpoint=-
# [train] step=258/500 | warm=0 | policy=32 | replay=18256 | world_total=11326.7629 | actor=-30.8438 | critic=8.7556 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=2746.8 | checkpoint=-
# [train] step=259/500 | warm=0 | policy=32 | replay=18288 | world_total=11326.8044 | actor=-33.2188 | critic=10.9320 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=2754.3 | checkpoint=-
# [train] step=260/500 | warm=0 | policy=32 | replay=18320 | world_total=11326.6995 | actor=-32.4062 | critic=16.0795 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2762.5 | checkpoint=-
# [train] step=261/500 | warm=0 | policy=32 | replay=18352 | world_total=11326.8217 | actor=-32.9062 | critic=11.4812 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2771.0 | checkpoint=-
# [train] step=262/500 | warm=0 | policy=32 | replay=18384 | world_total=11326.5848 | actor=-34.5000 | critic=12.0352 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2779.3 | checkpoint=-
# [train] step=263/500 | warm=0 | policy=32 | replay=18416 | world_total=11326.6055 | actor=-36.5625 | critic=9.6301 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2787.8 | checkpoint=-
# ...
# [train] step=420/500 | warm=0 | policy=32 | replay=23440 | world_total=11322.4824 | actor=-23.2812 | critic=13.8513 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4144.2 | checkpoint=-
# [train] step=421/500 | warm=0 | policy=32 | replay=23472 | world_total=11322.4606 | actor=-22.3125 | critic=15.8449 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=4153.1 | checkpoint=-
# [train] step=422/500 | warm=0 | policy=32 | replay=23504 | world_total=11322.3271 | actor=-21.3594 | critic=15.7522 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4160.4 | checkpoint=-
# [train] step=423/500 | warm=0 | policy=32 | replay=23536 | world_total=11322.4003 | actor=-21.0156 | critic=13.4972 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=4169.6 | checkpoint=-
# [train] step=424/500 | warm=0 | policy=32 | replay=23568 | world_total=11322.4897 | actor=-22.7344 | critic=13.2503 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=4177.0 | checkpoint=-
# [train] step=425/500 | warm=0 | policy=32 | replay=23600 | world_total=11322.3052 | actor=-21.1250 | critic=13.3598 | eval_reward=2.8758 | cycle_s=23.1 | elapsed_s=4200.1 | checkpoint=checkpoint_00425.pt
# [train] step=426/500 | warm=0 | policy=32 | replay=23632 | world_total=11322.2810 | actor=-23.6250 | critic=11.2228 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=4208.0 | checkpoint=-
# [train] step=427/500 | warm=0 | policy=32 | replay=23664 | world_total=11322.2899 | actor=-22.1094 | critic=15.5207 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4216.6 | checkpoint=-
# [train] step=428/500 | warm=0 | policy=32 | replay=23696 | world_total=11322.2227 | actor=-23.9375 | critic=12.6308 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4224.9 | checkpoint=-
# [train] step=429/500 | warm=0 | policy=32 | replay=23728 | world_total=11322.1941 | actor=-22.2031 | critic=17.2968 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4232.9 | checkpoint=-
# [train] step=430/500 | warm=0 | policy=32 | replay=23760 | world_total=11322.1584 | actor=-23.3438 | critic=13.1981 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4241.4 | checkpoint=-
# [train] step=431/500 | warm=0 | policy=32 | replay=23792 | world_total=11322.2230 | actor=-24.3906 | critic=11.1574 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4250.0 | checkpoint=-
# [train] step=432/500 | warm=0 | policy=32 | replay=23824 | world_total=11322.2708 | actor=-22.0781 | critic=17.1998 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4258.0 | checkpoint=-
# [train] step=433/500 | warm=0 | policy=32 | replay=23856 | world_total=11322.2172 | actor=-18.3438 | critic=22.3332 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=4265.5 | checkpoint=-
# [train] step=434/500 | warm=0 | policy=32 | replay=23888 | world_total=11322.2305 | actor=-19.6719 | critic=10.8083 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4273.2 | checkpoint=-
# [train] step=435/500 | warm=0 | policy=32 | replay=23920 | world_total=11322.2740 | actor=-18.3906 | critic=11.0065 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4280.7 | checkpoint=-
# [train] step=436/500 | warm=0 | policy=32 | replay=23952 | world_total=11322.2577 | actor=-17.8906 | critic=11.3930 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4288.0 | checkpoint=-
# [train] step=437/500 | warm=0 | policy=32 | replay=23984 | world_total=11322.1559 | actor=-17.8281 | critic=11.8889 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4296.1 | checkpoint=-
# [train] step=438/500 | warm=0 | policy=32 | replay=24016 | world_total=11322.1361 | actor=-16.8750 | critic=11.4009 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4304.5 | checkpoint=-
# [train] step=439/500 | warm=0 | policy=32 | replay=24048 | world_total=11322.0670 | actor=-16.3281 | critic=10.8351 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=4313.4 | checkpoint=-
# [train] step=440/500 | warm=0 | policy=32 | replay=24080 | world_total=11322.0350 | actor=-16.4688 | critic=10.1151 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4322.0 | checkpoint=-
# [train] step=441/500 | warm=0 | policy=32 | replay=24112 | world_total=11322.1604 | actor=-16.6094 | critic=11.6049 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=4330.3 | checkpoint=-
# [train] step=442/500 | warm=0 | policy=32 | replay=24144 | world_total=11322.1464 | actor=-19.5469 | critic=12.8077 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4337.5 | checkpoint=-
# [train] step=443/500 | warm=0 | policy=32 | replay=24176 | world_total=11322.1250 | actor=-21.1562 | critic=12.3234 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=4344.5 | checkpoint=-
# [train] step=444/500 | warm=0 | policy=32 | replay=24208 | world_total=11322.0477 | actor=-25.0312 | critic=12.9308 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=4352.2 | checkpoint=-
# [train] step=445/500 | warm=0 | policy=32 | replay=24240 | world_total=11322.0399 | actor=-25.7344 | critic=13.4674 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4360.8 | checkpoint=-
# [train] step=446/500 | warm=0 | policy=32 | replay=24272 | world_total=11322.0361 | actor=-23.5938 | critic=21.7589 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4368.1 | checkpoint=-
# [train] step=447/500 | warm=0 | policy=32 | replay=24304 | world_total=11322.0546 | actor=-22.9531 | critic=16.5108 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4375.4 | checkpoint=-
# [train] step=448/500 | warm=0 | policy=32 | replay=24336 | world_total=11321.9810 | actor=-22.9219 | critic=13.7537 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4383.8 | checkpoint=-
# [train] step=449/500 | warm=0 | policy=32 | replay=24368 | world_total=11322.0233 | actor=-18.0312 | critic=20.3526 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4391.8 | checkpoint=-
# [train] step=450/500 | warm=0 | policy=32 | replay=24400 | world_total=11321.9603 | actor=-19.6875 | critic=12.2529 | eval_reward=7.3048 | cycle_s=21.9 | elapsed_s=4413.7 | checkpoint=checkpoint_00450.pt
# [train] step=451/500 | warm=0 | policy=32 | replay=24432 | world_total=11322.1340 | actor=-20.2031 | critic=11.6566 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4421.8 | checkpoint=-
# [train] step=452/500 | warm=0 | policy=32 | replay=24464 | world_total=11322.0977 | actor=-20.8906 | critic=11.6328 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=4429.7 | checkpoint=-
# [train] step=453/500 | warm=0 | policy=32 | replay=24496 | world_total=11322.0220 | actor=-19.8281 | critic=17.0225 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4437.8 | checkpoint=-
# [train] step=454/500 | warm=0 | policy=32 | replay=24528 | world_total=11321.8546 | actor=-19.8750 | critic=16.3140 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=4444.7 | checkpoint=-
# [train] step=455/500 | warm=0 | policy=32 | replay=24560 | world_total=11321.7911 | actor=-17.8281 | critic=15.1319 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=4452.1 | checkpoint=-
# [train] step=456/500 | warm=0 | policy=32 | replay=24592 | world_total=11321.8137 | actor=-17.0625 | critic=12.7922 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4460.2 | checkpoint=-
# [train] step=457/500 | warm=0 | policy=32 | replay=24624 | world_total=11321.8873 | actor=-15.8984 | critic=11.3843 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=4468.1 | checkpoint=-
# [train] step=458/500 | warm=0 | policy=32 | replay=24656 | world_total=11321.8373 | actor=-13.2812 | critic=11.5415 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4475.3 | checkpoint=-
# [train] step=459/500 | warm=0 | policy=32 | replay=24688 | world_total=11321.7430 | actor=-13.3672 | critic=9.7663 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4483.6 | checkpoint=-
# [train] step=460/500 | warm=0 | policy=32 | replay=24720 | world_total=11321.7502 | actor=-13.6719 | critic=9.5091 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4492.0 | checkpoint=-
# [train] step=461/500 | warm=0 | policy=32 | replay=24752 | world_total=11321.8195 | actor=-14.1016 | critic=9.4446 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4500.5 | checkpoint=-
# [train] step=462/500 | warm=0 | policy=32 | replay=24784 | world_total=11321.7280 | actor=-15.0781 | critic=9.6669 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=4508.7 | checkpoint=-
# [train] step=463/500 | warm=0 | policy=32 | replay=24816 | world_total=11321.7634 | actor=-16.4219 | critic=10.3929 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=4517.7 | checkpoint=-
# [train] step=464/500 | warm=0 | policy=32 | replay=24848 | world_total=11321.7852 | actor=-19.2344 | critic=12.6826 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4526.1 | checkpoint=-
# [train] step=465/500 | warm=0 | policy=32 | replay=24880 | world_total=11321.6609 | actor=-21.5469 | critic=12.8059 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4534.5 | checkpoint=-
# [train] step=466/500 | warm=0 | policy=32 | replay=24912 | world_total=11321.7373 | actor=-19.9531 | critic=20.0155 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4542.8 | checkpoint=-
# [train] step=467/500 | warm=0 | policy=32 | replay=24944 | world_total=11321.6686 | actor=-16.9062 | critic=20.6553 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4550.2 | checkpoint=-
# [train] step=468/500 | warm=0 | policy=32 | replay=24976 | world_total=11321.6433 | actor=-16.6953 | critic=11.4753 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=4558.1 | checkpoint=-
# [train] step=469/500 | warm=0 | policy=32 | replay=25008 | world_total=11321.5750 | actor=-15.9062 | critic=10.8792 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4565.7 | checkpoint=-
# [train] step=470/500 | warm=0 | policy=32 | replay=25040 | world_total=11321.6257 | actor=-16.2656 | critic=11.3633 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=4573.1 | checkpoint=-
# [train] step=471/500 | warm=0 | policy=32 | replay=25072 | world_total=11321.6812 | actor=-16.9375 | critic=12.0771 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=4579.6 | checkpoint=-
# [train] step=472/500 | warm=0 | policy=32 | replay=25104 | world_total=11321.6194 | actor=-16.3750 | critic=13.0974 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=4586.1 | checkpoint=-
# [train] step=473/500 | warm=0 | policy=32 | replay=25136 | world_total=11321.6774 | actor=-15.5625 | critic=11.7899 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=4592.4 | checkpoint=-
# [train] step=474/500 | warm=0 | policy=32 | replay=25168 | world_total=11321.8475 | actor=-12.8203 | critic=10.7198 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=4598.7 | checkpoint=-
# [train] step=475/500 | warm=0 | policy=32 | replay=25200 | world_total=11321.6414 | actor=-13.7031 | critic=9.9614 | eval_reward=15.1840 | cycle_s=20.3 | elapsed_s=4619.0 | checkpoint=checkpoint_00475.pt
# [train] step=476/500 | warm=0 | policy=32 | replay=25232 | world_total=11321.5651 | actor=-14.9609 | critic=10.1622 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=4624.9 | checkpoint=-
# [train] step=477/500 | warm=0 | policy=32 | replay=25264 | world_total=11321.5592 | actor=-16.6719 | critic=12.5744 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=4631.2 | checkpoint=-
# [train] step=478/500 | warm=0 | policy=32 | replay=25296 | world_total=11321.5503 | actor=-14.3047 | critic=15.7032 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=4637.3 | checkpoint=-
# [train] step=479/500 | warm=0 | policy=32 | replay=25328 | world_total=11321.4727 | actor=-14.0625 | critic=10.4148 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=4643.1 | checkpoint=-
# [train] step=480/500 | warm=0 | policy=32 | replay=25360 | world_total=11321.6206 | actor=-13.8984 | critic=9.2586 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=4648.6 | checkpoint=-
# [train] step=481/500 | warm=0 | policy=32 | replay=25392 | world_total=11321.6045 | actor=-13.1875 | critic=8.8945 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=4655.0 | checkpoint=-
# [train] step=482/500 | warm=0 | policy=32 | replay=25424 | world_total=11321.5793 | actor=-13.1953 | critic=9.6770 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=4660.2 | checkpoint=-
# [train] step=483/500 | warm=0 | policy=32 | replay=25456 | world_total=11321.4404 | actor=-13.0078 | critic=9.1690 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=4665.6 | checkpoint=-
# [train] step=484/500 | warm=0 | policy=32 | replay=25488 | world_total=11321.4246 | actor=-11.9062 | critic=8.4381 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=4671.2 | checkpoint=-
# [train] step=485/500 | warm=0 | policy=32 | replay=25520 | world_total=11321.5017 | actor=-11.8984 | critic=8.0698 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=4675.9 | checkpoint=-
# [train] step=486/500 | warm=0 | policy=32 | replay=25552 | world_total=11321.4865 | actor=-13.5000 | critic=9.2232 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=4681.7 | checkpoint=-
# [train] step=487/500 | warm=0 | policy=32 | replay=25584 | world_total=11321.4150 | actor=-14.2656 | critic=9.8829 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=4686.9 | checkpoint=-
# [train] step=488/500 | warm=0 | policy=32 | replay=25616 | world_total=11321.4480 | actor=-15.9688 | critic=10.6613 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4691.9 | checkpoint=-
# [train] step=489/500 | warm=0 | policy=32 | replay=25648 | world_total=11321.4685 | actor=-14.7266 | critic=11.7826 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=4696.7 | checkpoint=-
# [train] step=490/500 | warm=0 | policy=32 | replay=25680 | world_total=11321.4028 | actor=-14.9609 | critic=9.7508 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=4701.3 | checkpoint=-
# [train] step=491/500 | warm=0 | policy=32 | replay=25712 | world_total=11321.4286 | actor=-16.2578 | critic=10.2708 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=4706.1 | checkpoint=-
# [train] step=492/500 | warm=0 | policy=32 | replay=25744 | world_total=11321.4980 | actor=-16.3906 | critic=11.4776 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4711.1 | checkpoint=-
# [train] step=493/500 | warm=0 | policy=32 | replay=25776 | world_total=11321.4730 | actor=-15.7422 | critic=11.8795 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4716.1 | checkpoint=-
# [train] step=494/500 | warm=0 | policy=32 | replay=25808 | world_total=11321.3986 | actor=-13.8203 | critic=9.6700 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=4720.9 | checkpoint=-
# [train] step=495/500 | warm=0 | policy=32 | replay=25840 | world_total=11321.4243 | actor=-13.4453 | critic=8.3384 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=4726.1 | checkpoint=-
# [train] step=496/500 | warm=0 | policy=32 | replay=25872 | world_total=11321.4773 | actor=-18.2812 | critic=13.7585 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=4731.4 | checkpoint=-
# [train] step=497/500 | warm=0 | policy=32 | replay=25904 | world_total=11321.3344 | actor=-20.8438 | critic=14.5061 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4736.4 | checkpoint=-
# [train] step=498/500 | warm=0 | policy=32 | replay=25936 | world_total=11321.3279 | actor=-19.2812 | critic=20.9450 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4741.4 | checkpoint=-
# [train] step=499/500 | warm=0 | policy=32 | replay=25968 | world_total=11321.3628 | actor=-20.0938 | critic=11.6296 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4746.4 | checkpoint=-
# [train] step=500/500 | warm=0 | policy=32 | replay=26000 | world_total=11321.3621 | actor=-17.4688 | critic=13.8523 | eval_reward=17.7788 | cycle_s=17.6 | elapsed_s=4764.0 | checkpoint=checkpoint_00500.pt
# Completed cycles: 500
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter24_mid_steering/checkpoints/checkpoint_00500.pt
# Latest metrics: {'step': 500, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 26000, 'world_model/reconstruction_loss': 11312.808227539062, 'world_model/reconstruction_mse': 0.00340014326502569, 'world_model/observation_log_prob': -11312.808227539062, 'world_model/reward_loss': 1.2742505371570587, 'world_model/continue_loss': 0.018628447083756328, 'world_model/kl_loss': 4.636746883392334, 'world_model/kl_loss_raw': 4.636746883392334, 'world_model/overshooting_kl_loss': 5.2483269572258, 'world_model/overshooting_feature_mse': 0.11794681381434202, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11321.362060546875, 'behavior/actor_loss': -17.46875, 'behavior/critic_loss': 13.852250337600708, 'behavior/imagined_reward_mean': 1.125, 'behavior/imagined_value_mean': 18.15625, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 17.778833750548976, 'evaluation/mean_steps': 22.4, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter24_mid_steering/checkpoints/checkpoint_00500.pt',
#  'latest_metrics': {'behavior/actor_loss': -17.46875,
#   'behavior/critic_loss': 13.852250337600708,
#   'behavior/imagined_reward_mean': 1.125,
#   'behavior/imagined_value_mean': 18.15625,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 17.778833750548976,
#   'evaluation/mean_steps': 22.4,
#   'policy_added': 32,
#   'replay_size': 26000,
#   'step': 500,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.018628447083756328,
#   'world_model/kl_loss': 4.636746883392334,
#   'world_model/kl_loss_raw': 4.636746883392334,
#   'world_model/observation_log_prob': -11312.808227539062,
#   'world_model/overshooting_feature_mse': 0.11794681381434202,
#   'world_model/overshooting_kl_loss': 5.2483269572258,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11312.808227539062,
#   'world_model/reconstruction_mse': 0.00340014326502569,
#   'world_model/reward_loss': 1.2742505371570587,
#   'world_model/total_loss': 11321.362060546875},
#  'latest_step': 500}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 17.778833750548976,
#   'best_eval_reward_step': 500,
#   'best_imagined_reward_mean': 1.25,
#   'best_imagined_reward_step': 376,
#   'best_world_model_step': 498,
#   'best_world_model_total_loss': 11321.327880859375,
#   'largest_replay_size': 26000,
#   'largest_replay_step': 500,
#   'last_metrics': {'behavior/actor_loss': -17.46875,
#    'behavior/critic_loss': 13.852250337600708,
#    'behavior/imagined_reward_mean': 1.125,
#    'behavior/imagined_value_mean': 18.15625,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 17.778833750548976,
#    'evaluation/mean_steps': 22.4,
#    'policy_added': 32,
#    'replay_size': 26000,
#    'step': 500,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.018628447083756328,
#    'world_model/kl_loss': 4.636746883392334,
#    'world_model/kl_loss_raw': 4.636746883392334,
#    'world_model/observation_log_prob': -11312.808227539062,
#    'world_model/overshooting_feature_mse': 0.11794681381434202,
#    'world_model/overshooting_kl_loss': 5.2483269572258,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11312.808227539062,
#    'world_model/reconstruction_mse': 0.00340014326502569,
#    'world_model/reward_loss': 1.2742505371570587,
#    'world_model/total_loss': 11321.362060546875},
#   'last_step': 500,
#   'num_records': 500},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11312.808227539062',
#   'world_model/reconstruction_mse': '0.00340014326502569',
#   'world_model/observation_log_prob': '-11312.808227539062',
#   'world_model/overshooting_kl_loss': '5.2483269572258',
#   'world_model/overshooting_feature_mse': '0.11794681381434202',
#   'evaluation/mean_reward': '17.778833750548976',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=132,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=7 | reward=-0.82 | CRASH | saved iter24_mid_steering_ep01.gif
# [demo] episode 2/10 | steps=15 | reward=6.14 | CRASH | saved iter24_mid_steering_ep02.gif
# [demo] episode 3/10 | steps=8 | reward=-0.54 | CRASH | saved iter24_mid_steering_ep03.gif
# [demo] episode 4/10 | steps=32 | reward=30.22 | CRASH | saved iter24_mid_steering_ep04.gif
# [demo] episode 5/10 | steps=7 | reward=-1.04 | CRASH | saved iter24_mid_steering_ep05.gif
# [demo] episode 6/10 | steps=11 | reward=3.98 | CRASH | saved iter24_mid_steering_ep06.gif
# [demo] episode 7/10 | steps=42 | reward=45.45 | CRASH | saved iter24_mid_steering_ep07.gif
# [demo] episode 8/10 | steps=6 | reward=-0.72 | CRASH | saved iter24_mid_steering_ep08.gif
# [demo] episode 9/10 | steps=13 | reward=4.59 | CRASH | saved iter24_mid_steering_ep09.gif
# [demo] episode 10/10 | steps=23 | reward=17.99 | CRASH | saved iter24_mid_steering_ep10.gif
# [demo] done | avg_reward=10.53 | summary=iter24_mid_steering_summary.json
#
# iter24_mid_steering_ep01.gif
# iter24_mid_steering_ep02.gif
# iter24_mid_steering_ep03.gif
# iter24_mid_steering_ep04.gif
# iter24_mid_steering_ep05.gif
# iter24_mid_steering_ep06.gif
# iter24_mid_steering_ep07.gif
# iter24_mid_steering_ep08.gif
# iter24_mid_steering_ep09.gif
# iter24_mid_steering_ep10.gif
