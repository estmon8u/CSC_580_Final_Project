# %% [markdown]
# # Tiny Dreamer Highway — Colab Sanity Run
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# Use this notebook for a short Colab validation run before any longer training job.

# %% [markdown]
# ## Runtime flow
#
# 1. Mount Google Drive.
# 2. Clone or pull the latest repository snapshot.
# 3. Install the package.
# 4. Run a short sanity job.
# 5. Confirm checkpoints, logs, overshooting metrics, and analysis artifacts are written.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'
WORKTREE = Path('/content/CSC_580_Final_Project')

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)

print('Drive root:', DRIVE_ROOT)
print('Artifact root:', ARTIFACT_ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive root: /content/drive/MyDrive/CSC_580_Final_Project
# Artifact root: /content/drive/MyDrive/CSC_580_Final_Project/artifacts

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Updating cba9e0a..aa8c273
# Fast-forward
#  examples/base_experiment.yaml                  |    1 +
#  examples/discrete_experiment.yaml              |    1 +
#  examples/discrete_training_run.yaml            |    1 +
#  notebooks/01_colab_setup_and_smoke_tests.ipynb |  427 +----
#  notebooks/02_colab_sanity_run.ipynb            |  201 +-
#  notebooks/04_colab_h100_run.ipynb              |  680 +------
#  notebooks/05_colab_optimized_run.ipynb         |   81 +-
#  notebooks/06_colab_h100_amp_run.ipynb          | 2346 +-----------------------
#  notebooks/07_discrete_baseline.ipynb           |  105 +-
#  9 files changed, 131 insertions(+), 3712 deletions(-)
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main       -> FETCH_HEAD
#    cba9e0a..aa8c273  main       -> origin/main

# %%
# %%bash
# set -e
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet

# %%
import json
import sys
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)
config = config.model_copy(deep=True)

# Sanity-run overrides: keep the newer Dreamer features enabled, but shrink the
# data requirements so short Colab validation runs do not fail on episode-boundary
# sequence sampling early in training.
config.replay.sequence_length = 8
config.replay.batch_size = 4
config.training.batch_size = 4
config.training.imagination_horizon = 5
config.training.world_model_updates_per_cycle = 1
config.training.behavior_updates_per_cycle = 1
config.env.reward.offroad_terminal = False
config.evaluation.interval = 5
config.evaluation.episodes = 2

print('Loaded base config from:', CONFIG_PATH)
print('Sanity sequence length:', config.replay.sequence_length)
print('Sanity batch size:', config.training.batch_size)
print('Sanity imagination horizon:', config.training.imagination_horizon)
print('Sanity offroad terminal:', config.env.reward.offroad_terminal)
# Out:
# Loaded base config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# Sanity sequence length: 8
# Sanity batch size: 4
# Sanity imagination horizon: 5
# Sanity offroad terminal: False

# %%
# Verify stability / optimisation knobs before launching
print("grad_clip_norm:", config.training.grad_clip_norm)
print("lr_warmup_steps:", config.training.lr_warmup_steps)
print("use_amp:", getattr(config.training, "use_amp", False))
print("amp_dtype:", getattr(config.training, "amp_dtype", None))
print("sequence_length:", config.replay.sequence_length)
print("batch_size:", config.training.batch_size)
# Out:
# grad_clip_norm: 100.0
# lr_warmup_steps: 50
# use_amp: False
# amp_dtype: bfloat16
# use_flash_optimizer: False
# sequence_length: 8
# batch_size: 4

# %%
RUN_NAME = 'sanity_check_001'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 50
WARM_START_STEPS = 256
POLICY_STEPS = 16
CHECKPOINT_INTERVAL = 1
RESUME_FROM = None

print('Run name:', RUN_NAME)
print('Cycles:', CYCLES)
print('Warm-start steps:', WARM_START_STEPS)
print('Policy steps:', POLICY_STEPS)
print('Sequence length:', config.replay.sequence_length)
print('Training batch size:', config.training.batch_size)
# Out:
# Run name: sanity_check_001
# Cycles: 50
# Warm-start steps: 256
# Policy steps: 16
# Sequence length: 8
# Training batch size: 4

# %%
print('Launching sanity run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching sanity run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=50 | start_step=1 | warm_start_steps=256 | policy_steps=16 | device=cuda
# [train] step=1/50 | warm=256 | policy=16 | replay=272 | world_total=5804.8740 | actor=-0.7465 | critic=2.0833 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=6.7 | checkpoint=checkpoint_00001.pt
# [train] step=2/50 | warm=0 | policy=16 | replay=288 | world_total=5574.2788 | actor=-1.0486 | critic=2.1827 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=7.7 | checkpoint=checkpoint_00002.pt
# [train] step=3/50 | warm=0 | policy=16 | replay=304 | world_total=5120.7188 | actor=-0.8562 | critic=2.3631 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=8.7 | checkpoint=checkpoint_00003.pt
# [train] step=4/50 | warm=0 | policy=16 | replay=320 | world_total=4977.2227 | actor=-1.2836 | critic=2.5884 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=9.7 | checkpoint=checkpoint_00004.pt
# [train] step=5/50 | warm=0 | policy=16 | replay=336 | world_total=4807.0107 | actor=-0.6761 | critic=1.8114 | eval_reward=-403.0109 | cycle_s=10.9 | elapsed_s=20.6 | checkpoint=checkpoint_00005.pt
# [train] step=6/50 | warm=0 | policy=16 | replay=352 | world_total=4604.4141 | actor=-0.8072 | critic=1.3431 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=21.6 | checkpoint=checkpoint_00006.pt
# [train] step=7/50 | warm=0 | policy=16 | replay=368 | world_total=4468.7798 | actor=-0.4907 | critic=1.2259 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=22.7 | checkpoint=checkpoint_00007.pt
# [train] step=8/50 | warm=0 | policy=16 | replay=384 | world_total=4513.9272 | actor=-0.6613 | critic=2.0855 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=23.7 | checkpoint=checkpoint_00008.pt
# [train] step=9/50 | warm=0 | policy=16 | replay=400 | world_total=4505.1079 | actor=-0.7932 | critic=2.0912 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=24.7 | checkpoint=checkpoint_00009.pt
# [train] step=10/50 | warm=0 | policy=16 | replay=416 | world_total=4359.2104 | actor=-1.1159 | critic=1.4555 | eval_reward=-537.9579 | cycle_s=11.6 | elapsed_s=36.2 | checkpoint=checkpoint_00010.pt
# [train] step=11/50 | warm=0 | policy=16 | replay=432 | world_total=4382.6489 | actor=-1.1108 | critic=1.5137 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=37.2 | checkpoint=checkpoint_00011.pt
# [train] step=12/50 | warm=0 | policy=16 | replay=448 | world_total=4297.0225 | actor=-1.5821 | critic=2.5220 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=38.2 | checkpoint=checkpoint_00012.pt
# [train] step=13/50 | warm=0 | policy=16 | replay=464 | world_total=4196.5864 | actor=-0.9363 | critic=1.7499 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=39.2 | checkpoint=checkpoint_00013.pt
# [train] step=14/50 | warm=0 | policy=16 | replay=480 | world_total=4165.2129 | actor=-0.4456 | critic=1.4011 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=40.3 | checkpoint=checkpoint_00014.pt
# [train] step=15/50 | warm=0 | policy=16 | replay=496 | world_total=4161.2173 | actor=0.5357 | critic=1.7747 | eval_reward=-125.6176 | cycle_s=3.9 | elapsed_s=44.2 | checkpoint=checkpoint_00015.pt
# [train] step=16/50 | warm=0 | policy=16 | replay=512 | world_total=4156.6499 | actor=-0.8635 | critic=2.2385 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=45.2 | checkpoint=checkpoint_00016.pt
# [train] step=17/50 | warm=0 | policy=16 | replay=528 | world_total=4149.5767 | actor=0.6506 | critic=2.1658 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=46.2 | checkpoint=checkpoint_00017.pt
# [train] step=18/50 | warm=0 | policy=16 | replay=544 | world_total=4100.5537 | actor=0.2108 | critic=2.0365 | eval_reward=n/a | cycle_s=2.0 | elapsed_s=48.3 | checkpoint=checkpoint_00018.pt
# [train] step=19/50 | warm=0 | policy=16 | replay=560 | world_total=4074.7791 | actor=0.2690 | critic=1.2780 | eval_reward=n/a | cycle_s=1.1 | elapsed_s=49.4 | checkpoint=checkpoint_00019.pt
# [train] step=20/50 | warm=0 | policy=16 | replay=576 | world_total=4071.3977 | actor=-0.1450 | critic=1.5632 | eval_reward=-527.9543 | cycle_s=11.9 | elapsed_s=61.2 | checkpoint=checkpoint_00020.pt
# [train] step=21/50 | warm=0 | policy=16 | replay=592 | world_total=4071.6357 | actor=0.3334 | critic=1.7011 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=62.3 | checkpoint=checkpoint_00021.pt
# [train] step=22/50 | warm=0 | policy=16 | replay=608 | world_total=4071.8477 | actor=0.3046 | critic=2.4696 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=63.3 | checkpoint=checkpoint_00022.pt
# [train] step=23/50 | warm=0 | policy=16 | replay=624 | world_total=4017.0703 | actor=0.6872 | critic=1.5308 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=64.3 | checkpoint=checkpoint_00023.pt
# [train] step=24/50 | warm=0 | policy=16 | replay=640 | world_total=4009.6125 | actor=-0.8852 | critic=1.9260 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=65.3 | checkpoint=checkpoint_00024.pt
# [train] step=25/50 | warm=0 | policy=16 | replay=656 | world_total=4033.2041 | actor=0.3379 | critic=1.8216 | eval_reward=-566.2332 | cycle_s=11.7 | elapsed_s=77.1 | checkpoint=checkpoint_00025.pt
# [train] step=26/50 | warm=0 | policy=16 | replay=672 | world_total=3974.8850 | actor=1.2443 | critic=3.2062 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=78.1 | checkpoint=checkpoint_00026.pt
# [train] step=27/50 | warm=0 | policy=16 | replay=688 | world_total=3995.8784 | actor=1.3155 | critic=2.8900 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=79.1 | checkpoint=checkpoint_00027.pt
# [train] step=28/50 | warm=0 | policy=16 | replay=704 | world_total=3982.2456 | actor=0.2791 | critic=1.6939 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=80.1 | checkpoint=checkpoint_00028.pt
# [train] step=29/50 | warm=0 | policy=16 | replay=720 | world_total=3958.7004 | actor=0.9262 | critic=2.3546 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=81.1 | checkpoint=checkpoint_00029.pt
# [train] step=30/50 | warm=0 | policy=16 | replay=736 | world_total=3960.0481 | actor=0.2948 | critic=1.8824 | eval_reward=-547.0517 | cycle_s=11.7 | elapsed_s=92.8 | checkpoint=checkpoint_00030.pt
# [train] step=31/50 | warm=0 | policy=16 | replay=752 | world_total=3959.1843 | actor=0.2807 | critic=1.4707 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=93.8 | checkpoint=checkpoint_00031.pt
# [train] step=32/50 | warm=0 | policy=16 | replay=768 | world_total=3954.9817 | actor=0.1895 | critic=1.7908 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=94.8 | checkpoint=checkpoint_00032.pt
# [train] step=33/50 | warm=0 | policy=16 | replay=784 | world_total=3960.0715 | actor=0.8042 | critic=1.8436 | eval_reward=n/a | cycle_s=1.3 | elapsed_s=96.2 | checkpoint=checkpoint_00033.pt
# [train] step=34/50 | warm=0 | policy=16 | replay=800 | world_total=3919.3057 | actor=2.8298 | critic=5.9963 | eval_reward=n/a | cycle_s=1.1 | elapsed_s=97.2 | checkpoint=checkpoint_00034.pt
# [train] step=35/50 | warm=0 | policy=16 | replay=816 | world_total=3934.5701 | actor=1.3798 | critic=2.5202 | eval_reward=-579.8939 | cycle_s=10.9 | elapsed_s=108.1 | checkpoint=checkpoint_00035.pt
# [train] step=36/50 | warm=0 | policy=16 | replay=832 | world_total=3911.0300 | actor=0.7386 | critic=1.9237 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=109.2 | checkpoint=checkpoint_00036.pt
# [train] step=37/50 | warm=0 | policy=16 | replay=848 | world_total=3906.1790 | actor=0.5250 | critic=1.7280 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=110.2 | checkpoint=checkpoint_00037.pt
# [train] step=38/50 | warm=0 | policy=16 | replay=864 | world_total=3930.6182 | actor=2.5068 | critic=5.0657 | eval_reward=n/a | cycle_s=1.1 | elapsed_s=111.3 | checkpoint=checkpoint_00038.pt
# [train] step=39/50 | warm=0 | policy=16 | replay=880 | world_total=3897.3445 | actor=1.9846 | critic=4.6365 | eval_reward=n/a | cycle_s=1.6 | elapsed_s=112.9 | checkpoint=checkpoint_00039.pt
# [train] step=40/50 | warm=0 | policy=16 | replay=896 | world_total=3896.2195 | actor=1.5560 | critic=3.6169 | eval_reward=-282.4033 | cycle_s=7.9 | elapsed_s=120.8 | checkpoint=checkpoint_00040.pt
# [train] step=41/50 | warm=0 | policy=16 | replay=912 | world_total=3892.4722 | actor=2.5142 | critic=5.4956 | eval_reward=n/a | cycle_s=1.2 | elapsed_s=122.0 | checkpoint=checkpoint_00041.pt
# [train] step=42/50 | warm=0 | policy=16 | replay=928 | world_total=3894.1829 | actor=3.3644 | critic=7.6255 | eval_reward=n/a | cycle_s=1.1 | elapsed_s=123.1 | checkpoint=checkpoint_00042.pt
# [train] step=43/50 | warm=0 | policy=16 | replay=944 | world_total=3889.6746 | actor=3.8770 | critic=7.4505 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=124.2 | checkpoint=checkpoint_00043.pt
# [train] step=44/50 | warm=0 | policy=16 | replay=960 | world_total=3875.9175 | actor=3.9668 | critic=10.1090 | eval_reward=n/a | cycle_s=1.1 | elapsed_s=125.2 | checkpoint=checkpoint_00044.pt
# [train] step=45/50 | warm=0 | policy=16 | replay=976 | world_total=3872.2625 | actor=4.6843 | critic=12.6232 | eval_reward=-526.0801 | cycle_s=11.8 | elapsed_s=137.0 | checkpoint=checkpoint_00045.pt
# [train] step=46/50 | warm=0 | policy=16 | replay=992 | world_total=3851.9622 | actor=3.9627 | critic=10.3996 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=138.1 | checkpoint=checkpoint_00046.pt
# [train] step=47/50 | warm=0 | policy=16 | replay=1008 | world_total=3858.1533 | actor=5.0900 | critic=11.9613 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=139.1 | checkpoint=checkpoint_00047.pt
# [train] step=48/50 | warm=0 | policy=16 | replay=1024 | world_total=3873.4707 | actor=5.3679 | critic=11.8978 | eval_reward=n/a | cycle_s=1.0 | elapsed_s=140.2 | checkpoint=checkpoint_00048.pt
# [train] step=49/50 | warm=0 | policy=16 | replay=1040 | world_total=3862.3843 | actor=5.9852 | critic=15.7994 | eval_reward=n/a | cycle_s=1.3 | elapsed_s=141.4 | checkpoint=checkpoint_00049.pt
# [train] step=50/50 | warm=0 | policy=16 | replay=1056 | world_total=3851.5623 | actor=3.5706 | critic=7.1513 | eval_reward=-560.9277 | cycle_s=11.2 | elapsed_s=152.6 | checkpoint=checkpoint_00050.pt
# Completed cycles: 50
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/sanity_check_001/checkpoints/checkpoint_00050.pt
# Latest metrics: {'step': 50, 'warm_start_added': 0, 'policy_added': 16, 'replay_size': 1056, 'world_model/reconstruction_loss': 3828.279296875, 'world_model/reconstruction_mse': 0.03140004724264145, 'world_model/observation_log_prob': -3828.279296875, 'world_model/reward_loss': 2.5137619972229004, 'world_model/continue_loss': 0.021037595346570015, 'world_model/kl_loss': 13.703826904296875, 'world_model/kl_loss_raw': 13.703826904296875, 'world_model/overshooting_kl_loss': 14.088879585266113, 'world_model/overshooting_feature_mse': 0.08175098150968552, 'world_model/overshooting_pairs': 18.0, 'world_model/total_loss': 3851.562255859375, 'behavior/actor_loss': 3.5705649852752686, 'behavior/critic_loss': 7.151295185089111, 'behavior/imagined_reward_mean': -1.158582091331482, 'behavior/imagined_value_mean': -1.0580610036849976, 'evaluation/episodes': 2.0, 'evaluation/mean_reward': -560.9276981330418, 'evaluation/mean_steps': 200.0, 'evaluation/crash_rate': 0.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
metrics_csv_path = training_summary.log_dir / 'cycle_metrics.csv'
metrics_jsonl_path = training_summary.log_dir / 'cycle_metrics.jsonl'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))

print('Summary exists:', summary_path.exists())
print('CSV exists:', metrics_csv_path.exists())
print('JSONL exists:', metrics_jsonl_path.exists())
print('Checkpoint exists:', training_summary.latest_checkpoint is not None and training_summary.latest_checkpoint.exists())
summary_payload
# Out:
# Summary exists: True
# CSV exists: True
# JSONL exists: True
# Checkpoint exists: True
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/sanity_check_001/checkpoints/checkpoint_00050.pt',
#  'latest_metrics': {'behavior/actor_loss': 3.5705649852752686,
#   'behavior/critic_loss': 7.151295185089111,
#   'behavior/imagined_reward_mean': -1.158582091331482,
#   'behavior/imagined_value_mean': -1.0580610036849976,
#   'evaluation/crash_rate': 0.0,
#   'evaluation/episodes': 2.0,
#   'evaluation/mean_reward': -560.9276981330418,
#   'evaluation/mean_steps': 200.0,
#   'policy_added': 16,
#   'replay_size': 1056,
#   'step': 50,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.021037595346570015,
#   'world_model/kl_loss': 13.703826904296875,
#   'world_model/kl_loss_raw': 13.703826904296875,
#   'world_model/observation_log_prob': -3828.279296875,
#   'world_model/overshooting_feature_mse': 0.08175098150968552,
#   'world_model/overshooting_kl_loss': 14.088879585266113,
#   'world_model/overshooting_pairs': 18.0,
#   'world_model/reconstruction_loss': 3828.279296875,
#   'world_model/reconstruction_mse': 0.03140004724264145,
#   'world_model/reward_loss': 2.5137619972229004,
#   'world_model/total_loss': 3851.562255859375},
#  'latest_step': 50}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with metrics_csv_path.open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_outputs': {
        'curves': str(analysis_outputs['curves']),
        'summary': str(analysis_outputs['summary']),
    },
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'world_model/overshooting_pairs': latest_metrics_row.get('world_model/overshooting_pairs'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_outputs': {'curves': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/sanity_check_001/analysis/sanity_check_001_curves.png',
#   'summary': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/sanity_check_001/analysis/sanity_check_001_summary.json'},
#  'analysis_summary': {'best_eval_mean_reward': -125.6176467175546,
#   'best_eval_reward_step': 15,
#   'best_imagined_reward_mean': 0.8954681754112244,
#   'best_imagined_reward_step': 12,
#   'best_world_model_step': 50,
#   'best_world_model_total_loss': 3851.562255859375,
#   'largest_replay_size': 1056,
#   'largest_replay_step': 50,
#   'last_metrics': {'behavior/actor_loss': 3.5705649852752686,
#    'behavior/critic_loss': 7.151295185089111,
#    'behavior/imagined_reward_mean': -1.158582091331482,
#    'behavior/imagined_value_mean': -1.0580610036849976,
#    'evaluation/crash_rate': 0.0,
#    'evaluation/episodes': 2.0,
#    'evaluation/mean_reward': -560.9276981330418,
#    'evaluation/mean_steps': 200.0,
#    'policy_added': 16,
#    'replay_size': 1056,
#    'step': 50,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.021037595346570015,
#    'world_model/kl_loss': 13.703826904296875,
#    'world_model/kl_loss_raw': 13.703826904296875,
#    'world_model/observation_log_prob': -3828.279296875,
#    'world_model/overshooting_feature_mse': 0.08175098150968552,
#    'world_model/overshooting_kl_loss': 14.088879585266113,
#    'world_model/overshooting_pairs': 18.0,
#    'world_model/reconstruction_loss': 3828.279296875,
#    'world_model/reconstruction_mse': 0.03140004724264145,
#    'world_model/reward_loss': 2.5137619972229004,
#    'world_model/total_loss': 3851.562255859375},
#   'last_step': 50,
#   'num_records': 50},
#  'phase4_metrics': {'world_model/overshooting_kl_loss': '14.088879585266113',
#   'world_model/overshooting_feature_mse': '0.08175098150968552',
#   'world_model/overshooting_pairs': '18.0',
#   'evaluation/mean_reward': '-560.9276981330418',
#   'evaluation/crash_rate': '0.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record a short GIF showing the trained policy driving in the real highway-env. The checkpoint from the run above is used to load the actor and world model, then the agent is rolled out for a few episodes.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=40,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=40 | reward=-92.84 | OK | saved sanity_check_001_ep01.gif
# [demo] episode 2/10 | steps=40 | reward=-108.68 | OK | saved sanity_check_001_ep02.gif
# [demo] episode 3/10 | steps=40 | reward=-77.11 | OK | saved sanity_check_001_ep03.gif
# [demo] episode 4/10 | steps=40 | reward=-104.72 | OK | saved sanity_check_001_ep04.gif
# [demo] episode 5/10 | steps=40 | reward=-85.51 | OK | saved sanity_check_001_ep05.gif
# [demo] episode 6/10 | steps=40 | reward=-97.04 | OK | saved sanity_check_001_ep06.gif
# [demo] episode 7/10 | steps=40 | reward=-88.73 | OK | saved sanity_check_001_ep07.gif
# [demo] episode 8/10 | steps=40 | reward=-69.57 | OK | saved sanity_check_001_ep08.gif
# [demo] episode 9/10 | steps=40 | reward=-80.79 | OK | saved sanity_check_001_ep09.gif
# [demo] episode 10/10 | steps=40 | reward=-93.10 | OK | saved sanity_check_001_ep10.gif
# [demo] done | avg_reward=-89.81 | summary=sanity_check_001_summary.json
#
# sanity_check_001_ep01.gif
# sanity_check_001_ep02.gif
# sanity_check_001_ep03.gif
# sanity_check_001_ep04.gif
# sanity_check_001_ep05.gif
# sanity_check_001_ep06.gif
# sanity_check_001_ep07.gif
# sanity_check_001_ep08.gif
# sanity_check_001_ep09.gif
# sanity_check_001_ep10.gif
