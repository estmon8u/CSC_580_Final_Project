# %% [markdown]
# # Tiny Dreamer Highway — Iter 22: Lower Steering Penalty
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10 + iter17 (max_episode_steps=120, batch_size=384)
# **New change:** `steering_penalty: 0.025 → 0.015`
# **Hypothesis:** Iter 17 @ 2000 became passive because steering_penalty=0.025 makes lane changes too costly relative to the overtake reward. The original 0.0075 was too low (jitter), 0.025 is too high (won't steer after extended training). 0.015 is a middle ground — still penalizes gratuitous jitter but low enough that the overtake reward can justify a lane change.

# %% [markdown]
# ## Iteration 22 — Cheaper lane changes (Phase 4, iter 17 base)
#
# Iter 17 at 2000 cycles learned to stay in one lane and never change — it crashes into the car ahead rather than steering around it. The steering_penalty=0.025 made lane changes too expensive. Reducing to 0.015 should make them affordable again while still discouraging pointless jitter.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/GrandpaDrivers'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD
# Already on 'GrandpaDrivers'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            GrandpaDrivers -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

# --- Iter 17 Overrides ---
config.env.max_episode_steps = 120
config.training.batch_size = 384

# --- Iter 22 Override: lower steering penalty ---
config.env.reward.steering_penalty = 0.015

print('\nAll overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')
print(f'  steering_penalty = {config.env.reward.steering_penalty}  (iter 22: 0.025 -> 0.015)')
print(f'  max_episode_steps = {config.env.max_episode_steps}')
print(f'  batch_size = {config.training.batch_size}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "actor_entropy_weight": 0.0,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# All overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#   steering_penalty = 0.015  (iter 22: 0.025 -> 0.015)
#   max_episode_steps = 120
#   batch_size = 384

# %%
RUN_NAME = 'iter22_low_steering_penalty'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 1000
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/' + RUN_NAME + '/checkpoints/checkpoint_00500.pt'

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter22_low_steering_penalty
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter22_low_steering_penalty/checkpoints/checkpoint_00500.pt
# Effective cycles: 1000
# Effective policy steps: 32

# %%
print('Launching iter22 run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching iter22 run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=1000 | start_step=501 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=501/1000 | warm=0 | policy=32 | replay=15592 | world_total=11302.3274 | actor=-3.1582 | critic=1.5339 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=5.3 | checkpoint=-
# [train] step=502/1000 | warm=0 | policy=32 | replay=15624 | world_total=11302.3435 | actor=-3.2285 | critic=1.6061 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=11.8 | checkpoint=-
# [train] step=503/1000 | warm=0 | policy=32 | replay=15656 | world_total=11302.2592 | actor=-2.9883 | critic=1.5798 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=18.7 | checkpoint=-
# [train] step=504/1000 | warm=0 | policy=32 | replay=15688 | world_total=11302.2649 | actor=-2.8652 | critic=1.6096 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=25.9 | checkpoint=-
# [train] step=505/1000 | warm=0 | policy=32 | replay=15720 | world_total=11302.3281 | actor=-2.6270 | critic=1.6427 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=32.9 | checkpoint=-
# [train] step=506/1000 | warm=0 | policy=32 | replay=15752 | world_total=11302.1710 | actor=-2.5059 | critic=1.6659 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=39.6 | checkpoint=-
# [train] step=507/1000 | warm=0 | policy=32 | replay=15784 | world_total=11303.0090 | actor=-2.6816 | critic=1.5088 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=46.1 | checkpoint=-
# [train] step=508/1000 | warm=0 | policy=32 | replay=15816 | world_total=11304.1780 | actor=-2.9375 | critic=1.5414 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=53.0 | checkpoint=-
# [train] step=509/1000 | warm=0 | policy=32 | replay=15848 | world_total=11303.6937 | actor=-3.3887 | critic=1.4140 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=60.0 | checkpoint=-
# [train] step=510/1000 | warm=0 | policy=32 | replay=15880 | world_total=11303.0177 | actor=-4.3691 | critic=1.5172 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=66.2 | checkpoint=-
# [train] step=511/1000 | warm=0 | policy=32 | replay=15912 | world_total=11303.1517 | actor=-5.2852 | critic=1.5340 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=72.7 | checkpoint=-
# [train] step=512/1000 | warm=0 | policy=32 | replay=15944 | world_total=11302.8822 | actor=-5.1758 | critic=1.5901 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=79.4 | checkpoint=-
# [train] step=513/1000 | warm=0 | policy=32 | replay=15976 | world_total=11302.6969 | actor=-5.1992 | critic=1.7577 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=86.1 | checkpoint=-
# [train] step=514/1000 | warm=0 | policy=32 | replay=16008 | world_total=11302.5588 | actor=-4.2285 | critic=1.8166 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=93.4 | checkpoint=-
# [train] step=515/1000 | warm=0 | policy=32 | replay=16040 | world_total=11302.4211 | actor=-4.2188 | critic=1.6983 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=100.6 | checkpoint=-
# [train] step=516/1000 | warm=0 | policy=32 | replay=16072 | world_total=11302.3588 | actor=-3.8848 | critic=1.7271 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=107.1 | checkpoint=-
# [train] step=517/1000 | warm=0 | policy=32 | replay=16104 | world_total=11302.2651 | actor=-3.5449 | critic=1.8384 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=113.4 | checkpoint=-
# [train] step=518/1000 | warm=0 | policy=32 | replay=16136 | world_total=11302.2131 | actor=-3.1270 | critic=1.8774 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=119.9 | checkpoint=-
# [train] step=519/1000 | warm=0 | policy=32 | replay=16168 | world_total=11302.2174 | actor=-3.1875 | critic=2.0271 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=126.2 | checkpoint=-
# [train] step=520/1000 | warm=0 | policy=32 | replay=16200 | world_total=11302.1941 | actor=-2.9062 | critic=2.0544 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=133.2 | checkpoint=-
# [train] step=521/1000 | warm=0 | policy=32 | replay=16232 | world_total=11302.1030 | actor=-2.4980 | critic=1.9335 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=140.2 | checkpoint=-
# [train] step=522/1000 | warm=0 | policy=32 | replay=16264 | world_total=11302.0948 | actor=-2.3271 | critic=1.9074 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=147.0 | checkpoint=-
# [train] step=523/1000 | warm=0 | policy=32 | replay=16296 | world_total=11302.0791 | actor=-1.8701 | critic=1.7720 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=153.5 | checkpoint=-
# [train] step=524/1000 | warm=0 | policy=32 | replay=16328 | world_total=11302.0796 | actor=-1.6016 | critic=1.6400 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=161.4 | checkpoint=-
# [train] step=525/1000 | warm=0 | policy=32 | replay=16360 | world_total=11302.0900 | actor=-1.3584 | critic=1.5381 | eval_reward=-0.5274 | cycle_s=47.0 | elapsed_s=208.4 | checkpoint=checkpoint_00525.pt
# [train] step=526/1000 | warm=0 | policy=32 | replay=16392 | world_total=11302.0532 | actor=-1.0312 | critic=1.3298 | eval_reward=n/a | cycle_s=10.9 | elapsed_s=219.3 | checkpoint=-
# [train] step=527/1000 | warm=0 | policy=32 | replay=16424 | world_total=11302.0625 | actor=-0.9873 | critic=1.3035 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=226.3 | checkpoint=-
# [train] step=528/1000 | warm=0 | policy=32 | replay=16456 | world_total=11302.0776 | actor=-0.9429 | critic=1.2506 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=233.1 | checkpoint=-
# [train] step=529/1000 | warm=0 | policy=32 | replay=16488 | world_total=11302.0513 | actor=-0.8481 | critic=1.1850 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=241.2 | checkpoint=-
# [train] step=530/1000 | warm=0 | policy=32 | replay=16520 | world_total=11302.0291 | actor=-0.8115 | critic=1.1256 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=248.7 | checkpoint=-
# [train] step=531/1000 | warm=0 | policy=32 | replay=16552 | world_total=11302.0272 | actor=-0.7588 | critic=1.1064 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=255.8 | checkpoint=-
# [train] step=532/1000 | warm=0 | policy=32 | replay=16584 | world_total=11302.0358 | actor=-0.7246 | critic=1.0895 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=263.0 | checkpoint=-
# [train] step=533/1000 | warm=0 | policy=32 | replay=16616 | world_total=11303.3462 | actor=-0.7793 | critic=1.0902 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=269.3 | checkpoint=-
# [train] step=534/1000 | warm=0 | policy=32 | replay=16648 | world_total=11303.4108 | actor=-0.8110 | critic=1.1185 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=276.1 | checkpoint=-
# [train] step=535/1000 | warm=0 | policy=32 | replay=16680 | world_total=11303.2001 | actor=-0.9038 | critic=1.1837 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=282.8 | checkpoint=-
# [train] step=536/1000 | warm=0 | policy=32 | replay=16712 | world_total=11302.7341 | actor=-1.1543 | critic=1.2857 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=289.7 | checkpoint=-
# [train] step=537/1000 | warm=0 | policy=32 | replay=16744 | world_total=11303.4240 | actor=-1.5957 | critic=1.4690 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=296.9 | checkpoint=-
# [train] step=538/1000 | warm=0 | policy=32 | replay=16776 | world_total=11304.2261 | actor=-2.8633 | critic=1.6444 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=303.7 | checkpoint=-
# [train] step=539/1000 | warm=0 | policy=32 | replay=16808 | world_total=11304.1667 | actor=-3.9746 | critic=1.6359 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=310.5 | checkpoint=-
# [train] step=540/1000 | warm=0 | policy=32 | replay=16840 | world_total=11303.4462 | actor=-5.3203 | critic=1.8062 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=317.1 | checkpoint=-
# [train] step=541/1000 | warm=0 | policy=32 | replay=16872 | world_total=11303.3602 | actor=-6.0625 | critic=1.8489 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=324.0 | checkpoint=-
# [train] step=542/1000 | warm=0 | policy=32 | replay=16904 | world_total=11303.0829 | actor=-6.9570 | critic=1.8512 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=330.5 | checkpoint=-
# [train] step=543/1000 | warm=0 | policy=32 | replay=16936 | world_total=11302.8090 | actor=-7.8438 | critic=2.0758 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=337.4 | checkpoint=-
# [train] step=544/1000 | warm=0 | policy=32 | replay=16968 | world_total=11303.1039 | actor=-7.3672 | critic=1.9643 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=344.3 | checkpoint=-
# [train] step=545/1000 | warm=0 | policy=32 | replay=17000 | world_total=11302.8201 | actor=-8.3516 | critic=2.1629 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=351.6 | checkpoint=-
# [train] step=546/1000 | warm=0 | policy=32 | replay=17032 | world_total=11302.6383 | actor=-9.1484 | critic=2.4498 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=358.2 | checkpoint=-
# [train] step=547/1000 | warm=0 | policy=32 | replay=17064 | world_total=11302.8690 | actor=-9.2891 | critic=2.8631 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=365.2 | checkpoint=-
# [train] step=548/1000 | warm=0 | policy=32 | replay=17096 | world_total=11302.9629 | actor=-8.6367 | critic=2.9560 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=372.5 | checkpoint=-
# [train] step=549/1000 | warm=0 | policy=32 | replay=17128 | world_total=11302.8126 | actor=-8.2852 | critic=2.7376 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=379.3 | checkpoint=-
# [train] step=550/1000 | warm=0 | policy=32 | replay=17160 | world_total=11302.6586 | actor=-10.4531 | critic=3.0485 | eval_reward=-0.5226 | cycle_s=63.2 | elapsed_s=442.5 | checkpoint=checkpoint_00550.pt
# [train] step=551/1000 | warm=0 | policy=32 | replay=17192 | world_total=11302.3240 | actor=-11.1641 | critic=2.8273 | eval_reward=n/a | cycle_s=15.4 | elapsed_s=457.9 | checkpoint=-
# [train] step=552/1000 | warm=0 | policy=32 | replay=17224 | world_total=11302.1750 | actor=-10.7031 | critic=2.8145 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=465.8 | checkpoint=-
# [train] step=553/1000 | warm=0 | policy=32 | replay=17256 | world_total=11302.0497 | actor=-11.1875 | critic=2.8816 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=472.5 | checkpoint=-
# [train] step=554/1000 | warm=0 | policy=32 | replay=17288 | world_total=11301.9779 | actor=-10.1016 | critic=2.7433 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=479.3 | checkpoint=-
# [train] step=555/1000 | warm=0 | policy=32 | replay=17320 | world_total=11301.9176 | actor=-9.3516 | critic=2.9962 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=485.9 | checkpoint=-
# [train] step=556/1000 | warm=0 | policy=32 | replay=17352 | world_total=11301.8699 | actor=-8.4688 | critic=2.6589 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=492.8 | checkpoint=-
# [train] step=557/1000 | warm=0 | policy=32 | replay=17384 | world_total=11301.8827 | actor=-7.6445 | critic=2.4738 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=499.4 | checkpoint=-
# [train] step=558/1000 | warm=0 | policy=32 | replay=17416 | world_total=11301.8395 | actor=-7.0469 | critic=2.5017 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=506.3 | checkpoint=-
# [train] step=559/1000 | warm=0 | policy=32 | replay=17448 | world_total=11301.8965 | actor=-6.0820 | critic=2.4687 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=513.5 | checkpoint=-
# [train] step=560/1000 | warm=0 | policy=32 | replay=17480 | world_total=11301.8595 | actor=-5.6133 | critic=2.3350 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=520.1 | checkpoint=-
# [train] step=561/1000 | warm=0 | policy=32 | replay=17512 | world_total=11301.8400 | actor=-5.0703 | critic=2.3663 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=527.1 | checkpoint=-
# [train] step=562/1000 | warm=0 | policy=32 | replay=17544 | world_total=11301.7958 | actor=-4.5449 | critic=2.2961 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=534.1 | checkpoint=-
# [train] step=563/1000 | warm=0 | policy=32 | replay=17576 | world_total=11301.7772 | actor=-4.2480 | critic=2.2600 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=541.1 | checkpoint=-
# [train] step=564/1000 | warm=0 | policy=32 | replay=17608 | world_total=11301.8080 | actor=-3.5059 | critic=2.2930 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=547.7 | checkpoint=-
# [train] step=565/1000 | warm=0 | policy=32 | replay=17640 | world_total=11301.7754 | actor=-3.1660 | critic=2.4174 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=555.4 | checkpoint=-
# [train] step=566/1000 | warm=0 | policy=32 | replay=17672 | world_total=11301.7744 | actor=-3.0059 | critic=2.3187 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=562.1 | checkpoint=-
# [train] step=567/1000 | warm=0 | policy=32 | replay=17704 | world_total=11301.7300 | actor=-2.3008 | critic=2.1671 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=568.7 | checkpoint=-
# [train] step=568/1000 | warm=0 | policy=32 | replay=17736 | world_total=11301.7318 | actor=-1.7217 | critic=1.9108 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=575.0 | checkpoint=-
# [train] step=569/1000 | warm=0 | policy=32 | replay=17768 | world_total=11301.7937 | actor=-1.5703 | critic=1.7071 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=582.5 | checkpoint=-
# [train] step=570/1000 | warm=0 | policy=32 | replay=17800 | world_total=11301.7548 | actor=-1.1924 | critic=1.4639 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=591.3 | checkpoint=-
# [train] step=571/1000 | warm=0 | policy=32 | replay=17832 | world_total=11302.3795 | actor=-0.9478 | critic=1.3632 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=598.8 | checkpoint=-
# [train] step=572/1000 | warm=0 | policy=32 | replay=17864 | world_total=11303.9655 | actor=-1.3838 | critic=1.6561 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=606.2 | checkpoint=-
# [train] step=573/1000 | warm=0 | policy=32 | replay=17896 | world_total=11303.0377 | actor=-3.2891 | critic=2.9243 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=614.7 | checkpoint=-
# [train] step=574/1000 | warm=0 | policy=32 | replay=17928 | world_total=11303.0367 | actor=-4.0664 | critic=2.1465 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=622.0 | checkpoint=-
# [train] step=575/1000 | warm=0 | policy=32 | replay=17960 | world_total=11302.8630 | actor=-5.1680 | critic=2.2689 | eval_reward=-0.5242 | cycle_s=69.7 | elapsed_s=691.7 | checkpoint=checkpoint_00575.pt
# [train] step=576/1000 | warm=0 | policy=32 | replay=17992 | world_total=11302.7865 | actor=-5.9609 | critic=2.0680 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=699.2 | checkpoint=-
# [train] step=577/1000 | warm=0 | policy=32 | replay=18024 | world_total=11303.2363 | actor=-6.2773 | critic=2.3851 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=706.1 | checkpoint=-
# [train] step=578/1000 | warm=0 | policy=32 | replay=18056 | world_total=11306.5730 | actor=-6.0273 | critic=2.5581 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=712.9 | checkpoint=-
# [train] step=579/1000 | warm=0 | policy=32 | replay=18088 | world_total=11305.3704 | actor=-5.9922 | critic=2.7564 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=719.1 | checkpoint=-
# [train] step=580/1000 | warm=0 | policy=32 | replay=18120 | world_total=11303.8766 | actor=-7.3789 | critic=2.5900 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=726.5 | checkpoint=-
# [train] step=581/1000 | warm=0 | policy=32 | replay=18152 | world_total=11303.5740 | actor=-7.4961 | critic=2.7622 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=733.8 | checkpoint=-
# [train] step=582/1000 | warm=0 | policy=32 | replay=18184 | world_total=11303.2633 | actor=-9.3359 | critic=3.3227 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=740.6 | checkpoint=-
# [train] step=583/1000 | warm=0 | policy=32 | replay=18216 | world_total=11302.9941 | actor=-10.0312 | critic=3.4508 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=747.4 | checkpoint=-
# [train] step=584/1000 | warm=0 | policy=32 | replay=18248 | world_total=11302.9719 | actor=-8.6914 | critic=4.2937 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=754.1 | checkpoint=-
# [train] step=585/1000 | warm=0 | policy=32 | replay=18280 | world_total=11303.5208 | actor=-11.2031 | critic=5.2373 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=761.2 | checkpoint=-
# [train] step=586/1000 | warm=0 | policy=32 | replay=18312 | world_total=11303.5989 | actor=-12.9141 | critic=4.5393 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=767.9 | checkpoint=-
# [train] step=587/1000 | warm=0 | policy=32 | replay=18344 | world_total=11303.7953 | actor=-13.9141 | critic=3.7696 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=774.8 | checkpoint=-
# [train] step=588/1000 | warm=0 | policy=32 | replay=18376 | world_total=11303.4048 | actor=-17.6406 | critic=4.4881 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=782.0 | checkpoint=-
# [train] step=589/1000 | warm=0 | policy=32 | replay=18408 | world_total=11303.1550 | actor=-16.9688 | critic=3.5767 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=788.6 | checkpoint=-
# [train] step=590/1000 | warm=0 | policy=32 | replay=18440 | world_total=11302.7273 | actor=-14.5547 | critic=3.6527 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=795.8 | checkpoint=-
# [train] step=591/1000 | warm=0 | policy=32 | replay=18472 | world_total=11302.9734 | actor=-14.5391 | critic=2.7915 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=802.4 | checkpoint=-
# [train] step=592/1000 | warm=0 | policy=32 | replay=18504 | world_total=11303.0750 | actor=-14.9688 | critic=2.7116 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=808.7 | checkpoint=-
# [train] step=593/1000 | warm=0 | policy=32 | replay=18536 | world_total=11302.7887 | actor=-15.4688 | critic=2.7488 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=815.7 | checkpoint=-
# [train] step=594/1000 | warm=0 | policy=32 | replay=18568 | world_total=11302.7427 | actor=-14.2969 | critic=2.4566 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=822.3 | checkpoint=-
# [train] step=595/1000 | warm=0 | policy=32 | replay=18600 | world_total=11302.7404 | actor=-12.8984 | critic=2.3130 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=829.3 | checkpoint=-
# [train] step=596/1000 | warm=0 | policy=32 | replay=18632 | world_total=11302.6107 | actor=-12.2031 | critic=2.4817 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=835.8 | checkpoint=-
# [train] step=597/1000 | warm=0 | policy=32 | replay=18664 | world_total=11302.8801 | actor=-12.3750 | critic=2.0609 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=842.9 | checkpoint=-
# [train] step=598/1000 | warm=0 | policy=32 | replay=18696 | world_total=11302.8450 | actor=-12.7812 | critic=2.0690 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=850.2 | checkpoint=-
# [train] step=599/1000 | warm=0 | policy=32 | replay=18728 | world_total=11302.8218 | actor=-13.6172 | critic=2.0361 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=856.4 | checkpoint=-
# [train] step=600/1000 | warm=0 | policy=32 | replay=18760 | world_total=11302.9233 | actor=-13.4609 | critic=2.0328 | eval_reward=-0.5253 | cycle_s=33.7 | elapsed_s=890.1 | checkpoint=checkpoint_00600.pt
# [train] step=601/1000 | warm=0 | policy=32 | replay=18792 | world_total=11302.8687 | actor=-13.6719 | critic=1.9867 | eval_reward=n/a | cycle_s=9.5 | elapsed_s=899.6 | checkpoint=-
# [train] step=602/1000 | warm=0 | policy=32 | replay=18824 | world_total=11302.7344 | actor=-13.1719 | critic=2.2287 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=907.0 | checkpoint=-
# [train] step=603/1000 | warm=0 | policy=32 | replay=18856 | world_total=11302.5093 | actor=-13.8047 | critic=1.8288 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=913.8 | checkpoint=-
# [train] step=604/1000 | warm=0 | policy=32 | replay=18888 | world_total=11302.3499 | actor=-13.5469 | critic=1.8320 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=920.8 | checkpoint=-
# [train] step=605/1000 | warm=0 | policy=32 | replay=18920 | world_total=11302.2631 | actor=-12.7500 | critic=1.6616 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=927.6 | checkpoint=-
# [train] step=606/1000 | warm=0 | policy=32 | replay=18952 | world_total=11302.2394 | actor=-11.5312 | critic=1.9563 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=934.8 | checkpoint=-
# [train] step=607/1000 | warm=0 | policy=32 | replay=18984 | world_total=11302.2336 | actor=-9.8203 | critic=1.8213 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=942.0 | checkpoint=-
# [train] step=608/1000 | warm=0 | policy=32 | replay=19016 | world_total=11302.6364 | actor=-7.9844 | critic=1.3950 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=949.4 | checkpoint=-
# [train] step=609/1000 | warm=0 | policy=32 | replay=19048 | world_total=11302.2245 | actor=-6.1602 | critic=1.3459 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=955.8 | checkpoint=-
# [train] step=610/1000 | warm=0 | policy=32 | replay=19080 | world_total=11302.5344 | actor=-5.3516 | critic=1.2630 | eval_reward=n/a | cycle_s=10.9 | elapsed_s=966.8 | checkpoint=-
# [train] step=611/1000 | warm=0 | policy=32 | replay=19112 | world_total=11302.6012 | actor=-5.1406 | critic=1.1823 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=974.4 | checkpoint=-
# [train] step=612/1000 | warm=0 | policy=32 | replay=19144 | world_total=11302.5684 | actor=-4.6641 | critic=1.1738 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=981.5 | checkpoint=-
# [train] step=613/1000 | warm=0 | policy=32 | replay=19176 | world_total=11302.3723 | actor=-4.8711 | critic=1.1660 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=988.2 | checkpoint=-
# [train] step=614/1000 | warm=0 | policy=32 | replay=19208 | world_total=11302.6051 | actor=-5.2461 | critic=1.1673 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=998.1 | checkpoint=-
# [train] step=615/1000 | warm=0 | policy=32 | replay=19240 | world_total=11302.6484 | actor=-5.8672 | critic=1.1635 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1005.2 | checkpoint=-
# [train] step=616/1000 | warm=0 | policy=32 | replay=19272 | world_total=11302.5948 | actor=-7.1445 | critic=1.2383 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=1015.2 | checkpoint=-
# [train] step=617/1000 | warm=0 | policy=32 | replay=19304 | world_total=11302.6345 | actor=-7.9062 | critic=1.2613 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1023.0 | checkpoint=-
# [train] step=618/1000 | warm=0 | policy=32 | replay=19336 | world_total=11302.6284 | actor=-7.5742 | critic=1.2240 | eval_reward=n/a | cycle_s=12.0 | elapsed_s=1035.1 | checkpoint=-
# [train] step=619/1000 | warm=0 | policy=32 | replay=19368 | world_total=11302.5724 | actor=-7.0977 | critic=1.2618 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1042.7 | checkpoint=-
# [train] step=620/1000 | warm=0 | policy=32 | replay=19400 | world_total=11302.5897 | actor=-6.5312 | critic=1.2942 | eval_reward=n/a | cycle_s=10.8 | elapsed_s=1053.5 | checkpoint=-
# [train] step=621/1000 | warm=0 | policy=32 | replay=19432 | world_total=11302.8557 | actor=-6.9414 | critic=1.1392 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1061.0 | checkpoint=-
# [train] step=622/1000 | warm=0 | policy=32 | replay=19464 | world_total=11302.5841 | actor=-7.6328 | critic=1.2322 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1068.3 | checkpoint=-
# [train] step=623/1000 | warm=0 | policy=32 | replay=19496 | world_total=11302.5935 | actor=-7.8984 | critic=1.2257 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1075.0 | checkpoint=-
# [train] step=624/1000 | warm=0 | policy=32 | replay=19528 | world_total=11302.5576 | actor=-8.2227 | critic=1.1933 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1081.5 | checkpoint=-
# [train] step=625/1000 | warm=0 | policy=32 | replay=19560 | world_total=11302.5677 | actor=-8.3828 | critic=1.2326 | eval_reward=-0.5210 | cycle_s=23.8 | elapsed_s=1105.2 | checkpoint=checkpoint_00625.pt
# [train] step=626/1000 | warm=0 | policy=32 | replay=19592 | world_total=11302.5420 | actor=-8.0742 | critic=1.2165 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1113.8 | checkpoint=-
# [train] step=627/1000 | warm=0 | policy=32 | replay=19624 | world_total=11302.4331 | actor=-7.9844 | critic=1.2047 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1121.3 | checkpoint=-
# [train] step=628/1000 | warm=0 | policy=32 | replay=19656 | world_total=11302.5691 | actor=-7.2539 | critic=1.2293 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1128.1 | checkpoint=-
# [train] step=629/1000 | warm=0 | policy=32 | replay=19688 | world_total=11302.3925 | actor=-6.8789 | critic=1.1358 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1134.9 | checkpoint=-
# [train] step=630/1000 | warm=0 | policy=32 | replay=19720 | world_total=11302.2080 | actor=-6.5742 | critic=1.1153 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1141.9 | checkpoint=-
# [train] step=631/1000 | warm=0 | policy=32 | replay=19752 | world_total=11302.1544 | actor=-5.7539 | critic=1.2605 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1148.5 | checkpoint=-
# [train] step=632/1000 | warm=0 | policy=32 | replay=19784 | world_total=11301.9326 | actor=-5.2891 | critic=1.1964 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1155.3 | checkpoint=-
# [train] step=633/1000 | warm=0 | policy=32 | replay=19816 | world_total=11301.7883 | actor=-4.8672 | critic=1.1275 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1162.1 | checkpoint=-
# [train] step=634/1000 | warm=0 | policy=32 | replay=19848 | world_total=11301.6887 | actor=-4.4883 | critic=1.1512 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1169.1 | checkpoint=-
# [train] step=635/1000 | warm=0 | policy=32 | replay=19880 | world_total=11301.6138 | actor=-4.4375 | critic=1.1537 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1175.9 | checkpoint=-
# [train] step=636/1000 | warm=0 | policy=32 | replay=19912 | world_total=11301.5399 | actor=-4.3711 | critic=1.1509 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1182.3 | checkpoint=-
# [train] step=637/1000 | warm=0 | policy=32 | replay=19944 | world_total=11301.4998 | actor=-4.3320 | critic=1.1500 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1189.3 | checkpoint=-
# [train] step=638/1000 | warm=0 | policy=32 | replay=19976 | world_total=11301.4989 | actor=-4.3398 | critic=1.1969 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1196.2 | checkpoint=-
# [train] step=639/1000 | warm=0 | policy=32 | replay=20008 | world_total=11301.4991 | actor=-4.1367 | critic=1.1879 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1202.2 | checkpoint=-
# [train] step=640/1000 | warm=0 | policy=32 | replay=20040 | world_total=11301.4310 | actor=-3.9180 | critic=1.2139 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1209.4 | checkpoint=-
# [train] step=641/1000 | warm=0 | policy=32 | replay=20072 | world_total=11301.4795 | actor=-3.8984 | critic=1.2338 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1216.0 | checkpoint=-
# [train] step=642/1000 | warm=0 | policy=32 | replay=20104 | world_total=11301.4771 | actor=-3.5664 | critic=1.2443 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1222.8 | checkpoint=-
# [train] step=643/1000 | warm=0 | policy=32 | replay=20136 | world_total=11301.4211 | actor=-3.6270 | critic=1.2281 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1229.2 | checkpoint=-
# [train] step=644/1000 | warm=0 | policy=32 | replay=20168 | world_total=11301.4126 | actor=-3.5273 | critic=1.2672 | eval_reward=n/a | cycle_s=10.4 | elapsed_s=1239.5 | checkpoint=-
# [train] step=645/1000 | warm=0 | policy=32 | replay=20200 | world_total=11301.3990 | actor=-3.4219 | critic=1.2721 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1247.3 | checkpoint=-
# [train] step=646/1000 | warm=0 | policy=32 | replay=20232 | world_total=11301.3813 | actor=-3.1602 | critic=1.2723 | eval_reward=n/a | cycle_s=10.9 | elapsed_s=1258.2 | checkpoint=-
# [train] step=647/1000 | warm=0 | policy=32 | replay=20264 | world_total=11301.3671 | actor=-3.1289 | critic=1.2516 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1265.4 | checkpoint=-
# [train] step=648/1000 | warm=0 | policy=32 | replay=20296 | world_total=11301.4301 | actor=-2.6562 | critic=1.2153 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1271.7 | checkpoint=-
# [train] step=649/1000 | warm=0 | policy=32 | replay=20328 | world_total=11301.3884 | actor=-2.5195 | critic=1.2011 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1278.2 | checkpoint=-
# [train] step=650/1000 | warm=0 | policy=32 | replay=20360 | world_total=11301.4224 | actor=-2.6035 | critic=1.1819 | eval_reward=-0.5263 | cycle_s=15.3 | elapsed_s=1293.6 | checkpoint=checkpoint_00650.pt
# [train] step=651/1000 | warm=0 | policy=32 | replay=20392 | world_total=11301.3801 | actor=-2.7305 | critic=1.1681 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1300.8 | checkpoint=-
# [train] step=652/1000 | warm=0 | policy=32 | replay=20424 | world_total=11301.5963 | actor=-2.2031 | critic=1.2848 | eval_reward=n/a | cycle_s=10.4 | elapsed_s=1311.1 | checkpoint=-
# [train] step=653/1000 | warm=0 | policy=32 | replay=20456 | world_total=11302.4043 | actor=-1.8691 | critic=1.2187 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1318.3 | checkpoint=-
# [train] step=654/1000 | warm=0 | policy=32 | replay=20488 | world_total=11302.0851 | actor=-1.9736 | critic=1.1347 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1325.7 | checkpoint=-
# [train] step=655/1000 | warm=0 | policy=32 | replay=20520 | world_total=11302.2615 | actor=-2.1084 | critic=1.0970 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1332.1 | checkpoint=-
# [train] step=656/1000 | warm=0 | policy=32 | replay=20552 | world_total=11302.2168 | actor=-2.0449 | critic=1.1233 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1339.4 | checkpoint=-
# [train] step=657/1000 | warm=0 | policy=32 | replay=20584 | world_total=11302.4993 | actor=-3.2051 | critic=1.0986 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1346.6 | checkpoint=-
# [train] step=658/1000 | warm=0 | policy=32 | replay=20616 | world_total=11302.5139 | actor=-3.9199 | critic=1.1361 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1352.8 | checkpoint=-
# [train] step=659/1000 | warm=0 | policy=32 | replay=20648 | world_total=11302.1722 | actor=-4.6211 | critic=1.2127 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1359.7 | checkpoint=-
# [train] step=660/1000 | warm=0 | policy=32 | replay=20680 | world_total=11302.4781 | actor=-6.0586 | critic=1.3842 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1366.9 | checkpoint=-
# [train] step=661/1000 | warm=0 | policy=32 | replay=20712 | world_total=11302.6686 | actor=-6.7539 | critic=1.4359 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1373.3 | checkpoint=-
# [train] step=662/1000 | warm=0 | policy=32 | replay=20744 | world_total=11302.2467 | actor=-7.4883 | critic=1.5234 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1380.0 | checkpoint=-
# [train] step=663/1000 | warm=0 | policy=32 | replay=20776 | world_total=11302.4260 | actor=-8.0039 | critic=1.4675 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1387.1 | checkpoint=-
# [train] step=664/1000 | warm=0 | policy=32 | replay=20808 | world_total=11302.4301 | actor=-8.5430 | critic=1.5524 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1394.3 | checkpoint=-
# [train] step=665/1000 | warm=0 | policy=32 | replay=20840 | world_total=11302.3175 | actor=-8.9375 | critic=1.5211 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1400.8 | checkpoint=-
# [train] step=666/1000 | warm=0 | policy=32 | replay=20872 | world_total=11302.3556 | actor=-8.4609 | critic=1.4875 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1408.0 | checkpoint=-
# [train] step=667/1000 | warm=0 | policy=32 | replay=20904 | world_total=11302.2297 | actor=-8.7344 | critic=1.4700 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1414.5 | checkpoint=-
# [train] step=668/1000 | warm=0 | policy=32 | replay=20936 | world_total=11302.1531 | actor=-8.6328 | critic=1.4785 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1421.0 | checkpoint=-
# [train] step=669/1000 | warm=0 | policy=32 | replay=20968 | world_total=11302.3459 | actor=-8.6875 | critic=1.4588 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1427.7 | checkpoint=-
# [train] step=670/1000 | warm=0 | policy=32 | replay=21000 | world_total=11302.2860 | actor=-8.2031 | critic=1.3888 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1434.6 | checkpoint=-
# [train] step=671/1000 | warm=0 | policy=32 | replay=21032 | world_total=11302.3036 | actor=-8.3516 | critic=1.3899 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1441.5 | checkpoint=-
# [train] step=672/1000 | warm=0 | policy=32 | replay=21064 | world_total=11302.6477 | actor=-8.9844 | critic=1.3964 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1448.2 | checkpoint=-
# [train] step=673/1000 | warm=0 | policy=32 | replay=21096 | world_total=11302.2213 | actor=-9.6094 | critic=1.4738 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1454.6 | checkpoint=-
# [train] step=674/1000 | warm=0 | policy=32 | replay=21128 | world_total=11301.8671 | actor=-10.2188 | critic=1.3732 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1462.4 | checkpoint=-
# [train] step=675/1000 | warm=0 | policy=32 | replay=21160 | world_total=11301.6190 | actor=-9.2969 | critic=1.3872 | eval_reward=-0.5279 | cycle_s=16.1 | elapsed_s=1478.5 | checkpoint=checkpoint_00675.pt
# [train] step=676/1000 | warm=0 | policy=32 | replay=21192 | world_total=11301.4008 | actor=-8.0781 | critic=1.4422 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1483.9 | checkpoint=-
# [train] step=677/1000 | warm=0 | policy=32 | replay=21224 | world_total=11301.3402 | actor=-7.6094 | critic=1.3239 | eval_reward=n/a | cycle_s=14.5 | elapsed_s=1498.3 | checkpoint=-
# [train] step=678/1000 | warm=0 | policy=32 | replay=21256 | world_total=11301.3759 | actor=-7.3828 | critic=1.2482 | eval_reward=n/a | cycle_s=13.9 | elapsed_s=1512.2 | checkpoint=-
# [train] step=679/1000 | warm=0 | policy=32 | replay=21288 | world_total=11301.2892 | actor=-7.1016 | critic=1.3207 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1519.1 | checkpoint=-
# [train] step=680/1000 | warm=0 | policy=32 | replay=21320 | world_total=11301.2317 | actor=-7.0781 | critic=1.3257 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1525.7 | checkpoint=-
# [train] step=681/1000 | warm=0 | policy=32 | replay=21352 | world_total=11301.2220 | actor=-6.5391 | critic=1.4093 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1532.6 | checkpoint=-
# [train] step=682/1000 | warm=0 | policy=32 | replay=21384 | world_total=11301.2540 | actor=-6.4102 | critic=1.4375 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1539.2 | checkpoint=-
# [train] step=683/1000 | warm=0 | policy=32 | replay=21416 | world_total=11301.2137 | actor=-6.1250 | critic=1.4339 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1545.9 | checkpoint=-
# [train] step=684/1000 | warm=0 | policy=32 | replay=21448 | world_total=11301.1776 | actor=-5.9023 | critic=1.4442 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1553.1 | checkpoint=-
# [train] step=685/1000 | warm=0 | policy=32 | replay=21480 | world_total=11301.2446 | actor=-5.6406 | critic=1.5412 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1560.2 | checkpoint=-
# [train] step=686/1000 | warm=0 | policy=32 | replay=21512 | world_total=11301.1989 | actor=-5.2227 | critic=1.4544 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1567.4 | checkpoint=-
# [train] step=687/1000 | warm=0 | policy=32 | replay=21544 | world_total=11301.1385 | actor=-5.1641 | critic=1.4597 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1573.8 | checkpoint=-
# [train] step=688/1000 | warm=0 | policy=32 | replay=21576 | world_total=11301.1459 | actor=-4.9922 | critic=1.4797 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1580.6 | checkpoint=-
# [train] step=689/1000 | warm=0 | policy=32 | replay=21608 | world_total=11301.1863 | actor=-4.6094 | critic=1.4769 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1586.9 | checkpoint=-
# [train] step=690/1000 | warm=0 | policy=32 | replay=21640 | world_total=11301.1697 | actor=-4.1953 | critic=1.4078 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1593.6 | checkpoint=-
# [train] step=691/1000 | warm=0 | policy=32 | replay=21672 | world_total=11301.1824 | actor=-3.8066 | critic=1.3762 | eval_reward=n/a | cycle_s=10.4 | elapsed_s=1604.0 | checkpoint=-
# [train] step=692/1000 | warm=0 | policy=32 | replay=21704 | world_total=11301.1687 | actor=-3.4297 | critic=1.3025 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1611.7 | checkpoint=-
# [train] step=693/1000 | warm=0 | policy=32 | replay=21736 | world_total=11301.1169 | actor=-3.3535 | critic=1.2323 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1618.5 | checkpoint=-
# [train] step=694/1000 | warm=0 | policy=32 | replay=21768 | world_total=11301.0601 | actor=-3.0352 | critic=1.2041 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1624.9 | checkpoint=-
# [train] step=695/1000 | warm=0 | policy=32 | replay=21800 | world_total=11301.1222 | actor=-2.6934 | critic=1.1760 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1631.8 | checkpoint=-
# [train] step=696/1000 | warm=0 | policy=32 | replay=21832 | world_total=11301.1379 | actor=-2.4395 | critic=1.1700 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=1637.6 | checkpoint=-
# [train] step=697/1000 | warm=0 | policy=32 | replay=21864 | world_total=11301.0853 | actor=-2.3535 | critic=1.1930 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1645.1 | checkpoint=-
# [train] step=698/1000 | warm=0 | policy=32 | replay=21896 | world_total=11301.0681 | actor=-2.3203 | critic=1.1649 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=1651.0 | checkpoint=-
# [train] step=699/1000 | warm=0 | policy=32 | replay=21928 | world_total=11302.1733 | actor=-1.8008 | critic=1.3208 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1657.0 | checkpoint=-
# [train] step=700/1000 | warm=0 | policy=32 | replay=21960 | world_total=11304.6674 | actor=-2.2539 | critic=1.1843 | eval_reward=-0.5252 | cycle_s=14.8 | elapsed_s=1671.8 | checkpoint=checkpoint_00700.pt
# [train] step=701/1000 | warm=0 | policy=32 | replay=21992 | world_total=11302.7892 | actor=-2.8164 | critic=1.1430 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1677.5 | checkpoint=-
# [train] step=702/1000 | warm=0 | policy=32 | replay=22024 | world_total=11302.2581 | actor=-3.7832 | critic=1.2351 | eval_reward=n/a | cycle_s=10.7 | elapsed_s=1688.2 | checkpoint=-
# [train] step=703/1000 | warm=0 | policy=32 | replay=22056 | world_total=11302.5530 | actor=-5.1094 | critic=1.3447 | eval_reward=n/a | cycle_s=12.7 | elapsed_s=1700.9 | checkpoint=-
# [train] step=704/1000 | warm=0 | policy=32 | replay=22088 | world_total=11301.8828 | actor=-6.5859 | critic=1.5974 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=1706.8 | checkpoint=-
# [train] step=705/1000 | warm=0 | policy=32 | replay=22120 | world_total=11302.2576 | actor=-6.1836 | critic=1.8445 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1713.8 | checkpoint=-
# [train] step=706/1000 | warm=0 | policy=32 | replay=22152 | world_total=11302.3911 | actor=-6.8633 | critic=1.5435 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1720.1 | checkpoint=-
# [train] step=707/1000 | warm=0 | policy=32 | replay=22184 | world_total=11301.8833 | actor=-7.6562 | critic=1.7464 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1726.8 | checkpoint=-
# [train] step=708/1000 | warm=0 | policy=32 | replay=22216 | world_total=11302.1830 | actor=-8.3828 | critic=1.7061 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1733.8 | checkpoint=-
# [train] step=709/1000 | warm=0 | policy=32 | replay=22248 | world_total=11302.2021 | actor=-8.2344 | critic=1.7291 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1740.4 | checkpoint=-
# [train] step=710/1000 | warm=0 | policy=32 | replay=22280 | world_total=11302.1260 | actor=-7.7891 | critic=1.5210 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1747.4 | checkpoint=-
# [train] step=711/1000 | warm=0 | policy=32 | replay=22312 | world_total=11302.1250 | actor=-7.5117 | critic=1.4988 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=1753.7 | checkpoint=-
# [train] step=712/1000 | warm=0 | policy=32 | replay=22344 | world_total=11301.9414 | actor=-8.3945 | critic=1.4230 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1760.3 | checkpoint=-
# [train] step=713/1000 | warm=0 | policy=32 | replay=22376 | world_total=11301.9263 | actor=-8.7266 | critic=1.5811 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1767.2 | checkpoint=-
# [train] step=714/1000 | warm=0 | policy=32 | replay=22408 | world_total=11301.9465 | actor=-8.2383 | critic=1.4625 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1773.9 | checkpoint=-
# [train] step=715/1000 | warm=0 | policy=32 | replay=22440 | world_total=11302.0468 | actor=-8.0352 | critic=1.3964 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1780.9 | checkpoint=-
# [train] step=716/1000 | warm=0 | policy=32 | replay=22472 | world_total=11301.9980 | actor=-8.2305 | critic=1.3040 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1788.0 | checkpoint=-
# [train] step=717/1000 | warm=0 | policy=32 | replay=22504 | world_total=11302.1112 | actor=-8.1562 | critic=1.3054 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=1794.1 | checkpoint=-
# [train] step=718/1000 | warm=0 | policy=32 | replay=22536 | world_total=11301.8918 | actor=-7.6562 | critic=1.3307 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1800.9 | checkpoint=-
# [train] step=719/1000 | warm=0 | policy=32 | replay=22568 | world_total=11302.1819 | actor=-7.9453 | critic=1.3163 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1807.8 | checkpoint=-
# [train] step=720/1000 | warm=0 | policy=32 | replay=22600 | world_total=11302.1298 | actor=-8.0469 | critic=1.2643 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1814.8 | checkpoint=-
# [train] step=721/1000 | warm=0 | policy=32 | replay=22632 | world_total=11302.2513 | actor=-8.0547 | critic=1.2275 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1821.8 | checkpoint=-
# [train] step=722/1000 | warm=0 | policy=32 | replay=22664 | world_total=11301.9575 | actor=-8.2188 | critic=1.2246 | eval_reward=n/a | cycle_s=13.5 | elapsed_s=1835.3 | checkpoint=-
# [train] step=723/1000 | warm=0 | policy=32 | replay=22696 | world_total=11301.8232 | actor=-8.2227 | critic=1.2296 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1842.4 | checkpoint=-
# [train] step=724/1000 | warm=0 | policy=32 | replay=22728 | world_total=11301.6136 | actor=-8.5781 | critic=1.1808 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1849.7 | checkpoint=-
# [train] step=725/1000 | warm=0 | policy=32 | replay=22760 | world_total=11301.7811 | actor=-8.1992 | critic=1.1549 | eval_reward=-0.5258 | cycle_s=15.6 | elapsed_s=1865.2 | checkpoint=checkpoint_00725.pt
# [train] step=726/1000 | warm=0 | policy=32 | replay=22792 | world_total=11301.8192 | actor=-8.0195 | critic=1.1192 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1870.7 | checkpoint=-
# [train] step=727/1000 | warm=0 | policy=32 | replay=22824 | world_total=11301.5432 | actor=-7.6250 | critic=1.2421 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=1876.2 | checkpoint=-
# [train] step=728/1000 | warm=0 | policy=32 | replay=22856 | world_total=11302.0085 | actor=-7.5586 | critic=1.2734 | eval_reward=n/a | cycle_s=15.1 | elapsed_s=1891.2 | checkpoint=-
# [train] step=729/1000 | warm=0 | policy=32 | replay=22888 | world_total=11301.7455 | actor=-7.5195 | critic=1.2138 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=1897.1 | checkpoint=-
# [train] step=730/1000 | warm=0 | policy=32 | replay=22920 | world_total=11302.0031 | actor=-7.6211 | critic=1.2213 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1903.2 | checkpoint=-
# [train] step=731/1000 | warm=0 | policy=32 | replay=22952 | world_total=11301.9622 | actor=-7.5938 | critic=1.2149 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1909.2 | checkpoint=-
# [train] step=732/1000 | warm=0 | policy=32 | replay=22984 | world_total=11301.9182 | actor=-7.8633 | critic=1.2178 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1915.9 | checkpoint=-
# [train] step=733/1000 | warm=0 | policy=32 | replay=23016 | world_total=11301.9135 | actor=-8.2734 | critic=1.1907 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1923.2 | checkpoint=-
# [train] step=734/1000 | warm=0 | policy=32 | replay=23048 | world_total=11301.9436 | actor=-8.1836 | critic=1.1646 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=1929.8 | checkpoint=-
# [train] step=735/1000 | warm=0 | policy=32 | replay=23080 | world_total=11301.9768 | actor=-7.6406 | critic=1.1884 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1937.1 | checkpoint=-
# [train] step=736/1000 | warm=0 | policy=32 | replay=23112 | world_total=11301.8457 | actor=-7.9688 | critic=1.1101 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1944.0 | checkpoint=-
# [train] step=737/1000 | warm=0 | policy=32 | replay=23144 | world_total=11301.7001 | actor=-8.1328 | critic=1.0822 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1951.0 | checkpoint=-
# [train] step=738/1000 | warm=0 | policy=32 | replay=23176 | world_total=11301.7852 | actor=-8.5625 | critic=1.0725 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1957.5 | checkpoint=-
# [train] step=739/1000 | warm=0 | policy=32 | replay=23208 | world_total=11302.0901 | actor=-9.1875 | critic=1.1204 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=1964.1 | checkpoint=-
# [train] step=740/1000 | warm=0 | policy=32 | replay=23240 | world_total=11301.8905 | actor=-9.1641 | critic=1.1376 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1971.1 | checkpoint=-
# [train] step=741/1000 | warm=0 | policy=32 | replay=23272 | world_total=11302.0374 | actor=-9.0938 | critic=1.1076 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1977.9 | checkpoint=-
# [train] step=742/1000 | warm=0 | policy=32 | replay=23304 | world_total=11301.8903 | actor=-8.9609 | critic=1.0804 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1984.7 | checkpoint=-
# [train] step=743/1000 | warm=0 | policy=32 | replay=23336 | world_total=11302.0337 | actor=-8.1211 | critic=1.0810 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1991.1 | checkpoint=-
# [train] step=744/1000 | warm=0 | policy=32 | replay=23368 | world_total=11301.9646 | actor=-7.6484 | critic=1.0808 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1998.9 | checkpoint=-
# [train] step=745/1000 | warm=0 | policy=32 | replay=23400 | world_total=11301.9301 | actor=-7.5078 | critic=1.0797 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=2005.6 | checkpoint=-
# [train] step=746/1000 | warm=0 | policy=32 | replay=23432 | world_total=11301.8634 | actor=-7.6523 | critic=1.0808 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=2011.7 | checkpoint=-
# [train] step=747/1000 | warm=0 | policy=32 | replay=23464 | world_total=11301.8108 | actor=-8.0039 | critic=1.1074 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=2017.2 | checkpoint=-
# [train] step=748/1000 | warm=0 | policy=32 | replay=23496 | world_total=11301.8252 | actor=-8.2852 | critic=1.1010 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=2023.9 | checkpoint=-
# [train] step=749/1000 | warm=0 | policy=32 | replay=23528 | world_total=11301.8301 | actor=-7.7227 | critic=1.0775 | eval_reward=n/a | cycle_s=14.2 | elapsed_s=2038.1 | checkpoint=-
# [train] step=750/1000 | warm=0 | policy=32 | replay=23560 | world_total=11301.8898 | actor=-7.8008 | critic=1.0966 | eval_reward=-0.5215 | cycle_s=16.0 | elapsed_s=2054.1 | checkpoint=checkpoint_00750.pt
# [train] step=751/1000 | warm=0 | policy=32 | replay=23592 | world_total=11301.7198 | actor=-7.8828 | critic=1.1262 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=2059.0 | checkpoint=-
# [train] step=752/1000 | warm=0 | policy=32 | replay=23624 | world_total=11301.7416 | actor=-7.3086 | critic=1.1728 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=2065.0 | checkpoint=-
# [train] step=753/1000 | warm=0 | policy=32 | replay=23656 | world_total=11301.7510 | actor=-7.4922 | critic=1.1505 | eval_reward=n/a | cycle_s=15.5 | elapsed_s=2080.5 | checkpoint=-
# [train] step=754/1000 | warm=0 | policy=32 | replay=23688 | world_total=11301.9515 | actor=-7.6133 | critic=1.1409 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=2087.3 | checkpoint=-
# [train] step=755/1000 | warm=0 | policy=32 | replay=23720 | world_total=11301.8702 | actor=-7.9688 | critic=1.0838 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=2094.2 | checkpoint=-
# [train] step=756/1000 | warm=0 | policy=32 | replay=23752 | world_total=11301.5730 | actor=-7.8867 | critic=1.1998 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=2101.0 | checkpoint=-
# [train] step=757/1000 | warm=0 | policy=32 | replay=23784 | world_total=11301.4248 | actor=-8.3438 | critic=1.2661 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=2107.9 | checkpoint=-
# [train] step=758/1000 | warm=0 | policy=32 | replay=23816 | world_total=11301.2924 | actor=-7.9961 | critic=1.0736 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=2114.5 | checkpoint=-
# [train] step=759/1000 | warm=0 | policy=32 | replay=23848 | world_total=11301.1327 | actor=-7.6719 | critic=1.0849 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=2121.0 | checkpoint=-
# [train] step=760/1000 | warm=0 | policy=32 | replay=23880 | world_total=11301.0463 | actor=-7.6680 | critic=1.0567 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=2128.1 | checkpoint=-
# [train] step=761/1000 | warm=0 | policy=32 | replay=23912 | world_total=11301.0149 | actor=-7.5664 | critic=1.1181 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=2134.6 | checkpoint=-
# [train] step=762/1000 | warm=0 | policy=32 | replay=23944 | world_total=11300.9827 | actor=-7.4102 | critic=1.1669 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=2141.7 | checkpoint=-
# [train] step=763/1000 | warm=0 | policy=32 | replay=23976 | world_total=11300.9133 | actor=-7.6523 | critic=1.2722 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=2148.7 | checkpoint=-
# ...
# [train] step=920/1000 | warm=0 | policy=32 | replay=29000 | world_total=11300.2419 | actor=-7.0195 | critic=1.3942 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3369.7 | checkpoint=-
# [train] step=921/1000 | warm=0 | policy=32 | replay=29032 | world_total=11300.2742 | actor=-6.6328 | critic=1.4008 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3376.3 | checkpoint=-
# [train] step=922/1000 | warm=0 | policy=32 | replay=29064 | world_total=11300.2374 | actor=-6.4023 | critic=1.4749 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3382.5 | checkpoint=-
# [train] step=923/1000 | warm=0 | policy=32 | replay=29096 | world_total=11300.2684 | actor=-6.2422 | critic=1.5751 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=3388.7 | checkpoint=-
# [train] step=924/1000 | warm=0 | policy=32 | replay=29128 | world_total=11300.2642 | actor=-6.2383 | critic=1.5230 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3395.2 | checkpoint=-
# [train] step=925/1000 | warm=0 | policy=32 | replay=29160 | world_total=11300.2417 | actor=-5.9492 | critic=1.6312 | eval_reward=-0.5284 | cycle_s=21.8 | elapsed_s=3417.0 | checkpoint=checkpoint_00925.pt
# [train] step=926/1000 | warm=0 | policy=32 | replay=29192 | world_total=11300.2240 | actor=-5.6250 | critic=1.6014 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=3424.7 | checkpoint=-
# [train] step=927/1000 | warm=0 | policy=32 | replay=29224 | world_total=11300.2555 | actor=-5.6562 | critic=1.6389 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3431.6 | checkpoint=-
# [train] step=928/1000 | warm=0 | policy=32 | replay=29256 | world_total=11300.2629 | actor=-5.4883 | critic=1.6567 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3438.2 | checkpoint=-
# [train] step=929/1000 | warm=0 | policy=32 | replay=29288 | world_total=11300.3080 | actor=-4.8594 | critic=1.8035 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=3446.1 | checkpoint=-
# [train] step=930/1000 | warm=0 | policy=32 | replay=29320 | world_total=11301.3723 | actor=-4.9648 | critic=1.5447 | eval_reward=n/a | cycle_s=12.8 | elapsed_s=3458.9 | checkpoint=-
# [train] step=931/1000 | warm=0 | policy=32 | replay=29352 | world_total=11302.4727 | actor=-3.9570 | critic=1.9651 | eval_reward=n/a | cycle_s=10.3 | elapsed_s=3469.2 | checkpoint=-
# [train] step=932/1000 | warm=0 | policy=32 | replay=29384 | world_total=11301.1886 | actor=-3.7559 | critic=1.3981 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=3477.2 | checkpoint=-
# [train] step=933/1000 | warm=0 | policy=32 | replay=29416 | world_total=11301.2510 | actor=-4.4023 | critic=1.4881 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=3484.8 | checkpoint=-
# [train] step=934/1000 | warm=0 | policy=32 | replay=29448 | world_total=11301.5355 | actor=-5.1367 | critic=1.4649 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=3492.4 | checkpoint=-
# [train] step=935/1000 | warm=0 | policy=32 | replay=29480 | world_total=11301.1257 | actor=-6.2461 | critic=1.4966 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=3499.3 | checkpoint=-
# [train] step=936/1000 | warm=0 | policy=32 | replay=29512 | world_total=11300.7784 | actor=-6.6641 | critic=1.5178 | eval_reward=n/a | cycle_s=16.7 | elapsed_s=3516.1 | checkpoint=-
# [train] step=937/1000 | warm=0 | policy=32 | replay=29544 | world_total=11300.5538 | actor=-6.3008 | critic=1.4015 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=3523.8 | checkpoint=-
# [train] step=938/1000 | warm=0 | policy=32 | replay=29576 | world_total=11300.3729 | actor=-6.1250 | critic=1.4243 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3530.4 | checkpoint=-
# [train] step=939/1000 | warm=0 | policy=32 | replay=29608 | world_total=11300.2679 | actor=-5.6875 | critic=1.4574 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=3537.2 | checkpoint=-
# [train] step=940/1000 | warm=0 | policy=32 | replay=29640 | world_total=11300.2607 | actor=-5.8945 | critic=1.5140 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=3544.8 | checkpoint=-
# [train] step=941/1000 | warm=0 | policy=32 | replay=29672 | world_total=11300.2466 | actor=-5.6484 | critic=1.4803 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=3551.8 | checkpoint=-
# [train] step=942/1000 | warm=0 | policy=32 | replay=29704 | world_total=11300.2433 | actor=-5.7461 | critic=1.5275 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3558.4 | checkpoint=-
# [train] step=943/1000 | warm=0 | policy=32 | replay=29736 | world_total=11300.1984 | actor=-5.3633 | critic=1.5177 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3564.8 | checkpoint=-
# [train] step=944/1000 | warm=0 | policy=32 | replay=29768 | world_total=11300.2103 | actor=-5.1211 | critic=1.5106 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3571.3 | checkpoint=-
# [train] step=945/1000 | warm=0 | policy=32 | replay=29800 | world_total=11300.1906 | actor=-5.1445 | critic=1.5373 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=3577.6 | checkpoint=-
# [train] step=946/1000 | warm=0 | policy=32 | replay=29832 | world_total=11300.1423 | actor=-4.7734 | critic=1.5397 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=3585.9 | checkpoint=-
# [train] step=947/1000 | warm=0 | policy=32 | replay=29864 | world_total=11300.2147 | actor=-4.3359 | critic=1.5254 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=3591.5 | checkpoint=-
# [train] step=948/1000 | warm=0 | policy=32 | replay=29896 | world_total=11300.1517 | actor=-4.2461 | critic=1.5336 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3597.9 | checkpoint=-
# [train] step=949/1000 | warm=0 | policy=32 | replay=29928 | world_total=11300.1853 | actor=-3.5391 | critic=1.4375 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3604.3 | checkpoint=-
# [train] step=950/1000 | warm=0 | policy=32 | replay=29960 | world_total=11300.1779 | actor=-3.3398 | critic=1.3455 | eval_reward=-0.5204 | cycle_s=16.2 | elapsed_s=3620.5 | checkpoint=checkpoint_00950.pt
# [train] step=951/1000 | warm=0 | policy=32 | replay=29992 | world_total=11300.1422 | actor=-3.2988 | critic=1.3521 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=3626.3 | checkpoint=-
# [train] step=952/1000 | warm=0 | policy=32 | replay=30024 | world_total=11300.1798 | actor=-2.9180 | critic=1.3088 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=3635.1 | checkpoint=-
# [train] step=953/1000 | warm=0 | policy=32 | replay=30056 | world_total=11300.1594 | actor=-2.8184 | critic=1.2953 | eval_reward=n/a | cycle_s=14.9 | elapsed_s=3650.1 | checkpoint=-
# [train] step=954/1000 | warm=0 | policy=32 | replay=30088 | world_total=11300.1741 | actor=-2.5332 | critic=1.2533 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=3655.1 | checkpoint=-
# [train] step=955/1000 | warm=0 | policy=32 | replay=30120 | world_total=11300.1744 | actor=-2.2471 | critic=1.2144 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3660.8 | checkpoint=-
# [train] step=956/1000 | warm=0 | policy=32 | replay=30152 | world_total=11300.0913 | actor=-2.3047 | critic=1.2575 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3667.3 | checkpoint=-
# [train] step=957/1000 | warm=0 | policy=32 | replay=30184 | world_total=11300.1515 | actor=-2.1191 | critic=1.2317 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3673.8 | checkpoint=-
# [train] step=958/1000 | warm=0 | policy=32 | replay=30216 | world_total=11300.1182 | actor=-2.0752 | critic=1.2266 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3680.1 | checkpoint=-
# [train] step=959/1000 | warm=0 | policy=32 | replay=30248 | world_total=11300.1760 | actor=-1.8721 | critic=1.2156 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3686.4 | checkpoint=-
# [train] step=960/1000 | warm=0 | policy=32 | replay=30280 | world_total=11300.1556 | actor=-1.6934 | critic=1.2097 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3692.8 | checkpoint=-
# [train] step=961/1000 | warm=0 | policy=32 | replay=30312 | world_total=11300.1106 | actor=-1.5361 | critic=1.1649 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3698.5 | checkpoint=-
# [train] step=962/1000 | warm=0 | policy=32 | replay=30344 | world_total=11301.3660 | actor=-1.4648 | critic=1.2278 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=3704.4 | checkpoint=-
# [train] step=963/1000 | warm=0 | policy=32 | replay=30376 | world_total=11301.7162 | actor=-1.2324 | critic=1.1469 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=3710.3 | checkpoint=-
# [train] step=964/1000 | warm=0 | policy=32 | replay=30408 | world_total=11301.2328 | actor=-1.6104 | critic=1.1916 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3716.6 | checkpoint=-
# [train] step=965/1000 | warm=0 | policy=32 | replay=30440 | world_total=11301.3003 | actor=-2.0039 | critic=1.1799 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3722.8 | checkpoint=-
# [train] step=966/1000 | warm=0 | policy=32 | replay=30472 | world_total=11301.7090 | actor=-2.9219 | critic=1.2452 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=3728.6 | checkpoint=-
# [train] step=967/1000 | warm=0 | policy=32 | replay=30504 | world_total=11303.0958 | actor=-3.6738 | critic=1.3290 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=3734.8 | checkpoint=-
# [train] step=968/1000 | warm=0 | policy=32 | replay=30536 | world_total=11304.5435 | actor=-5.2422 | critic=1.5713 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=3741.3 | checkpoint=-
# [train] step=969/1000 | warm=0 | policy=32 | replay=30568 | world_total=11303.4734 | actor=-7.6523 | critic=1.7095 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3747.4 | checkpoint=-
# [train] step=970/1000 | warm=0 | policy=32 | replay=30600 | world_total=11303.5460 | actor=-10.3984 | critic=2.1899 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3753.1 | checkpoint=-
# [train] step=971/1000 | warm=0 | policy=32 | replay=30632 | world_total=11302.9324 | actor=-11.3281 | critic=1.9557 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=3759.2 | checkpoint=-
# [train] step=972/1000 | warm=0 | policy=32 | replay=30664 | world_total=11301.4143 | actor=-13.6328 | critic=1.9078 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=3766.5 | checkpoint=-
# [train] step=973/1000 | warm=0 | policy=32 | replay=30696 | world_total=11300.8130 | actor=-15.7969 | critic=2.0136 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3773.3 | checkpoint=-
# [train] step=974/1000 | warm=0 | policy=32 | replay=30728 | world_total=11300.4215 | actor=-15.7969 | critic=1.9598 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=3779.9 | checkpoint=-
# [train] step=975/1000 | warm=0 | policy=32 | replay=30760 | world_total=11300.3035 | actor=-14.8516 | critic=1.8194 | eval_reward=-0.5279 | cycle_s=17.0 | elapsed_s=3796.8 | checkpoint=checkpoint_00975.pt
# [train] step=976/1000 | warm=0 | policy=32 | replay=30792 | world_total=11300.2010 | actor=-13.9375 | critic=1.8918 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=3805.6 | checkpoint=-
# [train] step=977/1000 | warm=0 | policy=32 | replay=30824 | world_total=11300.1045 | actor=-12.6172 | critic=1.9144 | eval_reward=n/a | cycle_s=13.1 | elapsed_s=3818.7 | checkpoint=-
# [train] step=978/1000 | warm=0 | policy=32 | replay=30856 | world_total=11300.0839 | actor=-12.2344 | critic=1.7532 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=3825.7 | checkpoint=-
# [train] step=979/1000 | warm=0 | policy=32 | replay=30888 | world_total=11300.0803 | actor=-10.7734 | critic=1.7151 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=3831.7 | checkpoint=-
# [train] step=980/1000 | warm=0 | policy=32 | replay=30920 | world_total=11300.0885 | actor=-9.7812 | critic=1.4315 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=3838.9 | checkpoint=-
# [train] step=981/1000 | warm=0 | policy=32 | replay=30952 | world_total=11300.0779 | actor=-8.6367 | critic=1.2924 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=3845.7 | checkpoint=-
# [train] step=982/1000 | warm=0 | policy=32 | replay=30984 | world_total=11300.0797 | actor=-8.3047 | critic=1.3274 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=3852.1 | checkpoint=-
# [train] step=983/1000 | warm=0 | policy=32 | replay=31016 | world_total=11300.1086 | actor=-7.8867 | critic=1.2672 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3858.8 | checkpoint=-
# [train] step=984/1000 | warm=0 | policy=32 | replay=31048 | world_total=11300.0989 | actor=-8.2305 | critic=1.3086 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=3865.6 | checkpoint=-
# [train] step=985/1000 | warm=0 | policy=32 | replay=31080 | world_total=11300.0138 | actor=-8.2969 | critic=1.3545 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=3871.5 | checkpoint=-
# [train] step=986/1000 | warm=0 | policy=32 | replay=31112 | world_total=11300.0460 | actor=-7.5977 | critic=1.4600 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3877.8 | checkpoint=-
# [train] step=987/1000 | warm=0 | policy=32 | replay=31144 | world_total=11300.0203 | actor=-7.4141 | critic=1.5185 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3884.1 | checkpoint=-
# [train] step=988/1000 | warm=0 | policy=32 | replay=31176 | world_total=11300.0983 | actor=-7.0859 | critic=1.4694 | eval_reward=n/a | cycle_s=6.7 | elapsed_s=3890.7 | checkpoint=-
# [train] step=989/1000 | warm=0 | policy=32 | replay=31208 | world_total=11300.0234 | actor=-7.2930 | critic=1.5565 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3897.0 | checkpoint=-
# [train] step=990/1000 | warm=0 | policy=32 | replay=31240 | world_total=11300.0551 | actor=-6.8906 | critic=1.7007 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3903.4 | checkpoint=-
# [train] step=991/1000 | warm=0 | policy=32 | replay=31272 | world_total=11300.0332 | actor=-6.7070 | critic=1.7290 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3909.7 | checkpoint=-
# [train] step=992/1000 | warm=0 | policy=32 | replay=31304 | world_total=11300.0100 | actor=-6.2461 | critic=1.6914 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=3916.0 | checkpoint=-
# [train] step=993/1000 | warm=0 | policy=32 | replay=31336 | world_total=11300.0325 | actor=-6.0508 | critic=1.8024 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=3921.3 | checkpoint=-
# [train] step=994/1000 | warm=0 | policy=32 | replay=31368 | world_total=11300.0081 | actor=-5.6562 | critic=1.7875 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=3926.8 | checkpoint=-
# [train] step=995/1000 | warm=0 | policy=32 | replay=31400 | world_total=11300.3900 | actor=-4.7188 | critic=2.0442 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=3935.1 | checkpoint=-
# [train] step=996/1000 | warm=0 | policy=32 | replay=31432 | world_total=11301.3220 | actor=-3.8828 | critic=1.8390 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3940.8 | checkpoint=-
# [train] step=997/1000 | warm=0 | policy=32 | replay=31464 | world_total=11300.8986 | actor=-4.3867 | critic=1.7350 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=3945.8 | checkpoint=-
# [train] step=998/1000 | warm=0 | policy=32 | replay=31496 | world_total=11301.3591 | actor=-5.5703 | critic=1.7091 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=3951.2 | checkpoint=-
# [train] step=999/1000 | warm=0 | policy=32 | replay=31528 | world_total=11300.9221 | actor=-6.5000 | critic=1.6255 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=3956.9 | checkpoint=-
# [train] step=1000/1000 | warm=0 | policy=32 | replay=31560 | world_total=11301.1632 | actor=-7.3203 | critic=1.7500 | eval_reward=-0.5194 | cycle_s=19.0 | elapsed_s=3975.9 | checkpoint=checkpoint_01000.pt
# Completed cycles: 1000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter22_low_steering_penalty/checkpoints/checkpoint_01000.pt
# Latest metrics: {'step': 1000, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 31560, 'world_model/reconstruction_loss': 11296.123291015625, 'world_model/reconstruction_mse': 0.0006846190881333314, 'world_model/observation_log_prob': -11296.123291015625, 'world_model/reward_loss': 0.9191580638289452, 'world_model/continue_loss': 2.1201318256558466e-08, 'world_model/kl_loss': 3.2706722021102905, 'world_model/kl_loss_raw': 2.728453427553177, 'world_model/overshooting_kl_loss': 1.7005048617720604, 'world_model/overshooting_feature_mse': 0.003277105890447274, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11301.163208007812, 'behavior/actor_loss': -7.3203125, 'behavior/critic_loss': 1.7500445395708084, 'behavior/imagined_reward_mean': 0.07586669921875, 'behavior/imagined_value_mean': 6.16015625, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': -0.5193676050379873, 'evaluation/mean_steps': 3.4, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter22_low_steering_penalty/checkpoints/checkpoint_01000.pt',
#  'latest_metrics': {'behavior/actor_loss': -7.3203125,
#   'behavior/critic_loss': 1.7500445395708084,
#   'behavior/imagined_reward_mean': 0.07586669921875,
#   'behavior/imagined_value_mean': 6.16015625,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': -0.5193676050379873,
#   'evaluation/mean_steps': 3.4,
#   'policy_added': 32,
#   'replay_size': 31560,
#   'step': 1000,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 2.1201318256558466e-08,
#   'world_model/kl_loss': 3.2706722021102905,
#   'world_model/kl_loss_raw': 2.728453427553177,
#   'world_model/observation_log_prob': -11296.123291015625,
#   'world_model/overshooting_feature_mse': 0.003277105890447274,
#   'world_model/overshooting_kl_loss': 1.7005048617720604,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11296.123291015625,
#   'world_model/reconstruction_mse': 0.0006846190881333314,
#   'world_model/reward_loss': 0.9191580638289452,
#   'world_model/total_loss': 11301.163208007812},
#  'latest_step': 1000}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': -0.5166618160530925,
#   'best_eval_reward_step': 425,
#   'best_imagined_reward_mean': 1.2744140625,
#   'best_imagined_reward_step': 49,
#   'best_world_model_step': 994,
#   'best_world_model_total_loss': 11300.008056640625,
#   'largest_replay_size': 31560,
#   'largest_replay_step': 1000,
#   'last_metrics': {'behavior/actor_loss': -7.3203125,
#    'behavior/critic_loss': 1.7500445395708084,
#    'behavior/imagined_reward_mean': 0.07586669921875,
#    'behavior/imagined_value_mean': 6.16015625,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': -0.5193676050379873,
#    'evaluation/mean_steps': 3.4,
#    'policy_added': 32,
#    'replay_size': 31560,
#    'step': 1000,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 2.1201318256558466e-08,
#    'world_model/kl_loss': 3.2706722021102905,
#    'world_model/kl_loss_raw': 2.728453427553177,
#    'world_model/observation_log_prob': -11296.123291015625,
#    'world_model/overshooting_feature_mse': 0.003277105890447274,
#    'world_model/overshooting_kl_loss': 1.7005048617720604,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11296.123291015625,
#    'world_model/reconstruction_mse': 0.0006846190881333314,
#    'world_model/reward_loss': 0.9191580638289452,
#    'world_model/total_loss': 11301.163208007812},
#   'last_step': 1000,
#   'num_records': 1548},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11296.123291015625',
#   'world_model/reconstruction_mse': '0.0006846190881333314',
#   'world_model/observation_log_prob': '-11296.123291015625',
#   'world_model/overshooting_kl_loss': '1.7005048617720604',
#   'world_model/overshooting_feature_mse': '0.003277105890447274',
#   'evaluation/mean_reward': '-0.5193676050379873',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=132,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=2 | reward=-0.51 | CRASH | saved iter22_low_steering_penalty_ep01.gif
# [demo] episode 2/10 | steps=4 | reward=-0.52 | CRASH | saved iter22_low_steering_penalty_ep02.gif
# [demo] episode 3/10 | steps=2 | reward=-0.51 | CRASH | saved iter22_low_steering_penalty_ep03.gif
# [demo] episode 4/10 | steps=5 | reward=-0.53 | CRASH | saved iter22_low_steering_penalty_ep04.gif
# [demo] episode 5/10 | steps=2 | reward=-0.51 | CRASH | saved iter22_low_steering_penalty_ep05.gif
# [demo] episode 6/10 | steps=5 | reward=-0.53 | CRASH | saved iter22_low_steering_penalty_ep06.gif
# [demo] episode 7/10 | steps=4 | reward=-0.52 | CRASH | saved iter22_low_steering_penalty_ep07.gif
# [demo] episode 8/10 | steps=5 | reward=-0.53 | CRASH | saved iter22_low_steering_penalty_ep08.gif
# [demo] episode 9/10 | steps=4 | reward=-0.52 | CRASH | saved iter22_low_steering_penalty_ep09.gif
# [demo] episode 10/10 | steps=5 | reward=-0.53 | CRASH | saved iter22_low_steering_penalty_ep10.gif
# [demo] done | avg_reward=-0.52 | summary=iter22_low_steering_penalty_summary.json
#
# iter22_low_steering_penalty_ep01.gif
# iter22_low_steering_penalty_ep02.gif
# iter22_low_steering_penalty_ep03.gif
# iter22_low_steering_penalty_ep04.gif
# iter22_low_steering_penalty_ep05.gif
# iter22_low_steering_penalty_ep06.gif
# iter22_low_steering_penalty_ep07.gif
# iter22_low_steering_penalty_ep08.gif
# iter22_low_steering_penalty_ep09.gif
# iter22_low_steering_penalty_ep10.gif
