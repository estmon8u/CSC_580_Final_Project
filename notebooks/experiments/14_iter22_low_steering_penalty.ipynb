# %% [markdown]
# # Tiny Dreamer Highway — Iter 22: Lower Steering Penalty
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10 + iter17 (max_episode_steps=120, batch_size=384)
# **New change:** `steering_penalty: 0.025 → 0.015`
# **Hypothesis:** Iter 17 @ 2000 became passive because steering_penalty=0.025 makes lane changes too costly relative to the overtake reward. The original 0.0075 was too low (jitter), 0.025 is too high (won't steer after extended training). 0.015 is a middle ground — still penalizes gratuitous jitter but low enough that the overtake reward can justify a lane change.

# %% [markdown]
# ## Iteration 22 — Cheaper lane changes (Phase 4, iter 17 base)
#
# Iter 17 at 2000 cycles learned to stay in one lane and never change — it crashes into the car ahead rather than steering around it. The steering_penalty=0.025 made lane changes too expensive. Reducing to 0.015 should make them affordable again while still discouraging pointless jitter.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main       -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main       -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

# --- Iter 17 Overrides ---
config.env.max_episode_steps = 120
config.training.batch_size = 384

# --- Iter 22 Override: lower steering penalty ---
config.env.reward.steering_penalty = 0.015

print('\nAll overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')
print(f'  steering_penalty = {config.env.reward.steering_penalty}  (iter 22: 0.025 -> 0.015)')
print(f'  max_episode_steps = {config.env.max_episode_steps}')
print(f'  batch_size = {config.training.batch_size}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 3,
#     "max_episode_steps": 120,
#     "lanes_count": 4,
#     "vehicles_count": 12,
#     "npc_speed_scale": 0.65,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.5,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": false,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.025,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 384,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "actor_entropy_weight": 0.0,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/notebooks/configs/training_run.yaml
# GPU: NVIDIA A100-SXM4-40GB
#
# All overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#   steering_penalty = 0.015  (iter 22: 0.025 -> 0.015)
#   max_episode_steps = 120
#   batch_size = 384

# %%
RUN_NAME = 'iter22_low_steering_penalty'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = None

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter22_low_steering_penalty
# Resume from: (fresh run — old artifacts will be cleared)
# Effective cycles: 500
# Effective policy steps: 32

# %%
print('Launching iter22 run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching iter22 run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=500 | start_step=1 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1/500 | warm=10000 | policy=32 | replay=10032 | world_total=15165.9039 | actor=-0.4675 | critic=2.6431 | eval_reward=n/a | cycle_s=418.6 | elapsed_s=418.6 | checkpoint=-
# [train] step=2/500 | warm=0 | policy=32 | replay=10064 | world_total=13397.2002 | actor=0.9072 | critic=2.1164 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=427.1 | checkpoint=-
# [train] step=3/500 | warm=0 | policy=32 | replay=10096 | world_total=12650.4950 | actor=-0.0446 | critic=1.6432 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=435.7 | checkpoint=-
# [train] step=4/500 | warm=0 | policy=32 | replay=10128 | world_total=12434.9045 | actor=-0.7241 | critic=1.9695 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=444.0 | checkpoint=-
# [train] step=5/500 | warm=0 | policy=32 | replay=10160 | world_total=12149.3956 | actor=-4.2461 | critic=9.2754 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=452.5 | checkpoint=-
# [train] step=6/500 | warm=0 | policy=32 | replay=10192 | world_total=11890.0662 | actor=-4.8164 | critic=4.8504 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=460.7 | checkpoint=-
# [train] step=7/500 | warm=0 | policy=32 | replay=10224 | world_total=11707.6350 | actor=-5.5625 | critic=3.1503 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=467.7 | checkpoint=-
# [train] step=8/500 | warm=0 | policy=32 | replay=10256 | world_total=11648.6322 | actor=-4.4258 | critic=1.4586 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=475.4 | checkpoint=-
# [train] step=9/500 | warm=0 | policy=32 | replay=10288 | world_total=11591.6639 | actor=-2.8691 | critic=2.8974 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=482.1 | checkpoint=-
# [train] step=10/500 | warm=0 | policy=32 | replay=10320 | world_total=11532.8281 | actor=-6.3281 | critic=1.6120 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=489.4 | checkpoint=-
# [train] step=11/500 | warm=0 | policy=32 | replay=10352 | world_total=11507.0270 | actor=-6.2539 | critic=1.1379 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=498.0 | checkpoint=-
# [train] step=12/500 | warm=0 | policy=32 | replay=10384 | world_total=11489.7084 | actor=-7.2227 | critic=1.4943 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=506.2 | checkpoint=-
# [train] step=13/500 | warm=0 | policy=32 | replay=10416 | world_total=11486.6410 | actor=-6.9883 | critic=1.0734 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=514.6 | checkpoint=-
# [train] step=14/500 | warm=0 | policy=32 | replay=10448 | world_total=11480.1259 | actor=-6.7500 | critic=1.1354 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=523.0 | checkpoint=-
# [train] step=15/500 | warm=0 | policy=32 | replay=10480 | world_total=11473.8479 | actor=-7.4531 | critic=1.2039 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=531.7 | checkpoint=-
# [train] step=16/500 | warm=0 | policy=32 | replay=10512 | world_total=11467.6056 | actor=-7.6680 | critic=1.0467 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=540.9 | checkpoint=-
# [train] step=17/500 | warm=0 | policy=32 | replay=10544 | world_total=11463.8303 | actor=-8.2656 | critic=1.0245 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=550.2 | checkpoint=-
# [train] step=18/500 | warm=0 | policy=32 | replay=10576 | world_total=11459.6620 | actor=-8.7969 | critic=1.2043 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=559.5 | checkpoint=-
# [train] step=19/500 | warm=0 | policy=32 | replay=10608 | world_total=11456.9592 | actor=-9.0781 | critic=0.9991 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=568.5 | checkpoint=-
# [train] step=20/500 | warm=0 | policy=32 | replay=10640 | world_total=11456.1089 | actor=-8.8594 | critic=1.0283 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=577.0 | checkpoint=-
# [train] step=21/500 | warm=0 | policy=32 | replay=10672 | world_total=11454.2614 | actor=-8.7656 | critic=1.0302 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=586.9 | checkpoint=-
# [train] step=22/500 | warm=0 | policy=32 | replay=10704 | world_total=11452.7621 | actor=-9.2109 | critic=1.0752 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=595.6 | checkpoint=-
# [train] step=23/500 | warm=0 | policy=32 | replay=10736 | world_total=11451.4862 | actor=-10.0859 | critic=1.2211 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=604.4 | checkpoint=-
# [train] step=24/500 | warm=0 | policy=32 | replay=10768 | world_total=11450.0284 | actor=-10.4453 | critic=1.0404 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=613.0 | checkpoint=-
# [train] step=25/500 | warm=0 | policy=32 | replay=10800 | world_total=11449.8312 | actor=-11.3438 | critic=1.0893 | eval_reward=-0.5211 | cycle_s=16.4 | elapsed_s=629.4 | checkpoint=checkpoint_00025.pt
# [train] step=26/500 | warm=0 | policy=32 | replay=10832 | world_total=11449.2788 | actor=-11.0078 | critic=1.0760 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=638.9 | checkpoint=-
# [train] step=27/500 | warm=0 | policy=32 | replay=10864 | world_total=11449.0647 | actor=-11.1016 | critic=1.0645 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=647.9 | checkpoint=-
# [train] step=28/500 | warm=0 | policy=32 | replay=10896 | world_total=11449.9270 | actor=-9.9609 | critic=1.3198 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=657.2 | checkpoint=-
# [train] step=29/500 | warm=0 | policy=32 | replay=10928 | world_total=11448.5597 | actor=-9.8750 | critic=1.1576 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=665.9 | checkpoint=-
# [train] step=30/500 | warm=0 | policy=32 | replay=10960 | world_total=11449.3182 | actor=-8.7812 | critic=1.1917 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=674.7 | checkpoint=-
# [train] step=31/500 | warm=0 | policy=32 | replay=10992 | world_total=11449.1033 | actor=-9.0547 | critic=1.1397 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=683.6 | checkpoint=-
# [train] step=32/500 | warm=0 | policy=32 | replay=11024 | world_total=11447.7402 | actor=-8.5000 | critic=1.1340 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=692.7 | checkpoint=-
# [train] step=33/500 | warm=0 | policy=32 | replay=11056 | world_total=11447.0911 | actor=-8.9922 | critic=1.1529 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=701.0 | checkpoint=-
# [train] step=34/500 | warm=0 | policy=32 | replay=11088 | world_total=11446.6218 | actor=-9.0703 | critic=1.1563 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=708.6 | checkpoint=-
# [train] step=35/500 | warm=0 | policy=32 | replay=11120 | world_total=11446.2153 | actor=-9.7500 | critic=1.2754 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=715.8 | checkpoint=-
# [train] step=36/500 | warm=0 | policy=32 | replay=11152 | world_total=11445.1967 | actor=-9.9688 | critic=1.2185 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=724.1 | checkpoint=-
# [train] step=37/500 | warm=0 | policy=32 | replay=11184 | world_total=11444.0355 | actor=-10.1094 | critic=1.1617 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=732.9 | checkpoint=-
# [train] step=38/500 | warm=0 | policy=32 | replay=11216 | world_total=11442.4688 | actor=-10.4297 | critic=1.2057 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=741.6 | checkpoint=-
# [train] step=39/500 | warm=0 | policy=32 | replay=11248 | world_total=11441.8612 | actor=-10.4609 | critic=1.2580 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=750.2 | checkpoint=-
# [train] step=40/500 | warm=0 | policy=32 | replay=11280 | world_total=11439.9001 | actor=-10.6328 | critic=1.3631 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=759.3 | checkpoint=-
# [train] step=41/500 | warm=0 | policy=32 | replay=11312 | world_total=11438.8521 | actor=-10.2656 | critic=1.3360 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=767.8 | checkpoint=-
# [train] step=42/500 | warm=0 | policy=32 | replay=11344 | world_total=11437.1614 | actor=-9.8906 | critic=1.3884 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=775.8 | checkpoint=-
# [train] step=43/500 | warm=0 | policy=32 | replay=11376 | world_total=11435.6279 | actor=-8.6562 | critic=1.8185 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=784.5 | checkpoint=-
# [train] step=44/500 | warm=0 | policy=32 | replay=11408 | world_total=11433.9996 | actor=-7.8242 | critic=1.3551 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=792.7 | checkpoint=-
# [train] step=45/500 | warm=0 | policy=32 | replay=11440 | world_total=11432.6735 | actor=-7.3125 | critic=1.2577 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=801.5 | checkpoint=-
# [train] step=46/500 | warm=0 | policy=32 | replay=11472 | world_total=11432.0780 | actor=-7.4297 | critic=1.3584 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=810.5 | checkpoint=-
# [train] step=47/500 | warm=0 | policy=32 | replay=11504 | world_total=11430.8552 | actor=-7.8516 | critic=1.3591 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=819.7 | checkpoint=-
# [train] step=48/500 | warm=0 | policy=32 | replay=11536 | world_total=11430.6559 | actor=-7.2578 | critic=1.5183 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=828.1 | checkpoint=-
# [train] step=49/500 | warm=0 | policy=32 | replay=11568 | world_total=11429.3955 | actor=-7.6016 | critic=1.3392 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=836.3 | checkpoint=-
# [train] step=50/500 | warm=0 | policy=32 | replay=11600 | world_total=11428.1476 | actor=-7.6484 | critic=1.2750 | eval_reward=3.6737 | cycle_s=16.8 | elapsed_s=853.1 | checkpoint=checkpoint_00050.pt
# [train] step=51/500 | warm=0 | policy=32 | replay=11632 | world_total=11426.8552 | actor=-7.7852 | critic=1.2608 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=861.5 | checkpoint=-
# [train] step=52/500 | warm=0 | policy=32 | replay=11664 | world_total=11425.5181 | actor=-7.3594 | critic=1.4716 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=870.0 | checkpoint=-
# [train] step=53/500 | warm=0 | policy=32 | replay=11696 | world_total=11424.5479 | actor=-7.3633 | critic=1.3486 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=878.2 | checkpoint=-
# [train] step=54/500 | warm=0 | policy=32 | replay=11728 | world_total=11423.5001 | actor=-6.7383 | critic=1.5555 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=886.3 | checkpoint=-
# [train] step=55/500 | warm=0 | policy=32 | replay=11760 | world_total=11422.7996 | actor=-5.9180 | critic=1.6584 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=893.7 | checkpoint=-
# [train] step=56/500 | warm=0 | policy=32 | replay=11792 | world_total=11421.1180 | actor=-6.1523 | critic=1.5291 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=901.0 | checkpoint=-
# [train] step=57/500 | warm=0 | policy=32 | replay=11824 | world_total=11419.3969 | actor=-5.2773 | critic=1.6766 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=908.9 | checkpoint=-
# [train] step=58/500 | warm=0 | policy=32 | replay=11856 | world_total=11417.8243 | actor=-5.2422 | critic=1.4824 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=917.1 | checkpoint=-
# [train] step=59/500 | warm=0 | policy=32 | replay=11888 | world_total=11415.5804 | actor=-5.2773 | critic=1.7372 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=925.4 | checkpoint=-
# [train] step=60/500 | warm=0 | policy=32 | replay=11920 | world_total=11413.8186 | actor=-6.1055 | critic=2.0274 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=934.6 | checkpoint=-
# [train] step=61/500 | warm=0 | policy=32 | replay=11952 | world_total=11411.9857 | actor=-6.0312 | critic=2.3517 | eval_reward=n/a | cycle_s=9.1 | elapsed_s=943.7 | checkpoint=-
# [train] step=62/500 | warm=0 | policy=32 | replay=11984 | world_total=11410.2085 | actor=-7.1562 | critic=2.2537 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=953.6 | checkpoint=-
# [train] step=63/500 | warm=0 | policy=32 | replay=12016 | world_total=11408.2448 | actor=-7.8828 | critic=2.8343 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=962.6 | checkpoint=-
# [train] step=64/500 | warm=0 | policy=32 | replay=12048 | world_total=11406.3022 | actor=-6.9727 | critic=4.0928 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=971.8 | checkpoint=-
# [train] step=65/500 | warm=0 | policy=32 | replay=12080 | world_total=11404.6555 | actor=-6.5703 | critic=3.0618 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=980.7 | checkpoint=-
# [train] step=66/500 | warm=0 | policy=32 | replay=12112 | world_total=11402.7632 | actor=-5.6953 | critic=3.2691 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=989.1 | checkpoint=-
# [train] step=67/500 | warm=0 | policy=32 | replay=12144 | world_total=11401.1600 | actor=-5.0508 | critic=3.2249 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=997.7 | checkpoint=-
# [train] step=68/500 | warm=0 | policy=32 | replay=12176 | world_total=11399.3365 | actor=-6.7578 | critic=3.9569 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1006.1 | checkpoint=-
# [train] step=69/500 | warm=0 | policy=32 | replay=12208 | world_total=11397.9326 | actor=-5.3672 | critic=5.0418 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=1014.9 | checkpoint=-
# [train] step=70/500 | warm=0 | policy=32 | replay=12240 | world_total=11396.1906 | actor=-5.1836 | critic=4.0579 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1023.6 | checkpoint=-
# [train] step=71/500 | warm=0 | policy=32 | replay=12272 | world_total=11394.3774 | actor=-5.7031 | critic=3.1762 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1032.1 | checkpoint=-
# [train] step=72/500 | warm=0 | policy=32 | replay=12304 | world_total=11392.7759 | actor=-3.1387 | critic=3.1909 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1039.9 | checkpoint=-
# [train] step=73/500 | warm=0 | policy=32 | replay=12336 | world_total=11391.3910 | actor=-3.3086 | critic=2.2201 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1047.7 | checkpoint=-
# [train] step=74/500 | warm=0 | policy=32 | replay=12368 | world_total=11389.5781 | actor=-3.5684 | critic=1.9640 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1055.7 | checkpoint=-
# [train] step=75/500 | warm=0 | policy=32 | replay=12400 | world_total=11387.9265 | actor=-4.1562 | critic=2.0231 | eval_reward=1.3072 | cycle_s=17.1 | elapsed_s=1072.8 | checkpoint=checkpoint_00075.pt
# [train] step=76/500 | warm=0 | policy=32 | replay=12432 | world_total=11385.9312 | actor=-4.4023 | critic=2.0657 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1080.7 | checkpoint=-
# [train] step=77/500 | warm=0 | policy=32 | replay=12464 | world_total=11384.4464 | actor=-5.4336 | critic=2.1548 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1088.5 | checkpoint=-
# [train] step=78/500 | warm=0 | policy=32 | replay=12496 | world_total=11383.8291 | actor=-5.9023 | critic=2.3334 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1096.0 | checkpoint=-
# [train] step=79/500 | warm=0 | policy=32 | replay=12528 | world_total=11382.7531 | actor=-6.1836 | critic=2.4422 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1103.8 | checkpoint=-
# [train] step=80/500 | warm=0 | policy=32 | replay=12560 | world_total=11380.9775 | actor=-7.4414 | critic=2.7436 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1112.8 | checkpoint=-
# [train] step=81/500 | warm=0 | policy=32 | replay=12592 | world_total=11379.3069 | actor=-8.8906 | critic=3.2665 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1121.2 | checkpoint=-
# [train] step=82/500 | warm=0 | policy=32 | replay=12624 | world_total=11378.2134 | actor=-8.8984 | critic=3.5599 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1129.1 | checkpoint=-
# [train] step=83/500 | warm=0 | policy=32 | replay=12656 | world_total=11376.9830 | actor=-10.2891 | critic=3.8366 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1136.2 | checkpoint=-
# [train] step=84/500 | warm=0 | policy=32 | replay=12688 | world_total=11375.3568 | actor=-10.2734 | critic=3.0723 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1144.5 | checkpoint=-
# [train] step=85/500 | warm=0 | policy=32 | replay=12720 | world_total=11373.9236 | actor=-11.8984 | critic=3.4635 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1151.5 | checkpoint=-
# [train] step=86/500 | warm=0 | policy=32 | replay=12752 | world_total=11372.9930 | actor=-11.1875 | critic=4.5630 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1158.7 | checkpoint=-
# [train] step=87/500 | warm=0 | policy=32 | replay=12784 | world_total=11371.2585 | actor=-9.9297 | critic=5.3732 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=1167.4 | checkpoint=-
# [train] step=88/500 | warm=0 | policy=32 | replay=12816 | world_total=11370.3733 | actor=-9.8359 | critic=3.6867 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=1176.3 | checkpoint=-
# [train] step=89/500 | warm=0 | policy=32 | replay=12848 | world_total=11369.3126 | actor=-10.2656 | critic=3.3291 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1184.6 | checkpoint=-
# [train] step=90/500 | warm=0 | policy=32 | replay=12880 | world_total=11367.6127 | actor=-10.7656 | critic=3.5018 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1193.2 | checkpoint=-
# [train] step=91/500 | warm=0 | policy=32 | replay=12912 | world_total=11366.1135 | actor=-11.6484 | critic=4.0442 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1201.0 | checkpoint=-
# [train] step=92/500 | warm=0 | policy=32 | replay=12944 | world_total=11364.7430 | actor=-12.5000 | critic=3.8119 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1209.2 | checkpoint=-
# [train] step=93/500 | warm=0 | policy=32 | replay=12976 | world_total=11364.2220 | actor=-14.0312 | critic=3.5904 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1217.7 | checkpoint=-
# [train] step=94/500 | warm=0 | policy=32 | replay=13008 | world_total=11362.1171 | actor=-14.4688 | critic=4.5121 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1226.3 | checkpoint=-
# [train] step=95/500 | warm=0 | policy=32 | replay=13040 | world_total=11361.0286 | actor=-15.4922 | critic=3.8023 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=1235.0 | checkpoint=-
# [train] step=96/500 | warm=0 | policy=32 | replay=13072 | world_total=11359.5018 | actor=-16.0625 | critic=3.9082 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=1243.5 | checkpoint=-
# [train] step=97/500 | warm=0 | policy=32 | replay=13104 | world_total=11358.1156 | actor=-17.7344 | critic=3.3666 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1251.8 | checkpoint=-
# [train] step=98/500 | warm=0 | policy=32 | replay=13136 | world_total=11356.3458 | actor=-19.1250 | critic=4.3017 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1260.0 | checkpoint=-
# [train] step=99/500 | warm=0 | policy=32 | replay=13168 | world_total=11355.2738 | actor=-20.1875 | critic=4.3055 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1268.3 | checkpoint=-
# [train] step=100/500 | warm=0 | policy=32 | replay=13200 | world_total=11353.6316 | actor=-18.7969 | critic=6.1482 | eval_reward=10.1176 | cycle_s=20.1 | elapsed_s=1288.5 | checkpoint=checkpoint_00100.pt
# [train] step=101/500 | warm=0 | policy=32 | replay=13232 | world_total=11352.0927 | actor=-17.2344 | critic=4.7151 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1296.3 | checkpoint=-
# [train] step=102/500 | warm=0 | policy=32 | replay=13264 | world_total=11350.8218 | actor=-16.4062 | critic=3.7221 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1303.3 | checkpoint=-
# [train] step=103/500 | warm=0 | policy=32 | replay=13296 | world_total=11349.9097 | actor=-16.8125 | critic=3.1193 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1311.3 | checkpoint=-
# [train] step=104/500 | warm=0 | policy=32 | replay=13328 | world_total=11348.7928 | actor=-18.5156 | critic=3.8663 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1319.0 | checkpoint=-
# [train] step=105/500 | warm=0 | policy=32 | replay=13360 | world_total=11348.4987 | actor=-21.2031 | critic=3.8542 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1326.1 | checkpoint=-
# [train] step=106/500 | warm=0 | policy=32 | replay=13392 | world_total=11347.4659 | actor=-22.9375 | critic=5.0868 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1333.3 | checkpoint=-
# [train] step=107/500 | warm=0 | policy=32 | replay=13424 | world_total=11347.1530 | actor=-25.2969 | critic=4.6122 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1340.3 | checkpoint=-
# [train] step=108/500 | warm=0 | policy=32 | replay=13456 | world_total=11346.4115 | actor=-24.7500 | critic=7.5334 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1348.0 | checkpoint=-
# [train] step=109/500 | warm=0 | policy=32 | replay=13488 | world_total=11345.6421 | actor=-23.5469 | critic=5.7353 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1356.2 | checkpoint=-
# [train] step=110/500 | warm=0 | policy=32 | replay=13520 | world_total=11345.0376 | actor=-21.7188 | critic=6.1849 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=1363.0 | checkpoint=-
# [train] step=111/500 | warm=0 | policy=32 | replay=13552 | world_total=11344.7631 | actor=-21.9844 | critic=4.9871 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1369.9 | checkpoint=-
# [train] step=112/500 | warm=0 | policy=32 | replay=13584 | world_total=11344.0962 | actor=-23.4531 | critic=5.3179 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1377.5 | checkpoint=-
# [train] step=113/500 | warm=0 | policy=32 | replay=13616 | world_total=11343.6277 | actor=-25.6094 | critic=5.1357 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1385.1 | checkpoint=-
# [train] step=114/500 | warm=0 | policy=32 | replay=13648 | world_total=11343.7579 | actor=-24.8594 | critic=9.0542 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1392.7 | checkpoint=-
# [train] step=115/500 | warm=0 | policy=32 | replay=13680 | world_total=11343.4473 | actor=-21.5156 | critic=9.2512 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1400.3 | checkpoint=-
# [train] step=116/500 | warm=0 | policy=32 | replay=13712 | world_total=11343.2899 | actor=-21.6094 | critic=6.0523 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1407.5 | checkpoint=-
# [train] step=117/500 | warm=0 | policy=32 | replay=13744 | world_total=11342.3727 | actor=-20.1875 | critic=6.2873 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1415.2 | checkpoint=-
# [train] step=118/500 | warm=0 | policy=32 | replay=13776 | world_total=11342.0074 | actor=-22.6719 | critic=6.6430 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1422.3 | checkpoint=-
# [train] step=119/500 | warm=0 | policy=32 | replay=13808 | world_total=11341.6030 | actor=-23.1250 | critic=7.5812 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1430.2 | checkpoint=-
# [train] step=120/500 | warm=0 | policy=32 | replay=13840 | world_total=11341.0135 | actor=-23.6406 | critic=7.3292 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1438.2 | checkpoint=-
# [train] step=121/500 | warm=0 | policy=32 | replay=13872 | world_total=11341.0427 | actor=-24.2031 | critic=6.7163 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=1447.0 | checkpoint=-
# [train] step=122/500 | warm=0 | policy=32 | replay=13904 | world_total=11340.5811 | actor=-23.5781 | critic=7.4038 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1455.3 | checkpoint=-
# [train] step=123/500 | warm=0 | policy=32 | replay=13936 | world_total=11340.1726 | actor=-24.5625 | critic=7.0374 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1463.1 | checkpoint=-
# [train] step=124/500 | warm=0 | policy=32 | replay=13968 | world_total=11339.8419 | actor=-24.7344 | critic=7.1151 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1471.0 | checkpoint=-
# [train] step=125/500 | warm=0 | policy=32 | replay=14000 | world_total=11339.7231 | actor=-24.5312 | critic=7.8116 | eval_reward=4.3200 | cycle_s=18.6 | elapsed_s=1489.6 | checkpoint=checkpoint_00125.pt
# [train] step=126/500 | warm=0 | policy=32 | replay=14032 | world_total=11339.4922 | actor=-24.5781 | critic=7.6122 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1496.9 | checkpoint=-
# [train] step=127/500 | warm=0 | policy=32 | replay=14064 | world_total=11339.2417 | actor=-25.5000 | critic=5.8241 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1504.1 | checkpoint=-
# [train] step=128/500 | warm=0 | policy=32 | replay=14096 | world_total=11338.7852 | actor=-27.1875 | critic=5.9597 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1511.7 | checkpoint=-
# [train] step=129/500 | warm=0 | policy=32 | replay=14128 | world_total=11338.5179 | actor=-28.6094 | critic=7.7344 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1520.0 | checkpoint=-
# [train] step=130/500 | warm=0 | policy=32 | replay=14160 | world_total=11338.1580 | actor=-28.5000 | critic=10.1670 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1527.9 | checkpoint=-
# [train] step=131/500 | warm=0 | policy=32 | replay=14192 | world_total=11337.9581 | actor=-25.8750 | critic=10.9703 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1535.8 | checkpoint=-
# [train] step=132/500 | warm=0 | policy=32 | replay=14224 | world_total=11337.7056 | actor=-23.9219 | critic=7.6131 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=1542.8 | checkpoint=-
# [train] step=133/500 | warm=0 | policy=32 | replay=14256 | world_total=11337.3101 | actor=-22.9844 | critic=7.9200 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1550.7 | checkpoint=-
# [train] step=134/500 | warm=0 | policy=32 | replay=14288 | world_total=11337.5308 | actor=-24.5938 | critic=7.9980 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1558.3 | checkpoint=-
# [train] step=135/500 | warm=0 | policy=32 | replay=14320 | world_total=11337.4236 | actor=-24.1719 | critic=10.8682 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1566.6 | checkpoint=-
# [train] step=136/500 | warm=0 | policy=32 | replay=14352 | world_total=11336.7168 | actor=-23.8125 | critic=11.1280 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1574.2 | checkpoint=-
# [train] step=137/500 | warm=0 | policy=32 | replay=14384 | world_total=11336.5212 | actor=-23.5625 | critic=8.0624 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1581.1 | checkpoint=-
# [train] step=138/500 | warm=0 | policy=32 | replay=14416 | world_total=11336.3607 | actor=-22.0938 | critic=9.2320 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1588.0 | checkpoint=-
# [train] step=139/500 | warm=0 | policy=32 | replay=14448 | world_total=11336.1460 | actor=-24.2500 | critic=7.9493 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1595.5 | checkpoint=-
# [train] step=140/500 | warm=0 | policy=32 | replay=14480 | world_total=11336.0679 | actor=-27.1875 | critic=7.5534 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1603.3 | checkpoint=-
# [train] step=141/500 | warm=0 | policy=32 | replay=14512 | world_total=11335.7944 | actor=-28.9375 | critic=10.3439 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=1610.6 | checkpoint=-
# [train] step=142/500 | warm=0 | policy=32 | replay=14544 | world_total=11335.6102 | actor=-29.3438 | critic=9.3543 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1618.2 | checkpoint=-
# [train] step=143/500 | warm=0 | policy=32 | replay=14576 | world_total=11335.4446 | actor=-28.6719 | critic=9.1014 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1625.3 | checkpoint=-
# [train] step=144/500 | warm=0 | policy=32 | replay=14608 | world_total=11335.2629 | actor=-26.3906 | critic=10.8693 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1632.7 | checkpoint=-
# [train] step=145/500 | warm=0 | policy=32 | replay=14640 | world_total=11334.9948 | actor=-24.1406 | critic=10.2466 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1640.7 | checkpoint=-
# [train] step=146/500 | warm=0 | policy=32 | replay=14672 | world_total=11334.8488 | actor=-22.0312 | critic=9.5953 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1648.5 | checkpoint=-
# [train] step=147/500 | warm=0 | policy=32 | replay=14704 | world_total=11334.7777 | actor=-20.7188 | critic=9.2843 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1656.0 | checkpoint=-
# [train] step=148/500 | warm=0 | policy=32 | replay=14736 | world_total=11334.7510 | actor=-21.4688 | critic=9.3448 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1663.7 | checkpoint=-
# [train] step=149/500 | warm=0 | policy=32 | replay=14768 | world_total=11334.8551 | actor=-23.0625 | critic=7.4641 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=1671.7 | checkpoint=-
# [train] step=150/500 | warm=0 | policy=32 | replay=14800 | world_total=11334.9855 | actor=-24.9375 | critic=9.3572 | eval_reward=7.1938 | cycle_s=19.1 | elapsed_s=1690.8 | checkpoint=checkpoint_00150.pt
# [train] step=151/500 | warm=0 | policy=32 | replay=14832 | world_total=11334.8547 | actor=-25.6719 | critic=10.9350 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1698.8 | checkpoint=-
# [train] step=152/500 | warm=0 | policy=32 | replay=14864 | world_total=11334.8361 | actor=-22.3906 | critic=15.1997 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1706.2 | checkpoint=-
# [train] step=153/500 | warm=0 | policy=32 | replay=14896 | world_total=11334.7786 | actor=-21.1875 | critic=9.7967 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1713.3 | checkpoint=-
# [train] step=154/500 | warm=0 | policy=32 | replay=14928 | world_total=11334.6909 | actor=-20.9531 | critic=9.7935 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1721.6 | checkpoint=-
# [train] step=155/500 | warm=0 | policy=32 | replay=14960 | world_total=11334.2552 | actor=-22.4844 | critic=7.5556 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1729.2 | checkpoint=-
# [train] step=156/500 | warm=0 | policy=32 | replay=14992 | world_total=11334.1586 | actor=-23.6250 | critic=8.5464 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1737.0 | checkpoint=-
# [train] step=157/500 | warm=0 | policy=32 | replay=15024 | world_total=11334.0411 | actor=-25.1406 | critic=8.8512 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1744.5 | checkpoint=-
# [train] step=158/500 | warm=0 | policy=32 | replay=15056 | world_total=11333.9723 | actor=-23.1562 | critic=15.5804 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1751.4 | checkpoint=-
# [train] step=159/500 | warm=0 | policy=32 | replay=15088 | world_total=11333.7123 | actor=-21.8125 | critic=11.4878 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1759.0 | checkpoint=-
# [train] step=160/500 | warm=0 | policy=32 | replay=15120 | world_total=11333.2438 | actor=-20.9062 | critic=9.1511 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1766.5 | checkpoint=-
# [train] step=161/500 | warm=0 | policy=32 | replay=15152 | world_total=11332.9628 | actor=-20.6250 | critic=8.6229 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=1772.9 | checkpoint=-
# [train] step=162/500 | warm=0 | policy=32 | replay=15184 | world_total=11332.9050 | actor=-21.9688 | critic=8.3104 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1780.1 | checkpoint=-
# [train] step=163/500 | warm=0 | policy=32 | replay=15216 | world_total=11332.6201 | actor=-21.5156 | critic=11.7633 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=1786.6 | checkpoint=-
# [train] step=164/500 | warm=0 | policy=32 | replay=15248 | world_total=11332.5265 | actor=-22.3906 | critic=8.9411 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1794.0 | checkpoint=-
# [train] step=165/500 | warm=0 | policy=32 | replay=15280 | world_total=11332.3872 | actor=-23.1875 | critic=8.6495 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1801.9 | checkpoint=-
# [train] step=166/500 | warm=0 | policy=32 | replay=15312 | world_total=11332.4661 | actor=-23.9219 | critic=8.8402 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1808.9 | checkpoint=-
# [train] step=167/500 | warm=0 | policy=32 | replay=15344 | world_total=11332.3335 | actor=-25.4844 | critic=9.1053 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1816.4 | checkpoint=-
# [train] step=168/500 | warm=0 | policy=32 | replay=15376 | world_total=11332.1637 | actor=-27.2500 | critic=9.8303 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1824.0 | checkpoint=-
# [train] step=169/500 | warm=0 | policy=32 | replay=15408 | world_total=11332.0016 | actor=-27.4688 | critic=12.2843 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1831.6 | checkpoint=-
# [train] step=170/500 | warm=0 | policy=32 | replay=15440 | world_total=11331.8147 | actor=-27.1719 | critic=10.7779 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1840.0 | checkpoint=-
# [train] step=171/500 | warm=0 | policy=32 | replay=15472 | world_total=11331.7446 | actor=-27.4375 | critic=9.2142 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1847.9 | checkpoint=-
# [train] step=172/500 | warm=0 | policy=32 | replay=15504 | world_total=11331.7810 | actor=-23.2344 | critic=17.7539 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=1856.1 | checkpoint=-
# [train] step=173/500 | warm=0 | policy=32 | replay=15536 | world_total=11331.6516 | actor=-22.6562 | critic=9.8534 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=1863.9 | checkpoint=-
# [train] step=174/500 | warm=0 | policy=32 | replay=15568 | world_total=11331.5377 | actor=-21.8594 | critic=8.8649 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=1872.3 | checkpoint=-
# [train] step=175/500 | warm=0 | policy=32 | replay=15600 | world_total=11331.3990 | actor=-22.7188 | critic=8.2888 | eval_reward=10.7602 | cycle_s=19.5 | elapsed_s=1891.8 | checkpoint=checkpoint_00175.pt
# [train] step=176/500 | warm=0 | policy=32 | replay=15632 | world_total=11331.2534 | actor=-24.0000 | critic=9.1855 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1900.1 | checkpoint=-
# [train] step=177/500 | warm=0 | policy=32 | replay=15664 | world_total=11331.2285 | actor=-25.7344 | critic=9.0960 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1908.1 | checkpoint=-
# [train] step=178/500 | warm=0 | policy=32 | replay=15696 | world_total=11331.0498 | actor=-25.8594 | critic=12.2980 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1915.5 | checkpoint=-
# [train] step=179/500 | warm=0 | policy=32 | replay=15728 | world_total=11330.9396 | actor=-24.7188 | critic=14.3796 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1922.6 | checkpoint=-
# [train] step=180/500 | warm=0 | policy=32 | replay=15760 | world_total=11330.9541 | actor=-24.8438 | critic=9.4761 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=1930.1 | checkpoint=-
# [train] step=181/500 | warm=0 | policy=32 | replay=15792 | world_total=11331.0038 | actor=-25.6094 | critic=8.3455 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1937.6 | checkpoint=-
# [train] step=182/500 | warm=0 | policy=32 | replay=15824 | world_total=11330.7350 | actor=-26.5156 | critic=8.5067 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=1945.1 | checkpoint=-
# [train] step=183/500 | warm=0 | policy=32 | replay=15856 | world_total=11330.7524 | actor=-26.3125 | critic=12.4367 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=1952.8 | checkpoint=-
# [train] step=184/500 | warm=0 | policy=32 | replay=15888 | world_total=11330.4420 | actor=-25.3906 | critic=12.0915 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1960.4 | checkpoint=-
# [train] step=185/500 | warm=0 | policy=32 | replay=15920 | world_total=11330.4720 | actor=-23.6094 | critic=11.3364 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=1968.0 | checkpoint=-
# [train] step=186/500 | warm=0 | policy=32 | replay=15952 | world_total=11330.2869 | actor=-21.5781 | critic=11.7419 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=1976.3 | checkpoint=-
# [train] step=187/500 | warm=0 | policy=32 | replay=15984 | world_total=11330.3567 | actor=-20.6250 | critic=9.2794 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=1984.2 | checkpoint=-
# [train] step=188/500 | warm=0 | policy=32 | replay=16016 | world_total=11330.1844 | actor=-19.7969 | critic=9.8668 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=1991.4 | checkpoint=-
# [train] step=189/500 | warm=0 | policy=32 | replay=16048 | world_total=11330.0746 | actor=-20.9219 | critic=8.7275 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1997.4 | checkpoint=-
# [train] step=190/500 | warm=0 | policy=32 | replay=16080 | world_total=11329.9974 | actor=-22.0938 | critic=9.6263 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=2004.0 | checkpoint=-
# [train] step=191/500 | warm=0 | policy=32 | replay=16112 | world_total=11330.0436 | actor=-21.5156 | critic=12.5612 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2011.3 | checkpoint=-
# [train] step=192/500 | warm=0 | policy=32 | replay=16144 | world_total=11330.0536 | actor=-22.9531 | critic=9.5686 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2019.2 | checkpoint=-
# [train] step=193/500 | warm=0 | policy=32 | replay=16176 | world_total=11330.0208 | actor=-24.4688 | critic=8.9772 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=2028.0 | checkpoint=-
# [train] step=194/500 | warm=0 | policy=32 | replay=16208 | world_total=11329.7800 | actor=-25.5312 | critic=10.7123 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2036.6 | checkpoint=-
# [train] step=195/500 | warm=0 | policy=32 | replay=16240 | world_total=11329.7084 | actor=-22.7188 | critic=20.1406 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2045.2 | checkpoint=-
# [train] step=196/500 | warm=0 | policy=32 | replay=16272 | world_total=11329.7178 | actor=-23.7812 | critic=8.8979 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2053.2 | checkpoint=-
# [train] step=197/500 | warm=0 | policy=32 | replay=16304 | world_total=11330.0865 | actor=-22.2812 | critic=7.7721 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2061.7 | checkpoint=-
# [train] step=198/500 | warm=0 | policy=32 | replay=16336 | world_total=11330.3315 | actor=-22.5469 | critic=9.6917 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=2070.3 | checkpoint=-
# [train] step=199/500 | warm=0 | policy=32 | replay=16368 | world_total=11329.8865 | actor=-23.1406 | critic=8.9885 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2078.6 | checkpoint=-
# [train] step=200/500 | warm=0 | policy=32 | replay=16400 | world_total=11329.6268 | actor=-24.4375 | critic=8.3937 | eval_reward=3.2728 | cycle_s=18.9 | elapsed_s=2097.5 | checkpoint=checkpoint_00200.pt
# [train] step=201/500 | warm=0 | policy=32 | replay=16432 | world_total=11329.3636 | actor=-24.1250 | critic=10.3286 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=2104.9 | checkpoint=-
# [train] step=202/500 | warm=0 | policy=32 | replay=16464 | world_total=11329.4274 | actor=-23.9844 | critic=12.3094 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2113.2 | checkpoint=-
# [train] step=203/500 | warm=0 | policy=32 | replay=16496 | world_total=11329.3644 | actor=-23.9219 | critic=9.3584 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2121.2 | checkpoint=-
# [train] step=204/500 | warm=0 | policy=32 | replay=16528 | world_total=11329.2690 | actor=-22.7969 | critic=11.0288 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2129.3 | checkpoint=-
# [train] step=205/500 | warm=0 | policy=32 | replay=16560 | world_total=11329.1935 | actor=-22.9531 | critic=9.4130 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2137.6 | checkpoint=-
# [train] step=206/500 | warm=0 | policy=32 | replay=16592 | world_total=11329.0531 | actor=-23.6875 | critic=8.4328 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=2146.8 | checkpoint=-
# [train] step=207/500 | warm=0 | policy=32 | replay=16624 | world_total=11328.9894 | actor=-26.5938 | critic=9.2529 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2155.7 | checkpoint=-
# [train] step=208/500 | warm=0 | policy=32 | replay=16656 | world_total=11328.7960 | actor=-28.8906 | critic=8.1529 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2163.5 | checkpoint=-
# [train] step=209/500 | warm=0 | policy=32 | replay=16688 | world_total=11328.8502 | actor=-33.5156 | critic=8.8202 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2172.1 | checkpoint=-
# [train] step=210/500 | warm=0 | policy=32 | replay=16720 | world_total=11328.9414 | actor=-37.5625 | critic=8.0481 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2180.0 | checkpoint=-
# [train] step=211/500 | warm=0 | policy=32 | replay=16752 | world_total=11328.8903 | actor=-40.0000 | critic=10.1082 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2188.3 | checkpoint=-
# [train] step=212/500 | warm=0 | policy=32 | replay=16784 | world_total=11328.7662 | actor=-37.4688 | critic=19.5028 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2196.1 | checkpoint=-
# [train] step=213/500 | warm=0 | policy=32 | replay=16816 | world_total=11328.7457 | actor=-32.5156 | critic=17.8163 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2204.3 | checkpoint=-
# [train] step=214/500 | warm=0 | policy=32 | replay=16848 | world_total=11328.6411 | actor=-27.1875 | critic=12.7922 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2212.0 | checkpoint=-
# [train] step=215/500 | warm=0 | policy=32 | replay=16880 | world_total=11328.5707 | actor=-24.9688 | critic=9.0110 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=2218.4 | checkpoint=-
# [train] step=216/500 | warm=0 | policy=32 | replay=16912 | world_total=11328.5062 | actor=-26.0000 | critic=9.0663 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2225.7 | checkpoint=-
# [train] step=217/500 | warm=0 | policy=32 | replay=16944 | world_total=11328.4659 | actor=-25.6250 | critic=9.0904 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2234.3 | checkpoint=-
# [train] step=218/500 | warm=0 | policy=32 | replay=16976 | world_total=11328.2450 | actor=-28.8594 | critic=7.9210 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2242.8 | checkpoint=-
# [train] step=219/500 | warm=0 | policy=32 | replay=17008 | world_total=11328.1884 | actor=-30.7188 | critic=7.1010 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=2250.9 | checkpoint=-
# [train] step=220/500 | warm=0 | policy=32 | replay=17040 | world_total=11328.2605 | actor=-30.7031 | critic=12.3999 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2259.1 | checkpoint=-
# [train] step=221/500 | warm=0 | policy=32 | replay=17072 | world_total=11328.2139 | actor=-29.7188 | critic=14.2546 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2268.1 | checkpoint=-
# [train] step=222/500 | warm=0 | policy=32 | replay=17104 | world_total=11328.1328 | actor=-26.1406 | critic=15.9459 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2276.5 | checkpoint=-
# [train] step=223/500 | warm=0 | policy=32 | replay=17136 | world_total=11327.9830 | actor=-22.9375 | critic=13.9507 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2285.1 | checkpoint=-
# [train] step=224/500 | warm=0 | policy=32 | replay=17168 | world_total=11327.9548 | actor=-21.4688 | critic=9.4116 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2293.7 | checkpoint=-
# [train] step=225/500 | warm=0 | policy=32 | replay=17200 | world_total=11327.9503 | actor=-20.0156 | critic=8.0127 | eval_reward=6.1875 | cycle_s=20.5 | elapsed_s=2314.2 | checkpoint=checkpoint_00225.pt
# [train] step=226/500 | warm=0 | policy=32 | replay=17232 | world_total=11327.8899 | actor=-20.0938 | critic=7.9376 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2322.0 | checkpoint=-
# [train] step=227/500 | warm=0 | policy=32 | replay=17264 | world_total=11327.8727 | actor=-21.1562 | critic=7.3936 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2329.7 | checkpoint=-
# [train] step=228/500 | warm=0 | policy=32 | replay=17296 | world_total=11327.8700 | actor=-21.9531 | critic=8.1352 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=2337.2 | checkpoint=-
# [train] step=229/500 | warm=0 | policy=32 | replay=17328 | world_total=11327.8192 | actor=-24.0312 | critic=7.8281 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2345.5 | checkpoint=-
# [train] step=230/500 | warm=0 | policy=32 | replay=17360 | world_total=11327.6499 | actor=-24.9219 | critic=8.4671 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2354.3 | checkpoint=-
# [train] step=231/500 | warm=0 | policy=32 | replay=17392 | world_total=11327.6030 | actor=-27.0469 | critic=7.7223 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=2362.4 | checkpoint=-
# [train] step=232/500 | warm=0 | policy=32 | replay=17424 | world_total=11327.7118 | actor=-29.7812 | critic=7.4898 | eval_reward=n/a | cycle_s=9.3 | elapsed_s=2371.7 | checkpoint=-
# [train] step=233/500 | warm=0 | policy=32 | replay=17456 | world_total=11327.6177 | actor=-29.4844 | critic=9.6808 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2380.4 | checkpoint=-
# [train] step=234/500 | warm=0 | policy=32 | replay=17488 | world_total=11328.2205 | actor=-27.9688 | critic=15.5233 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2389.1 | checkpoint=-
# [train] step=235/500 | warm=0 | policy=32 | replay=17520 | world_total=11328.1345 | actor=-25.7031 | critic=14.0426 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2396.9 | checkpoint=-
# [train] step=236/500 | warm=0 | policy=32 | replay=17552 | world_total=11327.7865 | actor=-24.0312 | critic=10.2939 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2405.0 | checkpoint=-
# [train] step=237/500 | warm=0 | policy=32 | replay=17584 | world_total=11327.3580 | actor=-24.6875 | critic=7.9622 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2412.7 | checkpoint=-
# [train] step=238/500 | warm=0 | policy=32 | replay=17616 | world_total=11327.2900 | actor=-24.3750 | critic=7.8893 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2420.9 | checkpoint=-
# [train] step=239/500 | warm=0 | policy=32 | replay=17648 | world_total=11327.2542 | actor=-26.8438 | critic=7.5354 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=2428.5 | checkpoint=-
# [train] step=240/500 | warm=0 | policy=32 | replay=17680 | world_total=11327.2617 | actor=-27.9375 | critic=8.0864 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=2434.3 | checkpoint=-
# [train] step=241/500 | warm=0 | policy=32 | replay=17712 | world_total=11327.2227 | actor=-30.7969 | critic=7.0501 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=2440.9 | checkpoint=-
# [train] step=242/500 | warm=0 | policy=32 | replay=17744 | world_total=11327.1963 | actor=-32.3594 | critic=7.9592 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=2447.7 | checkpoint=-
# [train] step=243/500 | warm=0 | policy=32 | replay=17776 | world_total=11327.7614 | actor=-32.9375 | critic=7.5784 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2455.7 | checkpoint=-
# [train] step=244/500 | warm=0 | policy=32 | replay=17808 | world_total=11328.8933 | actor=-31.8438 | critic=13.3311 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2463.4 | checkpoint=-
# [train] step=245/500 | warm=0 | policy=32 | replay=17840 | world_total=11327.8096 | actor=-32.1094 | critic=9.5055 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2472.1 | checkpoint=-
# [train] step=246/500 | warm=0 | policy=32 | replay=17872 | world_total=11327.1829 | actor=-31.5312 | critic=6.2030 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2480.8 | checkpoint=-
# [train] step=247/500 | warm=0 | policy=32 | replay=17904 | world_total=11327.0000 | actor=-32.1250 | critic=7.2181 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=2488.6 | checkpoint=-
# [train] step=248/500 | warm=0 | policy=32 | replay=17936 | world_total=11326.8965 | actor=-31.6719 | critic=9.1052 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2497.3 | checkpoint=-
# [train] step=249/500 | warm=0 | policy=32 | replay=17968 | world_total=11326.7872 | actor=-32.0625 | critic=8.5133 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=2505.9 | checkpoint=-
# [train] step=250/500 | warm=0 | policy=32 | replay=18000 | world_total=11326.7588 | actor=-30.3594 | critic=11.4064 | eval_reward=9.4620 | cycle_s=20.3 | elapsed_s=2526.2 | checkpoint=checkpoint_00250.pt
# [train] step=251/500 | warm=0 | policy=32 | replay=18032 | world_total=11326.6167 | actor=-29.5781 | critic=9.3180 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=2533.9 | checkpoint=-
# [train] step=252/500 | warm=0 | policy=32 | replay=18064 | world_total=11326.6156 | actor=-27.9375 | critic=10.0181 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=2541.4 | checkpoint=-
# [train] step=253/500 | warm=0 | policy=32 | replay=18096 | world_total=11326.6393 | actor=-26.6250 | critic=8.5807 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2548.7 | checkpoint=-
# [train] step=254/500 | warm=0 | policy=32 | replay=18128 | world_total=11326.6527 | actor=-27.3125 | critic=7.4219 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2556.7 | checkpoint=-
# [train] step=255/500 | warm=0 | policy=32 | replay=18160 | world_total=11326.5470 | actor=-26.5938 | critic=7.8570 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=2564.9 | checkpoint=-
# [train] step=256/500 | warm=0 | policy=32 | replay=18192 | world_total=11326.4565 | actor=-26.5469 | critic=8.5828 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=2572.8 | checkpoint=-
# [train] step=257/500 | warm=0 | policy=32 | replay=18224 | world_total=11326.4382 | actor=-26.8438 | critic=8.1755 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=2581.1 | checkpoint=-
# [train] step=258/500 | warm=0 | policy=32 | replay=18256 | world_total=11326.3990 | actor=-27.3438 | critic=7.7081 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2589.5 | checkpoint=-
# [train] step=259/500 | warm=0 | policy=32 | replay=18288 | world_total=11326.2844 | actor=-26.6406 | critic=9.1105 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=2598.7 | checkpoint=-
# [train] step=260/500 | warm=0 | policy=32 | replay=18320 | world_total=11326.3855 | actor=-27.3281 | critic=6.8749 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=2606.3 | checkpoint=-
# [train] step=261/500 | warm=0 | policy=32 | replay=18352 | world_total=11326.3362 | actor=-28.1250 | critic=7.3528 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=2614.3 | checkpoint=-
# [train] step=262/500 | warm=0 | policy=32 | replay=18384 | world_total=11326.2062 | actor=-28.5312 | critic=6.8988 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=2622.7 | checkpoint=-
# [train] step=263/500 | warm=0 | policy=32 | replay=18416 | world_total=11326.1244 | actor=-28.2656 | critic=8.2196 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2630.0 | checkpoint=-
# [train] step=264/500 | warm=0 | policy=32 | replay=18448 | world_total=11326.2380 | actor=-30.7969 | critic=6.6085 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=2637.3 | checkpoint=-
# ...
# [train] step=420/500 | warm=0 | policy=32 | replay=23440 | world_total=11321.8732 | actor=-20.3906 | critic=7.4473 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=3989.6 | checkpoint=-
# [train] step=421/500 | warm=0 | policy=32 | replay=23472 | world_total=11321.8430 | actor=-21.0938 | critic=8.3697 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=3997.6 | checkpoint=-
# [train] step=422/500 | warm=0 | policy=32 | replay=23504 | world_total=11321.7968 | actor=-19.2344 | critic=14.0180 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=4006.6 | checkpoint=-
# [train] step=423/500 | warm=0 | policy=32 | replay=23536 | world_total=11321.6951 | actor=-18.0625 | critic=13.5650 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4014.9 | checkpoint=-
# [train] step=424/500 | warm=0 | policy=32 | replay=23568 | world_total=11321.7577 | actor=-20.2188 | critic=8.8977 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4023.3 | checkpoint=-
# [train] step=425/500 | warm=0 | policy=32 | replay=23600 | world_total=11321.6952 | actor=-18.8594 | critic=9.1071 | eval_reward=8.8521 | cycle_s=21.8 | elapsed_s=4045.1 | checkpoint=checkpoint_00425.pt
# [train] step=426/500 | warm=0 | policy=32 | replay=23632 | world_total=11321.6422 | actor=-18.7031 | critic=10.1346 | eval_reward=n/a | cycle_s=8.8 | elapsed_s=4053.9 | checkpoint=-
# [train] step=427/500 | warm=0 | policy=32 | replay=23664 | world_total=11321.7131 | actor=-21.0000 | critic=8.6721 | eval_reward=n/a | cycle_s=9.0 | elapsed_s=4062.9 | checkpoint=-
# [train] step=428/500 | warm=0 | policy=32 | replay=23696 | world_total=11321.5719 | actor=-21.1094 | critic=9.5655 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4071.4 | checkpoint=-
# [train] step=429/500 | warm=0 | policy=32 | replay=23728 | world_total=11321.5836 | actor=-19.6562 | critic=13.7275 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4079.9 | checkpoint=-
# [train] step=430/500 | warm=0 | policy=32 | replay=23760 | world_total=11321.5197 | actor=-21.0156 | critic=9.9085 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=4088.8 | checkpoint=-
# [train] step=431/500 | warm=0 | policy=32 | replay=23792 | world_total=11321.5974 | actor=-20.2812 | critic=9.1751 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=4097.5 | checkpoint=-
# [train] step=432/500 | warm=0 | policy=32 | replay=23824 | world_total=11321.7023 | actor=-20.9219 | critic=9.8884 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=4105.3 | checkpoint=-
# [train] step=433/500 | warm=0 | policy=32 | replay=23856 | world_total=11321.6454 | actor=-18.8750 | critic=13.3852 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=4112.8 | checkpoint=-
# [train] step=434/500 | warm=0 | policy=32 | replay=23888 | world_total=11321.5232 | actor=-16.9688 | critic=13.1471 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4120.5 | checkpoint=-
# [train] step=435/500 | warm=0 | policy=32 | replay=23920 | world_total=11321.5918 | actor=-17.7188 | critic=8.1816 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=4129.7 | checkpoint=-
# [train] step=436/500 | warm=0 | policy=32 | replay=23952 | world_total=11321.5385 | actor=-18.2031 | critic=9.7670 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4138.0 | checkpoint=-
# [train] step=437/500 | warm=0 | policy=32 | replay=23984 | world_total=11321.5276 | actor=-17.3125 | critic=9.9980 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4145.2 | checkpoint=-
# [train] step=438/500 | warm=0 | policy=32 | replay=24016 | world_total=11321.5038 | actor=-16.9531 | critic=9.6301 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=4153.0 | checkpoint=-
# [train] step=439/500 | warm=0 | policy=32 | replay=24048 | world_total=11321.4293 | actor=-15.9375 | critic=11.0235 | eval_reward=n/a | cycle_s=7.7 | elapsed_s=4160.8 | checkpoint=-
# [train] step=440/500 | warm=0 | policy=32 | replay=24080 | world_total=11321.3678 | actor=-16.9375 | critic=8.0819 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4168.1 | checkpoint=-
# [train] step=441/500 | warm=0 | policy=32 | replay=24112 | world_total=11321.4869 | actor=-19.3594 | critic=10.5192 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=4174.0 | checkpoint=-
# [train] step=442/500 | warm=0 | policy=32 | replay=24144 | world_total=11321.6227 | actor=-20.3750 | critic=9.1042 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=4181.0 | checkpoint=-
# [train] step=443/500 | warm=0 | policy=32 | replay=24176 | world_total=11321.7378 | actor=-21.9844 | critic=10.6839 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=4188.5 | checkpoint=-
# [train] step=444/500 | warm=0 | policy=32 | replay=24208 | world_total=11321.5907 | actor=-20.1562 | critic=16.5883 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4195.7 | checkpoint=-
# [train] step=445/500 | warm=0 | policy=32 | replay=24240 | world_total=11321.4076 | actor=-19.0156 | critic=14.6422 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=4203.5 | checkpoint=-
# [train] step=446/500 | warm=0 | policy=32 | replay=24272 | world_total=11321.4071 | actor=-18.1406 | critic=10.6374 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=4211.4 | checkpoint=-
# [train] step=447/500 | warm=0 | policy=32 | replay=24304 | world_total=11321.3961 | actor=-17.0625 | critic=8.6843 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4219.0 | checkpoint=-
# [train] step=448/500 | warm=0 | policy=32 | replay=24336 | world_total=11321.3776 | actor=-18.8125 | critic=8.4180 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4227.3 | checkpoint=-
# [train] step=449/500 | warm=0 | policy=32 | replay=24368 | world_total=11321.4221 | actor=-16.9219 | critic=10.3788 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4235.8 | checkpoint=-
# [train] step=450/500 | warm=0 | policy=32 | replay=24400 | world_total=11321.4253 | actor=-19.2969 | critic=9.6342 | eval_reward=6.1087 | cycle_s=20.6 | elapsed_s=4256.5 | checkpoint=checkpoint_00450.pt
# [train] step=451/500 | warm=0 | policy=32 | replay=24432 | world_total=11321.5043 | actor=-19.7188 | critic=9.8032 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4265.0 | checkpoint=-
# [train] step=452/500 | warm=0 | policy=32 | replay=24464 | world_total=11321.3916 | actor=-21.0156 | critic=10.2450 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4273.1 | checkpoint=-
# [train] step=453/500 | warm=0 | policy=32 | replay=24496 | world_total=11321.4224 | actor=-16.5156 | critic=22.2137 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4281.2 | checkpoint=-
# [train] step=454/500 | warm=0 | policy=32 | replay=24528 | world_total=11321.2693 | actor=-16.0469 | critic=13.0017 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4289.7 | checkpoint=-
# [train] step=455/500 | warm=0 | policy=32 | replay=24560 | world_total=11321.2094 | actor=-13.9219 | critic=9.3982 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=4298.4 | checkpoint=-
# [train] step=456/500 | warm=0 | policy=32 | replay=24592 | world_total=11321.2272 | actor=-12.5000 | critic=7.2375 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=4307.3 | checkpoint=-
# [train] step=457/500 | warm=0 | policy=32 | replay=24624 | world_total=11321.1552 | actor=-12.4688 | critic=6.9729 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4315.9 | checkpoint=-
# [train] step=458/500 | warm=0 | policy=32 | replay=24656 | world_total=11321.2006 | actor=-12.3984 | critic=6.9802 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4323.2 | checkpoint=-
# [train] step=459/500 | warm=0 | policy=32 | replay=24688 | world_total=11321.1970 | actor=-12.2734 | critic=7.6037 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=4330.3 | checkpoint=-
# [train] step=460/500 | warm=0 | policy=32 | replay=24720 | world_total=11321.2616 | actor=-13.6250 | critic=7.6824 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=4337.8 | checkpoint=-
# [train] step=461/500 | warm=0 | policy=32 | replay=24752 | world_total=11321.3414 | actor=-14.1875 | critic=7.7495 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=4346.0 | checkpoint=-
# [train] step=462/500 | warm=0 | policy=32 | replay=24784 | world_total=11321.4005 | actor=-12.8750 | critic=9.3080 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=4353.3 | checkpoint=-
# [train] step=463/500 | warm=0 | policy=32 | replay=24816 | world_total=11321.2910 | actor=-12.5625 | critic=7.5799 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=4361.0 | checkpoint=-
# [train] step=464/500 | warm=0 | policy=32 | replay=24848 | world_total=11321.2300 | actor=-15.1641 | critic=9.8546 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4369.3 | checkpoint=-
# [train] step=465/500 | warm=0 | policy=32 | replay=24880 | world_total=11321.2373 | actor=-16.7109 | critic=9.1408 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4377.4 | checkpoint=-
# [train] step=466/500 | warm=0 | policy=32 | replay=24912 | world_total=11321.1453 | actor=-18.8750 | critic=9.5148 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=4384.3 | checkpoint=-
# [train] step=467/500 | warm=0 | policy=32 | replay=24944 | world_total=11321.1023 | actor=-15.2734 | critic=19.8638 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=4390.5 | checkpoint=-
# [train] step=468/500 | warm=0 | policy=32 | replay=24976 | world_total=11321.0931 | actor=-15.9688 | critic=12.2116 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=4397.1 | checkpoint=-
# [train] step=469/500 | warm=0 | policy=32 | replay=25008 | world_total=11321.0118 | actor=-15.6719 | critic=10.0369 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=4405.8 | checkpoint=-
# [train] step=470/500 | warm=0 | policy=32 | replay=25040 | world_total=11321.1244 | actor=-16.0078 | critic=9.6008 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4413.9 | checkpoint=-
# [train] step=471/500 | warm=0 | policy=32 | replay=25072 | world_total=11321.2261 | actor=-15.6328 | critic=10.8091 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=4422.2 | checkpoint=-
# [train] step=472/500 | warm=0 | policy=32 | replay=25104 | world_total=11321.1595 | actor=-13.9219 | critic=12.2535 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=4429.5 | checkpoint=-
# [train] step=473/500 | warm=0 | policy=32 | replay=25136 | world_total=11321.1589 | actor=-14.3438 | critic=9.4206 | eval_reward=n/a | cycle_s=8.0 | elapsed_s=4437.5 | checkpoint=-
# [train] step=474/500 | warm=0 | policy=32 | replay=25168 | world_total=11321.2020 | actor=-12.4219 | critic=8.2005 | eval_reward=n/a | cycle_s=8.1 | elapsed_s=4445.5 | checkpoint=-
# [train] step=475/500 | warm=0 | policy=32 | replay=25200 | world_total=11321.1295 | actor=-11.6484 | critic=6.9246 | eval_reward=8.1627 | cycle_s=23.3 | elapsed_s=4468.8 | checkpoint=checkpoint_00475.pt
# [train] step=476/500 | warm=0 | policy=32 | replay=25232 | world_total=11321.0718 | actor=-13.2266 | critic=8.7432 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4477.4 | checkpoint=-
# [train] step=477/500 | warm=0 | policy=32 | replay=25264 | world_total=11320.9862 | actor=-12.6406 | critic=8.0466 | eval_reward=n/a | cycle_s=8.4 | elapsed_s=4485.8 | checkpoint=-
# [train] step=478/500 | warm=0 | policy=32 | replay=25296 | world_total=11321.0594 | actor=-15.2344 | critic=9.4706 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4494.1 | checkpoint=-
# [train] step=479/500 | warm=0 | policy=32 | replay=25328 | world_total=11321.0432 | actor=-14.8828 | critic=9.7628 | eval_reward=n/a | cycle_s=8.5 | elapsed_s=4502.5 | checkpoint=-
# [train] step=480/500 | warm=0 | policy=32 | replay=25360 | world_total=11321.0109 | actor=-13.3750 | critic=10.6298 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=4511.1 | checkpoint=-
# [train] step=481/500 | warm=0 | policy=32 | replay=25392 | world_total=11320.8656 | actor=-12.1406 | critic=8.2715 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=4519.5 | checkpoint=-
# [train] step=482/500 | warm=0 | policy=32 | replay=25424 | world_total=11320.9808 | actor=-11.4219 | critic=6.7125 | eval_reward=n/a | cycle_s=8.2 | elapsed_s=4527.6 | checkpoint=-
# [train] step=483/500 | warm=0 | policy=32 | replay=25456 | world_total=11321.0009 | actor=-12.4922 | critic=7.5637 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4534.8 | checkpoint=-
# [train] step=484/500 | warm=0 | policy=32 | replay=25488 | world_total=11320.9821 | actor=-13.2188 | critic=8.2546 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=4543.5 | checkpoint=-
# [train] step=485/500 | warm=0 | policy=32 | replay=25520 | world_total=11321.0295 | actor=-12.2734 | critic=8.7942 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=4551.4 | checkpoint=-
# [train] step=486/500 | warm=0 | policy=32 | replay=25552 | world_total=11320.9233 | actor=-11.0234 | critic=6.4570 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=4558.6 | checkpoint=-
# [train] step=487/500 | warm=0 | policy=32 | replay=25584 | world_total=11320.8793 | actor=-11.6797 | critic=6.8869 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=4565.1 | checkpoint=-
# [train] step=488/500 | warm=0 | policy=32 | replay=25616 | world_total=11320.9413 | actor=-12.7266 | critic=7.4059 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=4571.1 | checkpoint=-
# [train] step=489/500 | warm=0 | policy=32 | replay=25648 | world_total=11320.9967 | actor=-12.9844 | critic=8.1429 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=4577.2 | checkpoint=-
# [train] step=490/500 | warm=0 | policy=32 | replay=25680 | world_total=11320.9257 | actor=-11.4141 | critic=8.0513 | eval_reward=n/a | cycle_s=7.0 | elapsed_s=4584.1 | checkpoint=-
# [train] step=491/500 | warm=0 | policy=32 | replay=25712 | world_total=11320.9709 | actor=-10.5391 | critic=5.6934 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=4590.0 | checkpoint=-
# [train] step=492/500 | warm=0 | policy=32 | replay=25744 | world_total=11321.0116 | actor=-13.1172 | critic=8.6497 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=4595.1 | checkpoint=-
# [train] step=493/500 | warm=0 | policy=32 | replay=25776 | world_total=11320.9771 | actor=-14.1562 | critic=8.5616 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=4601.8 | checkpoint=-
# [train] step=494/500 | warm=0 | policy=32 | replay=25808 | world_total=11320.9036 | actor=-13.2109 | critic=10.6755 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=4607.9 | checkpoint=-
# [train] step=495/500 | warm=0 | policy=32 | replay=25840 | world_total=11320.8447 | actor=-12.9062 | critic=7.5789 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=4614.3 | checkpoint=-
# [train] step=496/500 | warm=0 | policy=32 | replay=25872 | world_total=11320.9745 | actor=-11.8359 | critic=6.3394 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=4620.5 | checkpoint=-
# [train] step=497/500 | warm=0 | policy=32 | replay=25904 | world_total=11320.8348 | actor=-11.6797 | critic=6.5804 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=4626.4 | checkpoint=-
# [train] step=498/500 | warm=0 | policy=32 | replay=25936 | world_total=11320.7688 | actor=-11.3672 | critic=6.5431 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=4631.7 | checkpoint=-
# [train] step=499/500 | warm=0 | policy=32 | replay=25968 | world_total=11320.8938 | actor=-11.0234 | critic=6.3356 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=4637.2 | checkpoint=-
# [train] step=500/500 | warm=0 | policy=32 | replay=26000 | world_total=11320.8945 | actor=-12.2500 | critic=6.6639 | eval_reward=3.9381 | cycle_s=17.0 | elapsed_s=4654.2 | checkpoint=checkpoint_00500.pt
# Completed cycles: 500
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter22_low_steering_penalty/checkpoints/checkpoint_00500.pt
# Latest metrics: {'step': 500, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 26000, 'world_model/reconstruction_loss': 11312.727783203125, 'world_model/reconstruction_mse': 0.003387137723620981, 'world_model/observation_log_prob': -11312.727783203125, 'world_model/reward_loss': 1.260524496436119, 'world_model/continue_loss': 0.019481709459796548, 'world_model/kl_loss': 4.574932217597961, 'world_model/kl_loss_raw': 4.574932217597961, 'world_model/overshooting_kl_loss': 4.623514354228973, 'world_model/overshooting_feature_mse': 0.12168589606881142, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11320.89453125, 'behavior/actor_loss': -12.25, 'behavior/critic_loss': 6.663858354091644, 'behavior/imagined_reward_mean': 0.98291015625, 'behavior/imagined_value_mean': 10.2734375, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 3.9380932363172563, 'evaluation/mean_steps': 11.6, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter22_low_steering_penalty/checkpoints/checkpoint_00500.pt',
#  'latest_metrics': {'behavior/actor_loss': -12.25,
#   'behavior/critic_loss': 6.663858354091644,
#   'behavior/imagined_reward_mean': 0.98291015625,
#   'behavior/imagined_value_mean': 10.2734375,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 3.9380932363172563,
#   'evaluation/mean_steps': 11.6,
#   'policy_added': 32,
#   'replay_size': 26000,
#   'step': 500,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.019481709459796548,
#   'world_model/kl_loss': 4.574932217597961,
#   'world_model/kl_loss_raw': 4.574932217597961,
#   'world_model/observation_log_prob': -11312.727783203125,
#   'world_model/overshooting_feature_mse': 0.12168589606881142,
#   'world_model/overshooting_kl_loss': 4.623514354228973,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11312.727783203125,
#   'world_model/reconstruction_mse': 0.003387137723620981,
#   'world_model/reward_loss': 1.260524496436119,
#   'world_model/total_loss': 11320.89453125},
#  'latest_step': 500}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 16.19382174245555,
#   'best_eval_reward_step': 350,
#   'best_imagined_reward_mean': 1.16796875,
#   'best_imagined_reward_step': 469,
#   'best_world_model_step': 498,
#   'best_world_model_total_loss': 11320.768798828125,
#   'largest_replay_size': 26000,
#   'largest_replay_step': 500,
#   'last_metrics': {'behavior/actor_loss': -12.25,
#    'behavior/critic_loss': 6.663858354091644,
#    'behavior/imagined_reward_mean': 0.98291015625,
#    'behavior/imagined_value_mean': 10.2734375,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 3.9380932363172563,
#    'evaluation/mean_steps': 11.6,
#    'policy_added': 32,
#    'replay_size': 26000,
#    'step': 500,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.019481709459796548,
#    'world_model/kl_loss': 4.574932217597961,
#    'world_model/kl_loss_raw': 4.574932217597961,
#    'world_model/observation_log_prob': -11312.727783203125,
#    'world_model/overshooting_feature_mse': 0.12168589606881142,
#    'world_model/overshooting_kl_loss': 4.623514354228973,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11312.727783203125,
#    'world_model/reconstruction_mse': 0.003387137723620981,
#    'world_model/reward_loss': 1.260524496436119,
#    'world_model/total_loss': 11320.89453125},
#   'last_step': 500,
#   'num_records': 500},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11312.727783203125',
#   'world_model/reconstruction_mse': '0.003387137723620981',
#   'world_model/observation_log_prob': '-11312.727783203125',
#   'world_model/overshooting_kl_loss': '4.623514354228973',
#   'world_model/overshooting_feature_mse': '0.12168589606881142',
#   'evaluation/mean_reward': '3.9380932363172563',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=132,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=24 | reward=17.68 | CRASH | saved iter22_low_steering_penalty_ep01.gif
# [demo] episode 2/10 | steps=17 | reward=9.98 | CRASH | saved iter22_low_steering_penalty_ep02.gif
# [demo] episode 3/10 | steps=24 | reward=18.04 | CRASH | saved iter22_low_steering_penalty_ep03.gif
# [demo] episode 4/10 | steps=24 | reward=18.53 | CRASH | saved iter22_low_steering_penalty_ep04.gif
# [demo] episode 5/10 | steps=37 | reward=36.25 | CRASH | saved iter22_low_steering_penalty_ep05.gif
# [demo] episode 6/10 | steps=17 | reward=10.19 | CRASH | saved iter22_low_steering_penalty_ep06.gif
# [demo] episode 7/10 | steps=21 | reward=15.71 | CRASH | saved iter22_low_steering_penalty_ep07.gif
# [demo] episode 8/10 | steps=6 | reward=-0.74 | CRASH | saved iter22_low_steering_penalty_ep08.gif
# [demo] episode 9/10 | steps=13 | reward=4.65 | CRASH | saved iter22_low_steering_penalty_ep09.gif
# [demo] episode 10/10 | steps=6 | reward=-0.78 | CRASH | saved iter22_low_steering_penalty_ep10.gif
# [demo] done | avg_reward=12.95 | summary=iter22_low_steering_penalty_summary.json
#
# iter22_low_steering_penalty_ep01.gif
# iter22_low_steering_penalty_ep02.gif
# iter22_low_steering_penalty_ep03.gif
# iter22_low_steering_penalty_ep04.gif
# iter22_low_steering_penalty_ep05.gif
# iter22_low_steering_penalty_ep06.gif
# iter22_low_steering_penalty_ep07.gif
# iter22_low_steering_penalty_ep08.gif
# iter22_low_steering_penalty_ep09.gif
# iter22_low_steering_penalty_ep10.gif
