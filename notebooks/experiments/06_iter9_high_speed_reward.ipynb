# %% [markdown]
# # Tiny Dreamer Highway — Iter 9: high_speed_reward
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 cumulative
# **New change:** `high_speed_reward: 0.8 → 0.3`
# **Hypothesis:** Speed reward dominates the reward signal. Reducing it from 0.8 to 0.3 makes collision/steering penalties relatively more important, so the agent values survival over speed.

# %% [markdown]
# ## Iteration 9 — Speed control via reward weight
#
# Instead of capping target speed, reduce *how much* speed matters. The agent should still prefer faster over slower, but not at all costs.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides (current working config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nIter5 base overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 9 Override: high_speed_reward ---
# high_speed_reward 0.8 → 0.3: reduce speed incentive
config.env.reward.high_speed_reward = 0.3

print('Iter 9 override:')
print(f'  high_speed_reward = {config.env.reward.high_speed_reward}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Iter5 base overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
# Iter 9 override:
#   high_speed_reward = 0.3

# %%
RUN_NAME = 'iter9_high_speed_reward'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter9_high_speed_reward/checkpoints/checkpoint_00250.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter9_high_speed_reward
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter5_framestack/checkpoints/checkpoint_00025.pt
# Effective cycles: 250
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=250 | start_step=26 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=26/250 | warm=0 | policy=32 | replay=10832 | world_total=11450.0482 | actor=-9.9766 | critic=1.0570 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=6.5 | checkpoint=-
# [train] step=27/250 | warm=0 | policy=32 | replay=10864 | world_total=11561.0874 | actor=-1.2783 | critic=6.9642 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=12.0 | checkpoint=-
# [train] step=28/250 | warm=0 | policy=32 | replay=10896 | world_total=11486.8442 | actor=-4.3984 | critic=4.3149 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=18.0 | checkpoint=-
# [train] step=29/250 | warm=0 | policy=32 | replay=10928 | world_total=11460.6544 | actor=-10.9375 | critic=8.1135 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=23.8 | checkpoint=-
# [train] step=30/250 | warm=0 | policy=32 | replay=10960 | world_total=11455.9730 | actor=-10.1719 | critic=2.5884 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=29.4 | checkpoint=-
# [train] step=31/250 | warm=0 | policy=32 | replay=10992 | world_total=11452.1166 | actor=-11.6484 | critic=2.3735 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=35.1 | checkpoint=-
# [train] step=32/250 | warm=0 | policy=32 | replay=11024 | world_total=11450.3269 | actor=-11.1250 | critic=1.5032 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=40.8 | checkpoint=-
# [train] step=33/250 | warm=0 | policy=32 | replay=11056 | world_total=11449.3668 | actor=-11.2344 | critic=1.8863 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=46.2 | checkpoint=-
# [train] step=34/250 | warm=0 | policy=32 | replay=11088 | world_total=11448.8352 | actor=-12.6562 | critic=1.3815 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=52.1 | checkpoint=-
# [train] step=35/250 | warm=0 | policy=32 | replay=11120 | world_total=11451.4657 | actor=-9.7031 | critic=2.6982 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=57.5 | checkpoint=-
# [train] step=36/250 | warm=0 | policy=32 | replay=11152 | world_total=11449.9396 | actor=-9.1875 | critic=1.6576 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=63.4 | checkpoint=-
# [train] step=37/250 | warm=0 | policy=32 | replay=11184 | world_total=11448.3606 | actor=-10.4453 | critic=1.8533 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=69.2 | checkpoint=-
# [train] step=38/250 | warm=0 | policy=32 | replay=11216 | world_total=11446.5427 | actor=-9.2812 | critic=1.3153 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=74.9 | checkpoint=-
# [train] step=39/250 | warm=0 | policy=32 | replay=11248 | world_total=11445.9160 | actor=-8.9375 | critic=1.4026 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=80.8 | checkpoint=-
# [train] step=40/250 | warm=0 | policy=32 | replay=11280 | world_total=11444.7983 | actor=-8.0352 | critic=1.5124 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=86.3 | checkpoint=-
# [train] step=41/250 | warm=0 | policy=32 | replay=11312 | world_total=11443.6073 | actor=-7.6523 | critic=1.2755 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=91.9 | checkpoint=-
# [train] step=42/250 | warm=0 | policy=32 | replay=11344 | world_total=11442.3640 | actor=-7.4414 | critic=1.2345 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=97.4 | checkpoint=-
# [train] step=43/250 | warm=0 | policy=32 | replay=11376 | world_total=11440.9885 | actor=-6.9883 | critic=1.2866 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=103.1 | checkpoint=-
# [train] step=44/250 | warm=0 | policy=32 | replay=11408 | world_total=11438.9486 | actor=-6.1719 | critic=1.5379 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=108.3 | checkpoint=-
# [train] step=45/250 | warm=0 | policy=32 | replay=11440 | world_total=11438.0203 | actor=-6.0859 | critic=1.3882 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=113.8 | checkpoint=-
# [train] step=46/250 | warm=0 | policy=32 | replay=11472 | world_total=11437.4172 | actor=-5.0312 | critic=1.3011 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=119.7 | checkpoint=-
# [train] step=47/250 | warm=0 | policy=32 | replay=11504 | world_total=11435.8976 | actor=-4.7656 | critic=1.3475 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=125.5 | checkpoint=-
# [train] step=48/250 | warm=0 | policy=32 | replay=11536 | world_total=11434.1024 | actor=-4.2930 | critic=1.3537 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=130.7 | checkpoint=-
# [train] step=49/250 | warm=0 | policy=32 | replay=11568 | world_total=11432.8785 | actor=-3.8105 | critic=1.2252 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=135.9 | checkpoint=-
# [train] step=50/250 | warm=0 | policy=32 | replay=11600 | world_total=11431.5472 | actor=-3.8438 | critic=1.1887 | eval_reward=-0.5164 | cycle_s=12.9 | elapsed_s=148.8 | checkpoint=checkpoint_00050.pt
# [train] step=51/250 | warm=0 | policy=32 | replay=11632 | world_total=11430.6260 | actor=-3.5156 | critic=1.1677 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=154.8 | checkpoint=-
# [train] step=52/250 | warm=0 | policy=32 | replay=11664 | world_total=11429.2321 | actor=-3.2461 | critic=1.1802 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=160.6 | checkpoint=-
# [train] step=53/250 | warm=0 | policy=32 | replay=11696 | world_total=11427.9976 | actor=-3.0742 | critic=1.1537 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=166.3 | checkpoint=-
# [train] step=54/250 | warm=0 | policy=32 | replay=11728 | world_total=11427.0463 | actor=-3.0586 | critic=1.1482 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=172.2 | checkpoint=-
# [train] step=55/250 | warm=0 | policy=32 | replay=11760 | world_total=11426.3478 | actor=-2.9277 | critic=1.1590 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=177.5 | checkpoint=-
# [train] step=56/250 | warm=0 | policy=32 | replay=11792 | world_total=11425.0927 | actor=-3.1289 | critic=1.1489 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=183.1 | checkpoint=-
# [train] step=57/250 | warm=0 | policy=32 | replay=11824 | world_total=11423.9564 | actor=-3.6074 | critic=1.2045 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=188.8 | checkpoint=-
# [train] step=58/250 | warm=0 | policy=32 | replay=11856 | world_total=11422.7555 | actor=-4.0254 | critic=1.1410 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=194.2 | checkpoint=-
# [train] step=59/250 | warm=0 | policy=32 | replay=11888 | world_total=11421.3522 | actor=-5.1367 | critic=1.2877 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=199.4 | checkpoint=-
# [train] step=60/250 | warm=0 | policy=32 | replay=11920 | world_total=11420.0958 | actor=-5.9023 | critic=1.3636 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=204.6 | checkpoint=-
# [train] step=61/250 | warm=0 | policy=32 | replay=11952 | world_total=11418.6329 | actor=-6.9531 | critic=1.4183 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=210.2 | checkpoint=-
# [train] step=62/250 | warm=0 | policy=32 | replay=11984 | world_total=11418.1914 | actor=-8.4297 | critic=2.0281 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=215.7 | checkpoint=-
# [train] step=63/250 | warm=0 | policy=32 | replay=12016 | world_total=11416.4265 | actor=-8.7500 | critic=1.7444 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=221.3 | checkpoint=-
# [train] step=64/250 | warm=0 | policy=32 | replay=12048 | world_total=11415.1650 | actor=-10.1562 | critic=1.8143 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=226.9 | checkpoint=-
# [train] step=65/250 | warm=0 | policy=32 | replay=12080 | world_total=11412.9198 | actor=-11.3438 | critic=1.8002 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=232.6 | checkpoint=-
# [train] step=66/250 | warm=0 | policy=32 | replay=12112 | world_total=11411.3217 | actor=-11.7969 | critic=2.1925 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=238.1 | checkpoint=-
# [train] step=67/250 | warm=0 | policy=32 | replay=12144 | world_total=11410.0629 | actor=-12.0234 | critic=2.5220 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=243.9 | checkpoint=-
# [train] step=68/250 | warm=0 | policy=32 | replay=12176 | world_total=11408.2125 | actor=-9.2578 | critic=5.8933 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=249.4 | checkpoint=-
# [train] step=69/250 | warm=0 | policy=32 | replay=12208 | world_total=11406.5403 | actor=-7.8516 | critic=3.0143 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=254.9 | checkpoint=-
# [train] step=70/250 | warm=0 | policy=32 | replay=12240 | world_total=11404.9219 | actor=-6.9609 | critic=1.9986 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=260.6 | checkpoint=-
# [train] step=71/250 | warm=0 | policy=32 | replay=12272 | world_total=11403.0876 | actor=-6.4336 | critic=1.9605 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=265.8 | checkpoint=-
# [train] step=72/250 | warm=0 | policy=32 | replay=12304 | world_total=11401.9641 | actor=-5.8125 | critic=2.9520 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=270.9 | checkpoint=-
# [train] step=73/250 | warm=0 | policy=32 | replay=12336 | world_total=11401.1082 | actor=-5.1289 | critic=2.9645 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=276.9 | checkpoint=-
# [train] step=74/250 | warm=0 | policy=32 | replay=12368 | world_total=11399.3341 | actor=-5.5898 | critic=2.3084 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=282.7 | checkpoint=-
# [train] step=75/250 | warm=0 | policy=32 | replay=12400 | world_total=11397.4545 | actor=-4.7578 | critic=2.7359 | eval_reward=-0.5158 | cycle_s=13.5 | elapsed_s=296.3 | checkpoint=checkpoint_00075.pt
# [train] step=76/250 | warm=0 | policy=32 | replay=12432 | world_total=11395.8384 | actor=-4.8516 | critic=2.8010 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=302.2 | checkpoint=-
# [train] step=77/250 | warm=0 | policy=32 | replay=12464 | world_total=11394.3348 | actor=-2.4941 | critic=3.6101 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=307.8 | checkpoint=-
# [train] step=78/250 | warm=0 | policy=32 | replay=12496 | world_total=11392.2627 | actor=-2.9941 | critic=2.3221 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=312.7 | checkpoint=-
# [train] step=79/250 | warm=0 | policy=32 | replay=12528 | world_total=11390.3459 | actor=-2.4473 | critic=1.8947 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=318.3 | checkpoint=-
# [train] step=80/250 | warm=0 | policy=32 | replay=12560 | world_total=11388.6816 | actor=-1.8574 | critic=1.7985 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=323.6 | checkpoint=-
# [train] step=81/250 | warm=0 | policy=32 | replay=12592 | world_total=11387.1625 | actor=-3.3145 | critic=2.5997 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=328.8 | checkpoint=-
# [train] step=82/250 | warm=0 | policy=32 | replay=12624 | world_total=11384.9529 | actor=-1.8779 | critic=2.0643 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=334.7 | checkpoint=-
# [train] step=83/250 | warm=0 | policy=32 | replay=12656 | world_total=11383.0181 | actor=-2.5645 | critic=2.1008 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=340.8 | checkpoint=-
# [train] step=84/250 | warm=0 | policy=32 | replay=12688 | world_total=11381.8599 | actor=-1.1426 | critic=1.7098 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=346.0 | checkpoint=-
# [train] step=85/250 | warm=0 | policy=32 | replay=12720 | world_total=11380.3746 | actor=-1.0615 | critic=1.4699 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=351.5 | checkpoint=-
# [train] step=86/250 | warm=0 | policy=32 | replay=12752 | world_total=11379.3450 | actor=-0.7266 | critic=1.2645 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=357.6 | checkpoint=-
# [train] step=87/250 | warm=0 | policy=32 | replay=12784 | world_total=11378.5450 | actor=-0.6797 | critic=1.2371 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=363.3 | checkpoint=-
# [train] step=88/250 | warm=0 | policy=32 | replay=12816 | world_total=11376.7694 | actor=-0.6475 | critic=1.2056 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=368.8 | checkpoint=-
# [train] step=89/250 | warm=0 | policy=32 | replay=12848 | world_total=11375.5303 | actor=-1.0107 | critic=1.3531 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=374.7 | checkpoint=-
# [train] step=90/250 | warm=0 | policy=32 | replay=12880 | world_total=11374.5533 | actor=-0.9380 | critic=1.2617 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=380.2 | checkpoint=-
# [train] step=91/250 | warm=0 | policy=32 | replay=12912 | world_total=11373.4501 | actor=-0.7354 | critic=1.2212 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=385.6 | checkpoint=-
# [train] step=92/250 | warm=0 | policy=32 | replay=12944 | world_total=11372.4207 | actor=-0.6265 | critic=1.1812 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=390.8 | checkpoint=-
# [train] step=93/250 | warm=0 | policy=32 | replay=12976 | world_total=11371.7568 | actor=-0.7676 | critic=1.1779 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=396.6 | checkpoint=-
# [train] step=94/250 | warm=0 | policy=32 | replay=13008 | world_total=11370.7382 | actor=-0.8008 | critic=1.1792 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=402.4 | checkpoint=-
# [train] step=95/250 | warm=0 | policy=32 | replay=13040 | world_total=11369.7169 | actor=-0.5981 | critic=1.1402 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=408.0 | checkpoint=-
# [train] step=96/250 | warm=0 | policy=32 | replay=13072 | world_total=11368.6267 | actor=-0.6055 | critic=1.1204 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=414.0 | checkpoint=-
# [train] step=97/250 | warm=0 | policy=32 | replay=13104 | world_total=11368.0217 | actor=-0.6836 | critic=1.1335 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=419.6 | checkpoint=-
# [train] step=98/250 | warm=0 | policy=32 | replay=13136 | world_total=11366.8989 | actor=-0.6138 | critic=1.1216 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=425.3 | checkpoint=-
# [train] step=99/250 | warm=0 | policy=32 | replay=13168 | world_total=11366.3313 | actor=-0.7378 | critic=1.1759 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=431.1 | checkpoint=-
# [train] step=100/250 | warm=0 | policy=32 | replay=13200 | world_total=11365.1698 | actor=-1.0942 | critic=1.2474 | eval_reward=-0.5149 | cycle_s=12.5 | elapsed_s=443.6 | checkpoint=checkpoint_00100.pt
# [train] step=101/250 | warm=0 | policy=32 | replay=13232 | world_total=11364.0522 | actor=-1.3203 | critic=1.3109 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=447.9 | checkpoint=-
# [train] step=102/250 | warm=0 | policy=32 | replay=13264 | world_total=11363.1154 | actor=-1.9160 | critic=1.5575 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=453.6 | checkpoint=-
# [train] step=103/250 | warm=0 | policy=32 | replay=13296 | world_total=11362.0615 | actor=-2.6660 | critic=2.0283 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=458.2 | checkpoint=-
# [train] step=104/250 | warm=0 | policy=32 | replay=13328 | world_total=11360.9604 | actor=-2.9414 | critic=2.1666 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=463.3 | checkpoint=-
# [train] step=105/250 | warm=0 | policy=32 | replay=13360 | world_total=11360.4824 | actor=-3.0254 | critic=2.2704 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=467.6 | checkpoint=-
# [train] step=106/250 | warm=0 | policy=32 | replay=13392 | world_total=11359.7780 | actor=-2.8828 | critic=2.0570 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=472.8 | checkpoint=-
# [train] step=107/250 | warm=0 | policy=32 | replay=13424 | world_total=11359.1984 | actor=-3.1328 | critic=2.0392 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=477.7 | checkpoint=-
# [train] step=108/250 | warm=0 | policy=32 | replay=13456 | world_total=11358.1891 | actor=-3.0352 | critic=1.9769 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=482.9 | checkpoint=-
# [train] step=109/250 | warm=0 | policy=32 | replay=13488 | world_total=11357.6854 | actor=-3.0430 | critic=2.0259 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=487.6 | checkpoint=-
# [train] step=110/250 | warm=0 | policy=32 | replay=13520 | world_total=11356.6736 | actor=-2.9336 | critic=1.9737 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=492.3 | checkpoint=-
# [train] step=111/250 | warm=0 | policy=32 | replay=13552 | world_total=11355.7461 | actor=-3.2871 | critic=2.0033 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=497.5 | checkpoint=-
# [train] step=112/250 | warm=0 | policy=32 | replay=13584 | world_total=11355.2510 | actor=-3.4023 | critic=2.0297 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=502.1 | checkpoint=-
# [train] step=113/250 | warm=0 | policy=32 | replay=13616 | world_total=11354.4752 | actor=-3.9004 | critic=2.1326 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=506.0 | checkpoint=-
# [train] step=114/250 | warm=0 | policy=32 | replay=13648 | world_total=11354.3019 | actor=-4.1660 | critic=2.0741 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=511.4 | checkpoint=-
# [train] step=115/250 | warm=0 | policy=32 | replay=13680 | world_total=11354.1417 | actor=-4.5234 | critic=2.0642 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=515.9 | checkpoint=-
# [train] step=116/250 | warm=0 | policy=32 | replay=13712 | world_total=11353.6832 | actor=-5.1602 | critic=2.3515 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=521.2 | checkpoint=-
# [train] step=117/250 | warm=0 | policy=32 | replay=13744 | world_total=11353.5269 | actor=-6.3594 | critic=2.4090 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=526.0 | checkpoint=-
# [train] step=118/250 | warm=0 | policy=32 | replay=13776 | world_total=11352.8864 | actor=-6.8633 | critic=2.5871 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=530.5 | checkpoint=-
# [train] step=119/250 | warm=0 | policy=32 | replay=13808 | world_total=11352.3820 | actor=-7.8320 | critic=2.4150 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=534.8 | checkpoint=-
# [train] step=120/250 | warm=0 | policy=32 | replay=13840 | world_total=11352.7339 | actor=-8.5781 | critic=2.6085 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=539.1 | checkpoint=-
# [train] step=121/250 | warm=0 | policy=32 | replay=13872 | world_total=11352.4071 | actor=-9.7500 | critic=2.8118 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=543.9 | checkpoint=-
# [train] step=122/250 | warm=0 | policy=32 | replay=13904 | world_total=11352.2998 | actor=-10.2891 | critic=2.6977 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=548.3 | checkpoint=-
# [train] step=123/250 | warm=0 | policy=32 | replay=13936 | world_total=11352.1699 | actor=-10.9141 | critic=2.9641 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=553.1 | checkpoint=-
# [train] step=124/250 | warm=0 | policy=32 | replay=13968 | world_total=11351.8795 | actor=-11.3594 | critic=2.9848 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=557.8 | checkpoint=-
# [train] step=125/250 | warm=0 | policy=32 | replay=14000 | world_total=11351.6274 | actor=-12.8594 | critic=2.8066 | eval_reward=2.2565 | cycle_s=12.9 | elapsed_s=570.7 | checkpoint=checkpoint_00125.pt
# [train] step=126/250 | warm=0 | policy=32 | replay=14032 | world_total=11351.2589 | actor=-13.8438 | critic=2.5400 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=574.1 | checkpoint=-
# [train] step=127/250 | warm=0 | policy=32 | replay=14064 | world_total=11352.1353 | actor=-14.9375 | critic=2.6538 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=578.9 | checkpoint=-
# [train] step=128/250 | warm=0 | policy=32 | replay=14096 | world_total=11352.1018 | actor=-15.2109 | critic=3.5849 | eval_reward=n/a | cycle_s=7.6 | elapsed_s=586.4 | checkpoint=-
# [train] step=129/250 | warm=0 | policy=32 | replay=14128 | world_total=11351.4663 | actor=-15.2969 | critic=3.7732 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=591.4 | checkpoint=-
# [train] step=130/250 | warm=0 | policy=32 | replay=14160 | world_total=11350.8369 | actor=-15.2891 | critic=2.8347 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=596.4 | checkpoint=-
# [train] step=131/250 | warm=0 | policy=32 | replay=14192 | world_total=11351.1166 | actor=-14.1953 | critic=4.7830 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=600.7 | checkpoint=-
# [train] step=132/250 | warm=0 | policy=32 | replay=14224 | world_total=11350.5242 | actor=-14.5000 | critic=2.9411 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=605.8 | checkpoint=-
# [train] step=133/250 | warm=0 | policy=32 | replay=14256 | world_total=11350.5254 | actor=-15.5781 | critic=3.1239 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=610.2 | checkpoint=-
# [train] step=134/250 | warm=0 | policy=32 | replay=14288 | world_total=11350.0264 | actor=-15.5156 | critic=3.5100 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=614.5 | checkpoint=-
# [train] step=135/250 | warm=0 | policy=32 | replay=14320 | world_total=11349.8162 | actor=-16.7656 | critic=3.4086 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=619.5 | checkpoint=-
# [train] step=136/250 | warm=0 | policy=32 | replay=14352 | world_total=11349.2288 | actor=-16.7344 | critic=3.4568 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=623.6 | checkpoint=-
# [train] step=137/250 | warm=0 | policy=32 | replay=14384 | world_total=11350.3389 | actor=-16.8594 | critic=3.8230 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=628.0 | checkpoint=-
# [train] step=138/250 | warm=0 | policy=32 | replay=14416 | world_total=11349.8977 | actor=-16.3594 | critic=3.7602 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=632.8 | checkpoint=-
# [train] step=139/250 | warm=0 | policy=32 | replay=14448 | world_total=11349.6882 | actor=-15.3672 | critic=4.0870 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=637.8 | checkpoint=-
# [train] step=140/250 | warm=0 | policy=32 | replay=14480 | world_total=11349.7168 | actor=-15.5156 | critic=2.8493 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=642.8 | checkpoint=-
# [train] step=141/250 | warm=0 | policy=32 | replay=14512 | world_total=11349.4232 | actor=-15.2422 | critic=3.1871 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=647.3 | checkpoint=-
# [train] step=142/250 | warm=0 | policy=32 | replay=14544 | world_total=11348.8821 | actor=-16.1719 | critic=2.7133 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=651.5 | checkpoint=-
# [train] step=143/250 | warm=0 | policy=32 | replay=14576 | world_total=11348.5333 | actor=-16.8281 | critic=3.2462 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=656.1 | checkpoint=-
# [train] step=144/250 | warm=0 | policy=32 | replay=14608 | world_total=11348.3350 | actor=-18.1406 | critic=3.2190 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=662.0 | checkpoint=-
# [train] step=145/250 | warm=0 | policy=32 | replay=14640 | world_total=11347.9280 | actor=-19.7500 | critic=3.3000 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=666.1 | checkpoint=-
# [train] step=146/250 | warm=0 | policy=32 | replay=14672 | world_total=11347.5271 | actor=-18.6406 | critic=5.7340 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=670.4 | checkpoint=-
# [train] step=147/250 | warm=0 | policy=32 | replay=14704 | world_total=11347.2836 | actor=-17.7812 | critic=4.5478 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=674.9 | checkpoint=-
# [train] step=148/250 | warm=0 | policy=32 | replay=14736 | world_total=11346.5059 | actor=-16.7812 | critic=4.1967 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=680.0 | checkpoint=-
# [train] step=149/250 | warm=0 | policy=32 | replay=14768 | world_total=11346.6659 | actor=-16.6094 | critic=3.3356 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=684.5 | checkpoint=-
# [train] step=150/250 | warm=0 | policy=32 | replay=14800 | world_total=11346.2916 | actor=-18.3594 | critic=3.4118 | eval_reward=3.7161 | cycle_s=12.9 | elapsed_s=697.4 | checkpoint=checkpoint_00150.pt
# [train] step=151/250 | warm=0 | policy=32 | replay=14832 | world_total=11346.2026 | actor=-20.5000 | critic=3.7111 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=701.1 | checkpoint=-
# [train] step=152/250 | warm=0 | policy=32 | replay=14864 | world_total=11345.8752 | actor=-22.5938 | critic=3.8007 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=705.5 | checkpoint=-
# [train] step=153/250 | warm=0 | policy=32 | replay=14896 | world_total=11345.5989 | actor=-20.9688 | critic=9.4722 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=709.8 | checkpoint=-
# [train] step=154/250 | warm=0 | policy=32 | replay=14928 | world_total=11345.0913 | actor=-18.7812 | critic=5.8187 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=715.0 | checkpoint=-
# [train] step=155/250 | warm=0 | policy=32 | replay=14960 | world_total=11345.0118 | actor=-16.2891 | critic=4.6229 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=719.3 | checkpoint=-
# [train] step=156/250 | warm=0 | policy=32 | replay=14992 | world_total=11345.0303 | actor=-15.0547 | critic=3.6444 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=724.1 | checkpoint=-
# [train] step=157/250 | warm=0 | policy=32 | replay=15024 | world_total=11344.9714 | actor=-15.5781 | critic=3.1086 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=729.0 | checkpoint=-
# [train] step=158/250 | warm=0 | policy=32 | replay=15056 | world_total=11344.4431 | actor=-16.3750 | critic=2.9940 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=733.4 | checkpoint=-
# [train] step=159/250 | warm=0 | policy=32 | replay=15088 | world_total=11344.1870 | actor=-16.7969 | critic=4.9116 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=738.3 | checkpoint=-
# [train] step=160/250 | warm=0 | policy=32 | replay=15120 | world_total=11344.0504 | actor=-16.1562 | critic=5.7690 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=742.9 | checkpoint=-
# [train] step=161/250 | warm=0 | policy=32 | replay=15152 | world_total=11343.5150 | actor=-16.1562 | critic=4.5288 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=747.1 | checkpoint=-
# [train] step=162/250 | warm=0 | policy=32 | replay=15184 | world_total=11343.3082 | actor=-15.0469 | critic=3.7732 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=751.0 | checkpoint=-
# [train] step=163/250 | warm=0 | policy=32 | replay=15216 | world_total=11343.2166 | actor=-15.6328 | critic=3.6956 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=755.5 | checkpoint=-
# [train] step=164/250 | warm=0 | policy=32 | replay=15248 | world_total=11342.8661 | actor=-15.5859 | critic=3.1873 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=760.3 | checkpoint=-
# [train] step=165/250 | warm=0 | policy=32 | replay=15280 | world_total=11342.9358 | actor=-16.0000 | critic=3.8095 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=764.8 | checkpoint=-
# [train] step=166/250 | warm=0 | policy=32 | replay=15312 | world_total=11342.5619 | actor=-17.5938 | critic=3.9749 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=769.2 | checkpoint=-
# [train] step=167/250 | warm=0 | policy=32 | replay=15344 | world_total=11342.2323 | actor=-17.5938 | critic=3.7618 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=773.8 | checkpoint=-
# [train] step=168/250 | warm=0 | policy=32 | replay=15376 | world_total=11342.0697 | actor=-19.0000 | critic=3.8499 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=778.2 | checkpoint=-
# [train] step=169/250 | warm=0 | policy=32 | replay=15408 | world_total=11342.0084 | actor=-19.2031 | critic=4.4820 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=783.2 | checkpoint=-
# [train] step=170/250 | warm=0 | policy=32 | replay=15440 | world_total=11341.5680 | actor=-18.8906 | critic=4.3923 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=789.1 | checkpoint=-
# [train] step=171/250 | warm=0 | policy=32 | replay=15472 | world_total=11341.5709 | actor=-18.6562 | critic=3.9389 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=793.1 | checkpoint=-
# [train] step=172/250 | warm=0 | policy=32 | replay=15504 | world_total=11341.3615 | actor=-17.9219 | critic=4.1808 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=797.2 | checkpoint=-
# [train] step=173/250 | warm=0 | policy=32 | replay=15536 | world_total=11340.8771 | actor=-18.2969 | critic=3.4235 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=801.6 | checkpoint=-
# [train] step=174/250 | warm=0 | policy=32 | replay=15568 | world_total=11340.8466 | actor=-19.0781 | critic=3.0802 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=805.9 | checkpoint=-
# [train] step=175/250 | warm=0 | policy=32 | replay=15600 | world_total=11340.6813 | actor=-19.8594 | critic=3.5182 | eval_reward=9.2730 | cycle_s=13.2 | elapsed_s=819.1 | checkpoint=checkpoint_00175.pt
# [train] step=176/250 | warm=0 | policy=32 | replay=15632 | world_total=11340.5323 | actor=-19.9219 | critic=4.0779 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=822.5 | checkpoint=-
# [train] step=177/250 | warm=0 | policy=32 | replay=15664 | world_total=11340.2296 | actor=-20.2500 | critic=3.6908 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=827.6 | checkpoint=-
# [train] step=178/250 | warm=0 | policy=32 | replay=15696 | world_total=11339.9419 | actor=-18.3750 | critic=6.2998 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=832.0 | checkpoint=-
# [train] step=179/250 | warm=0 | policy=32 | replay=15728 | world_total=11340.1389 | actor=-16.7969 | critic=3.7769 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=838.6 | checkpoint=-
# [train] step=180/250 | warm=0 | policy=32 | replay=15760 | world_total=11339.6659 | actor=-16.7031 | critic=2.7920 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=843.2 | checkpoint=-
# [train] step=181/250 | warm=0 | policy=32 | replay=15792 | world_total=11339.4320 | actor=-16.5000 | critic=3.0289 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=847.8 | checkpoint=-
# [train] step=182/250 | warm=0 | policy=32 | replay=15824 | world_total=11339.2756 | actor=-17.7031 | critic=3.5111 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=852.1 | checkpoint=-
# [train] step=183/250 | warm=0 | policy=32 | replay=15856 | world_total=11339.1494 | actor=-17.1719 | critic=3.7026 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=856.7 | checkpoint=-
# [train] step=184/250 | warm=0 | policy=32 | replay=15888 | world_total=11339.1937 | actor=-16.9688 | critic=4.2753 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=861.8 | checkpoint=-
# [train] step=185/250 | warm=0 | policy=32 | replay=15920 | world_total=11338.7753 | actor=-16.2344 | critic=3.4123 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=865.8 | checkpoint=-
# [train] step=186/250 | warm=0 | policy=32 | replay=15952 | world_total=11338.7007 | actor=-15.8438 | critic=3.0582 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=870.4 | checkpoint=-
# [train] step=187/250 | warm=0 | policy=32 | replay=15984 | world_total=11338.5616 | actor=-17.7500 | critic=3.8469 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=875.6 | checkpoint=-
# [train] step=188/250 | warm=0 | policy=32 | replay=16016 | world_total=11338.7488 | actor=-18.3281 | critic=2.6588 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=879.9 | checkpoint=-
# [train] step=189/250 | warm=0 | policy=32 | replay=16048 | world_total=11338.4656 | actor=-18.4531 | critic=5.3219 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=884.2 | checkpoint=-
# [train] step=190/250 | warm=0 | policy=32 | replay=16080 | world_total=11338.1031 | actor=-17.7500 | critic=4.1546 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=888.7 | checkpoint=-
# [train] step=191/250 | warm=0 | policy=32 | replay=16112 | world_total=11338.1636 | actor=-18.4844 | critic=3.0766 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=893.3 | checkpoint=-
# [train] step=192/250 | warm=0 | policy=32 | replay=16144 | world_total=11338.1057 | actor=-19.0781 | critic=2.8389 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=897.9 | checkpoint=-
# [train] step=193/250 | warm=0 | policy=32 | replay=16176 | world_total=11337.9492 | actor=-19.7344 | critic=2.8709 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=902.7 | checkpoint=-
# [train] step=194/250 | warm=0 | policy=32 | replay=16208 | world_total=11338.3457 | actor=-20.0312 | critic=3.6984 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=907.0 | checkpoint=-
# [train] step=195/250 | warm=0 | policy=32 | replay=16240 | world_total=11337.6970 | actor=-20.1562 | critic=3.7216 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=911.5 | checkpoint=-
# [train] step=196/250 | warm=0 | policy=32 | replay=16272 | world_total=11337.3986 | actor=-20.2969 | critic=3.1405 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=916.5 | checkpoint=-
# [train] step=197/250 | warm=0 | policy=32 | replay=16304 | world_total=11337.1613 | actor=-19.5469 | critic=4.0077 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=921.5 | checkpoint=-
# [train] step=198/250 | warm=0 | policy=32 | replay=16336 | world_total=11336.9000 | actor=-17.8906 | critic=4.5348 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=925.8 | checkpoint=-
# [train] step=199/250 | warm=0 | policy=32 | replay=16368 | world_total=11336.7914 | actor=-18.3906 | critic=3.0725 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=929.8 | checkpoint=-
# [train] step=200/250 | warm=0 | policy=32 | replay=16400 | world_total=11336.7474 | actor=-18.5156 | critic=2.6225 | eval_reward=0.6366 | cycle_s=12.6 | elapsed_s=942.4 | checkpoint=checkpoint_00200.pt
# [train] step=201/250 | warm=0 | policy=32 | replay=16432 | world_total=11336.6776 | actor=-20.2031 | critic=3.4546 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=945.9 | checkpoint=-
# [train] step=202/250 | warm=0 | policy=32 | replay=16464 | world_total=11336.3958 | actor=-21.4688 | critic=3.5701 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=953.4 | checkpoint=-
# [train] step=203/250 | warm=0 | policy=32 | replay=16496 | world_total=11336.6519 | actor=-22.0469 | critic=3.9714 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=958.1 | checkpoint=-
# [train] step=204/250 | warm=0 | policy=32 | replay=16528 | world_total=11336.4698 | actor=-21.2500 | critic=5.3354 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=962.8 | checkpoint=-
# [train] step=205/250 | warm=0 | policy=32 | replay=16560 | world_total=11335.9916 | actor=-21.0938 | critic=2.8625 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=966.1 | checkpoint=-
# [train] step=206/250 | warm=0 | policy=32 | replay=16592 | world_total=11335.9800 | actor=-20.2031 | critic=3.3425 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=970.2 | checkpoint=-
# [train] step=207/250 | warm=0 | policy=32 | replay=16624 | world_total=11336.0070 | actor=-19.5156 | critic=3.6913 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=974.7 | checkpoint=-
# [train] step=208/250 | warm=0 | policy=32 | replay=16656 | world_total=11335.5930 | actor=-17.2500 | critic=6.2943 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=978.4 | checkpoint=-
# [train] step=209/250 | warm=0 | policy=32 | replay=16688 | world_total=11335.6327 | actor=-17.6719 | critic=3.0576 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=982.6 | checkpoint=-
# [train] step=210/250 | warm=0 | policy=32 | replay=16720 | world_total=11335.6113 | actor=-17.1562 | critic=2.6289 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=986.8 | checkpoint=-
# [train] step=211/250 | warm=0 | policy=32 | replay=16752 | world_total=11335.4076 | actor=-19.0312 | critic=3.1875 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=991.5 | checkpoint=-
# [train] step=212/250 | warm=0 | policy=32 | replay=16784 | world_total=11335.2635 | actor=-20.5625 | critic=3.0602 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=995.8 | checkpoint=-
# [train] step=213/250 | warm=0 | policy=32 | replay=16816 | world_total=11335.0238 | actor=-19.8906 | critic=5.5771 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=1000.7 | checkpoint=-
# [train] step=214/250 | warm=0 | policy=32 | replay=16848 | world_total=11334.9054 | actor=-20.0156 | critic=4.0199 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=1005.5 | checkpoint=-
# [train] step=215/250 | warm=0 | policy=32 | replay=16880 | world_total=11334.9243 | actor=-18.2969 | critic=4.7235 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1010.2 | checkpoint=-
# [train] step=216/250 | warm=0 | policy=32 | replay=16912 | world_total=11334.8510 | actor=-16.9375 | critic=3.7138 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1014.2 | checkpoint=-
# [train] step=217/250 | warm=0 | policy=32 | replay=16944 | world_total=11334.5780 | actor=-17.6094 | critic=3.3501 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=1019.1 | checkpoint=-
# [train] step=218/250 | warm=0 | policy=32 | replay=16976 | world_total=11335.2443 | actor=-17.3594 | critic=3.2007 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=1024.7 | checkpoint=-
# [train] step=219/250 | warm=0 | policy=32 | replay=17008 | world_total=11335.2360 | actor=-17.9219 | critic=2.6239 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1028.8 | checkpoint=-
# [train] step=220/250 | warm=0 | policy=32 | replay=17040 | world_total=11335.2910 | actor=-18.2031 | critic=3.1887 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1033.1 | checkpoint=-
# [train] step=221/250 | warm=0 | policy=32 | replay=17072 | world_total=11335.1046 | actor=-18.7031 | critic=3.1926 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1037.1 | checkpoint=-
# [train] step=222/250 | warm=0 | policy=32 | replay=17104 | world_total=11334.7332 | actor=-19.1094 | critic=2.9227 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1041.6 | checkpoint=-
# [train] step=223/250 | warm=0 | policy=32 | replay=17136 | world_total=11334.6819 | actor=-20.7031 | critic=3.0724 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1046.0 | checkpoint=-
# [train] step=224/250 | warm=0 | policy=32 | replay=17168 | world_total=11334.7970 | actor=-21.8125 | critic=3.0166 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1050.5 | checkpoint=-
# [train] step=225/250 | warm=0 | policy=32 | replay=17200 | world_total=11334.4250 | actor=-22.9219 | critic=3.6154 | eval_reward=7.6431 | cycle_s=14.1 | elapsed_s=1064.6 | checkpoint=checkpoint_00225.pt
# [train] step=226/250 | warm=0 | policy=32 | replay=17232 | world_total=11334.4253 | actor=-24.0625 | critic=3.1906 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=1067.7 | checkpoint=-
# [train] step=227/250 | warm=0 | policy=32 | replay=17264 | world_total=11333.8092 | actor=-23.5156 | critic=5.2803 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1072.1 | checkpoint=-
# [train] step=228/250 | warm=0 | policy=32 | replay=17296 | world_total=11333.5585 | actor=-23.1094 | critic=3.7497 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1076.0 | checkpoint=-
# [train] step=229/250 | warm=0 | policy=32 | replay=17328 | world_total=11333.6096 | actor=-21.6094 | critic=3.8207 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1080.6 | checkpoint=-
# [train] step=230/250 | warm=0 | policy=32 | replay=17360 | world_total=11333.2717 | actor=-21.9062 | critic=2.9382 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1085.2 | checkpoint=-
# [train] step=231/250 | warm=0 | policy=32 | replay=17392 | world_total=11333.1638 | actor=-21.8438 | critic=3.1244 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1089.8 | checkpoint=-
# [train] step=232/250 | warm=0 | policy=32 | replay=17424 | world_total=11332.9594 | actor=-21.7812 | critic=3.7725 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1094.5 | checkpoint=-
# [train] step=233/250 | warm=0 | policy=32 | replay=17456 | world_total=11332.6667 | actor=-20.7344 | critic=4.9058 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1099.2 | checkpoint=-
# [train] step=234/250 | warm=0 | policy=32 | replay=17488 | world_total=11332.7533 | actor=-19.2031 | critic=4.1447 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1103.7 | checkpoint=-
# [train] step=235/250 | warm=0 | policy=32 | replay=17520 | world_total=11332.5677 | actor=-18.9531 | critic=3.1560 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1107.9 | checkpoint=-
# [train] step=236/250 | warm=0 | policy=32 | replay=17552 | world_total=11332.7111 | actor=-18.6250 | critic=2.6521 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1111.8 | checkpoint=-
# [train] step=237/250 | warm=0 | policy=32 | replay=17584 | world_total=11332.4250 | actor=-20.2344 | critic=3.2150 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1115.8 | checkpoint=-
# [train] step=238/250 | warm=0 | policy=32 | replay=17616 | world_total=11332.3693 | actor=-20.8594 | critic=3.0843 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1120.3 | checkpoint=-
# [train] step=239/250 | warm=0 | policy=32 | replay=17648 | world_total=11332.1575 | actor=-22.7344 | critic=2.9766 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1124.4 | checkpoint=-
# [train] step=240/250 | warm=0 | policy=32 | replay=17680 | world_total=11332.0698 | actor=-22.6094 | critic=4.3210 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1128.1 | checkpoint=-
# [train] step=241/250 | warm=0 | policy=32 | replay=17712 | world_total=11332.2378 | actor=-22.6719 | critic=3.3446 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1132.1 | checkpoint=-
# [train] step=242/250 | warm=0 | policy=32 | replay=17744 | world_total=11331.9481 | actor=-22.7969 | critic=2.8808 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1136.3 | checkpoint=-
# [train] step=243/250 | warm=0 | policy=32 | replay=17776 | world_total=11331.9791 | actor=-22.5469 | critic=3.4328 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1140.6 | checkpoint=-
# [train] step=244/250 | warm=0 | policy=32 | replay=17808 | world_total=11331.9551 | actor=-22.3750 | critic=3.4753 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1144.3 | checkpoint=-
# [train] step=245/250 | warm=0 | policy=32 | replay=17840 | world_total=11331.7754 | actor=-22.9531 | critic=2.4463 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1148.5 | checkpoint=-
# [train] step=246/250 | warm=0 | policy=32 | replay=17872 | world_total=11331.8472 | actor=-21.9219 | critic=4.3488 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1152.2 | checkpoint=-
# [train] step=247/250 | warm=0 | policy=32 | replay=17904 | world_total=11331.5833 | actor=-21.1562 | critic=3.4595 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1156.1 | checkpoint=-
# [train] step=248/250 | warm=0 | policy=32 | replay=17936 | world_total=11331.3821 | actor=-19.9844 | critic=3.3890 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1159.7 | checkpoint=-
# [train] step=249/250 | warm=0 | policy=32 | replay=17968 | world_total=11331.5020 | actor=-20.4688 | critic=2.9559 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1163.9 | checkpoint=-
# [train] step=250/250 | warm=0 | policy=32 | replay=18000 | world_total=11331.2253 | actor=-20.5781 | critic=3.0217 | eval_reward=11.2190 | cycle_s=14.4 | elapsed_s=1178.3 | checkpoint=checkpoint_00250.pt
# Completed cycles: 250
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter9_high_speed_reward/checkpoints/checkpoint_00250.pt
# Latest metrics: {'step': 250, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 18000, 'world_model/reconstruction_loss': 11318.766967773438, 'world_model/reconstruction_mse': 0.004370145557913929, 'world_model/observation_log_prob': -11318.766967773438, 'world_model/reward_loss': 1.2200227975845337, 'world_model/continue_loss': 0.02187518449500203, 'world_model/kl_loss': 7.293732643127441, 'world_model/kl_loss_raw': 7.293732643127441, 'world_model/overshooting_kl_loss': 7.845239460468292, 'world_model/overshooting_feature_mse': 0.08175568468868732, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11331.225341796875, 'behavior/actor_loss': -20.578125, 'behavior/critic_loss': 3.0217340886592865, 'behavior/imagined_reward_mean': 0.58984375, 'behavior/imagined_value_mean': 20.234375, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 11.218954943090624, 'evaluation/mean_steps': 27.2, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter9_high_speed_reward/checkpoints/checkpoint_00250.pt',
#  'latest_metrics': {'behavior/actor_loss': -20.578125,
#   'behavior/critic_loss': 3.0217340886592865,
#   'behavior/imagined_reward_mean': 0.58984375,
#   'behavior/imagined_value_mean': 20.234375,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 11.218954943090624,
#   'evaluation/mean_steps': 27.2,
#   'policy_added': 32,
#   'replay_size': 18000,
#   'step': 250,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.02187518449500203,
#   'world_model/kl_loss': 7.293732643127441,
#   'world_model/kl_loss_raw': 7.293732643127441,
#   'world_model/observation_log_prob': -11318.766967773438,
#   'world_model/overshooting_feature_mse': 0.08175568468868732,
#   'world_model/overshooting_kl_loss': 7.845239460468292,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11318.766967773438,
#   'world_model/reconstruction_mse': 0.004370145557913929,
#   'world_model/reward_loss': 1.2200227975845337,
#   'world_model/total_loss': 11331.225341796875},
#  'latest_step': 250}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 11.218954943090624,
#   'best_eval_reward_step': 250,
#   'best_imagined_reward_mean': 0.62841796875,
#   'best_imagined_reward_step': 240,
#   'best_world_model_step': 250,
#   'best_world_model_total_loss': 11331.225341796875,
#   'largest_replay_size': 18000,
#   'largest_replay_step': 250,
#   'last_metrics': {'behavior/actor_loss': -20.578125,
#    'behavior/critic_loss': 3.0217340886592865,
#    'behavior/imagined_reward_mean': 0.58984375,
#    'behavior/imagined_value_mean': 20.234375,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 11.218954943090624,
#    'evaluation/mean_steps': 27.2,
#    'policy_added': 32,
#    'replay_size': 18000,
#    'step': 250,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.02187518449500203,
#    'world_model/kl_loss': 7.293732643127441,
#    'world_model/kl_loss_raw': 7.293732643127441,
#    'world_model/observation_log_prob': -11318.766967773438,
#    'world_model/overshooting_feature_mse': 0.08175568468868732,
#    'world_model/overshooting_kl_loss': 7.845239460468292,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11318.766967773438,
#    'world_model/reconstruction_mse': 0.004370145557913929,
#    'world_model/reward_loss': 1.2200227975845337,
#    'world_model/total_loss': 11331.225341796875},
#   'last_step': 250,
#   'num_records': 225},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11318.766967773438',
#   'world_model/reconstruction_mse': '0.004370145557913929',
#   'world_model/observation_log_prob': '-11318.766967773438',
#   'world_model/overshooting_kl_loss': '7.845239460468292',
#   'world_model/overshooting_feature_mse': '0.08175568468868732',
#   'evaluation/mean_reward': '11.218954943090624',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=8 | reward=-0.98 | CRASH | saved iter9_high_speed_reward_ep01.gif
# [demo] episode 2/10 | steps=51 | reward=32.24 | CRASH | saved iter9_high_speed_reward_ep02.gif
# [demo] episode 3/10 | steps=9 | reward=1.47 | CRASH | saved iter9_high_speed_reward_ep03.gif
# [demo] episode 4/10 | steps=30 | reward=14.27 | CRASH | saved iter9_high_speed_reward_ep04.gif
# [demo] episode 5/10 | steps=30 | reward=12.60 | CRASH | saved iter9_high_speed_reward_ep05.gif
# [demo] episode 6/10 | steps=37 | reward=20.11 | CRASH | saved iter9_high_speed_reward_ep06.gif
# [demo] episode 7/10 | steps=28 | reward=13.79 | CRASH | saved iter9_high_speed_reward_ep07.gif
# [demo] episode 8/10 | steps=9 | reward=-1.03 | CRASH | saved iter9_high_speed_reward_ep08.gif
# [demo] episode 9/10 | steps=7 | reward=-0.99 | CRASH | saved iter9_high_speed_reward_ep09.gif
# [demo] episode 10/10 | steps=7 | reward=-1.03 | CRASH | saved iter9_high_speed_reward_ep10.gif
# [demo] done | avg_reward=9.04 | summary=iter9_high_speed_reward_summary.json
#
# iter9_high_speed_reward_ep01.gif
# iter9_high_speed_reward_ep02.gif
# iter9_high_speed_reward_ep03.gif
# iter9_high_speed_reward_ep04.gif
# iter9_high_speed_reward_ep05.gif
# iter9_high_speed_reward_ep06.gif
# iter9_high_speed_reward_ep07.gif
# iter9_high_speed_reward_ep08.gif
# iter9_high_speed_reward_ep09.gif
# iter9_high_speed_reward_ep10.gif
