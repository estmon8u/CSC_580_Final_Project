# %% [markdown]
# # Tiny Dreamer Highway — Iter 15: batch_size
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10
# **New change:** `batch_size: 256 → 384`
# **Hypothesis:** Larger batches give more diverse transitions per update, reducing gradient noise and improving learned dynamics consistency.

# %% [markdown]
# ## Iteration 15 — Batch diversity
#
# With frame_stack=3, each sample is larger. Bigger batches ensure the model sees varied traffic scenarios every update.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base + Iter10 winner (current best config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3
config.env.reward.steering_penalty = 0.025

print('\nBase overrides (iter5 + iter10):')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')
print(f'  steering_penalty = {config.env.reward.steering_penalty}')

# --- Iter 15 Override: batch_size ---
# batch_size 256 → 384: more diverse transitions per update
config.training.batch_size = 384

print('Iter 15 override:')
print(f'  batch_size = {config.training.batch_size}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Base overrides (iter5 + iter10):
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#   steering_penalty = 0.025
# Iter 15 override:
#   batch_size = 384

# %%
RUN_NAME = 'iter15_batch_size'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 1500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter15_batch_size/checkpoints/checkpoint_01000.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter15_batch_size
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter15_batch_size/checkpoints/checkpoint_01000.pt
# Effective cycles: 2000
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=1500 | start_step=1001 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1001/1500 | warm=0 | policy=32 | replay=42032 | world_total=11320.8741 | actor=-8.3125 | critic=6.4927 | eval_reward=n/a | cycle_s=6.6 | elapsed_s=6.6 | checkpoint=-
# [train] step=1002/1500 | warm=0 | policy=32 | replay=42064 | world_total=11346.8530 | actor=-4.1211 | critic=6.3006 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=10.2 | checkpoint=-
# [train] step=1003/1500 | warm=0 | policy=32 | replay=42096 | world_total=11329.7483 | actor=-10.4453 | critic=12.7955 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=13.6 | checkpoint=-
# [train] step=1004/1500 | warm=0 | policy=32 | replay=42128 | world_total=11323.9484 | actor=-11.0156 | critic=7.9469 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=17.4 | checkpoint=-
# [train] step=1005/1500 | warm=0 | policy=32 | replay=42160 | world_total=11322.1969 | actor=-12.3906 | critic=9.7327 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=21.0 | checkpoint=-
# [train] step=1006/1500 | warm=0 | policy=32 | replay=42192 | world_total=11321.4655 | actor=-12.6562 | critic=10.1707 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=24.4 | checkpoint=-
# [train] step=1007/1500 | warm=0 | policy=32 | replay=42224 | world_total=11321.2079 | actor=-10.5547 | critic=11.3443 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=27.8 | checkpoint=-
# [train] step=1008/1500 | warm=0 | policy=32 | replay=42256 | world_total=11320.9741 | actor=-8.9922 | critic=7.7823 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=31.1 | checkpoint=-
# [train] step=1009/1500 | warm=0 | policy=32 | replay=42288 | world_total=11320.9192 | actor=-9.0703 | critic=6.9645 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=34.5 | checkpoint=-
# [train] step=1010/1500 | warm=0 | policy=32 | replay=42320 | world_total=11320.9012 | actor=-10.7656 | critic=8.9557 | eval_reward=n/a | cycle_s=6.8 | elapsed_s=41.3 | checkpoint=-
# [train] step=1011/1500 | warm=0 | policy=32 | replay=42352 | world_total=11320.8685 | actor=-9.9297 | critic=7.5679 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=45.1 | checkpoint=-
# [train] step=1012/1500 | warm=0 | policy=32 | replay=42384 | world_total=11320.8416 | actor=-9.6406 | critic=7.4494 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=48.9 | checkpoint=-
# [train] step=1013/1500 | warm=0 | policy=32 | replay=42416 | world_total=11320.8032 | actor=-9.8516 | critic=6.4423 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=52.6 | checkpoint=-
# [train] step=1014/1500 | warm=0 | policy=32 | replay=42448 | world_total=11320.8567 | actor=-10.1016 | critic=6.0895 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=56.5 | checkpoint=-
# [train] step=1015/1500 | warm=0 | policy=32 | replay=42480 | world_total=11320.8766 | actor=-10.1719 | critic=6.0512 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=60.3 | checkpoint=-
# [train] step=1016/1500 | warm=0 | policy=32 | replay=42512 | world_total=11320.7916 | actor=-11.5625 | critic=7.1413 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=64.1 | checkpoint=-
# [train] step=1017/1500 | warm=0 | policy=32 | replay=42544 | world_total=11320.8140 | actor=-12.8047 | critic=7.8419 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=67.5 | checkpoint=-
# [train] step=1018/1500 | warm=0 | policy=32 | replay=42576 | world_total=11320.9148 | actor=-13.5469 | critic=7.8970 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=71.6 | checkpoint=-
# [train] step=1019/1500 | warm=0 | policy=32 | replay=42608 | world_total=11320.9130 | actor=-14.3203 | critic=9.8876 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=75.4 | checkpoint=-
# [train] step=1020/1500 | warm=0 | policy=32 | replay=42640 | world_total=11320.8865 | actor=-12.1641 | critic=9.9612 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=78.7 | checkpoint=-
# [train] step=1021/1500 | warm=0 | policy=32 | replay=42672 | world_total=11320.7476 | actor=-10.2188 | critic=7.8872 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=82.4 | checkpoint=-
# [train] step=1022/1500 | warm=0 | policy=32 | replay=42704 | world_total=11320.8795 | actor=-9.7266 | critic=6.2940 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=85.9 | checkpoint=-
# [train] step=1023/1500 | warm=0 | policy=32 | replay=42736 | world_total=11320.8549 | actor=-10.2578 | critic=6.8551 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=89.5 | checkpoint=-
# [train] step=1024/1500 | warm=0 | policy=32 | replay=42768 | world_total=11320.8998 | actor=-12.0938 | critic=8.1808 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=92.9 | checkpoint=-
# [train] step=1025/1500 | warm=0 | policy=32 | replay=42800 | world_total=11320.8436 | actor=-11.6797 | critic=8.3277 | eval_reward=3.0577 | cycle_s=15.4 | elapsed_s=108.3 | checkpoint=checkpoint_01025.pt
# [train] step=1026/1500 | warm=0 | policy=32 | replay=42832 | world_total=11320.8806 | actor=-11.5938 | critic=8.5884 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=112.5 | checkpoint=-
# [train] step=1027/1500 | warm=0 | policy=32 | replay=42864 | world_total=11320.8409 | actor=-10.1484 | critic=7.7440 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=116.0 | checkpoint=-
# [train] step=1028/1500 | warm=0 | policy=32 | replay=42896 | world_total=11320.8802 | actor=-9.1328 | critic=6.7783 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=121.6 | checkpoint=-
# [train] step=1029/1500 | warm=0 | policy=32 | replay=42928 | world_total=11320.8099 | actor=-9.8203 | critic=6.9440 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=125.2 | checkpoint=-
# [train] step=1030/1500 | warm=0 | policy=32 | replay=42960 | world_total=11320.8726 | actor=-10.6016 | critic=7.4992 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=129.1 | checkpoint=-
# [train] step=1031/1500 | warm=0 | policy=32 | replay=42992 | world_total=11320.8735 | actor=-10.5781 | critic=7.2523 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=132.2 | checkpoint=-
# [train] step=1032/1500 | warm=0 | policy=32 | replay=43024 | world_total=11320.8492 | actor=-8.5781 | critic=8.3068 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=135.7 | checkpoint=-
# [train] step=1033/1500 | warm=0 | policy=32 | replay=43056 | world_total=11320.8784 | actor=-8.2461 | critic=5.9090 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=139.7 | checkpoint=-
# [train] step=1034/1500 | warm=0 | policy=32 | replay=43088 | world_total=11320.9166 | actor=-8.9141 | critic=6.2419 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=143.2 | checkpoint=-
# [train] step=1035/1500 | warm=0 | policy=32 | replay=43120 | world_total=11321.1975 | actor=-9.5703 | critic=6.2286 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=146.7 | checkpoint=-
# [train] step=1036/1500 | warm=0 | policy=32 | replay=43152 | world_total=11321.7336 | actor=-11.0547 | critic=7.3505 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=150.7 | checkpoint=-
# [train] step=1037/1500 | warm=0 | policy=32 | replay=43184 | world_total=11321.5549 | actor=-9.5078 | critic=7.6064 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=155.1 | checkpoint=-
# [train] step=1038/1500 | warm=0 | policy=32 | replay=43216 | world_total=11321.8800 | actor=-7.7891 | critic=6.9011 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=158.6 | checkpoint=-
# [train] step=1039/1500 | warm=0 | policy=32 | replay=43248 | world_total=11321.5813 | actor=-8.0781 | critic=6.1619 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=162.2 | checkpoint=-
# [train] step=1040/1500 | warm=0 | policy=32 | replay=43280 | world_total=11321.5331 | actor=-7.8477 | critic=5.3739 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=166.1 | checkpoint=-
# [train] step=1041/1500 | warm=0 | policy=32 | replay=43312 | world_total=11321.2644 | actor=-8.5547 | critic=5.9531 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=170.1 | checkpoint=-
# [train] step=1042/1500 | warm=0 | policy=32 | replay=43344 | world_total=11321.2780 | actor=-8.4453 | critic=5.8188 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=173.7 | checkpoint=-
# [train] step=1043/1500 | warm=0 | policy=32 | replay=43376 | world_total=11321.2501 | actor=-8.2852 | critic=5.9002 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=176.6 | checkpoint=-
# [train] step=1044/1500 | warm=0 | policy=32 | replay=43408 | world_total=11321.2295 | actor=-7.7969 | critic=5.6037 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=180.6 | checkpoint=-
# [train] step=1045/1500 | warm=0 | policy=32 | replay=43440 | world_total=11321.2496 | actor=-7.4414 | critic=5.2250 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=184.0 | checkpoint=-
# [train] step=1046/1500 | warm=0 | policy=32 | replay=43472 | world_total=11321.2469 | actor=-7.0469 | critic=5.1820 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=188.1 | checkpoint=-
# [train] step=1047/1500 | warm=0 | policy=32 | replay=43504 | world_total=11321.2020 | actor=-6.9844 | critic=5.0957 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=191.4 | checkpoint=-
# [train] step=1048/1500 | warm=0 | policy=32 | replay=43536 | world_total=11321.3981 | actor=-8.7422 | critic=6.9215 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=195.2 | checkpoint=-
# [train] step=1049/1500 | warm=0 | policy=32 | replay=43568 | world_total=11321.0271 | actor=-7.1914 | critic=6.7873 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=198.9 | checkpoint=-
# [train] step=1050/1500 | warm=0 | policy=32 | replay=43600 | world_total=11320.8566 | actor=-8.1719 | critic=5.7792 | eval_reward=0.0558 | cycle_s=20.7 | elapsed_s=219.6 | checkpoint=checkpoint_01050.pt
# [train] step=1051/1500 | warm=0 | policy=32 | replay=43632 | world_total=11320.7311 | actor=-7.8008 | critic=5.7493 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=224.2 | checkpoint=-
# [train] step=1052/1500 | warm=0 | policy=32 | replay=43664 | world_total=11320.7963 | actor=-8.3281 | critic=6.1790 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=231.4 | checkpoint=-
# [train] step=1053/1500 | warm=0 | policy=32 | replay=43696 | world_total=11320.7170 | actor=-7.6875 | critic=6.1103 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=235.4 | checkpoint=-
# [train] step=1054/1500 | warm=0 | policy=32 | replay=43728 | world_total=11320.6787 | actor=-6.5312 | critic=5.5552 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=239.3 | checkpoint=-
# [train] step=1055/1500 | warm=0 | policy=32 | replay=43760 | world_total=11320.7181 | actor=-6.2773 | critic=5.0337 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=243.8 | checkpoint=-
# [train] step=1056/1500 | warm=0 | policy=32 | replay=43792 | world_total=11320.7190 | actor=-7.0547 | critic=5.3081 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=248.1 | checkpoint=-
# [train] step=1057/1500 | warm=0 | policy=32 | replay=43824 | world_total=11320.7766 | actor=-7.0039 | critic=5.3373 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=252.2 | checkpoint=-
# [train] step=1058/1500 | warm=0 | policy=32 | replay=43856 | world_total=11320.7714 | actor=-8.1914 | critic=5.6990 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=256.8 | checkpoint=-
# [train] step=1059/1500 | warm=0 | policy=32 | replay=43888 | world_total=11320.7765 | actor=-7.4766 | critic=5.2051 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=261.0 | checkpoint=-
# [train] step=1060/1500 | warm=0 | policy=32 | replay=43920 | world_total=11320.7389 | actor=-7.2305 | critic=5.0432 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=265.1 | checkpoint=-
# [train] step=1061/1500 | warm=0 | policy=32 | replay=43952 | world_total=11320.7167 | actor=-7.5039 | critic=5.2774 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=269.4 | checkpoint=-
# [train] step=1062/1500 | warm=0 | policy=32 | replay=43984 | world_total=11320.6553 | actor=-7.8438 | critic=5.4087 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=274.2 | checkpoint=-
# [train] step=1063/1500 | warm=0 | policy=32 | replay=44016 | world_total=11320.6321 | actor=-9.1172 | critic=6.7035 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=278.5 | checkpoint=-
# [train] step=1064/1500 | warm=0 | policy=32 | replay=44048 | world_total=11320.6995 | actor=-10.7188 | critic=7.3964 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=282.4 | checkpoint=-
# [train] step=1065/1500 | warm=0 | policy=32 | replay=44080 | world_total=11320.7076 | actor=-11.0703 | critic=8.5911 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=286.3 | checkpoint=-
# [train] step=1066/1500 | warm=0 | policy=32 | replay=44112 | world_total=11320.8043 | actor=-11.7578 | critic=8.0601 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=290.3 | checkpoint=-
# [train] step=1067/1500 | warm=0 | policy=32 | replay=44144 | world_total=11320.7827 | actor=-10.4844 | critic=8.1802 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=294.1 | checkpoint=-
# [train] step=1068/1500 | warm=0 | policy=32 | replay=44176 | world_total=11320.7456 | actor=-8.5781 | critic=6.3654 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=298.2 | checkpoint=-
# [train] step=1069/1500 | warm=0 | policy=32 | replay=44208 | world_total=11320.7375 | actor=-7.9609 | critic=5.3329 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=303.5 | checkpoint=-
# [train] step=1070/1500 | warm=0 | policy=32 | replay=44240 | world_total=11320.8298 | actor=-6.9766 | critic=4.7740 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=308.2 | checkpoint=-
# [train] step=1071/1500 | warm=0 | policy=32 | replay=44272 | world_total=11320.7466 | actor=-7.9492 | critic=5.3198 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=311.8 | checkpoint=-
# [train] step=1072/1500 | warm=0 | policy=32 | replay=44304 | world_total=11320.7008 | actor=-7.9023 | critic=5.3157 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=315.8 | checkpoint=-
# [train] step=1073/1500 | warm=0 | policy=32 | replay=44336 | world_total=11320.7167 | actor=-8.5000 | critic=5.6885 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=320.3 | checkpoint=-
# [train] step=1074/1500 | warm=0 | policy=32 | replay=44368 | world_total=11320.7028 | actor=-8.1641 | critic=5.5239 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=323.6 | checkpoint=-
# [train] step=1075/1500 | warm=0 | policy=32 | replay=44400 | world_total=11320.7358 | actor=-6.8047 | critic=5.0443 | eval_reward=3.1867 | cycle_s=16.4 | elapsed_s=340.0 | checkpoint=checkpoint_01075.pt
# [train] step=1076/1500 | warm=0 | policy=32 | replay=44432 | world_total=11320.6594 | actor=-7.4453 | critic=5.6500 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=343.7 | checkpoint=-
# [train] step=1077/1500 | warm=0 | policy=32 | replay=44464 | world_total=11320.6796 | actor=-9.1484 | critic=6.4912 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=347.9 | checkpoint=-
# [train] step=1078/1500 | warm=0 | policy=32 | replay=44496 | world_total=11320.7375 | actor=-7.4844 | critic=8.5695 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=351.6 | checkpoint=-
# [train] step=1079/1500 | warm=0 | policy=32 | replay=44528 | world_total=11320.8960 | actor=-6.3789 | critic=5.0740 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=356.6 | checkpoint=-
# [train] step=1080/1500 | warm=0 | policy=32 | replay=44560 | world_total=11320.7939 | actor=-7.7695 | critic=7.1495 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=360.8 | checkpoint=-
# [train] step=1081/1500 | warm=0 | policy=32 | replay=44592 | world_total=11320.6769 | actor=-7.7617 | critic=5.6553 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=365.4 | checkpoint=-
# [train] step=1082/1500 | warm=0 | policy=32 | replay=44624 | world_total=11320.6650 | actor=-8.1875 | critic=6.2249 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=369.3 | checkpoint=-
# [train] step=1083/1500 | warm=0 | policy=32 | replay=44656 | world_total=11320.7166 | actor=-8.1953 | critic=5.3327 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=373.6 | checkpoint=-
# [train] step=1084/1500 | warm=0 | policy=32 | replay=44688 | world_total=11320.8098 | actor=-7.1367 | critic=5.0742 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=377.7 | checkpoint=-
# [train] step=1085/1500 | warm=0 | policy=32 | replay=44720 | world_total=11320.7516 | actor=-8.4375 | critic=5.6615 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=382.0 | checkpoint=-
# [train] step=1086/1500 | warm=0 | policy=32 | replay=44752 | world_total=11320.7905 | actor=-10.0000 | critic=7.0284 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=386.1 | checkpoint=-
# [train] step=1087/1500 | warm=0 | policy=32 | replay=44784 | world_total=11320.8032 | actor=-9.0625 | critic=7.5729 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=390.3 | checkpoint=-
# [train] step=1088/1500 | warm=0 | policy=32 | replay=44816 | world_total=11320.7953 | actor=-8.0781 | critic=5.3356 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=394.2 | checkpoint=-
# [train] step=1089/1500 | warm=0 | policy=32 | replay=44848 | world_total=11320.7262 | actor=-7.7891 | critic=4.9993 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=398.4 | checkpoint=-
# [train] step=1090/1500 | warm=0 | policy=32 | replay=44880 | world_total=11320.6740 | actor=-9.4688 | critic=6.7407 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=402.1 | checkpoint=-
# [train] step=1091/1500 | warm=0 | policy=32 | replay=44912 | world_total=11320.6641 | actor=-10.8750 | critic=6.8801 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=405.9 | checkpoint=-
# [train] step=1092/1500 | warm=0 | policy=32 | replay=44944 | world_total=11320.6422 | actor=-10.1328 | critic=8.8127 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=409.7 | checkpoint=-
# [train] step=1093/1500 | warm=0 | policy=32 | replay=44976 | world_total=11320.7665 | actor=-10.1094 | critic=6.7100 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=414.3 | checkpoint=-
# [train] step=1094/1500 | warm=0 | policy=32 | replay=45008 | world_total=11320.8448 | actor=-9.8125 | critic=6.5413 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=418.6 | checkpoint=-
# [train] step=1095/1500 | warm=0 | policy=32 | replay=45040 | world_total=11321.2295 | actor=-8.0078 | critic=6.1943 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=423.3 | checkpoint=-
# [train] step=1096/1500 | warm=0 | policy=32 | replay=45072 | world_total=11320.9263 | actor=-8.1250 | critic=5.3146 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=427.2 | checkpoint=-
# [train] step=1097/1500 | warm=0 | policy=32 | replay=45104 | world_total=11320.7693 | actor=-7.0508 | critic=4.8131 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=432.2 | checkpoint=-
# [train] step=1098/1500 | warm=0 | policy=32 | replay=45136 | world_total=11320.6677 | actor=-6.8711 | critic=4.2149 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=436.5 | checkpoint=-
# [train] step=1099/1500 | warm=0 | policy=32 | replay=45168 | world_total=11320.6774 | actor=-7.5547 | critic=4.3325 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=440.3 | checkpoint=-
# [train] step=1100/1500 | warm=0 | policy=32 | replay=45200 | world_total=11320.6237 | actor=-7.3203 | critic=4.2893 | eval_reward=4.0498 | cycle_s=19.4 | elapsed_s=459.6 | checkpoint=checkpoint_01100.pt
# [train] step=1101/1500 | warm=0 | policy=32 | replay=45232 | world_total=11320.6998 | actor=-7.8398 | critic=4.4918 | eval_reward=n/a | cycle_s=9.6 | elapsed_s=469.2 | checkpoint=-
# [train] step=1102/1500 | warm=0 | policy=32 | replay=45264 | world_total=11320.6886 | actor=-7.6523 | critic=4.5612 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=473.7 | checkpoint=-
# [train] step=1103/1500 | warm=0 | policy=32 | replay=45296 | world_total=11320.6824 | actor=-8.1484 | critic=4.9238 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=478.7 | checkpoint=-
# [train] step=1104/1500 | warm=0 | policy=32 | replay=45328 | world_total=11320.5853 | actor=-8.8203 | critic=5.7050 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=483.3 | checkpoint=-
# [train] step=1105/1500 | warm=0 | policy=32 | replay=45360 | world_total=11320.5670 | actor=-8.1641 | critic=5.3863 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=486.9 | checkpoint=-
# [train] step=1106/1500 | warm=0 | policy=32 | replay=45392 | world_total=11320.5648 | actor=-7.3438 | critic=4.5570 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=491.6 | checkpoint=-
# [train] step=1107/1500 | warm=0 | policy=32 | replay=45424 | world_total=11320.6232 | actor=-7.3008 | critic=4.7772 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=495.6 | checkpoint=-
# [train] step=1108/1500 | warm=0 | policy=32 | replay=45456 | world_total=11320.7078 | actor=-7.9492 | critic=5.1985 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=500.1 | checkpoint=-
# [train] step=1109/1500 | warm=0 | policy=32 | replay=45488 | world_total=11320.6334 | actor=-9.4453 | critic=6.0028 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=504.3 | checkpoint=-
# [train] step=1110/1500 | warm=0 | policy=32 | replay=45520 | world_total=11320.5522 | actor=-8.4375 | critic=6.9823 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=508.6 | checkpoint=-
# [train] step=1111/1500 | warm=0 | policy=32 | replay=45552 | world_total=11320.5935 | actor=-8.2734 | critic=5.4166 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=512.9 | checkpoint=-
# [train] step=1112/1500 | warm=0 | policy=32 | replay=45584 | world_total=11320.7039 | actor=-8.4297 | critic=5.4077 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=516.7 | checkpoint=-
# [train] step=1113/1500 | warm=0 | policy=32 | replay=45616 | world_total=11320.6963 | actor=-8.1016 | critic=5.2732 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=520.5 | checkpoint=-
# [train] step=1114/1500 | warm=0 | policy=32 | replay=45648 | world_total=11320.8175 | actor=-8.8828 | critic=5.3850 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=523.9 | checkpoint=-
# [train] step=1115/1500 | warm=0 | policy=32 | replay=45680 | world_total=11320.7086 | actor=-10.0156 | critic=6.4772 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=528.1 | checkpoint=-
# [train] step=1116/1500 | warm=0 | policy=32 | replay=45712 | world_total=11320.6593 | actor=-8.8828 | critic=6.9500 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=532.4 | checkpoint=-
# [train] step=1117/1500 | warm=0 | policy=32 | replay=45744 | world_total=11320.6163 | actor=-8.5391 | critic=5.0077 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=537.0 | checkpoint=-
# [train] step=1118/1500 | warm=0 | policy=32 | replay=45776 | world_total=11320.6475 | actor=-8.3516 | critic=4.8629 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=540.8 | checkpoint=-
# [train] step=1119/1500 | warm=0 | policy=32 | replay=45808 | world_total=11320.5664 | actor=-8.2266 | critic=5.0754 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=544.8 | checkpoint=-
# [train] step=1120/1500 | warm=0 | policy=32 | replay=45840 | world_total=11320.7866 | actor=-8.9531 | critic=5.3804 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=548.7 | checkpoint=-
# [train] step=1121/1500 | warm=0 | policy=32 | replay=45872 | world_total=11320.7585 | actor=-8.6641 | critic=4.9877 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=552.5 | checkpoint=-
# [train] step=1122/1500 | warm=0 | policy=32 | replay=45904 | world_total=11320.6141 | actor=-7.2031 | critic=4.5062 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=556.1 | checkpoint=-
# [train] step=1123/1500 | warm=0 | policy=32 | replay=45936 | world_total=11320.6338 | actor=-8.2422 | critic=5.7001 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=559.9 | checkpoint=-
# [train] step=1124/1500 | warm=0 | policy=32 | replay=45968 | world_total=11320.6737 | actor=-8.5078 | critic=5.1858 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=564.2 | checkpoint=-
# [train] step=1125/1500 | warm=0 | policy=32 | replay=46000 | world_total=11320.6227 | actor=-8.4609 | critic=5.1018 | eval_reward=4.2401 | cycle_s=16.0 | elapsed_s=580.2 | checkpoint=checkpoint_01125.pt
# [train] step=1126/1500 | warm=0 | policy=32 | replay=46032 | world_total=11320.6555 | actor=-8.2031 | critic=4.6548 | eval_reward=n/a | cycle_s=7.9 | elapsed_s=588.1 | checkpoint=-
# [train] step=1127/1500 | warm=0 | policy=32 | replay=46064 | world_total=11320.7729 | actor=-8.4062 | critic=4.8672 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=593.2 | checkpoint=-
# [train] step=1128/1500 | warm=0 | policy=32 | replay=46096 | world_total=11320.6407 | actor=-8.1562 | critic=4.6178 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=597.4 | checkpoint=-
# [train] step=1129/1500 | warm=0 | policy=32 | replay=46128 | world_total=11320.6458 | actor=-7.0391 | critic=4.2286 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=602.1 | checkpoint=-
# [train] step=1130/1500 | warm=0 | policy=32 | replay=46160 | world_total=11320.6886 | actor=-7.2109 | critic=4.3273 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=606.3 | checkpoint=-
# [train] step=1131/1500 | warm=0 | policy=32 | replay=46192 | world_total=11320.7650 | actor=-9.0625 | critic=5.4620 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=611.1 | checkpoint=-
# [train] step=1132/1500 | warm=0 | policy=32 | replay=46224 | world_total=11320.7395 | actor=-9.9922 | critic=5.9676 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=614.9 | checkpoint=-
# [train] step=1133/1500 | warm=0 | policy=32 | replay=46256 | world_total=11320.7234 | actor=-8.6719 | critic=5.7246 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=618.9 | checkpoint=-
# [train] step=1134/1500 | warm=0 | policy=32 | replay=46288 | world_total=11320.8263 | actor=-7.9062 | critic=4.5622 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=623.4 | checkpoint=-
# [train] step=1135/1500 | warm=0 | policy=32 | replay=46320 | world_total=11320.7438 | actor=-6.9844 | critic=3.7749 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=627.5 | checkpoint=-
# [train] step=1136/1500 | warm=0 | policy=32 | replay=46352 | world_total=11320.6433 | actor=-7.3711 | critic=4.1611 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=631.8 | checkpoint=-
# [train] step=1137/1500 | warm=0 | policy=32 | replay=46384 | world_total=11320.6844 | actor=-7.1875 | critic=4.2151 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=636.1 | checkpoint=-
# [train] step=1138/1500 | warm=0 | policy=32 | replay=46416 | world_total=11320.5936 | actor=-7.5156 | critic=4.2282 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=639.7 | checkpoint=-
# [train] step=1139/1500 | warm=0 | policy=32 | replay=46448 | world_total=11320.5607 | actor=-6.9688 | critic=3.9206 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=643.4 | checkpoint=-
# [train] step=1140/1500 | warm=0 | policy=32 | replay=46480 | world_total=11320.6472 | actor=-7.8789 | critic=4.5260 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=647.4 | checkpoint=-
# [train] step=1141/1500 | warm=0 | policy=32 | replay=46512 | world_total=11320.7087 | actor=-7.8398 | critic=4.1642 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=652.1 | checkpoint=-
# [train] step=1142/1500 | warm=0 | policy=32 | replay=46544 | world_total=11320.6027 | actor=-7.7500 | critic=4.2733 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=656.0 | checkpoint=-
# [train] step=1143/1500 | warm=0 | policy=32 | replay=46576 | world_total=11320.5752 | actor=-7.2344 | critic=4.1094 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=660.0 | checkpoint=-
# [train] step=1144/1500 | warm=0 | policy=32 | replay=46608 | world_total=11320.6005 | actor=-7.3750 | critic=4.1541 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=663.9 | checkpoint=-
# [train] step=1145/1500 | warm=0 | policy=32 | replay=46640 | world_total=11320.5245 | actor=-8.1719 | critic=4.6190 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=667.5 | checkpoint=-
# [train] step=1146/1500 | warm=0 | policy=32 | replay=46672 | world_total=11320.6334 | actor=-8.6484 | critic=4.8201 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=671.5 | checkpoint=-
# [train] step=1147/1500 | warm=0 | policy=32 | replay=46704 | world_total=11320.5668 | actor=-8.1172 | critic=4.4751 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=675.4 | checkpoint=-
# [train] step=1148/1500 | warm=0 | policy=32 | replay=46736 | world_total=11320.4998 | actor=-6.5000 | critic=3.8035 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=679.5 | checkpoint=-
# [train] step=1149/1500 | warm=0 | policy=32 | replay=46768 | world_total=11320.5360 | actor=-6.7930 | critic=3.8701 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=683.2 | checkpoint=-
# [train] step=1150/1500 | warm=0 | policy=32 | replay=46800 | world_total=11320.7212 | actor=-9.2266 | critic=5.7197 | eval_reward=5.4704 | cycle_s=16.5 | elapsed_s=699.7 | checkpoint=checkpoint_01150.pt
# [train] step=1151/1500 | warm=0 | policy=32 | replay=46832 | world_total=11320.7017 | actor=-9.9609 | critic=6.5490 | eval_reward=n/a | cycle_s=9.9 | elapsed_s=709.6 | checkpoint=-
# [train] step=1152/1500 | warm=0 | policy=32 | replay=46864 | world_total=11320.7452 | actor=-7.8906 | critic=5.2399 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=714.5 | checkpoint=-
# [train] step=1153/1500 | warm=0 | policy=32 | replay=46896 | world_total=11320.7751 | actor=-6.2266 | critic=3.7986 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=718.6 | checkpoint=-
# [train] step=1154/1500 | warm=0 | policy=32 | replay=46928 | world_total=11320.6451 | actor=-5.8789 | critic=3.4554 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=723.5 | checkpoint=-
# [train] step=1155/1500 | warm=0 | policy=32 | replay=46960 | world_total=11320.5907 | actor=-7.2461 | critic=4.2688 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=727.8 | checkpoint=-
# [train] step=1156/1500 | warm=0 | policy=32 | replay=46992 | world_total=11320.4808 | actor=-8.3906 | critic=4.7426 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=731.6 | checkpoint=-
# [train] step=1157/1500 | warm=0 | policy=32 | replay=47024 | world_total=11320.5607 | actor=-8.4219 | critic=4.7721 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=735.4 | checkpoint=-
# [train] step=1158/1500 | warm=0 | policy=32 | replay=47056 | world_total=11320.5914 | actor=-8.1797 | critic=4.6287 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=739.4 | checkpoint=-
# [train] step=1159/1500 | warm=0 | policy=32 | replay=47088 | world_total=11320.5236 | actor=-7.3945 | critic=4.4341 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=743.5 | checkpoint=-
# [train] step=1160/1500 | warm=0 | policy=32 | replay=47120 | world_total=11320.5095 | actor=-7.1758 | critic=4.0282 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=747.4 | checkpoint=-
# [train] step=1161/1500 | warm=0 | policy=32 | replay=47152 | world_total=11320.5953 | actor=-7.1133 | critic=3.9441 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=751.1 | checkpoint=-
# [train] step=1162/1500 | warm=0 | policy=32 | replay=47184 | world_total=11320.5137 | actor=-6.8555 | critic=3.8563 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=754.8 | checkpoint=-
# [train] step=1163/1500 | warm=0 | policy=32 | replay=47216 | world_total=11320.4860 | actor=-6.7109 | critic=3.7551 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=758.8 | checkpoint=-
# [train] step=1164/1500 | warm=0 | policy=32 | replay=47248 | world_total=11320.4609 | actor=-7.0156 | critic=3.9343 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=763.0 | checkpoint=-
# [train] step=1165/1500 | warm=0 | policy=32 | replay=47280 | world_total=11320.5519 | actor=-7.2188 | critic=3.8862 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=767.6 | checkpoint=-
# [train] step=1166/1500 | warm=0 | policy=32 | replay=47312 | world_total=11320.5400 | actor=-7.0703 | critic=3.8762 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=771.6 | checkpoint=-
# [train] step=1167/1500 | warm=0 | policy=32 | replay=47344 | world_total=11320.4674 | actor=-7.5625 | critic=4.2217 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=775.3 | checkpoint=-
# [train] step=1168/1500 | warm=0 | policy=32 | replay=47376 | world_total=11320.5028 | actor=-7.1875 | critic=4.2824 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=778.9 | checkpoint=-
# [train] step=1169/1500 | warm=0 | policy=32 | replay=47408 | world_total=11320.5787 | actor=-6.6289 | critic=3.9500 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=782.5 | checkpoint=-
# [train] step=1170/1500 | warm=0 | policy=32 | replay=47440 | world_total=11320.5402 | actor=-6.4453 | critic=3.7992 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=786.9 | checkpoint=-
# [train] step=1171/1500 | warm=0 | policy=32 | replay=47472 | world_total=11320.5236 | actor=-7.4414 | critic=4.5631 | eval_reward=n/a | cycle_s=9.2 | elapsed_s=796.0 | checkpoint=-
# [train] step=1172/1500 | warm=0 | policy=32 | replay=47504 | world_total=11320.5533 | actor=-7.8203 | critic=5.0109 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=800.1 | checkpoint=-
# [train] step=1173/1500 | warm=0 | policy=32 | replay=47536 | world_total=11320.5056 | actor=-7.8555 | critic=4.7454 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=805.1 | checkpoint=-
# [train] step=1174/1500 | warm=0 | policy=32 | replay=47568 | world_total=11320.5579 | actor=-6.5000 | critic=4.4737 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=809.3 | checkpoint=-
# [train] step=1175/1500 | warm=0 | policy=32 | replay=47600 | world_total=11320.5609 | actor=-6.9375 | critic=5.0799 | eval_reward=6.5863 | cycle_s=17.4 | elapsed_s=826.7 | checkpoint=checkpoint_01175.pt
# [train] step=1176/1500 | warm=0 | policy=32 | replay=47632 | world_total=11320.4991 | actor=-7.7266 | critic=5.1569 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=830.9 | checkpoint=-
# [train] step=1177/1500 | warm=0 | policy=32 | replay=47664 | world_total=11320.5254 | actor=-6.0859 | critic=4.6503 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=838.4 | checkpoint=-
# [train] step=1178/1500 | warm=0 | policy=32 | replay=47696 | world_total=11320.4835 | actor=-6.1953 | critic=4.5135 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=843.1 | checkpoint=-
# [train] step=1179/1500 | warm=0 | policy=32 | replay=47728 | world_total=11320.5062 | actor=-6.3516 | critic=4.1142 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=848.2 | checkpoint=-
# [train] step=1180/1500 | warm=0 | policy=32 | replay=47760 | world_total=11320.4863 | actor=-7.9961 | critic=4.9581 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=852.4 | checkpoint=-
# [train] step=1181/1500 | warm=0 | policy=32 | replay=47792 | world_total=11320.4576 | actor=-8.2734 | critic=4.8971 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=856.1 | checkpoint=-
# [train] step=1182/1500 | warm=0 | policy=32 | replay=47824 | world_total=11320.3428 | actor=-7.2656 | critic=4.3575 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=859.9 | checkpoint=-
# [train] step=1183/1500 | warm=0 | policy=32 | replay=47856 | world_total=11320.4432 | actor=-7.4609 | critic=4.1243 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=863.6 | checkpoint=-
# [train] step=1184/1500 | warm=0 | policy=32 | replay=47888 | world_total=11320.5771 | actor=-7.7852 | critic=4.1588 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=867.2 | checkpoint=-
# [train] step=1185/1500 | warm=0 | policy=32 | replay=47920 | world_total=11320.4297 | actor=-7.6953 | critic=4.0480 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=870.6 | checkpoint=-
# [train] step=1186/1500 | warm=0 | policy=32 | replay=47952 | world_total=11320.8207 | actor=-7.2070 | critic=3.8477 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=873.8 | checkpoint=-
# [train] step=1187/1500 | warm=0 | policy=32 | replay=47984 | world_total=11320.7556 | actor=-6.1328 | critic=3.2029 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=878.0 | checkpoint=-
# [train] step=1188/1500 | warm=0 | policy=32 | replay=48016 | world_total=11320.6058 | actor=-6.0586 | critic=3.3223 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=882.3 | checkpoint=-
# [train] step=1189/1500 | warm=0 | policy=32 | replay=48048 | world_total=11320.3239 | actor=-7.1523 | critic=3.7437 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=886.3 | checkpoint=-
# [train] step=1190/1500 | warm=0 | policy=32 | replay=48080 | world_total=11320.3813 | actor=-7.7969 | critic=4.0332 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=890.0 | checkpoint=-
# [train] step=1191/1500 | warm=0 | policy=32 | replay=48112 | world_total=11320.4038 | actor=-8.0898 | critic=4.2446 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=894.2 | checkpoint=-
# [train] step=1192/1500 | warm=0 | policy=32 | replay=48144 | world_total=11320.3174 | actor=-8.2031 | critic=4.1664 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=898.0 | checkpoint=-
# [train] step=1193/1500 | warm=0 | policy=32 | replay=48176 | world_total=11320.4210 | actor=-7.6562 | critic=3.8582 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=901.8 | checkpoint=-
# [train] step=1194/1500 | warm=0 | policy=32 | replay=48208 | world_total=11320.3877 | actor=-7.1875 | critic=3.6035 | eval_reward=n/a | cycle_s=8.3 | elapsed_s=910.0 | checkpoint=-
# [train] step=1195/1500 | warm=0 | policy=32 | replay=48240 | world_total=11320.3441 | actor=-7.6914 | critic=3.8701 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=914.5 | checkpoint=-
# [train] step=1196/1500 | warm=0 | policy=32 | replay=48272 | world_total=11320.3939 | actor=-7.5898 | critic=4.1215 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=918.6 | checkpoint=-
# [train] step=1197/1500 | warm=0 | policy=32 | replay=48304 | world_total=11320.4393 | actor=-6.8398 | critic=3.5452 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=922.5 | checkpoint=-
# [train] step=1198/1500 | warm=0 | policy=32 | replay=48336 | world_total=11320.4475 | actor=-7.0469 | critic=3.8429 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=926.4 | checkpoint=-
# [train] step=1199/1500 | warm=0 | policy=32 | replay=48368 | world_total=11320.7051 | actor=-8.9219 | critic=5.1542 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=930.9 | checkpoint=-
# [train] step=1200/1500 | warm=0 | policy=32 | replay=48400 | world_total=11320.6027 | actor=-8.6406 | critic=4.9847 | eval_reward=3.2114 | cycle_s=17.1 | elapsed_s=948.1 | checkpoint=checkpoint_01200.pt
# [train] step=1201/1500 | warm=0 | policy=32 | replay=48432 | world_total=11320.8157 | actor=-8.3125 | critic=4.4520 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=951.7 | checkpoint=-
# [train] step=1202/1500 | warm=0 | policy=32 | replay=48464 | world_total=11320.6211 | actor=-8.2422 | critic=4.2230 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=955.7 | checkpoint=-
# [train] step=1203/1500 | warm=0 | policy=32 | replay=48496 | world_total=11320.5269 | actor=-7.6133 | critic=3.9727 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=960.6 | checkpoint=-
# [train] step=1204/1500 | warm=0 | policy=32 | replay=48528 | world_total=11320.3932 | actor=-6.7305 | critic=3.4137 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=964.9 | checkpoint=-
# [train] step=1205/1500 | warm=0 | policy=32 | replay=48560 | world_total=11320.3315 | actor=-7.5703 | critic=4.0382 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=969.2 | checkpoint=-
# [train] step=1206/1500 | warm=0 | policy=32 | replay=48592 | world_total=11320.3351 | actor=-8.6016 | critic=4.5131 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=973.9 | checkpoint=-
# [train] step=1207/1500 | warm=0 | policy=32 | replay=48624 | world_total=11320.3696 | actor=-7.7852 | critic=4.1478 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=977.9 | checkpoint=-
# [train] step=1208/1500 | warm=0 | policy=32 | replay=48656 | world_total=11320.3794 | actor=-7.0430 | critic=3.8414 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=982.1 | checkpoint=-
# [train] step=1209/1500 | warm=0 | policy=32 | replay=48688 | world_total=11320.3837 | actor=-6.8750 | critic=3.4956 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=985.9 | checkpoint=-
# [train] step=1210/1500 | warm=0 | policy=32 | replay=48720 | world_total=11320.3923 | actor=-9.1328 | critic=5.3597 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=989.3 | checkpoint=-
# [train] step=1211/1500 | warm=0 | policy=32 | replay=48752 | world_total=11320.4801 | actor=-9.8594 | critic=5.5929 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=993.2 | checkpoint=-
# [train] step=1212/1500 | warm=0 | policy=32 | replay=48784 | world_total=11320.4506 | actor=-8.0156 | critic=4.9392 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=997.3 | checkpoint=-
# [train] step=1213/1500 | warm=0 | policy=32 | replay=48816 | world_total=11320.3589 | actor=-6.5781 | critic=3.5337 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1001.2 | checkpoint=-
# [train] step=1214/1500 | warm=0 | policy=32 | replay=48848 | world_total=11320.3241 | actor=-7.2148 | critic=3.9777 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=1006.0 | checkpoint=-
# [train] step=1215/1500 | warm=0 | policy=32 | replay=48880 | world_total=11320.3368 | actor=-8.2422 | critic=4.3548 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1010.0 | checkpoint=-
# [train] step=1216/1500 | warm=0 | policy=32 | replay=48912 | world_total=11320.4004 | actor=-7.6328 | critic=4.0367 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1014.1 | checkpoint=-
# [train] step=1217/1500 | warm=0 | policy=32 | replay=48944 | world_total=11320.3076 | actor=-7.1836 | critic=3.9470 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1018.8 | checkpoint=-
# [train] step=1218/1500 | warm=0 | policy=32 | replay=48976 | world_total=11320.4480 | actor=-7.5000 | critic=4.0969 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1022.4 | checkpoint=-
# [train] step=1219/1500 | warm=0 | policy=32 | replay=49008 | world_total=11320.4969 | actor=-6.7188 | critic=3.6477 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1026.4 | checkpoint=-
# [train] step=1220/1500 | warm=0 | policy=32 | replay=49040 | world_total=11320.3521 | actor=-6.6523 | critic=3.6647 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1030.4 | checkpoint=-
# [train] step=1221/1500 | warm=0 | policy=32 | replay=49072 | world_total=11320.2867 | actor=-6.9258 | critic=3.6867 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1034.5 | checkpoint=-
# [train] step=1222/1500 | warm=0 | policy=32 | replay=49104 | world_total=11320.3245 | actor=-6.7500 | critic=3.5734 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1039.1 | checkpoint=-
# [train] step=1223/1500 | warm=0 | policy=32 | replay=49136 | world_total=11320.3080 | actor=-6.8203 | critic=3.6259 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=1042.6 | checkpoint=-
# [train] step=1224/1500 | warm=0 | policy=32 | replay=49168 | world_total=11320.3715 | actor=-7.0195 | critic=3.7793 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1046.6 | checkpoint=-
# [train] step=1225/1500 | warm=0 | policy=32 | replay=49200 | world_total=11320.3162 | actor=-6.5117 | critic=3.3676 | eval_reward=5.7681 | cycle_s=16.8 | elapsed_s=1063.4 | checkpoint=checkpoint_01225.pt
# [train] step=1226/1500 | warm=0 | policy=32 | replay=49232 | world_total=11320.3235 | actor=-6.7266 | critic=3.6354 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1067.9 | checkpoint=-
# [train] step=1227/1500 | warm=0 | policy=32 | replay=49264 | world_total=11320.4813 | actor=-7.0703 | critic=3.8083 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1073.9 | checkpoint=-
# [train] step=1228/1500 | warm=0 | policy=32 | replay=49296 | world_total=11320.4337 | actor=-6.7305 | critic=3.6194 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1078.3 | checkpoint=-
# [train] step=1229/1500 | warm=0 | policy=32 | replay=49328 | world_total=11320.3984 | actor=-6.8086 | critic=3.6365 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1082.9 | checkpoint=-
# [train] step=1230/1500 | warm=0 | policy=32 | replay=49360 | world_total=11320.5824 | actor=-6.0859 | critic=3.4311 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=1087.8 | checkpoint=-
# [train] step=1231/1500 | warm=0 | policy=32 | replay=49392 | world_total=11320.4615 | actor=-7.3867 | critic=4.7269 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1092.3 | checkpoint=-
# [train] step=1232/1500 | warm=0 | policy=32 | replay=49424 | world_total=11320.3070 | actor=-8.6953 | critic=4.9356 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1096.2 | checkpoint=-
# [train] step=1233/1500 | warm=0 | policy=32 | replay=49456 | world_total=11320.3674 | actor=-8.1836 | critic=4.8708 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1099.9 | checkpoint=-
# [train] step=1234/1500 | warm=0 | policy=32 | replay=49488 | world_total=11320.3811 | actor=-7.3672 | critic=3.9888 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1103.7 | checkpoint=-
# [train] step=1235/1500 | warm=0 | policy=32 | replay=49520 | world_total=11320.3447 | actor=-7.5898 | critic=4.0450 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1107.1 | checkpoint=-
# [train] step=1236/1500 | warm=0 | policy=32 | replay=49552 | world_total=11320.4307 | actor=-7.8008 | critic=4.1388 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1111.7 | checkpoint=-
# [train] step=1237/1500 | warm=0 | policy=32 | replay=49584 | world_total=11320.3807 | actor=-8.6016 | critic=4.6955 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1115.3 | checkpoint=-
# [train] step=1238/1500 | warm=0 | policy=32 | replay=49616 | world_total=11320.3065 | actor=-8.9062 | critic=4.9475 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=1121.4 | checkpoint=-
# [train] step=1239/1500 | warm=0 | policy=32 | replay=49648 | world_total=11320.4041 | actor=-7.5117 | critic=4.0878 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1125.3 | checkpoint=-
# [train] step=1240/1500 | warm=0 | policy=32 | replay=49680 | world_total=11320.3663 | actor=-7.2539 | critic=3.7490 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1128.7 | checkpoint=-
# [train] step=1241/1500 | warm=0 | policy=32 | replay=49712 | world_total=11320.3480 | actor=-7.0469 | critic=3.5641 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1132.8 | checkpoint=-
# [train] step=1242/1500 | warm=0 | policy=32 | replay=49744 | world_total=11320.3490 | actor=-7.1602 | critic=3.7391 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1136.8 | checkpoint=-
# [train] step=1243/1500 | warm=0 | policy=32 | replay=49776 | world_total=11320.3538 | actor=-7.4375 | critic=4.0115 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1141.5 | checkpoint=-
# [train] step=1244/1500 | warm=0 | policy=32 | replay=49808 | world_total=11320.2717 | actor=-7.5586 | critic=3.7573 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1145.5 | checkpoint=-
# [train] step=1245/1500 | warm=0 | policy=32 | replay=49840 | world_total=11320.3141 | actor=-7.3281 | critic=3.6984 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1149.8 | checkpoint=-
# [train] step=1246/1500 | warm=0 | policy=32 | replay=49872 | world_total=11320.3923 | actor=-7.5742 | critic=3.8718 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1154.4 | checkpoint=-
# [train] step=1247/1500 | warm=0 | policy=32 | replay=49904 | world_total=11320.5320 | actor=-8.2148 | critic=4.0845 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1158.7 | checkpoint=-
# [train] step=1248/1500 | warm=0 | policy=32 | replay=49936 | world_total=11320.3060 | actor=-7.1406 | critic=3.8402 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1162.8 | checkpoint=-
# [train] step=1249/1500 | warm=0 | policy=32 | replay=49968 | world_total=11320.3506 | actor=-6.8594 | critic=3.6719 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1167.1 | checkpoint=-
# [train] step=1250/1500 | warm=0 | policy=32 | replay=50000 | world_total=11320.3030 | actor=-7.1211 | critic=3.6371 | eval_reward=11.8145 | cycle_s=17.9 | elapsed_s=1185.0 | checkpoint=checkpoint_01250.pt
# [train] step=1251/1500 | warm=0 | policy=32 | replay=50032 | world_total=11320.3409 | actor=-6.9062 | critic=3.3760 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1189.7 | checkpoint=-
# [train] step=1252/1500 | warm=0 | policy=32 | replay=50064 | world_total=11320.2760 | actor=-7.3789 | critic=3.5120 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1194.1 | checkpoint=-
# [train] step=1253/1500 | warm=0 | policy=32 | replay=50096 | world_total=11320.3280 | actor=-6.6172 | critic=3.3885 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1198.5 | checkpoint=-
# [train] step=1254/1500 | warm=0 | policy=32 | replay=50128 | world_total=11320.4386 | actor=-6.4531 | critic=3.2824 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=1203.3 | checkpoint=-
# [train] step=1255/1500 | warm=0 | policy=32 | replay=50160 | world_total=11320.4429 | actor=-6.6680 | critic=3.4693 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1207.0 | checkpoint=-
# [train] step=1256/1500 | warm=0 | policy=32 | replay=50192 | world_total=11320.7351 | actor=-6.5273 | critic=3.5722 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1211.7 | checkpoint=-
# [train] step=1257/1500 | warm=0 | policy=32 | replay=50224 | world_total=11321.2539 | actor=-7.4844 | critic=4.4548 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1216.3 | checkpoint=-
# [train] step=1258/1500 | warm=0 | policy=32 | replay=50256 | world_total=11321.0118 | actor=-6.1992 | critic=5.1916 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1219.7 | checkpoint=-
# [train] step=1259/1500 | warm=0 | policy=32 | replay=50288 | world_total=11320.8787 | actor=-5.7617 | critic=3.7250 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1223.1 | checkpoint=-
# [train] step=1260/1500 | warm=0 | policy=32 | replay=50320 | world_total=11320.5063 | actor=-6.7109 | critic=3.5559 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=1226.7 | checkpoint=-
# [train] step=1261/1500 | warm=0 | policy=32 | replay=50352 | world_total=11320.3083 | actor=-7.6602 | critic=3.9461 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1230.4 | checkpoint=-
# [train] step=1262/1500 | warm=0 | policy=32 | replay=50384 | world_total=11320.3284 | actor=-8.3438 | critic=4.3438 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1234.3 | checkpoint=-
# ...
# [train] step=1420/1500 | warm=0 | policy=32 | replay=55440 | world_total=11319.9286 | actor=-7.5195 | critic=3.2668 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1994.2 | checkpoint=-
# [train] step=1421/1500 | warm=0 | policy=32 | replay=55472 | world_total=11319.9883 | actor=-7.2969 | critic=3.1173 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1998.5 | checkpoint=-
# [train] step=1422/1500 | warm=0 | policy=32 | replay=55504 | world_total=11319.8713 | actor=-7.3633 | critic=3.2890 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2002.6 | checkpoint=-
# [train] step=1423/1500 | warm=0 | policy=32 | replay=55536 | world_total=11319.9879 | actor=-8.0078 | critic=3.5390 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2006.7 | checkpoint=-
# [train] step=1424/1500 | warm=0 | policy=32 | replay=55568 | world_total=11319.8785 | actor=-6.4648 | critic=3.2320 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=2011.3 | checkpoint=-
# [train] step=1425/1500 | warm=0 | policy=32 | replay=55600 | world_total=11319.9695 | actor=-7.4062 | critic=3.6383 | eval_reward=6.1057 | cycle_s=17.4 | elapsed_s=2028.7 | checkpoint=checkpoint_01425.pt
# [train] step=1426/1500 | warm=0 | policy=32 | replay=55632 | world_total=11319.9094 | actor=-8.0000 | critic=3.5888 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=2032.5 | checkpoint=-
# [train] step=1427/1500 | warm=0 | policy=32 | replay=55664 | world_total=11319.8311 | actor=-7.3828 | critic=3.0345 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=2036.9 | checkpoint=-
# [train] step=1428/1500 | warm=0 | policy=32 | replay=55696 | world_total=11319.9491 | actor=-7.2383 | critic=2.8444 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=2042.9 | checkpoint=-
# [train] step=1429/1500 | warm=0 | policy=32 | replay=55728 | world_total=11320.0466 | actor=-7.5625 | critic=3.0309 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2046.5 | checkpoint=-
# [train] step=1430/1500 | warm=0 | policy=32 | replay=55760 | world_total=11319.9279 | actor=-7.8906 | critic=3.2124 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=2051.2 | checkpoint=-
# [train] step=1431/1500 | warm=0 | policy=32 | replay=55792 | world_total=11319.9686 | actor=-8.2344 | critic=3.4734 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=2055.1 | checkpoint=-
# [train] step=1432/1500 | warm=0 | policy=32 | replay=55824 | world_total=11319.9437 | actor=-7.3516 | critic=3.1576 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2058.9 | checkpoint=-
# [train] step=1433/1500 | warm=0 | policy=32 | replay=55856 | world_total=11319.9121 | actor=-7.1211 | critic=2.9821 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2062.4 | checkpoint=-
# [train] step=1434/1500 | warm=0 | policy=32 | replay=55888 | world_total=11319.7887 | actor=-6.4414 | critic=3.0848 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2065.9 | checkpoint=-
# [train] step=1435/1500 | warm=0 | policy=32 | replay=55920 | world_total=11319.8966 | actor=-6.4375 | critic=3.0079 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2069.3 | checkpoint=-
# [train] step=1436/1500 | warm=0 | policy=32 | replay=55952 | world_total=11319.9545 | actor=-6.9102 | critic=2.9304 | eval_reward=n/a | cycle_s=10.0 | elapsed_s=2079.3 | checkpoint=-
# [train] step=1437/1500 | warm=0 | policy=32 | replay=55984 | world_total=11319.8640 | actor=-7.1992 | critic=2.9197 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=2084.1 | checkpoint=-
# [train] step=1438/1500 | warm=0 | policy=32 | replay=56016 | world_total=11319.8865 | actor=-6.1875 | critic=3.0463 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2088.4 | checkpoint=-
# [train] step=1439/1500 | warm=0 | policy=32 | replay=56048 | world_total=11319.9410 | actor=-7.0078 | critic=3.4616 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2092.5 | checkpoint=-
# [train] step=1440/1500 | warm=0 | policy=32 | replay=56080 | world_total=11319.8870 | actor=-7.4414 | critic=3.5870 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2096.9 | checkpoint=-
# [train] step=1441/1500 | warm=0 | policy=32 | replay=56112 | world_total=11319.8558 | actor=-7.1992 | critic=3.3209 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=2101.7 | checkpoint=-
# [train] step=1442/1500 | warm=0 | policy=32 | replay=56144 | world_total=11319.9043 | actor=-8.4688 | critic=4.1131 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=2106.1 | checkpoint=-
# [train] step=1443/1500 | warm=0 | policy=32 | replay=56176 | world_total=11319.9626 | actor=-7.1758 | critic=4.1041 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=2110.6 | checkpoint=-
# [train] step=1444/1500 | warm=0 | policy=32 | replay=56208 | world_total=11319.9545 | actor=-6.4180 | critic=3.3043 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2114.7 | checkpoint=-
# [train] step=1445/1500 | warm=0 | policy=32 | replay=56240 | world_total=11319.9320 | actor=-7.2109 | critic=3.3897 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2118.7 | checkpoint=-
# [train] step=1446/1500 | warm=0 | policy=32 | replay=56272 | world_total=11319.9667 | actor=-7.4180 | critic=3.1364 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=2122.9 | checkpoint=-
# [train] step=1447/1500 | warm=0 | policy=32 | replay=56304 | world_total=11319.8079 | actor=-7.9258 | critic=3.4393 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2126.5 | checkpoint=-
# [train] step=1448/1500 | warm=0 | policy=32 | replay=56336 | world_total=11319.8351 | actor=-7.4727 | critic=3.4552 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=2130.7 | checkpoint=-
# [train] step=1449/1500 | warm=0 | policy=32 | replay=56368 | world_total=11319.8280 | actor=-6.9453 | critic=3.0512 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=2135.8 | checkpoint=-
# [train] step=1450/1500 | warm=0 | policy=32 | replay=56400 | world_total=11319.9115 | actor=-7.9961 | critic=3.7366 | eval_reward=5.6975 | cycle_s=18.1 | elapsed_s=2154.0 | checkpoint=checkpoint_01450.pt
# [train] step=1451/1500 | warm=0 | policy=32 | replay=56432 | world_total=11319.8459 | actor=-8.5391 | critic=3.7769 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2158.2 | checkpoint=-
# [train] step=1452/1500 | warm=0 | policy=32 | replay=56464 | world_total=11319.8301 | actor=-8.0117 | critic=3.3377 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=2165.3 | checkpoint=-
# [train] step=1453/1500 | warm=0 | policy=32 | replay=56496 | world_total=11319.8965 | actor=-7.8789 | critic=3.4741 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2169.4 | checkpoint=-
# [train] step=1454/1500 | warm=0 | policy=32 | replay=56528 | world_total=11319.8165 | actor=-8.0898 | critic=3.5667 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2173.5 | checkpoint=-
# [train] step=1455/1500 | warm=0 | policy=32 | replay=56560 | world_total=11319.8116 | actor=-7.5195 | critic=3.0417 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2177.5 | checkpoint=-
# [train] step=1456/1500 | warm=0 | policy=32 | replay=56592 | world_total=11319.7560 | actor=-7.5039 | critic=3.0967 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2181.3 | checkpoint=-
# [train] step=1457/1500 | warm=0 | policy=32 | replay=56624 | world_total=11319.8143 | actor=-7.9062 | critic=3.2657 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=2186.3 | checkpoint=-
# [train] step=1458/1500 | warm=0 | policy=32 | replay=56656 | world_total=11319.7614 | actor=-6.9336 | critic=3.1220 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2189.7 | checkpoint=-
# [train] step=1459/1500 | warm=0 | policy=32 | replay=56688 | world_total=11319.9264 | actor=-8.4961 | critic=4.3579 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2193.4 | checkpoint=-
# [train] step=1460/1500 | warm=0 | policy=32 | replay=56720 | world_total=11319.9269 | actor=-8.1133 | critic=4.0831 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2197.2 | checkpoint=-
# [train] step=1461/1500 | warm=0 | policy=32 | replay=56752 | world_total=11320.5703 | actor=-8.1094 | critic=3.8235 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=2203.4 | checkpoint=-
# [train] step=1462/1500 | warm=0 | policy=32 | replay=56784 | world_total=11320.5751 | actor=-6.8203 | critic=4.0067 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2207.7 | checkpoint=-
# [train] step=1463/1500 | warm=0 | policy=32 | replay=56816 | world_total=11320.7498 | actor=-7.4766 | critic=5.0565 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=2212.4 | checkpoint=-
# [train] step=1464/1500 | warm=0 | policy=32 | replay=56848 | world_total=11320.7925 | actor=-8.3516 | critic=4.1632 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=2217.2 | checkpoint=-
# [train] step=1465/1500 | warm=0 | policy=32 | replay=56880 | world_total=11320.5876 | actor=-7.8711 | critic=3.4228 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=2221.8 | checkpoint=-
# [train] step=1466/1500 | warm=0 | policy=32 | replay=56912 | world_total=11320.5128 | actor=-6.4570 | critic=2.8648 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2226.1 | checkpoint=-
# [train] step=1467/1500 | warm=0 | policy=32 | replay=56944 | world_total=11320.2728 | actor=-7.2266 | critic=3.2377 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=2230.5 | checkpoint=-
# [train] step=1468/1500 | warm=0 | policy=32 | replay=56976 | world_total=11320.2234 | actor=-7.6211 | critic=3.3602 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=2234.4 | checkpoint=-
# [train] step=1469/1500 | warm=0 | policy=32 | replay=57008 | world_total=11320.1516 | actor=-7.1055 | critic=2.9931 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2238.2 | checkpoint=-
# [train] step=1470/1500 | warm=0 | policy=32 | replay=57040 | world_total=11320.1891 | actor=-8.0859 | critic=3.5968 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2241.9 | checkpoint=-
# [train] step=1471/1500 | warm=0 | policy=32 | replay=57072 | world_total=11319.9735 | actor=-8.7344 | critic=3.9530 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=2246.1 | checkpoint=-
# [train] step=1472/1500 | warm=0 | policy=32 | replay=57104 | world_total=11319.9080 | actor=-7.2578 | critic=3.1671 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2250.1 | checkpoint=-
# [train] step=1473/1500 | warm=0 | policy=32 | replay=57136 | world_total=11319.7615 | actor=-7.7188 | critic=3.2653 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2254.1 | checkpoint=-
# [train] step=1474/1500 | warm=0 | policy=32 | replay=57168 | world_total=11319.7866 | actor=-7.0117 | critic=3.2986 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2258.1 | checkpoint=-
# [train] step=1475/1500 | warm=0 | policy=32 | replay=57200 | world_total=11319.7499 | actor=-7.3047 | critic=3.2641 | eval_reward=3.8592 | cycle_s=18.3 | elapsed_s=2276.4 | checkpoint=checkpoint_01475.pt
# [train] step=1476/1500 | warm=0 | policy=32 | replay=57232 | world_total=11319.6698 | actor=-7.4336 | critic=3.3579 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2280.2 | checkpoint=-
# [train] step=1477/1500 | warm=0 | policy=32 | replay=57264 | world_total=11319.7513 | actor=-7.2305 | critic=3.2980 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=2284.7 | checkpoint=-
# [train] step=1478/1500 | warm=0 | policy=32 | replay=57296 | world_total=11319.7413 | actor=-6.3164 | critic=3.2726 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=2293.5 | checkpoint=-
# [train] step=1479/1500 | warm=0 | policy=32 | replay=57328 | world_total=11319.7570 | actor=-5.9727 | critic=3.0606 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2297.1 | checkpoint=-
# [train] step=1480/1500 | warm=0 | policy=32 | replay=57360 | world_total=11319.8607 | actor=-7.0117 | critic=3.2391 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2300.6 | checkpoint=-
# [train] step=1481/1500 | warm=0 | policy=32 | replay=57392 | world_total=11319.7758 | actor=-8.1250 | critic=3.6066 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2304.0 | checkpoint=-
# [train] step=1482/1500 | warm=0 | policy=32 | replay=57424 | world_total=11319.7451 | actor=-8.0781 | critic=3.5452 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2307.4 | checkpoint=-
# [train] step=1483/1500 | warm=0 | policy=32 | replay=57456 | world_total=11319.7062 | actor=-7.6914 | critic=3.3720 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2311.1 | checkpoint=-
# [train] step=1484/1500 | warm=0 | policy=32 | replay=57488 | world_total=11319.7057 | actor=-6.5391 | critic=2.9553 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=2314.4 | checkpoint=-
# [train] step=1485/1500 | warm=0 | policy=32 | replay=57520 | world_total=11319.6665 | actor=-6.3359 | critic=2.9962 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=2323.0 | checkpoint=-
# [train] step=1486/1500 | warm=0 | policy=32 | replay=57552 | world_total=11319.7322 | actor=-7.2148 | critic=3.3974 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2326.4 | checkpoint=-
# [train] step=1487/1500 | warm=0 | policy=32 | replay=57584 | world_total=11319.7310 | actor=-6.4648 | critic=3.1732 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2330.1 | checkpoint=-
# [train] step=1488/1500 | warm=0 | policy=32 | replay=57616 | world_total=11319.6897 | actor=-6.5000 | critic=3.4288 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2334.1 | checkpoint=-
# [train] step=1489/1500 | warm=0 | policy=32 | replay=57648 | world_total=11319.8330 | actor=-5.9961 | critic=3.4768 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2337.9 | checkpoint=-
# [train] step=1490/1500 | warm=0 | policy=32 | replay=57680 | world_total=11320.2570 | actor=-6.3125 | critic=3.3348 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2341.4 | checkpoint=-
# [train] step=1491/1500 | warm=0 | policy=32 | replay=57712 | world_total=11320.1442 | actor=-5.8125 | critic=3.1138 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=2345.2 | checkpoint=-
# [train] step=1492/1500 | warm=0 | policy=32 | replay=57744 | world_total=11319.9150 | actor=-5.8867 | critic=3.0068 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2348.9 | checkpoint=-
# [train] step=1493/1500 | warm=0 | policy=32 | replay=57776 | world_total=11319.7827 | actor=-7.3945 | critic=3.5570 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2351.9 | checkpoint=-
# [train] step=1494/1500 | warm=0 | policy=32 | replay=57808 | world_total=11319.7125 | actor=-6.0430 | critic=3.4885 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2355.4 | checkpoint=-
# [train] step=1495/1500 | warm=0 | policy=32 | replay=57840 | world_total=11319.6863 | actor=-5.7578 | critic=3.1831 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2358.3 | checkpoint=-
# [train] step=1496/1500 | warm=0 | policy=32 | replay=57872 | world_total=11319.6848 | actor=-6.4375 | critic=3.1994 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2362.1 | checkpoint=-
# [train] step=1497/1500 | warm=0 | policy=32 | replay=57904 | world_total=11319.6874 | actor=-7.1328 | critic=3.5157 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2365.8 | checkpoint=-
# [train] step=1498/1500 | warm=0 | policy=32 | replay=57936 | world_total=11319.7916 | actor=-6.3711 | critic=3.4335 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2369.6 | checkpoint=-
# [train] step=1499/1500 | warm=0 | policy=32 | replay=57968 | world_total=11319.9149 | actor=-6.4023 | critic=3.3776 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2373.3 | checkpoint=-
# [train] step=1500/1500 | warm=0 | policy=32 | replay=58000 | world_total=11319.9011 | actor=-6.5742 | critic=3.2759 | eval_reward=5.2083 | cycle_s=17.6 | elapsed_s=2390.9 | checkpoint=checkpoint_01500.pt
# Completed cycles: 2000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter15_batch_size/checkpoints/checkpoint_01500.pt
# Latest metrics: {'step': 1500, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 58000, 'world_model/reconstruction_loss': 11312.113403320312, 'world_model/reconstruction_mse': 0.0032871551520656794, 'world_model/observation_log_prob': -11312.113403320312, 'world_model/reward_loss': 1.2536669820547104, 'world_model/continue_loss': 0.018111595883965492, 'world_model/kl_loss': 3.881452351808548, 'world_model/kl_loss_raw': 3.881452351808548, 'world_model/overshooting_kl_loss': 5.269586443901062, 'world_model/overshooting_feature_mse': 1.4702068567276, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11319.901123046875, 'behavior/actor_loss': -6.57421875, 'behavior/critic_loss': 3.275922119617462, 'behavior/imagined_reward_mean': 0.9912109375, 'behavior/imagined_value_mean': 4.69921875, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 5.208324925930503, 'evaluation/mean_steps': 11.4, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter15_batch_size/checkpoints/checkpoint_01500.pt',
#  'latest_metrics': {'behavior/actor_loss': -6.57421875,
#   'behavior/critic_loss': 3.275922119617462,
#   'behavior/imagined_reward_mean': 0.9912109375,
#   'behavior/imagined_value_mean': 4.69921875,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 5.208324925930503,
#   'evaluation/mean_steps': 11.4,
#   'policy_added': 32,
#   'replay_size': 58000,
#   'step': 1500,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.018111595883965492,
#   'world_model/kl_loss': 3.881452351808548,
#   'world_model/kl_loss_raw': 3.881452351808548,
#   'world_model/observation_log_prob': -11312.113403320312,
#   'world_model/overshooting_feature_mse': 1.4702068567276,
#   'world_model/overshooting_kl_loss': 5.269586443901062,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11312.113403320312,
#   'world_model/reconstruction_mse': 0.0032871551520656794,
#   'world_model/reward_loss': 1.2536669820547104,
#   'world_model/total_loss': 11319.901123046875},
#  'latest_step': 1500}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 24.52614594089856,
#   'best_eval_reward_step': 250,
#   'best_imagined_reward_mean': 1.251953125,
#   'best_imagined_reward_step': 1341,
#   'best_world_model_step': 1485,
#   'best_world_model_total_loss': 11319.66650390625,
#   'largest_replay_size': 58000,
#   'largest_replay_step': 1500,
#   'last_metrics': {'behavior/actor_loss': -6.57421875,
#    'behavior/critic_loss': 3.275922119617462,
#    'behavior/imagined_reward_mean': 0.9912109375,
#    'behavior/imagined_value_mean': 4.69921875,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 5.208324925930503,
#    'evaluation/mean_steps': 11.4,
#    'policy_added': 32,
#    'replay_size': 58000,
#    'step': 1500,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.018111595883965492,
#    'world_model/kl_loss': 3.881452351808548,
#    'world_model/kl_loss_raw': 3.881452351808548,
#    'world_model/observation_log_prob': -11312.113403320312,
#    'world_model/overshooting_feature_mse': 1.4702068567276,
#    'world_model/overshooting_kl_loss': 5.269586443901062,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11312.113403320312,
#    'world_model/reconstruction_mse': 0.0032871551520656794,
#    'world_model/reward_loss': 1.2536669820547104,
#    'world_model/total_loss': 11319.901123046875},
#   'last_step': 1500,
#   'num_records': 1475},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11312.113403320312',
#   'world_model/reconstruction_mse': '0.0032871551520656794',
#   'world_model/observation_log_prob': '-11312.113403320312',
#   'world_model/overshooting_kl_loss': '5.269586443901062',
#   'world_model/overshooting_feature_mse': '1.4702068567276',
#   'evaluation/mean_reward': '5.208324925930503',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=10 | reward=2.21 | CRASH | saved iter15_batch_size_ep01.gif
# [demo] episode 2/10 | steps=13 | reward=4.22 | CRASH | saved iter15_batch_size_ep02.gif
# [demo] episode 3/10 | steps=8 | reward=-0.61 | CRASH | saved iter15_batch_size_ep03.gif
# [demo] episode 4/10 | steps=22 | reward=16.19 | CRASH | saved iter15_batch_size_ep04.gif
# [demo] episode 5/10 | steps=4 | reward=-0.52 | CRASH | saved iter15_batch_size_ep05.gif
# [demo] episode 6/10 | steps=6 | reward=-0.93 | CRASH | saved iter15_batch_size_ep06.gif
# [demo] episode 7/10 | steps=13 | reward=3.95 | CRASH | saved iter15_batch_size_ep07.gif
# [demo] episode 8/10 | steps=4 | reward=-0.53 | CRASH | saved iter15_batch_size_ep08.gif
# [demo] episode 9/10 | steps=11 | reward=2.71 | CRASH | saved iter15_batch_size_ep09.gif
# [demo] episode 10/10 | steps=23 | reward=17.49 | CRASH | saved iter15_batch_size_ep10.gif
# [demo] done | avg_reward=4.42 | summary=iter15_batch_size_summary.json
#
# iter15_batch_size_ep01.gif
# iter15_batch_size_ep02.gif
# iter15_batch_size_ep03.gif
# iter15_batch_size_ep04.gif
# iter15_batch_size_ep05.gif
# iter15_batch_size_ep06.gif
# iter15_batch_size_ep07.gif
# iter15_batch_size_ep08.gif
# iter15_batch_size_ep09.gif
# iter15_batch_size_ep10.gif
