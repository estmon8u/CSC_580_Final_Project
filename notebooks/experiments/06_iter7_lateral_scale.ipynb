# %% [markdown]
# # Tiny Dreamer Highway — Iter 7: lateral_scale
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 cumulative
# **New change:** `lateral_scale: 0.35 → 0.15`
# **Hypothesis:** Even when actor outputs ±1 steering, the physical effect is capped at 0.15 instead of 0.35. Jitter amplitude shrinks and lane changes become more gradual.

# %% [markdown]
# ## Iteration 7 — Anti-jitter via lateral cap
#
# Physical cap on steering authority. The policy can still request full left/right, but actual steering is half as aggressive. Should reduce wobble and accidental off-road.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides (current working config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nIter5 base overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 7 Override: lateral_scale ---
# lateral_scale 0.35 → 0.15: physical cap on max steering
config.env.action.lateral_scale = 0.15

print('Iter 7 override:')
print(f'  lateral_scale = {config.env.action.lateral_scale}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Iter5 base overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
# Iter 7 override:
#   lateral_scale = 0.15

# %%
RUN_NAME = 'iter7_lateral_scale'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter7_lateral_scale/checkpoints/checkpoint_00250.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter7_lateral_scale
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter5_framestack/checkpoints/checkpoint_00025.pt
# Effective cycles: 250
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=250 | start_step=26 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=26/250 | warm=0 | policy=32 | replay=10832 | world_total=11450.0482 | actor=-10.1250 | critic=1.0604 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=5.8 | checkpoint=-
# [train] step=27/250 | warm=0 | policy=32 | replay=10864 | world_total=11561.0874 | actor=-1.3672 | critic=6.8458 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=11.1 | checkpoint=-
# [train] step=28/250 | warm=0 | policy=32 | replay=10896 | world_total=11486.8442 | actor=-3.9180 | critic=4.4301 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=17.0 | checkpoint=-
# [train] step=29/250 | warm=0 | policy=32 | replay=10928 | world_total=11460.6544 | actor=-10.3828 | critic=7.2953 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=22.5 | checkpoint=-
# [train] step=30/250 | warm=0 | policy=32 | replay=10960 | world_total=11455.9730 | actor=-9.4375 | critic=2.3171 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=28.1 | checkpoint=-
# [train] step=31/250 | warm=0 | policy=32 | replay=10992 | world_total=11452.1166 | actor=-10.7188 | critic=2.0733 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=33.9 | checkpoint=-
# [train] step=32/250 | warm=0 | policy=32 | replay=11024 | world_total=11450.3269 | actor=-9.8906 | critic=1.5288 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=39.7 | checkpoint=-
# [train] step=33/250 | warm=0 | policy=32 | replay=11056 | world_total=11449.3668 | actor=-9.7812 | critic=1.9581 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=45.1 | checkpoint=-
# [train] step=34/250 | warm=0 | policy=32 | replay=11088 | world_total=11448.8352 | actor=-11.0312 | critic=1.3084 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=50.6 | checkpoint=-
# [train] step=35/250 | warm=0 | policy=32 | replay=11120 | world_total=11451.4657 | actor=-8.0938 | critic=2.6249 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=55.8 | checkpoint=-
# [train] step=36/250 | warm=0 | policy=32 | replay=11152 | world_total=11449.9396 | actor=-7.6719 | critic=1.5803 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=60.8 | checkpoint=-
# [train] step=37/250 | warm=0 | policy=32 | replay=11184 | world_total=11448.3606 | actor=-9.0156 | critic=1.9127 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=64.9 | checkpoint=-
# [train] step=38/250 | warm=0 | policy=32 | replay=11216 | world_total=11446.5427 | actor=-8.0117 | critic=1.2327 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=69.0 | checkpoint=-
# [train] step=39/250 | warm=0 | policy=32 | replay=11248 | world_total=11445.9160 | actor=-7.8789 | critic=1.2689 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=74.4 | checkpoint=-
# [train] step=40/250 | warm=0 | policy=32 | replay=11280 | world_total=11444.7983 | actor=-7.2461 | critic=1.3348 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=79.8 | checkpoint=-
# [train] step=41/250 | warm=0 | policy=32 | replay=11312 | world_total=11443.6073 | actor=-7.1523 | critic=1.2278 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=85.4 | checkpoint=-
# [train] step=42/250 | warm=0 | policy=32 | replay=11344 | world_total=11442.3640 | actor=-7.2031 | critic=1.2363 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=90.7 | checkpoint=-
# [train] step=43/250 | warm=0 | policy=32 | replay=11376 | world_total=11440.9885 | actor=-6.9805 | critic=1.2631 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=96.2 | checkpoint=-
# [train] step=44/250 | warm=0 | policy=32 | replay=11408 | world_total=11438.9486 | actor=-6.4062 | critic=1.4476 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=101.5 | checkpoint=-
# [train] step=45/250 | warm=0 | policy=32 | replay=11440 | world_total=11438.0203 | actor=-6.5156 | critic=1.3787 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=106.3 | checkpoint=-
# [train] step=46/250 | warm=0 | policy=32 | replay=11472 | world_total=11437.4172 | actor=-5.6719 | critic=1.3244 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=110.6 | checkpoint=-
# [train] step=47/250 | warm=0 | policy=32 | replay=11504 | world_total=11435.8976 | actor=-5.5352 | critic=1.3866 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=114.7 | checkpoint=-
# [train] step=48/250 | warm=0 | policy=32 | replay=11536 | world_total=11434.1024 | actor=-5.1328 | critic=1.4104 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=119.3 | checkpoint=-
# [train] step=49/250 | warm=0 | policy=32 | replay=11568 | world_total=11432.8785 | actor=-4.7578 | critic=1.2824 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=124.4 | checkpoint=-
# [train] step=50/250 | warm=0 | policy=32 | replay=11600 | world_total=11431.5472 | actor=-4.8906 | critic=1.2625 | eval_reward=-0.5090 | cycle_s=12.4 | elapsed_s=136.9 | checkpoint=checkpoint_00050.pt
# [train] step=51/250 | warm=0 | policy=32 | replay=11632 | world_total=11430.6971 | actor=-4.6641 | critic=1.2233 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=141.5 | checkpoint=-
# [train] step=52/250 | warm=0 | policy=32 | replay=11664 | world_total=11429.3722 | actor=-4.3828 | critic=1.2379 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=145.1 | checkpoint=-
# [train] step=53/250 | warm=0 | policy=32 | replay=11696 | world_total=11427.8949 | actor=-4.6641 | critic=1.1921 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=148.8 | checkpoint=-
# [train] step=54/250 | warm=0 | policy=32 | replay=11728 | world_total=11427.0635 | actor=-4.8164 | critic=1.1355 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=154.5 | checkpoint=-
# [train] step=55/250 | warm=0 | policy=32 | replay=11760 | world_total=11426.2343 | actor=-4.7422 | critic=1.1203 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=159.9 | checkpoint=-
# [train] step=56/250 | warm=0 | policy=32 | replay=11792 | world_total=11424.9332 | actor=-5.0078 | critic=1.1419 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=165.3 | checkpoint=-
# [train] step=57/250 | warm=0 | policy=32 | replay=11824 | world_total=11423.7662 | actor=-5.2578 | critic=1.1601 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=170.6 | checkpoint=-
# [train] step=58/250 | warm=0 | policy=32 | replay=11856 | world_total=11422.6378 | actor=-5.3359 | critic=1.1511 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=175.2 | checkpoint=-
# [train] step=59/250 | warm=0 | policy=32 | replay=11888 | world_total=11421.2737 | actor=-5.7578 | critic=1.1515 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=179.0 | checkpoint=-
# [train] step=60/250 | warm=0 | policy=32 | replay=11920 | world_total=11420.0404 | actor=-5.8711 | critic=1.1938 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=182.9 | checkpoint=-
# [train] step=61/250 | warm=0 | policy=32 | replay=11952 | world_total=11419.3583 | actor=-6.0977 | critic=1.2198 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=188.2 | checkpoint=-
# [train] step=62/250 | warm=0 | policy=32 | replay=11984 | world_total=11417.0699 | actor=-6.3711 | critic=1.2308 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=193.5 | checkpoint=-
# [train] step=63/250 | warm=0 | policy=32 | replay=12016 | world_total=11415.4623 | actor=-6.8828 | critic=1.3038 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=198.7 | checkpoint=-
# [train] step=64/250 | warm=0 | policy=32 | replay=12048 | world_total=11414.0596 | actor=-6.5156 | critic=1.5441 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=203.8 | checkpoint=-
# [train] step=65/250 | warm=0 | policy=32 | replay=12080 | world_total=11412.0692 | actor=-7.5469 | critic=1.5033 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=209.3 | checkpoint=-
# [train] step=66/250 | warm=0 | policy=32 | replay=12112 | world_total=11410.8124 | actor=-7.0938 | critic=1.7439 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=214.7 | checkpoint=-
# [train] step=67/250 | warm=0 | policy=32 | replay=12144 | world_total=11409.1543 | actor=-7.6172 | critic=1.5305 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=220.5 | checkpoint=-
# [train] step=68/250 | warm=0 | policy=32 | replay=12176 | world_total=11407.4822 | actor=-7.1719 | critic=1.9647 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=226.0 | checkpoint=-
# [train] step=69/250 | warm=0 | policy=32 | replay=12208 | world_total=11405.7209 | actor=-7.0938 | critic=2.1277 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=231.3 | checkpoint=-
# [train] step=70/250 | warm=0 | policy=32 | replay=12240 | world_total=11404.6659 | actor=-5.8633 | critic=2.6253 | eval_reward=n/a | cycle_s=5.6 | elapsed_s=237.0 | checkpoint=-
# [train] step=71/250 | warm=0 | policy=32 | replay=12272 | world_total=11403.2848 | actor=-5.0156 | critic=2.1921 | eval_reward=n/a | cycle_s=5.5 | elapsed_s=242.5 | checkpoint=-
# [train] step=72/250 | warm=0 | policy=32 | replay=12304 | world_total=11401.6237 | actor=-4.7344 | critic=1.7483 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=248.2 | checkpoint=-
# [train] step=73/250 | warm=0 | policy=32 | replay=12336 | world_total=11399.7258 | actor=-4.3438 | critic=1.6319 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=254.0 | checkpoint=-
# [train] step=74/250 | warm=0 | policy=32 | replay=12368 | world_total=11398.0260 | actor=-4.6133 | critic=1.7182 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=259.3 | checkpoint=-
# [train] step=75/250 | warm=0 | policy=32 | replay=12400 | world_total=11396.0782 | actor=-4.6797 | critic=1.7529 | eval_reward=-0.5076 | cycle_s=12.7 | elapsed_s=272.0 | checkpoint=checkpoint_00075.pt
# [train] step=76/250 | warm=0 | policy=32 | replay=12432 | world_total=11394.4375 | actor=-5.3203 | critic=1.9006 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=276.3 | checkpoint=-
# [train] step=77/250 | warm=0 | policy=32 | replay=12464 | world_total=11392.5538 | actor=-5.8047 | critic=2.0420 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=281.3 | checkpoint=-
# [train] step=78/250 | warm=0 | policy=32 | replay=12496 | world_total=11390.7388 | actor=-5.8594 | critic=2.0039 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=286.4 | checkpoint=-
# [train] step=79/250 | warm=0 | policy=32 | replay=12528 | world_total=11388.7336 | actor=-5.8594 | critic=2.0845 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=289.7 | checkpoint=-
# [train] step=80/250 | warm=0 | policy=32 | replay=12560 | world_total=11387.3627 | actor=-5.9219 | critic=2.1121 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=292.8 | checkpoint=-
# [train] step=81/250 | warm=0 | policy=32 | replay=12592 | world_total=11385.6687 | actor=-6.0859 | critic=2.2301 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=295.7 | checkpoint=-
# [train] step=82/250 | warm=0 | policy=32 | replay=12624 | world_total=11383.7466 | actor=-6.0312 | critic=2.0125 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=300.9 | checkpoint=-
# [train] step=83/250 | warm=0 | policy=32 | replay=12656 | world_total=11382.4854 | actor=-7.4258 | critic=2.6665 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=305.8 | checkpoint=-
# [train] step=84/250 | warm=0 | policy=32 | replay=12688 | world_total=11380.5422 | actor=-8.1523 | critic=2.3370 | eval_reward=n/a | cycle_s=6.0 | elapsed_s=311.8 | checkpoint=-
# [train] step=85/250 | warm=0 | policy=32 | replay=12720 | world_total=11379.4569 | actor=-8.2188 | critic=2.6735 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=316.9 | checkpoint=-
# [train] step=86/250 | warm=0 | policy=32 | replay=12752 | world_total=11378.2635 | actor=-8.4297 | critic=3.0191 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=322.0 | checkpoint=-
# [train] step=87/250 | warm=0 | policy=32 | replay=12784 | world_total=11377.0436 | actor=-8.9844 | critic=2.5624 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=326.9 | checkpoint=-
# [train] step=88/250 | warm=0 | policy=32 | replay=12816 | world_total=11375.5579 | actor=-9.6641 | critic=2.6574 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=331.1 | checkpoint=-
# [train] step=89/250 | warm=0 | policy=32 | replay=12848 | world_total=11374.5483 | actor=-8.8359 | critic=3.8651 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=334.6 | checkpoint=-
# [train] step=90/250 | warm=0 | policy=32 | replay=12880 | world_total=11373.6049 | actor=-9.6797 | critic=2.7365 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=339.3 | checkpoint=-
# [train] step=91/250 | warm=0 | policy=32 | replay=12912 | world_total=11372.5665 | actor=-9.7656 | critic=2.8209 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=344.4 | checkpoint=-
# [train] step=92/250 | warm=0 | policy=32 | replay=12944 | world_total=11371.6301 | actor=-9.5625 | critic=3.0238 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=349.0 | checkpoint=-
# [train] step=93/250 | warm=0 | policy=32 | replay=12976 | world_total=11370.7330 | actor=-10.2422 | critic=2.8616 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=352.8 | checkpoint=-
# [train] step=94/250 | warm=0 | policy=32 | replay=13008 | world_total=11369.8671 | actor=-10.0781 | critic=3.0835 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=356.8 | checkpoint=-
# [train] step=95/250 | warm=0 | policy=32 | replay=13040 | world_total=11369.1355 | actor=-10.2812 | critic=3.0031 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=361.8 | checkpoint=-
# [train] step=96/250 | warm=0 | policy=32 | replay=13072 | world_total=11367.8309 | actor=-10.6406 | critic=2.6984 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=366.3 | checkpoint=-
# [train] step=97/250 | warm=0 | policy=32 | replay=13104 | world_total=11366.9829 | actor=-11.2422 | critic=3.1833 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=369.6 | checkpoint=-
# [train] step=98/250 | warm=0 | policy=32 | replay=13136 | world_total=11366.3711 | actor=-12.7422 | critic=3.1543 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=373.6 | checkpoint=-
# [train] step=99/250 | warm=0 | policy=32 | replay=13168 | world_total=11365.5387 | actor=-15.7266 | critic=4.4487 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=378.6 | checkpoint=-
# [train] step=100/250 | warm=0 | policy=32 | replay=13200 | world_total=11365.2529 | actor=-17.2969 | critic=4.2020 | eval_reward=10.0689 | cycle_s=13.0 | elapsed_s=391.5 | checkpoint=checkpoint_00100.pt
# [train] step=101/250 | warm=0 | policy=32 | replay=13232 | world_total=11363.6443 | actor=-20.2344 | critic=4.4953 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=395.8 | checkpoint=-
# [train] step=102/250 | warm=0 | policy=32 | replay=13264 | world_total=11362.6312 | actor=-22.9688 | critic=5.1466 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=400.7 | checkpoint=-
# [train] step=103/250 | warm=0 | policy=32 | replay=13296 | world_total=11361.8719 | actor=-25.4531 | critic=4.9790 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=404.6 | checkpoint=-
# [train] step=104/250 | warm=0 | policy=32 | replay=13328 | world_total=11360.6448 | actor=-27.3594 | critic=5.7932 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=407.9 | checkpoint=-
# [train] step=105/250 | warm=0 | policy=32 | replay=13360 | world_total=11359.7482 | actor=-27.0000 | critic=7.8637 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=412.7 | checkpoint=-
# [train] step=106/250 | warm=0 | policy=32 | replay=13392 | world_total=11358.8699 | actor=-27.0625 | critic=5.3472 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=417.4 | checkpoint=-
# [train] step=107/250 | warm=0 | policy=32 | replay=13424 | world_total=11358.6418 | actor=-27.7500 | critic=6.2903 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=421.2 | checkpoint=-
# [train] step=108/250 | warm=0 | policy=32 | replay=13456 | world_total=11357.5431 | actor=-28.9062 | critic=6.6728 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=424.8 | checkpoint=-
# [train] step=109/250 | warm=0 | policy=32 | replay=13488 | world_total=11356.8993 | actor=-30.9219 | critic=6.3386 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=429.8 | checkpoint=-
# [train] step=110/250 | warm=0 | policy=32 | replay=13520 | world_total=11356.3634 | actor=-30.8750 | critic=7.3906 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=434.6 | checkpoint=-
# [train] step=111/250 | warm=0 | policy=32 | replay=13552 | world_total=11356.0991 | actor=-31.7656 | critic=6.0669 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=438.3 | checkpoint=-
# [train] step=112/250 | warm=0 | policy=32 | replay=13584 | world_total=11356.0104 | actor=-31.1250 | critic=8.1047 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=441.4 | checkpoint=-
# [train] step=113/250 | warm=0 | policy=32 | replay=13616 | world_total=11355.4647 | actor=-27.6094 | critic=12.4067 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=444.7 | checkpoint=-
# [train] step=114/250 | warm=0 | policy=32 | replay=13648 | world_total=11354.5802 | actor=-28.2188 | critic=8.2469 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=448.9 | checkpoint=-
# [train] step=115/250 | warm=0 | policy=32 | replay=13680 | world_total=11354.3585 | actor=-28.8281 | critic=6.7687 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=453.2 | checkpoint=-
# [train] step=116/250 | warm=0 | policy=32 | replay=13712 | world_total=11353.7538 | actor=-30.9531 | critic=7.2153 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=457.3 | checkpoint=-
# [train] step=117/250 | warm=0 | policy=32 | replay=13744 | world_total=11352.9479 | actor=-32.3125 | critic=9.2858 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=462.1 | checkpoint=-
# [train] step=118/250 | warm=0 | policy=32 | replay=13776 | world_total=11352.5414 | actor=-34.8750 | critic=7.0073 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=467.1 | checkpoint=-
# [train] step=119/250 | warm=0 | policy=32 | replay=13808 | world_total=11352.2631 | actor=-35.5938 | critic=9.9383 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=471.5 | checkpoint=-
# [train] step=120/250 | warm=0 | policy=32 | replay=13840 | world_total=11352.2874 | actor=-34.9062 | critic=9.7718 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=476.8 | checkpoint=-
# [train] step=121/250 | warm=0 | policy=32 | replay=13872 | world_total=11351.7164 | actor=-34.1562 | critic=8.7489 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=481.2 | checkpoint=-
# [train] step=122/250 | warm=0 | policy=32 | replay=13904 | world_total=11351.3451 | actor=-33.5000 | critic=9.0599 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=485.8 | checkpoint=-
# [train] step=123/250 | warm=0 | policy=32 | replay=13936 | world_total=11350.7758 | actor=-33.0000 | critic=11.6761 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=490.2 | checkpoint=-
# [train] step=124/250 | warm=0 | policy=32 | replay=13968 | world_total=11350.9751 | actor=-31.5156 | critic=10.1004 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=493.8 | checkpoint=-
# [train] step=125/250 | warm=0 | policy=32 | replay=14000 | world_total=11350.5863 | actor=-31.7500 | critic=9.6979 | eval_reward=10.0263 | cycle_s=13.0 | elapsed_s=506.8 | checkpoint=checkpoint_00125.pt
# [train] step=126/250 | warm=0 | policy=32 | replay=14032 | world_total=11349.9667 | actor=-30.3906 | critic=10.1121 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=510.9 | checkpoint=-
# [train] step=127/250 | warm=0 | policy=32 | replay=14064 | world_total=11349.7180 | actor=-31.5938 | critic=9.5416 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=515.9 | checkpoint=-
# [train] step=128/250 | warm=0 | policy=32 | replay=14096 | world_total=11349.3087 | actor=-29.2500 | critic=13.8533 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=520.4 | checkpoint=-
# [train] step=129/250 | warm=0 | policy=32 | replay=14128 | world_total=11348.9592 | actor=-29.0000 | critic=9.4327 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=525.1 | checkpoint=-
# [train] step=130/250 | warm=0 | policy=32 | replay=14160 | world_total=11348.9170 | actor=-30.1250 | critic=7.6858 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=529.5 | checkpoint=-
# [train] step=131/250 | warm=0 | policy=32 | replay=14192 | world_total=11348.1660 | actor=-33.0781 | critic=8.1680 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=534.3 | checkpoint=-
# [train] step=132/250 | warm=0 | policy=32 | replay=14224 | world_total=11347.9275 | actor=-35.6250 | critic=10.4495 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=539.2 | checkpoint=-
# [train] step=133/250 | warm=0 | policy=32 | replay=14256 | world_total=11347.9064 | actor=-35.4375 | critic=12.2902 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=543.7 | checkpoint=-
# [train] step=134/250 | warm=0 | policy=32 | replay=14288 | world_total=11348.0903 | actor=-31.0156 | critic=18.3863 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=548.4 | checkpoint=-
# [train] step=135/250 | warm=0 | policy=32 | replay=14320 | world_total=11347.9847 | actor=-29.0469 | critic=9.8996 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=553.9 | checkpoint=-
# [train] step=136/250 | warm=0 | policy=32 | replay=14352 | world_total=11347.7856 | actor=-28.6562 | critic=8.6653 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=558.6 | checkpoint=-
# [train] step=137/250 | warm=0 | policy=32 | replay=14384 | world_total=11347.8005 | actor=-30.3281 | critic=9.8232 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=562.8 | checkpoint=-
# [train] step=138/250 | warm=0 | policy=32 | replay=14416 | world_total=11347.8358 | actor=-29.8125 | critic=13.8368 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=566.3 | checkpoint=-
# [train] step=139/250 | warm=0 | policy=32 | replay=14448 | world_total=11347.2490 | actor=-29.2344 | critic=11.7667 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=569.6 | checkpoint=-
# [train] step=140/250 | warm=0 | policy=32 | replay=14480 | world_total=11346.8356 | actor=-26.9219 | critic=12.9263 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=573.2 | checkpoint=-
# [train] step=141/250 | warm=0 | policy=32 | replay=14512 | world_total=11346.5610 | actor=-27.5625 | critic=9.0983 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=577.9 | checkpoint=-
# [train] step=142/250 | warm=0 | policy=32 | replay=14544 | world_total=11346.5626 | actor=-27.6094 | critic=9.6444 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=582.6 | checkpoint=-
# [train] step=143/250 | warm=0 | policy=32 | replay=14576 | world_total=11346.5104 | actor=-28.2656 | critic=10.0246 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=586.4 | checkpoint=-
# [train] step=144/250 | warm=0 | policy=32 | replay=14608 | world_total=11346.1514 | actor=-27.8125 | critic=11.3828 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=591.6 | checkpoint=-
# [train] step=145/250 | warm=0 | policy=32 | replay=14640 | world_total=11345.6904 | actor=-28.0469 | critic=9.9309 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=595.8 | checkpoint=-
# [train] step=146/250 | warm=0 | policy=32 | replay=14672 | world_total=11345.4685 | actor=-28.4375 | critic=9.4254 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=600.6 | checkpoint=-
# [train] step=147/250 | warm=0 | policy=32 | replay=14704 | world_total=11344.9708 | actor=-29.0625 | critic=10.3904 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=605.3 | checkpoint=-
# [train] step=148/250 | warm=0 | policy=32 | replay=14736 | world_total=11345.1647 | actor=-29.1562 | critic=11.5509 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=609.8 | checkpoint=-
# [train] step=149/250 | warm=0 | policy=32 | replay=14768 | world_total=11344.5793 | actor=-31.0938 | critic=7.5816 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=614.6 | checkpoint=-
# [train] step=150/250 | warm=0 | policy=32 | replay=14800 | world_total=11344.8967 | actor=-32.6250 | critic=8.0400 | eval_reward=11.0382 | cycle_s=13.9 | elapsed_s=628.5 | checkpoint=checkpoint_00150.pt
# [train] step=151/250 | warm=0 | policy=32 | replay=14832 | world_total=11344.2034 | actor=-31.0156 | critic=18.0739 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=633.2 | checkpoint=-
# [train] step=152/250 | warm=0 | policy=32 | replay=14864 | world_total=11344.2617 | actor=-30.4219 | critic=10.4875 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=637.7 | checkpoint=-
# [train] step=153/250 | warm=0 | policy=32 | replay=14896 | world_total=11343.5630 | actor=-31.4688 | critic=7.6834 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=642.8 | checkpoint=-
# [train] step=154/250 | warm=0 | policy=32 | replay=14928 | world_total=11343.3790 | actor=-33.3438 | critic=9.1818 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=647.9 | checkpoint=-
# [train] step=155/250 | warm=0 | policy=32 | replay=14960 | world_total=11342.8751 | actor=-35.0000 | critic=10.3073 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=652.4 | checkpoint=-
# [train] step=156/250 | warm=0 | policy=32 | replay=14992 | world_total=11342.9521 | actor=-33.3125 | critic=15.4806 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=656.8 | checkpoint=-
# [train] step=157/250 | warm=0 | policy=32 | replay=15024 | world_total=11342.4432 | actor=-29.0781 | critic=17.9777 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=660.9 | checkpoint=-
# [train] step=158/250 | warm=0 | policy=32 | replay=15056 | world_total=11342.3235 | actor=-26.4844 | critic=10.5945 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=665.4 | checkpoint=-
# [train] step=159/250 | warm=0 | policy=32 | replay=15088 | world_total=11341.8766 | actor=-25.5625 | critic=10.2315 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=670.2 | checkpoint=-
# [train] step=160/250 | warm=0 | policy=32 | replay=15120 | world_total=11341.4843 | actor=-25.9062 | critic=9.1107 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=674.7 | checkpoint=-
# [train] step=161/250 | warm=0 | policy=32 | replay=15152 | world_total=11341.3962 | actor=-27.9531 | critic=8.7005 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=679.7 | checkpoint=-
# [train] step=162/250 | warm=0 | policy=32 | replay=15184 | world_total=11341.2338 | actor=-29.0781 | critic=10.0776 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=684.3 | checkpoint=-
# [train] step=163/250 | warm=0 | policy=32 | replay=15216 | world_total=11340.8130 | actor=-29.0156 | critic=11.9638 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=688.8 | checkpoint=-
# [train] step=164/250 | warm=0 | policy=32 | replay=15248 | world_total=11341.0710 | actor=-30.7188 | critic=8.5278 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=692.5 | checkpoint=-
# [train] step=165/250 | warm=0 | policy=32 | replay=15280 | world_total=11340.9481 | actor=-26.0938 | critic=20.1880 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=695.4 | checkpoint=-
# [train] step=166/250 | warm=0 | policy=32 | replay=15312 | world_total=11340.8105 | actor=-26.6094 | critic=9.6588 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=698.8 | checkpoint=-
# [train] step=167/250 | warm=0 | policy=32 | replay=15344 | world_total=11340.6104 | actor=-26.4844 | critic=8.9651 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=702.6 | checkpoint=-
# [train] step=168/250 | warm=0 | policy=32 | replay=15376 | world_total=11340.6849 | actor=-27.5938 | critic=9.0814 | eval_reward=n/a | cycle_s=7.2 | elapsed_s=709.8 | checkpoint=-
# [train] step=169/250 | warm=0 | policy=32 | replay=15408 | world_total=11340.3313 | actor=-27.9062 | critic=8.9950 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=714.5 | checkpoint=-
# [train] step=170/250 | warm=0 | policy=32 | replay=15440 | world_total=11340.1349 | actor=-26.5156 | critic=17.6464 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=719.4 | checkpoint=-
# [train] step=171/250 | warm=0 | policy=32 | replay=15472 | world_total=11339.9043 | actor=-25.8125 | critic=11.2634 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=724.0 | checkpoint=-
# [train] step=172/250 | warm=0 | policy=32 | replay=15504 | world_total=11339.7994 | actor=-24.1719 | critic=11.9972 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=728.6 | checkpoint=-
# [train] step=173/250 | warm=0 | policy=32 | replay=15536 | world_total=11339.4918 | actor=-26.4375 | critic=9.3870 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=733.5 | checkpoint=-
# [train] step=174/250 | warm=0 | policy=32 | replay=15568 | world_total=11339.1945 | actor=-26.9062 | critic=8.4844 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=738.1 | checkpoint=-
# [train] step=175/250 | warm=0 | policy=32 | replay=15600 | world_total=11338.8583 | actor=-27.0156 | critic=12.0837 | eval_reward=13.4279 | cycle_s=14.1 | elapsed_s=752.2 | checkpoint=checkpoint_00175.pt
# [train] step=176/250 | warm=0 | policy=32 | replay=15632 | world_total=11339.0605 | actor=-28.0000 | critic=10.5006 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=756.4 | checkpoint=-
# [train] step=177/250 | warm=0 | policy=32 | replay=15664 | world_total=11338.8541 | actor=-27.8125 | critic=9.4965 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=761.0 | checkpoint=-
# [train] step=178/250 | warm=0 | policy=32 | replay=15696 | world_total=11338.5959 | actor=-29.9844 | critic=7.6397 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=765.5 | checkpoint=-
# [train] step=179/250 | warm=0 | policy=32 | replay=15728 | world_total=11338.3064 | actor=-28.2031 | critic=14.5049 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=769.6 | checkpoint=-
# [train] step=180/250 | warm=0 | policy=32 | replay=15760 | world_total=11338.1434 | actor=-25.9688 | critic=17.4439 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=774.6 | checkpoint=-
# [train] step=181/250 | warm=0 | policy=32 | replay=15792 | world_total=11338.0505 | actor=-24.0938 | critic=11.6122 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=778.8 | checkpoint=-
# [train] step=182/250 | warm=0 | policy=32 | replay=15824 | world_total=11337.7919 | actor=-24.8594 | critic=8.3095 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=783.0 | checkpoint=-
# [train] step=183/250 | warm=0 | policy=32 | replay=15856 | world_total=11337.7225 | actor=-26.9688 | critic=11.0340 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=787.2 | checkpoint=-
# [train] step=184/250 | warm=0 | policy=32 | replay=15888 | world_total=11338.0724 | actor=-27.5312 | critic=8.6703 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=791.9 | checkpoint=-
# [train] step=185/250 | warm=0 | policy=32 | replay=15920 | world_total=11337.7498 | actor=-29.6719 | critic=7.7622 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=796.3 | checkpoint=-
# [train] step=186/250 | warm=0 | policy=32 | replay=15952 | world_total=11337.3645 | actor=-28.5625 | critic=14.9860 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=800.7 | checkpoint=-
# [train] step=187/250 | warm=0 | policy=32 | replay=15984 | world_total=11337.1144 | actor=-27.5000 | critic=13.1652 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=805.9 | checkpoint=-
# [train] step=188/250 | warm=0 | policy=32 | replay=16016 | world_total=11337.0095 | actor=-27.1875 | critic=8.6371 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=810.7 | checkpoint=-
# [train] step=189/250 | warm=0 | policy=32 | replay=16048 | world_total=11336.7618 | actor=-25.1719 | critic=10.5234 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=813.7 | checkpoint=-
# [train] step=190/250 | warm=0 | policy=32 | replay=16080 | world_total=11336.6876 | actor=-26.8281 | critic=8.8538 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=816.7 | checkpoint=-
# [train] step=191/250 | warm=0 | policy=32 | replay=16112 | world_total=11336.7065 | actor=-27.3125 | critic=8.6432 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=819.8 | checkpoint=-
# [train] step=192/250 | warm=0 | policy=32 | replay=16144 | world_total=11336.7499 | actor=-28.7500 | critic=9.5254 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=823.2 | checkpoint=-
# [train] step=193/250 | warm=0 | policy=32 | replay=16176 | world_total=11336.6758 | actor=-27.8906 | critic=12.8144 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=829.0 | checkpoint=-
# [train] step=194/250 | warm=0 | policy=32 | replay=16208 | world_total=11336.5430 | actor=-28.4531 | critic=9.5589 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=833.0 | checkpoint=-
# [train] step=195/250 | warm=0 | policy=32 | replay=16240 | world_total=11336.2202 | actor=-28.9062 | critic=7.9862 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=838.6 | checkpoint=-
# [train] step=196/250 | warm=0 | policy=32 | replay=16272 | world_total=11335.9677 | actor=-27.1875 | critic=12.0730 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=843.8 | checkpoint=-
# [train] step=197/250 | warm=0 | policy=32 | replay=16304 | world_total=11335.9520 | actor=-28.3125 | critic=7.8066 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=848.0 | checkpoint=-
# [train] step=198/250 | warm=0 | policy=32 | replay=16336 | world_total=11335.8098 | actor=-30.7031 | critic=8.5013 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=852.7 | checkpoint=-
# [train] step=199/250 | warm=0 | policy=32 | replay=16368 | world_total=11336.5702 | actor=-31.3594 | critic=9.3681 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=856.9 | checkpoint=-
# [train] step=200/250 | warm=0 | policy=32 | replay=16400 | world_total=11336.4094 | actor=-29.9688 | critic=17.2254 | eval_reward=3.7271 | cycle_s=13.3 | elapsed_s=870.3 | checkpoint=checkpoint_00200.pt
# [train] step=201/250 | warm=0 | policy=32 | replay=16432 | world_total=11336.2411 | actor=-31.2656 | critic=8.4227 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=875.0 | checkpoint=-
# [train] step=202/250 | warm=0 | policy=32 | replay=16464 | world_total=11335.9413 | actor=-28.7500 | critic=10.4430 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=879.7 | checkpoint=-
# [train] step=203/250 | warm=0 | policy=32 | replay=16496 | world_total=11336.0234 | actor=-28.6406 | critic=9.0636 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=884.0 | checkpoint=-
# [train] step=204/250 | warm=0 | policy=32 | replay=16528 | world_total=11335.9515 | actor=-30.3750 | critic=8.5565 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=888.8 | checkpoint=-
# [train] step=205/250 | warm=0 | policy=32 | replay=16560 | world_total=11335.7747 | actor=-29.7344 | critic=10.3211 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=893.6 | checkpoint=-
# [train] step=206/250 | warm=0 | policy=32 | replay=16592 | world_total=11335.7908 | actor=-31.1406 | critic=8.7304 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=898.1 | checkpoint=-
# [train] step=207/250 | warm=0 | policy=32 | replay=16624 | world_total=11335.5692 | actor=-32.5156 | critic=7.5841 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=902.9 | checkpoint=-
# [train] step=208/250 | warm=0 | policy=32 | replay=16656 | world_total=11335.5485 | actor=-32.2812 | critic=9.6623 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=907.4 | checkpoint=-
# [train] step=209/250 | warm=0 | policy=32 | replay=16688 | world_total=11335.6893 | actor=-35.2188 | critic=7.8839 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=911.9 | checkpoint=-
# [train] step=210/250 | warm=0 | policy=32 | replay=16720 | world_total=11335.3695 | actor=-30.7656 | critic=24.1844 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=916.5 | checkpoint=-
# [train] step=211/250 | warm=0 | policy=32 | replay=16752 | world_total=11335.1786 | actor=-28.0938 | critic=21.6575 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=920.9 | checkpoint=-
# [train] step=212/250 | warm=0 | policy=32 | replay=16784 | world_total=11334.8286 | actor=-30.2969 | critic=8.1791 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=925.6 | checkpoint=-
# [train] step=213/250 | warm=0 | policy=32 | replay=16816 | world_total=11334.4449 | actor=-29.9844 | critic=7.4244 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=930.4 | checkpoint=-
# [train] step=214/250 | warm=0 | policy=32 | replay=16848 | world_total=11334.0491 | actor=-28.0625 | critic=13.6590 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=934.9 | checkpoint=-
# [train] step=215/250 | warm=0 | policy=32 | replay=16880 | world_total=11334.3108 | actor=-25.7812 | critic=16.6257 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=938.2 | checkpoint=-
# [train] step=216/250 | warm=0 | policy=32 | replay=16912 | world_total=11334.0669 | actor=-26.1094 | critic=10.7416 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=940.9 | checkpoint=-
# [train] step=217/250 | warm=0 | policy=32 | replay=16944 | world_total=11334.1604 | actor=-25.2344 | critic=8.8197 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=944.5 | checkpoint=-
# [train] step=218/250 | warm=0 | policy=32 | replay=16976 | world_total=11333.7738 | actor=-25.7344 | critic=8.7542 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=949.4 | checkpoint=-
# [train] step=219/250 | warm=0 | policy=32 | replay=17008 | world_total=11333.8312 | actor=-25.0156 | critic=9.9897 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=953.4 | checkpoint=-
# [train] step=220/250 | warm=0 | policy=32 | replay=17040 | world_total=11333.7275 | actor=-25.0469 | critic=9.2568 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=958.3 | checkpoint=-
# [train] step=221/250 | warm=0 | policy=32 | replay=17072 | world_total=11333.7968 | actor=-24.9844 | critic=9.3479 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=962.6 | checkpoint=-
# [train] step=222/250 | warm=0 | policy=32 | replay=17104 | world_total=11333.5972 | actor=-23.8438 | critic=11.1865 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=966.5 | checkpoint=-
# [train] step=223/250 | warm=0 | policy=32 | replay=17136 | world_total=11333.3252 | actor=-25.1562 | critic=9.9471 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=970.4 | checkpoint=-
# [train] step=224/250 | warm=0 | policy=32 | replay=17168 | world_total=11333.0840 | actor=-26.9375 | critic=8.3974 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=974.0 | checkpoint=-
# [train] step=225/250 | warm=0 | policy=32 | replay=17200 | world_total=11333.3800 | actor=-28.0938 | critic=8.3053 | eval_reward=10.1835 | cycle_s=14.2 | elapsed_s=988.3 | checkpoint=checkpoint_00225.pt
# [train] step=226/250 | warm=0 | policy=32 | replay=17232 | world_total=11333.2693 | actor=-29.1406 | critic=10.4870 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=992.3 | checkpoint=-
# [train] step=227/250 | warm=0 | policy=32 | replay=17264 | world_total=11332.9792 | actor=-29.2031 | critic=10.0794 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=996.5 | checkpoint=-
# [train] step=228/250 | warm=0 | policy=32 | replay=17296 | world_total=11332.7726 | actor=-29.0000 | critic=11.1456 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1000.7 | checkpoint=-
# [train] step=229/250 | warm=0 | policy=32 | replay=17328 | world_total=11332.7280 | actor=-28.6094 | critic=8.6088 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1004.9 | checkpoint=-
# [train] step=230/250 | warm=0 | policy=32 | replay=17360 | world_total=11332.5143 | actor=-30.8594 | critic=8.7530 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1009.6 | checkpoint=-
# [train] step=231/250 | warm=0 | policy=32 | replay=17392 | world_total=11332.7900 | actor=-30.3281 | critic=9.3846 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=1014.3 | checkpoint=-
# [train] step=232/250 | warm=0 | policy=32 | replay=17424 | world_total=11332.2704 | actor=-30.3125 | critic=10.9928 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1018.9 | checkpoint=-
# [train] step=233/250 | warm=0 | policy=32 | replay=17456 | world_total=11332.3242 | actor=-31.0781 | critic=9.7982 | eval_reward=n/a | cycle_s=5.8 | elapsed_s=1024.7 | checkpoint=-
# [train] step=234/250 | warm=0 | policy=32 | replay=17488 | world_total=11332.3646 | actor=-30.1406 | critic=10.7830 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1029.2 | checkpoint=-
# [train] step=235/250 | warm=0 | policy=32 | replay=17520 | world_total=11332.1781 | actor=-29.6562 | critic=9.3315 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1033.1 | checkpoint=-
# [train] step=236/250 | warm=0 | policy=32 | replay=17552 | world_total=11332.1310 | actor=-30.3281 | critic=9.3906 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1037.1 | checkpoint=-
# [train] step=237/250 | warm=0 | policy=32 | replay=17584 | world_total=11332.1781 | actor=-27.8125 | critic=12.7022 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1041.6 | checkpoint=-
# [train] step=238/250 | warm=0 | policy=32 | replay=17616 | world_total=11332.1742 | actor=-27.0625 | critic=11.9008 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1046.2 | checkpoint=-
# [train] step=239/250 | warm=0 | policy=32 | replay=17648 | world_total=11331.7979 | actor=-27.5625 | critic=9.3050 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1050.3 | checkpoint=-
# [train] step=240/250 | warm=0 | policy=32 | replay=17680 | world_total=11331.9526 | actor=-29.3906 | critic=8.0713 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1054.7 | checkpoint=-
# [train] step=241/250 | warm=0 | policy=32 | replay=17712 | world_total=11331.8713 | actor=-32.4844 | critic=9.1085 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1059.1 | checkpoint=-
# [train] step=242/250 | warm=0 | policy=32 | replay=17744 | world_total=11331.7728 | actor=-34.1562 | critic=9.0436 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1062.5 | checkpoint=-
# [train] step=243/250 | warm=0 | policy=32 | replay=17776 | world_total=11331.4633 | actor=-33.4688 | critic=15.5711 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=1065.5 | checkpoint=-
# [train] step=244/250 | warm=0 | policy=32 | replay=17808 | world_total=11331.2020 | actor=-28.2969 | critic=32.5512 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1069.1 | checkpoint=-
# [train] step=245/250 | warm=0 | policy=32 | replay=17840 | world_total=11331.4878 | actor=-29.4844 | critic=9.5565 | eval_reward=n/a | cycle_s=6.9 | elapsed_s=1076.0 | checkpoint=-
# [train] step=246/250 | warm=0 | policy=32 | replay=17872 | world_total=11331.3351 | actor=-31.1875 | critic=10.5467 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1081.2 | checkpoint=-
# [train] step=247/250 | warm=0 | policy=32 | replay=17904 | world_total=11331.2793 | actor=-26.9375 | critic=16.5348 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1085.5 | checkpoint=-
# [train] step=248/250 | warm=0 | policy=32 | replay=17936 | world_total=11331.0464 | actor=-26.5312 | critic=13.2965 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1090.0 | checkpoint=-
# [train] step=249/250 | warm=0 | policy=32 | replay=17968 | world_total=11330.9229 | actor=-25.4062 | critic=10.1095 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1094.6 | checkpoint=-
# [train] step=250/250 | warm=0 | policy=32 | replay=18000 | world_total=11331.0780 | actor=-28.2031 | critic=10.6282 | eval_reward=18.4988 | cycle_s=14.9 | elapsed_s=1109.4 | checkpoint=checkpoint_00250.pt
# Completed cycles: 250
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter7_lateral_scale/checkpoints/checkpoint_00250.pt
# Latest metrics: {'step': 250, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 18000, 'world_model/reconstruction_loss': 11319.32275390625, 'world_model/reconstruction_mse': 0.0044606009614653885, 'world_model/observation_log_prob': -11319.32275390625, 'world_model/reward_loss': 1.2718822360038757, 'world_model/continue_loss': 0.01976049703080207, 'world_model/kl_loss': 6.797854006290436, 'world_model/kl_loss_raw': 6.797854006290436, 'world_model/overshooting_kl_loss': 7.331360101699829, 'world_model/overshooting_feature_mse': 0.08724161330610514, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11331.078002929688, 'behavior/actor_loss': -28.203125, 'behavior/critic_loss': 10.628171443939209, 'behavior/imagined_reward_mean': 1.0693359375, 'behavior/imagined_value_mean': 24.921875, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 18.498820557322006, 'evaluation/mean_steps': 22.0, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter7_lateral_scale/checkpoints/checkpoint_00250.pt',
#  'latest_metrics': {'behavior/actor_loss': -28.203125,
#   'behavior/critic_loss': 10.628171443939209,
#   'behavior/imagined_reward_mean': 1.0693359375,
#   'behavior/imagined_value_mean': 24.921875,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 18.498820557322006,
#   'evaluation/mean_steps': 22.0,
#   'policy_added': 32,
#   'replay_size': 18000,
#   'step': 250,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.01976049703080207,
#   'world_model/kl_loss': 6.797854006290436,
#   'world_model/kl_loss_raw': 6.797854006290436,
#   'world_model/observation_log_prob': -11319.32275390625,
#   'world_model/overshooting_feature_mse': 0.08724161330610514,
#   'world_model/overshooting_kl_loss': 7.331360101699829,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11319.32275390625,
#   'world_model/reconstruction_mse': 0.0044606009614653885,
#   'world_model/reward_loss': 1.2718822360038757,
#   'world_model/total_loss': 11331.078002929688},
#  'latest_step': 250}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 18.498820557322006,
#   'best_eval_reward_step': 250,
#   'best_imagined_reward_mean': 1.1142578125,
#   'best_imagined_reward_step': 246,
#   'best_world_model_step': 249,
#   'best_world_model_total_loss': 11330.9228515625,
#   'largest_replay_size': 18000,
#   'largest_replay_step': 250,
#   'last_metrics': {'behavior/actor_loss': -28.203125,
#    'behavior/critic_loss': 10.628171443939209,
#    'behavior/imagined_reward_mean': 1.0693359375,
#    'behavior/imagined_value_mean': 24.921875,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 18.498820557322006,
#    'evaluation/mean_steps': 22.0,
#    'policy_added': 32,
#    'replay_size': 18000,
#    'step': 250,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.01976049703080207,
#    'world_model/kl_loss': 6.797854006290436,
#    'world_model/kl_loss_raw': 6.797854006290436,
#    'world_model/observation_log_prob': -11319.32275390625,
#    'world_model/overshooting_feature_mse': 0.08724161330610514,
#    'world_model/overshooting_kl_loss': 7.331360101699829,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11319.32275390625,
#    'world_model/reconstruction_mse': 0.0044606009614653885,
#    'world_model/reward_loss': 1.2718822360038757,
#    'world_model/total_loss': 11331.078002929688},
#   'last_step': 250,
#   'num_records': 225},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11319.32275390625',
#   'world_model/reconstruction_mse': '0.0044606009614653885',
#   'world_model/observation_log_prob': '-11319.32275390625',
#   'world_model/overshooting_kl_loss': '7.331360101699829',
#   'world_model/overshooting_feature_mse': '0.08724161330610514',
#   'evaluation/mean_reward': '18.498820557322006',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=8 | reward=-0.16 | CRASH | saved iter7_lateral_scale_ep01.gif
# [demo] episode 2/10 | steps=32 | reward=32.67 | CRASH | saved iter7_lateral_scale_ep02.gif
# [demo] episode 3/10 | steps=7 | reward=-0.59 | CRASH | saved iter7_lateral_scale_ep03.gif
# [demo] episode 4/10 | steps=7 | reward=-0.53 | CRASH | saved iter7_lateral_scale_ep04.gif
# [demo] episode 5/10 | steps=12 | reward=3.53 | CRASH | saved iter7_lateral_scale_ep05.gif
# [demo] episode 6/10 | steps=21 | reward=16.44 | CRASH | saved iter7_lateral_scale_ep06.gif
# [demo] episode 7/10 | steps=6 | reward=-0.74 | CRASH | saved iter7_lateral_scale_ep07.gif
# [demo] episode 8/10 | steps=27 | reward=23.48 | CRASH | saved iter7_lateral_scale_ep08.gif
# [demo] episode 9/10 | steps=13 | reward=4.89 | CRASH | saved iter7_lateral_scale_ep09.gif
# [demo] episode 10/10 | steps=6 | reward=-0.71 | CRASH | saved iter7_lateral_scale_ep10.gif
# [demo] done | avg_reward=7.83 | summary=iter7_lateral_scale_summary.json
#
# iter7_lateral_scale_ep01.gif
# iter7_lateral_scale_ep02.gif
# iter7_lateral_scale_ep03.gif
# iter7_lateral_scale_ep04.gif
# iter7_lateral_scale_ep05.gif
# iter7_lateral_scale_ep06.gif
# iter7_lateral_scale_ep07.gif
# iter7_lateral_scale_ep08.gif
# iter7_lateral_scale_ep09.gif
# iter7_lateral_scale_ep10.gif
