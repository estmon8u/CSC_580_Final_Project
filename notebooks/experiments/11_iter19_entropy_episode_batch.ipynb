# %% [markdown]
# # Tiny Dreamer Highway — Iter 19: Iter 17 + Entropy Regularization
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 + iter10 + iter17 (steering_penalty=0.025, max_episode_steps=120, batch_size=384)
# **New change:** `actor_entropy_weight: 0.0 → 0.003` (entropy bonus in actor loss)
# **Hypothesis:** Iter 17 was the best at 1000 cycles (data diversity via longer episodes + bigger batches). Adding entropy regularization on top should further prevent actor std collapse, combining both anti-overfitting strategies: buffer-side diversity (iter 17) and policy-side exploration pressure (iter 18).

# %% [markdown]
# ## Iteration 19 — Iter 17 + Entropy regularization
#
# Iter 17 (longer episodes + bigger batches) was the best config at 1000 cycles. Iter 18 tests entropy regularization in isolation. This combines both: data diversity prevents buffer staleness, entropy bonus prevents actor std collapse. Two complementary anti-overfitting mechanisms.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides (current working config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nIter5 base overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 10 Override: steering_penalty ---
config.env.reward.steering_penalty = 0.025

print('\nIter 10 override:')
print(f'  steering_penalty = {config.env.reward.steering_penalty}')

# --- Iter 17 Overrides (Phase 3 winners) ---
config.env.max_episode_steps = 120
config.training.batch_size = 384

print('\nIter 17 overrides:')
print(f'  max_episode_steps = {config.env.max_episode_steps}')
print(f'  batch_size = {config.training.batch_size}')

# --- Iter 19 Override: actor entropy regularization ---
config.training.actor_entropy_weight = 0.003

print('\nIter 19 override (code change):')
print(f'  actor_entropy_weight = {config.training.actor_entropy_weight}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "actor_entropy_weight": 0.0,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Iter5 base overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
#
# Iter 10 override:
#   steering_penalty = 0.025
#
# Iter 17 overrides:
#   max_episode_steps = 120
#   batch_size = 384
#
# Iter 19 override (code change):
#   actor_entropy_weight = 0.003

# %%
RUN_NAME = 'iter19_entropy_episode_batch'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 2000
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter19_entropy_episode_batch/checkpoints/checkpoint_01800.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter19_entropy_episode_batch
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter19_entropy_episode_batch/checkpoints/checkpoint_01800.pt
# Effective cycles: 2000
# Effective policy steps: 32

# %%
print('Launching iter19 run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching iter19 run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=2000 | start_step=1801 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1801/2000 | warm=0 | policy=32 | replay=67632 | world_total=11318.8654 | actor=-6.9569 | critic=3.9814 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=4.3 | checkpoint=-
# [train] step=1802/2000 | warm=0 | policy=32 | replay=67664 | world_total=11320.9048 | actor=-5.8447 | critic=3.4213 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=7.6 | checkpoint=-
# [train] step=1803/2000 | warm=0 | policy=32 | replay=67696 | world_total=11320.3394 | actor=-7.0436 | critic=4.7139 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=11.1 | checkpoint=-
# [train] step=1804/2000 | warm=0 | policy=32 | replay=67728 | world_total=11319.6436 | actor=-8.4849 | critic=5.3934 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=15.0 | checkpoint=-
# [train] step=1805/2000 | warm=0 | policy=32 | replay=67760 | world_total=11319.2629 | actor=-7.8912 | critic=5.0847 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=19.7 | checkpoint=-
# [train] step=1806/2000 | warm=0 | policy=32 | replay=67792 | world_total=11318.9738 | actor=-7.5468 | critic=4.3632 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=24.2 | checkpoint=-
# [train] step=1807/2000 | warm=0 | policy=32 | replay=67824 | world_total=11318.9885 | actor=-6.7533 | critic=3.7531 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=29.0 | checkpoint=-
# [train] step=1808/2000 | warm=0 | policy=32 | replay=67856 | world_total=11318.8564 | actor=-6.7105 | critic=3.5943 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=33.1 | checkpoint=-
# [train] step=1809/2000 | warm=0 | policy=32 | replay=67888 | world_total=11318.9065 | actor=-6.8865 | critic=4.0019 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=37.6 | checkpoint=-
# [train] step=1810/2000 | warm=0 | policy=32 | replay=67920 | world_total=11318.9136 | actor=-6.9805 | critic=3.9852 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=42.3 | checkpoint=-
# [train] step=1811/2000 | warm=0 | policy=32 | replay=67952 | world_total=11318.9462 | actor=-6.7144 | critic=4.1450 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=46.1 | checkpoint=-
# [train] step=1812/2000 | warm=0 | policy=32 | replay=67984 | world_total=11319.0665 | actor=-6.2573 | critic=3.7319 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=50.1 | checkpoint=-
# [train] step=1813/2000 | warm=0 | policy=32 | replay=68016 | world_total=11319.1002 | actor=-6.7140 | critic=3.8255 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=54.3 | checkpoint=-
# [train] step=1814/2000 | warm=0 | policy=32 | replay=68048 | world_total=11319.0500 | actor=-7.4018 | critic=4.0722 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=59.0 | checkpoint=-
# [train] step=1815/2000 | warm=0 | policy=32 | replay=68080 | world_total=11319.0647 | actor=-7.1016 | critic=3.9052 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=63.4 | checkpoint=-
# [train] step=1816/2000 | warm=0 | policy=32 | replay=68112 | world_total=11318.9117 | actor=-6.8243 | critic=3.6314 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=67.9 | checkpoint=-
# [train] step=1817/2000 | warm=0 | policy=32 | replay=68144 | world_total=11318.8922 | actor=-6.0817 | critic=3.1351 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=72.2 | checkpoint=-
# [train] step=1818/2000 | warm=0 | policy=32 | replay=68176 | world_total=11318.8704 | actor=-6.5390 | critic=3.5102 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=76.1 | checkpoint=-
# [train] step=1819/2000 | warm=0 | policy=32 | replay=68208 | world_total=11318.9199 | actor=-6.7697 | critic=3.4547 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=80.0 | checkpoint=-
# [train] step=1820/2000 | warm=0 | policy=32 | replay=68240 | world_total=11318.9492 | actor=-7.2737 | critic=3.9630 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=83.8 | checkpoint=-
# [train] step=1821/2000 | warm=0 | policy=32 | replay=68272 | world_total=11318.8755 | actor=-7.0705 | critic=3.7398 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=87.8 | checkpoint=-
# [train] step=1822/2000 | warm=0 | policy=32 | replay=68304 | world_total=11318.9484 | actor=-6.3283 | critic=3.5909 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=91.3 | checkpoint=-
# [train] step=1823/2000 | warm=0 | policy=32 | replay=68336 | world_total=11318.9806 | actor=-6.3398 | critic=3.5396 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=94.8 | checkpoint=-
# [train] step=1824/2000 | warm=0 | policy=32 | replay=68368 | world_total=11318.9167 | actor=-6.2234 | critic=3.3548 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=99.0 | checkpoint=-
# [train] step=1825/2000 | warm=0 | policy=32 | replay=68400 | world_total=11319.0559 | actor=-7.1260 | critic=3.8468 | eval_reward=8.2556 | cycle_s=26.2 | elapsed_s=125.2 | checkpoint=checkpoint_01825.pt
# [train] step=1826/2000 | warm=0 | policy=32 | replay=68432 | world_total=11319.0424 | actor=-7.3531 | critic=3.9233 | eval_reward=n/a | cycle_s=7.4 | elapsed_s=132.6 | checkpoint=-
# [train] step=1827/2000 | warm=0 | policy=32 | replay=68464 | world_total=11319.1371 | actor=-6.3370 | critic=3.9576 | eval_reward=n/a | cycle_s=12.8 | elapsed_s=145.3 | checkpoint=-
# [train] step=1828/2000 | warm=0 | policy=32 | replay=68496 | world_total=11319.0001 | actor=-5.9387 | critic=3.4307 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=149.9 | checkpoint=-
# [train] step=1829/2000 | warm=0 | policy=32 | replay=68528 | world_total=11319.0007 | actor=-6.5319 | critic=3.5816 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=154.1 | checkpoint=-
# [train] step=1830/2000 | warm=0 | policy=32 | replay=68560 | world_total=11318.8752 | actor=-7.2383 | critic=4.1100 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=158.3 | checkpoint=-
# [train] step=1836/2000 | warm=0 | policy=32 | replay=68752 | world_total=11319.0023 | actor=-6.1519 | critic=3.6955 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=184.9 | checkpoint=-
# [train] step=1837/2000 | warm=0 | policy=32 | replay=68784 | world_total=11318.9720 | actor=-5.4680 | critic=3.1977 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=189.5 | checkpoint=-
# [train] step=1838/2000 | warm=0 | policy=32 | replay=68816 | world_total=11318.9451 | actor=-6.2648 | critic=3.6874 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=194.0 | checkpoint=-
# [train] step=1839/2000 | warm=0 | policy=32 | replay=68848 | world_total=11318.9430 | actor=-5.9525 | critic=3.7372 | eval_reward=n/a | cycle_s=10.1 | elapsed_s=204.2 | checkpoint=-
# [train] step=1840/2000 | warm=0 | policy=32 | replay=68880 | world_total=11318.9100 | actor=-5.2924 | critic=3.3622 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=208.6 | checkpoint=-
# [train] step=1841/2000 | warm=0 | policy=32 | replay=68912 | world_total=11318.9153 | actor=-5.8270 | critic=3.8788 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=213.3 | checkpoint=-
# [train] step=1842/2000 | warm=0 | policy=32 | replay=68944 | world_total=11318.8976 | actor=-5.9010 | critic=3.6762 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=218.1 | checkpoint=-
# [train] step=1843/2000 | warm=0 | policy=32 | replay=68976 | world_total=11318.9590 | actor=-5.7958 | critic=3.6175 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=222.5 | checkpoint=-
# [train] step=1844/2000 | warm=0 | policy=32 | replay=69008 | world_total=11319.0222 | actor=-5.7526 | critic=3.5023 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=226.4 | checkpoint=-
# [train] step=1845/2000 | warm=0 | policy=32 | replay=69040 | world_total=11318.9717 | actor=-6.6936 | critic=4.3642 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=230.5 | checkpoint=-
# [train] step=1846/2000 | warm=0 | policy=32 | replay=69072 | world_total=11319.4290 | actor=-5.4238 | critic=4.2186 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=234.6 | checkpoint=-
# [train] step=1847/2000 | warm=0 | policy=32 | replay=69104 | world_total=11319.3083 | actor=-5.5141 | critic=3.6311 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=238.9 | checkpoint=-
# [train] step=1848/2000 | warm=0 | policy=32 | replay=69136 | world_total=11319.0825 | actor=-5.5138 | critic=3.5717 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=243.3 | checkpoint=-
# [train] step=1849/2000 | warm=0 | policy=32 | replay=69168 | world_total=11319.0038 | actor=-5.9323 | critic=3.9235 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=252.0 | checkpoint=-
# [train] step=1850/2000 | warm=0 | policy=32 | replay=69200 | world_total=11318.8774 | actor=-5.4829 | critic=3.5770 | eval_reward=5.0083 | cycle_s=29.4 | elapsed_s=281.4 | checkpoint=checkpoint_01850.pt
# [train] step=1851/2000 | warm=0 | policy=32 | replay=69232 | world_total=11318.8280 | actor=-5.3651 | critic=3.7224 | eval_reward=n/a | cycle_s=13.4 | elapsed_s=294.8 | checkpoint=-
# [train] step=1852/2000 | warm=0 | policy=32 | replay=69264 | world_total=11318.8657 | actor=-5.2090 | critic=3.6857 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=299.1 | checkpoint=-
# [train] step=1853/2000 | warm=0 | policy=32 | replay=69296 | world_total=11318.9573 | actor=-5.8614 | critic=4.0480 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=303.3 | checkpoint=-
# [train] step=1854/2000 | warm=0 | policy=32 | replay=69328 | world_total=11318.9657 | actor=-4.8500 | critic=3.7724 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=307.7 | checkpoint=-
# [train] step=1855/2000 | warm=0 | policy=32 | replay=69360 | world_total=11318.9723 | actor=-4.5881 | critic=3.3825 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=312.2 | checkpoint=-
# [train] step=1856/2000 | warm=0 | policy=32 | replay=69392 | world_total=11318.9541 | actor=-4.5334 | critic=3.1552 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=316.8 | checkpoint=-
# [train] step=1857/2000 | warm=0 | policy=32 | replay=69424 | world_total=11318.8857 | actor=-4.2285 | critic=3.2342 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=321.4 | checkpoint=-
# [train] step=1858/2000 | warm=0 | policy=32 | replay=69456 | world_total=11318.9725 | actor=-4.1423 | critic=3.4337 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=325.8 | checkpoint=-
# [train] step=1859/2000 | warm=0 | policy=32 | replay=69488 | world_total=11318.9092 | actor=-4.9312 | critic=3.9407 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=330.1 | checkpoint=-
# [train] step=1860/2000 | warm=0 | policy=32 | replay=69520 | world_total=11318.9536 | actor=-4.9930 | critic=4.0072 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=334.8 | checkpoint=-
# [train] step=1861/2000 | warm=0 | policy=32 | replay=69552 | world_total=11318.9688 | actor=-4.4427 | critic=3.6810 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=339.7 | checkpoint=-
# [train] step=1862/2000 | warm=0 | policy=32 | replay=69584 | world_total=11318.9911 | actor=-4.4193 | critic=3.2240 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=344.0 | checkpoint=-
# [train] step=1863/2000 | warm=0 | policy=32 | replay=69616 | world_total=11318.8923 | actor=-4.3368 | critic=3.2575 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=348.6 | checkpoint=-
# [train] step=1864/2000 | warm=0 | policy=32 | replay=69648 | world_total=11318.9058 | actor=-4.1797 | critic=3.0281 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=352.8 | checkpoint=-
# [train] step=1865/2000 | warm=0 | policy=32 | replay=69680 | world_total=11318.9739 | actor=-4.9304 | critic=3.9289 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=357.3 | checkpoint=-
# [train] step=1866/2000 | warm=0 | policy=32 | replay=69712 | world_total=11318.8718 | actor=-5.1133 | critic=3.8491 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=361.4 | checkpoint=-
# [train] step=1867/2000 | warm=0 | policy=32 | replay=69744 | world_total=11318.8385 | actor=-4.8279 | critic=3.6316 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=365.6 | checkpoint=-
# [train] step=1868/2000 | warm=0 | policy=32 | replay=69776 | world_total=11318.9373 | actor=-4.4733 | critic=3.2989 | eval_reward=n/a | cycle_s=15.1 | elapsed_s=380.7 | checkpoint=-
# [train] step=1869/2000 | warm=0 | policy=32 | replay=69808 | world_total=11318.8809 | actor=-5.0747 | critic=4.2024 | eval_reward=n/a | cycle_s=12.0 | elapsed_s=392.8 | checkpoint=-
# [train] step=1870/2000 | warm=0 | policy=32 | replay=69840 | world_total=11318.9470 | actor=-5.7822 | critic=4.3776 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=397.4 | checkpoint=-
# [train] step=1871/2000 | warm=0 | policy=32 | replay=69872 | world_total=11318.9144 | actor=-4.8872 | critic=4.1942 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=401.6 | checkpoint=-
# [train] step=1872/2000 | warm=0 | policy=32 | replay=69904 | world_total=11318.8796 | actor=-4.2651 | critic=3.4168 | eval_reward=n/a | cycle_s=5.9 | elapsed_s=407.5 | checkpoint=-
# [train] step=1873/2000 | warm=0 | policy=32 | replay=69936 | world_total=11318.8333 | actor=-3.4923 | critic=3.0701 | eval_reward=n/a | cycle_s=4.8 | elapsed_s=412.3 | checkpoint=-
# [train] step=1874/2000 | warm=0 | policy=32 | replay=69968 | world_total=11318.8494 | actor=-4.1695 | critic=3.3117 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=416.6 | checkpoint=-
# [train] step=1875/2000 | warm=0 | policy=32 | replay=70000 | world_total=11318.9015 | actor=-4.5586 | critic=3.4951 | eval_reward=2.7906 | cycle_s=20.0 | elapsed_s=436.5 | checkpoint=checkpoint_01875.pt
# [train] step=1876/2000 | warm=0 | policy=32 | replay=70032 | world_total=11318.9076 | actor=-5.0426 | critic=3.6887 | eval_reward=n/a | cycle_s=7.5 | elapsed_s=444.0 | checkpoint=-
# [train] step=1877/2000 | warm=0 | policy=32 | replay=70064 | world_total=11318.9456 | actor=-4.6520 | critic=3.5542 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=448.2 | checkpoint=-
# [train] step=1878/2000 | warm=0 | policy=32 | replay=70096 | world_total=11318.8655 | actor=-4.7295 | critic=3.3921 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=452.6 | checkpoint=-
# [train] step=1879/2000 | warm=0 | policy=32 | replay=70128 | world_total=11318.8755 | actor=-4.5968 | critic=3.5429 | eval_reward=n/a | cycle_s=11.8 | elapsed_s=464.4 | checkpoint=-
# [train] step=1880/2000 | warm=0 | policy=32 | replay=70160 | world_total=11318.8085 | actor=-4.8078 | critic=3.6564 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=469.4 | checkpoint=-
# [train] step=1881/2000 | warm=0 | policy=32 | replay=70192 | world_total=11318.8606 | actor=-4.1106 | critic=3.2317 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=473.6 | checkpoint=-
# [train] step=1882/2000 | warm=0 | policy=32 | replay=70224 | world_total=11318.8481 | actor=-4.6748 | critic=3.6665 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=478.1 | checkpoint=-
# [train] step=1883/2000 | warm=0 | policy=32 | replay=70256 | world_total=11318.8645 | actor=-4.2876 | critic=3.4934 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=482.6 | checkpoint=-
# [train] step=1884/2000 | warm=0 | policy=32 | replay=70288 | world_total=11318.9482 | actor=-3.6995 | critic=3.0139 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=487.3 | checkpoint=-
# [train] step=1885/2000 | warm=0 | policy=32 | replay=70320 | world_total=11318.8589 | actor=-4.1551 | critic=3.6501 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=491.8 | checkpoint=-
# [train] step=1886/2000 | warm=0 | policy=32 | replay=70352 | world_total=11318.8912 | actor=-4.5495 | critic=3.3291 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=496.1 | checkpoint=-
# [train] step=1887/2000 | warm=0 | policy=32 | replay=70384 | world_total=11318.8153 | actor=-5.0494 | critic=3.8365 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=501.4 | checkpoint=-
# [train] step=1888/2000 | warm=0 | policy=32 | replay=70416 | world_total=11319.0054 | actor=-5.1085 | critic=3.6409 | eval_reward=n/a | cycle_s=12.2 | elapsed_s=513.6 | checkpoint=-
# [train] step=1889/2000 | warm=0 | policy=32 | replay=70448 | world_total=11319.0017 | actor=-5.5106 | critic=4.2189 | eval_reward=n/a | cycle_s=4.9 | elapsed_s=518.4 | checkpoint=-
# [train] step=1890/2000 | warm=0 | policy=32 | replay=70480 | world_total=11319.0183 | actor=-5.0927 | critic=3.7068 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=522.9 | checkpoint=-
# [train] step=1891/2000 | warm=0 | policy=32 | replay=70512 | world_total=11318.9869 | actor=-5.3427 | critic=4.0573 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=527.4 | checkpoint=-
# [train] step=1892/2000 | warm=0 | policy=32 | replay=70544 | world_total=11318.9458 | actor=-6.3111 | critic=4.7824 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=531.5 | checkpoint=-
# [train] step=1893/2000 | warm=0 | policy=32 | replay=70576 | world_total=11318.8992 | actor=-5.7846 | critic=4.4575 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=535.3 | checkpoint=-
# [train] step=1894/2000 | warm=0 | policy=32 | replay=70608 | world_total=11318.8456 | actor=-5.8283 | critic=4.1950 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=539.1 | checkpoint=-
# [train] step=1895/2000 | warm=0 | policy=32 | replay=70640 | world_total=11318.8268 | actor=-6.3483 | critic=4.3750 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=542.8 | checkpoint=-
# [train] step=1896/2000 | warm=0 | policy=32 | replay=70672 | world_total=11318.8492 | actor=-6.2582 | critic=4.3072 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=547.3 | checkpoint=-
# [train] step=1897/2000 | warm=0 | policy=32 | replay=70704 | world_total=11318.8785 | actor=-7.1215 | critic=4.7349 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=551.3 | checkpoint=-
# [train] step=1898/2000 | warm=0 | policy=32 | replay=70736 | world_total=11318.8210 | actor=-6.9109 | critic=4.6840 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=558.4 | checkpoint=-
# [train] step=1899/2000 | warm=0 | policy=32 | replay=70768 | world_total=11318.8862 | actor=-5.4923 | critic=3.6148 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=562.9 | checkpoint=-
# [train] step=1900/2000 | warm=0 | policy=32 | replay=70800 | world_total=11318.9525 | actor=-5.5592 | critic=3.6815 | eval_reward=3.2563 | cycle_s=23.7 | elapsed_s=586.6 | checkpoint=checkpoint_01900.pt
# [train] step=1901/2000 | warm=0 | policy=32 | replay=70832 | world_total=11319.3807 | actor=-5.6418 | critic=3.6994 | eval_reward=n/a | cycle_s=12.7 | elapsed_s=599.2 | checkpoint=-
# [train] step=1902/2000 | warm=0 | policy=32 | replay=70864 | world_total=11319.7983 | actor=-5.1032 | critic=3.1700 | eval_reward=n/a | cycle_s=13.1 | elapsed_s=612.4 | checkpoint=-
# [train] step=1903/2000 | warm=0 | policy=32 | replay=70896 | world_total=11319.3945 | actor=-5.6220 | critic=3.7366 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=616.2 | checkpoint=-
# [train] step=1904/2000 | warm=0 | policy=32 | replay=70928 | world_total=11319.0646 | actor=-6.2741 | critic=3.7662 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=620.3 | checkpoint=-
# [train] step=1905/2000 | warm=0 | policy=32 | replay=70960 | world_total=11318.8354 | actor=-6.7740 | critic=4.2154 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=624.1 | checkpoint=-
# [train] step=1906/2000 | warm=0 | policy=32 | replay=70992 | world_total=11318.9093 | actor=-5.5711 | critic=3.4775 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=627.7 | checkpoint=-
# [train] step=1907/2000 | warm=0 | policy=32 | replay=71024 | world_total=11318.7964 | actor=-6.2467 | critic=3.9747 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=631.2 | checkpoint=-
# [train] step=1908/2000 | warm=0 | policy=32 | replay=71056 | world_total=11318.8544 | actor=-6.3204 | critic=3.8479 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=634.7 | checkpoint=-
# [train] step=1909/2000 | warm=0 | policy=32 | replay=71088 | world_total=11318.7955 | actor=-6.0981 | critic=3.6933 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=638.6 | checkpoint=-
# [train] step=1910/2000 | warm=0 | policy=32 | replay=71120 | world_total=11318.8567 | actor=-6.2039 | critic=3.8192 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=642.4 | checkpoint=-
# [train] step=1911/2000 | warm=0 | policy=32 | replay=71152 | world_total=11318.9618 | actor=-6.1181 | critic=3.7461 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=646.1 | checkpoint=-
# [train] step=1912/2000 | warm=0 | policy=32 | replay=71184 | world_total=11319.1218 | actor=-6.8247 | critic=4.4124 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=649.8 | checkpoint=-
# [train] step=1913/2000 | warm=0 | policy=32 | replay=71216 | world_total=11319.5171 | actor=-5.5440 | critic=3.9319 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=653.2 | checkpoint=-
# [train] step=1914/2000 | warm=0 | policy=32 | replay=71248 | world_total=11319.1615 | actor=-6.2223 | critic=4.0083 | eval_reward=n/a | cycle_s=14.7 | elapsed_s=667.9 | checkpoint=-
# [train] step=1915/2000 | warm=0 | policy=32 | replay=71280 | world_total=11318.9188 | actor=-5.8558 | critic=3.7311 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=671.5 | checkpoint=-
# [train] step=1916/2000 | warm=0 | policy=32 | replay=71312 | world_total=11318.7755 | actor=-5.4529 | critic=3.3546 | eval_reward=n/a | cycle_s=11.4 | elapsed_s=682.9 | checkpoint=-
# [train] step=1917/2000 | warm=0 | policy=32 | replay=71344 | world_total=11318.7548 | actor=-5.2029 | critic=3.2640 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=686.6 | checkpoint=-
# [train] step=1918/2000 | warm=0 | policy=32 | replay=71376 | world_total=11318.7384 | actor=-5.2142 | critic=3.3357 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=690.5 | checkpoint=-
# [train] step=1919/2000 | warm=0 | policy=32 | replay=71408 | world_total=11318.7849 | actor=-5.3777 | critic=3.3840 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=696.3 | checkpoint=-
# [train] step=1920/2000 | warm=0 | policy=32 | replay=71440 | world_total=11318.7942 | actor=-5.4363 | critic=3.3544 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=700.5 | checkpoint=-
# [train] step=1921/2000 | warm=0 | policy=32 | replay=71472 | world_total=11318.7184 | actor=-5.3264 | critic=3.3663 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=704.3 | checkpoint=-
# [train] step=1922/2000 | warm=0 | policy=32 | replay=71504 | world_total=11318.7825 | actor=-5.1072 | critic=3.5155 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=708.1 | checkpoint=-
# [train] step=1923/2000 | warm=0 | policy=32 | replay=71536 | world_total=11318.8071 | actor=-4.9038 | critic=3.2385 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=711.8 | checkpoint=-
# [train] step=1924/2000 | warm=0 | policy=32 | replay=71568 | world_total=11318.8389 | actor=-4.7819 | critic=3.1624 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=715.5 | checkpoint=-
# [train] step=1925/2000 | warm=0 | policy=32 | replay=71600 | world_total=11318.8409 | actor=-5.0836 | critic=3.2472 | eval_reward=1.2357 | cycle_s=20.5 | elapsed_s=735.9 | checkpoint=checkpoint_01925.pt
# [train] step=1926/2000 | warm=0 | policy=32 | replay=71632 | world_total=11318.9200 | actor=-5.9662 | critic=3.8010 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=742.4 | checkpoint=-
# [train] step=1927/2000 | warm=0 | policy=32 | replay=71664 | world_total=11318.7780 | actor=-6.3644 | critic=4.2419 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=746.0 | checkpoint=-
# [train] step=1928/2000 | warm=0 | policy=32 | replay=71696 | world_total=11318.8047 | actor=-5.5514 | critic=3.8518 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=749.6 | checkpoint=-
# [train] step=1929/2000 | warm=0 | policy=32 | replay=71728 | world_total=11318.7654 | actor=-5.2421 | critic=3.3611 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=753.4 | checkpoint=-
# [train] step=1930/2000 | warm=0 | policy=32 | replay=71760 | world_total=11318.8164 | actor=-5.5740 | critic=3.6409 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=757.3 | checkpoint=-
# [train] step=1931/2000 | warm=0 | policy=32 | replay=71792 | world_total=11318.7891 | actor=-4.8750 | critic=3.3869 | eval_reward=n/a | cycle_s=12.4 | elapsed_s=769.7 | checkpoint=-
# [train] step=1932/2000 | warm=0 | policy=32 | replay=71824 | world_total=11318.8055 | actor=-5.0703 | critic=3.6424 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=773.9 | checkpoint=-
# [train] step=1933/2000 | warm=0 | policy=32 | replay=71856 | world_total=11318.9613 | actor=-5.8636 | critic=3.7602 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=778.0 | checkpoint=-
# [train] step=1934/2000 | warm=0 | policy=32 | replay=71888 | world_total=11318.8607 | actor=-6.0745 | critic=4.0583 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=781.8 | checkpoint=-
# [train] step=1935/2000 | warm=0 | policy=32 | replay=71920 | world_total=11318.7832 | actor=-6.0437 | critic=3.9258 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=785.3 | checkpoint=-
# [train] step=1936/2000 | warm=0 | policy=32 | replay=71952 | world_total=11318.8077 | actor=-5.4695 | critic=3.5396 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=788.9 | checkpoint=-
# [train] step=1937/2000 | warm=0 | policy=32 | replay=71984 | world_total=11318.8004 | actor=-5.1768 | critic=3.2203 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=792.7 | checkpoint=-
# [train] step=1938/2000 | warm=0 | policy=32 | replay=72016 | world_total=11318.7614 | actor=-5.4585 | critic=3.3878 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=796.4 | checkpoint=-
# [train] step=1939/2000 | warm=0 | policy=32 | replay=72048 | world_total=11318.7607 | actor=-5.9706 | critic=3.7152 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=800.3 | checkpoint=-
# [train] step=1940/2000 | warm=0 | policy=32 | replay=72080 | world_total=11318.8337 | actor=-5.6699 | critic=3.6075 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=803.9 | checkpoint=-
# [train] step=1941/2000 | warm=0 | policy=32 | replay=72112 | world_total=11319.3131 | actor=-5.3141 | critic=3.3354 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=806.9 | checkpoint=-
# [train] step=1942/2000 | warm=0 | policy=32 | replay=72144 | world_total=11319.6881 | actor=-6.2760 | critic=4.2884 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=810.6 | checkpoint=-
# [train] step=1943/2000 | warm=0 | policy=32 | replay=72176 | world_total=11319.2588 | actor=-6.7528 | critic=4.5889 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=814.6 | checkpoint=-
# [train] step=1944/2000 | warm=0 | policy=32 | replay=72208 | world_total=11318.9457 | actor=-5.8543 | critic=3.9883 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=817.9 | checkpoint=-
# [train] step=1945/2000 | warm=0 | policy=32 | replay=72240 | world_total=11318.8413 | actor=-5.4167 | critic=3.4398 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=824.0 | checkpoint=-
# [train] step=1946/2000 | warm=0 | policy=32 | replay=72272 | world_total=11318.7277 | actor=-5.1313 | critic=3.2390 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=827.8 | checkpoint=-
# [train] step=1947/2000 | warm=0 | policy=32 | replay=72304 | world_total=11318.7625 | actor=-5.6895 | critic=3.7149 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=832.4 | checkpoint=-
# [train] step=1948/2000 | warm=0 | policy=32 | replay=72336 | world_total=11318.7819 | actor=-6.3063 | critic=4.0741 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=836.2 | checkpoint=-
# [train] step=1949/2000 | warm=0 | policy=32 | replay=72368 | world_total=11318.7544 | actor=-6.7090 | critic=4.3602 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=840.4 | checkpoint=-
# [train] step=1950/2000 | warm=0 | policy=32 | replay=72400 | world_total=11318.6968 | actor=-6.0760 | critic=3.9131 | eval_reward=1.1296 | cycle_s=20.5 | elapsed_s=860.9 | checkpoint=checkpoint_01950.pt
# [train] step=1951/2000 | warm=0 | policy=32 | replay=72432 | world_total=11318.7572 | actor=-5.5558 | critic=3.8198 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=864.7 | checkpoint=-
# [train] step=1952/2000 | warm=0 | policy=32 | replay=72464 | world_total=11318.7616 | actor=-5.6419 | critic=3.4736 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=869.0 | checkpoint=-
# [train] step=1953/2000 | warm=0 | policy=32 | replay=72496 | world_total=11318.6946 | actor=-6.0247 | critic=3.7369 | eval_reward=n/a | cycle_s=15.5 | elapsed_s=884.5 | checkpoint=-
# [train] step=1954/2000 | warm=0 | policy=32 | replay=72528 | world_total=11318.8405 | actor=-5.8214 | critic=3.4917 | eval_reward=n/a | cycle_s=13.1 | elapsed_s=897.6 | checkpoint=-
# [train] step=1955/2000 | warm=0 | policy=32 | replay=72560 | world_total=11318.9275 | actor=-6.0362 | critic=3.8501 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=901.5 | checkpoint=-
# [train] step=1956/2000 | warm=0 | policy=32 | replay=72592 | world_total=11318.7766 | actor=-5.1965 | critic=3.5104 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=905.4 | checkpoint=-
# [train] step=1957/2000 | warm=0 | policy=32 | replay=72624 | world_total=11318.8615 | actor=-5.4557 | critic=3.4943 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=909.6 | checkpoint=-
# [train] step=1958/2000 | warm=0 | policy=32 | replay=72656 | world_total=11318.7305 | actor=-5.9943 | critic=3.9058 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=913.4 | checkpoint=-
# [train] step=1959/2000 | warm=0 | policy=32 | replay=72688 | world_total=11318.7634 | actor=-6.0766 | critic=3.9083 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=917.6 | checkpoint=-
# [train] step=1960/2000 | warm=0 | policy=32 | replay=72720 | world_total=11318.7203 | actor=-6.0651 | critic=3.8161 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=921.4 | checkpoint=-
# [train] step=1961/2000 | warm=0 | policy=32 | replay=72752 | world_total=11318.7297 | actor=-5.6308 | critic=3.7287 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=924.8 | checkpoint=-
# [train] step=1962/2000 | warm=0 | policy=32 | replay=72784 | world_total=11318.6024 | actor=-5.2947 | critic=3.3919 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=928.8 | checkpoint=-
# [train] step=1963/2000 | warm=0 | policy=32 | replay=72816 | world_total=11318.7676 | actor=-5.5965 | critic=3.5461 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=932.6 | checkpoint=-
# [train] step=1964/2000 | warm=0 | policy=32 | replay=72848 | world_total=11318.7815 | actor=-6.1271 | critic=4.1010 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=936.0 | checkpoint=-
# [train] step=1965/2000 | warm=0 | policy=32 | replay=72880 | world_total=11319.2417 | actor=-5.2765 | critic=3.8565 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=939.5 | checkpoint=-
# [train] step=1966/2000 | warm=0 | policy=32 | replay=72912 | world_total=11318.7585 | actor=-4.9802 | critic=3.4078 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=943.0 | checkpoint=-
# [train] step=1967/2000 | warm=0 | policy=32 | replay=72944 | world_total=11318.8074 | actor=-5.6833 | critic=3.7343 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=946.8 | checkpoint=-
# [train] step=1968/2000 | warm=0 | policy=32 | replay=72976 | world_total=11318.7269 | actor=-5.8319 | critic=3.8626 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=950.3 | checkpoint=-
# [train] step=1969/2000 | warm=0 | policy=32 | replay=73008 | world_total=11318.6912 | actor=-5.6948 | critic=3.8011 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=953.8 | checkpoint=-
# [train] step=1970/2000 | warm=0 | policy=32 | replay=73040 | world_total=11318.7269 | actor=-5.0465 | critic=3.2092 | eval_reward=n/a | cycle_s=13.3 | elapsed_s=967.1 | checkpoint=-
# [train] step=1971/2000 | warm=0 | policy=32 | replay=73072 | world_total=11318.6276 | actor=-4.6630 | critic=3.0217 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=971.3 | checkpoint=-
# [train] step=1972/2000 | warm=0 | policy=32 | replay=73104 | world_total=11318.7097 | actor=-5.1977 | critic=3.2170 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=975.2 | checkpoint=-
# [train] step=1973/2000 | warm=0 | policy=32 | replay=73136 | world_total=11318.7332 | actor=-5.0532 | critic=3.1718 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=979.1 | checkpoint=-
# [train] step=1974/2000 | warm=0 | policy=32 | replay=73168 | world_total=11318.7357 | actor=-5.3814 | critic=3.5459 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=983.0 | checkpoint=-
# [train] step=1975/2000 | warm=0 | policy=32 | replay=73200 | world_total=11318.7212 | actor=-5.7527 | critic=3.8333 | eval_reward=1.9742 | cycle_s=23.8 | elapsed_s=1006.8 | checkpoint=checkpoint_01975.pt
# [train] step=1976/2000 | warm=0 | policy=32 | replay=73232 | world_total=11318.7231 | actor=-4.9325 | critic=3.5003 | eval_reward=n/a | cycle_s=6.2 | elapsed_s=1013.0 | checkpoint=-
# [train] step=1977/2000 | warm=0 | policy=32 | replay=73264 | world_total=11318.6803 | actor=-4.7686 | critic=3.2612 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1017.2 | checkpoint=-
# [train] step=1978/2000 | warm=0 | policy=32 | replay=73296 | world_total=11318.6508 | actor=-5.1677 | critic=3.5867 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1021.2 | checkpoint=-
# [train] step=1979/2000 | warm=0 | policy=32 | replay=73328 | world_total=11318.6190 | actor=-4.9022 | critic=3.2920 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1025.3 | checkpoint=-
# [train] step=1980/2000 | warm=0 | policy=32 | replay=73360 | world_total=11318.7502 | actor=-4.3165 | critic=3.2717 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1029.7 | checkpoint=-
# [train] step=1981/2000 | warm=0 | policy=32 | replay=73392 | world_total=11318.8014 | actor=-4.8834 | critic=3.4272 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1033.5 | checkpoint=-
# [train] step=1982/2000 | warm=0 | policy=32 | replay=73424 | world_total=11318.6478 | actor=-5.1720 | critic=3.7944 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1037.3 | checkpoint=-
# [train] step=1983/2000 | warm=0 | policy=32 | replay=73456 | world_total=11318.7373 | actor=-5.2613 | critic=4.0406 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=1040.7 | checkpoint=-
# [train] step=1984/2000 | warm=0 | policy=32 | replay=73488 | world_total=11318.6481 | actor=-4.5080 | critic=3.5946 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1044.4 | checkpoint=-
# [train] step=1985/2000 | warm=0 | policy=32 | replay=73520 | world_total=11318.7310 | actor=-4.2028 | critic=3.3054 | eval_reward=n/a | cycle_s=11.6 | elapsed_s=1056.0 | checkpoint=-
# [train] step=1986/2000 | warm=0 | policy=32 | replay=73552 | world_total=11319.1179 | actor=-4.4142 | critic=3.1140 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1060.6 | checkpoint=-
# [train] step=1987/2000 | warm=0 | policy=32 | replay=73584 | world_total=11319.0039 | actor=-4.3008 | critic=3.1964 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=1065.2 | checkpoint=-
# [train] step=1988/2000 | warm=0 | policy=32 | replay=73616 | world_total=11318.8007 | actor=-4.7929 | critic=3.5891 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1069.0 | checkpoint=-
# [train] step=1989/2000 | warm=0 | policy=32 | replay=73648 | world_total=11318.7649 | actor=-4.6758 | critic=3.4883 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1073.2 | checkpoint=-
# [train] step=1990/2000 | warm=0 | policy=32 | replay=73680 | world_total=11318.7979 | actor=-4.8405 | critic=3.5943 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=1078.2 | checkpoint=-
# [train] step=1991/2000 | warm=0 | policy=32 | replay=73712 | world_total=11319.1116 | actor=-3.9165 | critic=3.1751 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1081.8 | checkpoint=-
# [train] step=1992/2000 | warm=0 | policy=32 | replay=73744 | world_total=11319.4966 | actor=-4.2115 | critic=3.1754 | eval_reward=n/a | cycle_s=13.2 | elapsed_s=1095.0 | checkpoint=-
# [train] step=1993/2000 | warm=0 | policy=32 | replay=73776 | world_total=11319.4034 | actor=-4.5089 | critic=3.5458 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1099.0 | checkpoint=-
# [train] step=1994/2000 | warm=0 | policy=32 | replay=73808 | world_total=11319.0643 | actor=-4.7038 | critic=3.3766 | eval_reward=n/a | cycle_s=12.1 | elapsed_s=1111.0 | checkpoint=-
# [train] step=1995/2000 | warm=0 | policy=32 | replay=73840 | world_total=11319.0988 | actor=-5.6732 | critic=4.1750 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1114.6 | checkpoint=-
# [train] step=1996/2000 | warm=0 | policy=32 | replay=73872 | world_total=11318.9312 | actor=-5.8094 | critic=4.3970 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1118.7 | checkpoint=-
# [train] step=1997/2000 | warm=0 | policy=32 | replay=73904 | world_total=11318.8160 | actor=-4.4109 | critic=3.4321 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1123.0 | checkpoint=-
# [train] step=1998/2000 | warm=0 | policy=32 | replay=73936 | world_total=11318.7700 | actor=-4.4266 | critic=3.1312 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1126.5 | checkpoint=-
# [train] step=1999/2000 | warm=0 | policy=32 | replay=73968 | world_total=11318.6549 | actor=-4.7513 | critic=3.2635 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1130.2 | checkpoint=-
# [train] step=2000/2000 | warm=0 | policy=32 | replay=74000 | world_total=11318.6525 | actor=-4.6964 | critic=3.1821 | eval_reward=0.9227 | cycle_s=20.6 | elapsed_s=1150.7 | checkpoint=checkpoint_02000.pt
# Completed cycles: 2000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter19_entropy_episode_batch/checkpoints/checkpoint_02000.pt
# Latest metrics: {'step': 2000, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 74000, 'world_model/reconstruction_loss': 11311.785522460938, 'world_model/reconstruction_mse': 0.0032337307929992676, 'world_model/observation_log_prob': -11311.785522460938, 'world_model/reward_loss': 1.231862798333168, 'world_model/continue_loss': 0.01729167252779007, 'world_model/kl_loss': 3.4075067341327667, 'world_model/kl_loss_raw': 3.4075067341327667, 'world_model/overshooting_kl_loss': 4.420825362205505, 'world_model/overshooting_feature_mse': 1.6820021271705627, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11318.652465820312, 'behavior/actor_loss': -4.696416139602661, 'behavior/critic_loss': 3.1821497976779938, 'behavior/imagined_reward_mean': 0.88525390625, 'behavior/imagined_value_mean': 3.30859375, 'behavior/actor_entropy': -3.675371140241623, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 0.9226784574976128, 'evaluation/mean_steps': 6.8, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter19_entropy_episode_batch/checkpoints/checkpoint_02000.pt',
#  'latest_metrics': {'behavior/actor_entropy': -3.675371140241623,
#   'behavior/actor_loss': -4.696416139602661,
#   'behavior/critic_loss': 3.1821497976779938,
#   'behavior/imagined_reward_mean': 0.88525390625,
#   'behavior/imagined_value_mean': 3.30859375,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 0.9226784574976128,
#   'evaluation/mean_steps': 6.8,
#   'policy_added': 32,
#   'replay_size': 74000,
#   'step': 2000,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.01729167252779007,
#   'world_model/kl_loss': 3.4075067341327667,
#   'world_model/kl_loss_raw': 3.4075067341327667,
#   'world_model/observation_log_prob': -11311.785522460938,
#   'world_model/overshooting_feature_mse': 1.6820021271705627,
#   'world_model/overshooting_kl_loss': 4.420825362205505,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11311.785522460938,
#   'world_model/reconstruction_mse': 0.0032337307929992676,
#   'world_model/reward_loss': 1.231862798333168,
#   'world_model/total_loss': 11318.652465820312},
#  'latest_step': 2000}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 23.16429424264369,
#   'best_eval_reward_step': 250,
#   'best_imagined_reward_mean': 1.2109375,
#   'best_imagined_reward_step': 1080,
#   'best_world_model_step': 1962,
#   'best_world_model_total_loss': 11318.602416992188,
#   'largest_replay_size': 74000,
#   'largest_replay_step': 2000,
#   'last_metrics': {'behavior/actor_entropy': -3.675371140241623,
#    'behavior/actor_loss': -4.696416139602661,
#    'behavior/critic_loss': 3.1821497976779938,
#    'behavior/imagined_reward_mean': 0.88525390625,
#    'behavior/imagined_value_mean': 3.30859375,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 0.9226784574976128,
#    'evaluation/mean_steps': 6.8,
#    'policy_added': 32,
#    'replay_size': 74000,
#    'step': 2000,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.01729167252779007,
#    'world_model/kl_loss': 3.4075067341327667,
#    'world_model/kl_loss_raw': 3.4075067341327667,
#    'world_model/observation_log_prob': -11311.785522460938,
#    'world_model/overshooting_feature_mse': 1.6820021271705627,
#    'world_model/overshooting_kl_loss': 4.420825362205505,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11311.785522460938,
#    'world_model/reconstruction_mse': 0.0032337307929992676,
#    'world_model/reward_loss': 1.231862798333168,
#    'world_model/total_loss': 11318.652465820312},
#   'last_step': 2000,
#   'num_records': 2216},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11311.785522460938',
#   'world_model/reconstruction_mse': '0.0032337307929992676',
#   'world_model/observation_log_prob': '-11311.785522460938',
#   'world_model/overshooting_kl_loss': '4.420825362205505',
#   'world_model/overshooting_feature_mse': '1.6820021271705627',
#   'evaluation/mean_reward': '0.9226784574976128',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=2 | reward=-0.52 | CRASH | saved iter19_entropy_episode_batch_ep01.gif
# [demo] episode 2/10 | steps=8 | reward=-0.40 | CRASH | saved iter19_entropy_episode_batch_ep02.gif
# [demo] episode 3/10 | steps=12 | reward=3.44 | CRASH | saved iter19_entropy_episode_batch_ep03.gif
# [demo] episode 4/10 | steps=2 | reward=-0.52 | CRASH | saved iter19_entropy_episode_batch_ep04.gif
# [demo] episode 5/10 | steps=23 | reward=15.60 | CRASH | saved iter19_entropy_episode_batch_ep05.gif
# [demo] episode 6/10 | steps=6 | reward=-0.37 | CRASH | saved iter19_entropy_episode_batch_ep06.gif
# [demo] episode 7/10 | steps=2 | reward=-0.52 | CRASH | saved iter19_entropy_episode_batch_ep07.gif
# [demo] episode 8/10 | steps=7 | reward=-0.55 | CRASH | saved iter19_entropy_episode_batch_ep08.gif
# [demo] episode 9/10 | steps=2 | reward=-0.52 | CRASH | saved iter19_entropy_episode_batch_ep09.gif
# [demo] episode 10/10 | steps=6 | reward=-0.37 | CRASH | saved iter19_entropy_episode_batch_ep10.gif
# [demo] done | avg_reward=1.53 | summary=iter19_entropy_episode_batch_summary.json
#
# iter19_entropy_episode_batch_ep01.gif
# iter19_entropy_episode_batch_ep02.gif
# iter19_entropy_episode_batch_ep03.gif
# iter19_entropy_episode_batch_ep04.gif
# iter19_entropy_episode_batch_ep05.gif
# iter19_entropy_episode_batch_ep06.gif
# iter19_entropy_episode_batch_ep07.gif
# iter19_entropy_episode_batch_ep08.gif
# iter19_entropy_episode_batch_ep09.gif
# iter19_entropy_episode_batch_ep10.gif
