# %% [markdown]
# # Tiny Dreamer Highway — Iter 10: steering_penalty
#
# **Name:** Esteban
# **Course:** CSC 580 AI 2
# **Assignment:** Final Project — Dream the Road
# **AI tools consulted:** GitHub Copilot
#
# **Base:** iter5 cumulative
# **New change:** `steering_penalty: 0.0075 → 0.025`
# **Hypothesis:** Penalizing steering magnitude (not just changes) pushes the agent toward straight-line driving by default. Lane changes only happen when the overtake reward clearly outweighs the steering cost.

# %% [markdown]
# ## Iteration 10 — Anti-jitter via steering cost
#
# Complements steering_change_penalty (iter 6). While change penalty taxes oscillation frequency, this taxes steering magnitude — the agent should prefer small, deliberate turns.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='main'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
# Your branch is up to date with 'origin/main'.
# Already up to date.
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD
# Already on 'main'
# From https://github.com/estmon8u/CSC_580_Final_Project
#  * branch            main -> FETCH_HEAD

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

CONFIG_PATH = PROJECT_ROOT / 'notebooks' / 'configs' / 'training_run.yaml'
config = load_experiment_config(CONFIG_PATH)

print(json.dumps(config.model_dump(), indent=2))

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)

# --- Iter5 base overrides (current working config) ---
config.env.action.smoothing_factor = 0.5
config.env.vehicles_count = 12
config.env.npc_speed_scale = 0.65
config.env.reward.normalize_reward = False
config.env.frame_stack = 3

print('\nIter5 base overrides:')
print(f'  smoothing_factor = {config.env.action.smoothing_factor}')
print(f'  vehicles_count = {config.env.vehicles_count}')
print(f'  npc_speed_scale = {config.env.npc_speed_scale}')
print(f'  normalize_reward = {config.env.reward.normalize_reward}')
print(f'  frame_stack = {config.env.frame_stack}')

# --- Iter 10 Override: steering_penalty ---
# steering_penalty 0.0075 → 0.025: penalize any steering magnitude
config.env.reward.steering_penalty = 0.025

print('Iter 10 override:')
print(f'  steering_penalty = {config.env.reward.steering_penalty}')
# Out:
# {
#   "seed": 7,
#   "device": "cuda",
#   "env": {
#     "env_id": "highway-v0",
#     "observation_height": 64,
#     "observation_width": 64,
#     "frame_stack": 1,
#     "max_episode_steps": 75,
#     "lanes_count": 4,
#     "vehicles_count": 28,
#     "npc_speed_scale": 0.85,
#     "simulation_frequency": 15,
#     "policy_frequency": 5,
#     "action": {
#       "type": "continuous",
#       "longitudinal": true,
#       "lateral": true,
#       "longitudinal_scale": 0.7,
#       "lateral_scale": 0.35,
#       "smoothing_factor": 0.6,
#       "num_actions": 5
#     },
#     "reward": {
#       "collision_reward": -1.0,
#       "right_lane_reward": 0.0,
#       "high_speed_reward": 0.8,
#       "lane_change_reward": 0.0,
#       "overtake_reward": 2.5,
#       "normalize_reward": true,
#       "reward_speed_range": [
#         26.0,
#         35.0
#       ],
#       "offroad_terminal": true,
#       "offroad_penalty": 0.5,
#       "steering_penalty": 0.0075,
#       "steering_change_penalty": 0.02
#     }
#   },
#   "replay": {
#     "capacity": 500000,
#     "sequence_length": 16,
#     "batch_size": 256
#   },
#   "training": {
#     "batch_size": 256,
#     "imagination_horizon": 20,
#     "discount": 0.99,
#     "lambda_": 0.95,
#     "overshooting_horizon": 5,
#     "overshooting_kl_weight": 0.5,
#     "world_model_lr": 0.0003,
#     "actor_lr": 8e-05,
#     "critic_lr": 8e-05,
#     "kl_weight": 1.0,
#     "free_nats": 3.0,
#     "continue_loss_weight": 1.0,
#     "grad_clip_norm": 100.0,
#     "lr_warmup_steps": 50,
#     "use_amp": true,
#     "amp_dtype": "bfloat16",
#     "deterministic_torch": false,
#     "world_model_updates_per_cycle": 8,
#     "behavior_updates_per_cycle": 8,
#     "cycles": 2000,
#     "warm_start_steps": 10000,
#     "policy_steps": 32,
#     "checkpoint_interval": 25
#   },
#   "evaluation": {
#     "interval": 25,
#     "episodes": 10,
#     "max_steps": 200
#   },
#   "model": {
#     "embedding_dim": 1024,
#     "deterministic_dim": 200,
#     "stochastic_dim": 30,
#     "hidden_dim": 200,
#     "rssm_num_layers": 2,
#     "rssm_min_std": 0.1,
#     "actor_hidden_dim": 200,
#     "actor_num_layers": 2,
#     "actor_init_std": 1.0,
#     "actor_mean_scale": 5.0,
#     "actor_min_std": 0.0001,
#     "critic_hidden_dim": 200,
#     "critic_num_layers": 3,
#     "critic_distribution_std": 1.0,
#     "observation_distribution_std": 1.0,
#     "reward_hidden_dim": 200,
#     "reward_num_layers": 2,
#     "reward_distribution_std": 1.0,
#     "use_continue_model": true,
#     "continue_hidden_dim": 200,
#     "continue_num_layers": 2
#   }
# }
# Loaded config from: /content/CSC_580_Final_Project/examples/training_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# Iter5 base overrides:
#   smoothing_factor = 0.5
#   vehicles_count = 12
#   npc_speed_scale = 0.65
#   normalize_reward = False
#   frame_stack = 3
# Iter 10 override:
#   steering_penalty = 0.025

# %%
RUN_NAME = 'iter10_steering_penalty'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

CYCLES = 1500
WARM_START_STEPS = None
POLICY_STEPS = None
CHECKPOINT_INTERVAL = None
RESUME_FROM = str('/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter10_steering_penalty/checkpoints/checkpoint_01000.pt')

print('Run name:', RUN_NAME)
print('Resume from:', RESUME_FROM if RESUME_FROM else '(fresh run — old artifacts will be cleared)')
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective policy steps:', config.training.policy_steps if POLICY_STEPS is None else POLICY_STEPS)
# Out:
# Run name: iter10_steering_penalty
# Resume from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter10_steering_penalty/checkpoints/checkpoint_01000.pt
# Effective cycles: 2000
# Effective policy steps: 32

# %%
print('Launching baseline real run. Per-cycle progress lines will appear below.')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('Completed cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching baseline real run. Per-cycle progress lines will appear below.
# [train] starting run | cycles=1500 | start_step=1001 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1001/1500 | warm=0 | policy=32 | replay=42032 | world_total=11320.1471 | actor=-9.7969 | critic=4.9361 | eval_reward=n/a | cycle_s=8.9 | elapsed_s=8.9 | checkpoint=-
# [train] step=1002/1500 | warm=0 | policy=32 | replay=42064 | world_total=11326.9476 | actor=-12.0547 | critic=7.9205 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=12.8 | checkpoint=-
# [train] step=1003/1500 | warm=0 | policy=32 | replay=42096 | world_total=11322.6304 | actor=-11.9766 | critic=7.6628 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=16.5 | checkpoint=-
# [train] step=1004/1500 | warm=0 | policy=32 | replay=42128 | world_total=11321.3010 | actor=-9.5781 | critic=7.5521 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=20.0 | checkpoint=-
# [train] step=1005/1500 | warm=0 | policy=32 | replay=42160 | world_total=11320.7169 | actor=-9.9844 | critic=5.8928 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=23.3 | checkpoint=-
# [train] step=1006/1500 | warm=0 | policy=32 | replay=42192 | world_total=11320.4562 | actor=-10.5469 | critic=5.3622 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=27.0 | checkpoint=-
# [train] step=1007/1500 | warm=0 | policy=32 | replay=42224 | world_total=11320.3909 | actor=-10.9219 | critic=5.5058 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=30.6 | checkpoint=-
# [train] step=1008/1500 | warm=0 | policy=32 | replay=42256 | world_total=11320.3112 | actor=-10.0391 | critic=5.0246 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=34.1 | checkpoint=-
# [train] step=1009/1500 | warm=0 | policy=32 | replay=42288 | world_total=11320.2140 | actor=-8.9062 | critic=4.2423 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=38.0 | checkpoint=-
# [train] step=1010/1500 | warm=0 | policy=32 | replay=42320 | world_total=11320.2334 | actor=-9.8438 | critic=5.0786 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=41.6 | checkpoint=-
# [train] step=1011/1500 | warm=0 | policy=32 | replay=42352 | world_total=11320.0614 | actor=-11.0234 | critic=5.3649 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=45.3 | checkpoint=-
# [train] step=1012/1500 | warm=0 | policy=32 | replay=42384 | world_total=11320.1440 | actor=-10.8828 | critic=5.7630 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=48.9 | checkpoint=-
# [train] step=1013/1500 | warm=0 | policy=32 | replay=42416 | world_total=11320.1774 | actor=-9.9375 | critic=4.5199 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=52.5 | checkpoint=-
# [train] step=1014/1500 | warm=0 | policy=32 | replay=42448 | world_total=11320.0276 | actor=-8.8047 | critic=3.8524 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=56.1 | checkpoint=-
# [train] step=1015/1500 | warm=0 | policy=32 | replay=42480 | world_total=11320.1416 | actor=-8.3047 | critic=3.8439 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=59.7 | checkpoint=-
# [train] step=1016/1500 | warm=0 | policy=32 | replay=42512 | world_total=11320.2559 | actor=-9.0938 | critic=4.0396 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=63.0 | checkpoint=-
# [train] step=1017/1500 | warm=0 | policy=32 | replay=42544 | world_total=11320.1056 | actor=-8.9766 | critic=3.8632 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=66.0 | checkpoint=-
# [train] step=1018/1500 | warm=0 | policy=32 | replay=42576 | world_total=11320.1018 | actor=-9.5078 | critic=4.0829 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=69.5 | checkpoint=-
# [train] step=1019/1500 | warm=0 | policy=32 | replay=42608 | world_total=11320.2180 | actor=-10.6484 | critic=4.9362 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=73.6 | checkpoint=-
# [train] step=1020/1500 | warm=0 | policy=32 | replay=42640 | world_total=11320.2361 | actor=-9.4766 | critic=5.6898 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=77.5 | checkpoint=-
# [train] step=1021/1500 | warm=0 | policy=32 | replay=42672 | world_total=11320.1165 | actor=-9.8438 | critic=4.7018 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=81.3 | checkpoint=-
# [train] step=1022/1500 | warm=0 | policy=32 | replay=42704 | world_total=11320.0914 | actor=-9.1641 | critic=4.1222 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=86.3 | checkpoint=-
# [train] step=1023/1500 | warm=0 | policy=32 | replay=42736 | world_total=11320.2426 | actor=-9.1094 | critic=4.1445 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=90.3 | checkpoint=-
# [train] step=1024/1500 | warm=0 | policy=32 | replay=42768 | world_total=11320.2721 | actor=-8.6406 | critic=4.1670 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=94.1 | checkpoint=-
# [train] step=1025/1500 | warm=0 | policy=32 | replay=42800 | world_total=11320.2977 | actor=-10.0078 | critic=4.3918 | eval_reward=3.3158 | cycle_s=16.3 | elapsed_s=110.4 | checkpoint=checkpoint_01025.pt
# [train] step=1026/1500 | warm=0 | policy=32 | replay=42832 | world_total=11320.2911 | actor=-9.8359 | critic=5.0855 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=113.4 | checkpoint=-
# [train] step=1027/1500 | warm=0 | policy=32 | replay=42864 | world_total=11320.1628 | actor=-8.9766 | critic=4.0326 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=116.8 | checkpoint=-
# [train] step=1028/1500 | warm=0 | policy=32 | replay=42896 | world_total=11320.3247 | actor=-9.6250 | critic=4.7297 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=120.3 | checkpoint=-
# [train] step=1029/1500 | warm=0 | policy=32 | replay=42928 | world_total=11320.2543 | actor=-9.7891 | critic=4.7568 | eval_reward=n/a | cycle_s=6.5 | elapsed_s=126.8 | checkpoint=-
# [train] step=1030/1500 | warm=0 | policy=32 | replay=42960 | world_total=11320.1274 | actor=-11.4062 | critic=5.1369 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=131.0 | checkpoint=-
# [train] step=1031/1500 | warm=0 | policy=32 | replay=42992 | world_total=11320.1410 | actor=-11.6797 | critic=5.8965 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=135.2 | checkpoint=-
# [train] step=1032/1500 | warm=0 | policy=32 | replay=43024 | world_total=11320.2772 | actor=-8.8594 | critic=6.0780 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=139.7 | checkpoint=-
# [train] step=1033/1500 | warm=0 | policy=32 | replay=43056 | world_total=11320.2037 | actor=-7.5625 | critic=4.0936 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=143.5 | checkpoint=-
# [train] step=1034/1500 | warm=0 | policy=32 | replay=43088 | world_total=11320.0863 | actor=-8.9453 | critic=4.5335 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=147.7 | checkpoint=-
# [train] step=1035/1500 | warm=0 | policy=32 | replay=43120 | world_total=11320.1150 | actor=-12.0547 | critic=5.6281 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=152.0 | checkpoint=-
# [train] step=1036/1500 | warm=0 | policy=32 | replay=43152 | world_total=11320.2323 | actor=-13.7969 | critic=6.5968 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=156.0 | checkpoint=-
# [train] step=1037/1500 | warm=0 | policy=32 | replay=43184 | world_total=11320.1871 | actor=-11.1172 | critic=8.0209 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=159.8 | checkpoint=-
# [train] step=1038/1500 | warm=0 | policy=32 | replay=43216 | world_total=11320.2555 | actor=-11.0625 | critic=5.8032 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=163.8 | checkpoint=-
# [train] step=1039/1500 | warm=0 | policy=32 | replay=43248 | world_total=11320.1852 | actor=-10.8359 | critic=5.5093 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=167.7 | checkpoint=-
# [train] step=1040/1500 | warm=0 | policy=32 | replay=43280 | world_total=11320.2389 | actor=-11.4766 | critic=5.7151 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=171.9 | checkpoint=-
# [train] step=1041/1500 | warm=0 | policy=32 | replay=43312 | world_total=11320.2455 | actor=-10.5000 | critic=5.2591 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=174.9 | checkpoint=-
# [train] step=1042/1500 | warm=0 | policy=32 | replay=43344 | world_total=11320.1753 | actor=-9.8516 | critic=4.4553 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=178.4 | checkpoint=-
# [train] step=1043/1500 | warm=0 | policy=32 | replay=43376 | world_total=11320.0419 | actor=-9.8047 | critic=4.7407 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=181.5 | checkpoint=-
# [train] step=1044/1500 | warm=0 | policy=32 | replay=43408 | world_total=11320.1956 | actor=-10.7578 | critic=4.8971 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=185.3 | checkpoint=-
# [train] step=1045/1500 | warm=0 | policy=32 | replay=43440 | world_total=11320.1094 | actor=-10.6016 | critic=5.1914 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=189.2 | checkpoint=-
# [train] step=1046/1500 | warm=0 | policy=32 | replay=43472 | world_total=11320.1259 | actor=-9.3438 | critic=4.6513 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=193.2 | checkpoint=-
# [train] step=1047/1500 | warm=0 | policy=32 | replay=43504 | world_total=11320.1632 | actor=-8.2969 | critic=4.0363 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=196.8 | checkpoint=-
# [train] step=1048/1500 | warm=0 | policy=32 | replay=43536 | world_total=11320.0970 | actor=-8.7188 | critic=4.1095 | eval_reward=n/a | cycle_s=5.7 | elapsed_s=202.5 | checkpoint=-
# [train] step=1049/1500 | warm=0 | policy=32 | replay=43568 | world_total=11320.0648 | actor=-10.2422 | critic=5.0045 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=206.5 | checkpoint=-
# [train] step=1050/1500 | warm=0 | policy=32 | replay=43600 | world_total=11320.2168 | actor=-11.2344 | critic=5.6961 | eval_reward=12.9520 | cycle_s=16.9 | elapsed_s=223.4 | checkpoint=checkpoint_01050.pt
# [train] step=1051/1500 | warm=0 | policy=32 | replay=43632 | world_total=11320.2606 | actor=-10.8594 | critic=4.9893 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=226.5 | checkpoint=-
# [train] step=1052/1500 | warm=0 | policy=32 | replay=43664 | world_total=11320.0811 | actor=-9.9844 | critic=4.5346 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=229.5 | checkpoint=-
# [train] step=1053/1500 | warm=0 | policy=32 | replay=43696 | world_total=11320.0106 | actor=-9.1953 | critic=4.1812 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=234.9 | checkpoint=-
# [train] step=1054/1500 | warm=0 | policy=32 | replay=43728 | world_total=11320.1404 | actor=-7.8945 | critic=3.7293 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=239.2 | checkpoint=-
# [train] step=1055/1500 | warm=0 | policy=32 | replay=43760 | world_total=11320.1691 | actor=-8.0508 | critic=3.7061 | eval_reward=n/a | cycle_s=5.2 | elapsed_s=244.4 | checkpoint=-
# [train] step=1056/1500 | warm=0 | policy=32 | replay=43792 | world_total=11320.1049 | actor=-8.6250 | critic=4.0671 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=248.5 | checkpoint=-
# [train] step=1057/1500 | warm=0 | policy=32 | replay=43824 | world_total=11320.0950 | actor=-9.0234 | critic=4.0143 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=252.7 | checkpoint=-
# [train] step=1058/1500 | warm=0 | policy=32 | replay=43856 | world_total=11320.1731 | actor=-10.7578 | critic=4.9883 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=256.8 | checkpoint=-
# [train] step=1059/1500 | warm=0 | policy=32 | replay=43888 | world_total=11320.1682 | actor=-12.2188 | critic=6.2804 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=261.1 | checkpoint=-
# [train] step=1060/1500 | warm=0 | policy=32 | replay=43920 | world_total=11320.1061 | actor=-9.5000 | critic=5.8535 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=265.0 | checkpoint=-
# [train] step=1061/1500 | warm=0 | policy=32 | replay=43952 | world_total=11320.1105 | actor=-10.0000 | critic=6.0461 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=268.9 | checkpoint=-
# [train] step=1062/1500 | warm=0 | policy=32 | replay=43984 | world_total=11320.0305 | actor=-10.9141 | critic=5.0078 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=272.5 | checkpoint=-
# [train] step=1063/1500 | warm=0 | policy=32 | replay=44016 | world_total=11320.1991 | actor=-9.9375 | critic=5.9828 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=275.8 | checkpoint=-
# [train] step=1064/1500 | warm=0 | policy=32 | replay=44048 | world_total=11320.1860 | actor=-10.2812 | critic=5.6068 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=279.3 | checkpoint=-
# [train] step=1065/1500 | warm=0 | policy=32 | replay=44080 | world_total=11320.0867 | actor=-11.4062 | critic=5.6101 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=282.9 | checkpoint=-
# [train] step=1066/1500 | warm=0 | policy=32 | replay=44112 | world_total=11320.0946 | actor=-12.4375 | critic=6.0125 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=286.9 | checkpoint=-
# [train] step=1067/1500 | warm=0 | policy=32 | replay=44144 | world_total=11320.1287 | actor=-10.1328 | critic=5.8726 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=290.9 | checkpoint=-
# [train] step=1068/1500 | warm=0 | policy=32 | replay=44176 | world_total=11320.1387 | actor=-8.4023 | critic=3.7909 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=294.4 | checkpoint=-
# [train] step=1069/1500 | warm=0 | policy=32 | replay=44208 | world_total=11320.0972 | actor=-8.7422 | critic=3.8465 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=297.7 | checkpoint=-
# [train] step=1070/1500 | warm=0 | policy=32 | replay=44240 | world_total=11320.1285 | actor=-9.9688 | critic=4.4508 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=301.0 | checkpoint=-
# [train] step=1071/1500 | warm=0 | policy=32 | replay=44272 | world_total=11319.9840 | actor=-10.1172 | critic=4.5038 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=304.6 | checkpoint=-
# [train] step=1072/1500 | warm=0 | policy=32 | replay=44304 | world_total=11320.0388 | actor=-8.1523 | critic=4.0280 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=308.8 | checkpoint=-
# [train] step=1073/1500 | warm=0 | policy=32 | replay=44336 | world_total=11320.0913 | actor=-8.1406 | critic=3.8175 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=312.3 | checkpoint=-
# [train] step=1074/1500 | warm=0 | policy=32 | replay=44368 | world_total=11320.0835 | actor=-9.7344 | critic=4.6040 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=315.4 | checkpoint=-
# [train] step=1075/1500 | warm=0 | policy=32 | replay=44400 | world_total=11320.0337 | actor=-11.2578 | critic=5.0920 | eval_reward=11.7818 | cycle_s=16.8 | elapsed_s=332.2 | checkpoint=checkpoint_01075.pt
# [train] step=1076/1500 | warm=0 | policy=32 | replay=44432 | world_total=11320.0616 | actor=-11.0391 | critic=5.2810 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=335.6 | checkpoint=-
# [train] step=1077/1500 | warm=0 | policy=32 | replay=44464 | world_total=11320.0405 | actor=-10.4688 | critic=4.5366 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=338.7 | checkpoint=-
# [train] step=1078/1500 | warm=0 | policy=32 | replay=44496 | world_total=11320.0752 | actor=-9.9766 | critic=4.3989 | eval_reward=n/a | cycle_s=6.3 | elapsed_s=345.1 | checkpoint=-
# [train] step=1079/1500 | warm=0 | policy=32 | replay=44528 | world_total=11320.1572 | actor=-10.2422 | critic=4.3699 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=348.2 | checkpoint=-
# [train] step=1080/1500 | warm=0 | policy=32 | replay=44560 | world_total=11319.9963 | actor=-9.7891 | critic=4.6203 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=351.1 | checkpoint=-
# [train] step=1081/1500 | warm=0 | policy=32 | replay=44592 | world_total=11320.0911 | actor=-10.6094 | critic=4.7686 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=354.6 | checkpoint=-
# [train] step=1082/1500 | warm=0 | policy=32 | replay=44624 | world_total=11320.0431 | actor=-11.5312 | critic=5.5743 | eval_reward=n/a | cycle_s=8.7 | elapsed_s=363.3 | checkpoint=-
# [train] step=1083/1500 | warm=0 | policy=32 | replay=44656 | world_total=11320.1688 | actor=-9.0195 | critic=5.5993 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=367.5 | checkpoint=-
# [train] step=1084/1500 | warm=0 | policy=32 | replay=44688 | world_total=11320.1660 | actor=-9.4141 | critic=5.9307 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=372.0 | checkpoint=-
# [train] step=1085/1500 | warm=0 | policy=32 | replay=44720 | world_total=11320.1428 | actor=-10.2891 | critic=5.7602 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=376.2 | checkpoint=-
# [train] step=1086/1500 | warm=0 | policy=32 | replay=44752 | world_total=11320.0208 | actor=-9.4297 | critic=4.6896 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=380.7 | checkpoint=-
# [train] step=1087/1500 | warm=0 | policy=32 | replay=44784 | world_total=11320.0261 | actor=-8.3438 | critic=3.9722 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=384.9 | checkpoint=-
# [train] step=1088/1500 | warm=0 | policy=32 | replay=44816 | world_total=11320.0126 | actor=-7.3125 | critic=3.3845 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=389.1 | checkpoint=-
# [train] step=1089/1500 | warm=0 | policy=32 | replay=44848 | world_total=11320.0085 | actor=-8.5859 | critic=4.3899 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=393.4 | checkpoint=-
# [train] step=1090/1500 | warm=0 | policy=32 | replay=44880 | world_total=11319.9349 | actor=-10.4922 | critic=4.5359 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=397.4 | checkpoint=-
# [train] step=1091/1500 | warm=0 | policy=32 | replay=44912 | world_total=11319.9407 | actor=-11.5000 | critic=5.0882 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=401.7 | checkpoint=-
# [train] step=1092/1500 | warm=0 | policy=32 | replay=44944 | world_total=11320.0337 | actor=-9.9219 | critic=4.8294 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=406.0 | checkpoint=-
# [train] step=1093/1500 | warm=0 | policy=32 | replay=44976 | world_total=11320.0354 | actor=-8.2930 | critic=3.7545 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=410.4 | checkpoint=-
# [train] step=1094/1500 | warm=0 | policy=32 | replay=45008 | world_total=11319.9246 | actor=-9.8438 | critic=5.3122 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=413.6 | checkpoint=-
# [train] step=1095/1500 | warm=0 | policy=32 | replay=45040 | world_total=11319.9049 | actor=-10.2344 | critic=4.6561 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=417.0 | checkpoint=-
# [train] step=1096/1500 | warm=0 | policy=32 | replay=45072 | world_total=11319.9158 | actor=-11.3125 | critic=5.0805 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=420.1 | checkpoint=-
# [train] step=1097/1500 | warm=0 | policy=32 | replay=45104 | world_total=11320.0149 | actor=-10.9375 | critic=4.6798 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=423.7 | checkpoint=-
# [train] step=1098/1500 | warm=0 | policy=32 | replay=45136 | world_total=11320.0988 | actor=-10.1484 | critic=4.4815 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=427.3 | checkpoint=-
# [train] step=1099/1500 | warm=0 | policy=32 | replay=45168 | world_total=11320.0631 | actor=-8.9141 | critic=4.0166 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=431.2 | checkpoint=-
# [train] step=1100/1500 | warm=0 | policy=32 | replay=45200 | world_total=11320.0782 | actor=-9.1875 | critic=4.3695 | eval_reward=8.8261 | cycle_s=16.4 | elapsed_s=447.6 | checkpoint=checkpoint_01100.pt
# [train] step=1101/1500 | warm=0 | policy=32 | replay=45232 | world_total=11320.0721 | actor=-8.5547 | critic=3.7952 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=451.1 | checkpoint=-
# [train] step=1102/1500 | warm=0 | policy=32 | replay=45264 | world_total=11320.0609 | actor=-8.5703 | critic=3.7941 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=454.6 | checkpoint=-
# [train] step=1103/1500 | warm=0 | policy=32 | replay=45296 | world_total=11320.0507 | actor=-10.9766 | critic=5.0023 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=457.9 | checkpoint=-
# [train] step=1104/1500 | warm=0 | policy=32 | replay=45328 | world_total=11320.1055 | actor=-11.8281 | critic=5.8703 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=461.2 | checkpoint=-
# [train] step=1105/1500 | warm=0 | policy=32 | replay=45360 | world_total=11320.0328 | actor=-10.3750 | critic=4.7619 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=464.1 | checkpoint=-
# [train] step=1106/1500 | warm=0 | policy=32 | replay=45392 | world_total=11320.0343 | actor=-9.4062 | critic=4.1715 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=467.4 | checkpoint=-
# [train] step=1107/1500 | warm=0 | policy=32 | replay=45424 | world_total=11319.9484 | actor=-9.2422 | critic=4.0973 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=470.6 | checkpoint=-
# [train] step=1108/1500 | warm=0 | policy=32 | replay=45456 | world_total=11320.1500 | actor=-8.4609 | critic=4.0585 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=474.1 | checkpoint=-
# [train] step=1109/1500 | warm=0 | policy=32 | replay=45488 | world_total=11319.9551 | actor=-9.1953 | critic=4.2084 | eval_reward=n/a | cycle_s=10.7 | elapsed_s=484.8 | checkpoint=-
# [train] step=1110/1500 | warm=0 | policy=32 | replay=45520 | world_total=11319.9979 | actor=-9.1406 | critic=4.1516 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=488.7 | checkpoint=-
# [train] step=1111/1500 | warm=0 | policy=32 | replay=45552 | world_total=11319.9495 | actor=-8.2969 | critic=3.5520 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=493.0 | checkpoint=-
# [train] step=1112/1500 | warm=0 | policy=32 | replay=45584 | world_total=11320.0975 | actor=-9.3828 | critic=4.2815 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=497.1 | checkpoint=-
# [train] step=1113/1500 | warm=0 | policy=32 | replay=45616 | world_total=11319.9160 | actor=-10.6719 | critic=4.8437 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=501.2 | checkpoint=-
# [train] step=1114/1500 | warm=0 | policy=32 | replay=45648 | world_total=11319.9324 | actor=-9.7891 | critic=4.3326 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=505.1 | checkpoint=-
# [train] step=1115/1500 | warm=0 | policy=32 | replay=45680 | world_total=11320.0038 | actor=-9.8672 | critic=4.5769 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=509.0 | checkpoint=-
# [train] step=1116/1500 | warm=0 | policy=32 | replay=45712 | world_total=11319.9568 | actor=-8.9531 | critic=3.9106 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=513.2 | checkpoint=-
# [train] step=1117/1500 | warm=0 | policy=32 | replay=45744 | world_total=11320.0746 | actor=-10.5000 | critic=4.8912 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=517.2 | checkpoint=-
# [train] step=1118/1500 | warm=0 | policy=32 | replay=45776 | world_total=11320.0084 | actor=-12.0156 | critic=5.5277 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=520.9 | checkpoint=-
# [train] step=1119/1500 | warm=0 | policy=32 | replay=45808 | world_total=11319.8801 | actor=-10.8984 | critic=5.7871 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=524.3 | checkpoint=-
# [train] step=1120/1500 | warm=0 | policy=32 | replay=45840 | world_total=11320.0310 | actor=-9.5547 | critic=4.5285 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=527.6 | checkpoint=-
# [train] step=1121/1500 | warm=0 | policy=32 | replay=45872 | world_total=11319.9476 | actor=-9.2656 | critic=4.1110 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=530.9 | checkpoint=-
# [train] step=1122/1500 | warm=0 | policy=32 | replay=45904 | world_total=11320.0029 | actor=-9.1172 | critic=3.9102 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=534.6 | checkpoint=-
# [train] step=1123/1500 | warm=0 | policy=32 | replay=45936 | world_total=11319.9424 | actor=-8.6719 | critic=3.4851 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=538.2 | checkpoint=-
# [train] step=1124/1500 | warm=0 | policy=32 | replay=45968 | world_total=11320.1633 | actor=-10.7422 | critic=5.6087 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=542.0 | checkpoint=-
# [train] step=1125/1500 | warm=0 | policy=32 | replay=46000 | world_total=11319.9347 | actor=-11.1406 | critic=5.6165 | eval_reward=3.8403 | cycle_s=16.9 | elapsed_s=558.9 | checkpoint=checkpoint_01125.pt
# [train] step=1126/1500 | warm=0 | policy=32 | replay=46032 | world_total=11320.0702 | actor=-9.7188 | critic=4.5874 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=562.6 | checkpoint=-
# [train] step=1127/1500 | warm=0 | policy=32 | replay=46064 | world_total=11319.9921 | actor=-9.0703 | critic=3.8190 | eval_reward=n/a | cycle_s=8.6 | elapsed_s=571.2 | checkpoint=-
# [train] step=1128/1500 | warm=0 | policy=32 | replay=46096 | world_total=11319.9685 | actor=-9.8281 | critic=4.1122 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=574.7 | checkpoint=-
# [train] step=1129/1500 | warm=0 | policy=32 | replay=46128 | world_total=11319.9856 | actor=-9.8594 | critic=3.7642 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=578.4 | checkpoint=-
# [train] step=1130/1500 | warm=0 | policy=32 | replay=46160 | world_total=11319.9379 | actor=-9.0469 | critic=3.6897 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=582.5 | checkpoint=-
# [train] step=1131/1500 | warm=0 | policy=32 | replay=46192 | world_total=11319.8861 | actor=-8.3672 | critic=3.0955 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=586.1 | checkpoint=-
# [train] step=1132/1500 | warm=0 | policy=32 | replay=46224 | world_total=11320.0121 | actor=-8.8281 | critic=3.7371 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=589.9 | checkpoint=-
# [train] step=1133/1500 | warm=0 | policy=32 | replay=46256 | world_total=11319.9501 | actor=-8.5391 | critic=3.5284 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=593.5 | checkpoint=-
# [train] step=1134/1500 | warm=0 | policy=32 | replay=46288 | world_total=11319.9143 | actor=-7.7383 | critic=2.9730 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=596.7 | checkpoint=-
# [train] step=1135/1500 | warm=0 | policy=32 | replay=46320 | world_total=11319.9722 | actor=-8.7031 | critic=4.0288 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=599.7 | checkpoint=-
# [train] step=1136/1500 | warm=0 | policy=32 | replay=46352 | world_total=11319.8717 | actor=-11.2188 | critic=4.8371 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=603.8 | checkpoint=-
# [train] step=1137/1500 | warm=0 | policy=32 | replay=46384 | world_total=11319.9414 | actor=-11.2422 | critic=5.2213 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=607.3 | checkpoint=-
# [train] step=1138/1500 | warm=0 | policy=32 | replay=46416 | world_total=11319.8492 | actor=-10.8828 | critic=4.5174 | eval_reward=n/a | cycle_s=6.4 | elapsed_s=613.7 | checkpoint=-
# [train] step=1139/1500 | warm=0 | policy=32 | replay=46448 | world_total=11319.8322 | actor=-8.4219 | critic=4.2138 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=618.2 | checkpoint=-
# [train] step=1140/1500 | warm=0 | policy=32 | replay=46480 | world_total=11319.9235 | actor=-8.0234 | critic=3.5597 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=622.3 | checkpoint=-
# [train] step=1141/1500 | warm=0 | policy=32 | replay=46512 | world_total=11319.9647 | actor=-8.2344 | critic=3.2934 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=626.2 | checkpoint=-
# [train] step=1142/1500 | warm=0 | policy=32 | replay=46544 | world_total=11319.8246 | actor=-8.3125 | critic=3.1575 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=630.2 | checkpoint=-
# [train] step=1143/1500 | warm=0 | policy=32 | replay=46576 | world_total=11319.8713 | actor=-7.3711 | critic=3.0478 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=634.5 | checkpoint=-
# [train] step=1144/1500 | warm=0 | policy=32 | replay=46608 | world_total=11319.8737 | actor=-8.2500 | critic=3.9028 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=638.1 | checkpoint=-
# [train] step=1145/1500 | warm=0 | policy=32 | replay=46640 | world_total=11319.9186 | actor=-8.5000 | critic=4.0397 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=641.4 | checkpoint=-
# [train] step=1146/1500 | warm=0 | policy=32 | replay=46672 | world_total=11319.9762 | actor=-7.4453 | critic=3.1697 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=644.4 | checkpoint=-
# [train] step=1147/1500 | warm=0 | policy=32 | replay=46704 | world_total=11319.9811 | actor=-8.6406 | critic=4.8881 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=647.9 | checkpoint=-
# [train] step=1148/1500 | warm=0 | policy=32 | replay=46736 | world_total=11319.8823 | actor=-9.3281 | critic=4.7727 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=652.2 | checkpoint=-
# [train] step=1149/1500 | warm=0 | policy=32 | replay=46768 | world_total=11319.9009 | actor=-8.0000 | critic=3.9632 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=656.3 | checkpoint=-
# [train] step=1150/1500 | warm=0 | policy=32 | replay=46800 | world_total=11319.9027 | actor=-7.2734 | critic=3.0463 | eval_reward=7.5430 | cycle_s=17.5 | elapsed_s=673.8 | checkpoint=checkpoint_01150.pt
# [train] step=1151/1500 | warm=0 | policy=32 | replay=46832 | world_total=11319.9042 | actor=-8.5547 | critic=3.9748 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=677.4 | checkpoint=-
# [train] step=1152/1500 | warm=0 | policy=32 | replay=46864 | world_total=11319.8546 | actor=-10.7188 | critic=5.0267 | eval_reward=n/a | cycle_s=7.8 | elapsed_s=685.3 | checkpoint=-
# [train] step=1153/1500 | warm=0 | policy=32 | replay=46896 | world_total=11319.8640 | actor=-9.0469 | critic=5.2560 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=689.0 | checkpoint=-
# [train] step=1154/1500 | warm=0 | policy=32 | replay=46928 | world_total=11319.8079 | actor=-8.0117 | critic=3.5542 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=692.8 | checkpoint=-
# [train] step=1155/1500 | warm=0 | policy=32 | replay=46960 | world_total=11320.2220 | actor=-9.6406 | critic=4.7324 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=696.9 | checkpoint=-
# [train] step=1156/1500 | warm=0 | policy=32 | replay=46992 | world_total=11320.0338 | actor=-10.2578 | critic=5.3832 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=700.8 | checkpoint=-
# [train] step=1157/1500 | warm=0 | policy=32 | replay=47024 | world_total=11319.7458 | actor=-8.3047 | critic=4.1112 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=706.1 | checkpoint=-
# [train] step=1158/1500 | warm=0 | policy=32 | replay=47056 | world_total=11319.9087 | actor=-8.4023 | critic=4.3519 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=710.3 | checkpoint=-
# [train] step=1159/1500 | warm=0 | policy=32 | replay=47088 | world_total=11319.8818 | actor=-9.4141 | critic=4.2527 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=713.9 | checkpoint=-
# [train] step=1160/1500 | warm=0 | policy=32 | replay=47120 | world_total=11319.8612 | actor=-8.2969 | critic=3.7429 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=717.7 | checkpoint=-
# [train] step=1161/1500 | warm=0 | policy=32 | replay=47152 | world_total=11319.7858 | actor=-9.1406 | critic=4.3843 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=720.9 | checkpoint=-
# [train] step=1162/1500 | warm=0 | policy=32 | replay=47184 | world_total=11319.9152 | actor=-11.0703 | critic=4.8611 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=724.5 | checkpoint=-
# [train] step=1163/1500 | warm=0 | policy=32 | replay=47216 | world_total=11319.8883 | actor=-11.0625 | critic=5.8829 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=728.5 | checkpoint=-
# [train] step=1164/1500 | warm=0 | policy=32 | replay=47248 | world_total=11319.8551 | actor=-9.9219 | critic=4.5124 | eval_reward=n/a | cycle_s=7.3 | elapsed_s=735.8 | checkpoint=-
# [train] step=1165/1500 | warm=0 | policy=32 | replay=47280 | world_total=11319.9476 | actor=-8.9219 | critic=3.7845 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=740.4 | checkpoint=-
# [train] step=1166/1500 | warm=0 | policy=32 | replay=47312 | world_total=11320.0023 | actor=-9.3125 | critic=3.8307 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=744.3 | checkpoint=-
# [train] step=1167/1500 | warm=0 | policy=32 | replay=47344 | world_total=11320.0125 | actor=-9.6562 | critic=4.1800 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=748.5 | checkpoint=-
# [train] step=1168/1500 | warm=0 | policy=32 | replay=47376 | world_total=11320.0516 | actor=-9.5703 | critic=3.9512 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=752.7 | checkpoint=-
# [train] step=1169/1500 | warm=0 | policy=32 | replay=47408 | world_total=11319.9027 | actor=-8.6719 | critic=3.8585 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=756.8 | checkpoint=-
# [train] step=1170/1500 | warm=0 | policy=32 | replay=47440 | world_total=11319.9016 | actor=-8.6172 | critic=3.6025 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=760.2 | checkpoint=-
# [train] step=1171/1500 | warm=0 | policy=32 | replay=47472 | world_total=11319.9535 | actor=-8.6172 | critic=3.5076 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=763.5 | checkpoint=-
# [train] step=1172/1500 | warm=0 | policy=32 | replay=47504 | world_total=11319.8258 | actor=-7.8711 | critic=3.3206 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=767.4 | checkpoint=-
# [train] step=1173/1500 | warm=0 | policy=32 | replay=47536 | world_total=11319.8125 | actor=-8.7422 | critic=4.2541 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=771.4 | checkpoint=-
# [train] step=1174/1500 | warm=0 | policy=32 | replay=47568 | world_total=11319.9581 | actor=-11.0234 | critic=4.9456 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=775.2 | checkpoint=-
# [train] step=1175/1500 | warm=0 | policy=32 | replay=47600 | world_total=11319.9921 | actor=-10.6562 | critic=5.2900 | eval_reward=10.2426 | cycle_s=17.7 | elapsed_s=792.8 | checkpoint=checkpoint_01175.pt
# [train] step=1176/1500 | warm=0 | policy=32 | replay=47632 | world_total=11319.9551 | actor=-9.6875 | critic=3.9282 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=796.5 | checkpoint=-
# [train] step=1177/1500 | warm=0 | policy=32 | replay=47664 | world_total=11319.9625 | actor=-8.9062 | critic=3.4956 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=801.6 | checkpoint=-
# [train] step=1178/1500 | warm=0 | policy=32 | replay=47696 | world_total=11319.8287 | actor=-9.3672 | critic=3.6101 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=805.1 | checkpoint=-
# [train] step=1179/1500 | warm=0 | policy=32 | replay=47728 | world_total=11319.7714 | actor=-9.3984 | critic=3.6295 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=809.2 | checkpoint=-
# [train] step=1180/1500 | warm=0 | policy=32 | replay=47760 | world_total=11319.8105 | actor=-9.1953 | critic=3.8493 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=813.5 | checkpoint=-
# [train] step=1181/1500 | warm=0 | policy=32 | replay=47792 | world_total=11319.8555 | actor=-8.7812 | critic=3.3279 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=817.8 | checkpoint=-
# [train] step=1182/1500 | warm=0 | policy=32 | replay=47824 | world_total=11319.9338 | actor=-9.9375 | critic=4.0765 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=821.3 | checkpoint=-
# [train] step=1183/1500 | warm=0 | policy=32 | replay=47856 | world_total=11319.8514 | actor=-12.2500 | critic=5.2205 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=824.7 | checkpoint=-
# [train] step=1184/1500 | warm=0 | policy=32 | replay=47888 | world_total=11319.7704 | actor=-9.9609 | critic=7.1895 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=828.1 | checkpoint=-
# [train] step=1185/1500 | warm=0 | policy=32 | replay=47920 | world_total=11319.8287 | actor=-8.2227 | critic=3.7683 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=831.7 | checkpoint=-
# [train] step=1186/1500 | warm=0 | policy=32 | replay=47952 | world_total=11319.9012 | actor=-8.9844 | critic=4.0348 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=835.0 | checkpoint=-
# [train] step=1187/1500 | warm=0 | policy=32 | replay=47984 | world_total=11319.8557 | actor=-9.6406 | critic=4.1653 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=838.4 | checkpoint=-
# [train] step=1188/1500 | warm=0 | policy=32 | replay=48016 | world_total=11319.7631 | actor=-10.6953 | critic=4.3333 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=842.7 | checkpoint=-
# [train] step=1189/1500 | warm=0 | policy=32 | replay=48048 | world_total=11319.8188 | actor=-9.2656 | critic=4.0843 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=847.0 | checkpoint=-
# [train] step=1190/1500 | warm=0 | policy=32 | replay=48080 | world_total=11319.7916 | actor=-8.2734 | critic=3.2937 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=850.6 | checkpoint=-
# [train] step=1191/1500 | warm=0 | policy=32 | replay=48112 | world_total=11319.8628 | actor=-9.2500 | critic=4.0712 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=854.3 | checkpoint=-
# [train] step=1192/1500 | warm=0 | policy=32 | replay=48144 | world_total=11319.9032 | actor=-8.9141 | critic=4.8397 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=858.4 | checkpoint=-
# [train] step=1193/1500 | warm=0 | policy=32 | replay=48176 | world_total=11319.8831 | actor=-8.5703 | critic=3.9360 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=862.4 | checkpoint=-
# [train] step=1194/1500 | warm=0 | policy=32 | replay=48208 | world_total=11319.8759 | actor=-10.0234 | critic=4.3414 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=866.9 | checkpoint=-
# [train] step=1195/1500 | warm=0 | policy=32 | replay=48240 | world_total=11319.8606 | actor=-11.0703 | critic=5.0166 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=870.9 | checkpoint=-
# [train] step=1196/1500 | warm=0 | policy=32 | replay=48272 | world_total=11319.7661 | actor=-10.2266 | critic=4.3320 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=874.4 | checkpoint=-
# [train] step=1197/1500 | warm=0 | policy=32 | replay=48304 | world_total=11319.7711 | actor=-8.9688 | critic=3.4390 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=877.9 | checkpoint=-
# [train] step=1198/1500 | warm=0 | policy=32 | replay=48336 | world_total=11319.8210 | actor=-8.2344 | critic=3.3085 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=881.3 | checkpoint=-
# [train] step=1199/1500 | warm=0 | policy=32 | replay=48368 | world_total=11319.8513 | actor=-8.4062 | critic=3.0530 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=885.7 | checkpoint=-
# [train] step=1200/1500 | warm=0 | policy=32 | replay=48400 | world_total=11319.7136 | actor=-8.3164 | critic=3.2593 | eval_reward=9.8825 | cycle_s=18.2 | elapsed_s=903.9 | checkpoint=checkpoint_01200.pt
# [train] step=1201/1500 | warm=0 | policy=32 | replay=48432 | world_total=11319.7671 | actor=-8.3438 | critic=3.1070 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=907.9 | checkpoint=-
# [train] step=1202/1500 | warm=0 | policy=32 | replay=48464 | world_total=11319.8677 | actor=-9.9453 | critic=4.2381 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=911.6 | checkpoint=-
# [train] step=1203/1500 | warm=0 | policy=32 | replay=48496 | world_total=11319.9200 | actor=-11.4609 | critic=4.6043 | eval_reward=n/a | cycle_s=5.1 | elapsed_s=916.7 | checkpoint=-
# [train] step=1204/1500 | warm=0 | policy=32 | replay=48528 | world_total=11319.9082 | actor=-8.9609 | critic=4.7519 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=920.4 | checkpoint=-
# [train] step=1205/1500 | warm=0 | policy=32 | replay=48560 | world_total=11319.8818 | actor=-8.2266 | critic=3.5745 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=924.3 | checkpoint=-
# [train] step=1206/1500 | warm=0 | policy=32 | replay=48592 | world_total=11319.7426 | actor=-8.3477 | critic=3.1719 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=928.2 | checkpoint=-
# [train] step=1207/1500 | warm=0 | policy=32 | replay=48624 | world_total=11319.6847 | actor=-9.1172 | critic=3.5560 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=932.4 | checkpoint=-
# [train] step=1208/1500 | warm=0 | policy=32 | replay=48656 | world_total=11319.8159 | actor=-8.9297 | critic=3.5421 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=936.4 | checkpoint=-
# [train] step=1209/1500 | warm=0 | policy=32 | replay=48688 | world_total=11319.6902 | actor=-7.5234 | critic=2.9597 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=940.3 | checkpoint=-
# [train] step=1210/1500 | warm=0 | policy=32 | replay=48720 | world_total=11319.9052 | actor=-8.8203 | critic=4.2171 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=943.8 | checkpoint=-
# [train] step=1211/1500 | warm=0 | policy=32 | replay=48752 | world_total=11319.8743 | actor=-9.1016 | critic=4.2715 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=947.4 | checkpoint=-
# [train] step=1212/1500 | warm=0 | policy=32 | replay=48784 | world_total=11319.8900 | actor=-8.2266 | critic=3.3744 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=950.6 | checkpoint=-
# [train] step=1213/1500 | warm=0 | policy=32 | replay=48816 | world_total=11319.8560 | actor=-9.9141 | critic=4.6279 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=954.2 | checkpoint=-
# [train] step=1214/1500 | warm=0 | policy=32 | replay=48848 | world_total=11319.9316 | actor=-10.3203 | critic=4.9396 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=957.6 | checkpoint=-
# [train] step=1215/1500 | warm=0 | policy=32 | replay=48880 | world_total=11319.9093 | actor=-8.1797 | critic=3.9149 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=961.1 | checkpoint=-
# [train] step=1216/1500 | warm=0 | policy=32 | replay=48912 | world_total=11319.8462 | actor=-7.7383 | critic=3.5933 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=964.7 | checkpoint=-
# [train] step=1217/1500 | warm=0 | policy=32 | replay=48944 | world_total=11319.8573 | actor=-7.7266 | critic=3.3117 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=969.2 | checkpoint=-
# [train] step=1218/1500 | warm=0 | policy=32 | replay=48976 | world_total=11319.8209 | actor=-8.1719 | critic=3.3748 | eval_reward=n/a | cycle_s=4.6 | elapsed_s=973.7 | checkpoint=-
# [train] step=1219/1500 | warm=0 | policy=32 | replay=49008 | world_total=11319.7693 | actor=-8.2773 | critic=3.3706 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=977.7 | checkpoint=-
# [train] step=1220/1500 | warm=0 | policy=32 | replay=49040 | world_total=11319.8334 | actor=-8.5234 | critic=3.5206 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=982.1 | checkpoint=-
# [train] step=1221/1500 | warm=0 | policy=32 | replay=49072 | world_total=11319.9246 | actor=-9.6172 | critic=3.9855 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=986.4 | checkpoint=-
# [train] step=1222/1500 | warm=0 | policy=32 | replay=49104 | world_total=11319.9478 | actor=-8.3164 | critic=3.9189 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=990.7 | checkpoint=-
# [train] step=1223/1500 | warm=0 | policy=32 | replay=49136 | world_total=11319.7847 | actor=-10.1016 | critic=6.5279 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=994.0 | checkpoint=-
# [train] step=1224/1500 | warm=0 | policy=32 | replay=49168 | world_total=11319.8126 | actor=-8.8047 | critic=5.1224 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=997.6 | checkpoint=-
# [train] step=1225/1500 | warm=0 | policy=32 | replay=49200 | world_total=11319.8556 | actor=-9.2031 | critic=3.7591 | eval_reward=7.1455 | cycle_s=17.1 | elapsed_s=1014.7 | checkpoint=checkpoint_01225.pt
# [train] step=1226/1500 | warm=0 | policy=32 | replay=49232 | world_total=11319.7482 | actor=-8.0391 | critic=3.4420 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=1018.0 | checkpoint=-
# [train] step=1227/1500 | warm=0 | policy=32 | replay=49264 | world_total=11319.7798 | actor=-7.3633 | critic=3.0004 | eval_reward=n/a | cycle_s=5.4 | elapsed_s=1023.4 | checkpoint=-
# [train] step=1228/1500 | warm=0 | policy=32 | replay=49296 | world_total=11319.8846 | actor=-7.7031 | critic=3.1850 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1027.8 | checkpoint=-
# [train] step=1229/1500 | warm=0 | policy=32 | replay=49328 | world_total=11319.7292 | actor=-9.8672 | critic=4.0275 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1031.5 | checkpoint=-
# [train] step=1230/1500 | warm=0 | policy=32 | replay=49360 | world_total=11319.7418 | actor=-9.7031 | critic=4.4001 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=1034.9 | checkpoint=-
# [train] step=1231/1500 | warm=0 | policy=32 | replay=49392 | world_total=11319.9193 | actor=-7.2695 | critic=4.2922 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1038.5 | checkpoint=-
# [train] step=1232/1500 | warm=0 | policy=32 | replay=49424 | world_total=11319.7429 | actor=-7.7734 | critic=4.8034 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1042.1 | checkpoint=-
# [train] step=1233/1500 | warm=0 | policy=32 | replay=49456 | world_total=11319.9155 | actor=-9.4453 | critic=4.2728 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1046.0 | checkpoint=-
# [train] step=1234/1500 | warm=0 | policy=32 | replay=49488 | world_total=11319.8842 | actor=-11.7500 | critic=5.3693 | eval_reward=n/a | cycle_s=6.1 | elapsed_s=1052.1 | checkpoint=-
# [train] step=1235/1500 | warm=0 | policy=32 | replay=49520 | world_total=11319.8702 | actor=-10.1562 | critic=6.7804 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1056.6 | checkpoint=-
# [train] step=1236/1500 | warm=0 | policy=32 | replay=49552 | world_total=11319.9591 | actor=-8.2852 | critic=3.9117 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1060.7 | checkpoint=-
# [train] step=1237/1500 | warm=0 | policy=32 | replay=49584 | world_total=11319.7545 | actor=-8.5742 | critic=4.2479 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1065.0 | checkpoint=-
# [train] step=1238/1500 | warm=0 | policy=32 | replay=49616 | world_total=11319.7939 | actor=-8.8906 | critic=4.0362 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1068.6 | checkpoint=-
# [train] step=1239/1500 | warm=0 | policy=32 | replay=49648 | world_total=11319.7582 | actor=-8.0039 | critic=3.3947 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=1071.9 | checkpoint=-
# [train] step=1240/1500 | warm=0 | policy=32 | replay=49680 | world_total=11319.6899 | actor=-9.1797 | critic=4.5838 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1075.6 | checkpoint=-
# [train] step=1241/1500 | warm=0 | policy=32 | replay=49712 | world_total=11319.8384 | actor=-11.1484 | critic=4.9964 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1079.4 | checkpoint=-
# [train] step=1242/1500 | warm=0 | policy=32 | replay=49744 | world_total=11319.8467 | actor=-10.7031 | critic=5.9708 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1083.3 | checkpoint=-
# [train] step=1243/1500 | warm=0 | policy=32 | replay=49776 | world_total=11319.7941 | actor=-8.3438 | critic=4.0250 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1087.6 | checkpoint=-
# [train] step=1244/1500 | warm=0 | policy=32 | replay=49808 | world_total=11319.7760 | actor=-9.2500 | critic=5.8862 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1091.9 | checkpoint=-
# [train] step=1245/1500 | warm=0 | policy=32 | replay=49840 | world_total=11319.7911 | actor=-8.6953 | critic=4.5542 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=1095.0 | checkpoint=-
# [train] step=1246/1500 | warm=0 | policy=32 | replay=49872 | world_total=11319.7732 | actor=-8.6953 | critic=3.6581 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1099.2 | checkpoint=-
# [train] step=1247/1500 | warm=0 | policy=32 | replay=49904 | world_total=11319.7009 | actor=-8.8906 | critic=3.9940 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1103.7 | checkpoint=-
# [train] step=1248/1500 | warm=0 | policy=32 | replay=49936 | world_total=11319.7896 | actor=-10.0156 | critic=4.5015 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1107.4 | checkpoint=-
# [train] step=1249/1500 | warm=0 | policy=32 | replay=49968 | world_total=11319.7766 | actor=-8.6172 | critic=5.4974 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1111.0 | checkpoint=-
# [train] step=1250/1500 | warm=0 | policy=32 | replay=50000 | world_total=11319.8464 | actor=-7.2500 | critic=3.1554 | eval_reward=12.2403 | cycle_s=18.1 | elapsed_s=1129.1 | checkpoint=checkpoint_01250.pt
# [train] step=1251/1500 | warm=0 | policy=32 | replay=50032 | world_total=11319.7706 | actor=-8.1797 | critic=3.7505 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=1132.4 | checkpoint=-
# [train] step=1252/1500 | warm=0 | policy=32 | replay=50064 | world_total=11319.9045 | actor=-10.4766 | critic=5.0971 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1136.6 | checkpoint=-
# [train] step=1253/1500 | warm=0 | policy=32 | replay=50096 | world_total=11319.8840 | actor=-9.3281 | critic=5.6608 | eval_reward=n/a | cycle_s=5.3 | elapsed_s=1141.9 | checkpoint=-
# [train] step=1254/1500 | warm=0 | policy=32 | replay=50128 | world_total=11319.7964 | actor=-9.8125 | critic=4.4157 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1145.8 | checkpoint=-
# [train] step=1255/1500 | warm=0 | policy=32 | replay=50160 | world_total=11319.8656 | actor=-9.1641 | critic=3.9056 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=1149.5 | checkpoint=-
# [train] step=1256/1500 | warm=0 | policy=32 | replay=50192 | world_total=11319.6490 | actor=-8.9062 | critic=3.5678 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1153.3 | checkpoint=-
# [train] step=1257/1500 | warm=0 | policy=32 | replay=50224 | world_total=11319.8629 | actor=-8.8516 | critic=3.6486 | eval_reward=n/a | cycle_s=4.7 | elapsed_s=1158.0 | checkpoint=-
# [train] step=1258/1500 | warm=0 | policy=32 | replay=50256 | world_total=11320.0231 | actor=-8.2500 | critic=3.4155 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1162.0 | checkpoint=-
# [train] step=1259/1500 | warm=0 | policy=32 | replay=50288 | world_total=11319.8723 | actor=-8.3516 | critic=3.2352 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1166.1 | checkpoint=-
# [train] step=1260/1500 | warm=0 | policy=32 | replay=50320 | world_total=11319.7991 | actor=-8.8047 | critic=3.7452 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1170.5 | checkpoint=-
# [train] step=1261/1500 | warm=0 | policy=32 | replay=50352 | world_total=11319.7504 | actor=-9.1016 | critic=3.6050 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=1174.7 | checkpoint=-
# [train] step=1262/1500 | warm=0 | policy=32 | replay=50384 | world_total=11319.8130 | actor=-8.9219 | critic=3.5821 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1178.7 | checkpoint=-
# ...
# [train] step=1420/1500 | warm=0 | policy=32 | replay=55440 | world_total=11319.5494 | actor=-10.1562 | critic=4.4146 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=1933.4 | checkpoint=-
# [train] step=1421/1500 | warm=0 | policy=32 | replay=55472 | world_total=11319.5081 | actor=-8.3555 | critic=4.2569 | eval_reward=n/a | cycle_s=7.1 | elapsed_s=1940.5 | checkpoint=-
# [train] step=1422/1500 | warm=0 | policy=32 | replay=55504 | world_total=11319.5663 | actor=-6.9453 | critic=3.1177 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=1944.2 | checkpoint=-
# [train] step=1423/1500 | warm=0 | policy=32 | replay=55536 | world_total=11319.6416 | actor=-7.9922 | critic=3.4619 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1948.1 | checkpoint=-
# [train] step=1424/1500 | warm=0 | policy=32 | replay=55568 | world_total=11319.5275 | actor=-7.7188 | critic=3.8471 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1952.0 | checkpoint=-
# [train] step=1425/1500 | warm=0 | policy=32 | replay=55600 | world_total=11319.5953 | actor=-7.7344 | critic=3.8729 | eval_reward=4.8380 | cycle_s=18.2 | elapsed_s=1970.2 | checkpoint=checkpoint_01425.pt
# [train] step=1426/1500 | warm=0 | policy=32 | replay=55632 | world_total=11319.4921 | actor=-8.7109 | critic=3.9171 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1974.2 | checkpoint=-
# [train] step=1427/1500 | warm=0 | policy=32 | replay=55664 | world_total=11319.4285 | actor=-7.4297 | critic=3.5837 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=1978.6 | checkpoint=-
# [train] step=1428/1500 | warm=0 | policy=32 | replay=55696 | world_total=11319.4928 | actor=-7.6172 | critic=3.9395 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=1982.7 | checkpoint=-
# [train] step=1429/1500 | warm=0 | policy=32 | replay=55728 | world_total=11319.4064 | actor=-8.5547 | critic=3.8207 | eval_reward=n/a | cycle_s=4.5 | elapsed_s=1987.2 | checkpoint=-
# [train] step=1430/1500 | warm=0 | policy=32 | replay=55760 | world_total=11319.4081 | actor=-7.2461 | critic=3.5232 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=1991.2 | checkpoint=-
# [train] step=1431/1500 | warm=0 | policy=32 | replay=55792 | world_total=11319.5012 | actor=-7.2383 | critic=3.7785 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=1995.1 | checkpoint=-
# [train] step=1432/1500 | warm=0 | policy=32 | replay=55824 | world_total=11319.5428 | actor=-7.8633 | critic=3.3830 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=1999.0 | checkpoint=-
# [train] step=1433/1500 | warm=0 | policy=32 | replay=55856 | world_total=11319.4825 | actor=-7.5664 | critic=3.0963 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=2003.2 | checkpoint=-
# [train] step=1434/1500 | warm=0 | policy=32 | replay=55888 | world_total=11319.5695 | actor=-7.0625 | critic=2.7479 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2006.9 | checkpoint=-
# [train] step=1435/1500 | warm=0 | policy=32 | replay=55920 | world_total=11319.5837 | actor=-7.9062 | critic=3.0364 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2010.6 | checkpoint=-
# [train] step=1436/1500 | warm=0 | policy=32 | replay=55952 | world_total=11319.6727 | actor=-7.5508 | critic=3.2775 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2014.3 | checkpoint=-
# [train] step=1437/1500 | warm=0 | policy=32 | replay=55984 | world_total=11319.5555 | actor=-7.8203 | critic=3.0359 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=2018.5 | checkpoint=-
# [train] step=1438/1500 | warm=0 | policy=32 | replay=56016 | world_total=11319.5646 | actor=-7.7852 | critic=3.1307 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2022.5 | checkpoint=-
# [train] step=1439/1500 | warm=0 | policy=32 | replay=56048 | world_total=11319.4064 | actor=-7.2070 | critic=3.0504 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=2026.7 | checkpoint=-
# [train] step=1440/1500 | warm=0 | policy=32 | replay=56080 | world_total=11319.5649 | actor=-6.4883 | critic=2.6056 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=2030.6 | checkpoint=-
# [train] step=1441/1500 | warm=0 | policy=32 | replay=56112 | world_total=11319.6146 | actor=-6.9531 | critic=3.1576 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2034.3 | checkpoint=-
# [train] step=1442/1500 | warm=0 | policy=32 | replay=56144 | world_total=11319.4998 | actor=-8.0898 | critic=3.3472 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2038.3 | checkpoint=-
# [train] step=1443/1500 | warm=0 | policy=32 | replay=56176 | world_total=11319.6017 | actor=-7.9492 | critic=3.3472 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2041.8 | checkpoint=-
# [train] step=1444/1500 | warm=0 | policy=32 | replay=56208 | world_total=11319.5514 | actor=-6.4961 | critic=2.8632 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2045.6 | checkpoint=-
# [train] step=1445/1500 | warm=0 | policy=32 | replay=56240 | world_total=11319.4868 | actor=-6.2109 | critic=2.7225 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2049.4 | checkpoint=-
# [train] step=1446/1500 | warm=0 | policy=32 | replay=56272 | world_total=11319.5754 | actor=-6.7891 | critic=2.8429 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=2052.7 | checkpoint=-
# [train] step=1447/1500 | warm=0 | policy=32 | replay=56304 | world_total=11319.5479 | actor=-7.3125 | critic=2.9913 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2055.9 | checkpoint=-
# [train] step=1448/1500 | warm=0 | policy=32 | replay=56336 | world_total=11319.5742 | actor=-8.6328 | critic=3.6710 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2059.4 | checkpoint=-
# [train] step=1449/1500 | warm=0 | policy=32 | replay=56368 | world_total=11319.5780 | actor=-9.2656 | critic=3.7973 | eval_reward=n/a | cycle_s=9.4 | elapsed_s=2068.7 | checkpoint=-
# [train] step=1450/1500 | warm=0 | policy=32 | replay=56400 | world_total=11319.5692 | actor=-8.6250 | critic=3.8138 | eval_reward=2.8104 | cycle_s=19.0 | elapsed_s=2087.7 | checkpoint=checkpoint_01450.pt
# [train] step=1451/1500 | warm=0 | policy=32 | replay=56432 | world_total=11319.5115 | actor=-7.3125 | critic=3.0640 | eval_reward=n/a | cycle_s=10.5 | elapsed_s=2098.2 | checkpoint=-
# [train] step=1452/1500 | warm=0 | policy=32 | replay=56464 | world_total=11319.5801 | actor=-7.3086 | critic=2.8551 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=2101.8 | checkpoint=-
# [train] step=1453/1500 | warm=0 | policy=32 | replay=56496 | world_total=11319.5577 | actor=-7.7852 | critic=2.9768 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=2105.1 | checkpoint=-
# [train] step=1454/1500 | warm=0 | policy=32 | replay=56528 | world_total=11319.6240 | actor=-7.8047 | critic=3.3362 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=2108.9 | checkpoint=-
# [train] step=1455/1500 | warm=0 | policy=32 | replay=56560 | world_total=11319.4753 | actor=-8.4844 | critic=3.1988 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2112.5 | checkpoint=-
# [train] step=1456/1500 | warm=0 | policy=32 | replay=56592 | world_total=11319.5679 | actor=-7.5820 | critic=3.3386 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=2116.6 | checkpoint=-
# [train] step=1457/1500 | warm=0 | policy=32 | replay=56624 | world_total=11319.4838 | actor=-7.0625 | critic=3.0358 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=2120.3 | checkpoint=-
# [train] step=1458/1500 | warm=0 | policy=32 | replay=56656 | world_total=11319.5100 | actor=-7.3398 | critic=2.9133 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2123.8 | checkpoint=-
# [train] step=1459/1500 | warm=0 | policy=32 | replay=56688 | world_total=11319.4731 | actor=-7.6406 | critic=2.8637 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2127.2 | checkpoint=-
# [train] step=1460/1500 | warm=0 | policy=32 | replay=56720 | world_total=11319.4471 | actor=-7.7852 | critic=2.9860 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=2130.8 | checkpoint=-
# [train] step=1461/1500 | warm=0 | policy=32 | replay=56752 | world_total=11319.4314 | actor=-7.5547 | critic=2.7129 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2134.0 | checkpoint=-
# [train] step=1462/1500 | warm=0 | policy=32 | replay=56784 | world_total=11319.4554 | actor=-6.9297 | critic=2.6650 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=2136.8 | checkpoint=-
# [train] step=1463/1500 | warm=0 | policy=32 | replay=56816 | world_total=11319.5312 | actor=-7.1211 | critic=2.5977 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2139.8 | checkpoint=-
# [train] step=1464/1500 | warm=0 | policy=32 | replay=56848 | world_total=11319.4681 | actor=-7.8438 | critic=2.9848 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=2143.0 | checkpoint=-
# [train] step=1465/1500 | warm=0 | policy=32 | replay=56880 | world_total=11319.5751 | actor=-9.3906 | critic=3.6910 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=2145.5 | checkpoint=-
# [train] step=1466/1500 | warm=0 | policy=32 | replay=56912 | world_total=11319.4468 | actor=-10.4844 | critic=4.3279 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2148.5 | checkpoint=-
# [train] step=1467/1500 | warm=0 | policy=32 | replay=56944 | world_total=11319.4752 | actor=-8.0508 | critic=4.7022 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2151.5 | checkpoint=-
# [train] step=1468/1500 | warm=0 | policy=32 | replay=56976 | world_total=11319.3839 | actor=-8.2969 | critic=5.0448 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2154.2 | checkpoint=-
# [train] step=1469/1500 | warm=0 | policy=32 | replay=57008 | world_total=11319.4478 | actor=-9.5859 | critic=4.2430 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2156.9 | checkpoint=-
# [train] step=1470/1500 | warm=0 | policy=32 | replay=57040 | world_total=11319.4174 | actor=-8.2422 | critic=4.3720 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2159.7 | checkpoint=-
# [train] step=1471/1500 | warm=0 | policy=32 | replay=57072 | world_total=11319.6003 | actor=-7.7734 | critic=4.2573 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2162.8 | checkpoint=-
# [train] step=1472/1500 | warm=0 | policy=32 | replay=57104 | world_total=11319.5774 | actor=-8.3477 | critic=3.4635 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2165.8 | checkpoint=-
# [train] step=1473/1500 | warm=0 | policy=32 | replay=57136 | world_total=11319.4039 | actor=-7.5664 | critic=3.0235 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2169.0 | checkpoint=-
# [train] step=1474/1500 | warm=0 | policy=32 | replay=57168 | world_total=11319.4174 | actor=-7.6250 | critic=2.9251 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=2171.8 | checkpoint=-
# [train] step=1475/1500 | warm=0 | policy=32 | replay=57200 | world_total=11319.4537 | actor=-7.7305 | critic=2.9260 | eval_reward=5.6502 | cycle_s=17.3 | elapsed_s=2189.1 | checkpoint=checkpoint_01475.pt
# [train] step=1476/1500 | warm=0 | policy=32 | replay=57232 | world_total=11319.4099 | actor=-7.4102 | critic=2.7242 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2191.8 | checkpoint=-
# [train] step=1477/1500 | warm=0 | policy=32 | replay=57264 | world_total=11319.4733 | actor=-7.3711 | critic=2.7201 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=2194.5 | checkpoint=-
# [train] step=1478/1500 | warm=0 | policy=32 | replay=57296 | world_total=11319.3940 | actor=-7.3828 | critic=2.7800 | eval_reward=n/a | cycle_s=5.0 | elapsed_s=2199.5 | checkpoint=-
# [train] step=1479/1500 | warm=0 | policy=32 | replay=57328 | world_total=11319.3933 | actor=-6.8555 | critic=2.5544 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2202.4 | checkpoint=-
# [train] step=1480/1500 | warm=0 | policy=32 | replay=57360 | world_total=11319.4131 | actor=-7.7305 | critic=3.1587 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2205.7 | checkpoint=-
# [train] step=1481/1500 | warm=0 | policy=32 | replay=57392 | world_total=11319.3485 | actor=-7.0703 | critic=3.1006 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2208.6 | checkpoint=-
# [train] step=1482/1500 | warm=0 | policy=32 | replay=57424 | world_total=11319.3678 | actor=-5.9727 | critic=2.5418 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2211.5 | checkpoint=-
# [train] step=1483/1500 | warm=0 | policy=32 | replay=57456 | world_total=11319.5590 | actor=-7.0195 | critic=3.3777 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2214.5 | checkpoint=-
# [train] step=1484/1500 | warm=0 | policy=32 | replay=57488 | world_total=11319.4794 | actor=-7.2266 | critic=3.2516 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=2217.6 | checkpoint=-
# [train] step=1485/1500 | warm=0 | policy=32 | replay=57520 | world_total=11319.4457 | actor=-6.9258 | critic=2.8222 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=2220.7 | checkpoint=-
# [train] step=1486/1500 | warm=0 | policy=32 | replay=57552 | world_total=11319.3467 | actor=-7.1289 | critic=2.7174 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=2223.8 | checkpoint=-
# [train] step=1487/1500 | warm=0 | policy=32 | replay=57584 | world_total=11319.4724 | actor=-6.6797 | critic=2.7500 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2226.8 | checkpoint=-
# [train] step=1488/1500 | warm=0 | policy=32 | replay=57616 | world_total=11319.3805 | actor=-6.5625 | critic=2.4360 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2230.1 | checkpoint=-
# [train] step=1489/1500 | warm=0 | policy=32 | replay=57648 | world_total=11319.4556 | actor=-6.2227 | critic=2.6436 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2233.0 | checkpoint=-
# [train] step=1490/1500 | warm=0 | policy=32 | replay=57680 | world_total=11319.4183 | actor=-5.9609 | critic=2.3927 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=2236.1 | checkpoint=-
# [train] step=1491/1500 | warm=0 | policy=32 | replay=57712 | world_total=11319.5344 | actor=-6.4180 | critic=2.5422 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2239.1 | checkpoint=-
# [train] step=1492/1500 | warm=0 | policy=32 | replay=57744 | world_total=11319.6654 | actor=-6.2109 | critic=2.4898 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2241.8 | checkpoint=-
# [train] step=1493/1500 | warm=0 | policy=32 | replay=57776 | world_total=11319.6583 | actor=-7.4258 | critic=3.3943 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=2245.1 | checkpoint=-
# [train] step=1494/1500 | warm=0 | policy=32 | replay=57808 | world_total=11319.4775 | actor=-8.3984 | critic=3.4315 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2247.8 | checkpoint=-
# [train] step=1495/1500 | warm=0 | policy=32 | replay=57840 | world_total=11319.5099 | actor=-7.9336 | critic=3.2803 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2251.0 | checkpoint=-
# [train] step=1496/1500 | warm=0 | policy=32 | replay=57872 | world_total=11319.4542 | actor=-6.2148 | critic=2.6348 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=2253.7 | checkpoint=-
# [train] step=1497/1500 | warm=0 | policy=32 | replay=57904 | world_total=11319.5682 | actor=-7.4492 | critic=4.6487 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=2256.7 | checkpoint=-
# [train] step=1498/1500 | warm=0 | policy=32 | replay=57936 | world_total=11319.4797 | actor=-9.5312 | critic=4.3360 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=2259.9 | checkpoint=-
# [train] step=1499/1500 | warm=0 | policy=32 | replay=57968 | world_total=11319.4247 | actor=-7.8750 | critic=5.2060 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=2262.8 | checkpoint=-
# [train] step=1500/1500 | warm=0 | policy=32 | replay=58000 | world_total=11319.4597 | actor=-6.8047 | critic=3.2811 | eval_reward=9.9754 | cycle_s=17.0 | elapsed_s=2279.8 | checkpoint=checkpoint_01500.pt
# Completed cycles: 2000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter10_steering_penalty/checkpoints/checkpoint_01500.pt
# Latest metrics: {'step': 1500, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 58000, 'world_model/reconstruction_loss': 11312.101928710938, 'world_model/reconstruction_mse': 0.0032853392185643315, 'world_model/observation_log_prob': -11312.101928710938, 'world_model/reward_loss': 1.2696038037538528, 'world_model/continue_loss': 0.014270211569964886, 'world_model/kl_loss': 3.684805393218994, 'world_model/kl_loss_raw': 3.684805393218994, 'world_model/overshooting_kl_loss': 4.779025852680206, 'world_model/overshooting_feature_mse': 0.8650285750627518, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 11319.459716796875, 'behavior/actor_loss': -6.8046875, 'behavior/critic_loss': 3.281108111143112, 'behavior/imagined_reward_mean': 0.97314453125, 'behavior/imagined_value_mean': 3.869140625, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 9.975367123446231, 'evaluation/mean_steps': 16.6, 'evaluation/crash_rate': 1.0}

# %%
summary_path = training_summary.log_dir / 'latest_summary.json'
summary_payload = json.loads(summary_path.read_text(encoding='utf-8'))
summary_payload
# Out:
# {'checkpoint_file': '/content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/iter10_steering_penalty/checkpoints/checkpoint_01500.pt',
#  'latest_metrics': {'behavior/actor_loss': -6.8046875,
#   'behavior/critic_loss': 3.281108111143112,
#   'behavior/imagined_reward_mean': 0.97314453125,
#   'behavior/imagined_value_mean': 3.869140625,
#   'evaluation/crash_rate': 1.0,
#   'evaluation/episodes': 10.0,
#   'evaluation/mean_reward': 9.975367123446231,
#   'evaluation/mean_steps': 16.6,
#   'policy_added': 32,
#   'replay_size': 58000,
#   'step': 1500,
#   'warm_start_added': 0,
#   'world_model/continue_loss': 0.014270211569964886,
#   'world_model/kl_loss': 3.684805393218994,
#   'world_model/kl_loss_raw': 3.684805393218994,
#   'world_model/observation_log_prob': -11312.101928710938,
#   'world_model/overshooting_feature_mse': 0.8650285750627518,
#   'world_model/overshooting_kl_loss': 4.779025852680206,
#   'world_model/overshooting_pairs': 65.0,
#   'world_model/reconstruction_loss': 11312.101928710938,
#   'world_model/reconstruction_mse': 0.0032853392185643315,
#   'world_model/reward_loss': 1.2696038037538528,
#   'world_model/total_loss': 11319.459716796875},
#  'latest_step': 1500}

# %%
from IPython.display import Image, display
import csv
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as training_analysis

training_analysis = importlib.reload(training_analysis)
export_training_history_artifacts = training_analysis.export_training_history_artifacts

analysis_outputs = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

display(Image(filename=str(analysis_outputs['curves'])))
analysis_summary = json.loads(analysis_outputs['summary'].read_text(encoding='utf-8'))
with (training_summary.log_dir / 'cycle_metrics.csv').open('r', encoding='utf-8', newline='') as handle:
    metric_rows = list(csv.DictReader(handle))
latest_metrics_row = metric_rows[-1]
{
    'analysis_summary': analysis_summary,
    'phase4_metrics': {
        'world_model/reconstruction_loss': latest_metrics_row.get('world_model/reconstruction_loss'),
        'world_model/reconstruction_mse': latest_metrics_row.get('world_model/reconstruction_mse'),
        'world_model/observation_log_prob': latest_metrics_row.get('world_model/observation_log_prob'),
        'world_model/overshooting_kl_loss': latest_metrics_row.get('world_model/overshooting_kl_loss'),
        'world_model/overshooting_feature_mse': latest_metrics_row.get('world_model/overshooting_feature_mse'),
        'evaluation/mean_reward': latest_metrics_row.get('evaluation/mean_reward'),
        'evaluation/crash_rate': latest_metrics_row.get('evaluation/crash_rate'),
    },
}
# Out:
# {'analysis_summary': {'best_eval_mean_reward': 27.80786567256889,
#   'best_eval_reward_step': 600,
#   'best_imagined_reward_mean': 1.1552734375,
#   'best_imagined_reward_step': 1468,
#   'best_world_model_step': 1486,
#   'best_world_model_total_loss': 11319.3466796875,
#   'largest_replay_size': 58000,
#   'largest_replay_step': 1500,
#   'last_metrics': {'behavior/actor_loss': -6.8046875,
#    'behavior/critic_loss': 3.281108111143112,
#    'behavior/imagined_reward_mean': 0.97314453125,
#    'behavior/imagined_value_mean': 3.869140625,
#    'evaluation/crash_rate': 1.0,
#    'evaluation/episodes': 10.0,
#    'evaluation/mean_reward': 9.975367123446231,
#    'evaluation/mean_steps': 16.6,
#    'policy_added': 32,
#    'replay_size': 58000,
#    'step': 1500,
#    'warm_start_added': 0,
#    'world_model/continue_loss': 0.014270211569964886,
#    'world_model/kl_loss': 3.684805393218994,
#    'world_model/kl_loss_raw': 3.684805393218994,
#    'world_model/observation_log_prob': -11312.101928710938,
#    'world_model/overshooting_feature_mse': 0.8650285750627518,
#    'world_model/overshooting_kl_loss': 4.779025852680206,
#    'world_model/overshooting_pairs': 65.0,
#    'world_model/reconstruction_loss': 11312.101928710938,
#    'world_model/reconstruction_mse': 0.0032853392185643315,
#    'world_model/reward_loss': 1.2696038037538528,
#    'world_model/total_loss': 11319.459716796875},
#   'last_step': 1500,
#   'num_records': 1500},
#  'phase4_metrics': {'world_model/reconstruction_loss': '11312.101928710938',
#   'world_model/reconstruction_mse': '0.0032853392185643315',
#   'world_model/observation_log_prob': '-11312.101928710938',
#   'world_model/overshooting_kl_loss': '4.779025852680206',
#   'world_model/overshooting_feature_mse': '0.8650285750627518',
#   'evaluation/mean_reward': '9.975367123446231',
#   'evaluation/crash_rate': '1.0'}}

# %% [markdown]
# ## Agent Driving Demo
#
# Record agent-driving GIFs using the trained policy from this run. These show the actor driving in the real highway-env.

# %%
from IPython.display import Image, display
import importlib
import tiny_dreamer_highway.evaluation as evaluation_pkg

try:
    evaluation_pkg = importlib.reload(evaluation_pkg)
    record_demo_videos = evaluation_pkg.record_demo_videos
except (AttributeError, ImportError):
    from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos

print('Using demo recorder from:', record_demo_videos.__module__)

demo_outputs = record_demo_videos(
    config,
    checkpoint_path=training_summary.latest_checkpoint,
    output_dir=RUN_ARTIFACT_ROOT / 'demo_videos',
    num_episodes=10,
    max_steps=1000,
    fps=15,
    seed=config.seed,
    prefix=RUN_NAME,
    device=config.device,
)

for gif_path in demo_outputs.video_paths:
    print(f'\n{gif_path.name}')
    display(Image(filename=str(gif_path)))
# Out:
# Using demo recorder from: tiny_dreamer_highway.evaluation.policy_rollout
# [demo] episode 1/10 | steps=8 | reward=0.16 | CRASH | saved iter10_steering_penalty_ep01.gif
# [demo] episode 2/10 | steps=20 | reward=13.54 | CRASH | saved iter10_steering_penalty_ep02.gif
# [demo] episode 3/10 | steps=27 | reward=22.68 | CRASH | saved iter10_steering_penalty_ep03.gif
# [demo] episode 4/10 | steps=28 | reward=22.28 | CRASH | saved iter10_steering_penalty_ep04.gif
# [demo] episode 5/10 | steps=7 | reward=-0.65 | CRASH | saved iter10_steering_penalty_ep05.gif
# [demo] episode 6/10 | steps=22 | reward=16.68 | CRASH | saved iter10_steering_penalty_ep06.gif
# [demo] episode 7/10 | steps=12 | reward=3.48 | CRASH | saved iter10_steering_penalty_ep07.gif
# [demo] episode 8/10 | steps=29 | reward=23.07 | CRASH | saved iter10_steering_penalty_ep08.gif
# [demo] episode 9/10 | steps=13 | reward=4.62 | CRASH | saved iter10_steering_penalty_ep09.gif
# [demo] episode 10/10 | steps=6 | reward=-0.80 | CRASH | saved iter10_steering_penalty_ep10.gif
# [demo] done | avg_reward=10.50 | summary=iter10_steering_penalty_summary.json
#
# iter10_steering_penalty_ep01.gif
# iter10_steering_penalty_ep02.gif
# iter10_steering_penalty_ep03.gif
# iter10_steering_penalty_ep04.gif
# iter10_steering_penalty_ep05.gif
# iter10_steering_penalty_ep06.gif
# iter10_steering_penalty_ep07.gif
# iter10_steering_penalty_ep08.gif
# iter10_steering_penalty_ep09.gif
# iter10_steering_penalty_ep10.gif
