# %% [markdown]
# # Tiny Dreamer Highway — Final Run
#
# **Name:** Esteban Montelongo | **Course:** CSC 580 AI 2 | **Assignment:** Final Project — Dream the Road | **AI tools:** GitHub Copilot
#
# ---
#
# This notebook trains and evaluates a **DreamerV1** continuous-control agent on `highway-v0`.
#
# DreamerV1 separates world-model learning from policy learning: the RSSM (Recurrent State-Space Model) learns a compressed latent representation of the environment from pixel observations, then the actor-critic is trained entirely inside imagined latent rollouts — never touching the real environment during policy updates. See the project report for full algorithm derivations.
#
# ## Experiment Design
#
# | Phase | Environment | Config | Purpose |
# |-------|-------------|--------|---------|
# | **A — training** | 4 lanes, 28 cars | `final_run.yaml` | Learn a speed-maximising continuous-control policy |
# | **B — showcase** | 6 lanes, 45 cars | `final_showcase_eval.yaml` | Evaluate trained weights in denser, wider traffic |
#
# **Sections:** Setup → Config → Training → Training curves → N-step prediction eval → Driving demos → Submission bundle

# %% [markdown]
# ## 1 · Environment Setup
#
# Mount Drive for artifact persistence (Colab VMs are ephemeral — everything under `/content/` is lost on disconnect), then clone/update the repo and install the package in editable mode so imports resolve from source.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')
REPO_URL = 'https://github.com/estmon8u/CSC_580_Final_Project.git'
DRIVE_ROOT = Path('/content/drive/MyDrive/CSC_580_Final_Project')
ARTIFACT_ROOT = DRIVE_ROOT / 'artifacts'

for path in [DRIVE_ROOT, ARTIFACT_ROOT, ARTIFACT_ROOT / 'training_runs']:
    path.mkdir(parents=True, exist_ok=True)

print('Drive root:', DRIVE_ROOT)
print('Artifact root:', ARTIFACT_ROOT)
# Out:
# Mounted at /content/drive
# Drive root: /content/drive/MyDrive/CSC_580_Final_Project
# Artifact root: /content/drive/MyDrive/CSC_580_Final_Project/artifacts

# %%
# %%bash
# set -e
# REPO_URL='https://github.com/estmon8u/CSC_580_Final_Project.git'
# BRANCH='GrandpaDrivers'
# if [ ! -d /content/CSC_580_Final_Project/.git ]; then
#   git clone -b "${BRANCH}" "${REPO_URL}" /content/CSC_580_Final_Project
# else
#   cd /content/CSC_580_Final_Project
#   git fetch origin "${BRANCH}"
#   git checkout "${BRANCH}"
#   git pull --ff-only origin "${BRANCH}"
# fi
# cd /content/CSC_580_Final_Project
# python -m pip install --upgrade pip --quiet
# python -m pip install -e . --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.3 MB/s eta 0:00:00
# Cloning into '/content/CSC_580_Final_Project'...

# %% [markdown]
# ## 2 · Experiment Configuration
#
# Key choices in `final_run.yaml` and their rationale:
#
# | Setting | Value | Why |
# |---------|-------|-----|
# | `lanes_count` | 4 | Project requirement (minimum 4) |
# | `vehicles_count` | 28 | Moderately hard — enough traffic to require overtaking without overwhelming random resets during warm-start |
# | `high_speed_reward` | 0.7 | Strong speed signal — raised from 0.5 so the agent actively overtakes rather than trailing slower traffic |
# | `right_lane_reward` | 0.0 | Zero — any positive value creates a degenerate "lane-hugger" policy that ignores speed |
# | `reward_speed_range` | [20, 35] | Higher upper bound keeps the reward gradient active at faster cruising speeds |
# | `steering_penalty` | 0.0075 | Slightly lower than baseline, but not so low that lane changes become twitchy |
# | `steering_change_penalty` | 0.02 | Reduced more conservatively to allow overtaking without inviting oscillation |
# | `max_episode_steps` | 75 | Extended from 50 — gives the agent more runway to build speed after a lane change |
# | `imagination_horizon` | 20 | Long enough for multi-step lane-change credit assignment; beyond ~25 steps RSSM drift degrades λ-return estimates |
# | `free_nats` | 3.0 | Prevents posterior collapse early in training by ignoring KL below this threshold |
# | `use_amp` / `bfloat16` | true | H100 tensor-core throughput; bfloat16 preserves fp32 exponent range, safe for KL spikes |
# | `batch_size` / updates | 256 / 16 | Large batches keep world-model and behavior updates stable on H100 hardware |

# %%
import json
import sys
import torch
from pathlib import Path

PROJECT_ROOT = Path('/content/CSC_580_Final_Project')
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tiny_dreamer_highway.config import load_experiment_config
from tiny_dreamer_highway.training import run_training_experiment

# Phase-A training config — tuned for aggressive, fast continuous control
CONFIG_PATH = PROJECT_ROOT / 'examples' / 'final_run.yaml'
config = load_experiment_config(CONFIG_PATH)

gpu_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'
print('Loaded config from:', CONFIG_PATH)
print('GPU:', gpu_name)
if 'H100' not in gpu_name:
    print('Note: config is optimised for H100 but will run on any CUDA device.')

print('\n--- Environment ---')
print('Action type:', config.env.action.type)
print('Lanes count:', config.env.lanes_count)
print('Vehicles count:', config.env.vehicles_count)
print('Max episode steps:', config.env.max_episode_steps)

print('\n--- Reward shaping ---')
print('high_speed_reward:', config.env.reward.high_speed_reward)
print('right_lane_reward:', config.env.reward.right_lane_reward)
print('reward_speed_range:', config.env.reward.reward_speed_range)
print('offroad_terminal:', config.env.reward.offroad_terminal)

print('\n--- Training knobs ---')
print('grad_clip_norm:', config.training.grad_clip_norm)
print('lr_warmup_steps:', config.training.lr_warmup_steps)
print('use_amp:', config.training.use_amp, f'({config.training.amp_dtype})')
print('batch_size:', config.training.batch_size)
print('world_model_updates_per_cycle:', config.training.world_model_updates_per_cycle)
print('behavior_updates_per_cycle:', config.training.behavior_updates_per_cycle)
# Out:
# Loaded config from: /content/CSC_580_Final_Project/examples/final_run.yaml
# GPU: NVIDIA H100 80GB HBM3
#
# --- Environment ---
# Action type: continuous
# Lanes count: 4
# Vehicles count: 28
# Max episode steps: 75
#
# --- Reward shaping ---
# high_speed_reward: 0.7
# right_lane_reward: 0.0
# reward_speed_range: (20.0, 35.0)
# offroad_terminal: True
#
# --- Training knobs ---
# grad_clip_norm: 100.0
# lr_warmup_steps: 0
# use_amp: False (bfloat16)
# use_flash_optimizer: False
# batch_size: 256
# world_model_updates_per_cycle: 8
# behavior_updates_per_cycle: 8
#
# FlashAdamW: not installed — will fall back to AdamW

# %% [markdown]
# ## 3 · Training
#
# `run_training_experiment` drives the outer loop. Each *cycle* runs:
# 1. **World model update** (`world_model_updates_per_cycle` gradient steps) — sample sequences from the replay buffer, compute the ELBO (reconstruction + KL + reward + continue losses), update encoder/RSSM/decoder weights.
# 2. **Behavior update** (`behavior_updates_per_cycle` gradient steps) — imagine `imagination_horizon` steps via the RSSM prior, build λ-return targets, update actor and critic.
# 3. **Environment collection** (`policy_steps` real env steps) — run the trained actor, add new transitions to the replay buffer.
#
# `warm_start_steps` pre-fills the replay buffer with random transitions before any gradient updates begin. `RESUME_FROM = None` starts fresh; set it to a checkpoint path to continue an interrupted run.

# %%
RUN_NAME = 'final_run_001'
RUN_ARTIFACT_ROOT = ARTIFACT_ROOT / 'training_runs' / RUN_NAME
RUN_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

# Use None to take values from the YAML; override to shorten without editing config.
CYCLES              = None   # None → YAML default (2000)
WARM_START_STEPS    = None   # None → YAML default (10000)
POLICY_STEPS        = None   # None → YAML default (64)
CHECKPOINT_INTERVAL = None   # None → YAML default (25)

# Always start fresh for the first post-fix run — checkpoints now store richer
# replay and scheduler state that must be rebuilt from scratch.
RESUME_FROM = None

print('Run name:', RUN_NAME)
print('Artifact root:', RUN_ARTIFACT_ROOT)
print('Effective cycles:', config.training.cycles if CYCLES is None else CYCLES)
print('Effective warm-start steps:',
      config.training.warm_start_steps if WARM_START_STEPS is None else WARM_START_STEPS)
print('Sequence length:', config.replay.sequence_length)
print('Replay capacity:', config.replay.capacity)
# Out:
# Run name: final_run_001
# Artifact root: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001
# Effective cycles: 2000
# Effective warm-start steps: 10000
# Sequence length: 16
# Replay capacity: 500000

# %% [markdown]
# ### Launch
#
# Override any YAML default by setting the variable to a non-`None` value. The training loop prints one line per cycle with current losses and evaluation reward. Full derivations of the ELBO objective, λ-returns, and overshooting regularisation are in the project report.

# %%
print('Launching Phase-A final continuous-control run.')
print('Environment: 4 lanes, 28 cars — reward-tuned for speed and overtaking.')
print('Per-cycle progress lines will appear below.\n')

training_summary = run_training_experiment(
    config,
    RUN_ARTIFACT_ROOT,
    cycles=CYCLES,
    warm_start_steps=WARM_START_STEPS,
    policy_steps=POLICY_STEPS,
    checkpoint_interval=CHECKPOINT_INTERVAL,
    resume_from=RESUME_FROM,
)

print('\nCompleted cycles:', training_summary.completed_cycles)
print('Latest checkpoint:', training_summary.latest_checkpoint)
print('Latest metrics:', training_summary.latest_record)
# Out:
# Launching Phase-A final continuous-control run.
# Environment: 4 lanes, 28 cars — reward-tuned for speed and overtaking.
# Per-cycle progress lines will appear below.
#
# [train] starting run | cycles=2000 | start_step=1 | warm_start_steps=10000 | policy_steps=32 | device=cuda
# [train] step=1/2000 | warm=10000 | policy=32 | replay=10032 | world_total=5309.2071 | actor=-1.7900 | critic=2.5817 | eval_reward=n/a | cycle_s=427.2 | elapsed_s=427.2 | checkpoint=-
# [train] step=2/2000 | warm=0 | policy=32 | replay=10064 | world_total=4004.1328 | actor=-5.2804 | critic=10.9973 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=430.5 | checkpoint=-
# [train] step=3/2000 | warm=0 | policy=32 | replay=10096 | world_total=3914.0120 | actor=-6.2777 | critic=11.8413 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=434.1 | checkpoint=-
# [train] step=4/2000 | warm=0 | policy=32 | replay=10128 | world_total=3872.5775 | actor=-8.9632 | critic=21.5419 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=437.4 | checkpoint=-
# [train] step=5/2000 | warm=0 | policy=32 | replay=10160 | world_total=3846.0184 | actor=-10.6909 | critic=16.8400 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=441.2 | checkpoint=-
# [train] step=6/2000 | warm=0 | policy=32 | replay=10192 | world_total=3832.5598 | actor=-14.2799 | critic=21.0640 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=444.5 | checkpoint=-
# [train] step=7/2000 | warm=0 | policy=32 | replay=10224 | world_total=3827.6462 | actor=-16.0876 | critic=17.1566 | eval_reward=n/a | cycle_s=3.4 | elapsed_s=447.9 | checkpoint=-
# [train] step=8/2000 | warm=0 | policy=32 | replay=10256 | world_total=3826.6358 | actor=-13.8075 | critic=2.4701 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=451.4 | checkpoint=-
# [train] step=9/2000 | warm=0 | policy=32 | replay=10288 | world_total=3824.5528 | actor=-16.6013 | critic=4.2084 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=455.0 | checkpoint=-
# [train] step=10/2000 | warm=0 | policy=32 | replay=10320 | world_total=3824.2893 | actor=-17.7042 | critic=3.3282 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=459.0 | checkpoint=-
# [train] step=11/2000 | warm=0 | policy=32 | replay=10352 | world_total=3824.7840 | actor=-18.8390 | critic=5.5406 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=463.1 | checkpoint=-
# [train] step=12/2000 | warm=0 | policy=32 | replay=10384 | world_total=3822.8174 | actor=-22.7393 | critic=7.7721 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=467.0 | checkpoint=-
# [train] step=13/2000 | warm=0 | policy=32 | replay=10416 | world_total=3821.9333 | actor=-25.4595 | critic=6.4784 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=471.0 | checkpoint=-
# [train] step=14/2000 | warm=0 | policy=32 | replay=10448 | world_total=3820.8000 | actor=-29.4386 | critic=5.6932 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=475.2 | checkpoint=-
# [train] step=15/2000 | warm=0 | policy=32 | replay=10480 | world_total=3820.3866 | actor=-29.9650 | critic=3.0460 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=479.0 | checkpoint=-
# [train] step=16/2000 | warm=0 | policy=32 | replay=10512 | world_total=3819.4973 | actor=-33.7127 | critic=3.3872 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=483.0 | checkpoint=-
# [train] step=17/2000 | warm=0 | policy=32 | replay=10544 | world_total=3818.4324 | actor=-34.8945 | critic=3.2176 | eval_reward=n/a | cycle_s=3.7 | elapsed_s=486.7 | checkpoint=-
# [train] step=18/2000 | warm=0 | policy=32 | replay=10576 | world_total=3817.1519 | actor=-36.8580 | critic=3.0436 | eval_reward=n/a | cycle_s=3.8 | elapsed_s=490.5 | checkpoint=-
# [train] step=19/2000 | warm=0 | policy=32 | replay=10608 | world_total=3815.7502 | actor=-36.0668 | critic=4.2871 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=494.7 | checkpoint=-
# [train] step=20/2000 | warm=0 | policy=32 | replay=10640 | world_total=3814.1380 | actor=-36.5797 | critic=3.0995 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=498.8 | checkpoint=-
# [train] step=21/2000 | warm=0 | policy=32 | replay=10672 | world_total=3812.8045 | actor=-34.0933 | critic=2.9375 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=502.8 | checkpoint=-
# [train] step=22/2000 | warm=0 | policy=32 | replay=10704 | world_total=3811.2757 | actor=-32.9284 | critic=2.4401 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=506.8 | checkpoint=-
# [train] step=23/2000 | warm=0 | policy=32 | replay=10736 | world_total=3809.2344 | actor=-31.4104 | critic=2.5632 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=510.9 | checkpoint=-
# [train] step=24/2000 | warm=0 | policy=32 | replay=10768 | world_total=3807.0908 | actor=-31.1031 | critic=2.4632 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=514.9 | checkpoint=-
# [train] step=25/2000 | warm=0 | policy=32 | replay=10800 | world_total=3804.8241 | actor=-30.2287 | critic=2.5327 | eval_reward=1.8153 | cycle_s=8.0 | elapsed_s=522.8 | checkpoint=checkpoint_00025.pt
# [train] step=26/2000 | warm=0 | policy=32 | replay=10832 | world_total=3802.4054 | actor=-29.5349 | critic=2.9088 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=527.1 | checkpoint=-
# [train] step=27/2000 | warm=0 | policy=32 | replay=10864 | world_total=3800.2764 | actor=-29.4968 | critic=2.8406 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=531.0 | checkpoint=-
# [train] step=28/2000 | warm=0 | policy=32 | replay=10896 | world_total=3798.4025 | actor=-28.3172 | critic=3.6478 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=535.0 | checkpoint=-
# [train] step=29/2000 | warm=0 | policy=32 | replay=10928 | world_total=3796.9363 | actor=-28.5712 | critic=3.1130 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=539.0 | checkpoint=-
# [train] step=30/2000 | warm=0 | policy=32 | replay=10960 | world_total=3795.5745 | actor=-27.6340 | critic=3.8561 | eval_reward=n/a | cycle_s=3.9 | elapsed_s=542.8 | checkpoint=-
# [train] step=31/2000 | warm=0 | policy=32 | replay=10992 | world_total=3794.4492 | actor=-25.1065 | critic=7.1578 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=547.1 | checkpoint=-
# [train] step=32/2000 | warm=0 | policy=32 | replay=11024 | world_total=3793.6204 | actor=-25.1701 | critic=3.7165 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=551.3 | checkpoint=-
# [train] step=33/2000 | warm=0 | policy=32 | replay=11056 | world_total=3792.6667 | actor=-22.6244 | critic=4.9400 | eval_reward=n/a | cycle_s=4.1 | elapsed_s=555.4 | checkpoint=-
# [train] step=34/2000 | warm=0 | policy=32 | replay=11088 | world_total=3791.8423 | actor=-22.3350 | critic=4.0730 | eval_reward=n/a | cycle_s=4.3 | elapsed_s=559.7 | checkpoint=-
# [train] step=35/2000 | warm=0 | policy=32 | replay=11120 | world_total=3791.1879 | actor=-20.8403 | critic=4.8380 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=563.8 | checkpoint=-
# [train] step=36/2000 | warm=0 | policy=32 | replay=11152 | world_total=3790.5761 | actor=-19.5673 | critic=4.2943 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=568.0 | checkpoint=-
# [train] step=37/2000 | warm=0 | policy=32 | replay=11184 | world_total=3789.9547 | actor=-16.7351 | critic=6.1421 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=572.2 | checkpoint=-
# [train] step=38/2000 | warm=0 | policy=32 | replay=11216 | world_total=3789.5292 | actor=-13.7921 | critic=5.5163 | eval_reward=n/a | cycle_s=4.4 | elapsed_s=576.6 | checkpoint=-
# [train] step=39/2000 | warm=0 | policy=32 | replay=11248 | world_total=3789.2121 | actor=-10.1778 | critic=5.5280 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=580.7 | checkpoint=-
# [train] step=40/2000 | warm=0 | policy=32 | replay=11280 | world_total=3788.7971 | actor=-8.4571 | critic=3.8750 | eval_reward=n/a | cycle_s=4.0 | elapsed_s=584.7 | checkpoint=-
# [train] step=41/2000 | warm=0 | policy=32 | replay=11312 | world_total=3788.2704 | actor=-8.2216 | critic=4.4441 | eval_reward=n/a | cycle_s=3.5 | elapsed_s=588.2 | checkpoint=-
# [train] step=42/2000 | warm=0 | policy=32 | replay=11344 | world_total=3787.8645 | actor=-11.2985 | critic=5.8995 | eval_reward=n/a | cycle_s=3.6 | elapsed_s=591.8 | checkpoint=-
# [train] step=43/2000 | warm=0 | policy=32 | replay=11376 | world_total=3787.3611 | actor=-12.4639 | critic=6.3461 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=595.1 | checkpoint=-
# [train] step=44/2000 | warm=0 | policy=32 | replay=11408 | world_total=3787.0373 | actor=-12.7335 | critic=5.7488 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=598.4 | checkpoint=-
# [train] step=45/2000 | warm=0 | policy=32 | replay=11440 | world_total=3786.8642 | actor=-13.0138 | critic=5.4263 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=601.8 | checkpoint=-
# [train] step=46/2000 | warm=0 | policy=32 | replay=11472 | world_total=3786.4200 | actor=-13.8109 | critic=5.5148 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=604.8 | checkpoint=-
# [train] step=47/2000 | warm=0 | policy=32 | replay=11504 | world_total=3786.1619 | actor=-14.4226 | critic=5.2157 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=607.7 | checkpoint=-
# [train] step=48/2000 | warm=0 | policy=32 | replay=11536 | world_total=3785.8098 | actor=-16.6644 | critic=5.2206 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=610.7 | checkpoint=-
# [train] step=49/2000 | warm=0 | policy=32 | replay=11568 | world_total=3785.5393 | actor=-18.6264 | critic=4.6612 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=613.6 | checkpoint=-
# [train] step=50/2000 | warm=0 | policy=32 | replay=11600 | world_total=3785.4128 | actor=-21.3284 | critic=4.3224 | eval_reward=42.1541 | cycle_s=18.5 | elapsed_s=632.0 | checkpoint=checkpoint_00050.pt
# [train] step=51/2000 | warm=0 | policy=32 | replay=11632 | world_total=3784.9794 | actor=-24.1885 | critic=3.9143 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=634.7 | checkpoint=-
# [train] step=52/2000 | warm=0 | policy=32 | replay=11664 | world_total=3784.7595 | actor=-26.9984 | critic=3.6717 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=637.3 | checkpoint=-
# [train] step=53/2000 | warm=0 | policy=32 | replay=11696 | world_total=3784.5176 | actor=-28.8094 | critic=3.2968 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=640.3 | checkpoint=-
# [train] step=54/2000 | warm=0 | policy=32 | replay=11728 | world_total=3784.2101 | actor=-32.2471 | critic=3.0363 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=643.1 | checkpoint=-
# [train] step=55/2000 | warm=0 | policy=32 | replay=11760 | world_total=3783.9962 | actor=-35.8231 | critic=3.0205 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=645.8 | checkpoint=-
# [train] step=56/2000 | warm=0 | policy=32 | replay=11792 | world_total=3783.8060 | actor=-38.3883 | critic=2.7693 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=648.5 | checkpoint=-
# [train] step=57/2000 | warm=0 | policy=32 | replay=11824 | world_total=3783.4521 | actor=-40.9654 | critic=2.4492 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=651.2 | checkpoint=-
# [train] step=58/2000 | warm=0 | policy=32 | replay=11856 | world_total=3783.2224 | actor=-43.5838 | critic=2.2792 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=653.9 | checkpoint=-
# [train] step=59/2000 | warm=0 | policy=32 | replay=11888 | world_total=3783.0761 | actor=-46.0791 | critic=2.4000 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=656.6 | checkpoint=-
# [train] step=60/2000 | warm=0 | policy=32 | replay=11920 | world_total=3782.8509 | actor=-46.2434 | critic=2.9948 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=659.3 | checkpoint=-
# [train] step=61/2000 | warm=0 | policy=32 | replay=11952 | world_total=3782.6820 | actor=-47.6224 | critic=2.3597 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=661.9 | checkpoint=-
# [train] step=62/2000 | warm=0 | policy=32 | replay=11984 | world_total=3782.4135 | actor=-48.5629 | critic=2.4657 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=664.7 | checkpoint=-
# [train] step=63/2000 | warm=0 | policy=32 | replay=12016 | world_total=3782.1302 | actor=-49.7398 | critic=2.4248 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=667.3 | checkpoint=-
# [train] step=64/2000 | warm=0 | policy=32 | replay=12048 | world_total=3782.0132 | actor=-50.5436 | critic=2.3489 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=670.0 | checkpoint=-
# [train] step=65/2000 | warm=0 | policy=32 | replay=12080 | world_total=3781.8799 | actor=-50.9640 | critic=2.2951 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=672.7 | checkpoint=-
# [train] step=66/2000 | warm=0 | policy=32 | replay=12112 | world_total=3781.6905 | actor=-50.5948 | critic=2.4275 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=675.4 | checkpoint=-
# [train] step=67/2000 | warm=0 | policy=32 | replay=12144 | world_total=3781.6317 | actor=-50.0506 | critic=2.1312 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=678.1 | checkpoint=-
# [train] step=68/2000 | warm=0 | policy=32 | replay=12176 | world_total=3781.3159 | actor=-49.9904 | critic=2.1563 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=680.7 | checkpoint=-
# [train] step=69/2000 | warm=0 | policy=32 | replay=12208 | world_total=3781.2250 | actor=-50.8667 | critic=2.1048 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=683.4 | checkpoint=-
# [train] step=70/2000 | warm=0 | policy=32 | replay=12240 | world_total=3781.1369 | actor=-50.5710 | critic=2.2130 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=686.1 | checkpoint=-
# [train] step=71/2000 | warm=0 | policy=32 | replay=12272 | world_total=3781.0983 | actor=-51.3495 | critic=2.1981 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=688.8 | checkpoint=-
# [train] step=72/2000 | warm=0 | policy=32 | replay=12304 | world_total=3780.8236 | actor=-51.8455 | critic=2.1769 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=691.5 | checkpoint=-
# [train] step=73/2000 | warm=0 | policy=32 | replay=12336 | world_total=3780.6326 | actor=-52.9918 | critic=2.1888 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=694.2 | checkpoint=-
# [train] step=74/2000 | warm=0 | policy=32 | replay=12368 | world_total=3780.5865 | actor=-53.8602 | critic=2.2208 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=696.9 | checkpoint=-
# [train] step=75/2000 | warm=0 | policy=32 | replay=12400 | world_total=3780.4050 | actor=-55.2391 | critic=2.1364 | eval_reward=44.7355 | cycle_s=19.8 | elapsed_s=716.7 | checkpoint=checkpoint_00075.pt
# [train] step=76/2000 | warm=0 | policy=32 | replay=12432 | world_total=3780.2578 | actor=-56.2095 | critic=2.1764 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=719.4 | checkpoint=-
# [train] step=77/2000 | warm=0 | policy=32 | replay=12464 | world_total=3780.3008 | actor=-55.5220 | critic=2.2474 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=722.0 | checkpoint=-
# [train] step=78/2000 | warm=0 | policy=32 | replay=12496 | world_total=3780.1278 | actor=-55.5336 | critic=2.1311 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=724.7 | checkpoint=-
# [train] step=79/2000 | warm=0 | policy=32 | replay=12528 | world_total=3779.9854 | actor=-54.8746 | critic=2.0510 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=727.5 | checkpoint=-
# [train] step=80/2000 | warm=0 | policy=32 | replay=12560 | world_total=3779.7916 | actor=-54.6320 | critic=2.1821 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=730.3 | checkpoint=-
# [train] step=81/2000 | warm=0 | policy=32 | replay=12592 | world_total=3779.7317 | actor=-55.3767 | critic=2.1042 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=733.1 | checkpoint=-
# [train] step=82/2000 | warm=0 | policy=32 | replay=12624 | world_total=3779.7096 | actor=-55.3049 | critic=2.0334 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=735.8 | checkpoint=-
# [train] step=83/2000 | warm=0 | policy=32 | replay=12656 | world_total=3779.4841 | actor=-55.6855 | critic=2.0286 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=738.4 | checkpoint=-
# [train] step=84/2000 | warm=0 | policy=32 | replay=12688 | world_total=3779.6212 | actor=-55.1560 | critic=1.9999 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=741.2 | checkpoint=-
# [train] step=85/2000 | warm=0 | policy=32 | replay=12720 | world_total=3779.3951 | actor=-55.6528 | critic=1.9893 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=743.9 | checkpoint=-
# [train] step=86/2000 | warm=0 | policy=32 | replay=12752 | world_total=3779.3560 | actor=-55.7871 | critic=1.9883 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=746.6 | checkpoint=-
# [train] step=87/2000 | warm=0 | policy=32 | replay=12784 | world_total=3779.1941 | actor=-55.7987 | critic=1.9689 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=749.3 | checkpoint=-
# [train] step=88/2000 | warm=0 | policy=32 | replay=12816 | world_total=3779.0899 | actor=-56.0826 | critic=1.9605 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=752.0 | checkpoint=-
# [train] step=89/2000 | warm=0 | policy=32 | replay=12848 | world_total=3779.0972 | actor=-55.9860 | critic=1.9536 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=754.8 | checkpoint=-
# [train] step=90/2000 | warm=0 | policy=32 | replay=12880 | world_total=3779.0790 | actor=-55.8066 | critic=1.9381 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=757.4 | checkpoint=-
# [train] step=91/2000 | warm=0 | policy=32 | replay=12912 | world_total=3779.0113 | actor=-55.1048 | critic=1.9252 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=760.1 | checkpoint=-
# [train] step=92/2000 | warm=0 | policy=32 | replay=12944 | world_total=3778.9662 | actor=-54.6649 | critic=1.8910 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=762.8 | checkpoint=-
# [train] step=93/2000 | warm=0 | policy=32 | replay=12976 | world_total=3778.7974 | actor=-55.2232 | critic=1.9358 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=765.6 | checkpoint=-
# [train] step=94/2000 | warm=0 | policy=32 | replay=13008 | world_total=3778.7909 | actor=-55.7710 | critic=1.8642 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=768.3 | checkpoint=-
# [train] step=95/2000 | warm=0 | policy=32 | replay=13040 | world_total=3778.6852 | actor=-56.3059 | critic=1.9029 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=771.0 | checkpoint=-
# [train] step=96/2000 | warm=0 | policy=32 | replay=13072 | world_total=3778.6995 | actor=-55.9683 | critic=1.9544 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=773.7 | checkpoint=-
# [train] step=97/2000 | warm=0 | policy=32 | replay=13104 | world_total=3778.6429 | actor=-55.6132 | critic=1.9033 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=776.5 | checkpoint=-
# [train] step=98/2000 | warm=0 | policy=32 | replay=13136 | world_total=3778.5325 | actor=-55.2476 | critic=1.9398 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=779.2 | checkpoint=-
# [train] step=99/2000 | warm=0 | policy=32 | replay=13168 | world_total=3778.3843 | actor=-55.4316 | critic=1.8316 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=781.9 | checkpoint=-
# [train] step=100/2000 | warm=0 | policy=32 | replay=13200 | world_total=3778.3681 | actor=-55.8833 | critic=2.0096 | eval_reward=45.1419 | cycle_s=19.9 | elapsed_s=801.8 | checkpoint=checkpoint_00100.pt
# [train] step=101/2000 | warm=0 | policy=32 | replay=13232 | world_total=3778.6253 | actor=-56.0558 | critic=1.8544 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=804.5 | checkpoint=-
# [train] step=102/2000 | warm=0 | policy=32 | replay=13264 | world_total=3778.4641 | actor=-56.2339 | critic=1.9338 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=807.2 | checkpoint=-
# [train] step=103/2000 | warm=0 | policy=32 | replay=13296 | world_total=3778.4371 | actor=-57.0258 | critic=1.9226 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=809.9 | checkpoint=-
# [train] step=104/2000 | warm=0 | policy=32 | replay=13328 | world_total=3778.3469 | actor=-57.4735 | critic=1.9259 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=812.7 | checkpoint=-
# [train] step=105/2000 | warm=0 | policy=32 | replay=13360 | world_total=3778.2077 | actor=-57.7358 | critic=1.8808 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=815.6 | checkpoint=-
# [train] step=106/2000 | warm=0 | policy=32 | replay=13392 | world_total=3778.2284 | actor=-57.4883 | critic=1.8812 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=818.4 | checkpoint=-
# [train] step=107/2000 | warm=0 | policy=32 | replay=13424 | world_total=3778.1991 | actor=-57.4775 | critic=1.9393 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=821.1 | checkpoint=-
# [train] step=108/2000 | warm=0 | policy=32 | replay=13456 | world_total=3778.1523 | actor=-58.0891 | critic=1.8845 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=823.7 | checkpoint=-
# [train] step=109/2000 | warm=0 | policy=32 | replay=13488 | world_total=3778.2741 | actor=-59.1865 | critic=2.0239 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=826.4 | checkpoint=-
# [train] step=110/2000 | warm=0 | policy=32 | replay=13520 | world_total=3778.0667 | actor=-58.7260 | critic=1.9227 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=829.1 | checkpoint=-
# [train] step=111/2000 | warm=0 | policy=32 | replay=13552 | world_total=3778.1295 | actor=-58.9657 | critic=1.9362 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=831.7 | checkpoint=-
# [train] step=112/2000 | warm=0 | policy=32 | replay=13584 | world_total=3777.9802 | actor=-58.8607 | critic=1.9087 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=834.5 | checkpoint=-
# [train] step=113/2000 | warm=0 | policy=32 | replay=13616 | world_total=3777.9680 | actor=-59.3124 | critic=1.9466 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=837.1 | checkpoint=-
# [train] step=114/2000 | warm=0 | policy=32 | replay=13648 | world_total=3777.8596 | actor=-59.0646 | critic=1.9114 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=839.8 | checkpoint=-
# [train] step=115/2000 | warm=0 | policy=32 | replay=13680 | world_total=3777.9021 | actor=-58.3020 | critic=1.8649 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=842.5 | checkpoint=-
# [train] step=116/2000 | warm=0 | policy=32 | replay=13712 | world_total=3777.7926 | actor=-57.8910 | critic=1.9023 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=845.2 | checkpoint=-
# [train] step=117/2000 | warm=0 | policy=32 | replay=13744 | world_total=3777.8160 | actor=-57.7961 | critic=1.8081 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=847.8 | checkpoint=-
# [train] step=118/2000 | warm=0 | policy=32 | replay=13776 | world_total=3777.9510 | actor=-57.2280 | critic=1.8681 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=850.6 | checkpoint=-
# [train] step=119/2000 | warm=0 | policy=32 | replay=13808 | world_total=3777.7899 | actor=-57.1975 | critic=1.8418 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=853.3 | checkpoint=-
# [train] step=120/2000 | warm=0 | policy=32 | replay=13840 | world_total=3777.7003 | actor=-57.8632 | critic=1.8750 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=856.1 | checkpoint=-
# [train] step=121/2000 | warm=0 | policy=32 | replay=13872 | world_total=3777.6493 | actor=-58.5405 | critic=1.8318 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=858.8 | checkpoint=-
# [train] step=122/2000 | warm=0 | policy=32 | replay=13904 | world_total=3777.5729 | actor=-59.0422 | critic=1.8522 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=861.6 | checkpoint=-
# [train] step=123/2000 | warm=0 | policy=32 | replay=13936 | world_total=3777.6843 | actor=-58.9075 | critic=1.8329 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=864.3 | checkpoint=-
# [train] step=124/2000 | warm=0 | policy=32 | replay=13968 | world_total=3777.6646 | actor=-59.3641 | critic=1.9012 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=867.0 | checkpoint=-
# [train] step=125/2000 | warm=0 | policy=32 | replay=14000 | world_total=3777.6319 | actor=-58.4770 | critic=1.9186 | eval_reward=45.1227 | cycle_s=20.0 | elapsed_s=887.0 | checkpoint=checkpoint_00125.pt
# [train] step=126/2000 | warm=0 | policy=32 | replay=14032 | world_total=3777.4977 | actor=-57.8988 | critic=1.7908 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=889.8 | checkpoint=-
# [train] step=127/2000 | warm=0 | policy=32 | replay=14064 | world_total=3777.5162 | actor=-57.3249 | critic=1.7623 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=892.5 | checkpoint=-
# [train] step=128/2000 | warm=0 | policy=32 | replay=14096 | world_total=3777.4960 | actor=-57.8104 | critic=1.8395 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=895.2 | checkpoint=-
# [train] step=129/2000 | warm=0 | policy=32 | replay=14128 | world_total=3777.4594 | actor=-58.8263 | critic=1.8141 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=898.2 | checkpoint=-
# [train] step=130/2000 | warm=0 | policy=32 | replay=14160 | world_total=3777.4351 | actor=-59.8638 | critic=1.8271 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=901.0 | checkpoint=-
# [train] step=131/2000 | warm=0 | policy=32 | replay=14192 | world_total=3777.4159 | actor=-59.5176 | critic=1.8440 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=903.8 | checkpoint=-
# [train] step=132/2000 | warm=0 | policy=32 | replay=14224 | world_total=3777.4785 | actor=-57.9982 | critic=1.8521 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=906.5 | checkpoint=-
# [train] step=133/2000 | warm=0 | policy=32 | replay=14256 | world_total=3777.6784 | actor=-56.9790 | critic=1.7569 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=909.2 | checkpoint=-
# [train] step=134/2000 | warm=0 | policy=32 | replay=14288 | world_total=3777.3795 | actor=-57.0845 | critic=1.8099 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=911.9 | checkpoint=-
# [train] step=135/2000 | warm=0 | policy=32 | replay=14320 | world_total=3777.3625 | actor=-58.4248 | critic=1.8662 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=914.7 | checkpoint=-
# [train] step=136/2000 | warm=0 | policy=32 | replay=14352 | world_total=3777.3456 | actor=-59.6770 | critic=1.9619 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=917.4 | checkpoint=-
# [train] step=137/2000 | warm=0 | policy=32 | replay=14384 | world_total=3777.2745 | actor=-59.7986 | critic=1.8194 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=920.1 | checkpoint=-
# [train] step=138/2000 | warm=0 | policy=32 | replay=14416 | world_total=3777.3282 | actor=-59.0602 | critic=1.7720 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=922.8 | checkpoint=-
# [train] step=139/2000 | warm=0 | policy=32 | replay=14448 | world_total=3777.2323 | actor=-57.9632 | critic=1.7995 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=925.6 | checkpoint=-
# [train] step=140/2000 | warm=0 | policy=32 | replay=14480 | world_total=3777.2558 | actor=-57.1309 | critic=1.8263 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=928.3 | checkpoint=-
# [train] step=141/2000 | warm=0 | policy=32 | replay=14512 | world_total=3777.2118 | actor=-57.5734 | critic=1.7374 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=931.0 | checkpoint=-
# [train] step=142/2000 | warm=0 | policy=32 | replay=14544 | world_total=3777.1996 | actor=-58.6165 | critic=1.7889 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=933.7 | checkpoint=-
# [train] step=143/2000 | warm=0 | policy=32 | replay=14576 | world_total=3777.2246 | actor=-59.8734 | critic=1.8112 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=936.4 | checkpoint=-
# [train] step=144/2000 | warm=0 | policy=32 | replay=14608 | world_total=3777.1433 | actor=-60.5770 | critic=1.8093 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=939.1 | checkpoint=-
# [train] step=145/2000 | warm=0 | policy=32 | replay=14640 | world_total=3777.0904 | actor=-60.1239 | critic=1.7787 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=941.8 | checkpoint=-
# [train] step=146/2000 | warm=0 | policy=32 | replay=14672 | world_total=3777.1301 | actor=-59.0696 | critic=1.7753 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=944.5 | checkpoint=-
# [train] step=147/2000 | warm=0 | policy=32 | replay=14704 | world_total=3777.0967 | actor=-58.2046 | critic=1.7611 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=947.3 | checkpoint=-
# [train] step=148/2000 | warm=0 | policy=32 | replay=14736 | world_total=3777.1880 | actor=-56.6800 | critic=1.6804 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=950.0 | checkpoint=-
# [train] step=149/2000 | warm=0 | policy=32 | replay=14768 | world_total=3777.1884 | actor=-56.6279 | critic=1.7086 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=952.7 | checkpoint=-
# [train] step=150/2000 | warm=0 | policy=32 | replay=14800 | world_total=3777.1417 | actor=-56.6821 | critic=1.7279 | eval_reward=45.1350 | cycle_s=20.0 | elapsed_s=972.6 | checkpoint=checkpoint_00150.pt
# [train] step=151/2000 | warm=0 | policy=32 | replay=14832 | world_total=3777.0463 | actor=-57.6922 | critic=1.7745 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=975.3 | checkpoint=-
# [train] step=152/2000 | warm=0 | policy=32 | replay=14864 | world_total=3777.0233 | actor=-58.8247 | critic=1.7475 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=978.0 | checkpoint=-
# [train] step=153/2000 | warm=0 | policy=32 | replay=14896 | world_total=3776.9997 | actor=-59.5515 | critic=1.7925 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=980.8 | checkpoint=-
# [train] step=154/2000 | warm=0 | policy=32 | replay=14928 | world_total=3777.0193 | actor=-59.9057 | critic=1.7515 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=983.5 | checkpoint=-
# [train] step=155/2000 | warm=0 | policy=32 | replay=14960 | world_total=3777.0149 | actor=-59.4629 | critic=1.8232 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=986.4 | checkpoint=-
# [train] step=156/2000 | warm=0 | policy=32 | replay=14992 | world_total=3776.9724 | actor=-59.3308 | critic=1.7734 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=989.1 | checkpoint=-
# [train] step=157/2000 | warm=0 | policy=32 | replay=15024 | world_total=3777.0310 | actor=-59.3424 | critic=1.8697 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=991.9 | checkpoint=-
# [train] step=158/2000 | warm=0 | policy=32 | replay=15056 | world_total=3776.9515 | actor=-59.6123 | critic=1.7189 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=994.6 | checkpoint=-
# [train] step=159/2000 | warm=0 | policy=32 | replay=15088 | world_total=3776.9322 | actor=-59.0960 | critic=1.7742 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=997.3 | checkpoint=-
# [train] step=160/2000 | warm=0 | policy=32 | replay=15120 | world_total=3776.8817 | actor=-59.0465 | critic=1.7376 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1000.0 | checkpoint=-
# [train] step=161/2000 | warm=0 | policy=32 | replay=15152 | world_total=3776.8808 | actor=-58.7181 | critic=1.7086 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1002.7 | checkpoint=-
# [train] step=162/2000 | warm=0 | policy=32 | replay=15184 | world_total=3776.8838 | actor=-58.9304 | critic=1.7299 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1005.4 | checkpoint=-
# [train] step=163/2000 | warm=0 | policy=32 | replay=15216 | world_total=3776.9494 | actor=-58.4577 | critic=1.7132 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1008.1 | checkpoint=-
# [train] step=164/2000 | warm=0 | policy=32 | replay=15248 | world_total=3776.8180 | actor=-58.4868 | critic=1.6990 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1010.9 | checkpoint=-
# [train] step=165/2000 | warm=0 | policy=32 | replay=15280 | world_total=3776.7911 | actor=-58.9938 | critic=1.6627 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1013.7 | checkpoint=-
# [train] step=166/2000 | warm=0 | policy=32 | replay=15312 | world_total=3776.8320 | actor=-59.2906 | critic=1.7112 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1016.4 | checkpoint=-
# [train] step=167/2000 | warm=0 | policy=32 | replay=15344 | world_total=3776.8500 | actor=-58.7724 | critic=1.7317 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1019.1 | checkpoint=-
# [train] step=168/2000 | warm=0 | policy=32 | replay=15376 | world_total=3776.8072 | actor=-58.2764 | critic=1.6644 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1021.9 | checkpoint=-
# [train] step=169/2000 | warm=0 | policy=32 | replay=15408 | world_total=3776.8795 | actor=-58.8731 | critic=1.7034 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1024.6 | checkpoint=-
# [train] step=170/2000 | warm=0 | policy=32 | replay=15440 | world_total=3776.8351 | actor=-59.4264 | critic=1.7233 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1027.3 | checkpoint=-
# [train] step=171/2000 | warm=0 | policy=32 | replay=15472 | world_total=3776.7234 | actor=-59.2060 | critic=1.7052 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1030.0 | checkpoint=-
# [train] step=172/2000 | warm=0 | policy=32 | replay=15504 | world_total=3776.8143 | actor=-59.2355 | critic=1.7150 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1032.7 | checkpoint=-
# [train] step=173/2000 | warm=0 | policy=32 | replay=15536 | world_total=3776.9416 | actor=-58.4198 | critic=1.8131 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1035.5 | checkpoint=-
# [train] step=174/2000 | warm=0 | policy=32 | replay=15568 | world_total=3776.8460 | actor=-58.4392 | critic=1.8103 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1038.2 | checkpoint=-
# [train] step=175/2000 | warm=0 | policy=32 | replay=15600 | world_total=3776.7499 | actor=-58.1318 | critic=1.7311 | eval_reward=45.1392 | cycle_s=20.1 | elapsed_s=1058.3 | checkpoint=checkpoint_00175.pt
# [train] step=176/2000 | warm=0 | policy=32 | replay=15632 | world_total=3776.6946 | actor=-58.6185 | critic=1.7089 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1061.0 | checkpoint=-
# [train] step=177/2000 | warm=0 | policy=32 | replay=15664 | world_total=3776.7205 | actor=-59.1114 | critic=1.6841 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1063.7 | checkpoint=-
# [train] step=178/2000 | warm=0 | policy=32 | replay=15696 | world_total=3776.6491 | actor=-59.8154 | critic=1.7269 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1066.4 | checkpoint=-
# [train] step=179/2000 | warm=0 | policy=32 | replay=15728 | world_total=3776.6985 | actor=-59.5319 | critic=1.7130 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1069.2 | checkpoint=-
# [train] step=180/2000 | warm=0 | policy=32 | replay=15760 | world_total=3776.7373 | actor=-59.0919 | critic=1.6891 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=1072.2 | checkpoint=-
# [train] step=181/2000 | warm=0 | policy=32 | replay=15792 | world_total=3776.6845 | actor=-58.4796 | critic=1.7970 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1074.9 | checkpoint=-
# [train] step=182/2000 | warm=0 | policy=32 | replay=15824 | world_total=3776.6904 | actor=-58.7735 | critic=1.7535 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1077.6 | checkpoint=-
# [train] step=183/2000 | warm=0 | policy=32 | replay=15856 | world_total=3776.6491 | actor=-59.2067 | critic=1.7968 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1080.3 | checkpoint=-
# [train] step=184/2000 | warm=0 | policy=32 | replay=15888 | world_total=3776.5975 | actor=-58.7544 | critic=1.7028 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1083.1 | checkpoint=-
# [train] step=185/2000 | warm=0 | policy=32 | replay=15920 | world_total=3776.5706 | actor=-58.5399 | critic=1.7340 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1085.8 | checkpoint=-
# [train] step=186/2000 | warm=0 | policy=32 | replay=15952 | world_total=3776.6161 | actor=-58.4958 | critic=1.6583 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1088.5 | checkpoint=-
# [train] step=187/2000 | warm=0 | policy=32 | replay=15984 | world_total=3776.5753 | actor=-58.8352 | critic=1.6971 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1091.2 | checkpoint=-
# [train] step=188/2000 | warm=0 | policy=32 | replay=16016 | world_total=3776.5985 | actor=-58.8973 | critic=1.6429 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1094.0 | checkpoint=-
# [train] step=189/2000 | warm=0 | policy=32 | replay=16048 | world_total=3776.5571 | actor=-58.9861 | critic=1.6474 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1096.7 | checkpoint=-
# [train] step=190/2000 | warm=0 | policy=32 | replay=16080 | world_total=3776.6012 | actor=-58.4704 | critic=1.6748 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1099.4 | checkpoint=-
# [train] step=191/2000 | warm=0 | policy=32 | replay=16112 | world_total=3776.5681 | actor=-57.7314 | critic=1.6215 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1102.2 | checkpoint=-
# [train] step=192/2000 | warm=0 | policy=32 | replay=16144 | world_total=3776.6072 | actor=-58.3112 | critic=1.7398 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1104.9 | checkpoint=-
# [train] step=193/2000 | warm=0 | policy=32 | replay=16176 | world_total=3776.5305 | actor=-59.3683 | critic=1.6922 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1107.7 | checkpoint=-
# [train] step=194/2000 | warm=0 | policy=32 | replay=16208 | world_total=3776.5447 | actor=-59.4438 | critic=1.7272 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1110.4 | checkpoint=-
# [train] step=195/2000 | warm=0 | policy=32 | replay=16240 | world_total=3776.6174 | actor=-59.3830 | critic=1.7251 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1113.2 | checkpoint=-
# [train] step=196/2000 | warm=0 | policy=32 | replay=16272 | world_total=3776.6175 | actor=-58.9217 | critic=1.7503 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1115.9 | checkpoint=-
# [train] step=197/2000 | warm=0 | policy=32 | replay=16304 | world_total=3776.7394 | actor=-59.0332 | critic=1.8183 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1118.6 | checkpoint=-
# [train] step=198/2000 | warm=0 | policy=32 | replay=16336 | world_total=3776.5262 | actor=-59.1519 | critic=1.7549 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1121.3 | checkpoint=-
# [train] step=199/2000 | warm=0 | policy=32 | replay=16368 | world_total=3776.4624 | actor=-58.8895 | critic=1.7546 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1124.0 | checkpoint=-
# [train] step=200/2000 | warm=0 | policy=32 | replay=16400 | world_total=3776.5118 | actor=-58.7053 | critic=1.7879 | eval_reward=45.1955 | cycle_s=20.2 | elapsed_s=1144.3 | checkpoint=checkpoint_00200.pt
# [train] step=201/2000 | warm=0 | policy=32 | replay=16432 | world_total=3776.4973 | actor=-58.7359 | critic=1.7552 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1147.0 | checkpoint=-
# [train] step=202/2000 | warm=0 | policy=32 | replay=16464 | world_total=3776.6273 | actor=-58.3863 | critic=1.8246 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1149.7 | checkpoint=-
# [train] step=203/2000 | warm=0 | policy=32 | replay=16496 | world_total=3776.5577 | actor=-59.0056 | critic=1.7366 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1152.4 | checkpoint=-
# [train] step=204/2000 | warm=0 | policy=32 | replay=16528 | world_total=3776.4710 | actor=-59.2344 | critic=1.7854 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1155.2 | checkpoint=-
# [train] step=205/2000 | warm=0 | policy=32 | replay=16560 | world_total=3776.4424 | actor=-59.0993 | critic=1.8465 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1158.0 | checkpoint=-
# [train] step=206/2000 | warm=0 | policy=32 | replay=16592 | world_total=3776.4564 | actor=-59.1003 | critic=1.8112 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1160.8 | checkpoint=-
# [train] step=207/2000 | warm=0 | policy=32 | replay=16624 | world_total=3776.3757 | actor=-59.1999 | critic=1.7260 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1163.6 | checkpoint=-
# [train] step=208/2000 | warm=0 | policy=32 | replay=16656 | world_total=3776.4013 | actor=-58.8151 | critic=1.8483 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1166.3 | checkpoint=-
# [train] step=209/2000 | warm=0 | policy=32 | replay=16688 | world_total=3776.4560 | actor=-58.1902 | critic=1.7897 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1169.0 | checkpoint=-
# [train] step=210/2000 | warm=0 | policy=32 | replay=16720 | world_total=3776.4848 | actor=-58.4002 | critic=1.7420 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1171.7 | checkpoint=-
# [train] step=211/2000 | warm=0 | policy=32 | replay=16752 | world_total=3776.4573 | actor=-58.8391 | critic=1.7919 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1174.5 | checkpoint=-
# [train] step=212/2000 | warm=0 | policy=32 | replay=16784 | world_total=3776.4484 | actor=-59.0437 | critic=1.8181 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1177.2 | checkpoint=-
# [train] step=213/2000 | warm=0 | policy=32 | replay=16816 | world_total=3776.4393 | actor=-58.6873 | critic=1.8078 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1179.9 | checkpoint=-
# [train] step=214/2000 | warm=0 | policy=32 | replay=16848 | world_total=3776.5094 | actor=-58.7545 | critic=1.8741 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1182.6 | checkpoint=-
# [train] step=215/2000 | warm=0 | policy=32 | replay=16880 | world_total=3776.3989 | actor=-59.3138 | critic=1.8287 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1185.4 | checkpoint=-
# [train] step=216/2000 | warm=0 | policy=32 | replay=16912 | world_total=3776.4487 | actor=-59.5353 | critic=1.9133 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1188.1 | checkpoint=-
# [train] step=217/2000 | warm=0 | policy=32 | replay=16944 | world_total=3776.5490 | actor=-59.2033 | critic=1.9101 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1190.8 | checkpoint=-
# [train] step=218/2000 | warm=0 | policy=32 | replay=16976 | world_total=3776.7508 | actor=-58.9338 | critic=2.0571 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1193.5 | checkpoint=-
# [train] step=219/2000 | warm=0 | policy=32 | replay=17008 | world_total=3776.5277 | actor=-60.8901 | critic=2.1690 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1196.3 | checkpoint=-
# [train] step=220/2000 | warm=0 | policy=32 | replay=17040 | world_total=3776.4237 | actor=-62.5801 | critic=2.2088 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1199.1 | checkpoint=-
# [train] step=221/2000 | warm=0 | policy=32 | replay=17072 | world_total=3776.3941 | actor=-63.3882 | critic=2.1963 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1201.8 | checkpoint=-
# [train] step=222/2000 | warm=0 | policy=32 | replay=17104 | world_total=3776.3027 | actor=-63.4905 | critic=2.1781 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1204.5 | checkpoint=-
# [train] step=223/2000 | warm=0 | policy=32 | replay=17136 | world_total=3776.3396 | actor=-63.4709 | critic=2.1451 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=1207.5 | checkpoint=-
# [train] step=224/2000 | warm=0 | policy=32 | replay=17168 | world_total=3776.3489 | actor=-63.9302 | critic=2.1323 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1210.3 | checkpoint=-
# [train] step=225/2000 | warm=0 | policy=32 | replay=17200 | world_total=3776.3859 | actor=-63.5853 | critic=2.2289 | eval_reward=45.9909 | cycle_s=20.4 | elapsed_s=1230.7 | checkpoint=checkpoint_00225.pt
# [train] step=226/2000 | warm=0 | policy=32 | replay=17232 | world_total=3776.5012 | actor=-64.0398 | critic=2.3283 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1233.4 | checkpoint=-
# [train] step=227/2000 | warm=0 | policy=32 | replay=17264 | world_total=3776.4275 | actor=-64.8476 | critic=2.3531 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1236.2 | checkpoint=-
# [train] step=228/2000 | warm=0 | policy=32 | replay=17296 | world_total=3776.4157 | actor=-65.4406 | critic=2.4644 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=1239.5 | checkpoint=-
# [train] step=229/2000 | warm=0 | policy=32 | replay=17328 | world_total=3776.4223 | actor=-66.5502 | critic=2.4687 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=1242.5 | checkpoint=-
# [train] step=230/2000 | warm=0 | policy=32 | replay=17360 | world_total=3776.4141 | actor=-67.4385 | critic=2.4806 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1245.3 | checkpoint=-
# [train] step=231/2000 | warm=0 | policy=32 | replay=17392 | world_total=3776.3672 | actor=-68.1464 | critic=2.6223 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1248.3 | checkpoint=-
# [train] step=232/2000 | warm=0 | policy=32 | replay=17424 | world_total=3776.2939 | actor=-69.0317 | critic=2.6039 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1251.0 | checkpoint=-
# [train] step=233/2000 | warm=0 | policy=32 | replay=17456 | world_total=3776.3498 | actor=-68.6830 | critic=2.4401 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1253.8 | checkpoint=-
# [train] step=234/2000 | warm=0 | policy=32 | replay=17488 | world_total=3776.3029 | actor=-67.2087 | critic=2.4750 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1256.6 | checkpoint=-
# [train] step=235/2000 | warm=0 | policy=32 | replay=17520 | world_total=3776.3051 | actor=-65.8056 | critic=2.0584 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1259.6 | checkpoint=-
# [train] step=236/2000 | warm=0 | policy=32 | replay=17552 | world_total=3776.2637 | actor=-66.8443 | critic=2.1485 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1262.3 | checkpoint=-
# [train] step=237/2000 | warm=0 | policy=32 | replay=17584 | world_total=3776.3008 | actor=-68.4428 | critic=2.4494 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1265.0 | checkpoint=-
# [train] step=238/2000 | warm=0 | policy=32 | replay=17616 | world_total=3776.2805 | actor=-67.9842 | critic=2.1284 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1267.7 | checkpoint=-
# [train] step=239/2000 | warm=0 | policy=32 | replay=17648 | world_total=3776.2983 | actor=-67.3562 | critic=2.0749 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1270.4 | checkpoint=-
# [train] step=240/2000 | warm=0 | policy=32 | replay=17680 | world_total=3776.4213 | actor=-66.5610 | critic=2.1416 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1273.2 | checkpoint=-
# [train] step=241/2000 | warm=0 | policy=32 | replay=17712 | world_total=3776.6376 | actor=-64.8119 | critic=2.2223 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1275.9 | checkpoint=-
# [train] step=242/2000 | warm=0 | policy=32 | replay=17744 | world_total=3776.4095 | actor=-64.6570 | critic=2.3523 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1278.8 | checkpoint=-
# [train] step=243/2000 | warm=0 | policy=32 | replay=17776 | world_total=3776.3988 | actor=-66.8191 | critic=2.4095 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1281.5 | checkpoint=-
# [train] step=244/2000 | warm=0 | policy=32 | replay=17808 | world_total=3776.3419 | actor=-68.1505 | critic=2.2752 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1284.3 | checkpoint=-
# [train] step=245/2000 | warm=0 | policy=32 | replay=17840 | world_total=3776.3281 | actor=-67.9324 | critic=2.1731 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1287.0 | checkpoint=-
# [train] step=246/2000 | warm=0 | policy=32 | replay=17872 | world_total=3776.3364 | actor=-66.8622 | critic=2.1513 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1289.8 | checkpoint=-
# [train] step=247/2000 | warm=0 | policy=32 | replay=17904 | world_total=3776.3191 | actor=-65.8020 | critic=2.1083 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1292.5 | checkpoint=-
# [train] step=248/2000 | warm=0 | policy=32 | replay=17936 | world_total=3776.2803 | actor=-66.6340 | critic=2.0044 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1295.3 | checkpoint=-
# [train] step=249/2000 | warm=0 | policy=32 | replay=17968 | world_total=3776.2388 | actor=-67.2259 | critic=2.0831 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1298.0 | checkpoint=-
# [train] step=250/2000 | warm=0 | policy=32 | replay=18000 | world_total=3776.2449 | actor=-66.9718 | critic=2.0129 | eval_reward=46.5284 | cycle_s=20.4 | elapsed_s=1318.5 | checkpoint=checkpoint_00250.pt
# [train] step=251/2000 | warm=0 | policy=32 | replay=18032 | world_total=3776.3370 | actor=-65.4745 | critic=1.8253 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1321.2 | checkpoint=-
# [train] step=252/2000 | warm=0 | policy=32 | replay=18064 | world_total=3776.2626 | actor=-64.5578 | critic=1.8247 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1324.0 | checkpoint=-
# [train] step=253/2000 | warm=0 | policy=32 | replay=18096 | world_total=3776.2549 | actor=-65.1936 | critic=1.7660 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1326.7 | checkpoint=-
# [train] step=254/2000 | warm=0 | policy=32 | replay=18128 | world_total=3776.3133 | actor=-65.8583 | critic=1.8386 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=1329.6 | checkpoint=-
# [train] step=255/2000 | warm=0 | policy=32 | replay=18160 | world_total=3776.2437 | actor=-66.7929 | critic=1.8571 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1332.4 | checkpoint=-
# [train] step=256/2000 | warm=0 | policy=32 | replay=18192 | world_total=3776.2301 | actor=-66.0517 | critic=1.7986 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1335.2 | checkpoint=-
# [train] step=257/2000 | warm=0 | policy=32 | replay=18224 | world_total=3776.2747 | actor=-63.9446 | critic=1.8976 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1337.9 | checkpoint=-
# [train] step=258/2000 | warm=0 | policy=32 | replay=18256 | world_total=3776.2747 | actor=-64.2284 | critic=1.6518 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1340.7 | checkpoint=-
# [train] step=259/2000 | warm=0 | policy=32 | replay=18288 | world_total=3776.2404 | actor=-64.4565 | critic=1.8160 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1343.4 | checkpoint=-
# [train] step=260/2000 | warm=0 | policy=32 | replay=18320 | world_total=3776.2597 | actor=-63.9012 | critic=1.7038 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1346.2 | checkpoint=-
# [train] step=261/2000 | warm=0 | policy=32 | replay=18352 | world_total=3776.2433 | actor=-64.1762 | critic=1.6437 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=1349.4 | checkpoint=-
# [train] step=262/2000 | warm=0 | policy=32 | replay=18384 | world_total=3776.2450 | actor=-64.4546 | critic=1.6634 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=1352.2 | checkpoint=-
# [train] step=263/2000 | warm=0 | policy=32 | replay=18416 | world_total=3776.2393 | actor=-63.5385 | critic=1.6278 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=1354.9 | checkpoint=-
# ...
# [train] step=1920/2000 | warm=0 | policy=32 | replay=71440 | world_total=3772.8268 | actor=-57.3852 | critic=2.7058 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7195.6 | checkpoint=-
# [train] step=1921/2000 | warm=0 | policy=32 | replay=71472 | world_total=3772.8092 | actor=-57.0939 | critic=3.0273 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7198.4 | checkpoint=-
# [train] step=1922/2000 | warm=0 | policy=32 | replay=71504 | world_total=3772.8154 | actor=-56.8069 | critic=3.0573 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7201.1 | checkpoint=-
# [train] step=1923/2000 | warm=0 | policy=32 | replay=71536 | world_total=3772.7592 | actor=-57.5436 | critic=2.4918 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7203.9 | checkpoint=-
# [train] step=1924/2000 | warm=0 | policy=32 | replay=71568 | world_total=3772.7759 | actor=-58.3693 | critic=3.0951 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7206.7 | checkpoint=-
# [train] step=1925/2000 | warm=0 | policy=32 | replay=71600 | world_total=3772.8240 | actor=-58.0083 | critic=4.5609 | eval_reward=43.6720 | cycle_s=22.5 | elapsed_s=7229.2 | checkpoint=checkpoint_01925.pt
# [train] step=1926/2000 | warm=0 | policy=32 | replay=71632 | world_total=3772.8258 | actor=-57.0180 | critic=4.0039 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7232.0 | checkpoint=-
# [train] step=1927/2000 | warm=0 | policy=32 | replay=71664 | world_total=3772.7802 | actor=-56.5900 | critic=3.4326 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7234.7 | checkpoint=-
# [train] step=1928/2000 | warm=0 | policy=32 | replay=71696 | world_total=3772.8304 | actor=-56.8504 | critic=5.3737 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7237.6 | checkpoint=-
# [train] step=1929/2000 | warm=0 | policy=32 | replay=71728 | world_total=3772.8228 | actor=-57.6526 | critic=2.6506 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7240.4 | checkpoint=-
# [train] step=1930/2000 | warm=0 | policy=32 | replay=71760 | world_total=3772.7744 | actor=-58.8210 | critic=2.6991 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7243.1 | checkpoint=-
# [train] step=1931/2000 | warm=0 | policy=32 | replay=71792 | world_total=3772.7759 | actor=-59.7215 | critic=2.6077 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7245.9 | checkpoint=-
# [train] step=1932/2000 | warm=0 | policy=32 | replay=71824 | world_total=3772.7889 | actor=-59.3655 | critic=5.1013 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7248.8 | checkpoint=-
# [train] step=1933/2000 | warm=0 | policy=32 | replay=71856 | world_total=3772.8190 | actor=-58.2240 | critic=2.7099 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7251.6 | checkpoint=-
# [train] step=1934/2000 | warm=0 | policy=32 | replay=71888 | world_total=3772.7589 | actor=-57.8250 | critic=1.6815 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7254.4 | checkpoint=-
# [train] step=1935/2000 | warm=0 | policy=32 | replay=71920 | world_total=3772.7844 | actor=-58.1692 | critic=2.0513 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7257.2 | checkpoint=-
# [train] step=1936/2000 | warm=0 | policy=32 | replay=71952 | world_total=3772.8611 | actor=-58.4420 | critic=2.2173 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7260.0 | checkpoint=-
# [train] step=1937/2000 | warm=0 | policy=32 | replay=71984 | world_total=3772.7796 | actor=-58.6527 | critic=1.1001 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7262.7 | checkpoint=-
# [train] step=1938/2000 | warm=0 | policy=32 | replay=72016 | world_total=3772.7878 | actor=-58.6065 | critic=3.2470 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7265.5 | checkpoint=-
# [train] step=1939/2000 | warm=0 | policy=32 | replay=72048 | world_total=3772.8407 | actor=-58.2714 | critic=2.5123 | eval_reward=n/a | cycle_s=2.6 | elapsed_s=7268.0 | checkpoint=-
# [train] step=1940/2000 | warm=0 | policy=32 | replay=72080 | world_total=3772.7764 | actor=-57.7893 | critic=2.8368 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7270.7 | checkpoint=-
# [train] step=1941/2000 | warm=0 | policy=32 | replay=72112 | world_total=3772.7604 | actor=-57.6406 | critic=3.3981 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7273.4 | checkpoint=-
# [train] step=1942/2000 | warm=0 | policy=32 | replay=72144 | world_total=3772.7612 | actor=-58.0224 | critic=3.8946 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7276.2 | checkpoint=-
# [train] step=1943/2000 | warm=0 | policy=32 | replay=72176 | world_total=3772.8225 | actor=-58.5385 | critic=2.5571 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7278.9 | checkpoint=-
# [train] step=1944/2000 | warm=0 | policy=32 | replay=72208 | world_total=3772.8383 | actor=-58.7655 | critic=3.6139 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7281.8 | checkpoint=-
# [train] step=1945/2000 | warm=0 | policy=32 | replay=72240 | world_total=3772.7777 | actor=-58.8391 | critic=2.7336 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7284.6 | checkpoint=-
# [train] step=1946/2000 | warm=0 | policy=32 | replay=72272 | world_total=3772.7721 | actor=-59.1248 | critic=1.2621 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7287.5 | checkpoint=-
# [train] step=1947/2000 | warm=0 | policy=32 | replay=72304 | world_total=3772.7845 | actor=-59.5952 | critic=1.2418 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7290.3 | checkpoint=-
# [train] step=1948/2000 | warm=0 | policy=32 | replay=72336 | world_total=3772.7876 | actor=-59.6037 | critic=2.9577 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7293.1 | checkpoint=-
# [train] step=1949/2000 | warm=0 | policy=32 | replay=72368 | world_total=3772.7816 | actor=-58.9946 | critic=2.4568 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7296.0 | checkpoint=-
# [train] step=1950/2000 | warm=0 | policy=32 | replay=72400 | world_total=3772.7437 | actor=-58.0701 | critic=3.4316 | eval_reward=42.2837 | cycle_s=23.0 | elapsed_s=7319.0 | checkpoint=checkpoint_01950.pt
# [train] step=1951/2000 | warm=0 | policy=32 | replay=72432 | world_total=3772.8261 | actor=-57.5230 | critic=2.0430 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=7322.1 | checkpoint=-
# [train] step=1952/2000 | warm=0 | policy=32 | replay=72464 | world_total=3772.8047 | actor=-58.1416 | critic=1.7112 | eval_reward=n/a | cycle_s=3.1 | elapsed_s=7325.2 | checkpoint=-
# [train] step=1953/2000 | warm=0 | policy=32 | replay=72496 | world_total=3772.7872 | actor=-58.8637 | critic=1.1841 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7328.0 | checkpoint=-
# [train] step=1954/2000 | warm=0 | policy=32 | replay=72528 | world_total=3772.7722 | actor=-59.0599 | critic=1.4392 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7330.8 | checkpoint=-
# [train] step=1955/2000 | warm=0 | policy=32 | replay=72560 | world_total=3772.7385 | actor=-59.2597 | critic=1.4215 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7333.6 | checkpoint=-
# [train] step=1956/2000 | warm=0 | policy=32 | replay=72592 | world_total=3772.7693 | actor=-59.6987 | critic=1.1272 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7336.4 | checkpoint=-
# [train] step=1957/2000 | warm=0 | policy=32 | replay=72624 | world_total=3772.7840 | actor=-59.9319 | critic=1.8609 | eval_reward=n/a | cycle_s=3.3 | elapsed_s=7339.7 | checkpoint=-
# [train] step=1958/2000 | warm=0 | policy=32 | replay=72656 | world_total=3772.7360 | actor=-59.7535 | critic=2.1784 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7342.5 | checkpoint=-
# [train] step=1959/2000 | warm=0 | policy=32 | replay=72688 | world_total=3772.8031 | actor=-59.3842 | critic=1.9761 | eval_reward=n/a | cycle_s=3.2 | elapsed_s=7345.7 | checkpoint=-
# [train] step=1960/2000 | warm=0 | policy=32 | replay=72720 | world_total=3772.7677 | actor=-58.8459 | critic=1.5084 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7348.5 | checkpoint=-
# [train] step=1961/2000 | warm=0 | policy=32 | replay=72752 | world_total=3772.7492 | actor=-58.5302 | critic=1.6200 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7351.2 | checkpoint=-
# [train] step=1962/2000 | warm=0 | policy=32 | replay=72784 | world_total=3772.7953 | actor=-58.3216 | critic=2.7314 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7354.0 | checkpoint=-
# [train] step=1963/2000 | warm=0 | policy=32 | replay=72816 | world_total=3772.8264 | actor=-57.7295 | critic=3.7941 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7356.8 | checkpoint=-
# [train] step=1964/2000 | warm=0 | policy=32 | replay=72848 | world_total=3772.7632 | actor=-57.1928 | critic=3.0417 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7359.5 | checkpoint=-
# [train] step=1965/2000 | warm=0 | policy=32 | replay=72880 | world_total=3772.8254 | actor=-57.2521 | critic=1.9553 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7362.3 | checkpoint=-
# [train] step=1966/2000 | warm=0 | policy=32 | replay=72912 | world_total=3772.7914 | actor=-57.7500 | critic=3.0570 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=7365.3 | checkpoint=-
# [train] step=1967/2000 | warm=0 | policy=32 | replay=72944 | world_total=3772.8383 | actor=-58.6043 | critic=2.7396 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7368.1 | checkpoint=-
# [train] step=1968/2000 | warm=0 | policy=32 | replay=72976 | world_total=3772.8517 | actor=-59.2518 | critic=2.3124 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7370.8 | checkpoint=-
# [train] step=1969/2000 | warm=0 | policy=32 | replay=73008 | world_total=3772.8276 | actor=-59.4196 | critic=1.8330 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7373.6 | checkpoint=-
# [train] step=1970/2000 | warm=0 | policy=32 | replay=73040 | world_total=3772.7736 | actor=-58.9956 | critic=2.9393 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7376.4 | checkpoint=-
# [train] step=1971/2000 | warm=0 | policy=32 | replay=73072 | world_total=3772.7267 | actor=-58.3023 | critic=2.4488 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7379.3 | checkpoint=-
# [train] step=1972/2000 | warm=0 | policy=32 | replay=73104 | world_total=3772.7550 | actor=-57.1513 | critic=4.9652 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7382.1 | checkpoint=-
# [train] step=1973/2000 | warm=0 | policy=32 | replay=73136 | world_total=3772.7934 | actor=-56.3828 | critic=3.6986 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7384.9 | checkpoint=-
# [train] step=1974/2000 | warm=0 | policy=32 | replay=73168 | world_total=3772.7874 | actor=-56.9483 | critic=2.3549 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7387.7 | checkpoint=-
# [train] step=1975/2000 | warm=0 | policy=32 | replay=73200 | world_total=3772.8284 | actor=-57.7619 | critic=2.6140 | eval_reward=40.8611 | cycle_s=22.0 | elapsed_s=7409.7 | checkpoint=checkpoint_01975.pt
# [train] step=1976/2000 | warm=0 | policy=32 | replay=73232 | world_total=3772.7936 | actor=-58.3199 | critic=1.7776 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7412.5 | checkpoint=-
# [train] step=1977/2000 | warm=0 | policy=32 | replay=73264 | world_total=3772.7527 | actor=-58.5922 | critic=2.1575 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7415.3 | checkpoint=-
# [train] step=1978/2000 | warm=0 | policy=32 | replay=73296 | world_total=3772.7498 | actor=-58.7843 | critic=1.4992 | eval_reward=n/a | cycle_s=4.2 | elapsed_s=7419.4 | checkpoint=-
# [train] step=1979/2000 | warm=0 | policy=32 | replay=73328 | world_total=3772.7618 | actor=-58.9660 | critic=2.5452 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=7422.4 | checkpoint=-
# [train] step=1980/2000 | warm=0 | policy=32 | replay=73360 | world_total=3772.7884 | actor=-59.1662 | critic=1.8273 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=7425.4 | checkpoint=-
# [train] step=1981/2000 | warm=0 | policy=32 | replay=73392 | world_total=3772.7549 | actor=-59.5669 | critic=1.0469 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7428.3 | checkpoint=-
# [train] step=1982/2000 | warm=0 | policy=32 | replay=73424 | world_total=3772.7508 | actor=-59.8281 | critic=1.6919 | eval_reward=n/a | cycle_s=3.0 | elapsed_s=7431.3 | checkpoint=-
# [train] step=1983/2000 | warm=0 | policy=32 | replay=73456 | world_total=3772.7559 | actor=-59.5529 | critic=1.9546 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7434.2 | checkpoint=-
# [train] step=1984/2000 | warm=0 | policy=32 | replay=73488 | world_total=3772.7848 | actor=-59.0272 | critic=1.6471 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7437.0 | checkpoint=-
# [train] step=1985/2000 | warm=0 | policy=32 | replay=73520 | world_total=3772.7313 | actor=-58.4783 | critic=2.6995 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7439.8 | checkpoint=-
# [train] step=1986/2000 | warm=0 | policy=32 | replay=73552 | world_total=3772.7227 | actor=-57.9890 | critic=2.0017 | eval_reward=n/a | cycle_s=2.9 | elapsed_s=7442.7 | checkpoint=-
# [train] step=1987/2000 | warm=0 | policy=32 | replay=73584 | world_total=3772.7363 | actor=-57.7847 | critic=1.9727 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7445.4 | checkpoint=-
# [train] step=1988/2000 | warm=0 | policy=32 | replay=73616 | world_total=3772.7849 | actor=-57.9921 | critic=2.0565 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7448.2 | checkpoint=-
# [train] step=1989/2000 | warm=0 | policy=32 | replay=73648 | world_total=3772.7722 | actor=-58.6402 | critic=1.7830 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7450.9 | checkpoint=-
# [train] step=1990/2000 | warm=0 | policy=32 | replay=73680 | world_total=3772.7305 | actor=-59.1620 | critic=1.7887 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7453.7 | checkpoint=-
# [train] step=1991/2000 | warm=0 | policy=32 | replay=73712 | world_total=3772.7931 | actor=-58.9774 | critic=1.1531 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7456.4 | checkpoint=-
# [train] step=1992/2000 | warm=0 | policy=32 | replay=73744 | world_total=3772.7511 | actor=-58.3304 | critic=2.4600 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7459.2 | checkpoint=-
# [train] step=1993/2000 | warm=0 | policy=32 | replay=73776 | world_total=3772.7428 | actor=-58.2636 | critic=1.7616 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7461.9 | checkpoint=-
# [train] step=1994/2000 | warm=0 | policy=32 | replay=73808 | world_total=3772.7723 | actor=-58.9188 | critic=1.6045 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7464.7 | checkpoint=-
# [train] step=1995/2000 | warm=0 | policy=32 | replay=73840 | world_total=3772.7272 | actor=-59.5282 | critic=1.4842 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7467.4 | checkpoint=-
# [train] step=1996/2000 | warm=0 | policy=32 | replay=73872 | world_total=3772.7245 | actor=-59.5567 | critic=1.4430 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7470.2 | checkpoint=-
# [train] step=1997/2000 | warm=0 | policy=32 | replay=73904 | world_total=3772.7349 | actor=-59.1817 | critic=1.8813 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7473.0 | checkpoint=-
# [train] step=1998/2000 | warm=0 | policy=32 | replay=73936 | world_total=3772.7534 | actor=-58.5254 | critic=1.4088 | eval_reward=n/a | cycle_s=2.8 | elapsed_s=7475.8 | checkpoint=-
# [train] step=1999/2000 | warm=0 | policy=32 | replay=73968 | world_total=3772.7059 | actor=-58.0674 | critic=2.0484 | eval_reward=n/a | cycle_s=2.7 | elapsed_s=7478.5 | checkpoint=-
# [train] step=2000/2000 | warm=0 | policy=32 | replay=74000 | world_total=3772.7537 | actor=-58.0978 | critic=1.4079 | eval_reward=43.9051 | cycle_s=22.8 | elapsed_s=7501.3 | checkpoint=checkpoint_02000.pt
#
# Completed cycles: 2000
# Latest checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/checkpoints/checkpoint_02000.pt
# Latest metrics: {'step': 2000, 'warm_start_added': 0, 'policy_added': 32, 'replay_size': 74000, 'world_model/reconstruction_loss': 3766.2029724121094, 'world_model/reconstruction_mse': 0.0010892665741266683, 'world_model/observation_log_prob': -3766.2029724121094, 'world_model/reward_loss': 0.9191356673836708, 'world_model/continue_loss': 0.0004526612385689077, 'world_model/kl_loss': 3.4903756976127625, 'world_model/kl_loss_raw': 3.482669770717621, 'world_model/overshooting_kl_loss': 4.28133761882782, 'world_model/overshooting_feature_mse': 6.1868380308151245, 'world_model/overshooting_pairs': 65.0, 'world_model/total_loss': 3772.753692626953, 'behavior/actor_loss': -58.097832679748535, 'behavior/critic_loss': 1.4078638702630997, 'behavior/imagined_reward_mean': 0.5993547216057777, 'behavior/imagined_value_mean': 58.022449016571045, 'evaluation/episodes': 10.0, 'evaluation/mean_reward': 43.90505679903971, 'evaluation/mean_steps': 75.0, 'evaluation/crash_rate': 0.4}

# %% [markdown]
# ## 4 · Training History
#
# `export_training_history_artifacts` reads `cycle_metrics.csv` and writes a multi-panel PNG (`curves`) and a JSON summary (`summary`).
#
# **What to look for in the curves:**
# - `reconstruction_loss` — should decrease steadily as the encoder/decoder learns to compress observations.
# - `kl_loss` — should settle at a stable positive value; collapse to zero means the stochastic state is unused.
# - `evaluation/mean_reward` — the primary performance signal; should trend upward as the actor learns.
# - `evaluation/crash_rate` — should decrease toward zero for a robust policy.

# %%
from IPython.display import Image, display
import importlib
import json
import tiny_dreamer_highway.evaluation.training_analysis as _ta_mod

_ta_mod = importlib.reload(_ta_mod)
export_training_history_artifacts = _ta_mod.export_training_history_artifacts

history_artifacts = export_training_history_artifacts(
    training_summary.log_dir / 'cycle_metrics.csv',
    RUN_ARTIFACT_ROOT / 'analysis',
    prefix=RUN_NAME,
)

# export_training_history_artifacts returns:
#   history_artifacts['curves']  — multi-panel learning-curves PNG
#   history_artifacts['summary'] — JSON Path with per-metric summary stats
display(Image(filename=str(history_artifacts['curves'])))
analysis_summary = json.loads(history_artifacts['summary'].read_text(encoding='utf-8'))
print(json.dumps(analysis_summary, indent=2))
# Out:
# {
#   "best_eval_mean_reward": 46.528432830500996,
#   "best_eval_reward_step": 250,
#   "best_imagined_reward_mean": 1.2580223679542542,
#   "best_imagined_reward_step": 2,
#   "best_world_model_step": 1999,
#   "best_world_model_total_loss": 3772.7059326171875,
#   "largest_replay_size": 74000,
#   "largest_replay_step": 2000,
#   "last_metrics": {
#     "behavior/actor_loss": -58.097832679748535,
#     "behavior/critic_loss": 1.4078638702630997,
#     "behavior/imagined_reward_mean": 0.5993547216057777,
#     "behavior/imagined_value_mean": 58.022449016571045,
#     "evaluation/crash_rate": 0.4,
#     "evaluation/episodes": 10.0,
#     "evaluation/mean_reward": 43.90505679903971,
#     "evaluation/mean_steps": 75.0,
#     "policy_added": 32,
#     "replay_size": 74000,
#     "step": 2000,
#     "warm_start_added": 0,
#     "world_model/continue_loss": 0.0004526612385689077,
#     "world_model/kl_loss": 3.4903756976127625,
#     "world_model/kl_loss_raw": 3.482669770717621,
#     "world_model/observation_log_prob": -3766.2029724121094,
#     "world_model/overshooting_feature_mse": 6.1868380308151245,
#     "world_model/overshooting_kl_loss": 4.28133761882782,
#     "world_model/overshooting_pairs": 65.0,
#     "world_model/reconstruction_loss": 3766.2029724121094,
#     "world_model/reconstruction_mse": 0.0010892665741266683,
#     "world_model/reward_loss": 0.9191356673836708,
#     "world_model/total_loss": 3772.753692626953
#   },
#   "last_step": 2000,
#   "num_records": 2000
# }

# %% [markdown]
# ## 5 · N-step World Model Prediction Evaluation
#
# Given a **seed observation** and the **real actions** recorded in the replay buffer, the world model is asked to predict what the next `EVAL_HORIZON` frames would look like using only the RSSM prior — no observations after the first.
#
# **Protocol:**
# 1. Encode the seed frame → posterior state (RSSM grounded in reality).
# 2. Roll forward `EVAL_HORIZON` steps via the prior, applying the recorded actions.
# 3. Decode each imagined latent to a pixel prediction.
# 4. Compare predicted vs. actual frames with MSE, PSNR, and SSIM per step.
#
# **Expected pattern:** metrics degrade with step count because autonomous vehicles move unpredictably and the prior accumulates uncertainty. Graceful degradation (slow MSE rise) indicates a well-regularised RSSM; a sharp cliff at step 2–3 indicates the prior has not learned useful multi-step dynamics.
#
# First, load the checkpoint and replay buffer companion file saved by the training loop.

# %%
import torch
from tiny_dreamer_highway.data.replay_buffer import ReplayBuffer
from tiny_dreamer_highway.evaluation.policy_rollout import _load_models_from_checkpoint
from tiny_dreamer_highway.evaluation.prediction_eval import (
    evaluate_n_step_predictions,
    evaluate_latent_rollout_consistency,
)
from tiny_dreamer_highway.evaluation.visualization import export_prediction_media_bundle

# ── Load world model and actor weights from the latest checkpoint ────────────
DEVICE = torch.device(config.device if torch.cuda.is_available() else 'cpu')
CKPT_PATH = training_summary.latest_checkpoint
world_model, actor = _load_models_from_checkpoint(CKPT_PATH, config, DEVICE)
print('World model loaded from:', CKPT_PATH)

# ── Restore the replay buffer for ground-truth observation sequences ──────────
# Each checkpoint has a companion replay_{step:05d}.pt in the same directory,
# saved automatically by the training loop.
step_num = int(CKPT_PATH.stem.split('_')[-1])
replay_path = CKPT_PATH.with_name(f'replay_{step_num:05d}.pt')
replay_buffer = ReplayBuffer(capacity=config.replay.capacity)
replay_state = torch.load(replay_path, map_location='cpu', weights_only=False)
replay_buffer.load_state_dict(replay_state)
print(f'Replay buffer restored: {len(replay_buffer):,} transitions  '
      f'(capacity: {replay_buffer.capacity:,})')
# Out:
# World model loaded from: /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/checkpoints/checkpoint_02000.pt
# Replay buffer restored: 74,000 transitions  (capacity: 500,000)

# %% [markdown]
# ### Checkpoint and Replay Buffer
#
# The checkpoint saved by the training loop contains:
# ```
# step              — environment step count at save time
# world_model       — state dict for encoder, RSSM, decoder, reward head, continue head
# actor             — state dict for the policy MLP (tanh-Normal output)
# critic            — state dict for the value MLP
# wm_optimizer      — AdamW / FlashAdamW state for world model parameters
# actor_optimizer   — optimizer state for actor
# critic_optimizer  — optimizer state for critic
# metrics           — list of per-cycle metric dicts logged during training
# ```
#
# The companion `replay_{step:05d}.pt` is loaded to get real held-out sequences for the prediction evaluation. Using replay data (rather than new rollouts) ensures the evaluation tests generalisation to transitions not seen during the most recent gradient updates.

# %%
# ── Sample ground-truth sequences from the replay buffer ─────────────────────
# We request sequences of length (EVAL_HORIZON + 1) so that:
#   observations[:, 0]            → seed frame fed to the encoder
#   observations[:, 1:H+1]        → H actual next frames (prediction targets)
#   actions[:, :H]                 → H actions that produced those transitions

EVAL_HORIZON = 15   # Number of imagination steps
EVAL_BATCH   = 8    # Sequences per evaluation (metrics averaged over this)

seq_batch = replay_buffer.sample_sequence_batch(
    batch_size=EVAL_BATCH,
    sequence_length=EVAL_HORIZON + 1,
)

seed_obs       = torch.as_tensor(seq_batch.observations[:, 0], device=DEVICE)
future_actions = torch.as_tensor(
    seq_batch.actions[:, :EVAL_HORIZON], dtype=torch.float32, device=DEVICE
)
target_obs     = torch.as_tensor(seq_batch.observations[:, 1:EVAL_HORIZON + 1], device=DEVICE)

print(f'seed_obs:       {tuple(seed_obs.shape)}')
print(f'future_actions: {tuple(future_actions.shape)}')
print(f'target_obs:     {tuple(target_obs.shape)}')

# ── Pixel-level n-step prediction evaluation ─────────────────────────────────
# Imagines EVAL_HORIZON steps from the seed frame, then computes MSE/PSNR/SSIM
# per step against the actual frames captured during the same transitions.
n_step_result = evaluate_n_step_predictions(world_model, seed_obs, future_actions, target_obs)

print('\nN-step prediction summary (average over all steps and batch):')
for key, value in n_step_result['summary'].items():
    print(f'  {key}: {value:.4f}')

print('\nPer-step pixel metrics (first 5 steps):')
for item in n_step_result['step_metrics'][:5]:
    step = int(item['step'])
    print(f"  step {step:2d}  MSE={item['mse']:.4f}  "
          f"PSNR={item['psnr']:.2f} dB  SSIM={item['ssim']:.4f}")
# Out:
# seed_obs:       (8, 1, 64, 64)
# future_actions: (8, 15, 2)
# target_obs:     (8, 15, 1, 64, 64)
#
# N-step prediction summary (average over all steps and batch):
#   mse_mean: 0.0395
#   psnr_mean: 14.0838
#   ssim_mean: 0.1409
#   nll_mean: 3844.8091
#
# Per-step pixel metrics (first 5 steps):
#   step  1  MSE=0.0417  PSNR=13.80 dB  SSIM=0.0908
#   step  2  MSE=0.0492  PSNR=13.08 dB  SSIM=-0.0528
#   step  3  MSE=0.0397  PSNR=14.01 dB  SSIM=0.1772
#   step  4  MSE=0.0327  PSNR=14.85 dB  SSIM=0.2770
#   step  5  MSE=0.0326  PSNR=14.87 dB  SSIM=0.2762

# %% [markdown]
# ### Prediction Media Export
#
# `export_prediction_media_bundle` produces three files:
# - **`metrics_plot.png`** — MSE / PSNR / SSIM curves vs. imagination step.
# - **`comparison_grid.png`** — rows = steps, columns = Target | Predicted | Absolute Error (magma colormap).
# - **`comparison_video.gif`** — animated version of the grid at 2 fps.
#
# MSE should rise and PSNR should fall with step count. The error column highlights *where* in the frame prediction accuracy is weakest — bright regions around vehicle boundaries are expected; bright errors on empty road indicate decoder quality issues.

# %%
# ── Export side-by-side comparison media ─────────────────────────────────────
# Produces three artifacts per run:
#   metrics_plot     — PNG with per-step MSE / PSNR / SSIM curves
#   comparison_grid  — PNG with rows=steps, cols=(Target | Predicted | Error)
#   comparison_video — animated GIF showing the same layout over time (fps=2
#                      so each step is visible clearly)
from IPython.display import Image, display

pred_media = export_prediction_media_bundle(
    n_step_result['step_metrics'],
    n_step_result['predictions'],
    target_obs,
    RUN_ARTIFACT_ROOT / 'world_model_predictions',
    prefix=RUN_NAME,
    max_steps=EVAL_HORIZON,
    fps=2,
)

print('Exported prediction artifacts:')
for key, path in pred_media.items():
    print(f'  {key}: {path.name}')

print('\nPer-step metric curves (MSE / PSNR / SSIM vs imagination step):')
display(Image(filename=str(pred_media['metrics_plot'])))

print('\nComparison grid — Target | Predicted | Absolute Error per step:')
display(Image(filename=str(pred_media['comparison_grid'])))

print('\nPrediction GIF — animated Target | Predicted | Error:')
display(Image(filename=str(pred_media['comparison_video'])))
# Out:
# Exported prediction artifacts:
#   metrics_plot: final_run_001_metrics.png
#   comparison_grid: final_run_001_comparison.png
#   comparison_video: final_run_001_comparison.gif
#
# Per-step metric curves (MSE / PSNR / SSIM vs imagination step):
# Comparison grid — Target | Predicted | Absolute Error per step:
# Prediction GIF — animated Target | Predicted | Error:

# %% [markdown]
# ### Latent Rollout Consistency
#
# Measures how far the RSSM's **imagined** latent state drifts from the **observation-corrected posterior** state when the same actions are applied.
#
# Two paths from the same starting state:
# - **Grounded** — at every step the model receives the real observation and updates via the posterior.
# - **Imagined** — the model runs entirely via the prior, no observations after step 0.
#
# `latent_mse` in the table below is the feature-space MSE between these two paths at each step. Low drift means the prior has learned to stay close to what the posterior would be — which is what makes imagination-based planning reliable. The `free_nats = 3.0` threshold is the floor below which the training loss does not penalise prior–posterior divergence.

# %%
# ── Latent-space rollout consistency ─────────────────────────────────────────
# Measures how quickly the latent state drifts when the model rolls out purely
# in imagination (no observation correction).  Lower drift → tighter world model.
latent_result = evaluate_latent_rollout_consistency(
    world_model,
    seed_obs,
    future_actions,
    target_obs,
)

print('=== Latent Rollout Consistency ===')
print(f"Summary: {latent_result['summary']}")
print()
print(f"{'Step':>4}  {'Det MSE':>12}  {'Stoch MSE':>12}  {'Feature MSE':>12}  {'Prior-Post KL':>14}")
print('-' * 62)
for s in latent_result['step_metrics']:
    print(
        f"{int(s['step']):>4}  "
        f"{s['deterministic_mse']:>12.6f}  "
        f"{s['stochastic_mse']:>12.6f}  "
        f"{s['feature_mse']:>12.6f}  "
        f"{s['prior_posterior_kl']:>14.6f}"
    )
# Out:
# === Latent Rollout Consistency ===
# Summary: {'deterministic_mse_mean': 0.19067226052284242, 'stochastic_mse_mean': 77.04714762369791, 'feature_mse_mean': 10.215429210662842, 'prior_posterior_kl_mean': 6.413534005482991}
#
# Step       Det MSE     Stoch MSE   Feature MSE   Prior-Post KL
# --------------------------------------------------------------
#    1      0.000000     45.884998      5.984999        5.138072
#    2      0.077252    127.118332     16.647827        6.834618
#    3      0.165882     97.516403     12.863775        6.485307
#    4      0.197047    129.356339     17.043911        6.591878
#    5      0.210825     57.545040      7.689200        5.896423
#    6      0.193186     68.082237      9.048278        6.172748
#    7      0.214165     74.170982      9.860708        6.495634
#    8      0.229636     56.089375      7.515688        7.806956
#    9      0.209832     90.781906     12.023580        6.191458
#   10      0.248781     69.854019      9.327723        6.016844
#   11      0.231597     64.794357      8.652826        6.219131
#   12      0.215181     84.381149     11.193349        7.639864
#   13      0.225077     67.657036      9.020550        5.897947
#   14      0.229874     55.446056      7.431983        6.247363
#   15      0.211749     67.028984      8.927041        6.568767

# %% [markdown]
# ## 6 · Agent Driving Demo — Training Environment (Phase A)
#
# Record the trained actor in the **same 4-lane, 28-car environment it was trained in**. At inference the policy runs a real-time RSSM posterior loop: encode frame → observe step → actor mode (tanh of mean, not a sample) → smooth with previous action → scale and execute.
#
# 10 episodes, up to 400 steps each. A well-trained agent should accelerate in clear lanes, initiate lane changes ahead of blocked traffic, and avoid collisions.

# %%
from tiny_dreamer_highway.evaluation.policy_rollout import record_demo_videos
from IPython.display import Image, display

demo_output_dir = RUN_ARTIFACT_ROOT / 'demo_training_env'

demo_bundle = record_demo_videos(
    config=config,
    checkpoint_path=CKPT_PATH,
    output_dir=demo_output_dir,
    num_episodes=10,
    max_steps=400,
    fps=15,
    seed=42,
    prefix=f'{RUN_NAME}_train_env',
    device=DEVICE,
)

# DemoBundle fields: video_paths (list of Path), results (list of RolloutResult)
ep_rewards = [result.total_reward for result in demo_bundle.results]
ep_lengths = [result.steps for result in demo_bundle.results]

print(f'Episodes recorded : {len(demo_bundle.video_paths)}')
print(f'Mean reward       : {sum(ep_rewards)/len(ep_rewards):.3f}')
print(f'Mean episode len  : {sum(ep_lengths)/len(ep_lengths):.1f}')
print(f'Videos saved to   : {demo_output_dir}')

if demo_bundle.video_paths:
    # Display first episode GIF
    display(Image(filename=str(demo_bundle.video_paths[0])))
else:
    print('No demo GIFs were written; check env.render() / render_mode configuration.')
# Out:
# [demo] episode 1/10 | steps=76 | reward=44.93 | OK | saved final_run_001_train_env_ep01.gif
# [demo] episode 2/10 | steps=76 | reward=44.94 | OK | saved final_run_001_train_env_ep02.gif
# [demo] episode 3/10 | steps=75 | reward=43.36 | CRASH | saved final_run_001_train_env_ep03.gif
# [demo] episode 4/10 | steps=76 | reward=44.96 | OK | saved final_run_001_train_env_ep04.gif
# [demo] episode 5/10 | steps=76 | reward=44.97 | OK | saved final_run_001_train_env_ep05.gif
# [demo] episode 6/10 | steps=76 | reward=44.89 | OK | saved final_run_001_train_env_ep06.gif
# [demo] episode 7/10 | steps=76 | reward=44.94 | OK | saved final_run_001_train_env_ep07.gif
# [demo] episode 8/10 | steps=76 | reward=44.84 | OK | saved final_run_001_train_env_ep08.gif
# [demo] episode 9/10 | steps=76 | reward=44.95 | OK | saved final_run_001_train_env_ep09.gif
# [demo] episode 10/10 | steps=76 | reward=44.95 | OK | saved final_run_001_train_env_ep10.gif
# [demo] done | avg_reward=44.77 | summary=final_run_001_train_env_summary.json
# Episodes recorded : 10
# Mean reward       : 44.773
# Mean episode len  : 75.9
# Videos saved to   : /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/demo_training_env

# %% [markdown]
# ## 7 · Showcase Demo — 6 Lanes, 45 Cars (Phase B)
#
# Evaluate the **same checkpoint** in a harder environment not seen during training. No fine-tuning — the same weights are deployed directly. The observation is always a 64×64 image, so the CNN encoder processes wider roads the same way it processes the training layout; lane markings simply appear at different pixel positions.
#
# 5 episodes, up to 600 steps each. Some reward reduction compared to Phase A is expected due to denser traffic; qualitative behaviour (staying on road, overtaking) should remain intact.

# %%
from tiny_dreamer_highway.config import load_experiment_config

showcase_config = load_experiment_config(
    PROJECT_ROOT / 'examples' / 'final_showcase_eval.yaml'
)
print(f"Showcase env: {showcase_config.env.lanes_count} lanes, "
      f"{showcase_config.env.vehicles_count} vehicles")

showcase_output_dir = RUN_ARTIFACT_ROOT / 'demo_showcase_env'

showcase_bundle = record_demo_videos(
    config=showcase_config,
    checkpoint_path=CKPT_PATH,   # same weights as training-env demo
    output_dir=showcase_output_dir,
    num_episodes=5,
    max_steps=600,
    fps=15,
    seed=99,
    prefix=f'{RUN_NAME}_showcase',
    device=DEVICE,
)

sc_rewards = [result.total_reward for result in showcase_bundle.results]
sc_lengths = [result.steps for result in showcase_bundle.results]

print(f'\nShowcase Demo (6 lanes / 45 cars):')
print(f'  Episodes recorded : {len(showcase_bundle.video_paths)}')
print(f'  Mean reward       : {sum(sc_rewards)/len(sc_rewards):.3f}')
print(f'  Mean episode len  : {sum(sc_lengths)/len(sc_lengths):.1f}')
print(f'  Videos saved to   : {showcase_output_dir}')

if showcase_bundle.video_paths:
    display(Image(filename=str(showcase_bundle.video_paths[0])))
else:
    print('No showcase GIFs were written; check env.render() / render_mode configuration.')
# Out:
# Showcase env: 6 lanes, 45 vehicles
# [demo] episode 1/5 | steps=61 | reward=36.18 | OK | saved final_run_001_showcase_ep01.gif
# [demo] episode 2/5 | steps=61 | reward=36.17 | OK | saved final_run_001_showcase_ep02.gif
# [demo] episode 3/5 | steps=61 | reward=36.05 | OK | saved final_run_001_showcase_ep03.gif
# [demo] episode 4/5 | steps=61 | reward=36.18 | OK | saved final_run_001_showcase_ep04.gif
# [demo] episode 5/5 | steps=61 | reward=36.25 | OK | saved final_run_001_showcase_ep05.gif
# [demo] done | avg_reward=36.16 | summary=final_run_001_showcase_summary.json
#
# Showcase Demo (6 lanes / 45 cars):
#   Episodes recorded : 5
#   Mean reward       : 36.163
#   Mean episode len  : 61.0
#   Videos saved to   : /content/drive/MyDrive/CSC_580_Final_Project/artifacts/training_runs/final_run_001/demo_showcase_env

# %% [markdown]
# ## 8 · Submission Bundle
#
# `export_submission_bundle` copies all artifact files into a single directory and writes a `manifest.json` with the bundle name, file list, and any metadata passed in. `create_archive=True` additionally tars and gzips the directory.
#
# | Artifact | Description |
# |----------|-------------|
# | Training curves PNG | Multi-panel learning-curves figure |
# | Checkpoint | World model + actor + critic weights |
# | Comparison grid PNG | Target vs. predicted frames per step |
# | Prediction metrics plot | MSE / PSNR / SSIM curves |
# | Prediction GIF | Animated target / predicted / error |
# | Demo videos | Phase A (training env) and Phase B (showcase) first episodes |
# | JSON summaries | N-step summary, latent summary, episode stats |

# %%
from tiny_dreamer_highway.evaluation.artifact_bundle import export_submission_bundle
import json
import datetime

# ── Compute episode stats from DemoBundle.results ────────────────────────────
ep_rewards = [result.total_reward for result in demo_bundle.results]
sc_rewards = [result.total_reward for result in showcase_bundle.results]

# ── Write lightweight JSON sidecar summaries ──────────────────────────────────
summary_dir = RUN_ARTIFACT_ROOT / 'summaries'
summary_dir.mkdir(parents=True, exist_ok=True)

sidecars = {
    'n_step_summary.json': n_step_result['summary'],
    'latent_summary.json': latent_result['summary'],
    'demo_train_stats.json': {
        'num_episodes': len(demo_bundle.video_paths),
        'mean_reward': sum(ep_rewards) / len(ep_rewards),
        'rewards': ep_rewards,
    },
    'demo_showcase_stats.json': {
        'num_episodes': len(showcase_bundle.video_paths),
        'mean_reward': sum(sc_rewards) / len(sc_rewards),
        'rewards': sc_rewards,
    },
}
for fname, data in sidecars.items():
    (summary_dir / fname).write_text(json.dumps(data, indent=2, default=str))

# ── Bundle all artifacts ──────────────────────────────────────────────────────
# export_submission_bundle copies files and writes a manifest with bundle_name,
# files list, and optional metadata. No SHA digests are generated by default.
artifacts = {
    'training_curves': history_artifacts['curves'],
    'checkpoint': CKPT_PATH,
    'prediction_metrics_plot': pred_media['metrics_plot'],
    'comparison_grid': pred_media['comparison_grid'],
    'prediction_gif': pred_media['comparison_video'],
    'n_step_summary': summary_dir / 'n_step_summary.json',
    'latent_summary': summary_dir / 'latent_summary.json',
    'demo_train_stats': summary_dir / 'demo_train_stats.json',
    'demo_showcase_stats': summary_dir / 'demo_showcase_stats.json',
}
if demo_bundle.video_paths:
    artifacts['demo_train_ep0'] = demo_bundle.video_paths[0]
if showcase_bundle.video_paths:
    artifacts['demo_showcase_ep0'] = showcase_bundle.video_paths[0]

bundle_paths = export_submission_bundle(
    artifacts=artifacts,
    output_dir=DRIVE_ROOT / 'submission',
    bundle_name=f'csc580_final_{RUN_NAME}',
    metadata={
        'run_name': RUN_NAME,
        'timestamp': datetime.datetime.now().isoformat(),
        'lanes': config.env.lanes_count,
        'vehicles': config.env.vehicles_count,
        'n_step_summary': n_step_result['summary'],
        'latent_summary': latent_result['summary'],
        'demo_mean_reward': sum(ep_rewards) / len(ep_rewards),
        'showcase_mean_reward': sum(sc_rewards) / len(sc_rewards),
    },
    create_archive=True,
)

print('=== Submission Bundle ===')
for key, path in bundle_paths.items():
    print(f'  {key}: {path}')
print('\nUpload the .tar.gz to the class submission portal.')
# Out:
# === Submission Bundle ===
#   bundle_dir: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001
#   manifest: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/manifest.json
#   training_curves: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_curves.png
#   checkpoint: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/checkpoint_02000.pt
#   prediction_metrics_plot: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_metrics.png
#   comparison_grid: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_comparison.png
#   prediction_gif: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_comparison.gif
#   n_step_summary: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/n_step_summary.json
#   latent_summary: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/latent_summary.json
#   demo_train_stats: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/demo_train_stats.json
#   demo_showcase_stats: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/demo_showcase_stats.json
#   demo_train_ep0: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_train_env_ep01.gif
#   demo_showcase_ep0: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001/final_run_001_showcase_ep01.gif
#   archive: /content/drive/MyDrive/CSC_580_Final_Project/submission/csc580_final_final_run_001.zip
#
# Upload the .tar.gz to the class submission portal.
